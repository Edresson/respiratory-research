# %% [markdown]
# # Rede CNN - Modelo 2
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - Dataset 1 - slide10

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP_TRAIN = 'slide10'
GROUP_TEST = 'slide10'
DATASET = 'dataset_1'
DURATION = 10
SIZE = 431
CSV_TRAIN = 'train1.csv'
CSV_TEST = 'test1.csv'
MODEL_NAME = f'CNN2_{DATASET}_{GROUP_TRAIN}'

# %%
train_file_paths = glob.glob(f'../datasets/{DATASET}/{GROUP_TRAIN}/train/**/*.wav', recursive=True)
train_file_names = [os.path.splitext(os.path.basename(p))[0] for p in train_file_paths]

test_file_paths = glob.glob(f'../datasets/{DATASET}/{GROUP_TEST}/test/**/*.wav', recursive=True)
test_file_names = [os.path.splitext(os.path.basename(p))[0] for p in test_file_paths]

# %%
train_p_id_in_file = [] # patient IDs corresponding to each file
test_p_id_in_file = [] # patient IDs corresponding to each file
for name in train_file_names:
    train_p_id_in_file.append(int(name[:3]))

for name in test_file_names:
    test_p_id_in_file.append(int(name[:3]))

train_p_id_in_file = np.array(train_p_id_in_file)
test_p_id_in_file = np.array(test_p_id_in_file)

# %%
max_pad_len = SIZE

os.makedirs("features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=DURATION) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
train_p_diag = pd.read_csv(f"../Respiratory_Sound_Database/Respiratory_Sound_Database_Pneumo_Healthy_Only/{CSV_TRAIN}", header=None) # patient diagnosis file
test_p_diag = pd.read_csv(f"../Respiratory_Sound_Database/Respiratory_Sound_Database_Pneumo_Healthy_Only/{CSV_TEST}", header=None) # patient diagnosis file
train_p_diag.head(5)
# Out:
#      0        1
# 0  102  Healthy
# 1  121  Healthy
# 2  123  Healthy
# 3  125  Healthy
# 4  126  Healthy

# %%
train_labels = np.array([train_p_diag[train_p_diag[0] == x][1].values[0] for x in train_p_id_in_file]) 
test_labels = np.array([test_p_diag[test_p_diag[0] == x][1].values[0] for x in test_p_id_in_file])

# %%
train_features = [] 
test_features = []

for file_name in train_file_paths:
    data = extract_features(file_name)
    train_features.append(data)

for file_name in test_file_paths:
    data = extract_features(file_name)
    test_features.append(data)

print('Finished feature extraction from ', (len(train_features)+len(train_features)), ' files')
train_features = np.array(train_features)
test_features = np.array(test_features)
# Out:
# Finished feature extraction from  976  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(train_features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
np.unique(train_labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
unique_elements, counts_elements = np.unique(train_labels, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))

unique_elements_test, counts_elements_test = np.unique(test_labels, return_counts=True)
print(np.asarray((unique_elements_test, counts_elements_test)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['256' '232']]
# [['Healthy' 'Pneumonia']
#  ['24' '64']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %% [markdown]
# __Balanceando dados__

# %%
def balance_data(X, labels):
    """Balances data duplicating some instances of the minority classes"""
    balX = None
    baly = None
    unique, counts = np.unique(labels, return_counts=True)
    max_inst = max(counts)
    # For every class duplicate the necessary amount
    for label in unique:
        data_of_label = []
        for x, y in zip(X, labels):
            if y == label:
                data_of_label.append(x)
        data_of_label = np.asarray(data_of_label)
        extra = data_of_label[np.random.choice(data_of_label.shape[0],
                                               max_inst,
                                               replace=True), :]
        if balX is not None:
            balX = np.stack((balX, extra), axis = 0) 
            baly = np.stack((baly, np.asarray([label for i in range(len(extra))])))
        else:
            balX = extra
            baly = np.asarray([label for i in range(len(extra))])
    balX = np.concatenate(balX)
    baly = np.concatenate(baly)
    return balX, baly

# %%
train_features, train_labels = balance_data(train_features, train_labels)
test_features, test_labels = balance_data(test_features, test_labels)

# %%
unique_elements, counts_elements = np.unique(train_labels, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))

unique_elements_test, counts_elements_test = np.unique(test_labels, return_counts=True)
print(np.asarray((unique_elements_test, counts_elements_test)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['256' '256']]
# [['Healthy' 'Pneumonia']
#  ['64' '64']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
le.fit(train_labels)
train_labels_cat = to_categorical(le.transform(train_labels)) 
test_labels_cat = to_categorical(le.transform(test_labels))

# %%
train_features.shape
# Out:
# (512, 40, 431)

# %%
train_features = np.reshape(train_features, (*train_features.shape,1)) 
print(train_features.shape, train_labels_cat.shape)
test_features = np.reshape(test_features, (*test_features.shape,1)) 
print(test_features.shape, test_labels_cat.shape)
# Out:
# (512, 40, 431, 1) (512, 2)
# (128, 40, 431, 1) (128, 2)

# %%
x_test, y_test = test_features, test_labels_cat
x_train, y_train = train_features, train_labels_cat

# %% [markdown]
# **CNN model architecture**

# %%
num_labels = train_labels_cat.shape[1]

num_rows = 40
num_columns = SIZE
num_channels = 1

filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(Conv2D(filters=16, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(Conv2D(filters=8, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(Conv2D(filters=4, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 430, 32)       160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 215, 32)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 215, 32)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 214, 16)       2064
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 107, 16)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 107, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 106, 8)         520
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 53, 8)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 53, 8)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 52, 4)          132
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 26, 4)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 26, 4)          0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 4)                 0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 10
# =================================================================
# Total params: 2,886
# Trainable params: 2,886
# Non-trainable params: 0
# _________________________________________________________________
# 128/128 [==============================] - 1s 9ms/sample - loss: 3.0260 - accuracy: 0.5000
# Pre-training accuracy: 50.0000%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 500
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/' + MODEL_NAME + '_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 512 samples, validate on 128 samples
# Epoch 1/500
# 480/512 [===========================>..] - ETA: 0s - loss: 3.8974 - accuracy: 0.4792
# Epoch 00001: val_accuracy improved from -inf to 0.50000, saving model to models/CNN2_dataset_1_slide10_01.h5
# 512/512 [==============================] - 2s 3ms/sample - loss: 3.7102 - accuracy: 0.4824 - val_loss: 0.8322 - val_accuracy: 0.5000
# Epoch 2/500
# 510/512 [============================>.] - ETA: 0s - loss: 0.8017 - accuracy: 0.5725
# Epoch 00002: val_accuracy did not improve from 0.50000
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.7995 - accuracy: 0.5742 - val_loss: 0.6854 - val_accuracy: 0.5000
# Epoch 3/500
# 480/512 [===========================>..] - ETA: 0s - loss: 0.7248 - accuracy: 0.5771
# Epoch 00003: val_accuracy did not improve from 0.50000
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.7209 - accuracy: 0.5801 - val_loss: 0.6871 - val_accuracy: 0.5000
# Epoch 4/500
# 480/512 [===========================>..] - ETA: 0s - loss: 0.6578 - accuracy: 0.6271
# Epoch 00004: val_accuracy did not improve from 0.50000
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.6500 - accuracy: 0.6348 - val_loss: 0.6866 - val_accuracy: 0.5000
# Epoch 5/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.5962 - accuracy: 0.6468
# Epoch 00005: val_accuracy did not improve from 0.50000
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.5930 - accuracy: 0.6504 - val_loss: 0.6882 - val_accuracy: 0.5000
# Epoch 6/500
# 490/512 [===========================>..] - ETA: 0s - loss: 0.5389 - accuracy: 0.7143
# Epoch 00006: val_accuracy did not improve from 0.50000
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.5406 - accuracy: 0.7148 - val_loss: 0.6929 - val_accuracy: 0.5000
# Epoch 7/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.5238 - accuracy: 0.7383
# Epoch 00007: val_accuracy did not improve from 0.50000
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.5201 - accuracy: 0.7344 - val_loss: 0.6749 - val_accuracy: 0.5000
# Epoch 8/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.5039 - accuracy: 0.7511
# Epoch 00008: val_accuracy improved from 0.50000 to 0.51562, saving model to models/CNN2_dataset_1_slide10_08.h5
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.5004 - accuracy: 0.7461 - val_loss: 0.6634 - val_accuracy: 0.5156
# Epoch 9/500
# 490/512 [===========================>..] - ETA: 0s - loss: 0.5191 - accuracy: 0.7429
# Epoch 00009: val_accuracy did not improve from 0.51562
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.5165 - accuracy: 0.7461 - val_loss: 0.6664 - val_accuracy: 0.5156
# Epoch 10/500
# 510/512 [============================>.] - ETA: 0s - loss: 0.4702 - accuracy: 0.7765
# Epoch 00010: val_accuracy improved from 0.51562 to 0.57812, saving model to models/CNN2_dataset_1_slide10_10.h5
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.4699 - accuracy: 0.7773 - val_loss: 0.6607 - val_accuracy: 0.5781
# Epoch 11/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.4235 - accuracy: 0.8106
# Epoch 00011: val_accuracy improved from 0.57812 to 0.68750, saving model to models/CNN2_dataset_1_slide10_11.h5
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.4199 - accuracy: 0.8125 - val_loss: 0.6397 - val_accuracy: 0.6875
# Epoch 12/500
# 490/512 [===========================>..] - ETA: 0s - loss: 0.4212 - accuracy: 0.8143
# Epoch 00012: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.4175 - accuracy: 0.8145 - val_loss: 0.6455 - val_accuracy: 0.6250
# Epoch 13/500
# 510/512 [============================>.] - ETA: 0s - loss: 0.3600 - accuracy: 0.8431
# Epoch 00013: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.3587 - accuracy: 0.8438 - val_loss: 0.6508 - val_accuracy: 0.5938
# Epoch 14/500
# 510/512 [============================>.] - ETA: 0s - loss: 0.3502 - accuracy: 0.8490
# Epoch 00014: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.3514 - accuracy: 0.8477 - val_loss: 0.6888 - val_accuracy: 0.3359
# Epoch 15/500
# 510/512 [============================>.] - ETA: 0s - loss: 0.3849 - accuracy: 0.8294
# Epoch 00015: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.3861 - accuracy: 0.8281 - val_loss: 0.6704 - val_accuracy: 0.5312
# Epoch 16/500
# 510/512 [============================>.] - ETA: 0s - loss: 0.3367 - accuracy: 0.8529
# Epoch 00016: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.3363 - accuracy: 0.8535 - val_loss: 0.6699 - val_accuracy: 0.5469
# Epoch 17/500
# 490/512 [===========================>..] - ETA: 0s - loss: 0.2621 - accuracy: 0.8939
# Epoch 00017: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.2703 - accuracy: 0.8867 - val_loss: 0.6943 - val_accuracy: 0.4297
# Epoch 18/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.2955 - accuracy: 0.8681
# Epoch 00018: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.2995 - accuracy: 0.8672 - val_loss: 0.6930 - val_accuracy: 0.5312
# Epoch 19/500
# 490/512 [===========================>..] - ETA: 0s - loss: 0.2796 - accuracy: 0.8776
# Epoch 00019: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.2734 - accuracy: 0.8828 - val_loss: 0.8469 - val_accuracy: 0.3281
# Epoch 20/500
# 500/512 [============================>.] - ETA: 0s - loss: 0.2561 - accuracy: 0.8740
# Epoch 00020: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.2548 - accuracy: 0.8750 - val_loss: 0.8037 - val_accuracy: 0.3438
# Epoch 21/500
# 510/512 [============================>.] - ETA: 0s - loss: 0.2247 - accuracy: 0.9039
# Epoch 00021: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.2239 - accuracy: 0.9043 - val_loss: 0.7857 - val_accuracy: 0.3594
# Epoch 22/500
# 490/512 [===========================>..] - ETA: 0s - loss: 0.2334 - accuracy: 0.9000
# Epoch 00022: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.2306 - accuracy: 0.9004 - val_loss: 0.7557 - val_accuracy: 0.5625
# Epoch 23/500
# 480/512 [===========================>..] - ETA: 0s - loss: 0.2628 - accuracy: 0.9000
# Epoch 00023: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.2549 - accuracy: 0.9023 - val_loss: 0.8395 - val_accuracy: 0.3438
# Epoch 24/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.2114 - accuracy: 0.9000
# Epoch 00024: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.2081 - accuracy: 0.9023 - val_loss: 0.7555 - val_accuracy: 0.5156
# Epoch 25/500
# 500/512 [============================>.] - ETA: 0s - loss: 0.2276 - accuracy: 0.9120
# Epoch 00025: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.2233 - accuracy: 0.9141 - val_loss: 0.7592 - val_accuracy: 0.5391
# Epoch 26/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.2025 - accuracy: 0.9128
# Epoch 00026: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.2038 - accuracy: 0.9141 - val_loss: 0.8687 - val_accuracy: 0.3203
# Epoch 27/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.1926 - accuracy: 0.9255
# Epoch 00027: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.2103 - accuracy: 0.9160 - val_loss: 0.8318 - val_accuracy: 0.3359
# Epoch 28/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.2075 - accuracy: 0.9043
# Epoch 00028: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.2050 - accuracy: 0.9043 - val_loss: 0.8036 - val_accuracy: 0.4688
# Epoch 29/500
# 510/512 [============================>.] - ETA: 0s - loss: 0.1905 - accuracy: 0.9157
# Epoch 00029: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.1899 - accuracy: 0.9160 - val_loss: 0.8193 - val_accuracy: 0.4453
# Epoch 30/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.1818 - accuracy: 0.9298
# Epoch 00030: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.1859 - accuracy: 0.9297 - val_loss: 0.8409 - val_accuracy: 0.3125
# Epoch 31/500
# 460/512 [=========================>....] - ETA: 0s - loss: 0.1964 - accuracy: 0.9326
# Epoch 00031: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.1914 - accuracy: 0.9355 - val_loss: 0.8995 - val_accuracy: 0.3281
# Epoch 32/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.1632 - accuracy: 0.9362
# Epoch 00032: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.1928 - accuracy: 0.9258 - val_loss: 0.7978 - val_accuracy: 0.5000
# Epoch 33/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.1890 - accuracy: 0.9362
# Epoch 00033: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.1867 - accuracy: 0.9316 - val_loss: 0.8522 - val_accuracy: 0.3281
# Epoch 34/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.1509 - accuracy: 0.9404
# Epoch 00034: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.1490 - accuracy: 0.9414 - val_loss: 0.8545 - val_accuracy: 0.3984
# Epoch 35/500
# 490/512 [===========================>..] - ETA: 0s - loss: 0.1517 - accuracy: 0.9469
# Epoch 00035: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.1539 - accuracy: 0.9453 - val_loss: 0.8732 - val_accuracy: 0.4844
# Epoch 36/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.1882 - accuracy: 0.9298
# Epoch 00036: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.1865 - accuracy: 0.9277 - val_loss: 0.8340 - val_accuracy: 0.5000
# Epoch 37/500
# 460/512 [=========================>....] - ETA: 0s - loss: 0.1631 - accuracy: 0.9239
# Epoch 00037: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.1705 - accuracy: 0.9180 - val_loss: 0.8265 - val_accuracy: 0.4922
# Epoch 38/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.1481 - accuracy: 0.9383
# Epoch 00038: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.1453 - accuracy: 0.9395 - val_loss: 0.9604 - val_accuracy: 0.3203
# Epoch 39/500
# 510/512 [============================>.] - ETA: 0s - loss: 0.1581 - accuracy: 0.9392
# Epoch 00039: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.1578 - accuracy: 0.9395 - val_loss: 0.8685 - val_accuracy: 0.4844
# Epoch 40/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.1694 - accuracy: 0.9255
# Epoch 00040: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.1603 - accuracy: 0.9316 - val_loss: 0.8349 - val_accuracy: 0.5391
# Epoch 41/500
# 480/512 [===========================>..] - ETA: 0s - loss: 0.1298 - accuracy: 0.9583
# Epoch 00041: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.1318 - accuracy: 0.9570 - val_loss: 0.9074 - val_accuracy: 0.4062
# Epoch 42/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.1736 - accuracy: 0.9277
# Epoch 00042: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.1726 - accuracy: 0.9277 - val_loss: 0.9258 - val_accuracy: 0.4688
# Epoch 43/500
# 480/512 [===========================>..] - ETA: 0s - loss: 0.1561 - accuracy: 0.9250
# Epoch 00043: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.1545 - accuracy: 0.9277 - val_loss: 0.9209 - val_accuracy: 0.4062
# Epoch 44/500
# 460/512 [=========================>....] - ETA: 0s - loss: 0.1142 - accuracy: 0.9674
# Epoch 00044: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.1175 - accuracy: 0.9668 - val_loss: 1.0331 - val_accuracy: 0.3203
# Epoch 45/500
# 490/512 [===========================>..] - ETA: 0s - loss: 0.1264 - accuracy: 0.9449
# Epoch 00045: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.1274 - accuracy: 0.9434 - val_loss: 0.8823 - val_accuracy: 0.4922
# Epoch 46/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.1282 - accuracy: 0.9383
# Epoch 00046: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.1298 - accuracy: 0.9395 - val_loss: 0.9244 - val_accuracy: 0.5000
# Epoch 47/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.1247 - accuracy: 0.9553
# Epoch 00047: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.1352 - accuracy: 0.9512 - val_loss: 0.8588 - val_accuracy: 0.6016
# Epoch 48/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.1517 - accuracy: 0.9298
# Epoch 00048: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.1576 - accuracy: 0.9277 - val_loss: 0.8735 - val_accuracy: 0.4922
# Epoch 49/500
# 460/512 [=========================>....] - ETA: 0s - loss: 0.1375 - accuracy: 0.9478
# Epoch 00049: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.1487 - accuracy: 0.9414 - val_loss: 0.8042 - val_accuracy: 0.6094
# Epoch 50/500
# 500/512 [============================>.] - ETA: 0s - loss: 0.1300 - accuracy: 0.9560
# Epoch 00050: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.1284 - accuracy: 0.9570 - val_loss: 0.8533 - val_accuracy: 0.6016
# Epoch 51/500
# 510/512 [============================>.] - ETA: 0s - loss: 0.1088 - accuracy: 0.9529
# Epoch 00051: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.1085 - accuracy: 0.9531 - val_loss: 0.9215 - val_accuracy: 0.6172
# Epoch 52/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.1324 - accuracy: 0.9511
# Epoch 00052: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.1317 - accuracy: 0.9531 - val_loss: 0.9826 - val_accuracy: 0.5391
# Epoch 53/500
# 490/512 [===========================>..] - ETA: 0s - loss: 0.1296 - accuracy: 0.9449
# Epoch 00053: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.1250 - accuracy: 0.9473 - val_loss: 1.0542 - val_accuracy: 0.5078
# Epoch 54/500
# 510/512 [============================>.] - ETA: 0s - loss: 0.1288 - accuracy: 0.9412
# Epoch 00054: val_accuracy did not improve from 0.68750
# 512/512 [==============================] - 1s 1ms/sample - loss: 0
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0202 - accuracy: 0.9883 - val_loss: 3.0357 - val_accuracy: 0.6953
# Epoch 448/500
# 510/512 [============================>.] - ETA: 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 00448: val_accuracy did not improve from 0.79688
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0042 - accuracy: 1.0000 - val_loss: 2.7719 - val_accuracy: 0.7500
# Epoch 449/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.0164 - accuracy: 0.9936
# Epoch 00449: val_accuracy did not improve from 0.79688
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0160 - accuracy: 0.9941 - val_loss: 2.3025 - val_accuracy: 0.6328
# Epoch 450/500
# 510/512 [============================>.] - ETA: 0s - loss: 0.0190 - accuracy: 0.9941
# Epoch 00450: val_accuracy did not improve from 0.79688
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0189 - accuracy: 0.9941 - val_loss: 2.0269 - val_accuracy: 0.6719
# Epoch 451/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 00451: val_accuracy did not improve from 0.79688
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.0249 - val_accuracy: 0.6875
# Epoch 452/500
# 510/512 [============================>.] - ETA: 0s - loss: 0.0103 - accuracy: 0.9980
# Epoch 00452: val_accuracy did not improve from 0.79688
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0103 - accuracy: 0.9980 - val_loss: 2.7907 - val_accuracy: 0.6953
# Epoch 453/500
# 510/512 [============================>.] - ETA: 0s - loss: 0.0176 - accuracy: 0.9922
# Epoch 00453: val_accuracy did not improve from 0.79688
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0176 - accuracy: 0.9922 - val_loss: 1.8833 - val_accuracy: 0.6875
# Epoch 454/500
# 510/512 [============================>.] - ETA: 0s - loss: 0.0226 - accuracy: 0.9922
# Epoch 00454: val_accuracy did not improve from 0.79688
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0225 - accuracy: 0.9922 - val_loss: 2.1170 - val_accuracy: 0.7500
# Epoch 455/500
# 510/512 [============================>.] - ETA: 0s - loss: 0.0049 - accuracy: 0.9980
# Epoch 00455: val_accuracy did not improve from 0.79688
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0049 - accuracy: 0.9980 - val_loss: 2.1816 - val_accuracy: 0.7031
# Epoch 456/500
# 510/512 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 00456: val_accuracy did not improve from 0.79688
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0019 - accuracy: 1.0000 - val_loss: 2.5665 - val_accuracy: 0.7188
# Epoch 457/500
# 480/512 [===========================>..] - ETA: 0s - loss: 0.0306 - accuracy: 0.9896
# Epoch 00457: val_accuracy did not improve from 0.79688
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0287 - accuracy: 0.9902 - val_loss: 2.1193 - val_accuracy: 0.7188
# Epoch 458/500
# 500/512 [============================>.] - ETA: 0s - loss: 0.0126 - accuracy: 0.9940
# Epoch 00458: val_accuracy did not improve from 0.79688
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0123 - accuracy: 0.9941 - val_loss: 2.0233 - val_accuracy: 0.6484
# Epoch 459/500
# 490/512 [===========================>..] - ETA: 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 00459: val_accuracy did not improve from 0.79688
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0032 - accuracy: 1.0000 - val_loss: 2.2301 - val_accuracy: 0.7578
# Epoch 460/500
# 500/512 [============================>.] - ETA: 0s - loss: 0.0159 - accuracy: 0.9940
# Epoch 00460: val_accuracy did not improve from 0.79688
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0157 - accuracy: 0.9941 - val_loss: 1.6388 - val_accuracy: 0.7656
# Epoch 461/500
# 480/512 [===========================>..] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 00461: val_accuracy did not improve from 0.79688
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.3476 - val_accuracy: 0.7812
# Epoch 462/500
# 510/512 [============================>.] - ETA: 0s - loss: 0.0080 - accuracy: 0.9941
# Epoch 00462: val_accuracy did not improve from 0.79688
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0080 - accuracy: 0.9941 - val_loss: 1.2933 - val_accuracy: 0.7500
# Epoch 463/500
# 500/512 [============================>.] - ETA: 0s - loss: 0.0152 - accuracy: 0.9940
# Epoch 00463: val_accuracy did not improve from 0.79688
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0148 - accuracy: 0.9941 - val_loss: 2.1579 - val_accuracy: 0.6328
# Epoch 464/500
# 490/512 [===========================>..] - ETA: 0s - loss: 0.0116 - accuracy: 0.9939
# Epoch 00464: val_accuracy did not improve from 0.79688
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0231 - accuracy: 0.9902 - val_loss: 1.6356 - val_accuracy: 0.7344
# Epoch 465/500
# 500/512 [============================>.] - ETA: 0s - loss: 0.0132 - accuracy: 0.9960
# Epoch 00465: val_accuracy did not improve from 0.79688
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0130 - accuracy: 0.9961 - val_loss: 1.0426 - val_accuracy: 0.7344
# Epoch 466/500
# 480/512 [===========================>..] - ETA: 0s - loss: 0.0057 - accuracy: 0.9979
# Epoch 00466: val_accuracy improved from 0.79688 to 0.80469, saving model to models/CNN2_dataset_1_slide10_466.h5
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0053 - accuracy: 0.9980 - val_loss: 1.6938 - val_accuracy: 0.8047
# Epoch 467/500
# 460/512 [=========================>....] - ETA: 0s - loss: 0.0414 - accuracy: 0.9804
# Epoch 00467: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0374 - accuracy: 0.9824 - val_loss: 1.3985 - val_accuracy: 0.7734
# Epoch 468/500
# 490/512 [===========================>..] - ETA: 0s - loss: 0.0087 - accuracy: 0.9959
# Epoch 00468: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0084 - accuracy: 0.9961 - val_loss: 1.3666 - val_accuracy: 0.7188
# Epoch 469/500
# 500/512 [============================>.] - ETA: 0s - loss: 0.0106 - accuracy: 0.9940
# Epoch 00469: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0104 - accuracy: 0.9941 - val_loss: 1.6723 - val_accuracy: 0.7578
# Epoch 470/500
# 490/512 [===========================>..] - ETA: 0s - loss: 0.0268 - accuracy: 0.9898
# Epoch 00470: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0256 - accuracy: 0.9902 - val_loss: 1.7085 - val_accuracy: 0.6562
# Epoch 471/500
# 490/512 [===========================>..] - ETA: 0s - loss: 0.0221 - accuracy: 0.9898
# Epoch 00471: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0213 - accuracy: 0.9902 - val_loss: 2.0204 - val_accuracy: 0.7188
# Epoch 472/500
# 500/512 [============================>.] - ETA: 0s - loss: 0.0173 - accuracy: 0.9900
# Epoch 00472: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0169 - accuracy: 0.9902 - val_loss: 1.5281 - val_accuracy: 0.6797
# Epoch 473/500
# 460/512 [=========================>....] - ETA: 0s - loss: 0.0027 - accuracy: 1.0000
# Epoch 00473: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0073 - accuracy: 0.9980 - val_loss: 2.1041 - val_accuracy: 0.6719
# Epoch 474/500
# 500/512 [============================>.] - ETA: 0s - loss: 0.0060 - accuracy: 0.9980
# Epoch 00474: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0058 - accuracy: 0.9980 - val_loss: 1.9283 - val_accuracy: 0.6797
# Epoch 475/500
# 510/512 [============================>.] - ETA: 0s - loss: 0.0061 - accuracy: 0.9961
# Epoch 00475: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0060 - accuracy: 0.9961 - val_loss: 1.6076 - val_accuracy: 0.7031
# Epoch 476/500
# 500/512 [============================>.] - ETA: 0s - loss: 0.0083 - accuracy: 0.9960
# Epoch 00476: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0105 - accuracy: 0.9961 - val_loss: 1.5924 - val_accuracy: 0.6562
# Epoch 477/500
# 510/512 [============================>.] - ETA: 0s - loss: 0.0087 - accuracy: 0.9980
# Epoch 00477: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0087 - accuracy: 0.9980 - val_loss: 2.9121 - val_accuracy: 0.6406
# Epoch 478/500
# 480/512 [===========================>..] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 00478: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.6214 - val_accuracy: 0.7344
# Epoch 479/500
# 500/512 [============================>.] - ETA: 0s - loss: 0.0108 - accuracy: 0.9940
# Epoch 00479: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0109 - accuracy: 0.9941 - val_loss: 1.8691 - val_accuracy: 0.7188
# Epoch 480/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.1072 - accuracy: 0.9660
# Epoch 00480: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0985 - accuracy: 0.9688 - val_loss: 2.3778 - val_accuracy: 0.6875
# Epoch 481/500
# 500/512 [============================>.] - ETA: 0s - loss: 0.0088 - accuracy: 0.9980
# Epoch 00481: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0086 - accuracy: 0.9980 - val_loss: 2.1502 - val_accuracy: 0.7031
# Epoch 482/500
# 480/512 [===========================>..] - ETA: 0s - loss: 0.0100 - accuracy: 0.9937
# Epoch 00482: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0094 - accuracy: 0.9941 - val_loss: 2.0749 - val_accuracy: 0.6875
# Epoch 483/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.0178 - accuracy: 0.9915
# Epoch 00483: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0166 - accuracy: 0.9922 - val_loss: 2.3379 - val_accuracy: 0.7031
# Epoch 484/500
# 500/512 [============================>.] - ETA: 0s - loss: 0.0129 - accuracy: 0.9960
# Epoch 00484: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0126 - accuracy: 0.9961 - val_loss: 1.6070 - val_accuracy: 0.8047
# Epoch 485/500
# 500/512 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 1.0000
# Epoch 00485: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0060 - accuracy: 1.0000 - val_loss: 2.0298 - val_accuracy: 0.7969
# Epoch 486/500
# 480/512 [===========================>..] - ETA: 0s - loss: 0.0083 - accuracy: 0.9979
# Epoch 00486: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0078 - accuracy: 0.9980 - val_loss: 2.1084 - val_accuracy: 0.7500
# Epoch 487/500
# 510/512 [============================>.] - ETA: 0s - loss: 0.0163 - accuracy: 0.9902
# Epoch 00487: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0163 - accuracy: 0.9902 - val_loss: 2.0883 - val_accuracy: 0.8047
# Epoch 488/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.0029 - accuracy: 0.9979
# Epoch 00488: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0027 - accuracy: 0.9980 - val_loss: 1.8261 - val_accuracy: 0.8047
# Epoch 489/500
# 470/512 [==========================>...] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 00489: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0018 - accuracy: 1.0000 - val_loss: 2.1805 - val_accuracy: 0.7578
# Epoch 490/500
# 500/512 [============================>.] - ETA: 0s - loss: 0.0049 - accuracy: 0.9980
# Epoch 00490: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0048 - accuracy: 0.9980 - val_loss: 2.1639 - val_accuracy: 0.7656
# Epoch 491/500
# 500/512 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 0.9920
# Epoch 00491: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0240 - accuracy: 0.9922 - val_loss: 2.3946 - val_accuracy: 0.7344
# Epoch 492/500
# 510/512 [============================>.] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 00492: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0038 - accuracy: 1.0000 - val_loss: 2.1076 - val_accuracy: 0.7422
# Epoch 493/500
# 500/512 [============================>.] - ETA: 0s - loss: 0.0065 - accuracy: 0.9980
# Epoch 00493: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0063 - accuracy: 0.9980 - val_loss: 2.0969 - val_accuracy: 0.7812
# Epoch 494/500
# 500/512 [============================>.] - ETA: 0s - loss: 0.0109 - accuracy: 0.9940
# Epoch 00494: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0107 - accuracy: 0.9941 - val_loss: 2.0035 - val_accuracy: 0.7266
# Epoch 495/500
# 510/512 [============================>.] - ETA: 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 00495: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0032 - accuracy: 1.0000 - val_loss: 2.7452 - val_accuracy: 0.7109
# Epoch 496/500
# 490/512 [===========================>..] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 00496: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0027 - accuracy: 1.0000 - val_loss: 2.4375 - val_accuracy: 0.7578
# Epoch 497/500
# 490/512 [===========================>..] - ETA: 0s - loss: 8.4116e-04 - accuracy: 1.0000
# Epoch 00497: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 8.4554e-04 - accuracy: 1.0000 - val_loss: 2.1291 - val_accuracy: 0.7656
# Epoch 498/500
# 490/512 [===========================>..] - ETA: 0s - loss: 0.0027 - accuracy: 0.9980
# Epoch 00498: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0027 - accuracy: 0.9980 - val_loss: 2.0860 - val_accuracy: 0.7578
# Epoch 499/500
# 490/512 [===========================>..] - ETA: 0s - loss: 0.0451 - accuracy: 0.9878
# Epoch 00499: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0434 - accuracy: 0.9883 - val_loss: 2.9195 - val_accuracy: 0.5703
# Epoch 500/500
# 460/512 [=========================>....] - ETA: 0s - loss: 0.0111 - accuracy: 0.9935
# Epoch 00500: val_accuracy did not improve from 0.80469
# 512/512 [==============================] - 1s 1ms/sample - loss: 0.0100 - accuracy: 0.9941 - val_loss: 1.7189 - val_accuracy: 0.7969
# Training completed in time:  0:04:56.460659

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
train_acc = score[1]
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
test_acc = score[1]
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  1.0
# Testing Accuracy:  0.796875

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.72      0.98      0.83        64
#    Pneumonia       0.97      0.61      0.75        64
#
#     accuracy                           0.80       128
#    macro avg       0.85      0.80      0.79       128
# weighted avg       0.85      0.80      0.79       128

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[63  1]
#  [25 39]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap='plasma'):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 1.4
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] < thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])

# %% [markdown]
# __Write CSV__

# %%
with open('report.csv', 'a') as report:
    report.write(f'{MODEL_NAME},{DATASET},{GROUP_TRAIN},{DURATION},{train_acc},{test_acc}\n')
