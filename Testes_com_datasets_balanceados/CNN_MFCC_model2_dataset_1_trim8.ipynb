# %% [markdown]
# # Rede CNN - Modelo 2
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - Dataset 1 - trim8

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP_TRAIN = 'trim8'
GROUP_TEST = 'trim8'
DATASET = 'dataset_1'
DURATION = 8
SIZE = 345
CSV_TRAIN = 'train1.csv'
CSV_TEST = 'test1.csv'
MODEL_NAME = f'CNN2_{DATASET}_{GROUP_TRAIN}'

# %%
train_file_paths = glob.glob(f'../datasets/{DATASET}/{GROUP_TRAIN}/train/**/*.wav', recursive=True)
train_file_names = [os.path.splitext(os.path.basename(p))[0] for p in train_file_paths]

test_file_paths = glob.glob(f'../datasets/{DATASET}/{GROUP_TEST}/test/**/*.wav', recursive=True)
test_file_names = [os.path.splitext(os.path.basename(p))[0] for p in test_file_paths]

# %%
train_p_id_in_file = [] # patient IDs corresponding to each file
test_p_id_in_file = [] # patient IDs corresponding to each file
for name in train_file_names:
    train_p_id_in_file.append(int(name[:3]))

for name in test_file_names:
    test_p_id_in_file.append(int(name[:3]))

train_p_id_in_file = np.array(train_p_id_in_file)
test_p_id_in_file = np.array(test_p_id_in_file)

# %%
max_pad_len = SIZE

os.makedirs("features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=DURATION) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        print(e)
        return None 
    np.save(os.path.join("./features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
train_p_diag = pd.read_csv(f"../Respiratory_Sound_Database/Respiratory_Sound_Database_Pneumo_Healthy_Only/{CSV_TRAIN}", header=None) # patient diagnosis file
test_p_diag = pd.read_csv(f"../Respiratory_Sound_Database/Respiratory_Sound_Database_Pneumo_Healthy_Only/{CSV_TEST}", header=None) # patient diagnosis file
train_p_diag.head(5)
# Out:
#      0        1
# 0  102  Healthy
# 1  121  Healthy
# 2  123  Healthy
# 3  125  Healthy
# 4  126  Healthy

# %%
train_labels = np.array([train_p_diag[train_p_diag[0] == x][1].values[0] for x in train_p_id_in_file]) 
test_labels = np.array([test_p_diag[test_p_diag[0] == x][1].values[0] for x in test_p_id_in_file])

# %%
train_features = [] 
test_features = []

for file_name in train_file_paths:
    data = extract_features(file_name)
    train_features.append(data)

for file_name in test_file_paths:
    data = extract_features(file_name)
    test_features.append(data)

print('Finished feature extraction from ', (len(train_features)+len(train_features)), ' files')
train_features = np.array(train_features)
test_features = np.array(test_features)
# Out:
# Finished feature extraction from  244  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(train_features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
np.unique(train_labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
unique_elements, counts_elements = np.unique(train_labels, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))

unique_elements_test, counts_elements_test = np.unique(test_labels, return_counts=True)
print(np.asarray((unique_elements_test, counts_elements_test)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['64' '58']]
# [['Healthy' 'Pneumonia']
#  ['6' '16']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %% [markdown]
# __Balanceando dados__

# %%
def balance_data(X, labels):
    """Balances data duplicating some instances of the minority classes"""
    balX = None
    baly = None
    unique, counts = np.unique(labels, return_counts=True)
    max_inst = max(counts)
    # For every class duplicate the necessary amount
    for label in unique:
        data_of_label = []
        for x, y in zip(X, labels):
            if y == label:
                data_of_label.append(x)
        data_of_label = np.asarray(data_of_label)
        extra = data_of_label[np.random.choice(data_of_label.shape[0],
                                               max_inst,
                                               replace=True), :]
        if balX is not None:
            balX = np.stack((balX, extra), axis = 0) 
            baly = np.stack((baly, np.asarray([label for i in range(len(extra))])))
        else:
            balX = extra
            baly = np.asarray([label for i in range(len(extra))])
    balX = np.concatenate(balX)
    baly = np.concatenate(baly)
    return balX, baly

# %%
train_features, train_labels = balance_data(train_features, train_labels)
test_features, test_labels = balance_data(test_features, test_labels)

# %%
unique_elements, counts_elements = np.unique(train_labels, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))

unique_elements_test, counts_elements_test = np.unique(test_labels, return_counts=True)
print(np.asarray((unique_elements_test, counts_elements_test)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['64' '64']]
# [['Healthy' 'Pneumonia']
#  ['16' '16']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
le.fit(train_labels)
train_labels_cat = to_categorical(le.transform(train_labels)) 
test_labels_cat = to_categorical(le.transform(test_labels))

# %%
train_features.shape
# Out:
# (128, 40, 345)

# %%
train_features = np.reshape(train_features, (*train_features.shape,1)) 
print(train_features.shape, train_labels_cat.shape)
test_features = np.reshape(test_features, (*test_features.shape,1)) 
print(test_features.shape, test_labels_cat.shape)
# Out:
# (128, 40, 345, 1) (128, 2)
# (32, 40, 345, 1) (32, 2)

# %%
x_test, y_test = test_features, test_labels_cat
x_train, y_train = train_features, train_labels_cat

# %% [markdown]
# **CNN model architecture**

# %%
num_labels = train_labels_cat.shape[1]

num_rows = 40
num_columns = SIZE
num_channels = 1

filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(Conv2D(filters=16, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(Conv2D(filters=8, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(Conv2D(filters=4, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 344, 32)       160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 172, 32)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 172, 32)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 171, 16)       2064
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 85, 16)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 85, 16)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 84, 8)          520
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 42, 8)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 42, 8)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 41, 4)          132
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 20, 4)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 20, 4)          0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 4)                 0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 10
# =================================================================
# Total params: 2,886
# Trainable params: 2,886
# Non-trainable params: 0
# _________________________________________________________________
# 32/32 [==============================] - 1s 33ms/sample - loss: 2.4591 - accuracy: 0.5000
# Pre-training accuracy: 50.0000%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 500
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/' + MODEL_NAME + '_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 128 samples, validate on 32 samples
# Epoch 1/500
#  70/128 [===============>..............] - ETA: 0s - loss: 6.1265 - accuracy: 0.5429
# Epoch 00001: val_accuracy improved from -inf to 0.50000, saving model to models/CNN2_dataset_1_trim8_01.h5
# 128/128 [==============================] - 1s 7ms/sample - loss: 4.7907 - accuracy: 0.5547 - val_loss: 1.6265 - val_accuracy: 0.5000
# Epoch 2/500
#  70/128 [===============>..............] - ETA: 0s - loss: 2.8349 - accuracy: 0.5429
# Epoch 00002: val_accuracy did not improve from 0.50000
# 128/128 [==============================] - 0s 977us/sample - loss: 2.9152 - accuracy: 0.5469 - val_loss: 0.9160 - val_accuracy: 0.5000
# Epoch 3/500
#  80/128 [=================>............] - ETA: 0s - loss: 2.1603 - accuracy: 0.4250
# Epoch 00003: val_accuracy did not improve from 0.50000
# 128/128 [==============================] - 0s 1ms/sample - loss: 2.1011 - accuracy: 0.4609 - val_loss: 0.8921 - val_accuracy: 0.5000
# Epoch 4/500
# 110/128 [========================>.....] - ETA: 0s - loss: 1.4971 - accuracy: 0.5091
# Epoch 00004: val_accuracy did not improve from 0.50000
# 128/128 [==============================] - 0s 1ms/sample - loss: 1.4366 - accuracy: 0.5312 - val_loss: 0.7492 - val_accuracy: 0.5000
# Epoch 5/500
#  70/128 [===============>..............] - ETA: 0s - loss: 1.0076 - accuracy: 0.5857
# Epoch 00005: val_accuracy did not improve from 0.50000
# 128/128 [==============================] - 0s 960us/sample - loss: 1.2058 - accuracy: 0.5391 - val_loss: 0.7377 - val_accuracy: 0.5000
# Epoch 6/500
#  70/128 [===============>..............] - ETA: 0s - loss: 1.1489 - accuracy: 0.4571
# Epoch 00006: val_accuracy did not improve from 0.50000
# 128/128 [==============================] - 0s 975us/sample - loss: 1.0662 - accuracy: 0.4844 - val_loss: 0.7240 - val_accuracy: 0.5000
# Epoch 7/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.7228 - accuracy: 0.6500
# Epoch 00007: val_accuracy did not improve from 0.50000
# 128/128 [==============================] - 0s 973us/sample - loss: 0.8546 - accuracy: 0.5703 - val_loss: 0.7195 - val_accuracy: 0.5000
# Epoch 8/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.6323 - accuracy: 0.6500
# Epoch 00008: val_accuracy did not improve from 0.50000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.6786 - accuracy: 0.6250 - val_loss: 0.7257 - val_accuracy: 0.5000
# Epoch 9/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.8397 - accuracy: 0.5250
# Epoch 00009: val_accuracy did not improve from 0.50000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.8582 - accuracy: 0.5156 - val_loss: 0.7265 - val_accuracy: 0.5000
# Epoch 10/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.7143 - accuracy: 0.6000
# Epoch 00010: val_accuracy did not improve from 0.50000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.7373 - accuracy: 0.5938 - val_loss: 0.7241 - val_accuracy: 0.5000
# Epoch 11/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.7578 - accuracy: 0.6000
# Epoch 00011: val_accuracy did not improve from 0.50000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.8520 - accuracy: 0.5625 - val_loss: 0.7228 - val_accuracy: 0.5000
# Epoch 12/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.6843 - accuracy: 0.6143
# Epoch 00012: val_accuracy did not improve from 0.50000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.6687 - accuracy: 0.5938 - val_loss: 0.7230 - val_accuracy: 0.5000
# Epoch 13/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.8473 - accuracy: 0.5000
# Epoch 00013: val_accuracy did not improve from 0.50000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.7732 - accuracy: 0.5547 - val_loss: 0.7218 - val_accuracy: 0.4688
# Epoch 14/500
#  60/128 [=============>................] - ETA: 0s - loss: 0.6180 - accuracy: 0.5667
# Epoch 00014: val_accuracy did not improve from 0.50000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.6460 - accuracy: 0.6172 - val_loss: 0.7231 - val_accuracy: 0.4375
# Epoch 15/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.7379 - accuracy: 0.5857
# Epoch 00015: val_accuracy did not improve from 0.50000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.6636 - accuracy: 0.6250 - val_loss: 0.7240 - val_accuracy: 0.5000
# Epoch 16/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.6670 - accuracy: 0.5714
# Epoch 00016: val_accuracy did not improve from 0.50000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.6491 - accuracy: 0.6406 - val_loss: 0.7237 - val_accuracy: 0.4688
# Epoch 17/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.7015 - accuracy: 0.6083
# Epoch 00017: val_accuracy improved from 0.50000 to 0.53125, saving model to models/CNN2_dataset_1_trim8_17.h5
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.6977 - accuracy: 0.6172 - val_loss: 0.7257 - val_accuracy: 0.5312
# Epoch 18/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.6293 - accuracy: 0.6571
# Epoch 00018: val_accuracy improved from 0.53125 to 0.62500, saving model to models/CNN2_dataset_1_trim8_18.h5
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.6601 - accuracy: 0.6328 - val_loss: 0.7221 - val_accuracy: 0.6250
# Epoch 19/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.6818 - accuracy: 0.5583
# Epoch 00019: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.6762 - accuracy: 0.5703 - val_loss: 0.7200 - val_accuracy: 0.6250
# Epoch 20/500
# 110/128 [========================>.....] - ETA: 0s - loss: 0.6595 - accuracy: 0.5909
# Epoch 00020: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.6779 - accuracy: 0.5781 - val_loss: 0.7159 - val_accuracy: 0.6250
# Epoch 21/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.6765 - accuracy: 0.6857
# Epoch 00021: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.6572 - accuracy: 0.6641 - val_loss: 0.7139 - val_accuracy: 0.6250
# Epoch 22/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.5710 - accuracy: 0.6857
# Epoch 00022: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 979us/sample - loss: 0.6380 - accuracy: 0.6094 - val_loss: 0.7121 - val_accuracy: 0.6250
# Epoch 23/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.5507 - accuracy: 0.6571
# Epoch 00023: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 996us/sample - loss: 0.5476 - accuracy: 0.6797 - val_loss: 0.7073 - val_accuracy: 0.4062
# Epoch 24/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.4881 - accuracy: 0.7571
# Epoch 00024: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.5004 - accuracy: 0.7734 - val_loss: 0.7056 - val_accuracy: 0.3125
# Epoch 25/500
# 110/128 [========================>.....] - ETA: 0s - loss: 0.5045 - accuracy: 0.8091
# Epoch 00025: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.5479 - accuracy: 0.7656 - val_loss: 0.7028 - val_accuracy: 0.2812
# Epoch 26/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.4879 - accuracy: 0.7417
# Epoch 00026: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.5092 - accuracy: 0.7266 - val_loss: 0.7022 - val_accuracy: 0.3125
# Epoch 27/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.4856 - accuracy: 0.7000
# Epoch 00027: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.5019 - accuracy: 0.7188 - val_loss: 0.7030 - val_accuracy: 0.2812
# Epoch 28/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.4713 - accuracy: 0.7417
# Epoch 00028: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4694 - accuracy: 0.7422 - val_loss: 0.6995 - val_accuracy: 0.3125
# Epoch 29/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.4191 - accuracy: 0.7714
# Epoch 00029: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4462 - accuracy: 0.7812 - val_loss: 0.6991 - val_accuracy: 0.3125
# Epoch 30/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.4036 - accuracy: 0.8143
# Epoch 00030: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4246 - accuracy: 0.7812 - val_loss: 0.7050 - val_accuracy: 0.2812
# Epoch 31/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.4544 - accuracy: 0.7857
# Epoch 00031: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4501 - accuracy: 0.7656 - val_loss: 0.7062 - val_accuracy: 0.5000
# Epoch 32/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3788 - accuracy: 0.8286
# Epoch 00032: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4108 - accuracy: 0.7969 - val_loss: 0.7072 - val_accuracy: 0.3125
# Epoch 33/500
# 110/128 [========================>.....] - ETA: 0s - loss: 0.4545 - accuracy: 0.7727
# Epoch 00033: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4578 - accuracy: 0.7578 - val_loss: 0.7063 - val_accuracy: 0.5938
# Epoch 34/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.4495 - accuracy: 0.7667
# Epoch 00034: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4346 - accuracy: 0.7812 - val_loss: 0.7074 - val_accuracy: 0.3750
# Epoch 35/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.4889 - accuracy: 0.7286
# Epoch 00035: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 994us/sample - loss: 0.4208 - accuracy: 0.7969 - val_loss: 0.7054 - val_accuracy: 0.3750
# Epoch 36/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.4210 - accuracy: 0.8000
# Epoch 00036: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 984us/sample - loss: 0.4041 - accuracy: 0.8125 - val_loss: 0.7075 - val_accuracy: 0.3750
# Epoch 37/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.4763 - accuracy: 0.7429
# Epoch 00037: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4320 - accuracy: 0.7812 - val_loss: 0.7093 - val_accuracy: 0.5000
# Epoch 38/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.3918 - accuracy: 0.7833
# Epoch 00038: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3868 - accuracy: 0.7812 - val_loss: 0.7112 - val_accuracy: 0.4062
# Epoch 39/500
# 110/128 [========================>.....] - ETA: 0s - loss: 0.3899 - accuracy: 0.8091
# Epoch 00039: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3856 - accuracy: 0.8125 - val_loss: 0.7146 - val_accuracy: 0.5000
# Epoch 40/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.4122 - accuracy: 0.8167
# Epoch 00040: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4160 - accuracy: 0.8125 - val_loss: 0.7091 - val_accuracy: 0.5000
# Epoch 41/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3691 - accuracy: 0.8000
# Epoch 00041: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3807 - accuracy: 0.8203 - val_loss: 0.7038 - val_accuracy: 0.5000
# Epoch 42/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3624 - accuracy: 0.8714
# Epoch 00042: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 995us/sample - loss: 0.3524 - accuracy: 0.8516 - val_loss: 0.7073 - val_accuracy: 0.5625
# Epoch 43/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.4871 - accuracy: 0.7286
# Epoch 00043: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4045 - accuracy: 0.7891 - val_loss: 0.7006 - val_accuracy: 0.5000
# Epoch 44/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3293 - accuracy: 0.9000
# Epoch 00044: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3622 - accuracy: 0.8438 - val_loss: 0.6990 - val_accuracy: 0.5000
# Epoch 45/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3428 - accuracy: 0.8857
# Epoch 00045: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3542 - accuracy: 0.8672 - val_loss: 0.7071 - val_accuracy: 0.5625
# Epoch 46/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.4305 - accuracy: 0.7857
# Epoch 00046: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 970us/sample - loss: 0.4131 - accuracy: 0.7969 - val_loss: 0.7096 - val_accuracy: 0.5625
# Epoch 47/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3765 - accuracy: 0.8143
# Epoch 00047: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3942 - accuracy: 0.7891 - val_loss: 0.7084 - val_accuracy: 0.6250
# Epoch 48/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.3496 - accuracy: 0.8500
# Epoch 00048: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3350 - accuracy: 0.8594 - val_loss: 0.7091 - val_accuracy: 0.6250
# Epoch 49/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2835 - accuracy: 0.8571
# Epoch 00049: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3079 - accuracy: 0.8594 - val_loss: 0.7070 - val_accuracy: 0.5000
# Epoch 50/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2907 - accuracy: 0.8583
# Epoch 00050: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2882 - accuracy: 0.8672 - val_loss: 0.7022 - val_accuracy: 0.5625
# Epoch 51/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3625 - accuracy: 0.8286
# Epoch 00051: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2934 - accuracy: 0.8906 - val_loss: 0.7269 - val_accuracy: 0.5625
# Epoch 52/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2649 - accuracy: 0.9000
# Epoch 00052: val_accuracy did not improve from 0.62500
# 128/128 [==============================] - 0s 979us/sample - loss: 0.3697 - accuracy: 0.8438 - val_loss: 0.7222 - val_accuracy: 0.4688
# Epoch 53/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3761 - accuracy: 0.8286
# Epoch 00053: val_accuracy improved from 0.62500 to 0.65625, saving model to models/CNN2_dataset_1_trim8_53.h5
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4085 - accuracy: 0.7891 - val_loss: 0.7496 - val_accuracy: 0.6562
# Epoch 54/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3425 - accuracy: 0.8571
# Epoch 00054: val_accuracy did not improve from 0.65625
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2922 - accuracy: 0.8750 - val_loss: 0.7160 - val_accuracy: 0.5000
# Epoch 55/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2535 - accuracy: 0.8917
# Epoch 00055: val_accuracy did not improve from 0.65625
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2579 - accuracy: 0.8906 - val_loss: 0.7462 - val_accuracy: 0.5625
# Epoch 56/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.3466 - accuracy: 0.8250
# Epoch 00056: val_accuracy did not improve from 0.65625
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3323 - accuracy: 0.8359 - val_loss: 0.7130 - val_accuracy: 0.4375
# Epoch 57/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.3705 - accuracy: 0.8500
# Epoch 00057: val_accuracy did not improve from 0.65625
# 128/128 [==============================] - 0s 957us/sample - loss: 0.3717 - accuracy: 0.8281 - val_loss: 0.7536 - val_accuracy: 0.6562
# Epoch 58/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3918 - accuracy: 0.8857
# Epoch 00058: val_accuracy did not improve from 0.65625
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3011 - accuracy: 0.9141 - val_loss: 0.7513 - val_accuracy: 0.5625
# Epoch 59/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2893 - accuracy: 0.9000
# Epoch 00059: val_accuracy did not improve from 0.65625
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2834 - accuracy: 0.9062 - val_loss: 0.7348 - val_accuracy: 0.5625
# Epoch 60/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2969 - accuracy: 0.8917
# Epoch 00060: val_accuracy did not improve from 0.65625
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2843 - accuracy: 0.8984 - val_loss: 0.7766 - val_accuracy: 0.6562
# Epoch 61/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2116 - accuracy: 0.9167
# Epoch 00061: val_accuracy did not improve from 0.65625
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2225 - accuracy: 0.9062 - val_loss: 0.7586 - val_accuracy: 0.6250
# Epoch 62/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2401 - accuracy: 0.9429
# Epoch 00062: val_accuracy did not improve from 0.65625
# 128/128 [==============================] - 0s 974us/sample - loss: 0.2344 - accuracy: 0.9297 - val_loss: 0.7808 - val_accuracy: 0.5625
# Epoch 63/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2287 - accuracy: 0.9571
# Epoch 00063: val_accuracy did not improve from 0.65625
# 128/128 [==============================] - 0s 999us/sample - loss: 0.2950 - accuracy: 0.8984 - val_loss: 0.7498 - val_accuracy: 0.5625
# Epoch 64/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2265 - accuracy: 0.9286
# Epoch 00064: val_accuracy did not improve from 0.65625
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2223 - accuracy: 0.9141 - val_loss: 0.7927 - val_accuracy: 0.6562
# Epoch 65/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.4269 - accuracy: 0.8571
# Epoch 00065: val_accuracy did not improve from 0.65625
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3424 - accuracy: 0.8828 - val_loss: 0.7311 - val_accuracy: 0.4375
# Epoch 66/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2945 - accuracy: 0.8500
# Epoch 00066: val_accuracy did not improve from 0.65625
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2970 - accuracy: 0.8438 - val_loss: 0.7406 - val_accuracy: 0.5625
# Epoch 67/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.3177 - accuracy: 0.8917
# Epoch 00067: val_accuracy did not improve from 0.65625
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3038 - accuracy: 0.8984 - val_loss: 0.7630 - val_accuracy: 0.6250
# Epoch 68/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2562 - accuracy: 0.9000
# Epoch 00068: val_accuracy did not improve from 0.65625
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2420 - accuracy: 0.9297 - val_loss: 0.7334 - val_accuracy: 0.4375
# Epoch 69/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1997 - accuracy: 0.9143
# Epoch 00069: val_accuracy did not improve from 0.65625
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2841 - accuracy: 0.8672 - val_loss: 0.8008 - val_accuracy: 0.6562
# Epoch 70/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2690 - accuracy: 0.8571
# Epoch 00070: val_accuracy did not improve from 0.65625
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2774 - accuracy: 0.8672 - val_loss: 0.7505 - val_accuracy: 0.5625
# Epoch 71/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2538 - accuracy: 0.9143
# Epoch 00071: val_accuracy did not improve from 0.65625
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2414 - accuracy: 0.9062 - val_loss: 0.7653 - val_accuracy: 0.6250
# Epoch 72/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2146 - accuracy: 0.9571
# Epoch 00072: val_accuracy did not improve from 0.65625
# 128/128 [==============================] - 0s 985us/sample - loss: 0.2109 - accuracy: 0.9453 - val_loss: 0.7721 - val_accuracy: 0.6250
# Epoch 73/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2609 - accuracy: 0.8714
# Epoch 00073: val_accuracy improved from 0.65625 to 0.71875, saving model to models/CNN2_dataset_1_trim8_73.h5
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2918 - accuracy: 0.8828 - val_loss: 0.8225 - val_accuracy: 0.7188
# Epoch 74/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2888 - accuracy: 0.8429
# Epoch 00074: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2778 - accuracy: 0.8672 - val_loss: 0.7757 - val_accuracy: 0.5625
# Epoch 75/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2903 - accuracy: 0.8857
# Epoch 00075: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2269 - accuracy: 0.9141 - val_loss: 0.7733 - val_accuracy: 0.5625
# Epoch 76/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.3166 - accuracy: 0.9000
# Epoch 00076: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 998us/sample - loss: 0.2788 - accuracy: 0.9219 - val_loss: 0.7531 - val_accuracy: 0.4375
# Epoch 77/500
# 110/128 [========================>.....] - ETA: 0s - loss: 0.2110 - accuracy: 0.9091
# Epoch 00077: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1976 - accuracy: 0.9141 - val_loss: 0.7831 - val_accuracy: 0.6250
# Epoch 78/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1860 - accuracy: 0.9286
# Epoch 00078: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1679 - accuracy: 0.9297 - val_loss: 0.7666 - val_accuracy: 0.5625
# Epoch 79/500
# 110/128 [========================>.....] - ETA: 0s - loss: 0.2300 - accuracy: 0.9364
# Epoch 00079: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2282 - accuracy: 0.9219 - val_loss: 0.7724 - val_accuracy: 0.5625
# Epoch 80/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2871 - accuracy: 0.8857
# Epoch 00080: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 984us/sample - loss: 0.2571 - accuracy: 0.8984 - val_loss: 0.7335 - val_accuracy: 0.4375
# Epoch 81/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3526 - accuracy: 0.8571
# Epoch 00081: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3164 - accuracy: 0.8594 - val_loss: 0.7795 - val_accuracy: 0.6250
# Epoch 82/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2584 - accuracy: 0.8833
# Epoch 00082: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2596 - accuracy: 0.8750 - val_loss: 0.7940 - val_accuracy: 0.6250
# Epoch 83/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2351 - accuracy: 0.8857
# Epoch 00083: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1985 - accuracy: 0.9062 - val_loss: 0.7985 - val_accuracy: 0.6250
# Epoch 84/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.2214 - accuracy: 0.9125
# Epoch 00084: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2246 - accuracy: 0.9141 - val_loss: 0.7834 - val_accuracy: 0.6250
# Epoch 85/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.1795 - accuracy: 0.9500
# Epoch 00085: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1794 - accuracy: 0.9531 - val_loss: 0.7861 - val_accuracy: 0.6250
# Epoch 86/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3103 - accuracy: 0.8429
# Epoch 00086: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2622 - accuracy: 0.8672 - val_loss: 0.8319 - val_accuracy: 0.6250
# Epoch 87/500
# 110/128 [========================>.....] - ETA: 0s - loss: 0.2498 - accuracy: 0.9000
# Epoch 00087: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2538 - accuracy: 0.8828 - val_loss: 0.7786 - val_accuracy: 0.5625
# Epoch 88/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1775 - accuracy: 0.9857
# Epoch 00088: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 989us/sample - loss: 0.2017 - accuracy: 0.9297 - val_loss: 0.7857 - val_accuracy: 0.5625
# Epoch 89/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2585 - accuracy: 0.9143
# Epoch 00089: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2869 - accuracy: 0.8906 - val_loss: 0.7642 - val_accuracy: 0.5625
# Epoch 90/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.1510 - accuracy: 0.9500
# Epoch 00090: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1537 - accuracy: 0.9531 - val_loss: 0.8101 - val_accuracy: 0.7188
# Epoch 91/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2342 - accuracy: 0.8714
# Epoch 00091: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2374 - accuracy: 0.8828 - val_loss: 0.7714 - val_accuracy: 0.5625
# Epoch 92/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2845 - accuracy: 0.8714
# Epoch 00092: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 986us/sample - loss: 0.2775 - accuracy: 0.8750 - val_loss: 0.8053 - val_accuracy: 0.6250
# Epoch 93/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1898 - accuracy: 0.9286
# Epoch 00093: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2163 - accuracy: 0.9219 - val_loss: 0.7916 - val_accuracy: 0.6250
# Epoch 94/500
# 110/128 [========================>.....] - ETA: 0s - loss: 0.2297 - accuracy: 0.8818
# Epoch 00094: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2110 - accuracy: 0.8984 - val_loss: 0.8448 - val_accuracy: 0.6562
# Epoch 95/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2843 - accuracy: 0.8714
# Epoch 00095: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2169 - accuracy: 0.9141 - val_loss: 0.7700 - val_accuracy: 0.4375
# Epoch 96/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2103 - accuracy: 0.9000
# Epoch 00096: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2029 - accuracy: 0.8984 - val_loss: 0.8388 - val_accuracy: 0.6250
# Epoch 97/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.1908 - accuracy: 0.9417
# Epoch 00097: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1927 - accuracy: 0.9453 - val_loss: 0.7858 - val_accuracy: 0.5625
# Epoch 98/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1985 - accuracy: 0.9000
# Epoch 00098: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2131 - accuracy: 0.9219 - val_loss: 0.8216 - val_accuracy: 0.7188
# Epoch 99/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2519 - accuracy: 0.8571
# Epoch 00099: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2168 - accuracy: 0.8984 - val_loss: 0.7749 - val_accuracy: 0.5625
# Epoch 100/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1818 - accuracy: 0.9286
# Epoch 00100: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1648 - accuracy: 0.9375 - val_loss: 0.8358 - val_accuracy: 0.7188
# Epoch 101/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.1611 - accuracy: 0.9167
# Epoch 00101: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1693 - accuracy: 0.9141 - val_loss: 0.7801 - val_accuracy: 0.5625
# Epoch 102/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1947 - accuracy: 0.9286
# Epoch 00102: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1713 - accuracy: 0.9453 - val_loss: 0.8620 - val_accuracy: 0.7188
# Epoch 103/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2103 - accuracy: 0.8857
# Epoch 00103: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2189 - accuracy: 0.9141 - val_loss: 0.8034 - val_accuracy: 0.5625
# Epoch 104/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1656 - accuracy: 0.9143
# Epoch 00104: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2028 - accuracy: 0.9062 - val_loss: 0.8348 - val_accuracy: 0.6250
# Epoch 105/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.1682 - accuracy: 0.9500
# Epoch 00105: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1673 - accuracy: 0.9531 - val_loss: 0.8318 - val_accuracy: 0.6250
# Epoch 106/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2451 - accuracy: 0.8917
# Epoch 00106: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2391 - accuracy: 0.8984 - val_loss: 0.8246 - val_accuracy: 0.6250
# Epoch 107/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1765 - accuracy: 0.9143
# Epoch 00107: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2024 - accuracy: 0.8984 - val_loss: 0.8755 - val_accuracy: 0.6562
# Epoch 108/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2297 - accuracy: 0.8833
# Epoch 00108: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2295 - accuracy: 0.8828 - val_loss: 0.8326 - val_accuracy: 0.6250
# Epoch 109/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.1854 - accuracy: 0.9250
# Epoch 00109: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1961 - accuracy: 0.9141 - val_loss: 0.8878 - val_accuracy: 0.7188
# Epoch 110/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2393 - accuracy: 0.8714
# Epoch 00110: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2052 - accuracy: 0.9062 - val_loss: 0.8316 - val_accuracy: 0.6250
# Epoch 111/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.1807 - accuracy: 0.9333
# Epoch 00111: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1844 - accuracy: 0.9297 - val_loss: 0.8488 - val_accuracy: 0.7188
# Epoch 112/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2009 - accuracy: 0.9000
# Epoch 00112: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1893 - accuracy: 0.9219 - val_loss: 0.8335 - val_accuracy: 0.6250
# Epoch 113/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1558 - accuracy: 0.9429
# Epoch 00113: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1554 - accuracy: 0.9453 - val_loss: 0.8340 - val_accuracy: 0.7188
# Epoch 114/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1749 - accuracy: 0.9143
# Epoch 00114: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1313 - accuracy: 0.9531 - val_loss: 0.8257 - val_accuracy: 0.7188
# Epoch 115/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2514 - accuracy: 0.9000
# Epoch 00115: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2432 - accuracy: 0.9062 - val_loss: 0.8117 - val_accuracy: 0.6250
# Epoch 116/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.1523 - accuracy: 0.9500
# Epoch 00116: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1685 - accuracy: 0.9453 - val_loss: 0.8141 - val_accuracy: 0.6250
# Epoch 117/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.1466 - accuracy: 0.9333
# Epoch 00117: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1481 - accuracy: 0.9297 - val_loss: 0.8906 - val_accuracy: 0.7188
# Epoch 118/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1874 - accuracy: 0.9286
# Epoch 00118: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1721 - accuracy: 0.9375 - val_loss: 0.8575 - val_accuracy: 0.5625
# Epoch 119/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1652 - accuracy: 0.9286
# Epoch 00119: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2038 - accuracy: 0.9219 - val_loss: 0.9803 - val_accuracy: 0.7188
# Epoch 120/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1912 - accuracy: 0.9143
# Epoch 00120: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 957us/sample - loss: 0.2143 - accuracy: 0.9219 - val_loss: 0.8492 - val_accuracy: 0.5625
# Epoch 121/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2077 - accuracy: 0.9286
# Epoch 00121: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2422 - accuracy: 0.8906 - val_loss: 0.8777 - val_accuracy: 0.6250
# Epoch 122/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.2383 - accuracy: 0.8750
# Epoch 00122: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 980us/sample - loss: 0.2063 - accuracy: 0.9062 - val_loss: 0.9171 - val_accuracy: 0.6250
# Epoch 123/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.2874 - accuracy: 0.9125
# Epoch 00123: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2375 - accuracy: 0.9297 - val_loss: 0.8567 - val_accuracy: 0.5625
# Epoch 124/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2183 - accuracy: 0.9143
# Epoch 00124: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 978us/sample - loss: 0.1957 - accuracy: 0.9219 - val_loss: 0.8984 - val_accuracy: 0.7188
# Epoch 125/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.1666 - accuracy: 0.9125
# Epoch 00125: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 976us/sample - loss: 0.2036 - accuracy: 0.8984 - val_loss: 0.8387 - val_accuracy: 0.7188
# Epoch 126/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2863 - accuracy: 0.9000
# Epoch 00126: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2593 - accuracy: 0.8828 - val_loss: 0.8092 - val_accuracy: 0.6250
# Epoch 127/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2222 - accuracy: 0.8857
# Epoch 00127: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1866 - accuracy: 0.9141 - val_loss: 0.8216 - val_accuracy: 0.6250
# Epoch 128/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1541 - accuracy: 0.9143
# Epoch 00128: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1298 - accuracy: 0.9375 - val_loss: 0.8128 - val_accuracy: 0.6250
# Epoch 129/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.1594 - accuracy: 0.9250
# Epoch 00129: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 960us/sample - loss: 0.1486 - accuracy: 0.9375 - val_loss: 0.8543 - val_accuracy: 0.7188
# Epoch 130/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2135 - accuracy: 0.9143
# Epoch 00130: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1954 - accuracy: 0.9141 - val_loss: 0.9216 - val_accuracy: 0.7188
# Epoch 131/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2069 - accuracy: 0.9000
# Epoch 00131: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2306 - accuracy: 0.9141 - val_loss: 0.7937 - val_accuracy: 0.5625
# Epoch 132/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2521 - accuracy: 0.8857
# Epoch 00132: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2291 - accuracy: 0.8984 - val_loss: 0.8580 - val_accuracy: 0.7188
# Epoch 133/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.1017 - accuracy: 0.9750
# Epoch 00133: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0996 - accuracy: 0.9766 - val_loss: 0.8981 - val_accuracy: 0.7188
# Epoch 134/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1245 - accuracy: 0.9286
# Epoch 00134: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1753 - accuracy: 0.9141 - val_loss: 0.8202 - val_accuracy: 0.6250
# Epoch 135/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1438 - accuracy: 0.9429
# Epoch 00135: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1397 - accuracy: 0.9297 - val_loss: 0.8859 - val_accuracy: 0.7188
# Epoch 136/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.1667 - accuracy: 0.9250
# Epoch 00136: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1432 - accuracy: 0.9375 - val_loss: 0.8681 - val_accuracy: 0.6250
# Epoch 137/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2293 - accuracy: 0.9000
# Epoch 00137: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1869 - accuracy: 0.9297 - val_loss: 0.8484 - val_accuracy: 0.6250
# Epoch 138/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.1680 - accuracy: 0.9333
# Epoch 00138: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1808 - accuracy: 0.9297 - val_loss: 0.8993 - val_accuracy: 0.7188
# Epoch 139/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1893 - accuracy: 0.9429
# Epoch 00139: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1350 - accuracy: 0.9688 - val_loss: 0.8654 - val_accuracy: 0.6250
# Epoch 140/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0704 - accuracy: 0.9857
# Epoch 00140: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0811 - accuracy: 0.9844 - val_loss: 0.8615 - val_accuracy: 0.7188
# Epoch 141/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0802 - accuracy: 0.9857
# Epoch 00141: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1448 - accuracy: 0.9531 - val_loss: 0.9376 - val_accuracy: 0.7188
# Epoch 142/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1936 - accuracy: 0.9286
# Epoch 00142: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2127 - accuracy: 0.9141 - val_loss: 0.9020 - val_accuracy: 0.6250
# Epoch 143/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1025 - accuracy: 0.9714
# Epoch 00143: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1334 - accuracy: 0.9453 - val_loss: 0.9500 - val_accuracy: 0.7188
# Epoch 144/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1325 - accuracy: 0.9286
# Epoch 00144: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1269 - accuracy: 0.9453 - val_loss: 0.9344 - val_accuracy: 0.7188
# Epoch 145/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1835 - accuracy: 0.8857
# Epoch 00145: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1509 - accuracy: 0.9141 - val_loss: 0.8267 - val_accuracy: 0.5625
# Epoch 146/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1563 - accuracy: 0.9429
# Epoch 00146: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 975us/sample - loss: 0.1543 - accuracy: 0.9531 - val_loss: 0.8532 - val_accuracy: 0.7188
# Epoch 147/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1743 - accuracy: 0.9429
# Epoch 00147: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 965us/sample - loss: 0.1336 - accuracy: 0.9453 - val_loss: 0.9490 - val_accuracy: 0.6562
# Epoch 148/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1771 - accuracy: 0.9143
# Epoch 00148: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1993 - accuracy: 0.9062 - val_loss: 0.8008 - val_accuracy: 0.6250
# Epoch 149/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1032 - accuracy: 0.9714
# Epoch 00149: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1513 - accuracy: 0.9375 - val_loss: 0.8459 - val_accuracy: 0.6250
# Epoch 150/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2233 - accuracy: 0.9143
# Epoch 00150: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1960 - accuracy: 0.9062 - val_loss: 0.8681 - val_accuracy: 0.7188
# Epoch 151/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2378 - accuracy: 0.9286
# Epoch 00151: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1733 - accuracy: 0.9531 - val_loss: 0.8778 - val_accuracy: 0.7188
# Epoch 152/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1706 - accuracy: 0.9286
# Epoch 00152: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1847 - accuracy: 0.9141 - val_loss: 0.8861 - val_accuracy: 0.7188
# Epoch 153/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1259 - accuracy: 0.9571
# Epoch 00153: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1337 - accuracy: 0.9453 - val_loss: 0.9228 - val_accuracy: 0.7188
# Epoch 154/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1406 - accuracy: 0.9429
# Epoch 00154: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1563 - accuracy: 0.9375 - val_loss: 0.8384 - val_accuracy: 0.5625
# Epoch 155/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1245 - accuracy: 0.9714
# Epoch 00155: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1177 - accuracy: 0.9688 - val_loss: 0.9122 - val_accuracy: 0.7188
# Epoch 156/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1353 - accuracy: 0.9429
# Epoch 00156: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1347 - accuracy: 0.9531 - val_loss: 0.8583 - val_accuracy: 0.7188
# Epoch 157/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1568 - accuracy: 0.9143
# Epoch 00157: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 999us/sample - loss: 0.1267 - accuracy: 0.9453 - val_loss: 0.9748 - val_accuracy: 0.6562
# Epoch 158/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1982 - accuracy: 0.9000
# Epoch 00158: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1719 - accuracy: 0.9219 - val_loss: 0.9355 - val_accuracy: 0.7188
# Epoch 159/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1475 - accuracy: 0.9571
# Epoch 00159: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1271 - accuracy: 0.9531 - val_loss: 0.8960 - val_accuracy: 0.5625
# Epoch 160/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1492 - accuracy: 0.9714
# Epoch 00160: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1700 - accuracy: 0.9375 - val_loss: 0.9624 - val_accuracy: 0.7188
# Epoch 161/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1082 - accuracy: 0.9571
# Epoch 00161: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0969 - accuracy: 0.9531 - val_loss: 0.9868 - val_accuracy: 0.7188
# Epoch 162/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1350 - accuracy: 0.9429
# Epoch 00162: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 974us/sample - loss: 0.1337 - accuracy: 0.9453 - val_loss: 0.8761 - val_accuracy: 0.5625
# Epoch 163/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.1447 - accuracy: 0.9375
# Epoch 00163: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1360 - accuracy: 0.9453 - val_loss: 1.0230 - val_accuracy: 0.6562
# Epoch 164/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0830 - accuracy: 0.9857
# Epoch 00164: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0907 - accuracy: 0.9766 - val_loss: 0.9727 - val_accuracy: 0.7188
# Epoch 165/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2164 - accuracy: 0.8857
# Epoch 00165: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2236 - accuracy: 0.8984 - val_loss: 0.9151 - val_accuracy: 0.7188
# Epoch 166/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1156 - accuracy: 0.9714
# Epoch 00166: val_accuracy did not improve from 0.71875
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1185 - accuracy: 0.9766 - val_loss: 1.0207 - val_accuracy: 0.6562
# Epoch 167/500
# ...
# Epoch 446/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0212 - accuracy: 0.9857
# Epoch 00446: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0505 - accuracy: 0.9766 - val_loss: 1.1346 - val_accuracy: 0.7188
# Epoch 447/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0879 - accuracy: 0.9571
# Epoch 00447: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0721 - accuracy: 0.9609 - val_loss: 1.5645 - val_accuracy: 0.7188
# Epoch 448/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1500 - accuracy: 0.9571
# Epoch 00448: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1186 - accuracy: 0.9531 - val_loss: 0.9698 - val_accuracy: 0.6250
# Epoch 449/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0325 - accuracy: 1.0000
# Epoch 00449: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0360 - accuracy: 0.9922 - val_loss: 1.3522 - val_accuracy: 0.7188
# Epoch 450/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0697 - accuracy: 0.9714
# Epoch 00450: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0423 - accuracy: 0.9844 - val_loss: 1.0738 - val_accuracy: 0.7188
# Epoch 451/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0917 - accuracy: 0.9500
# Epoch 00451: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0860 - accuracy: 0.9531 - val_loss: 1.0693 - val_accuracy: 0.7188
# Epoch 452/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.1570 - accuracy: 0.9250
# Epoch 00452: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1069 - accuracy: 0.9531 - val_loss: 1.6545 - val_accuracy: 0.6562
# Epoch 453/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0646 - accuracy: 0.9571
# Epoch 00453: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0437 - accuracy: 0.9766 - val_loss: 1.1252 - val_accuracy: 0.7188
# Epoch 454/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0553 - accuracy: 0.9750
# Epoch 00454: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0627 - accuracy: 0.9688 - val_loss: 1.3995 - val_accuracy: 0.7188
# Epoch 455/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0354 - accuracy: 0.9714
# Epoch 00455: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0374 - accuracy: 0.9688 - val_loss: 1.3144 - val_accuracy: 0.7188
# Epoch 456/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0807 - accuracy: 0.9571
# Epoch 00456: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0602 - accuracy: 0.9766 - val_loss: 1.2132 - val_accuracy: 0.7188
# Epoch 457/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0321 - accuracy: 0.9857
# Epoch 00457: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0214 - accuracy: 0.9922 - val_loss: 1.2572 - val_accuracy: 0.7188
# Epoch 458/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0597 - accuracy: 0.9714
# Epoch 00458: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0366 - accuracy: 0.9844 - val_loss: 1.1043 - val_accuracy: 0.7188
# Epoch 459/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0583 - accuracy: 0.9714
# Epoch 00459: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0777 - accuracy: 0.9609 - val_loss: 1.3483 - val_accuracy: 0.7188
# Epoch 460/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0691 - accuracy: 0.9500
# Epoch 00460: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0931 - accuracy: 0.9531 - val_loss: 1.1088 - val_accuracy: 0.7188
# Epoch 461/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0877 - accuracy: 0.9857
# Epoch 00461: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 996us/sample - loss: 0.0801 - accuracy: 0.9844 - val_loss: 1.1105 - val_accuracy: 0.7188
# Epoch 462/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0729 - accuracy: 0.9714
# Epoch 00462: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1165 - accuracy: 0.9531 - val_loss: 1.3360 - val_accuracy: 0.7188
# Epoch 463/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0296 - accuracy: 1.0000
# Epoch 00463: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0551 - accuracy: 0.9766 - val_loss: 0.8676 - val_accuracy: 0.6562
# Epoch 464/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0764 - accuracy: 0.9714
# Epoch 00464: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0608 - accuracy: 0.9766 - val_loss: 1.4872 - val_accuracy: 0.6562
# Epoch 465/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0550 - accuracy: 0.9714
# Epoch 00465: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0534 - accuracy: 0.9766 - val_loss: 0.8519 - val_accuracy: 0.6562
# Epoch 466/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0246 - accuracy: 1.0000
# Epoch 00466: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 979us/sample - loss: 0.0330 - accuracy: 0.9922 - val_loss: 0.9956 - val_accuracy: 0.7500
# Epoch 467/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0236 - accuracy: 1.0000
# Epoch 00467: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0318 - accuracy: 1.0000 - val_loss: 1.1597 - val_accuracy: 0.7188
# Epoch 468/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0479 - accuracy: 0.9714
# Epoch 00468: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0340 - accuracy: 0.9844 - val_loss: 1.7535 - val_accuracy: 0.6562
# Epoch 469/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0711 - accuracy: 0.9625
# Epoch 00469: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0494 - accuracy: 0.9766 - val_loss: 1.1440 - val_accuracy: 0.6250
# Epoch 470/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0183 - accuracy: 1.0000
# Epoch 00470: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0269 - accuracy: 0.9922 - val_loss: 1.5455 - val_accuracy: 0.7188
# Epoch 471/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0839 - accuracy: 0.9625
# Epoch 00471: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0744 - accuracy: 0.9609 - val_loss: 1.1226 - val_accuracy: 0.7188
# Epoch 472/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0188 - accuracy: 1.0000
# Epoch 00472: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0249 - accuracy: 0.9922 - val_loss: 1.1778 - val_accuracy: 0.7188
# Epoch 473/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0363 - accuracy: 0.9857
# Epoch 00473: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0349 - accuracy: 0.9844 - val_loss: 1.5132 - val_accuracy: 0.7188
# Epoch 474/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0421 - accuracy: 0.9857
# Epoch 00474: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0558 - accuracy: 0.9844 - val_loss: 1.0694 - val_accuracy: 0.7188
# Epoch 475/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0342 - accuracy: 0.9857
# Epoch 00475: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0292 - accuracy: 0.9922 - val_loss: 1.8691 - val_accuracy: 0.6562
# Epoch 476/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0723 - accuracy: 0.9714
# Epoch 00476: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 998us/sample - loss: 0.0504 - accuracy: 0.9844 - val_loss: 1.1703 - val_accuracy: 0.7188
# Epoch 477/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0361 - accuracy: 0.9875
# Epoch 00477: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 987us/sample - loss: 0.0535 - accuracy: 0.9844 - val_loss: 1.1270 - val_accuracy: 0.7188
# Epoch 478/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0461 - accuracy: 0.9714
# Epoch 00478: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0493 - accuracy: 0.9688 - val_loss: 1.7020 - val_accuracy: 0.6562
# Epoch 479/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0385 - accuracy: 0.9750
# Epoch 00479: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0327 - accuracy: 0.9844 - val_loss: 1.3945 - val_accuracy: 0.7188
# Epoch 480/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0751 - accuracy: 0.9714
# Epoch 00480: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0616 - accuracy: 0.9688 - val_loss: 1.3663 - val_accuracy: 0.7188
# Epoch 481/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0135 - accuracy: 1.0000
# Epoch 00481: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0222 - accuracy: 0.9922 - val_loss: 1.4402 - val_accuracy: 0.7188
# Epoch 482/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0198 - accuracy: 1.0000
# Epoch 00482: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0384 - accuracy: 0.9844 - val_loss: 1.1493 - val_accuracy: 0.7188
# Epoch 483/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0473 - accuracy: 0.9750
# Epoch 00483: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0365 - accuracy: 0.9844 - val_loss: 1.1791 - val_accuracy: 0.7188
# Epoch 484/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0175 - accuracy: 1.0000
# Epoch 00484: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 984us/sample - loss: 0.0157 - accuracy: 1.0000 - val_loss: 1.2391 - val_accuracy: 0.7188
# Epoch 485/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0191 - accuracy: 1.0000
# Epoch 00485: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0863 - accuracy: 0.9766 - val_loss: 1.5307 - val_accuracy: 0.6562
# Epoch 486/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0432 - accuracy: 0.9750
# Epoch 00486: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0696 - accuracy: 0.9609 - val_loss: 1.3273 - val_accuracy: 0.7188
# Epoch 487/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0316 - accuracy: 0.9857
# Epoch 00487: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0331 - accuracy: 0.9844 - val_loss: 0.8803 - val_accuracy: 0.6562
# Epoch 488/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0180 - accuracy: 1.0000
# Epoch 00488: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0550 - accuracy: 0.9844 - val_loss: 1.0063 - val_accuracy: 0.7500
# Epoch 489/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0454 - accuracy: 0.9875
# Epoch 00489: val_accuracy did not improve from 0.75000
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0371 - accuracy: 0.9922 - val_loss: 1.2295 - val_accuracy: 0.7188
# Epoch 490/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0286 - accuracy: 0.9875
# Epoch 00490: val_accuracy improved from 0.75000 to 0.81250, saving model to models/CNN2_dataset_1_trim8_490.h5
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0198 - accuracy: 0.9922 - val_loss: 0.9169 - val_accuracy: 0.8125
# Epoch 491/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0551 - accuracy: 0.9857
# Epoch 00491: val_accuracy did not improve from 0.81250
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0443 - accuracy: 0.9844 - val_loss: 1.6264 - val_accuracy: 0.6562
# Epoch 492/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0375 - accuracy: 0.9857
# Epoch 00492: val_accuracy did not improve from 0.81250
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0338 - accuracy: 0.9922 - val_loss: 1.2346 - val_accuracy: 0.7188
# Epoch 493/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0616 - accuracy: 0.9571
# Epoch 00493: val_accuracy did not improve from 0.81250
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0377 - accuracy: 0.9766 - val_loss: 0.9891 - val_accuracy: 0.7500
# Epoch 494/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0653 - accuracy: 0.9857
# Epoch 00494: val_accuracy did not improve from 0.81250
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0421 - accuracy: 0.9922 - val_loss: 1.1849 - val_accuracy: 0.7188
# Epoch 495/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0124 - accuracy: 1.0000
# Epoch 00495: val_accuracy did not improve from 0.81250
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0282 - accuracy: 0.9922 - val_loss: 1.1405 - val_accuracy: 0.7188
# Epoch 496/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.1011 - accuracy: 0.9500
# Epoch 00496: val_accuracy did not improve from 0.81250
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0994 - accuracy: 0.9609 - val_loss: 1.1708 - val_accuracy: 0.7188
# Epoch 497/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0214 - accuracy: 0.9857
# Epoch 00497: val_accuracy did not improve from 0.81250
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0315 - accuracy: 0.9844 - val_loss: 1.2163 - val_accuracy: 0.7188
# Epoch 498/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0430 - accuracy: 0.9857
# Epoch 00498: val_accuracy did not improve from 0.81250
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0407 - accuracy: 0.9844 - val_loss: 0.8876 - val_accuracy: 0.8125
# Epoch 499/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1213 - accuracy: 0.9429
# Epoch 00499: val_accuracy did not improve from 0.81250
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1317 - accuracy: 0.9453 - val_loss: 1.5552 - val_accuracy: 0.6562
# Epoch 500/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0724 - accuracy: 0.9500
# Epoch 00500: val_accuracy did not improve from 0.81250
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0849 - accuracy: 0.9531 - val_loss: 0.7821 - val_accuracy: 0.6562
# Training completed in time:  0:01:08.603458

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
train_acc = score[1]
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
test_acc = score[1]
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.96875
# Testing Accuracy:  0.65625

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.65      0.69      0.67        16
#    Pneumonia       0.67      0.62      0.65        16
#
#     accuracy                           0.66        32
#    macro avg       0.66      0.66      0.66        32
# weighted avg       0.66      0.66      0.66        32

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[11  5]
#  [ 6 10]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])

# %% [markdown]
# __Write CSV__

# %%
with open('report.csv', 'a') as report:
    report.write(f'{MODEL_NAME},{DATASET},{GROUP_TRAIN},{DURATION},{train_acc},{test_acc}\n')
