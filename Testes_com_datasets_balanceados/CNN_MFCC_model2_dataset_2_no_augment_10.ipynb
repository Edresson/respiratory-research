# %% [markdown]
# # Rede CNN - Modelo 2
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - Dataset 2 - no_augment_10

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP_TRAIN = 'no_augment_10'
GROUP_TEST = 'no_augment_10'
DATASET = 'dataset_2'
DURATION = 10
SIZE = 431
CSV_TRAIN = 'train2.csv'
CSV_TEST = 'test2.csv'
MODEL_NAME = f'CNN2_{DATASET}_{GROUP_TRAIN}'

# %%
train_file_paths = glob.glob(f'../datasets/{DATASET}/{GROUP_TRAIN}/train/**/*.wav', recursive=True)
train_file_names = [os.path.splitext(os.path.basename(p))[0] for p in train_file_paths]

test_file_paths = glob.glob(f'../datasets/{DATASET}/{GROUP_TEST}/test/**/*.wav', recursive=True)
test_file_names = [os.path.splitext(os.path.basename(p))[0] for p in test_file_paths]

# %%
train_p_id_in_file = [] # patient IDs corresponding to each file
test_p_id_in_file = [] # patient IDs corresponding to each file
for name in train_file_names:
    train_p_id_in_file.append(int(name[:3]))

for name in test_file_names:
    test_p_id_in_file.append(int(name[:3]))

train_p_id_in_file = np.array(train_p_id_in_file)
test_p_id_in_file = np.array(test_p_id_in_file)

# %%
max_pad_len = SIZE

os.makedirs("features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=DURATION) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
train_p_diag = pd.read_csv(f"../Respiratory_Sound_Database/Respiratory_Sound_Database_Pneumo_Healthy_Only/{CSV_TRAIN}", header=None) # patient diagnosis file
test_p_diag = pd.read_csv(f"../Respiratory_Sound_Database/Respiratory_Sound_Database_Pneumo_Healthy_Only/{CSV_TEST}", header=None) # patient diagnosis file
train_p_diag.head(5)
# Out:
#      0        1
# 0  123  Healthy
# 1  125  Healthy
# 2  126  Healthy
# 3  127  Healthy
# 4  136  Healthy

# %%
train_labels = np.array([train_p_diag[train_p_diag[0] == x][1].values[0] for x in train_p_id_in_file]) 
test_labels = np.array([test_p_diag[test_p_diag[0] == x][1].values[0] for x in test_p_id_in_file])

# %%
train_features = [] 
test_features = []

for file_name in train_file_paths:
    data = extract_features(file_name)
    train_features.append(data)

for file_name in test_file_paths:
    data = extract_features(file_name)
    test_features.append(data)

print('Finished feature extraction from ', (len(train_features)+len(train_features)), ' files')
train_features = np.array(train_features)
test_features = np.array(test_features)
# Out:
# Finished feature extraction from  112  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(train_features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
np.unique(train_labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
unique_elements, counts_elements = np.unique(train_labels, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))

unique_elements_test, counts_elements_test = np.unique(test_labels, return_counts=True)
print(np.asarray((unique_elements_test, counts_elements_test)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['32' '24']]
# [['Healthy' 'Pneumonia']
#  ['3' '13']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %% [markdown]
# __Balanceando dados__

# %%
def balance_data(X, labels):
    """Balances data duplicating some instances of the minority classes"""
    balX = None
    baly = None
    unique, counts = np.unique(labels, return_counts=True)
    max_inst = max(counts)
    # For every class duplicate the necessary amount
    for label in unique:
        data_of_label = []
        for x, y in zip(X, labels):
            if y == label:
                data_of_label.append(x)
        data_of_label = np.asarray(data_of_label)
        extra = data_of_label[np.random.choice(data_of_label.shape[0],
                                               max_inst,
                                               replace=True), :]
        if balX is not None:
            balX = np.stack((balX, extra), axis = 0) 
            baly = np.stack((baly, np.asarray([label for i in range(len(extra))])))
        else:
            balX = extra
            baly = np.asarray([label for i in range(len(extra))])
    balX = np.concatenate(balX)
    baly = np.concatenate(baly)
    return balX, baly

# %%
train_features, train_labels = balance_data(train_features, train_labels)
test_features, test_labels = balance_data(test_features, test_labels)

# %%
unique_elements, counts_elements = np.unique(train_labels, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))

unique_elements_test, counts_elements_test = np.unique(test_labels, return_counts=True)
print(np.asarray((unique_elements_test, counts_elements_test)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['32' '32']]
# [['Healthy' 'Pneumonia']
#  ['13' '13']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
le.fit(train_labels)
train_labels_cat = to_categorical(le.transform(train_labels)) 
test_labels_cat = to_categorical(le.transform(test_labels))

# %%
train_features.shape
# Out:
# (64, 40, 431)

# %%
train_features = np.reshape(train_features, (*train_features.shape,1)) 
print(train_features.shape, train_labels_cat.shape)
test_features = np.reshape(test_features, (*test_features.shape,1)) 
print(test_features.shape, test_labels_cat.shape)
# Out:
# (64, 40, 431, 1) (64, 2)
# (26, 40, 431, 1) (26, 2)

# %%
x_test, y_test = test_features, test_labels_cat
x_train, y_train = train_features, train_labels_cat

# %% [markdown]
# **CNN model architecture**

# %%
num_labels = train_labels_cat.shape[1]

num_rows = 40
num_columns = SIZE
num_channels = 1

filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(Conv2D(filters=16, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(Conv2D(filters=8, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(Conv2D(filters=4, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 430, 32)       160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 215, 32)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 215, 32)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 214, 16)       2064
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 107, 16)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 107, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 106, 8)         520
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 53, 8)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 53, 8)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 52, 4)          132
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 26, 4)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 26, 4)          0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 4)                 0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 10
# =================================================================
# Total params: 2,886
# Trainable params: 2,886
# Non-trainable params: 0
# _________________________________________________________________
# 26/26 [==============================] - 1s 47ms/sample - loss: 4.5775 - accuracy: 0.5000
# Pre-training accuracy: 50.0000%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 500
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/' + MODEL_NAME + '_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 64 samples, validate on 26 samples
# Epoch 1/500
# 60/64 [===========================>..] - ETA: 0s - loss: 13.9630 - accuracy: 0.5167
# Epoch 00001: val_accuracy improved from -inf to 0.50000, saving model to models/CNN2_dataset_2_no_augment_10_01.h5
# 64/64 [==============================] - 1s 18ms/sample - loss: 13.7161 - accuracy: 0.5000 - val_loss: 0.7331 - val_accuracy: 0.5000
# Epoch 2/500
# 60/64 [===========================>..] - ETA: 0s - loss: 5.2460 - accuracy: 0.5000
# Epoch 00002: val_accuracy did not improve from 0.50000
# 64/64 [==============================] - 0s 1ms/sample - loss: 5.2194 - accuracy: 0.5000 - val_loss: 0.8980 - val_accuracy: 0.5000
# Epoch 3/500
# 60/64 [===========================>..] - ETA: 0s - loss: 2.4791 - accuracy: 0.5000
# Epoch 00003: val_accuracy did not improve from 0.50000
# 64/64 [==============================] - 0s 1ms/sample - loss: 2.4156 - accuracy: 0.5000 - val_loss: 0.7802 - val_accuracy: 0.5000
# Epoch 4/500
# 60/64 [===========================>..] - ETA: 0s - loss: 1.3735 - accuracy: 0.4833
# Epoch 00004: val_accuracy improved from 0.50000 to 0.53846, saving model to models/CNN2_dataset_2_no_augment_10_04.h5
# 64/64 [==============================] - 0s 2ms/sample - loss: 1.3485 - accuracy: 0.4688 - val_loss: 0.6742 - val_accuracy: 0.5385
# Epoch 5/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.9258 - accuracy: 0.5000
# Epoch 00005: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.9294 - accuracy: 0.5000 - val_loss: 0.6851 - val_accuracy: 0.5000
# Epoch 6/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.9920 - accuracy: 0.4500
# Epoch 00006: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 1.0303 - accuracy: 0.4219 - val_loss: 0.6829 - val_accuracy: 0.5000
# Epoch 7/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.9246 - accuracy: 0.3833
# Epoch 00007: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.9233 - accuracy: 0.3906 - val_loss: 0.6659 - val_accuracy: 0.5000
# Epoch 8/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.9289 - accuracy: 0.4000
# Epoch 00008: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.9687 - accuracy: 0.3750 - val_loss: 0.6615 - val_accuracy: 0.5000
# Epoch 9/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.8069 - accuracy: 0.5333
# Epoch 00009: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.8058 - accuracy: 0.5312 - val_loss: 0.6618 - val_accuracy: 0.5000
# Epoch 10/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.8892 - accuracy: 0.3500
# Epoch 00010: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.8589 - accuracy: 0.3906 - val_loss: 0.6626 - val_accuracy: 0.5000
# Epoch 11/500
# 50/64 [======================>.......] - ETA: 0s - loss: 0.8250 - accuracy: 0.4800
# Epoch 00011: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.8174 - accuracy: 0.4531 - val_loss: 0.6629 - val_accuracy: 0.5000
# Epoch 12/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.7445 - accuracy: 0.5500
# Epoch 00012: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.7564 - accuracy: 0.5312 - val_loss: 0.6641 - val_accuracy: 0.5000
# Epoch 13/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.8297 - accuracy: 0.4333
# Epoch 00013: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.8504 - accuracy: 0.4062 - val_loss: 0.6605 - val_accuracy: 0.5000
# Epoch 14/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.7575 - accuracy: 0.4833
# Epoch 00014: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.7663 - accuracy: 0.4688 - val_loss: 0.6601 - val_accuracy: 0.5000
# Epoch 15/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.8456 - accuracy: 0.5167
# Epoch 00015: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.8565 - accuracy: 0.4844 - val_loss: 0.6583 - val_accuracy: 0.5000
# Epoch 16/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.7388 - accuracy: 0.5500
# Epoch 00016: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.7369 - accuracy: 0.5469 - val_loss: 0.6584 - val_accuracy: 0.5000
# Epoch 17/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.7612 - accuracy: 0.4500
# Epoch 00017: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.7730 - accuracy: 0.4531 - val_loss: 0.6609 - val_accuracy: 0.5000
# Epoch 18/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.7169 - accuracy: 0.5167
# Epoch 00018: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.7245 - accuracy: 0.5156 - val_loss: 0.6594 - val_accuracy: 0.5000
# Epoch 19/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.7718 - accuracy: 0.4833
# Epoch 00019: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.7536 - accuracy: 0.5000 - val_loss: 0.6627 - val_accuracy: 0.5000
# Epoch 20/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.7195 - accuracy: 0.5833
# Epoch 00020: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.7145 - accuracy: 0.5781 - val_loss: 0.6675 - val_accuracy: 0.5000
# Epoch 21/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.7218 - accuracy: 0.5500
# Epoch 00021: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.7067 - accuracy: 0.5781 - val_loss: 0.6723 - val_accuracy: 0.5000
# Epoch 22/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.7116 - accuracy: 0.5667
# Epoch 00022: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.7113 - accuracy: 0.5625 - val_loss: 0.6703 - val_accuracy: 0.5000
# Epoch 23/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.7740 - accuracy: 0.4667
# Epoch 00023: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.7893 - accuracy: 0.4375 - val_loss: 0.6713 - val_accuracy: 0.5000
# Epoch 24/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.7581 - accuracy: 0.5500
# Epoch 00024: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.7525 - accuracy: 0.5469 - val_loss: 0.6825 - val_accuracy: 0.5000
# Epoch 25/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.7253 - accuracy: 0.5500
# Epoch 00025: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.7343 - accuracy: 0.5312 - val_loss: 0.6884 - val_accuracy: 0.5000
# Epoch 26/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.6163 - accuracy: 0.6333
# Epoch 00026: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.6236 - accuracy: 0.6250 - val_loss: 0.6930 - val_accuracy: 0.5000
# Epoch 27/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.6437 - accuracy: 0.6000
# Epoch 00027: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.6613 - accuracy: 0.5938 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 28/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.7663 - accuracy: 0.5000
# Epoch 00028: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.7822 - accuracy: 0.4844 - val_loss: 0.6910 - val_accuracy: 0.5000
# Epoch 29/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.6526 - accuracy: 0.6500
# Epoch 00029: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.6690 - accuracy: 0.6250 - val_loss: 0.6745 - val_accuracy: 0.5000
# Epoch 30/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.6501 - accuracy: 0.6833
# Epoch 00030: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.6607 - accuracy: 0.6875 - val_loss: 0.6718 - val_accuracy: 0.5000
# Epoch 31/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.6274 - accuracy: 0.6500
# Epoch 00031: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.6265 - accuracy: 0.6562 - val_loss: 0.6772 - val_accuracy: 0.5000
# Epoch 32/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.6666 - accuracy: 0.6167
# Epoch 00032: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.6703 - accuracy: 0.5938 - val_loss: 0.6824 - val_accuracy: 0.5000
# Epoch 33/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.6417 - accuracy: 0.5667
# Epoch 00033: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.6455 - accuracy: 0.5781 - val_loss: 0.6850 - val_accuracy: 0.5000
# Epoch 34/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.6561 - accuracy: 0.5833
# Epoch 00034: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.6463 - accuracy: 0.5938 - val_loss: 0.6705 - val_accuracy: 0.5000
# Epoch 35/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.6533 - accuracy: 0.6000
# Epoch 00035: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.6680 - accuracy: 0.5781 - val_loss: 0.6771 - val_accuracy: 0.5000
# Epoch 36/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.6923 - accuracy: 0.6500
# Epoch 00036: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.6692 - accuracy: 0.6719 - val_loss: 0.6751 - val_accuracy: 0.5000
# Epoch 37/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.6586 - accuracy: 0.6167
# Epoch 00037: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.6782 - accuracy: 0.5938 - val_loss: 0.6815 - val_accuracy: 0.5000
# Epoch 38/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.6240 - accuracy: 0.6500
# Epoch 00038: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.6477 - accuracy: 0.6406 - val_loss: 0.6979 - val_accuracy: 0.5000
# Epoch 39/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.6201 - accuracy: 0.6833
# Epoch 00039: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.6269 - accuracy: 0.6875 - val_loss: 0.6926 - val_accuracy: 0.5000
# Epoch 40/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.6066 - accuracy: 0.7000
# Epoch 00040: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.6033 - accuracy: 0.7031 - val_loss: 0.6833 - val_accuracy: 0.5000
# Epoch 41/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.6775 - accuracy: 0.5667
# Epoch 00041: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.6596 - accuracy: 0.5938 - val_loss: 0.6963 - val_accuracy: 0.5000
# Epoch 42/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.5975 - accuracy: 0.6667
# Epoch 00042: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.6022 - accuracy: 0.6562 - val_loss: 0.7111 - val_accuracy: 0.5000
# Epoch 43/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.6135 - accuracy: 0.6500
# Epoch 00043: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.6084 - accuracy: 0.6719 - val_loss: 0.7352 - val_accuracy: 0.5000
# Epoch 44/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.6680 - accuracy: 0.5833
# Epoch 00044: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.6509 - accuracy: 0.6094 - val_loss: 0.7235 - val_accuracy: 0.5000
# Epoch 45/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.6117 - accuracy: 0.6000
# Epoch 00045: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.6199 - accuracy: 0.5938 - val_loss: 0.6868 - val_accuracy: 0.5000
# Epoch 46/500
# 50/64 [======================>.......] - ETA: 0s - loss: 0.5790 - accuracy: 0.7200
# Epoch 00046: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.5894 - accuracy: 0.6875 - val_loss: 0.7025 - val_accuracy: 0.5000
# Epoch 47/500
# 50/64 [======================>.......] - ETA: 0s - loss: 0.6398 - accuracy: 0.6600
# Epoch 00047: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.6134 - accuracy: 0.7031 - val_loss: 0.7145 - val_accuracy: 0.5000
# Epoch 48/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.5762 - accuracy: 0.7167
# Epoch 00048: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.5761 - accuracy: 0.7188 - val_loss: 0.7271 - val_accuracy: 0.5000
# Epoch 49/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.6377 - accuracy: 0.6833
# Epoch 00049: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.6320 - accuracy: 0.6875 - val_loss: 0.7216 - val_accuracy: 0.5000
# Epoch 50/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.5680 - accuracy: 0.7167
# Epoch 00050: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.5766 - accuracy: 0.7188 - val_loss: 0.7245 - val_accuracy: 0.5000
# Epoch 51/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.6139 - accuracy: 0.6500
# Epoch 00051: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.6183 - accuracy: 0.6406 - val_loss: 0.7218 - val_accuracy: 0.5000
# Epoch 52/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.6085 - accuracy: 0.7167
# Epoch 00052: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.6123 - accuracy: 0.7031 - val_loss: 0.7331 - val_accuracy: 0.5000
# Epoch 53/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.6093 - accuracy: 0.6667
# Epoch 00053: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.5983 - accuracy: 0.6719 - val_loss: 0.7424 - val_accuracy: 0.5000
# Epoch 54/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.6028 - accuracy: 0.7333
# Epoch 00054: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.5981 - accuracy: 0.7344 - val_loss: 0.7629 - val_accuracy: 0.5000
# Epoch 55/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.5221 - accuracy: 0.7500
# Epoch 00055: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.5661 - accuracy: 0.7344 - val_loss: 0.7751 - val_accuracy: 0.5000
# Epoch 56/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.5330 - accuracy: 0.7333
# Epoch 00056: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.5347 - accuracy: 0.7188 - val_loss: 0.7297 - val_accuracy: 0.5000
# Epoch 57/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.5152 - accuracy: 0.7167
# Epoch 00057: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.5292 - accuracy: 0.7188 - val_loss: 0.7361 - val_accuracy: 0.5000
# Epoch 58/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.4982 - accuracy: 0.7500
# Epoch 00058: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.5101 - accuracy: 0.7344 - val_loss: 0.7722 - val_accuracy: 0.5000
# Epoch 59/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.5629 - accuracy: 0.7167
# Epoch 00059: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.5704 - accuracy: 0.7031 - val_loss: 0.8131 - val_accuracy: 0.5000
# Epoch 60/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.5555 - accuracy: 0.7500
# Epoch 00060: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.5494 - accuracy: 0.7500 - val_loss: 0.7455 - val_accuracy: 0.5000
# Epoch 61/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.5935 - accuracy: 0.6833
# Epoch 00061: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.5919 - accuracy: 0.6875 - val_loss: 0.6966 - val_accuracy: 0.5000
# Epoch 62/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.4827 - accuracy: 0.7667
# Epoch 00062: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.4860 - accuracy: 0.7500 - val_loss: 0.7598 - val_accuracy: 0.5000
# Epoch 63/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.5762 - accuracy: 0.6833
# Epoch 00063: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.5598 - accuracy: 0.7031 - val_loss: 0.7782 - val_accuracy: 0.5000
# Epoch 64/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.5473 - accuracy: 0.7833
# Epoch 00064: val_accuracy did not improve from 0.53846
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.5486 - accuracy: 0.7812 - val_loss: 0.7350 - val_accuracy: 0.5000
# Epoch 65/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.4866 - accuracy: 0.7833
# Epoch 00065: val_accuracy improved from 0.53846 to 0.69231, saving model to models/CNN2_dataset_2_no_augment_10_65.h5
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.5176 - accuracy: 0.7656 - val_loss: 0.6684 - val_accuracy: 0.6923
# Epoch 66/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.4427 - accuracy: 0.8333
# Epoch 00066: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.4594 - accuracy: 0.8125 - val_loss: 0.7445 - val_accuracy: 0.5000
# Epoch 67/500
# 50/64 [======================>.......] - ETA: 0s - loss: 0.4762 - accuracy: 0.8400
# Epoch 00067: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.5217 - accuracy: 0.7812 - val_loss: 0.7247 - val_accuracy: 0.5000
# Epoch 68/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.4769 - accuracy: 0.7500
# Epoch 00068: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.4642 - accuracy: 0.7500 - val_loss: 0.6814 - val_accuracy: 0.6923
# Epoch 69/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.4689 - accuracy: 0.7833
# Epoch 00069: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.4702 - accuracy: 0.7969 - val_loss: 0.6953 - val_accuracy: 0.6923
# Epoch 70/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.4722 - accuracy: 0.8167
# Epoch 00070: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.4660 - accuracy: 0.8125 - val_loss: 0.6572 - val_accuracy: 0.6923
# Epoch 71/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.5109 - accuracy: 0.8167
# Epoch 00071: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.4916 - accuracy: 0.8281 - val_loss: 0.6854 - val_accuracy: 0.6923
# Epoch 72/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.3879 - accuracy: 0.8667
# Epoch 00072: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.4039 - accuracy: 0.8438 - val_loss: 0.6157 - val_accuracy: 0.6923
# Epoch 73/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.4362 - accuracy: 0.8000
# Epoch 00073: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.4302 - accuracy: 0.7969 - val_loss: 0.6705 - val_accuracy: 0.6923
# Epoch 74/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.4391 - accuracy: 0.8333
# Epoch 00074: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.4188 - accuracy: 0.8438 - val_loss: 0.6276 - val_accuracy: 0.6923
# Epoch 75/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.4116 - accuracy: 0.8667
# Epoch 00075: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.4020 - accuracy: 0.8594 - val_loss: 0.6097 - val_accuracy: 0.6923
# Epoch 76/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.3951 - accuracy: 0.8000
# Epoch 00076: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.4107 - accuracy: 0.7969 - val_loss: 0.5989 - val_accuracy: 0.6923
# Epoch 77/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.3495 - accuracy: 0.8667
# Epoch 00077: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3557 - accuracy: 0.8594 - val_loss: 0.6339 - val_accuracy: 0.6923
# Epoch 78/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.4103 - accuracy: 0.8167
# Epoch 00078: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.4314 - accuracy: 0.8125 - val_loss: 0.6441 - val_accuracy: 0.6923
# Epoch 79/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.3348 - accuracy: 0.8833
# Epoch 00079: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.3402 - accuracy: 0.8750 - val_loss: 0.9594 - val_accuracy: 0.5000
# Epoch 80/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.3790 - accuracy: 0.8500
# Epoch 00080: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3700 - accuracy: 0.8594 - val_loss: 0.5552 - val_accuracy: 0.6923
# Epoch 81/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.3875 - accuracy: 0.7667
# Epoch 00081: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3766 - accuracy: 0.7812 - val_loss: 0.6391 - val_accuracy: 0.6923
# Epoch 82/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.3646 - accuracy: 0.8500
# Epoch 00082: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.3692 - accuracy: 0.8281 - val_loss: 0.6570 - val_accuracy: 0.6923
# Epoch 83/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.3348 - accuracy: 0.8833
# Epoch 00083: val_accuracy improved from 0.69231 to 0.84615, saving model to models/CNN2_dataset_2_no_augment_10_83.h5
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.3284 - accuracy: 0.8906 - val_loss: 0.4615 - val_accuracy: 0.8462
# Epoch 84/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.3459 - accuracy: 0.8333
# Epoch 00084: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.3689 - accuracy: 0.8125 - val_loss: 0.6707 - val_accuracy: 0.6923
# Epoch 85/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.3557 - accuracy: 0.8833
# Epoch 00085: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3509 - accuracy: 0.8906 - val_loss: 0.6190 - val_accuracy: 0.6923
# Epoch 86/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.3003 - accuracy: 0.9000
# Epoch 00086: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3002 - accuracy: 0.8906 - val_loss: 0.4174 - val_accuracy: 0.8462
# Epoch 87/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3624 - accuracy: 0.7000
# Epoch 00087: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3362 - accuracy: 0.7969 - val_loss: 0.5487 - val_accuracy: 0.6923
# Epoch 88/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.3203 - accuracy: 0.8333
# Epoch 00088: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3088 - accuracy: 0.8438 - val_loss: 0.4679 - val_accuracy: 0.8462
# Epoch 89/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2678 - accuracy: 0.9000
# Epoch 00089: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2585 - accuracy: 0.9062 - val_loss: 0.3617 - val_accuracy: 0.8462
# Epoch 90/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.3318 - accuracy: 0.8667
# Epoch 00090: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3416 - accuracy: 0.8594 - val_loss: 0.4487 - val_accuracy: 0.8462
# Epoch 91/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2688 - accuracy: 0.9000
# Epoch 00091: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2667 - accuracy: 0.9062 - val_loss: 0.5507 - val_accuracy: 0.6923
# Epoch 92/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2129 - accuracy: 0.9000
# Epoch 00092: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2444 - accuracy: 0.8906 - val_loss: 0.3878 - val_accuracy: 0.8462
# Epoch 93/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2403 - accuracy: 0.8667
# Epoch 00093: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2368 - accuracy: 0.8750 - val_loss: 0.5353 - val_accuracy: 0.6923
# Epoch 94/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2823 - accuracy: 0.8333
# Epoch 00094: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2772 - accuracy: 0.8438 - val_loss: 0.3931 - val_accuracy: 0.8462
# Epoch 95/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1874 - accuracy: 0.9667
# Epoch 00095: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.1779 - accuracy: 0.9688 - val_loss: 0.5385 - val_accuracy: 0.8462
# Epoch 96/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.3361 - accuracy: 0.8167
# Epoch 00096: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.3591 - accuracy: 0.8125 - val_loss: 0.3001 - val_accuracy: 0.7692
# Epoch 97/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.3578 - accuracy: 0.8167
# Epoch 00097: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.3546 - accuracy: 0.8125 - val_loss: 0.3323 - val_accuracy: 0.8462
# Epoch 98/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.3672 - accuracy: 0.8333
# Epoch 00098: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.3458 - accuracy: 0.8438 - val_loss: 0.4325 - val_accuracy: 0.8462
# Epoch 99/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2250 - accuracy: 0.9167
# Epoch 00099: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.2323 - accuracy: 0.9062 - val_loss: 0.2713 - val_accuracy: 0.8077
# Epoch 100/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.3482 - accuracy: 0.8667
# Epoch 00100: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.3386 - accuracy: 0.8750 - val_loss: 0.2927 - val_accuracy: 0.8462
# Epoch 101/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2226 - accuracy: 0.9333
# Epoch 00101: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.2312 - accuracy: 0.9219 - val_loss: 0.3281 - val_accuracy: 0.8462
# Epoch 102/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1998 - accuracy: 0.9333
# Epoch 00102: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.2327 - accuracy: 0.9219 - val_loss: 0.3966 - val_accuracy: 0.8462
# Epoch 103/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2732 - accuracy: 0.8833
# Epoch 00103: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.2875 - accuracy: 0.8750 - val_loss: 0.2994 - val_accuracy: 0.8077
# Epoch 104/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2226 - accuracy: 0.9000
# Epoch 00104: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.2347 - accuracy: 0.8906 - val_loss: 0.4438 - val_accuracy: 0.8462
# Epoch 105/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2291 - accuracy: 0.9167
# Epoch 00105: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.2162 - accuracy: 0.9219 - val_loss: 0.4437 - val_accuracy: 0.8462
# Epoch 106/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2156 - accuracy: 0.9167
# Epoch 00106: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.2194 - accuracy: 0.9062 - val_loss: 0.3381 - val_accuracy: 0.8077
# Epoch 107/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2062 - accuracy: 0.9667
# Epoch 00107: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.2646 - accuracy: 0.9375 - val_loss: 0.5251 - val_accuracy: 0.8462
# Epoch 108/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.3039 - accuracy: 0.8667
# Epoch 00108: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2923 - accuracy: 0.8750 - val_loss: 0.3086 - val_accuracy: 0.8077
# Epoch 109/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2470 - accuracy: 0.8833
# Epoch 00109: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2345 - accuracy: 0.8906 - val_loss: 0.3979 - val_accuracy: 0.8462
# Epoch 110/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2413 - accuracy: 0.8667
# Epoch 00110: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2430 - accuracy: 0.8750 - val_loss: 0.4590 - val_accuracy: 0.8462
# Epoch 111/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2574 - accuracy: 0.9000
# Epoch 00111: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2510 - accuracy: 0.9062 - val_loss: 0.3010 - val_accuracy: 0.8077
# Epoch 112/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.3211 - accuracy: 0.8667
# Epoch 00112: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.3077 - accuracy: 0.8750 - val_loss: 0.3370 - val_accuracy: 0.8077
# Epoch 113/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2204 - accuracy: 0.9500
# Epoch 00113: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2079 - accuracy: 0.9531 - val_loss: 0.5114 - val_accuracy: 0.8462
# Epoch 114/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2946 - accuracy: 0.8667
# Epoch 00114: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.3037 - accuracy: 0.8594 - val_loss: 0.3569 - val_accuracy: 0.8077
# Epoch 115/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2400 - accuracy: 0.9000
# Epoch 00115: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2347 - accuracy: 0.9062 - val_loss: 0.3192 - val_accuracy: 0.8077
# Epoch 116/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2373 - accuracy: 0.9000
# Epoch 00116: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2302 - accuracy: 0.9062 - val_loss: 0.3596 - val_accuracy: 0.8462
# Epoch 117/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1845 - accuracy: 0.9333
# Epoch 00117: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1798 - accuracy: 0.9375 - val_loss: 0.3178 - val_accuracy: 0.8462
# Epoch 118/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2148 - accuracy: 0.8667
# Epoch 00118: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.2022 - accuracy: 0.8750 - val_loss: 0.2523 - val_accuracy: 0.7692
# Epoch 119/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1972 - accuracy: 0.9500
# Epoch 00119: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.1945 - accuracy: 0.9531 - val_loss: 0.2784 - val_accuracy: 0.8077
# Epoch 120/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1908 - accuracy: 0.9167
# Epoch 00120: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1798 - accuracy: 0.9219 - val_loss: 0.2938 - val_accuracy: 0.8077
# Epoch 121/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1595 - accuracy: 0.9333
# Epoch 00121: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.1777 - accuracy: 0.9219 - val_loss: 0.3297 - val_accuracy: 0.8077
# Epoch 122/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2214 - accuracy: 0.9333
# Epoch 00122: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2120 - accuracy: 0.9375 - val_loss: 0.3481 - val_accuracy: 0.8077
# Epoch 123/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1401 - accuracy: 0.9667
# Epoch 00123: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.1373 - accuracy: 0.9688 - val_loss: 0.3273 - val_accuracy: 0.8077
# Epoch 124/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2181 - accuracy: 0.9000
# Epoch 00124: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.2119 - accuracy: 0.9062 - val_loss: 0.4490 - val_accuracy: 0.8462
# Epoch 125/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2356 - accuracy: 0.8833
# Epoch 00125: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2239 - accuracy: 0.8906 - val_loss: 0.2897 - val_accuracy: 0.7692
# Epoch 126/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.3470 - accuracy: 0.9167
# Epoch 00126: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.3371 - accuracy: 0.9219 - val_loss: 0.3584 - val_accuracy: 0.8077
# Epoch 127/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2427 - accuracy: 0.8833
# Epoch 00127: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.2444 - accuracy: 0.8750 - val_loss: 0.3125 - val_accuracy: 0.8077
# Epoch 128/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2694 - accuracy: 0.8833
# Epoch 00128: val_accuracy improved from 0.84615 to 0.92308, saving model to models/CNN2_dataset_2_no_augment_10_128.h5
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.2597 - accuracy: 0.8906 - val_loss: 0.2307 - val_accuracy: 0.9231
# Epoch 129/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1906 - accuracy: 0.9000
# Epoch 00129: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.1887 - accuracy: 0.9062 - val_loss: 0.3166 - val_accuracy: 0.8462
# Epoch 130/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1480 - accuracy: 0.9333
# Epoch 00130: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.1528 - accuracy: 0.9219 - val_loss: 0.2710 - val_accuracy: 0.8077
# Epoch 131/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2277 - accuracy: 0.8833
# Epoch 00131: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.2147 - accuracy: 0.8906 - val_loss: 0.3031 - val_accuracy: 0.8077
# Epoch 132/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1884 - accuracy: 0.9000
# Epoch 00132: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.1840 - accuracy: 0.9062 - val_loss: 0.2702 - val_accuracy: 0.8077
# Epoch 133/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2640 - accuracy: 0.8667
# Epoch 00133: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.2567 - accuracy: 0.8750 - val_loss: 0.2880 - val_accuracy: 0.8077
# Epoch 134/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1878 - accuracy: 0.9333
# Epoch 00134: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.1772 - accuracy: 0.9375 - val_loss: 0.3612 - val_accuracy: 0.8462
# Epoch 135/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1806 - accuracy: 0.9000
# Epoch 00135: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.1702 - accuracy: 0.9062 - val_loss: 0.2309 - val_accuracy: 0.9231
# Epoch 136/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1925 - accuracy: 0.9167
# Epoch 00136: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1867 - accuracy: 0.9219 - val_loss: 0.2574 - val_accuracy: 0.8077
# Epoch 137/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1559 - accuracy: 0.9500
# Epoch 00137: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1481 - accuracy: 0.9531 - val_loss: 0.3353 - val_accuracy: 0.8462
# Epoch 138/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.3026 - accuracy: 0.8667
# Epoch 00138: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.2962 - accuracy: 0.8594 - val_loss: 0.2325 - val_accuracy: 0.7692
# Epoch 139/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1355 - accuracy: 0.9667
# Epoch 00139: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.1285 - accuracy: 0.9688 - val_loss: 0.2546 - val_accuracy: 0.8077
# Epoch 140/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1731 - accuracy: 0.9333
# Epoch 00140: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1691 - accuracy: 0.9375 - val_loss: 0.2823 - val_accuracy: 0.8077
# Epoch 141/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1591 - accuracy: 0.9167
# Epoch 00141: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1720 - accuracy: 0.9062 - val_loss: 0.2863 - val_accuracy: 0.8077
# Epoch 142/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2045 - accuracy: 0.9000
# Epoch 00142: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1926 - accuracy: 0.9062 - val_loss: 0.3228 - val_accuracy: 0.8077
# Epoch 143/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1810 - accuracy: 0.9167
# Epoch 00143: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1912 - accuracy: 0.9062 - val_loss: 0.3562 - val_accuracy: 0.8462
# Epoch 144/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1613 - accuracy: 0.9667
# Epoch 00144: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1984 - accuracy: 0.9531 - val_loss: 0.3198 - val_accuracy: 0.8077
# Epoch 145/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2402 - accuracy: 0.9000
# Epoch 00145: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2347 - accuracy: 0.9062 - val_loss: 0.2225 - val_accuracy: 0.9231
# Epoch 146/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2367 - accuracy: 0.9000
# Epoch 00146: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2506 - accuracy: 0.8906 - val_loss: 0.2416 - val_accuracy: 0.8077
# Epoch 147/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2023 - accuracy: 0.9000
# Epoch 00147: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1984 - accuracy: 0.9062 - val_loss: 0.4285 - val_accuracy: 0.8462
# Epoch 148/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1877 - accuracy: 0.9500
# Epoch 00148: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1769 - accuracy: 0.9531 - val_loss: 0.2230 - val_accuracy: 0.9231
# Epoch 149/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2648 - accuracy: 0.8667
# Epoch 00149: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2620 - accuracy: 0.8750 - val_loss: 0.2184 - val_accuracy: 0.8077
# Epoch 150/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1945 - accuracy: 0.8833
# Epoch 00150: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1871 - accuracy: 0.8906 - val_loss: 0.2837 - val_accuracy: 0.8462
# Epoch 151/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1912 - accuracy: 1.0000
# Epoch 00151: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1354 - accuracy: 0.9375 - val_loss: 0.2018 - val_accuracy: 0.9231
# Epoch 152/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2957 - accuracy: 0.9167
# Epoch 00152: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2789 - accuracy: 0.9219 - val_loss: 0.2498 - val_accuracy: 0.8077
# Epoch 153/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1618 - accuracy: 0.9500
# Epoch 00153: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1614 - accuracy: 0.9531 - val_loss: 0.3275 - val_accuracy: 0.8462
# Epoch 154/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1484 - accuracy: 0.9667
# Epoch 00154: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.1485 - accuracy: 0.9688 - val_loss: 0.3340 - val_accuracy: 0.8077
# Epoch 155/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1625 - accuracy: 0.9500
# Epoch 00155: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1596 - accuracy: 0.9531 - val_loss: 0.2649 - val_accuracy: 0.8077
# Epoch 156/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2205 - accuracy: 0.8833
# Epoch 00156: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2151 - accuracy: 0.8906 - val_loss: 0.2262 - val_accuracy: 0.7692
# Epoch 157/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1912 - accuracy: 0.9000
# Epoch 00157: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1798 - accuracy: 0.9062 - val_loss: 0.3645 - val_accuracy: 0.8462
# Epoch 158/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2155 - accuracy: 0.9333
# Epoch 00158: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2398 - accuracy: 0.9219 - val_loss: 0.2448 - val_accuracy: 0.8077
# Epoch 159/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2207 - accuracy: 0.9167
# Epoch 00159: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2355 - accuracy: 0.9062 - val_loss: 0.1971 - val_accuracy: 0.9231
# Epoch 160/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1835 - accuracy: 0.9000
# Epoch 00160: val_accuracy did not improve from 0.92308
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1746 - accuracy: 0.9062 - val_loss: 0.2427 - val_accuracy: 0.8077
# Epoch 161/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1723 - accuracy: 0.9167
# Epoch 00161: val_accuracy improved from 0.92308 to 0.96154, saving model to models/CNN2_dataset_2_no_augment_10_161.h5
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.1630 - accuracy: 0.9219 - val_loss: 0.1860 - val_accuracy: 0.9615
# Epoch 162/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1712 - accuracy: 0.8833
# Epoch 00162: val_accuracy did not improve from 0.96154
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.1646 - accuracy: 0.8906 - val_loss: 0.2149 - val_accuracy: 0.8077
# Epoch 163/500
# 50/64 [======================>.......] - ETA: 0s - loss: 0.1933 - accuracy: 0.8800
# Epoch 00163: val_accuracy did not improve from 0.96154
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.2043 - accuracy: 0.8750 - val_loss: 0.3014 - val_accuracy: 0.8462
# Epoch 164/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1999 - accuracy: 0.9000
# Epoch 00164: val_accuracy did not improve from 0.96154
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.1979 - accuracy: 0.9062 - val_loss: 0.2438 - val_accuracy: 0.8077
# Epoch 165/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1619 - accuracy: 0.9500
# Epoch 00165: val_accuracy did not improve from 0.96154
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1566 - accuracy: 0.9531 - val_loss: 0.2146 - val_accuracy: 0.9231
# Epoch 166/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1715 - accuracy: 0.9000
# Epoch 00166: val_accuracy did not improve from 0.96154
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1611 - accuracy: 0.9062 - val_loss: 0.3321 - val_accuracy: 0.8462
# Epoch 167/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1232 - accuracy: 0.9667
# Epoch 00167: val_accuracy did not improve from 0.96154
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1498 - accuracy: 0.9375 - val_loss: 0.3363 - val_accuracy: 0.8462
# Epoch 168/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1995 - accuracy: 0.9333
# Epoch 00168: val_accuracy did not improve from 0.96154
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1979 - accuracy: 0.9375 - val_loss: 0.2559 - val_accuracy: 0.8077
# Epoch 169/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1865 - accuracy: 0.9500
# ...
# Epoch 445/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0241 - accuracy: 1.0000
# Epoch 00445: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0977 - accuracy: 0.9688 - val_loss: 0.1743 - val_accuracy: 0.9231
# Epoch 446/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0107 - accuracy: 1.0000
# Epoch 00446: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.0250 - val_accuracy: 1.0000
# Epoch 447/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0751 - accuracy: 0.9500
# Epoch 00447: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0704 - accuracy: 0.9531 - val_loss: 0.0895 - val_accuracy: 0.9615
# Epoch 448/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0148 - accuracy: 1.0000
# Epoch 00448: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.1803 - val_accuracy: 0.8846
# Epoch 449/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0150 - accuracy: 1.0000
# Epoch 00449: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0395 - accuracy: 0.9844 - val_loss: 0.1029 - val_accuracy: 0.9615
# Epoch 450/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0513 - accuracy: 0.9833
# Epoch 00450: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0496 - accuracy: 0.9844 - val_loss: 0.1064 - val_accuracy: 0.9231
# Epoch 451/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0514 - accuracy: 0.9833
# Epoch 00451: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0535 - accuracy: 0.9844 - val_loss: 0.3212 - val_accuracy: 0.8077
# Epoch 452/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0204 - accuracy: 1.0000
# Epoch 00452: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0671 - accuracy: 0.9844 - val_loss: 0.1866 - val_accuracy: 0.9231
# Epoch 453/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0436 - accuracy: 0.9833
# Epoch 00453: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0469 - accuracy: 0.9844 - val_loss: 0.0380 - val_accuracy: 1.0000
# Epoch 454/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0262 - accuracy: 1.0000
# Epoch 00454: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0245 - accuracy: 1.0000 - val_loss: 0.0533 - val_accuracy: 1.0000
# Epoch 455/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2588 - accuracy: 0.9000
# Epoch 00455: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0598 - accuracy: 0.9844 - val_loss: 0.3173 - val_accuracy: 0.8077
# Epoch 456/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1891 - accuracy: 0.9500
# Epoch 00456: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1781 - accuracy: 0.9531 - val_loss: 0.0763 - val_accuracy: 0.9615
# Epoch 457/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0501 - accuracy: 0.9833
# Epoch 00457: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0472 - accuracy: 0.9844 - val_loss: 0.0951 - val_accuracy: 1.0000
# Epoch 458/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0249 - accuracy: 1.0000
# Epoch 00458: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0823 - accuracy: 0.9531 - val_loss: 0.0755 - val_accuracy: 0.9615
# Epoch 459/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0244 - accuracy: 1.0000
# Epoch 00459: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0229 - accuracy: 1.0000 - val_loss: 0.3102 - val_accuracy: 0.8077
# Epoch 460/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0843 - accuracy: 0.9833
# Epoch 00460: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0791 - accuracy: 0.9844 - val_loss: 0.0664 - val_accuracy: 0.9615
# Epoch 461/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0480 - accuracy: 0.9667
# Epoch 00461: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0462 - accuracy: 0.9688 - val_loss: 0.0365 - val_accuracy: 1.0000
# Epoch 462/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0509 - accuracy: 0.9667
# Epoch 00462: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0477 - accuracy: 0.9688 - val_loss: 0.0999 - val_accuracy: 0.9615
# Epoch 463/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0311 - accuracy: 1.0000
# Epoch 00463: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0292 - accuracy: 1.0000 - val_loss: 0.1792 - val_accuracy: 0.9231
# Epoch 464/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0444 - accuracy: 0.9667
# Epoch 00464: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0426 - accuracy: 0.9688 - val_loss: 0.0276 - val_accuracy: 1.0000
# Epoch 465/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0353 - accuracy: 0.9833
# Epoch 00465: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0372 - accuracy: 0.9844 - val_loss: 0.0306 - val_accuracy: 1.0000
# Epoch 466/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0145 - accuracy: 1.0000
# Epoch 00466: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0183 - accuracy: 1.0000 - val_loss: 0.1194 - val_accuracy: 0.9615
# Epoch 467/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0275 - accuracy: 1.0000
# Epoch 00467: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0546 - accuracy: 0.9844 - val_loss: 0.1508 - val_accuracy: 0.9615
# Epoch 468/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0616 - accuracy: 0.9833
# Epoch 00468: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0614 - accuracy: 0.9844 - val_loss: 0.0373 - val_accuracy: 1.0000
# Epoch 469/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0296 - accuracy: 0.9833
# Epoch 00469: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0281 - accuracy: 0.9844 - val_loss: 0.0583 - val_accuracy: 1.0000
# Epoch 470/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0250 - accuracy: 1.0000
# Epoch 00470: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0252 - accuracy: 1.0000 - val_loss: 0.0554 - val_accuracy: 0.9615
# Epoch 471/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1562 - accuracy: 0.9667
# Epoch 00471: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1483 - accuracy: 0.9688 - val_loss: 0.1639 - val_accuracy: 0.9231
# Epoch 472/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0749 - accuracy: 0.9000
# Epoch 00472: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0313 - accuracy: 0.9844 - val_loss: 0.1538 - val_accuracy: 0.9231
# Epoch 473/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0237 - accuracy: 1.0000
# Epoch 00473: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.0925 - val_accuracy: 0.9615
# Epoch 474/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0525 - accuracy: 0.9833
# Epoch 00474: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0493 - accuracy: 0.9844 - val_loss: 0.0275 - val_accuracy: 1.0000
# Epoch 475/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0683 - accuracy: 0.9833
# Epoch 00475: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0644 - accuracy: 0.9844 - val_loss: 0.3396 - val_accuracy: 0.8077
# Epoch 476/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0531 - accuracy: 0.9667
# Epoch 00476: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0939 - accuracy: 0.9531 - val_loss: 0.1179 - val_accuracy: 0.9615
# Epoch 477/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1090 - accuracy: 0.9333
# Epoch 00477: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1024 - accuracy: 0.9375 - val_loss: 0.2224 - val_accuracy: 0.8462
# Epoch 478/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0544 - accuracy: 0.9833
# Epoch 00478: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0517 - accuracy: 0.9844 - val_loss: 0.0624 - val_accuracy: 0.9615
# Epoch 479/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0190 - accuracy: 1.0000
# Epoch 00479: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.0857 - val_accuracy: 0.9615
# Epoch 480/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0339 - accuracy: 0.9833
# Epoch 00480: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0373 - accuracy: 0.9844 - val_loss: 0.1105 - val_accuracy: 0.9615
# Epoch 481/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0130 - accuracy: 1.0000
# Epoch 00481: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.0696 - val_accuracy: 0.9615
# Epoch 482/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0429 - accuracy: 0.9833
# Epoch 00482: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0404 - accuracy: 0.9844 - val_loss: 0.1229 - val_accuracy: 0.9615
# Epoch 483/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0374 - accuracy: 0.9833
# Epoch 00483: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0359 - accuracy: 0.9844 - val_loss: 0.0929 - val_accuracy: 0.9615
# Epoch 484/500
# 40/64 [=================>............] - ETA: 0s - loss: 0.0089 - accuracy: 1.0000
# Epoch 00484: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.0886 - val_accuracy: 0.9615
# Epoch 485/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0213 - accuracy: 1.0000
# Epoch 00485: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.1864 - val_accuracy: 0.9231
# Epoch 486/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0106 - accuracy: 1.0000
# Epoch 00486: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.2476 - val_accuracy: 0.8077
# Epoch 487/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0383 - accuracy: 0.9833
# Epoch 00487: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0361 - accuracy: 0.9844 - val_loss: 0.1136 - val_accuracy: 0.9615
# Epoch 488/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 00488: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0163 - accuracy: 1.0000 - val_loss: 0.0932 - val_accuracy: 0.9615
# Epoch 489/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0084 - accuracy: 1.0000
# Epoch 00489: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0261 - accuracy: 0.9844 - val_loss: 0.0830 - val_accuracy: 0.9615
# Epoch 490/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0208 - accuracy: 1.0000
# Epoch 00490: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.0697 - val_accuracy: 0.9615
# Epoch 491/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0542 - accuracy: 0.9500
# Epoch 00491: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0510 - accuracy: 0.9531 - val_loss: 0.3762 - val_accuracy: 0.8077
# Epoch 492/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0349 - accuracy: 0.9833
# Epoch 00492: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0328 - accuracy: 0.9844 - val_loss: 0.1986 - val_accuracy: 0.8846
# Epoch 493/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0282 - accuracy: 0.9833
# Epoch 00493: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0264 - accuracy: 0.9844 - val_loss: 0.0580 - val_accuracy: 0.9615
# Epoch 494/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0194 - accuracy: 1.0000
# Epoch 00494: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.0603 - val_accuracy: 0.9615
# Epoch 495/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0129 - accuracy: 1.0000
# Epoch 00495: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.0867 - val_accuracy: 0.9615
# Epoch 496/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0294 - accuracy: 0.9833
# Epoch 00496: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0288 - accuracy: 0.9844 - val_loss: 0.1423 - val_accuracy: 0.9615
# Epoch 497/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0291 - accuracy: 0.9833
# Epoch 00497: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0310 - accuracy: 0.9844 - val_loss: 0.1231 - val_accuracy: 0.9615
# Epoch 498/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0131 - accuracy: 1.0000
# Epoch 00498: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0166 - accuracy: 1.0000 - val_loss: 0.0854 - val_accuracy: 0.9615
# Epoch 499/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0671 - accuracy: 0.9667
# Epoch 00499: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0629 - accuracy: 0.9688 - val_loss: 0.0509 - val_accuracy: 0.9615
# Epoch 500/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.0393 - accuracy: 0.9833
# Epoch 00500: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.0371 - accuracy: 0.9844 - val_loss: 0.1946 - val_accuracy: 0.8846
# Training completed in time:  0:00:47.203575

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
train_acc = score[1]
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
test_acc = score[1]
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  1.0
# Testing Accuracy:  0.88461536

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.81      1.00      0.90        13
#    Pneumonia       1.00      0.77      0.87        13
#
#     accuracy                           0.88        26
#    macro avg       0.91      0.88      0.88        26
# weighted avg       0.91      0.88      0.88        26

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[13  0]
#  [ 3 10]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])

# %% [markdown]
# __Write CSV__

# %%
with open('report.csv', 'a') as report:
    report.write(f'{MODEL_NAME},{DATASET},{GROUP_TRAIN},{DURATION},{train_acc},{test_acc}\n')
