# %% [markdown]
# # Rede CNN - Modelo 2
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - Dataset 2 - no_augment_5

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP_TRAIN = 'no_augment_5'
GROUP_TEST = 'no_augment_5'
DATASET = 'dataset_2'
DURATION = 5
SIZE = 216
CSV_TRAIN = 'train2.csv'
CSV_TEST = 'test2.csv'
MODEL_NAME = f'CNN2_{DATASET}_{GROUP_TRAIN}'

# %%
train_file_paths = glob.glob(f'../datasets/{DATASET}/{GROUP_TRAIN}/train/**/*.wav', recursive=True)
train_file_names = [os.path.splitext(os.path.basename(p))[0] for p in train_file_paths]

test_file_paths = glob.glob(f'../datasets/{DATASET}/{GROUP_TEST}/test/**/*.wav', recursive=True)
test_file_names = [os.path.splitext(os.path.basename(p))[0] for p in test_file_paths]

# %%
train_p_id_in_file = [] # patient IDs corresponding to each file
test_p_id_in_file = [] # patient IDs corresponding to each file
for name in train_file_names:
    train_p_id_in_file.append(int(name[:3]))

for name in test_file_names:
    test_p_id_in_file.append(int(name[:3]))

train_p_id_in_file = np.array(train_p_id_in_file)
test_p_id_in_file = np.array(test_p_id_in_file)

# %%
max_pad_len = SIZE

os.makedirs("features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=DURATION) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
train_p_diag = pd.read_csv(f"../Respiratory_Sound_Database/Respiratory_Sound_Database_Pneumo_Healthy_Only/{CSV_TRAIN}", header=None) # patient diagnosis file
test_p_diag = pd.read_csv(f"../Respiratory_Sound_Database/Respiratory_Sound_Database_Pneumo_Healthy_Only/{CSV_TEST}", header=None) # patient diagnosis file
train_p_diag.head(5)
# Out:
#      0        1
# 0  123  Healthy
# 1  125  Healthy
# 2  126  Healthy
# 3  127  Healthy
# 4  136  Healthy

# %%
train_labels = np.array([train_p_diag[train_p_diag[0] == x][1].values[0] for x in train_p_id_in_file]) 
test_labels = np.array([test_p_diag[test_p_diag[0] == x][1].values[0] for x in test_p_id_in_file])

# %%
train_features = [] 
test_features = []

for file_name in train_file_paths:
    data = extract_features(file_name)
    train_features.append(data)

for file_name in test_file_paths:
    data = extract_features(file_name)
    test_features.append(data)

print('Finished feature extraction from ', (len(train_features)+len(train_features)), ' files')
train_features = np.array(train_features)
test_features = np.array(test_features)
# Out:
# Finished feature extraction from  112  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(train_features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
np.unique(train_labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
unique_elements, counts_elements = np.unique(train_labels, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))

unique_elements_test, counts_elements_test = np.unique(test_labels, return_counts=True)
print(np.asarray((unique_elements_test, counts_elements_test)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['32' '24']]
# [['Healthy' 'Pneumonia']
#  ['3' '13']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %% [markdown]
# __Balanceando dados__

# %%
def balance_data(X, labels):
    """Balances data duplicating some instances of the minority classes"""
    balX = None
    baly = None
    unique, counts = np.unique(labels, return_counts=True)
    max_inst = max(counts)
    # For every class duplicate the necessary amount
    for label in unique:
        data_of_label = []
        for x, y in zip(X, labels):
            if y == label:
                data_of_label.append(x)
        data_of_label = np.asarray(data_of_label)
        extra = data_of_label[np.random.choice(data_of_label.shape[0],
                                               max_inst,
                                               replace=True), :]
        if balX is not None:
            balX = np.stack((balX, extra), axis = 0) 
            baly = np.stack((baly, np.asarray([label for i in range(len(extra))])))
        else:
            balX = extra
            baly = np.asarray([label for i in range(len(extra))])
    balX = np.concatenate(balX)
    baly = np.concatenate(baly)
    return balX, baly

# %%
train_features, train_labels = balance_data(train_features, train_labels)
test_features, test_labels = balance_data(test_features, test_labels)

# %%
unique_elements, counts_elements = np.unique(train_labels, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))

unique_elements_test, counts_elements_test = np.unique(test_labels, return_counts=True)
print(np.asarray((unique_elements_test, counts_elements_test)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['32' '32']]
# [['Healthy' 'Pneumonia']
#  ['13' '13']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
le.fit(train_labels)
train_labels_cat = to_categorical(le.transform(train_labels)) 
test_labels_cat = to_categorical(le.transform(test_labels))

# %%
train_features.shape
# Out:
# (64, 40, 216)

# %%
train_features = np.reshape(train_features, (*train_features.shape,1)) 
print(train_features.shape, train_labels_cat.shape)
test_features = np.reshape(test_features, (*test_features.shape,1)) 
print(test_features.shape, test_labels_cat.shape)
# Out:
# (64, 40, 216, 1) (64, 2)
# (26, 40, 216, 1) (26, 2)

# %%
x_test, y_test = test_features, test_labels_cat
x_train, y_train = train_features, train_labels_cat

# %% [markdown]
# **CNN model architecture**

# %%
num_labels = train_labels_cat.shape[1]

num_rows = 40
num_columns = SIZE
num_channels = 1

filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(Conv2D(filters=16, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(Conv2D(filters=8, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(Conv2D(filters=4, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 215, 32)       160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 107, 32)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 107, 32)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 106, 16)       2064
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 53, 16)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 53, 16)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 52, 8)          520
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 26, 8)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 26, 8)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 25, 4)          132
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 12, 4)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 12, 4)          0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 4)                 0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 10
# =================================================================
# Total params: 2,886
# Trainable params: 2,886
# Non-trainable params: 0
# _________________________________________________________________
# 26/26 [==============================] - 1s 36ms/sample - loss: 1.0049 - accuracy: 0.5000
# Pre-training accuracy: 50.0000%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 500
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/' + MODEL_NAME + '_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 64 samples, validate on 26 samples
# Epoch 1/500
# 10/64 [===>..........................] - ETA: 3s - loss: 6.4851 - accuracy: 0.4000
# Epoch 00001: val_accuracy improved from -inf to 0.61538, saving model to models/CNN2_dataset_2_no_augment_5_01.h5
# 64/64 [==============================] - 1s 14ms/sample - loss: 4.8076 - accuracy: 0.5000 - val_loss: 0.7674 - val_accuracy: 0.6154
# Epoch 2/500
# 10/64 [===>..........................] - ETA: 0s - loss: 4.2850 - accuracy: 0.4000
# Epoch 00002: val_accuracy did not improve from 0.61538
# 64/64 [==============================] - 0s 927us/sample - loss: 3.6832 - accuracy: 0.4844 - val_loss: 0.7126 - val_accuracy: 0.5000
# Epoch 3/500
# 10/64 [===>..........................] - ETA: 0s - loss: 6.4134 - accuracy: 0.2000
# Epoch 00003: val_accuracy did not improve from 0.61538
# 64/64 [==============================] - 0s 973us/sample - loss: 3.3482 - accuracy: 0.4219 - val_loss: 0.7067 - val_accuracy: 0.3077
# Epoch 4/500
# 10/64 [===>..........................] - ETA: 0s - loss: 1.4457 - accuracy: 0.6000
# Epoch 00004: val_accuracy improved from 0.61538 to 0.69231, saving model to models/CNN2_dataset_2_no_augment_5_04.h5
# 64/64 [==============================] - 0s 1ms/sample - loss: 1.9113 - accuracy: 0.5312 - val_loss: 0.7205 - val_accuracy: 0.6923
# Epoch 5/500
# 10/64 [===>..........................] - ETA: 0s - loss: 1.6125 - accuracy: 0.5000
# Epoch 00005: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 851us/sample - loss: 1.2044 - accuracy: 0.5781 - val_loss: 0.7226 - val_accuracy: 0.5000
# Epoch 6/500
# 10/64 [===>..........................] - ETA: 0s - loss: 2.3220 - accuracy: 0.5000
# Epoch 00006: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 959us/sample - loss: 1.2455 - accuracy: 0.5625 - val_loss: 0.7296 - val_accuracy: 0.5000
# Epoch 7/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.9293 - accuracy: 0.6000
# Epoch 00007: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 939us/sample - loss: 1.6588 - accuracy: 0.5000 - val_loss: 0.7166 - val_accuracy: 0.5000
# Epoch 8/500
# 10/64 [===>..........................] - ETA: 0s - loss: 1.2434 - accuracy: 0.5000
# Epoch 00008: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 927us/sample - loss: 1.4624 - accuracy: 0.4531 - val_loss: 0.7136 - val_accuracy: 0.5000
# Epoch 9/500
# 10/64 [===>..........................] - ETA: 0s - loss: 1.1730 - accuracy: 0.5000
# Epoch 00009: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 940us/sample - loss: 1.1212 - accuracy: 0.5469 - val_loss: 0.7108 - val_accuracy: 0.5000
# Epoch 10/500
# 10/64 [===>..........................] - ETA: 0s - loss: 1.2036 - accuracy: 0.5000
# Epoch 00010: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 916us/sample - loss: 0.9693 - accuracy: 0.5156 - val_loss: 0.7090 - val_accuracy: 0.5000
# Epoch 11/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.8677 - accuracy: 0.6000
# Epoch 00011: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 916us/sample - loss: 1.0984 - accuracy: 0.4688 - val_loss: 0.7066 - val_accuracy: 0.5000
# Epoch 12/500
# 10/64 [===>..........................] - ETA: 0s - loss: 1.1186 - accuracy: 0.3000
# Epoch 00012: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 857us/sample - loss: 0.8510 - accuracy: 0.5156 - val_loss: 0.7042 - val_accuracy: 0.5000
# Epoch 13/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.8175 - accuracy: 0.3000
# Epoch 00013: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 980us/sample - loss: 1.0524 - accuracy: 0.3906 - val_loss: 0.7021 - val_accuracy: 0.5000
# Epoch 14/500
# 10/64 [===>..........................] - ETA: 0s - loss: 1.0524 - accuracy: 0.5000
# Epoch 00014: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 848us/sample - loss: 0.8848 - accuracy: 0.5312 - val_loss: 0.7004 - val_accuracy: 0.5000
# Epoch 15/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.7420 - accuracy: 0.6000
# Epoch 00015: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 992us/sample - loss: 0.7849 - accuracy: 0.5156 - val_loss: 0.6994 - val_accuracy: 0.5000
# Epoch 16/500
# 10/64 [===>..........................] - ETA: 0s - loss: 1.0645 - accuracy: 0.4000
# Epoch 00016: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 931us/sample - loss: 0.8492 - accuracy: 0.4375 - val_loss: 0.6969 - val_accuracy: 0.3846
# Epoch 17/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.7651 - accuracy: 0.5000
# Epoch 00017: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 889us/sample - loss: 0.7963 - accuracy: 0.5312 - val_loss: 0.6954 - val_accuracy: 0.3077
# Epoch 18/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.5994 - accuracy: 0.6000
# Epoch 00018: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 836us/sample - loss: 0.7891 - accuracy: 0.5000 - val_loss: 0.6957 - val_accuracy: 0.4231
# Epoch 19/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.9485 - accuracy: 0.1000
# Epoch 00019: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 839us/sample - loss: 0.7231 - accuracy: 0.4688 - val_loss: 0.6934 - val_accuracy: 0.6923
# Epoch 20/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.9186 - accuracy: 0.5000
# Epoch 00020: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 918us/sample - loss: 0.8576 - accuracy: 0.4219 - val_loss: 0.6927 - val_accuracy: 0.6923
# Epoch 21/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.5314 - accuracy: 0.7000
# Epoch 00021: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 828us/sample - loss: 0.6967 - accuracy: 0.5469 - val_loss: 0.6913 - val_accuracy: 0.6923
# Epoch 22/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.8718 - accuracy: 0.4000
# Epoch 00022: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 938us/sample - loss: 0.8487 - accuracy: 0.4062 - val_loss: 0.6900 - val_accuracy: 0.5769
# Epoch 23/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.9336 - accuracy: 0.4000
# Epoch 00023: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 873us/sample - loss: 0.8169 - accuracy: 0.5000 - val_loss: 0.6896 - val_accuracy: 0.6538
# Epoch 24/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.7410 - accuracy: 0.5000
# Epoch 00024: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 901us/sample - loss: 0.7931 - accuracy: 0.5469 - val_loss: 0.6927 - val_accuracy: 0.5000
# Epoch 25/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.8585 - accuracy: 0.4000
# Epoch 00025: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 846us/sample - loss: 0.7684 - accuracy: 0.4375 - val_loss: 0.6907 - val_accuracy: 0.6923
# Epoch 26/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.5771 - accuracy: 0.7000
# Epoch 00026: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 918us/sample - loss: 0.6935 - accuracy: 0.5312 - val_loss: 0.6893 - val_accuracy: 0.5769
# Epoch 27/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.8604 - accuracy: 0.4000
# Epoch 00027: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 883us/sample - loss: 0.7061 - accuracy: 0.4844 - val_loss: 0.6904 - val_accuracy: 0.6923
# Epoch 28/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.8004 - accuracy: 0.5000
# Epoch 00028: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 900us/sample - loss: 0.6689 - accuracy: 0.5781 - val_loss: 0.6883 - val_accuracy: 0.3846
# Epoch 29/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.5619 - accuracy: 0.7000
# Epoch 00029: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 869us/sample - loss: 0.7079 - accuracy: 0.5781 - val_loss: 0.6841 - val_accuracy: 0.6538
# Epoch 30/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.6206 - accuracy: 0.5000
# Epoch 00030: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 889us/sample - loss: 0.6657 - accuracy: 0.6250 - val_loss: 0.6859 - val_accuracy: 0.4231
# Epoch 31/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.7737 - accuracy: 0.4000
# Epoch 00031: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 830us/sample - loss: 0.6866 - accuracy: 0.5625 - val_loss: 0.6929 - val_accuracy: 0.5000
# Epoch 32/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.6261 - accuracy: 0.5000
# Epoch 00032: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 855us/sample - loss: 0.7075 - accuracy: 0.6094 - val_loss: 0.6894 - val_accuracy: 0.6923
# Epoch 33/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.9476 - accuracy: 0.4000
# Epoch 00033: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 878us/sample - loss: 0.7156 - accuracy: 0.5938 - val_loss: 0.6762 - val_accuracy: 0.5769
# Epoch 34/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.5921 - accuracy: 0.8000
# Epoch 00034: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 854us/sample - loss: 0.6282 - accuracy: 0.5938 - val_loss: 0.6565 - val_accuracy: 0.5769
# Epoch 35/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.6587 - accuracy: 0.9000
# Epoch 00035: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 897us/sample - loss: 0.7132 - accuracy: 0.5469 - val_loss: 0.6620 - val_accuracy: 0.6538
# Epoch 36/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.5297 - accuracy: 0.9000
# Epoch 00036: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 883us/sample - loss: 0.5769 - accuracy: 0.7031 - val_loss: 0.6508 - val_accuracy: 0.5769
# Epoch 37/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.5399 - accuracy: 0.9000
# Epoch 00037: val_accuracy did not improve from 0.69231
# 64/64 [==============================] - 0s 900us/sample - loss: 0.7011 - accuracy: 0.5469 - val_loss: 0.6467 - val_accuracy: 0.5769
# Epoch 38/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.5429 - accuracy: 0.7000
# Epoch 00038: val_accuracy improved from 0.69231 to 0.84615, saving model to models/CNN2_dataset_2_no_augment_5_38.h5
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.6467 - accuracy: 0.6406 - val_loss: 0.6657 - val_accuracy: 0.8462
# Epoch 39/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.4754 - accuracy: 0.7000
# Epoch 00039: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 897us/sample - loss: 0.6392 - accuracy: 0.6406 - val_loss: 0.6323 - val_accuracy: 0.5769
# Epoch 40/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.7673 - accuracy: 0.6000
# Epoch 00040: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 902us/sample - loss: 0.6006 - accuracy: 0.6406 - val_loss: 0.6124 - val_accuracy: 0.5769
# Epoch 41/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.7956 - accuracy: 0.3000
# Epoch 00041: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 868us/sample - loss: 0.6338 - accuracy: 0.6406 - val_loss: 0.6083 - val_accuracy: 0.6538
# Epoch 42/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.8342 - accuracy: 0.5000
# Epoch 00042: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 939us/sample - loss: 0.7232 - accuracy: 0.6406 - val_loss: 0.5979 - val_accuracy: 0.6538
# Epoch 43/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.6983 - accuracy: 0.5000
# Epoch 00043: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 964us/sample - loss: 0.6121 - accuracy: 0.6562 - val_loss: 0.5888 - val_accuracy: 0.6538
# Epoch 44/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.5975 - accuracy: 0.6000
# Epoch 00044: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 975us/sample - loss: 0.5868 - accuracy: 0.6094 - val_loss: 0.5938 - val_accuracy: 0.6538
# Epoch 45/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.5347 - accuracy: 0.9000
# Epoch 00045: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 912us/sample - loss: 0.6277 - accuracy: 0.7344 - val_loss: 0.5846 - val_accuracy: 0.5769
# Epoch 46/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.4589 - accuracy: 0.8000
# Epoch 00046: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 890us/sample - loss: 0.5579 - accuracy: 0.7188 - val_loss: 0.5811 - val_accuracy: 0.6154
# Epoch 47/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3636 - accuracy: 1.0000
# Epoch 00047: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.4770 - accuracy: 0.8125 - val_loss: 0.5814 - val_accuracy: 0.5769
# Epoch 48/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.4094 - accuracy: 0.8000
# Epoch 00048: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.4941 - accuracy: 0.7656 - val_loss: 0.5723 - val_accuracy: 0.5769
# Epoch 49/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3701 - accuracy: 0.9000
# Epoch 00049: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.4839 - accuracy: 0.7344 - val_loss: 0.5530 - val_accuracy: 0.7308
# Epoch 50/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.5087 - accuracy: 0.9000
# Epoch 00050: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.6124 - accuracy: 0.6875 - val_loss: 0.5323 - val_accuracy: 0.6923
# Epoch 51/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.4783 - accuracy: 0.6000
# Epoch 00051: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.5252 - accuracy: 0.7188 - val_loss: 0.5454 - val_accuracy: 0.5769
# Epoch 52/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.4862 - accuracy: 0.8000
# Epoch 00052: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.5586 - accuracy: 0.6875 - val_loss: 0.5001 - val_accuracy: 0.7308
# Epoch 53/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2579 - accuracy: 1.0000
# Epoch 00053: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.4079 - accuracy: 0.8594 - val_loss: 0.4730 - val_accuracy: 0.7308
# Epoch 54/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.5420 - accuracy: 0.8000
# Epoch 00054: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.4435 - accuracy: 0.8281 - val_loss: 0.4599 - val_accuracy: 0.7308
# Epoch 55/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.5472 - accuracy: 0.6000
# Epoch 00055: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.4773 - accuracy: 0.7656 - val_loss: 0.4217 - val_accuracy: 0.8462
# Epoch 56/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.4085 - accuracy: 0.9000
# Epoch 00056: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.4245 - accuracy: 0.8281 - val_loss: 0.4263 - val_accuracy: 0.7308
# Epoch 57/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.4826 - accuracy: 0.6000
# Epoch 00057: val_accuracy did not improve from 0.84615
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.4417 - accuracy: 0.7812 - val_loss: 0.4359 - val_accuracy: 0.7308
# Epoch 58/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3151 - accuracy: 0.9000
# Epoch 00058: val_accuracy improved from 0.84615 to 1.00000, saving model to models/CNN2_dataset_2_no_augment_5_58.h5
# 64/64 [==============================] - 0s 2ms/sample - loss: 0.4685 - accuracy: 0.7656 - val_loss: 0.3821 - val_accuracy: 1.0000
# Epoch 59/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.4987 - accuracy: 0.7000
# Epoch 00059: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3754 - accuracy: 0.8438 - val_loss: 0.4342 - val_accuracy: 0.7308
# Epoch 60/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.4223 - accuracy: 0.9000
# Epoch 00060: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3546 - accuracy: 0.8906 - val_loss: 0.3971 - val_accuracy: 0.7692
# Epoch 61/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.6406 - accuracy: 0.6000
# Epoch 00061: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3884 - accuracy: 0.8438 - val_loss: 0.4155 - val_accuracy: 0.7308
# Epoch 62/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.5646 - accuracy: 0.6000
# Epoch 00062: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.4030 - accuracy: 0.8281 - val_loss: 0.4225 - val_accuracy: 0.7308
# Epoch 63/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.5119 - accuracy: 0.8000
# Epoch 00063: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.4235 - accuracy: 0.8125 - val_loss: 0.4341 - val_accuracy: 0.6923
# Epoch 64/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.8616 - accuracy: 0.5000
# Epoch 00064: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.4646 - accuracy: 0.7500 - val_loss: 0.3713 - val_accuracy: 0.7692
# Epoch 65/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.5154 - accuracy: 0.7000
# Epoch 00065: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3908 - accuracy: 0.7969 - val_loss: 0.4268 - val_accuracy: 0.6923
# Epoch 66/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3287 - accuracy: 0.8000
# Epoch 00066: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3770 - accuracy: 0.8125 - val_loss: 0.4017 - val_accuracy: 0.7308
# Epoch 67/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3737 - accuracy: 0.8000
# Epoch 00067: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3563 - accuracy: 0.8594 - val_loss: 0.3241 - val_accuracy: 0.8462
# Epoch 68/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2776 - accuracy: 0.9000
# Epoch 00068: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 921us/sample - loss: 0.4003 - accuracy: 0.8281 - val_loss: 0.3985 - val_accuracy: 0.7308
# Epoch 69/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3958 - accuracy: 0.9000
# Epoch 00069: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 951us/sample - loss: 0.3215 - accuracy: 0.8594 - val_loss: 0.3889 - val_accuracy: 0.7308
# Epoch 70/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3971 - accuracy: 0.7000
# Epoch 00070: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 867us/sample - loss: 0.3087 - accuracy: 0.8750 - val_loss: 0.3060 - val_accuracy: 0.8462
# Epoch 71/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2060 - accuracy: 1.0000
# Epoch 00071: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 947us/sample - loss: 0.3278 - accuracy: 0.8594 - val_loss: 0.3296 - val_accuracy: 0.7692
# Epoch 72/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1946 - accuracy: 0.9000
# Epoch 00072: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2755 - accuracy: 0.8906 - val_loss: 0.3829 - val_accuracy: 0.7308
# Epoch 73/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2307 - accuracy: 1.0000
# Epoch 00073: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 941us/sample - loss: 0.3904 - accuracy: 0.8906 - val_loss: 0.3398 - val_accuracy: 0.7692
# Epoch 74/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.4264 - accuracy: 0.8000
# Epoch 00074: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 966us/sample - loss: 0.2955 - accuracy: 0.8594 - val_loss: 0.3143 - val_accuracy: 0.7692
# Epoch 75/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1660 - accuracy: 1.0000
# Epoch 00075: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 965us/sample - loss: 0.3135 - accuracy: 0.8906 - val_loss: 0.3546 - val_accuracy: 0.7308
# Epoch 76/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3753 - accuracy: 0.8000
# Epoch 00076: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 971us/sample - loss: 0.3422 - accuracy: 0.8125 - val_loss: 0.3210 - val_accuracy: 0.7692
# Epoch 77/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2240 - accuracy: 1.0000
# Epoch 00077: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 913us/sample - loss: 0.2905 - accuracy: 0.9375 - val_loss: 0.2540 - val_accuracy: 1.0000
# Epoch 78/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1219 - accuracy: 1.0000
# Epoch 00078: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2921 - accuracy: 0.9062 - val_loss: 0.3417 - val_accuracy: 0.7308
# Epoch 79/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0336 - accuracy: 1.0000
# Epoch 00079: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3038 - accuracy: 0.8594 - val_loss: 0.3421 - val_accuracy: 0.7308
# Epoch 80/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.4722 - accuracy: 0.8000
# Epoch 00080: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 931us/sample - loss: 0.3748 - accuracy: 0.8594 - val_loss: 0.2425 - val_accuracy: 1.0000
# Epoch 81/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3092 - accuracy: 0.8000
# Epoch 00081: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 844us/sample - loss: 0.2968 - accuracy: 0.8594 - val_loss: 0.2588 - val_accuracy: 0.8846
# Epoch 82/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2337 - accuracy: 0.9000
# Epoch 00082: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 829us/sample - loss: 0.3250 - accuracy: 0.8438 - val_loss: 0.4002 - val_accuracy: 0.7308
# Epoch 83/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0625 - accuracy: 1.0000
# Epoch 00083: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 915us/sample - loss: 0.2768 - accuracy: 0.8906 - val_loss: 0.2845 - val_accuracy: 0.8462
# Epoch 84/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2783 - accuracy: 0.9000
# Epoch 00084: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 845us/sample - loss: 0.3584 - accuracy: 0.8750 - val_loss: 0.3986 - val_accuracy: 0.7308
# Epoch 85/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.4424 - accuracy: 0.7000
# Epoch 00085: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 858us/sample - loss: 0.3557 - accuracy: 0.8438 - val_loss: 0.3741 - val_accuracy: 0.7308
# Epoch 86/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2115 - accuracy: 0.9000
# Epoch 00086: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 845us/sample - loss: 0.2920 - accuracy: 0.8750 - val_loss: 0.2984 - val_accuracy: 0.7692
# Epoch 87/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2622 - accuracy: 1.0000
# Epoch 00087: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 948us/sample - loss: 0.2692 - accuracy: 0.8750 - val_loss: 0.3391 - val_accuracy: 0.7308
# Epoch 88/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.4152 - accuracy: 0.9000
# Epoch 00088: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3544 - accuracy: 0.8594 - val_loss: 0.3211 - val_accuracy: 0.7692
# Epoch 89/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.6021 - accuracy: 0.8000
# Epoch 00089: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.4163 - accuracy: 0.8125 - val_loss: 0.3021 - val_accuracy: 0.7692
# Epoch 90/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.4890 - accuracy: 0.7000
# Epoch 00090: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3090 - accuracy: 0.8281 - val_loss: 0.3268 - val_accuracy: 0.7692
# Epoch 91/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2416 - accuracy: 0.9000
# Epoch 00091: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3440 - accuracy: 0.8281 - val_loss: 0.2431 - val_accuracy: 0.8846
# Epoch 92/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1780 - accuracy: 0.9000
# Epoch 00092: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 958us/sample - loss: 0.2783 - accuracy: 0.8906 - val_loss: 0.2372 - val_accuracy: 0.8846
# Epoch 93/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2083 - accuracy: 1.0000
# Epoch 00093: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2776 - accuracy: 0.9219 - val_loss: 0.2939 - val_accuracy: 0.7692
# Epoch 94/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1834 - accuracy: 1.0000
# Epoch 00094: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2720 - accuracy: 0.9062 - val_loss: 0.2718 - val_accuracy: 0.8462
# Epoch 95/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.4006 - accuracy: 0.7000
# Epoch 00095: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 982us/sample - loss: 0.3026 - accuracy: 0.8594 - val_loss: 0.2139 - val_accuracy: 1.0000
# Epoch 96/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0834 - accuracy: 1.0000
# Epoch 00096: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2519 - accuracy: 0.9062 - val_loss: 0.3562 - val_accuracy: 0.7308
# Epoch 97/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1119 - accuracy: 1.0000
# Epoch 00097: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3666 - accuracy: 0.8281 - val_loss: 0.2307 - val_accuracy: 0.8846
# Epoch 98/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1495 - accuracy: 1.0000
# Epoch 00098: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3396 - accuracy: 0.8594 - val_loss: 0.2720 - val_accuracy: 0.7692
# Epoch 99/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2814 - accuracy: 0.9000
# Epoch 00099: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2729 - accuracy: 0.8750 - val_loss: 0.3158 - val_accuracy: 0.7308
# Epoch 100/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3795 - accuracy: 0.7000
# Epoch 00100: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3147 - accuracy: 0.8594 - val_loss: 0.2401 - val_accuracy: 0.8846
# Epoch 101/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.5346 - accuracy: 0.9000
# Epoch 00101: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2692 - accuracy: 0.8906 - val_loss: 0.2240 - val_accuracy: 1.0000
# Epoch 102/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2404 - accuracy: 0.9000
# Epoch 00102: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2223 - accuracy: 0.9375 - val_loss: 0.2773 - val_accuracy: 0.7692
# Epoch 103/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0656 - accuracy: 1.0000
# Epoch 00103: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2421 - accuracy: 0.9062 - val_loss: 0.2595 - val_accuracy: 0.8462
# Epoch 104/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1567 - accuracy: 0.9000
# Epoch 00104: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2185 - accuracy: 0.9219 - val_loss: 0.2530 - val_accuracy: 0.8462
# Epoch 105/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3970 - accuracy: 0.8000
# Epoch 00105: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2877 - accuracy: 0.8906 - val_loss: 0.2454 - val_accuracy: 0.8846
# Epoch 106/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2118 - accuracy: 1.0000
# Epoch 00106: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2621 - accuracy: 0.8906 - val_loss: 0.2280 - val_accuracy: 0.8846
# Epoch 107/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3293 - accuracy: 0.9000
# Epoch 00107: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2511 - accuracy: 0.8750 - val_loss: 0.2174 - val_accuracy: 1.0000
# Epoch 108/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0938 - accuracy: 0.9000
# Epoch 00108: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2832 - accuracy: 0.8594 - val_loss: 0.3490 - val_accuracy: 0.7308
# Epoch 109/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1144 - accuracy: 1.0000
# Epoch 00109: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2741 - accuracy: 0.8594 - val_loss: 0.2271 - val_accuracy: 0.8846
# Epoch 110/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0739 - accuracy: 1.0000
# Epoch 00110: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2638 - accuracy: 0.8281 - val_loss: 0.2017 - val_accuracy: 1.0000
# Epoch 111/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3220 - accuracy: 0.8000
# Epoch 00111: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2405 - accuracy: 0.9219 - val_loss: 0.3694 - val_accuracy: 0.7308
# Epoch 112/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3423 - accuracy: 0.8000
# Epoch 00112: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3761 - accuracy: 0.8750 - val_loss: 0.2285 - val_accuracy: 0.8846
# Epoch 113/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2265 - accuracy: 0.9000
# Epoch 00113: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2490 - accuracy: 0.8594 - val_loss: 0.1884 - val_accuracy: 1.0000
# Epoch 114/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.5296 - accuracy: 0.8000
# Epoch 00114: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2767 - accuracy: 0.9062 - val_loss: 0.2822 - val_accuracy: 0.7692
# Epoch 115/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3072 - accuracy: 0.9000
# Epoch 00115: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3519 - accuracy: 0.8750 - val_loss: 0.3319 - val_accuracy: 0.7308
# Epoch 116/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0821 - accuracy: 1.0000
# Epoch 00116: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2386 - accuracy: 0.9219 - val_loss: 0.2855 - val_accuracy: 0.7308
# Epoch 117/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3932 - accuracy: 0.9000
# Epoch 00117: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2820 - accuracy: 0.9062 - val_loss: 0.2075 - val_accuracy: 0.8846
# Epoch 118/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0583 - accuracy: 1.0000
# Epoch 00118: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 974us/sample - loss: 0.2104 - accuracy: 0.9062 - val_loss: 0.3124 - val_accuracy: 0.7308
# Epoch 119/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0855 - accuracy: 1.0000
# Epoch 00119: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2872 - accuracy: 0.9219 - val_loss: 0.2850 - val_accuracy: 0.7692
# Epoch 120/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1333 - accuracy: 1.0000
# Epoch 00120: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2772 - accuracy: 0.8750 - val_loss: 0.2248 - val_accuracy: 0.8846
# Epoch 121/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3600 - accuracy: 0.8000
# Epoch 00121: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2336 - accuracy: 0.9219 - val_loss: 0.2455 - val_accuracy: 0.8846
# Epoch 122/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.4236 - accuracy: 0.8000
# Epoch 00122: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2547 - accuracy: 0.9062 - val_loss: 0.2950 - val_accuracy: 0.7692
# Epoch 123/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.4248 - accuracy: 0.8000
# Epoch 00123: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2488 - accuracy: 0.9062 - val_loss: 0.1972 - val_accuracy: 0.8846
# Epoch 124/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2765 - accuracy: 0.9000
# Epoch 00124: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2737 - accuracy: 0.9062 - val_loss: 0.2926 - val_accuracy: 0.7692
# Epoch 125/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3923 - accuracy: 0.8000
# Epoch 00125: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2559 - accuracy: 0.8906 - val_loss: 0.2981 - val_accuracy: 0.7692
# Epoch 126/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.6140 - accuracy: 0.8000
# Epoch 00126: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3466 - accuracy: 0.8438 - val_loss: 0.2086 - val_accuracy: 0.8846
# Epoch 127/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2487 - accuracy: 0.9000
# Epoch 00127: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 975us/sample - loss: 0.2582 - accuracy: 0.8750 - val_loss: 0.2655 - val_accuracy: 0.8462
# Epoch 128/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0810 - accuracy: 1.0000
# Epoch 00128: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3142 - accuracy: 0.9062 - val_loss: 0.3089 - val_accuracy: 0.7692
# Epoch 129/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3510 - accuracy: 0.8000
# Epoch 00129: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3018 - accuracy: 0.8750 - val_loss: 0.2219 - val_accuracy: 0.8846
# Epoch 130/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.4899 - accuracy: 0.6000
# Epoch 00130: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3728 - accuracy: 0.7969 - val_loss: 0.2032 - val_accuracy: 0.8846
# Epoch 131/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2687 - accuracy: 0.9000
# Epoch 00131: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2616 - accuracy: 0.8750 - val_loss: 0.3607 - val_accuracy: 0.7308
# Epoch 132/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3137 - accuracy: 0.8000
# Epoch 00132: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2840 - accuracy: 0.8750 - val_loss: 0.2182 - val_accuracy: 0.8846
# Epoch 133/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3894 - accuracy: 0.9000
# Epoch 00133: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2982 - accuracy: 0.8594 - val_loss: 0.2026 - val_accuracy: 1.0000
# Epoch 134/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3298 - accuracy: 0.8000
# Epoch 00134: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3073 - accuracy: 0.8906 - val_loss: 0.2180 - val_accuracy: 0.8846
# Epoch 135/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.4020 - accuracy: 0.7000
# Epoch 00135: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2853 - accuracy: 0.8594 - val_loss: 0.2381 - val_accuracy: 0.8846
# Epoch 136/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3459 - accuracy: 0.8000
# Epoch 00136: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 963us/sample - loss: 0.2734 - accuracy: 0.8594 - val_loss: 0.2323 - val_accuracy: 0.8846
# Epoch 137/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.4420 - accuracy: 0.8000
# Epoch 00137: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2580 - accuracy: 0.8906 - val_loss: 0.3215 - val_accuracy: 0.7692
# Epoch 138/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1822 - accuracy: 0.9000
# Epoch 00138: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2669 - accuracy: 0.8750 - val_loss: 0.2622 - val_accuracy: 0.8462
# Epoch 139/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1393 - accuracy: 1.0000
# Epoch 00139: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3002 - accuracy: 0.8906 - val_loss: 0.2657 - val_accuracy: 0.8462
# Epoch 140/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.4129 - accuracy: 0.8000
# Epoch 00140: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3309 - accuracy: 0.8281 - val_loss: 0.3762 - val_accuracy: 0.7308
# Epoch 141/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3976 - accuracy: 0.8000
# Epoch 00141: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2688 - accuracy: 0.9062 - val_loss: 0.2157 - val_accuracy: 0.8846
# Epoch 142/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3053 - accuracy: 0.8000
# Epoch 00142: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2663 - accuracy: 0.8594 - val_loss: 0.3735 - val_accuracy: 0.7308
# Epoch 143/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.4906 - accuracy: 0.8000
# Epoch 00143: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3113 - accuracy: 0.8750 - val_loss: 0.2723 - val_accuracy: 0.8462
# Epoch 144/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.6400 - accuracy: 0.7000
# Epoch 00144: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 987us/sample - loss: 0.3158 - accuracy: 0.9062 - val_loss: 0.2636 - val_accuracy: 0.8846
# Epoch 145/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3933 - accuracy: 0.8000
# Epoch 00145: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2858 - accuracy: 0.8750 - val_loss: 0.1927 - val_accuracy: 1.0000
# Epoch 146/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3112 - accuracy: 0.9000
# Epoch 00146: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2657 - accuracy: 0.8594 - val_loss: 0.3815 - val_accuracy: 0.7308
# Epoch 147/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2988 - accuracy: 0.9000
# Epoch 00147: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2558 - accuracy: 0.9062 - val_loss: 0.2447 - val_accuracy: 0.8846
# Epoch 148/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1222 - accuracy: 1.0000
# Epoch 00148: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 975us/sample - loss: 0.2353 - accuracy: 0.8906 - val_loss: 0.2084 - val_accuracy: 0.8846
# Epoch 149/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1976 - accuracy: 0.9000
# Epoch 00149: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 982us/sample - loss: 0.2190 - accuracy: 0.8906 - val_loss: 0.2819 - val_accuracy: 0.7692
# Epoch 150/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2137 - accuracy: 0.9000
# Epoch 00150: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2591 - accuracy: 0.8594 - val_loss: 0.2961 - val_accuracy: 0.7308
# Epoch 151/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2688 - accuracy: 0.8000
# Epoch 00151: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2141 - accuracy: 0.8906 - val_loss: 0.2454 - val_accuracy: 0.8846
# Epoch 152/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1920 - accuracy: 0.9000
# Epoch 00152: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 967us/sample - loss: 0.2759 - accuracy: 0.8750 - val_loss: 0.3572 - val_accuracy: 0.7308
# Epoch 153/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0320 - accuracy: 1.0000
# Epoch 00153: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.3223 - accuracy: 0.8750 - val_loss: 0.3663 - val_accuracy: 0.7308
# Epoch 154/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1109 - accuracy: 1.0000
# Epoch 00154: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2542 - accuracy: 0.8906 - val_loss: 0.2749 - val_accuracy: 0.8462
# Epoch 155/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0566 - accuracy: 1.0000
# Epoch 00155: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 980us/sample - loss: 0.2304 - accuracy: 0.9219 - val_loss: 0.3124 - val_accuracy: 0.7308
# Epoch 156/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1191 - accuracy: 1.0000
# Epoch 00156: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 965us/sample - loss: 0.2603 - accuracy: 0.8906 - val_loss: 0.3208 - val_accuracy: 0.7308
# Epoch 157/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1377 - accuracy: 1.0000
# Epoch 00157: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 942us/sample - loss: 0.2253 - accuracy: 0.9219 - val_loss: 0.4154 - val_accuracy: 0.7308
# Epoch 158/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.5385 - accuracy: 0.8000
# Epoch 00158: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2506 - accuracy: 0.9062 - val_loss: 0.2164 - val_accuracy: 0.8846
# Epoch 159/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1658 - accuracy: 1.0000
# Epoch 00159: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2835 - accuracy: 0.8906 - val_loss: 0.2223 - val_accuracy: 0.8846
# Epoch 160/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1028 - accuracy: 1.0000
# Epoch 00160: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2324 - accuracy: 0.9219 - val_loss: 0.2632 - val_accuracy: 0.8462
# Epoch 161/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1382 - accuracy: 1.0000
# Epoch 00161: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 978us/sample - loss: 0.2004 - accuracy: 0.9219 - val_loss: 0.3078 - val_accuracy: 0.7308
# Epoch 162/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1217 - accuracy: 1.0000
# Epoch 00162: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1726 - accuracy: 0.9531 - val_loss: 0.3068 - val_accuracy: 0.7308
# Epoch 163/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0745 - accuracy: 1.0000
# Epoch 00163: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 978us/sample - loss: 0.1717 - accuracy: 0.9062 - val_loss: 0.2500 - val_accuracy: 0.8462
# Epoch 164/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2307 - accuracy: 0.9000
# Epoch 00164: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2450 - accuracy: 0.8594 - val_loss: 0.3451 - val_accuracy: 0.7308
# Epoch 165/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3040 - accuracy: 0.9000
# Epoch 00165: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 930us/sample - loss: 0.2475 - accuracy: 0.9062 - val_loss: 0.3061 - val_accuracy: 0.7308
# Epoch 166/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1724 - accuracy: 0.9000
# Epoch 00166: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2606 - accuracy: 0.8906 - val_loss: 0.1913 - val_accuracy: 1.0000
# Epoch 167/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3978 - accuracy: 0.8000
# Epoch 00167: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 987us/sample - loss: 0.2957 - accuracy: 0.8750 - val_loss: 0.3190 - val_accuracy: 0.7308
# Epoch 168/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.4815 - accuracy: 0.8000
# Epoch 00168: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 977us/sample - loss: 0.3009 - accuracy: 0.8438 - val_loss: 0.4365 - val_accuracy: 0.7308
# Epoch 169/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1335 - accuracy: 0.9000
# ...
# Epoch 445/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0355 - accuracy: 1.0000
# Epoch 00445: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 965us/sample - loss: 0.1462 - accuracy: 0.9375 - val_loss: 0.2714 - val_accuracy: 0.7692
# Epoch 446/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3000 - accuracy: 0.9000
# Epoch 00446: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 900us/sample - loss: 0.1652 - accuracy: 0.9062 - val_loss: 0.3611 - val_accuracy: 0.7308
# Epoch 447/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0166 - accuracy: 1.0000
# Epoch 00447: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 923us/sample - loss: 0.1236 - accuracy: 0.9375 - val_loss: 0.3781 - val_accuracy: 0.7308
# Epoch 448/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0845 - accuracy: 1.0000
# Epoch 00448: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 917us/sample - loss: 0.1267 - accuracy: 0.9531 - val_loss: 0.4126 - val_accuracy: 0.7308
# Epoch 449/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.5107 - accuracy: 0.8000
# Epoch 00449: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 887us/sample - loss: 0.2753 - accuracy: 0.9062 - val_loss: 0.4586 - val_accuracy: 0.7308
# Epoch 450/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0382 - accuracy: 1.0000
# Epoch 00450: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 952us/sample - loss: 0.2122 - accuracy: 0.9062 - val_loss: 0.3116 - val_accuracy: 0.7308
# Epoch 451/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0418 - accuracy: 1.0000
# Epoch 00451: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 945us/sample - loss: 0.1447 - accuracy: 0.9375 - val_loss: 0.3526 - val_accuracy: 0.7308
# Epoch 452/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.5460 - accuracy: 0.8000
# Epoch 00452: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 949us/sample - loss: 0.2256 - accuracy: 0.9219 - val_loss: 0.4235 - val_accuracy: 0.7308
# Epoch 453/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1064 - accuracy: 1.0000
# Epoch 00453: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 927us/sample - loss: 0.1226 - accuracy: 0.9531 - val_loss: 0.5260 - val_accuracy: 0.6154
# Epoch 454/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2531 - accuracy: 0.9000
# Epoch 00454: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 889us/sample - loss: 0.1277 - accuracy: 0.9375 - val_loss: 0.3597 - val_accuracy: 0.7308
# Epoch 455/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2783 - accuracy: 0.9000
# Epoch 00455: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 878us/sample - loss: 0.1356 - accuracy: 0.9219 - val_loss: 0.2047 - val_accuracy: 1.0000
# Epoch 456/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1171 - accuracy: 1.0000
# Epoch 00456: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 884us/sample - loss: 0.1285 - accuracy: 0.9688 - val_loss: 0.2890 - val_accuracy: 0.7308
# Epoch 457/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1963 - accuracy: 0.8000
# Epoch 00457: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 906us/sample - loss: 0.1782 - accuracy: 0.9062 - val_loss: 0.3744 - val_accuracy: 0.7308
# Epoch 458/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3600 - accuracy: 0.8000
# Epoch 00458: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 836us/sample - loss: 0.1552 - accuracy: 0.9375 - val_loss: 0.3242 - val_accuracy: 0.7308
# Epoch 459/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1013 - accuracy: 1.0000
# Epoch 00459: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 897us/sample - loss: 0.1916 - accuracy: 0.9375 - val_loss: 0.3698 - val_accuracy: 0.7308
# Epoch 460/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0430 - accuracy: 1.0000
# Epoch 00460: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 882us/sample - loss: 0.1942 - accuracy: 0.9375 - val_loss: 0.3701 - val_accuracy: 0.7308
# Epoch 461/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0466 - accuracy: 1.0000
# Epoch 00461: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 901us/sample - loss: 0.1371 - accuracy: 0.9531 - val_loss: 0.3244 - val_accuracy: 0.7308
# Epoch 462/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0947 - accuracy: 0.9000
# Epoch 00462: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 943us/sample - loss: 0.1647 - accuracy: 0.9219 - val_loss: 0.3421 - val_accuracy: 0.7308
# Epoch 463/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1363 - accuracy: 1.0000
# Epoch 00463: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 896us/sample - loss: 0.1443 - accuracy: 0.9531 - val_loss: 0.4295 - val_accuracy: 0.6538
# Epoch 464/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0826 - accuracy: 1.0000
# Epoch 00464: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 913us/sample - loss: 0.1609 - accuracy: 0.9531 - val_loss: 0.3074 - val_accuracy: 0.7308
# Epoch 465/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1882 - accuracy: 0.9000
# Epoch 00465: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 857us/sample - loss: 0.1516 - accuracy: 0.9062 - val_loss: 0.2659 - val_accuracy: 0.7692
# Epoch 466/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1386 - accuracy: 1.0000
# Epoch 00466: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 929us/sample - loss: 0.1787 - accuracy: 0.9219 - val_loss: 0.3587 - val_accuracy: 0.7308
# Epoch 467/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0593 - accuracy: 1.0000
# Epoch 00467: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 874us/sample - loss: 0.1374 - accuracy: 0.9531 - val_loss: 0.3876 - val_accuracy: 0.7308
# Epoch 468/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.5458 - accuracy: 0.8000
# Epoch 00468: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 879us/sample - loss: 0.2490 - accuracy: 0.9219 - val_loss: 0.4334 - val_accuracy: 0.6538
# Epoch 469/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2009 - accuracy: 0.9000
# Epoch 00469: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 886us/sample - loss: 0.1669 - accuracy: 0.9531 - val_loss: 0.4573 - val_accuracy: 0.6538
# Epoch 470/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3664 - accuracy: 0.8000
# Epoch 00470: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 967us/sample - loss: 0.2395 - accuracy: 0.9062 - val_loss: 0.4309 - val_accuracy: 0.6538
# Epoch 471/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0412 - accuracy: 1.0000
# Epoch 00471: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 877us/sample - loss: 0.2121 - accuracy: 0.9375 - val_loss: 0.4770 - val_accuracy: 0.6538
# Epoch 472/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1715 - accuracy: 1.0000
# Epoch 00472: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 845us/sample - loss: 0.1457 - accuracy: 0.9531 - val_loss: 0.2510 - val_accuracy: 0.8462
# Epoch 473/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.4272 - accuracy: 0.9000
# Epoch 00473: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 907us/sample - loss: 0.1757 - accuracy: 0.9375 - val_loss: 0.2793 - val_accuracy: 0.7692
# Epoch 474/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0695 - accuracy: 1.0000
# Epoch 00474: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 897us/sample - loss: 0.1915 - accuracy: 0.9375 - val_loss: 0.2970 - val_accuracy: 0.7692
# Epoch 475/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0670 - accuracy: 1.0000
# Epoch 00475: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 884us/sample - loss: 0.1499 - accuracy: 0.9531 - val_loss: 0.3634 - val_accuracy: 0.7308
# Epoch 476/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0284 - accuracy: 1.0000
# Epoch 00476: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 909us/sample - loss: 0.1444 - accuracy: 0.9219 - val_loss: 0.3655 - val_accuracy: 0.7308
# Epoch 477/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0822 - accuracy: 1.0000
# Epoch 00477: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 913us/sample - loss: 0.1874 - accuracy: 0.9219 - val_loss: 0.3380 - val_accuracy: 0.7308
# Epoch 478/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1043 - accuracy: 1.0000
# Epoch 00478: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 874us/sample - loss: 0.1105 - accuracy: 0.9688 - val_loss: 0.3336 - val_accuracy: 0.7692
# Epoch 479/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1066 - accuracy: 1.0000
# Epoch 00479: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 868us/sample - loss: 0.1572 - accuracy: 0.9375 - val_loss: 0.2032 - val_accuracy: 1.0000
# Epoch 480/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0737 - accuracy: 1.0000
# Epoch 00480: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 889us/sample - loss: 0.2129 - accuracy: 0.9062 - val_loss: 0.2537 - val_accuracy: 0.8462
# Epoch 481/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1098 - accuracy: 1.0000
# Epoch 00481: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 932us/sample - loss: 0.2131 - accuracy: 0.9062 - val_loss: 0.4659 - val_accuracy: 0.6538
# Epoch 482/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.4916 - accuracy: 0.9000
# Epoch 00482: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 874us/sample - loss: 0.1248 - accuracy: 0.9844 - val_loss: 0.4468 - val_accuracy: 0.6538
# Epoch 483/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2771 - accuracy: 0.8000
# Epoch 00483: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 907us/sample - loss: 0.1350 - accuracy: 0.9531 - val_loss: 0.3251 - val_accuracy: 0.7308
# Epoch 484/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0379 - accuracy: 1.0000
# Epoch 00484: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 872us/sample - loss: 0.1562 - accuracy: 0.9375 - val_loss: 0.3772 - val_accuracy: 0.7308
# Epoch 485/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0149 - accuracy: 1.0000
# Epoch 00485: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 908us/sample - loss: 0.1797 - accuracy: 0.9531 - val_loss: 0.3449 - val_accuracy: 0.7308
# Epoch 486/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0085 - accuracy: 1.0000
# Epoch 00486: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 884us/sample - loss: 0.1374 - accuracy: 0.9531 - val_loss: 0.4491 - val_accuracy: 0.6538
# Epoch 487/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1642 - accuracy: 0.9000
# Epoch 00487: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 880us/sample - loss: 0.2116 - accuracy: 0.9219 - val_loss: 0.4075 - val_accuracy: 0.6538
# Epoch 488/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1296 - accuracy: 0.9000
# Epoch 00488: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 931us/sample - loss: 0.1639 - accuracy: 0.9219 - val_loss: 0.2578 - val_accuracy: 0.8462
# Epoch 489/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3370 - accuracy: 0.9000
# Epoch 00489: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 866us/sample - loss: 0.1691 - accuracy: 0.9375 - val_loss: 0.2459 - val_accuracy: 0.8462
# Epoch 490/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3205 - accuracy: 0.7000
# Epoch 00490: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 927us/sample - loss: 0.1717 - accuracy: 0.9062 - val_loss: 0.2423 - val_accuracy: 0.8462
# Epoch 491/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0195 - accuracy: 1.0000
# Epoch 00491: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 882us/sample - loss: 0.1447 - accuracy: 0.9531 - val_loss: 0.2662 - val_accuracy: 0.8462
# Epoch 492/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.3383 - accuracy: 0.8000
# Epoch 00492: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 861us/sample - loss: 0.1566 - accuracy: 0.9531 - val_loss: 0.4552 - val_accuracy: 0.6538
# Epoch 493/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1885 - accuracy: 0.9000
# Epoch 00493: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 877us/sample - loss: 0.1303 - accuracy: 0.9531 - val_loss: 0.3494 - val_accuracy: 0.7308
# Epoch 494/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2590 - accuracy: 0.9000
# Epoch 00494: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 875us/sample - loss: 0.2429 - accuracy: 0.8750 - val_loss: 0.2527 - val_accuracy: 0.8462
# Epoch 495/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1239 - accuracy: 1.0000
# Epoch 00495: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 937us/sample - loss: 0.1982 - accuracy: 0.9375 - val_loss: 0.4698 - val_accuracy: 0.6538
# Epoch 496/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.1055 - accuracy: 0.9000
# Epoch 00496: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1144 - accuracy: 0.9375 - val_loss: 0.3848 - val_accuracy: 0.7308
# Epoch 497/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2273 - accuracy: 0.9000
# Epoch 00497: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 865us/sample - loss: 0.2050 - accuracy: 0.9219 - val_loss: 0.3565 - val_accuracy: 0.7308
# Epoch 498/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0913 - accuracy: 1.0000
# Epoch 00498: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 860us/sample - loss: 0.1287 - accuracy: 0.9531 - val_loss: 0.5824 - val_accuracy: 0.6154
# Epoch 499/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.0710 - accuracy: 1.0000
# Epoch 00499: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.2398 - accuracy: 0.8906 - val_loss: 0.3609 - val_accuracy: 0.7308
# Epoch 500/500
# 10/64 [===>..........................] - ETA: 0s - loss: 0.2592 - accuracy: 0.8000
# Epoch 00500: val_accuracy did not improve from 1.00000
# 64/64 [==============================] - 0s 1ms/sample - loss: 0.1506 - accuracy: 0.9062 - val_loss: 0.3309 - val_accuracy: 0.7692
# Training completed in time:  0:00:32.307047

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
train_acc = score[1]
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
test_acc = score[1]
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.96875
# Testing Accuracy:  0.7692308

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.68      1.00      0.81        13
#    Pneumonia       1.00      0.54      0.70        13
#
#     accuracy                           0.77        26
#    macro avg       0.84      0.77      0.76        26
# weighted avg       0.84      0.77      0.76        26

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[13  0]
#  [ 6  7]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])

# %% [markdown]
# __Write CSV__

# %%
with open('report.csv', 'a') as report:
    report.write(f'{MODEL_NAME},{DATASET},{GROUP_TRAIN},{DURATION},{train_acc},{test_acc}\n')
