# %% [markdown]
# # Rede CNN - Modelo 2
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - Dataset 2 - trim8

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP_TRAIN = 'trim8'
GROUP_TEST = 'trim8'
DATASET = 'dataset_2'
DURATION = 8
SIZE = 345
CSV_TRAIN = 'train2.csv'
CSV_TEST = 'test2.csv'
MODEL_NAME = f'CNN2_{DATASET}_{GROUP_TRAIN}'

# %%
train_file_paths = glob.glob(f'../datasets/{DATASET}/{GROUP_TRAIN}/train/**/*.wav', recursive=True)
train_file_names = [os.path.splitext(os.path.basename(p))[0] for p in train_file_paths]

test_file_paths = glob.glob(f'../datasets/{DATASET}/{GROUP_TEST}/test/**/*.wav', recursive=True)
test_file_names = [os.path.splitext(os.path.basename(p))[0] for p in test_file_paths]

# %%
train_p_id_in_file = [] # patient IDs corresponding to each file
test_p_id_in_file = [] # patient IDs corresponding to each file
for name in train_file_names:
    train_p_id_in_file.append(int(name[:3]))

for name in test_file_names:
    test_p_id_in_file.append(int(name[:3]))

train_p_id_in_file = np.array(train_p_id_in_file)
test_p_id_in_file = np.array(test_p_id_in_file)

# %%
max_pad_len = SIZE

os.makedirs("features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=DURATION) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
train_p_diag = pd.read_csv(f"../Respiratory_Sound_Database/Respiratory_Sound_Database_Pneumo_Healthy_Only/{CSV_TRAIN}", header=None) # patient diagnosis file
test_p_diag = pd.read_csv(f"../Respiratory_Sound_Database/Respiratory_Sound_Database_Pneumo_Healthy_Only/{CSV_TEST}", header=None) # patient diagnosis file
train_p_diag.head(5)
# Out:
#      0        1
# 0  123  Healthy
# 1  125  Healthy
# 2  126  Healthy
# 3  127  Healthy
# 4  136  Healthy

# %%
train_labels = np.array([train_p_diag[train_p_diag[0] == x][1].values[0] for x in train_p_id_in_file]) 
test_labels = np.array([test_p_diag[test_p_diag[0] == x][1].values[0] for x in test_p_id_in_file])

# %%
train_features = [] 
test_features = []

for file_name in train_file_paths:
    data = extract_features(file_name)
    train_features.append(data)

for file_name in test_file_paths:
    data = extract_features(file_name)
    test_features.append(data)

print('Finished feature extraction from ', (len(train_features)+len(train_features)), ' files')
train_features = np.array(train_features)
test_features = np.array(test_features)
# Out:
# Finished feature extraction from  224  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(train_features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
np.unique(train_labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
unique_elements, counts_elements = np.unique(train_labels, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))

unique_elements_test, counts_elements_test = np.unique(test_labels, return_counts=True)
print(np.asarray((unique_elements_test, counts_elements_test)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['64' '48']]
# [['Healthy' 'Pneumonia']
#  ['6' '26']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %% [markdown]
# __Balanceando dados__

# %%
def balance_data(X, labels):
    """Balances data duplicating some instances of the minority classes"""
    balX = None
    baly = None
    unique, counts = np.unique(labels, return_counts=True)
    max_inst = max(counts)
    # For every class duplicate the necessary amount
    for label in unique:
        data_of_label = []
        for x, y in zip(X, labels):
            if y == label:
                data_of_label.append(x)
        data_of_label = np.asarray(data_of_label)
        extra = data_of_label[np.random.choice(data_of_label.shape[0],
                                               max_inst,
                                               replace=True), :]
        if balX is not None:
            balX = np.stack((balX, extra), axis = 0) 
            baly = np.stack((baly, np.asarray([label for i in range(len(extra))])))
        else:
            balX = extra
            baly = np.asarray([label for i in range(len(extra))])
    balX = np.concatenate(balX)
    baly = np.concatenate(baly)
    return balX, baly

# %%
train_features, train_labels = balance_data(train_features, train_labels)
test_features, test_labels = balance_data(test_features, test_labels)

# %%
unique_elements, counts_elements = np.unique(train_labels, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))

unique_elements_test, counts_elements_test = np.unique(test_labels, return_counts=True)
print(np.asarray((unique_elements_test, counts_elements_test)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['64' '64']]
# [['Healthy' 'Pneumonia']
#  ['26' '26']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
le.fit(train_labels)
train_labels_cat = to_categorical(le.transform(train_labels)) 
test_labels_cat = to_categorical(le.transform(test_labels))

# %%
train_features.shape
# Out:
# (128, 40, 345)

# %%
train_features = np.reshape(train_features, (*train_features.shape,1)) 
print(train_features.shape, train_labels_cat.shape)
test_features = np.reshape(test_features, (*test_features.shape,1)) 
print(test_features.shape, test_labels_cat.shape)
# Out:
# (128, 40, 345, 1) (128, 2)
# (52, 40, 345, 1) (52, 2)

# %%
x_test, y_test = test_features, test_labels_cat
x_train, y_train = train_features, train_labels_cat

# %% [markdown]
# **CNN model architecture**

# %%
num_labels = train_labels_cat.shape[1]

num_rows = 40
num_columns = SIZE
num_channels = 1

filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(Conv2D(filters=16, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(Conv2D(filters=8, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(Conv2D(filters=4, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 344, 32)       160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 172, 32)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 172, 32)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 171, 16)       2064
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 85, 16)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 85, 16)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 84, 8)          520
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 42, 8)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 42, 8)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 41, 4)          132
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 20, 4)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 20, 4)          0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 4)                 0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 10
# =================================================================
# Total params: 2,886
# Trainable params: 2,886
# Non-trainable params: 0
# _________________________________________________________________
# 52/52 [==============================] - 1s 24ms/sample - loss: 10.3643 - accuracy: 0.5000
# Pre-training accuracy: 50.0000%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 500
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/' + MODEL_NAME + '_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 128 samples, validate on 52 samples
# Epoch 1/500
#  70/128 [===============>..............] - ETA: 0s - loss: 10.6149 - accuracy: 0.5571
# Epoch 00001: val_accuracy improved from -inf to 0.50000, saving model to models/CNN2_dataset_2_trim8_01.h5
# 128/128 [==============================] - 1s 8ms/sample - loss: 10.3659 - accuracy: 0.5469 - val_loss: 2.0787 - val_accuracy: 0.5000
# Epoch 2/500
# 110/128 [========================>.....] - ETA: 0s - loss: 6.1846 - accuracy: 0.4909
# Epoch 00002: val_accuracy did not improve from 0.50000
# 128/128 [==============================] - 0s 1ms/sample - loss: 5.9024 - accuracy: 0.5000 - val_loss: 0.7346 - val_accuracy: 0.5000
# Epoch 3/500
# 120/128 [===========================>..] - ETA: 0s - loss: 4.7712 - accuracy: 0.5500
# Epoch 00003: val_accuracy improved from 0.50000 to 0.78846, saving model to models/CNN2_dataset_2_trim8_03.h5
# 128/128 [==============================] - 0s 1ms/sample - loss: 4.6080 - accuracy: 0.5391 - val_loss: 0.6387 - val_accuracy: 0.7885
# Epoch 4/500
# 120/128 [===========================>..] - ETA: 0s - loss: 2.8609 - accuracy: 0.5083
# Epoch 00004: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 3.2032 - accuracy: 0.4922 - val_loss: 0.7991 - val_accuracy: 0.5000
# Epoch 5/500
#  70/128 [===============>..............] - ETA: 0s - loss: 2.5705 - accuracy: 0.5000
# Epoch 00005: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 2.5097 - accuracy: 0.5156 - val_loss: 0.7014 - val_accuracy: 0.4231
# Epoch 6/500
#  70/128 [===============>..............] - ETA: 0s - loss: 2.3238 - accuracy: 0.5143
# Epoch 00006: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 2.1886 - accuracy: 0.5234 - val_loss: 0.6659 - val_accuracy: 0.5000
# Epoch 7/500
#  70/128 [===============>..............] - ETA: 0s - loss: 1.5626 - accuracy: 0.5286
# Epoch 00007: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 1.4847 - accuracy: 0.5703 - val_loss: 0.6651 - val_accuracy: 0.5000
# Epoch 8/500
#  70/128 [===============>..............] - ETA: 0s - loss: 2.5606 - accuracy: 0.5143
# Epoch 00008: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 2.0349 - accuracy: 0.5625 - val_loss: 0.6420 - val_accuracy: 0.5000
# Epoch 9/500
#  70/128 [===============>..............] - ETA: 0s - loss: 1.1756 - accuracy: 0.5857
# Epoch 00009: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 1.2327 - accuracy: 0.5859 - val_loss: 0.6398 - val_accuracy: 0.5000
# Epoch 10/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.9520 - accuracy: 0.6429
# Epoch 00010: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 1.2304 - accuracy: 0.5938 - val_loss: 0.6385 - val_accuracy: 0.5000
# Epoch 11/500
# 120/128 [===========================>..] - ETA: 0s - loss: 1.0567 - accuracy: 0.5667
# Epoch 00011: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 1.1133 - accuracy: 0.5781 - val_loss: 0.6538 - val_accuracy: 0.5000
# Epoch 12/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.7288 - accuracy: 0.6571
# Epoch 00012: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.8080 - accuracy: 0.6328 - val_loss: 0.6479 - val_accuracy: 0.5000
# Epoch 13/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.8941 - accuracy: 0.6286
# Epoch 00013: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.9880 - accuracy: 0.5781 - val_loss: 0.6392 - val_accuracy: 0.5000
# Epoch 14/500
# 120/128 [===========================>..] - ETA: 0s - loss: 1.1327 - accuracy: 0.4750
# Epoch 00014: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 1.1191 - accuracy: 0.4688 - val_loss: 0.6388 - val_accuracy: 0.5000
# Epoch 15/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.9547 - accuracy: 0.6143
# Epoch 00015: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 1.0150 - accuracy: 0.5859 - val_loss: 0.6349 - val_accuracy: 0.5000
# Epoch 16/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.9664 - accuracy: 0.5667
# Epoch 00016: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.9273 - accuracy: 0.5781 - val_loss: 0.6327 - val_accuracy: 0.5000
# Epoch 17/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.7168 - accuracy: 0.6917
# Epoch 00017: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.7147 - accuracy: 0.6953 - val_loss: 0.6403 - val_accuracy: 0.5000
# Epoch 18/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.9354 - accuracy: 0.5429
# Epoch 00018: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.9516 - accuracy: 0.5547 - val_loss: 0.6412 - val_accuracy: 0.5000
# Epoch 19/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.6755 - accuracy: 0.6417
# Epoch 00019: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.6836 - accuracy: 0.6328 - val_loss: 0.6440 - val_accuracy: 0.5000
# Epoch 20/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.7133 - accuracy: 0.6583
# Epoch 00020: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.7249 - accuracy: 0.6641 - val_loss: 0.6511 - val_accuracy: 0.5000
# Epoch 21/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.8798 - accuracy: 0.6143
# Epoch 00021: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.7888 - accuracy: 0.6406 - val_loss: 0.6514 - val_accuracy: 0.5000
# Epoch 22/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.6916 - accuracy: 0.6583 ETA: 0s - loss: 0.6403 - accuracy: 0.65
# Epoch 00022: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.7226 - accuracy: 0.6484 - val_loss: 0.6533 - val_accuracy: 0.5000
# Epoch 23/500
# 110/128 [========================>.....] - ETA: 0s - loss: 0.6676 - accuracy: 0.6636
# Epoch 00023: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.7054 - accuracy: 0.6562 - val_loss: 0.6562 - val_accuracy: 0.5000
# Epoch 24/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.7219 - accuracy: 0.6417
# Epoch 00024: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.7151 - accuracy: 0.6484 - val_loss: 0.6570 - val_accuracy: 0.5000
# Epoch 25/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.7488 - accuracy: 0.5917
# Epoch 00025: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.7601 - accuracy: 0.5703 - val_loss: 0.6540 - val_accuracy: 0.5000
# Epoch 26/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.6509 - accuracy: 0.6750
# Epoch 00026: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.6745 - accuracy: 0.6641 - val_loss: 0.6563 - val_accuracy: 0.5000
# Epoch 27/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.7299 - accuracy: 0.5857
# Epoch 00027: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.7486 - accuracy: 0.5781 - val_loss: 0.6547 - val_accuracy: 0.5000
# Epoch 28/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.7932 - accuracy: 0.6143
# Epoch 00028: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.6933 - accuracy: 0.6484 - val_loss: 0.6552 - val_accuracy: 0.5000
# Epoch 29/500
# 110/128 [========================>.....] - ETA: 0s - loss: 0.5758 - accuracy: 0.6909
# Epoch 00029: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.5796 - accuracy: 0.6797 - val_loss: 0.6587 - val_accuracy: 0.5000
# Epoch 30/500
# 110/128 [========================>.....] - ETA: 0s - loss: 0.5851 - accuracy: 0.7455
# Epoch 00030: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.6328 - accuracy: 0.7109 - val_loss: 0.6620 - val_accuracy: 0.5000
# Epoch 31/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.7037 - accuracy: 0.6286
# Epoch 00031: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.6701 - accuracy: 0.6719 - val_loss: 0.6565 - val_accuracy: 0.5962
# Epoch 32/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.6441 - accuracy: 0.6143
# Epoch 00032: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.5868 - accuracy: 0.6641 - val_loss: 0.6562 - val_accuracy: 0.5962
# Epoch 33/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.5495 - accuracy: 0.7250
# Epoch 00033: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.5443 - accuracy: 0.7266 - val_loss: 0.6466 - val_accuracy: 0.6154
# Epoch 34/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.6556 - accuracy: 0.6833
# Epoch 00034: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.6565 - accuracy: 0.6797 - val_loss: 0.6363 - val_accuracy: 0.7885
# Epoch 35/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.4701 - accuracy: 0.8083
# Epoch 00035: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4760 - accuracy: 0.7969 - val_loss: 0.6274 - val_accuracy: 0.7115
# Epoch 36/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.5427 - accuracy: 0.7286
# Epoch 00036: val_accuracy did not improve from 0.78846
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.6179 - accuracy: 0.6641 - val_loss: 0.6126 - val_accuracy: 0.7692
# Epoch 37/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.5770 - accuracy: 0.6917
# Epoch 00037: val_accuracy improved from 0.78846 to 0.84615, saving model to models/CNN2_dataset_2_trim8_37.h5
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.5497 - accuracy: 0.7109 - val_loss: 0.6062 - val_accuracy: 0.8462
# Epoch 38/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.5865 - accuracy: 0.6917
# Epoch 00038: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.5863 - accuracy: 0.6953 - val_loss: 0.6084 - val_accuracy: 0.7692
# Epoch 39/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.4216 - accuracy: 0.7857
# Epoch 00039: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4261 - accuracy: 0.8047 - val_loss: 0.5846 - val_accuracy: 0.8077
# Epoch 40/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.4535 - accuracy: 0.8000
# Epoch 00040: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4416 - accuracy: 0.8125 - val_loss: 0.5842 - val_accuracy: 0.7500
# Epoch 41/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.5235 - accuracy: 0.7583
# Epoch 00041: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.5020 - accuracy: 0.7734 - val_loss: 0.6024 - val_accuracy: 0.7500
# Epoch 42/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.5860 - accuracy: 0.7000
# Epoch 00042: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.5218 - accuracy: 0.7031 - val_loss: 0.6054 - val_accuracy: 0.7500
# Epoch 43/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.4288 - accuracy: 0.8000
# Epoch 00043: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4643 - accuracy: 0.7734 - val_loss: 0.6091 - val_accuracy: 0.7115
# Epoch 44/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.4753 - accuracy: 0.7917
# Epoch 00044: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4627 - accuracy: 0.7969 - val_loss: 0.6199 - val_accuracy: 0.7115
# Epoch 45/500
# 110/128 [========================>.....] - ETA: 0s - loss: 0.4395 - accuracy: 0.7727
# Epoch 00045: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4690 - accuracy: 0.7422 - val_loss: 0.6452 - val_accuracy: 0.5769
# Epoch 46/500
# 100/128 [======================>.......] - ETA: 0s - loss: 0.4830 - accuracy: 0.6900
# Epoch 00046: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4852 - accuracy: 0.6875 - val_loss: 0.5688 - val_accuracy: 0.7115
# Epoch 47/500
# 110/128 [========================>.....] - ETA: 0s - loss: 0.4535 - accuracy: 0.8000
# Epoch 00047: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4509 - accuracy: 0.7969 - val_loss: 0.6408 - val_accuracy: 0.7692
# Epoch 48/500
# 110/128 [========================>.....] - ETA: 0s - loss: 0.4682 - accuracy: 0.7545
# Epoch 00048: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4566 - accuracy: 0.7578 - val_loss: 0.6323 - val_accuracy: 0.7115
# Epoch 49/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.4860 - accuracy: 0.7417
# Epoch 00049: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4705 - accuracy: 0.7500 - val_loss: 0.7258 - val_accuracy: 0.5962
# Epoch 50/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.4410 - accuracy: 0.8167
# Epoch 00050: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4441 - accuracy: 0.8047 - val_loss: 0.6764 - val_accuracy: 0.5385
# Epoch 51/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.4682 - accuracy: 0.7750
# Epoch 00051: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4735 - accuracy: 0.7656 - val_loss: 0.6466 - val_accuracy: 0.6923
# Epoch 52/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.4446 - accuracy: 0.8000
# Epoch 00052: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3773 - accuracy: 0.8281 - val_loss: 0.7040 - val_accuracy: 0.5962
# Epoch 53/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.3895 - accuracy: 0.8333
# Epoch 00053: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3871 - accuracy: 0.8359 - val_loss: 0.6963 - val_accuracy: 0.5769
# Epoch 54/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.4281 - accuracy: 0.7583
# Epoch 00054: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4190 - accuracy: 0.7578 - val_loss: 0.6523 - val_accuracy: 0.7115
# Epoch 55/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3395 - accuracy: 0.8286
# Epoch 00055: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4011 - accuracy: 0.8203 - val_loss: 0.6680 - val_accuracy: 0.7115
# Epoch 56/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.4409 - accuracy: 0.8000
# Epoch 00056: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4373 - accuracy: 0.7812 - val_loss: 0.6505 - val_accuracy: 0.6923
# Epoch 57/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.3603 - accuracy: 0.8250
# Epoch 00057: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3687 - accuracy: 0.8281 - val_loss: 0.7237 - val_accuracy: 0.5385
# Epoch 58/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.3844 - accuracy: 0.8167
# Epoch 00058: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3750 - accuracy: 0.8203 - val_loss: 0.7461 - val_accuracy: 0.5385
# Epoch 59/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.3453 - accuracy: 0.8250
# Epoch 00059: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3360 - accuracy: 0.8281 - val_loss: 0.7558 - val_accuracy: 0.5385
# Epoch 60/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.3468 - accuracy: 0.8250
# Epoch 00060: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3676 - accuracy: 0.8047 - val_loss: 0.9484 - val_accuracy: 0.5769
# Epoch 61/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3617 - accuracy: 0.8143
# Epoch 00061: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4133 - accuracy: 0.7891 - val_loss: 0.8671 - val_accuracy: 0.5962
# Epoch 62/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.3695 - accuracy: 0.8250
# Epoch 00062: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3638 - accuracy: 0.8281 - val_loss: 0.8886 - val_accuracy: 0.6154
# Epoch 63/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.3858 - accuracy: 0.8333
# Epoch 00063: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3720 - accuracy: 0.8438 - val_loss: 0.7794 - val_accuracy: 0.5577
# Epoch 64/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.3630 - accuracy: 0.8333
# Epoch 00064: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3696 - accuracy: 0.8281 - val_loss: 0.7932 - val_accuracy: 0.6154
# Epoch 65/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.4095 - accuracy: 0.8714
# Epoch 00065: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4059 - accuracy: 0.8359 - val_loss: 0.7361 - val_accuracy: 0.7308
# Epoch 66/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.4735 - accuracy: 0.7857
# Epoch 00066: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4048 - accuracy: 0.8203 - val_loss: 0.7550 - val_accuracy: 0.5962
# Epoch 67/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.3822 - accuracy: 0.8167
# Epoch 00067: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3861 - accuracy: 0.8203 - val_loss: 0.8051 - val_accuracy: 0.5962
# Epoch 68/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.3146 - accuracy: 0.8583
# Epoch 00068: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3291 - accuracy: 0.8438 - val_loss: 0.7909 - val_accuracy: 0.5577
# Epoch 69/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.4252 - accuracy: 0.8083
# Epoch 00069: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4140 - accuracy: 0.8125 - val_loss: 0.8281 - val_accuracy: 0.5962
# Epoch 70/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3533 - accuracy: 0.8286
# Epoch 00070: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3562 - accuracy: 0.8203 - val_loss: 0.8418 - val_accuracy: 0.5577
# Epoch 71/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2956 - accuracy: 0.8571
# Epoch 00071: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.4242 - accuracy: 0.7969 - val_loss: 0.9387 - val_accuracy: 0.5769
# Epoch 72/500
# 110/128 [========================>.....] - ETA: 0s - loss: 0.3683 - accuracy: 0.8000
# Epoch 00072: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3623 - accuracy: 0.8047 - val_loss: 0.7712 - val_accuracy: 0.6154
# Epoch 73/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2966 - accuracy: 0.9286
# Epoch 00073: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3080 - accuracy: 0.8984 - val_loss: 0.7159 - val_accuracy: 0.7692
# Epoch 74/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2788 - accuracy: 0.8667
# Epoch 00074: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2765 - accuracy: 0.8750 - val_loss: 0.7612 - val_accuracy: 0.7885
# Epoch 75/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3487 - accuracy: 0.8429
# Epoch 00075: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3589 - accuracy: 0.8203 - val_loss: 0.8853 - val_accuracy: 0.6154
# Epoch 76/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3665 - accuracy: 0.8143
# Epoch 00076: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3105 - accuracy: 0.8516 - val_loss: 0.7933 - val_accuracy: 0.7692
# Epoch 77/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3525 - accuracy: 0.8000
# Epoch 00077: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3392 - accuracy: 0.8203 - val_loss: 0.7912 - val_accuracy: 0.7885
# Epoch 78/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3398 - accuracy: 0.8286
# Epoch 00078: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3121 - accuracy: 0.8438 - val_loss: 0.8306 - val_accuracy: 0.7885
# Epoch 79/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2278 - accuracy: 0.9143
# Epoch 00079: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2953 - accuracy: 0.8516 - val_loss: 0.8558 - val_accuracy: 0.7692
# Epoch 80/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3117 - accuracy: 0.8571
# Epoch 00080: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3104 - accuracy: 0.8672 - val_loss: 0.9057 - val_accuracy: 0.5962
# Epoch 81/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2692 - accuracy: 0.8750
# Epoch 00081: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2737 - accuracy: 0.8750 - val_loss: 0.9102 - val_accuracy: 0.5962
# Epoch 82/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2778 - accuracy: 0.8429
# Epoch 00082: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2827 - accuracy: 0.8594 - val_loss: 0.9057 - val_accuracy: 0.5962
# Epoch 83/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3319 - accuracy: 0.8000
# Epoch 00083: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3246 - accuracy: 0.8125 - val_loss: 0.9022 - val_accuracy: 0.7692
# Epoch 84/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.3363 - accuracy: 0.8250
# Epoch 00084: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3268 - accuracy: 0.8359 - val_loss: 0.9176 - val_accuracy: 0.7885
# Epoch 85/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2626 - accuracy: 0.8714
# Epoch 00085: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3136 - accuracy: 0.8516 - val_loss: 0.8637 - val_accuracy: 0.7692
# Epoch 86/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3506 - accuracy: 0.8000
# Epoch 00086: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2948 - accuracy: 0.8516 - val_loss: 1.0082 - val_accuracy: 0.6154
# Epoch 87/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.3452 - accuracy: 0.8167
# Epoch 00087: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3542 - accuracy: 0.8125 - val_loss: 0.8445 - val_accuracy: 0.7692
# Epoch 88/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.3327 - accuracy: 0.8250
# Epoch 00088: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3323 - accuracy: 0.8203 - val_loss: 0.9444 - val_accuracy: 0.6154
# Epoch 89/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3266 - accuracy: 0.8571
# Epoch 00089: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2745 - accuracy: 0.8828 - val_loss: 0.9070 - val_accuracy: 0.7885
# Epoch 90/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2313 - accuracy: 0.8714
# Epoch 00090: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2614 - accuracy: 0.8594 - val_loss: 0.8497 - val_accuracy: 0.7308
# Epoch 91/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3412 - accuracy: 0.8714
# Epoch 00091: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3304 - accuracy: 0.8828 - val_loss: 0.8120 - val_accuracy: 0.7308
# Epoch 92/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2831 - accuracy: 0.8286
# Epoch 00092: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2895 - accuracy: 0.8281 - val_loss: 0.9340 - val_accuracy: 0.6154
# Epoch 93/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2676 - accuracy: 0.8571
# Epoch 00093: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2496 - accuracy: 0.8828 - val_loss: 0.8014 - val_accuracy: 0.7115
# Epoch 94/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3047 - accuracy: 0.8143
# Epoch 00094: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3184 - accuracy: 0.8281 - val_loss: 0.9041 - val_accuracy: 0.5962
# Epoch 95/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.4432 - accuracy: 0.7714
# Epoch 00095: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3826 - accuracy: 0.7969 - val_loss: 0.8291 - val_accuracy: 0.7692
# Epoch 96/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2289 - accuracy: 0.9286
# Epoch 00096: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3162 - accuracy: 0.8906 - val_loss: 0.7854 - val_accuracy: 0.7308
# Epoch 97/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2848 - accuracy: 0.8857
# Epoch 00097: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2617 - accuracy: 0.8828 - val_loss: 0.9188 - val_accuracy: 0.6154
# Epoch 98/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3803 - accuracy: 0.8143
# Epoch 00098: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3284 - accuracy: 0.8516 - val_loss: 0.8615 - val_accuracy: 0.7308
# Epoch 99/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2898 - accuracy: 0.8571
# Epoch 00099: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3066 - accuracy: 0.8438 - val_loss: 0.9074 - val_accuracy: 0.5962
# Epoch 100/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2547 - accuracy: 0.8833
# Epoch 00100: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2623 - accuracy: 0.8672 - val_loss: 0.8798 - val_accuracy: 0.7308
# Epoch 101/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2777 - accuracy: 0.8429
# Epoch 00101: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2918 - accuracy: 0.8281 - val_loss: 0.9758 - val_accuracy: 0.6154
# Epoch 102/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.3406 - accuracy: 0.8250
# Epoch 00102: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3258 - accuracy: 0.8359 - val_loss: 0.8242 - val_accuracy: 0.7692
# Epoch 103/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2901 - accuracy: 0.8714
# Epoch 00103: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3094 - accuracy: 0.8750 - val_loss: 0.8754 - val_accuracy: 0.7885
# Epoch 104/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.3395 - accuracy: 0.8000
# Epoch 00104: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3263 - accuracy: 0.8125 - val_loss: 1.0428 - val_accuracy: 0.6154
# Epoch 105/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2202 - accuracy: 0.9000
# Epoch 00105: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2379 - accuracy: 0.8906 - val_loss: 0.8629 - val_accuracy: 0.7308
# Epoch 106/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3190 - accuracy: 0.8286
# Epoch 00106: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2764 - accuracy: 0.8516 - val_loss: 0.9570 - val_accuracy: 0.6154
# Epoch 107/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2563 - accuracy: 0.8714
# Epoch 00107: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2816 - accuracy: 0.8516 - val_loss: 0.8438 - val_accuracy: 0.7308
# Epoch 108/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2892 - accuracy: 0.8429
# Epoch 00108: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3056 - accuracy: 0.8359 - val_loss: 0.9091 - val_accuracy: 0.7885
# Epoch 109/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2949 - accuracy: 0.8857
# Epoch 00109: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2768 - accuracy: 0.8828 - val_loss: 0.8802 - val_accuracy: 0.7885
# Epoch 110/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2646 - accuracy: 0.8571
# Epoch 00110: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2548 - accuracy: 0.8672 - val_loss: 0.9724 - val_accuracy: 0.7885
# Epoch 111/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3060 - accuracy: 0.8429
# Epoch 00111: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2878 - accuracy: 0.8594 - val_loss: 0.8349 - val_accuracy: 0.7692
# Epoch 112/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2860 - accuracy: 0.9000
# Epoch 00112: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2504 - accuracy: 0.9141 - val_loss: 1.0478 - val_accuracy: 0.6154
# Epoch 113/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2085 - accuracy: 0.8857
# Epoch 00113: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2456 - accuracy: 0.8672 - val_loss: 0.8941 - val_accuracy: 0.7885
# Epoch 114/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.3347 - accuracy: 0.8250
# Epoch 00114: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2855 - accuracy: 0.8594 - val_loss: 0.9797 - val_accuracy: 0.7885
# Epoch 115/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.2630 - accuracy: 0.9000
# Epoch 00115: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3032 - accuracy: 0.8828 - val_loss: 0.8252 - val_accuracy: 0.7692
# Epoch 116/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2743 - accuracy: 0.8571
# Epoch 00116: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2629 - accuracy: 0.8906 - val_loss: 0.8817 - val_accuracy: 0.7885
# Epoch 117/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2034 - accuracy: 0.9143
# Epoch 00117: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2263 - accuracy: 0.8984 - val_loss: 1.0843 - val_accuracy: 0.6154
# Epoch 118/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1871 - accuracy: 0.9429
# Epoch 00118: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2520 - accuracy: 0.9062 - val_loss: 0.8563 - val_accuracy: 0.7692
# Epoch 119/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3390 - accuracy: 0.8429
# Epoch 00119: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2937 - accuracy: 0.8672 - val_loss: 0.8213 - val_accuracy: 0.7885
# Epoch 120/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2356 - accuracy: 0.8714
# Epoch 00120: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2381 - accuracy: 0.8672 - val_loss: 0.8811 - val_accuracy: 0.7885
# Epoch 121/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2781 - accuracy: 0.8429
# Epoch 00121: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2933 - accuracy: 0.8438 - val_loss: 0.9327 - val_accuracy: 0.7885
# Epoch 122/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2638 - accuracy: 0.8571
# Epoch 00122: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3034 - accuracy: 0.8594 - val_loss: 0.9747 - val_accuracy: 0.6154
# Epoch 123/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3041 - accuracy: 0.8143
# Epoch 00123: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2757 - accuracy: 0.8516 - val_loss: 0.8921 - val_accuracy: 0.7885
# Epoch 124/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2554 - accuracy: 0.8571
# Epoch 00124: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2226 - accuracy: 0.8906 - val_loss: 0.8424 - val_accuracy: 0.7885
# Epoch 125/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3181 - accuracy: 0.8143
# Epoch 00125: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2872 - accuracy: 0.8359 - val_loss: 0.8438 - val_accuracy: 0.7885
# Epoch 126/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.1828 - accuracy: 0.9375
# Epoch 00126: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2128 - accuracy: 0.9141 - val_loss: 0.9820 - val_accuracy: 0.7885
# Epoch 127/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1835 - accuracy: 0.9000
# Epoch 00127: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1647 - accuracy: 0.9219 - val_loss: 0.9612 - val_accuracy: 0.7885
# Epoch 128/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2377 - accuracy: 0.9000
# Epoch 00128: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2314 - accuracy: 0.9141 - val_loss: 1.2441 - val_accuracy: 0.6154
# Epoch 129/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3391 - accuracy: 0.8857
# Epoch 00129: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2632 - accuracy: 0.8906 - val_loss: 1.0375 - val_accuracy: 0.7885
# Epoch 130/500
# 110/128 [========================>.....] - ETA: 0s - loss: 0.2221 - accuracy: 0.9182
# Epoch 00130: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2011 - accuracy: 0.9297 - val_loss: 1.0123 - val_accuracy: 0.7885
# Epoch 131/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2090 - accuracy: 0.9000
# Epoch 00131: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2446 - accuracy: 0.8984 - val_loss: 0.9526 - val_accuracy: 0.7885
# Epoch 132/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2398 - accuracy: 0.8833
# Epoch 00132: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2398 - accuracy: 0.8828 - val_loss: 1.1811 - val_accuracy: 0.6154
# Epoch 133/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2003 - accuracy: 0.9000
# Epoch 00133: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1899 - accuracy: 0.9062 - val_loss: 0.9928 - val_accuracy: 0.7692
# Epoch 134/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2917 - accuracy: 0.8667
# Epoch 00134: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2841 - accuracy: 0.8750 - val_loss: 1.1272 - val_accuracy: 0.6154
# Epoch 135/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3139 - accuracy: 0.8286
# Epoch 00135: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2711 - accuracy: 0.8672 - val_loss: 0.9686 - val_accuracy: 0.7885
# Epoch 136/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.2457 - accuracy: 0.9000
# Epoch 00136: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2532 - accuracy: 0.9141 - val_loss: 1.0361 - val_accuracy: 0.6154
# Epoch 137/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2238 - accuracy: 0.8917
# Epoch 00137: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2418 - accuracy: 0.8750 - val_loss: 0.8128 - val_accuracy: 0.7308
# Epoch 138/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2283 - accuracy: 0.8833
# Epoch 00138: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2408 - accuracy: 0.8750 - val_loss: 0.9861 - val_accuracy: 0.7885
# Epoch 139/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.3173 - accuracy: 0.8583
# Epoch 00139: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.3081 - accuracy: 0.8594 - val_loss: 0.8372 - val_accuracy: 0.7885
# Epoch 140/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2368 - accuracy: 0.8583
# Epoch 00140: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2447 - accuracy: 0.8516 - val_loss: 0.9802 - val_accuracy: 0.7885
# Epoch 141/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2333 - accuracy: 0.8750
# Epoch 00141: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2500 - accuracy: 0.8750 - val_loss: 0.9336 - val_accuracy: 0.7885
# Epoch 142/500
# 110/128 [========================>.....] - ETA: 0s - loss: 0.2369 - accuracy: 0.8818
# Epoch 00142: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 2ms/sample - loss: 0.2598 - accuracy: 0.8750 - val_loss: 1.1045 - val_accuracy: 0.6154
# Epoch 143/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2224 - accuracy: 0.9083
# Epoch 00143: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2182 - accuracy: 0.9062 - val_loss: 0.9808 - val_accuracy: 0.7885
# Epoch 144/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1750 - accuracy: 0.9429
# Epoch 00144: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2020 - accuracy: 0.9297 - val_loss: 0.8713 - val_accuracy: 0.7885
# Epoch 145/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2059 - accuracy: 0.9286
# Epoch 00145: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2279 - accuracy: 0.8984 - val_loss: 1.0980 - val_accuracy: 0.6154
# Epoch 146/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2598 - accuracy: 0.8833
# Epoch 00146: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2486 - accuracy: 0.8906 - val_loss: 1.0646 - val_accuracy: 0.6154
# Epoch 147/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2003 - accuracy: 0.9286
# Epoch 00147: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1943 - accuracy: 0.9062 - val_loss: 1.0792 - val_accuracy: 0.6154
# Epoch 148/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2349 - accuracy: 0.8833
# Epoch 00148: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2464 - accuracy: 0.8828 - val_loss: 1.0465 - val_accuracy: 0.7885
# Epoch 149/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.3178 - accuracy: 0.8286
# Epoch 00149: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2750 - accuracy: 0.8750 - val_loss: 1.1816 - val_accuracy: 0.6154
# Epoch 150/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2181 - accuracy: 0.9000
# Epoch 00150: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2092 - accuracy: 0.9062 - val_loss: 1.1120 - val_accuracy: 0.6154
# Epoch 151/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2251 - accuracy: 0.9333
# Epoch 00151: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2232 - accuracy: 0.9297 - val_loss: 1.0352 - val_accuracy: 0.6154
# Epoch 152/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2400 - accuracy: 0.8583
# Epoch 00152: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2449 - accuracy: 0.8594 - val_loss: 1.1899 - val_accuracy: 0.6154
# Epoch 153/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2292 - accuracy: 0.9000
# Epoch 00153: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2285 - accuracy: 0.8984 - val_loss: 1.0554 - val_accuracy: 0.7885
# Epoch 154/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.1952 - accuracy: 0.9083
# Epoch 00154: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1926 - accuracy: 0.9062 - val_loss: 1.1371 - val_accuracy: 0.6154
# Epoch 155/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1989 - accuracy: 0.9429
# Epoch 00155: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1934 - accuracy: 0.9453 - val_loss: 1.1282 - val_accuracy: 0.6154
# Epoch 156/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1850 - accuracy: 0.9286
# Epoch 00156: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2005 - accuracy: 0.9219 - val_loss: 1.0877 - val_accuracy: 0.7885
# Epoch 157/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.2093 - accuracy: 0.8750
# Epoch 00157: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1971 - accuracy: 0.8828 - val_loss: 1.0684 - val_accuracy: 0.7885
# Epoch 158/500
# 110/128 [========================>.....] - ETA: 0s - loss: 0.1985 - accuracy: 0.9000
# Epoch 00158: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1945 - accuracy: 0.9062 - val_loss: 0.9325 - val_accuracy: 0.7692
# Epoch 159/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.1910 - accuracy: 0.9083
# Epoch 00159: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1825 - accuracy: 0.9141 - val_loss: 1.0945 - val_accuracy: 0.7885
# Epoch 160/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2233 - accuracy: 0.9000
# Epoch 00160: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2100 - accuracy: 0.8984 - val_loss: 1.0066 - val_accuracy: 0.7885
# Epoch 161/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.1884 - accuracy: 0.9083
# Epoch 00161: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2003 - accuracy: 0.9062 - val_loss: 1.2435 - val_accuracy: 0.6154
# Epoch 162/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2018 - accuracy: 0.9000
# Epoch 00162: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2083 - accuracy: 0.9062 - val_loss: 1.1788 - val_accuracy: 0.7885
# Epoch 163/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.1725 - accuracy: 0.9000
# Epoch 00163: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1860 - accuracy: 0.8906 - val_loss: 1.3677 - val_accuracy: 0.6154
# Epoch 164/500
# 110/128 [========================>.....] - ETA: 0s - loss: 0.1463 - accuracy: 0.9364
# Epoch 00164: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1624 - accuracy: 0.9297 - val_loss: 1.1279 - val_accuracy: 0.7885
# Epoch 165/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.1840 - accuracy: 0.9000
# Epoch 00165: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1851 - accuracy: 0.8984 - val_loss: 1.2944 - val_accuracy: 0.7885
# Epoch 166/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2332 - accuracy: 0.9143
# Epoch 00166: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2024 - accuracy: 0.9297 - val_loss: 1.1219 - val_accuracy: 0.7885
# Epoch 167/500
# 120/128 [===========================>..] - ETA: 0s - loss: 0.1688 - accuracy: 0.9333
# Epoch 00167: val_accuracy did not improve from 0.84615
# ...
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0537 - accuracy: 0.9922 - val_loss: 1.6960 - val_accuracy: 0.6923
# Epoch 446/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0391 - accuracy: 0.9857
# Epoch 00446: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0857 - accuracy: 0.9688 - val_loss: 1.8044 - val_accuracy: 0.7500
# Epoch 447/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0781 - accuracy: 0.9500
# Epoch 00447: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1195 - accuracy: 0.9531 - val_loss: 1.6626 - val_accuracy: 0.7115
# Epoch 448/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1301 - accuracy: 0.9429
# Epoch 00448: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0983 - accuracy: 0.9531 - val_loss: 1.5923 - val_accuracy: 0.7115
# Epoch 449/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0506 - accuracy: 0.9857
# Epoch 00449: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0495 - accuracy: 0.9766 - val_loss: 1.8134 - val_accuracy: 0.7500
# Epoch 450/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0594 - accuracy: 0.9714
# Epoch 00450: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0585 - accuracy: 0.9766 - val_loss: 1.9694 - val_accuracy: 0.7500
# Epoch 451/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.1551 - accuracy: 0.9250
# Epoch 00451: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2572 - accuracy: 0.8984 - val_loss: 1.6078 - val_accuracy: 0.7115
# Epoch 452/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.2356 - accuracy: 0.9429
# Epoch 00452: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2473 - accuracy: 0.9219 - val_loss: 0.8323 - val_accuracy: 0.7500
# Epoch 453/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.2603 - accuracy: 0.9000
# Epoch 00453: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.2387 - accuracy: 0.9141 - val_loss: 0.7682 - val_accuracy: 0.6346
# Epoch 454/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1669 - accuracy: 0.9143
# Epoch 00454: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1523 - accuracy: 0.9141 - val_loss: 0.9411 - val_accuracy: 0.6538
# Epoch 455/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0591 - accuracy: 0.9875
# Epoch 00455: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0755 - accuracy: 0.9766 - val_loss: 1.0676 - val_accuracy: 0.6154
# Epoch 456/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0931 - accuracy: 0.9625
# Epoch 00456: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0854 - accuracy: 0.9609 - val_loss: 1.1714 - val_accuracy: 0.7115
# Epoch 457/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1079 - accuracy: 0.9571
# Epoch 00457: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0991 - accuracy: 0.9531 - val_loss: 1.1682 - val_accuracy: 0.6538
# Epoch 458/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0637 - accuracy: 0.9714
# Epoch 00458: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0795 - accuracy: 0.9766 - val_loss: 1.2411 - val_accuracy: 0.6538
# Epoch 459/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0956 - accuracy: 0.9571
# Epoch 00459: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0652 - accuracy: 0.9766 - val_loss: 1.2650 - val_accuracy: 0.6346
# Epoch 460/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0586 - accuracy: 0.9857
# Epoch 00460: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0833 - accuracy: 0.9609 - val_loss: 1.4036 - val_accuracy: 0.7115
# Epoch 461/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0667 - accuracy: 0.9857
# Epoch 00461: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0583 - accuracy: 0.9766 - val_loss: 1.3217 - val_accuracy: 0.6346
# Epoch 462/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1146 - accuracy: 0.9571
# Epoch 00462: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0817 - accuracy: 0.9609 - val_loss: 1.4723 - val_accuracy: 0.6346
# Epoch 463/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0812 - accuracy: 0.9857
# Epoch 00463: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0913 - accuracy: 0.9766 - val_loss: 1.5242 - val_accuracy: 0.6923
# Epoch 464/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0996 - accuracy: 0.9429
# Epoch 00464: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1084 - accuracy: 0.9375 - val_loss: 1.4429 - val_accuracy: 0.6538
# Epoch 465/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0216 - accuracy: 1.0000
# Epoch 00465: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0436 - accuracy: 0.9922 - val_loss: 1.5147 - val_accuracy: 0.7115
# Epoch 466/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0665 - accuracy: 0.9875
# Epoch 00466: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0786 - accuracy: 0.9766 - val_loss: 1.4533 - val_accuracy: 0.6346
# Epoch 467/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0833 - accuracy: 0.9571
# Epoch 00467: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0739 - accuracy: 0.9609 - val_loss: 1.4589 - val_accuracy: 0.6538
# Epoch 468/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0562 - accuracy: 0.9857
# Epoch 00468: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0627 - accuracy: 0.9766 - val_loss: 1.6001 - val_accuracy: 0.7308
# Epoch 469/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1063 - accuracy: 0.9429
# Epoch 00469: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0814 - accuracy: 0.9609 - val_loss: 1.5278 - val_accuracy: 0.6346
# Epoch 470/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0504 - accuracy: 0.9857
# Epoch 00470: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0387 - accuracy: 0.9922 - val_loss: 1.6462 - val_accuracy: 0.6538
# Epoch 471/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1557 - accuracy: 0.9143
# Epoch 00471: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1119 - accuracy: 0.9375 - val_loss: 1.6192 - val_accuracy: 0.6923
# Epoch 472/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1133 - accuracy: 0.9571
# Epoch 00472: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1125 - accuracy: 0.9609 - val_loss: 1.9118 - val_accuracy: 0.7692
# Epoch 473/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1007 - accuracy: 0.9714
# Epoch 00473: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0714 - accuracy: 0.9844 - val_loss: 1.6423 - val_accuracy: 0.7115
# Epoch 474/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1006 - accuracy: 0.9571
# Epoch 00474: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0912 - accuracy: 0.9531 - val_loss: 1.6018 - val_accuracy: 0.6923
# Epoch 475/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0284 - accuracy: 1.0000
# Epoch 00475: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0571 - accuracy: 0.9922 - val_loss: 1.5955 - val_accuracy: 0.6923
# Epoch 476/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0513 - accuracy: 0.9875
# Epoch 00476: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0810 - accuracy: 0.9766 - val_loss: 1.5856 - val_accuracy: 0.6346
# Epoch 477/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0862 - accuracy: 0.9429
# Epoch 00477: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0874 - accuracy: 0.9531 - val_loss: 1.9229 - val_accuracy: 0.7500
# Epoch 478/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.1019 - accuracy: 0.9625
# Epoch 00478: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0822 - accuracy: 0.9688 - val_loss: 1.6911 - val_accuracy: 0.7308
# Epoch 479/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0402 - accuracy: 0.9875
# Epoch 00479: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0399 - accuracy: 0.9922 - val_loss: 1.6324 - val_accuracy: 0.6923
# Epoch 480/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0229 - accuracy: 1.0000
# Epoch 00480: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0393 - accuracy: 0.9922 - val_loss: 1.7910 - val_accuracy: 0.6923
# Epoch 481/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0605 - accuracy: 0.9571
# Epoch 00481: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0757 - accuracy: 0.9531 - val_loss: 1.9377 - val_accuracy: 0.7500
# Epoch 482/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0897 - accuracy: 0.9625
# Epoch 00482: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0688 - accuracy: 0.9766 - val_loss: 1.8374 - val_accuracy: 0.7115
# Epoch 483/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0648 - accuracy: 0.9571
# Epoch 00483: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1075 - accuracy: 0.9453 - val_loss: 1.7939 - val_accuracy: 0.6923
# Epoch 484/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0699 - accuracy: 0.9571
# Epoch 00484: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0633 - accuracy: 0.9688 - val_loss: 2.0172 - val_accuracy: 0.7500
# Epoch 485/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0361 - accuracy: 1.0000
# Epoch 00485: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0469 - accuracy: 0.9844 - val_loss: 1.8660 - val_accuracy: 0.6346
# Epoch 486/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0518 - accuracy: 0.9857
# Epoch 00486: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0988 - accuracy: 0.9688 - val_loss: 2.0803 - val_accuracy: 0.6923
# Epoch 487/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0430 - accuracy: 0.9875
# Epoch 00487: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0434 - accuracy: 0.9844 - val_loss: 2.1264 - val_accuracy: 0.6538
# Epoch 488/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0686 - accuracy: 0.9625
# Epoch 00488: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0975 - accuracy: 0.9531 - val_loss: 2.1249 - val_accuracy: 0.7500
# Epoch 489/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1244 - accuracy: 0.9571
# Epoch 00489: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1906 - accuracy: 0.9375 - val_loss: 1.7491 - val_accuracy: 0.6346
# Epoch 490/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0817 - accuracy: 0.9714
# Epoch 00490: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1020 - accuracy: 0.9609 - val_loss: 1.8111 - val_accuracy: 0.7500
# Epoch 491/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0591 - accuracy: 0.9750
# Epoch 00491: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0869 - accuracy: 0.9688 - val_loss: 1.5334 - val_accuracy: 0.5385
# Epoch 492/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0465 - accuracy: 0.9714
# Epoch 00492: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0546 - accuracy: 0.9844 - val_loss: 1.8147 - val_accuracy: 0.7500
# Epoch 493/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0996 - accuracy: 0.9571
# Epoch 00493: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0701 - accuracy: 0.9766 - val_loss: 1.7457 - val_accuracy: 0.6731
# Epoch 494/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0889 - accuracy: 0.9714
# Epoch 00494: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0750 - accuracy: 0.9688 - val_loss: 1.7663 - val_accuracy: 0.5385
# Epoch 495/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0374 - accuracy: 0.9857
# Epoch 00495: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0472 - accuracy: 0.9844 - val_loss: 1.7767 - val_accuracy: 0.6346
# Epoch 496/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0981 - accuracy: 0.9429
# Epoch 00496: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0662 - accuracy: 0.9688 - val_loss: 1.8416 - val_accuracy: 0.7115
# Epoch 497/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.0663 - accuracy: 0.9857
# Epoch 00497: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0601 - accuracy: 0.9844 - val_loss: 1.7718 - val_accuracy: 0.5385
# Epoch 498/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1573 - accuracy: 0.9286
# Epoch 00498: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1262 - accuracy: 0.9453 - val_loss: 2.0517 - val_accuracy: 0.7500
# Epoch 499/500
#  70/128 [===============>..............] - ETA: 0s - loss: 0.1475 - accuracy: 0.9714
# Epoch 00499: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.1120 - accuracy: 0.9688 - val_loss: 1.6411 - val_accuracy: 0.5385
# Epoch 500/500
#  80/128 [=================>............] - ETA: 0s - loss: 0.0768 - accuracy: 0.9500
# Epoch 00500: val_accuracy did not improve from 0.84615
# 128/128 [==============================] - 0s 1ms/sample - loss: 0.0620 - accuracy: 0.9688 - val_loss: 1.6887 - val_accuracy: 0.7308
# Training completed in time:  0:01:15.985036

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
train_acc = score[1]
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
test_acc = score[1]
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.96875
# Testing Accuracy:  0.7307692

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.83      0.58      0.68        26
#    Pneumonia       0.68      0.88      0.77        26
#
#     accuracy                           0.73        52
#    macro avg       0.75      0.73      0.72        52
# weighted avg       0.75      0.73      0.72        52

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[15 11]
#  [ 3 23]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])

# %% [markdown]
# __Write CSV__

# %%
with open('report.csv', 'a') as report:
    report.write(f'{MODEL_NAME},{DATASET},{GROUP_TRAIN},{DURATION},{train_acc},{test_acc}\n')
