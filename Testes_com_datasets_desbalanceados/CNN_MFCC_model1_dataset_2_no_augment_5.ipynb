# %% [markdown]
# # Rede CNN - Modelo 1
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - Dataset 2 - no_augment_5

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP_TRAIN = 'no_augment_5'
GROUP_TEST = 'no_augment_5'
DATASET = 'dataset_2'
DURATION = 5
SIZE = 216
CSV_TRAIN = 'train2.csv'
CSV_TEST = 'test2.csv'
MODEL_NAME = f'CNN1_{DATASET}_{GROUP_TRAIN}'

# %%
train_file_paths = glob.glob(f'../datasets/{DATASET}/{GROUP_TRAIN}/train/**/*.wav', recursive=True)
train_file_names = [os.path.splitext(os.path.basename(p))[0] for p in train_file_paths]

test_file_paths = glob.glob(f'../datasets/{DATASET}/{GROUP_TEST}/test/**/*.wav', recursive=True)
test_file_names = [os.path.splitext(os.path.basename(p))[0] for p in test_file_paths]

# %%
train_p_id_in_file = [] # patient IDs corresponding to each file
test_p_id_in_file = [] # patient IDs corresponding to each file
for name in train_file_names:
    train_p_id_in_file.append(int(name[:3]))

for name in test_file_names:
    test_p_id_in_file.append(int(name[:3]))

train_p_id_in_file = np.array(train_p_id_in_file)
test_p_id_in_file = np.array(test_p_id_in_file)

# %%
max_pad_len = SIZE

os.makedirs("features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=DURATION) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
train_p_diag = pd.read_csv(f"../Respiratory_Sound_Database/Respiratory_Sound_Database_Pneumo_Healthy_Only/{CSV_TRAIN}", header=None) # patient diagnosis file
test_p_diag = pd.read_csv(f"../Respiratory_Sound_Database/Respiratory_Sound_Database_Pneumo_Healthy_Only/{CSV_TEST}", header=None) # patient diagnosis file
train_p_diag.head(5)
# Out:
#      0        1
# 0  123  Healthy
# 1  125  Healthy
# 2  126  Healthy
# 3  127  Healthy
# 4  136  Healthy

# %%
train_labels = np.array([train_p_diag[train_p_diag[0] == x][1].values[0] for x in train_p_id_in_file]) 
test_labels = np.array([test_p_diag[test_p_diag[0] == x][1].values[0] for x in test_p_id_in_file])

# %%
train_features = [] 
test_features = []

for file_name in train_file_paths:
    data = extract_features(file_name)
    train_features.append(data)

for file_name in test_file_paths:
    data = extract_features(file_name)
    test_features.append(data)

print('Finished feature extraction from ', (len(train_features)+len(train_features)), ' files')
train_features = np.array(train_features)
test_features = np.array(test_features)
# Out:
# Finished feature extraction from  112  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(train_features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
np.unique(train_labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
unique_elements, counts_elements = np.unique(train_labels, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))

unique_elements_test, counts_elements_test = np.unique(test_labels, return_counts=True)
print(np.asarray((unique_elements_test, counts_elements_test)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['32' '24']]
# [['Healthy' 'Pneumonia']
#  ['3' '13']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
le.fit(train_labels)
train_labels_cat = to_categorical(le.transform(train_labels)) 
test_labels_cat = to_categorical(le.transform(test_labels))

# %%
train_features.shape
# Out:
# (56, 40, 216)

# %%
train_features = np.reshape(train_features, (*train_features.shape,1)) 
print(train_features.shape, train_labels_cat.shape)
test_features = np.reshape(test_features, (*test_features.shape,1)) 
print(test_features.shape, test_labels_cat.shape)
# Out:
# (56, 40, 216, 1) (56, 2)
# (16, 40, 216, 1) (16, 2)

# %%
# train test split
x_train, x_val, y_train, y_val = train_test_split(train_features, train_labels_cat, test_size=0.2, random_state = 42)
x_test, y_test = test_features, test_labels_cat

# %% [markdown]
# **CNN model architecture**

# %%
num_labels = train_labels_cat.shape[1]

num_rows = 40
num_columns = SIZE
num_channels = 1

filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 215, 16)       80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 107, 16)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 107, 16)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 106, 32)       2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 53, 32)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 53, 32)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 52, 64)         8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 26, 64)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 26, 64)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 25, 128)        32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 12, 128)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 12, 128)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 258
# =================================================================
# Total params: 43,570
# Trainable params: 43,570
# Non-trainable params: 0
# _________________________________________________________________
# 16/16 [==============================] - 1s 52ms/sample - loss: 0.6688 - accuracy: 0.6875
# Pre-training accuracy: 68.7500%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 500
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/' + MODEL_NAME + '_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_val, y_val), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 44 samples, validate on 12 samples
# Epoch 1/500
# 10/44 [=====>........................] - ETA: 1s - loss: 1.3859 - accuracy: 0.5000
# Epoch 00001: val_accuracy improved from -inf to 0.58333, saving model to models/CNN2_dataset_2_no_augment_5_01.h5
# 44/44 [==============================] - 1s 17ms/sample - loss: 4.1515 - accuracy: 0.4773 - val_loss: 0.8797 - val_accuracy: 0.5833
# Epoch 2/500
# 10/44 [=====>........................] - ETA: 0s - loss: 4.9859 - accuracy: 0.6000
# Epoch 00002: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 892us/sample - loss: 2.5669 - accuracy: 0.6591 - val_loss: 3.3481 - val_accuracy: 0.4167
# Epoch 3/500
# 10/44 [=====>........................] - ETA: 0s - loss: 4.1398 - accuracy: 0.4000
# Epoch 00003: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 916us/sample - loss: 2.7181 - accuracy: 0.5455 - val_loss: 0.6304 - val_accuracy: 0.5833
# Epoch 4/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.9365 - accuracy: 0.6000
# Epoch 00004: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 869us/sample - loss: 1.7441 - accuracy: 0.4318 - val_loss: 1.6794 - val_accuracy: 0.5000
# Epoch 5/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.8144 - accuracy: 0.7000
# Epoch 00005: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 838us/sample - loss: 1.4684 - accuracy: 0.5227 - val_loss: 0.6134 - val_accuracy: 0.5000
# Epoch 6/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.7612 - accuracy: 0.5000
# Epoch 00006: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 868us/sample - loss: 1.9370 - accuracy: 0.5227 - val_loss: 1.2152 - val_accuracy: 0.5000
# Epoch 7/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.3100 - accuracy: 0.4000
# Epoch 00007: val_accuracy improved from 0.58333 to 0.66667, saving model to models/CNN2_dataset_2_no_augment_5_07.h5
# 44/44 [==============================] - 0s 1ms/sample - loss: 1.0362 - accuracy: 0.5909 - val_loss: 0.7387 - val_accuracy: 0.6667
# Epoch 8/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6824 - accuracy: 0.7000
# Epoch 00008: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 884us/sample - loss: 0.8357 - accuracy: 0.6591 - val_loss: 0.8745 - val_accuracy: 0.5833
# Epoch 9/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.1970 - accuracy: 0.5000
# Epoch 00009: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 838us/sample - loss: 0.7563 - accuracy: 0.7273 - val_loss: 0.6924 - val_accuracy: 0.4167
# Epoch 10/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6724 - accuracy: 0.7000
# Epoch 00010: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 845us/sample - loss: 0.6922 - accuracy: 0.7273 - val_loss: 0.7751 - val_accuracy: 0.4167
# Epoch 11/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.1130 - accuracy: 0.7000
# Epoch 00011: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 816us/sample - loss: 0.7909 - accuracy: 0.7045 - val_loss: 0.7755 - val_accuracy: 0.4167
# Epoch 12/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1910 - accuracy: 0.9000
# Epoch 00012: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 982us/sample - loss: 0.7583 - accuracy: 0.7045 - val_loss: 0.7732 - val_accuracy: 0.4167
# Epoch 13/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5365 - accuracy: 0.6000
# Epoch 00013: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6731 - accuracy: 0.6591 - val_loss: 0.8196 - val_accuracy: 0.4167
# Epoch 14/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4002 - accuracy: 0.9000
# Epoch 00014: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6225 - accuracy: 0.7273 - val_loss: 0.7957 - val_accuracy: 0.4167
# Epoch 15/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6568 - accuracy: 0.7000
# Epoch 00015: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 887us/sample - loss: 0.5886 - accuracy: 0.6818 - val_loss: 0.7677 - val_accuracy: 0.4167
# Epoch 16/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.8020 - accuracy: 0.4000
# Epoch 00016: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 835us/sample - loss: 0.5292 - accuracy: 0.7045 - val_loss: 0.7375 - val_accuracy: 0.3333
# Epoch 17/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.4545 - accuracy: 0.5000
# Epoch 00017: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 825us/sample - loss: 0.8092 - accuracy: 0.6136 - val_loss: 0.7552 - val_accuracy: 0.4167
# Epoch 18/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3746 - accuracy: 0.8000
# Epoch 00018: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 831us/sample - loss: 0.8317 - accuracy: 0.6818 - val_loss: 0.7489 - val_accuracy: 0.4167
# Epoch 19/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2429 - accuracy: 0.9000
# Epoch 00019: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 900us/sample - loss: 0.4862 - accuracy: 0.7500 - val_loss: 0.8223 - val_accuracy: 0.5833
# Epoch 20/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.0063 - accuracy: 0.7000
# Epoch 00020: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 913us/sample - loss: 0.5698 - accuracy: 0.7500 - val_loss: 0.7096 - val_accuracy: 0.5000
# Epoch 21/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4789 - accuracy: 0.8000
# Epoch 00021: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 990us/sample - loss: 0.4693 - accuracy: 0.7727 - val_loss: 0.6718 - val_accuracy: 0.4167
# Epoch 22/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.7296 - accuracy: 0.8000
# Epoch 00022: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4330 - accuracy: 0.8182 - val_loss: 0.6785 - val_accuracy: 0.4167
# Epoch 23/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3645 - accuracy: 0.9000
# Epoch 00023: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 966us/sample - loss: 0.4523 - accuracy: 0.7273 - val_loss: 0.6490 - val_accuracy: 0.4167
# Epoch 24/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0699 - accuracy: 1.0000
# Epoch 00024: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 916us/sample - loss: 0.4901 - accuracy: 0.7955 - val_loss: 0.7357 - val_accuracy: 0.5833
# Epoch 25/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1821 - accuracy: 0.9000
# Epoch 00025: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 922us/sample - loss: 0.4487 - accuracy: 0.8182 - val_loss: 0.6681 - val_accuracy: 0.5833
# Epoch 26/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5410 - accuracy: 0.8000
# Epoch 00026: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 969us/sample - loss: 0.5081 - accuracy: 0.7955 - val_loss: 0.7356 - val_accuracy: 0.5833
# Epoch 27/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4275 - accuracy: 0.8000
# Epoch 00027: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 910us/sample - loss: 0.4281 - accuracy: 0.8409 - val_loss: 0.5933 - val_accuracy: 0.5833
# Epoch 28/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3361 - accuracy: 0.8000
# Epoch 00028: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 856us/sample - loss: 0.4575 - accuracy: 0.7045 - val_loss: 0.5812 - val_accuracy: 0.5833
# Epoch 29/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4073 - accuracy: 0.9000
# Epoch 00029: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 923us/sample - loss: 0.5132 - accuracy: 0.7500 - val_loss: 0.6516 - val_accuracy: 0.5833
# Epoch 30/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3873 - accuracy: 0.8000
# Epoch 00030: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 898us/sample - loss: 0.4996 - accuracy: 0.7045 - val_loss: 0.5999 - val_accuracy: 0.6667
# Epoch 31/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4280 - accuracy: 0.8000
# Epoch 00031: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 881us/sample - loss: 0.3257 - accuracy: 0.8636 - val_loss: 0.6016 - val_accuracy: 0.6667
# Epoch 32/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1739 - accuracy: 0.9000
# Epoch 00032: val_accuracy improved from 0.66667 to 0.75000, saving model to models/CNN2_dataset_2_no_augment_5_32.h5
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2374 - accuracy: 0.8409 - val_loss: 0.5917 - val_accuracy: 0.7500
# Epoch 33/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4887 - accuracy: 0.8000
# Epoch 00033: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 924us/sample - loss: 0.5371 - accuracy: 0.7727 - val_loss: 0.6927 - val_accuracy: 0.5833
# Epoch 34/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.7570 - accuracy: 0.5000
# Epoch 00034: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 887us/sample - loss: 0.6383 - accuracy: 0.7045 - val_loss: 0.6067 - val_accuracy: 0.6667
# Epoch 35/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3852 - accuracy: 0.7000
# Epoch 00035: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 948us/sample - loss: 0.6925 - accuracy: 0.6818 - val_loss: 0.6091 - val_accuracy: 0.6667
# Epoch 36/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2229 - accuracy: 0.9000
# Epoch 00036: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 889us/sample - loss: 0.7936 - accuracy: 0.6818 - val_loss: 0.6640 - val_accuracy: 0.5833
# Epoch 37/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3563 - accuracy: 0.7000
# Epoch 00037: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 875us/sample - loss: 0.3506 - accuracy: 0.8182 - val_loss: 0.5796 - val_accuracy: 0.5833
# Epoch 38/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2770 - accuracy: 0.8000
# Epoch 00038: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 795us/sample - loss: 0.2927 - accuracy: 0.8636 - val_loss: 0.7043 - val_accuracy: 0.5833
# Epoch 39/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3807 - accuracy: 0.8000
# Epoch 00039: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 843us/sample - loss: 0.4310 - accuracy: 0.8182 - val_loss: 0.6173 - val_accuracy: 0.5833
# Epoch 40/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3625 - accuracy: 0.9000
# Epoch 00040: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 925us/sample - loss: 0.4722 - accuracy: 0.7955 - val_loss: 0.6311 - val_accuracy: 0.7500
# Epoch 41/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3647 - accuracy: 0.9000
# Epoch 00041: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 859us/sample - loss: 0.3378 - accuracy: 0.8636 - val_loss: 0.6562 - val_accuracy: 0.6667
# Epoch 42/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.7092 - accuracy: 0.7000
# Epoch 00042: val_accuracy improved from 0.75000 to 0.83333, saving model to models/CNN2_dataset_2_no_augment_5_42.h5
# 44/44 [==============================] - 0s 2ms/sample - loss: 0.5069 - accuracy: 0.7273 - val_loss: 0.5439 - val_accuracy: 0.8333
# Epoch 43/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1764 - accuracy: 0.9000
# Epoch 00043: val_accuracy improved from 0.83333 to 0.91667, saving model to models/CNN2_dataset_2_no_augment_5_43.h5
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4256 - accuracy: 0.7955 - val_loss: 0.5208 - val_accuracy: 0.9167
# Epoch 44/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2971 - accuracy: 0.9000
# Epoch 00044: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 885us/sample - loss: 0.3426 - accuracy: 0.8409 - val_loss: 0.5136 - val_accuracy: 0.6667
# Epoch 45/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0631 - accuracy: 1.0000
# Epoch 00045: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 881us/sample - loss: 0.2311 - accuracy: 0.9318 - val_loss: 0.5640 - val_accuracy: 0.7500
# Epoch 46/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1849 - accuracy: 0.9000
# Epoch 00046: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 854us/sample - loss: 0.3839 - accuracy: 0.8409 - val_loss: 0.5257 - val_accuracy: 0.7500
# Epoch 47/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4142 - accuracy: 0.9000
# Epoch 00047: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 811us/sample - loss: 0.4922 - accuracy: 0.8182 - val_loss: 0.5157 - val_accuracy: 0.7500
# Epoch 48/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2007 - accuracy: 0.9000
# Epoch 00048: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 880us/sample - loss: 0.2311 - accuracy: 0.9318 - val_loss: 0.6706 - val_accuracy: 0.6667
# Epoch 49/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1198 - accuracy: 0.9000
# Epoch 00049: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 920us/sample - loss: 0.3411 - accuracy: 0.8182 - val_loss: 0.5728 - val_accuracy: 0.5833
# Epoch 50/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0
val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 847us/sample - loss: 0.0498 - accuracy: 1.0000 - val_loss: 0.6924 - val_accuracy: 0.7500
# Epoch 155/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0436 - accuracy: 1.0000
# Epoch 00155: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 843us/sample - loss: 0.0815 - accuracy: 0.9545 - val_loss: 0.8743 - val_accuracy: 0.7500
# Epoch 156/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0085 - accuracy: 1.0000
# Epoch 00156: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 842us/sample - loss: 0.0544 - accuracy: 1.0000 - val_loss: 0.9694 - val_accuracy: 0.7500
# Epoch 157/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0314 - accuracy: 1.0000
# Epoch 00157: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 809us/sample - loss: 0.0995 - accuracy: 0.9773 - val_loss: 1.2001 - val_accuracy: 0.7500
# Epoch 158/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0118 - accuracy: 1.0000
# Epoch 00158: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 793us/sample - loss: 0.0832 - accuracy: 0.9545 - val_loss: 1.0603 - val_accuracy: 0.7500
# Epoch 159/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0213 - accuracy: 1.0000
# Epoch 00159: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 841us/sample - loss: 0.0509 - accuracy: 1.0000 - val_loss: 1.1593 - val_accuracy: 0.7500
# Epoch 160/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1000 - accuracy: 0.9000
# Epoch 00160: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 828us/sample - loss: 0.0897 - accuracy: 0.9318 - val_loss: 0.9725 - val_accuracy: 0.7500
# Epoch 161/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0348 - accuracy: 1.0000
# Epoch 00161: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 865us/sample - loss: 0.0335 - accuracy: 1.0000 - val_loss: 1.6900 - val_accuracy: 0.6667
# Epoch 162/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0087 - accuracy: 1.0000
# Epoch 00162: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 843us/sample - loss: 0.0615 - accuracy: 0.9773 - val_loss: 0.8541 - val_accuracy: 0.7500
# Epoch 163/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0669 - accuracy: 1.0000
# Epoch 00163: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 864us/sample - loss: 0.0943 - accuracy: 0.9773 - val_loss: 0.8919 - val_accuracy: 0.7500
# Epoch 164/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0868 - accuracy: 1.0000
# Epoch 00164: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 860us/sample - loss: 0.0567 - accuracy: 0.9773 - val_loss: 1.8298 - val_accuracy: 0.6667
# Epoch 165/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 00165: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 900us/sample - loss: 0.1690 - accuracy: 0.9318 - val_loss: 0.7375 - val_accuracy: 0.6667
# Epoch 166/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2005 - accuracy: 0.9000
# Epoch 00166: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 833us/sample - loss: 0.1472 - accuracy: 0.9091 - val_loss: 1.5183 - val_accuracy: 0.7500
# Epoch 167/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 00167: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 856us/sample - loss: 0.1744 - accuracy: 0.9318 - val_loss: 1.2136 - val_accuracy: 0.7500
# Epoch 168/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0217 - accuracy: 1.0000
# ...
# 44/44 [==============================] - 0s 772us/sample - loss: 0.0300 - accuracy: 0.9773 - val_loss: 0.8467 - val_accuracy: 0.7500
# Epoch 446/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3843 - accuracy: 0.8000
# Epoch 00446: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 813us/sample - loss: 0.0952 - accuracy: 0.9545 - val_loss: 1.5633 - val_accuracy: 0.6667
# Epoch 447/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.7370e-04 - accuracy: 1.0000
# Epoch 00447: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 807us/sample - loss: 0.1021 - accuracy: 0.9545 - val_loss: 0.8248 - val_accuracy: 0.7500
# Epoch 448/500
# 10/44 [=====>........................] - ETA: 0s - loss: 6.2557e-05 - accuracy: 1.0000
# Epoch 00448: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s
500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0190 - accuracy: 1.0000
# Epoch 00481: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 805us/sample - loss: 0.0241 - accuracy: 0.9773 - val_loss: 2.1171 - val_accuracy: 0.6667
# Epoch 482/500
# 10/44 [=====>........................] - ETA: 0s - loss: 3.6537e-04 - accuracy: 1.0000
# Epoch 00482: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 777us/sample - loss: 9.3199e-04 - accuracy: 1.0000 - val_loss: 1.2259 - val_accuracy: 0.6667
# Epoch 483/500
# 10/44 [=====>........................] - ETA: 0s - loss: 6.8141e-05 - accuracy: 1.0000
# Epoch 00483: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 838us/sample - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.9630 - val_accuracy: 0.6667
# Epoch 484/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0414 - accuracy: 1.0000
# Epoch 00484: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 782us/sample - loss: 0.0102 - accuracy: 1.0000 - val_loss: 1.2359 - val_accuracy: 0.6667
# Epoch 485/500
# 10/44 [=====>........................] - ETA: 0s - loss: 3.6547e-05 - accuracy: 1.0000
# Epoch 00485: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 825us/sample - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.5232 - val_accuracy: 0.6667
# Epoch 486/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 00486: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 759us/sample - loss: 8.5405e-04 - accuracy: 1.0000 - val_loss: 1.7166 - val_accuracy: 0.6667
# Epoch 487/500
# 10/44 [=====>........................] - ETA: 0s - loss: 2.8522e-04 - accuracy: 1.0000
# Epoch 00487: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 767us/sample - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.7971 - val_accuracy: 0.6667
# Epoch 488/500
# 10/44 [=====>........................] - ETA: 0s - loss: 4.0402e-04 - accuracy: 1.0000
# Epoch 00488: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 833us/sample - loss: 8.8413e-04 - accuracy: 1.0000 - val_loss: 1.8097 - val_accuracy: 0.6667
# Epoch 489/500
# 10/44 [=====>........................] - ETA: 0s - loss: 4.2541e-04 - accuracy: 1.0000
# Epoch 00489: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 770us/sample - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.9483 - val_accuracy: 0.6667
# Epoch 490/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.6473e-04 - accuracy: 1.0000
# Epoch 00490: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 805us/sample - loss: 7.7264e-04 - accuracy: 1.0000 - val_loss: 2.0159 - val_accuracy: 0.6667
# Epoch 491/500
# 10/44 [=====>........................] - ETA: 0s - loss: 7.7408e-04 - accuracy: 1.0000
# Epoch 00491: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 832us/sample - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.6570 - val_accuracy: 0.6667
# Epoch 492/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00492: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 806us/sample - loss: 0.0664 - accuracy: 0.9773 - val_loss: 0.4758 - val_accuracy: 0.9167
# Epoch 493/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 00493: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 864us/sample - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.6875 - val_accuracy: 0.8333
# Epoch 494/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2555 - accuracy: 0.9000
# Epoch 00494: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 773us/sample - loss: 0.1427 - accuracy: 0.9318 - val_loss: 5.1407 - val_accuracy: 0.6667
# Epoch 495/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 00495: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 815us/sample - loss: 0.8050 - accuracy: 0.9318 - val_loss: 0.4620 - val_accuracy: 0.7500
# Epoch 496/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 00496: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 799us/sample - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.5294 - val_accuracy: 0.9167
# Epoch 497/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1321 - accuracy: 0.9000
# Epoch 00497: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 789us/sample - loss: 0.7192 - accuracy: 0.9318 - val_loss: 0.8943 - val_accuracy: 0.6667
# Epoch 498/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0390 - accuracy: 1.0000
# Epoch 00498: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 772us/sample - loss: 0.6899 - accuracy: 0.8636 - val_loss: 0.9047 - val_accuracy: 0.6667
# Epoch 499/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0952 - accuracy: 0.9000
# Epoch 00499: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 769us/sample - loss: 0.3039 - accuracy: 0.8636 - val_loss: 1.6631 - val_accuracy: 0.5833
# Epoch 500/500
# 10/44 [=====>........................] - ETA: 0s - loss: 8.4515e-04 - accuracy: 1.0000
# Epoch 00500: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 808us/sample - loss: 0.0750 - accuracy: 0.9773 - val_loss: 2.6503 - val_accuracy: 0.6667
# Training completed in time:  0:00:19.791757

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.9318182
# Testing Accuracy:  0.1875

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.19      1.00      0.32         3
#    Pneumonia       0.00      0.00      0.00        13
#
#     accuracy                           0.19        16
#    macro avg       0.09      0.50      0.16        16
# weighted avg       0.04      0.19      0.06        16
# /home/lucas/.local/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[ 3  0]
#  [13  0]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])
