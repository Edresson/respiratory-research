# %% [markdown]
# # Rede CNN - Modelo 2
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - Dataset 2 - no_augment_10

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP_TRAIN = 'no_augment_10'
GROUP_TEST = 'no_augment_10'
DATASET = 'dataset_2'
DURATION = 10
SIZE = 431
CSV_TRAIN = 'train2.csv'
CSV_TEST = 'test2.csv'
MODEL_NAME = f'CNN2_{DATASET}_{GROUP_TRAIN}'

# %%
train_file_paths = glob.glob(f'../datasets/{DATASET}/{GROUP_TRAIN}/train/**/*.wav', recursive=True)
train_file_names = [os.path.splitext(os.path.basename(p))[0] for p in train_file_paths]

test_file_paths = glob.glob(f'../datasets/{DATASET}/{GROUP_TEST}/test/**/*.wav', recursive=True)
test_file_names = [os.path.splitext(os.path.basename(p))[0] for p in test_file_paths]

# %%
train_p_id_in_file = [] # patient IDs corresponding to each file
test_p_id_in_file = [] # patient IDs corresponding to each file
for name in train_file_names:
    train_p_id_in_file.append(int(name[:3]))

for name in test_file_names:
    test_p_id_in_file.append(int(name[:3]))

train_p_id_in_file = np.array(train_p_id_in_file)
test_p_id_in_file = np.array(test_p_id_in_file)

# %%
max_pad_len = SIZE

os.makedirs("features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=DURATION) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
train_p_diag = pd.read_csv(f"../Respiratory_Sound_Database/Respiratory_Sound_Database_Pneumo_Healthy_Only/{CSV_TRAIN}", header=None) # patient diagnosis file
test_p_diag = pd.read_csv(f"../Respiratory_Sound_Database/Respiratory_Sound_Database_Pneumo_Healthy_Only/{CSV_TEST}", header=None) # patient diagnosis file
train_p_diag.head(5)
# Out:
#      0        1
# 0  123  Healthy
# 1  125  Healthy
# 2  126  Healthy
# 3  127  Healthy
# 4  136  Healthy

# %%
train_labels = np.array([train_p_diag[train_p_diag[0] == x][1].values[0] for x in train_p_id_in_file]) 
test_labels = np.array([test_p_diag[test_p_diag[0] == x][1].values[0] for x in test_p_id_in_file])

# %%
train_features = [] 
test_features = []

for file_name in train_file_paths:
    data = extract_features(file_name)
    train_features.append(data)

for file_name in test_file_paths:
    data = extract_features(file_name)
    test_features.append(data)

print('Finished feature extraction from ', (len(train_features)+len(train_features)), ' files')
train_features = np.array(train_features)
test_features = np.array(test_features)
# Out:
# Finished feature extraction from  112  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(train_features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
np.unique(train_labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
unique_elements, counts_elements = np.unique(train_labels, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))

unique_elements_test, counts_elements_test = np.unique(test_labels, return_counts=True)
print(np.asarray((unique_elements_test, counts_elements_test)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['32' '24']]
# [['Healthy' 'Pneumonia']
#  ['3' '13']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
le.fit(train_labels)
train_labels_cat = to_categorical(le.transform(train_labels)) 
test_labels_cat = to_categorical(le.transform(test_labels))

# %%
train_features.shape
# Out:
# (56, 40, 431)

# %%
input_dim = train_features.shape[1]*train_features.shape[2]

# %%
train_features = np.reshape(train_features, (*train_features.shape,1)) 
print(train_features.shape, train_labels_cat.shape)
test_features = np.reshape(test_features, (*test_features.shape,1)) 
print(test_features.shape, test_labels_cat.shape)
# Out:
# (56, 40, 431, 1) (56, 2)
# (16, 40, 431, 1) (16, 2)

# %%
# train test split
x_train, x_val, y_train, y_val = train_test_split(train_features, train_labels_cat, test_size=0.2, random_state = 42)
x_test, y_test = test_features, test_labels_cat

# %% [markdown]
# **CNN model architecture**

# %%
num_labels = train_labels_cat.shape[1]

num_rows = 40
num_columns = SIZE
num_channels = 1

filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(Conv2D(filters=16, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(Conv2D(filters=8, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(Conv2D(filters=4, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 430, 32)       160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 215, 32)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 215, 32)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 214, 16)       2064
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 107, 16)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 107, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 106, 8)         520
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 53, 8)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 53, 8)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 52, 4)          132
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 26, 4)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 26, 4)          0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 4)                 0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 10
# =================================================================
# Total params: 2,886
# Trainable params: 2,886
# Non-trainable params: 0
# _________________________________________________________________
# 16/16 [==============================] - 1s 54ms/sample - loss: 3.4944 - accuracy: 0.1875
# Pre-training accuracy: 18.7500%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 500
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/' + MODEL_NAME + '_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_val, y_val), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 44 samples, validate on 12 samples
# Epoch 1/500
# 10/44 [=====>........................] - ETA: 1s - loss: 32.6456 - accuracy: 0.6000
# Epoch 00001: val_accuracy improved from -inf to 0.58333, saving model to models/CNN2_dataset_2_no_augment_10_01.h5
# 44/44 [==============================] - 1s 18ms/sample - loss: 25.3494 - accuracy: 0.5682 - val_loss: 0.9503 - val_accuracy: 0.5833
# Epoch 2/500
# 10/44 [=====>........................] - ETA: 0s - loss: 12.6628 - accuracy: 0.6000
# Epoch 00002: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 11.6218 - accuracy: 0.5682 - val_loss: 0.7582 - val_accuracy: 0.5833
# Epoch 3/500
# 10/44 [=====>........................] - ETA: 0s - loss: 8.0633 - accuracy: 0.4000
# Epoch 00003: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 6.1044 - accuracy: 0.5682 - val_loss: 0.7025 - val_accuracy: 0.5833
# Epoch 4/500
# 10/44 [=====>........................] - ETA: 0s - loss: 2.5867 - accuracy: 0.7000
# Epoch 00004: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 2.9687 - accuracy: 0.5909 - val_loss: 0.6768 - val_accuracy: 0.5833
# Epoch 5/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.9831 - accuracy: 0.7000
# Epoch 00005: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 1.3614 - accuracy: 0.5000 - val_loss: 0.6976 - val_accuracy: 0.5000
# Epoch 6/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.1824 - accuracy: 0.6000
# Epoch 00006: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 1.1269 - accuracy: 0.5455 - val_loss: 0.7133 - val_accuracy: 0.5000
# Epoch 7/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.8149 - accuracy: 0.4000
# Epoch 00007: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 1.3115 - accuracy: 0.4545 - val_loss: 0.7054 - val_accuracy: 0.4167
# Epoch 8/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.2807 - accuracy: 0.1000
# Epoch 00008: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 1.1728 - accuracy: 0.3864 - val_loss: 0.6973 - val_accuracy: 0.4167
# Epoch 9/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5542 - accuracy: 0.7000
# Epoch 00009: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.8070 - accuracy: 0.5227 - val_loss: 0.6926 - val_accuracy: 0.5833
# Epoch 10/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.8044 - accuracy: 0.5000
# Epoch 00010: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.8775 - accuracy: 0.5000 - val_loss: 0.6924 - val_accuracy: 0.5000
# Epoch 11/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.7747 - accuracy: 0.5000
# Epoch 00011: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.7606 - accuracy: 0.5227 - val_loss: 0.6941 - val_accuracy: 0.5000
# Epoch 12/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4023 - accuracy: 0.9000
# Epoch 00012: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.8858 - accuracy: 0.6818 - val_loss: 0.6953 - val_accuracy: 0.4167
# Epoch 13/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.0571 - accuracy: 0.5000
# Epoch 00013: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 1.1092 - accuracy: 0.5455 - val_loss: 0.6956 - val_accuracy: 0.4167
# Epoch 14/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.0520 - accuracy: 0.4000
# Epoch 00014: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.9144 - accuracy: 0.5000 - val_loss: 0.6959 - val_accuracy: 0.4167
# Epoch 15/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.0199 - accuracy: 0.6000
# Epoch 00015: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.8135 - accuracy: 0.5682 - val_loss: 0.6966 - val_accuracy: 0.4167
# Epoch 16/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.7681 - accuracy: 0.6000
# Epoch 00016: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.9930 - accuracy: 0.5227 - val_loss: 0.6974 - val_accuracy: 0.4167
# Epoch 17/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3976 - accuracy: 0.8000
# Epoch 00017: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.7528 - accuracy: 0.5909 - val_loss: 0.6980 - val_accuracy: 0.4167
# Epoch 18/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.7606 - accuracy: 0.4000
# Epoch 00018: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.7180 - accuracy: 0.4318 - val_loss: 0.6984 - val_accuracy: 0.4167
# Epoch 19/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.7532 - accuracy: 0.7000
# Epoch 00019: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.7968 - accuracy: 0.5909 - val_loss: 0.6984 - val_accuracy: 0.4167
# Epoch 20/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.8088 - accuracy: 0.4000
# Epoch 00020: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.7741 - accuracy: 0.5000 - val_loss: 0.6983 - val_accuracy: 0.4167
# Epoch 21/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4966 - accuracy: 0.8000
# Epoch 00021: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6548 - accuracy: 0.6364 - val_loss: 0.6980 - val_accuracy: 0.4167
# Epoch 22/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.7244 - accuracy: 0.7000
# Epoch 00022: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.9012 - accuracy: 0.5455 - val_loss: 0.6984 - val_accuracy: 0.4167
# Epoch 23/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.7291 - accuracy: 0.6000
# Epoch 00023: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6741 - accuracy: 0.6364 - val_loss: 0.6987 - val_accuracy: 0.4167
# Epoch 24/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5026 - accuracy: 0.8000
# Epoch 00024: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6551 - accuracy: 0.6136 - val_loss: 0.6990 - val_accuracy: 0.4167
# Epoch 25/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.0735 - accuracy: 0.3000
# Epoch 00025: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.8488 - accuracy: 0.5455 - val_loss: 0.6987 - val_accuracy: 0.4167
# Epoch 26/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5465 - accuracy: 0.8000
# Epoch 00026: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6801 - accuracy: 0.7045 - val_loss: 0.6987 - val_accuracy: 0.4167
# Epoch 27/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.1673 - accuracy: 0.4000
# Epoch 00027: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.9618 - accuracy: 0.4545 - val_loss: 0.6985 - val_accuracy: 0.4167
# Epoch 28/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3047 - accuracy: 1.0000
# Epoch 00028: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6772 - accuracy: 0.6136 - val_loss: 0.6984 - val_accuracy: 0.4167
# Epoch 29/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4365 - accuracy: 0.7000
# Epoch 00029: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.7487 - accuracy: 0.5682 - val_loss: 0.6984 - val_accuracy: 0.4167
# Epoch 30/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.0517 - accuracy: 0.3000
# Epoch 00030: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.7875 - accuracy: 0.5682 - val_loss: 0.6984 - val_accuracy: 0.4167
# Epoch 31/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4762 - accuracy: 0.7000
# Epoch 00031: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6553 - accuracy: 0.6136 - val_loss: 0.6982 - val_accuracy: 0.4167
# Epoch 32/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.3220 - accuracy: 0.3000
# Epoch 00032: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.9148 - accuracy: 0.5455 - val_loss: 0.6984 - val_accuracy: 0.4167
# Epoch 33/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3237 - accuracy: 0.9000
# Epoch 00033: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5451 - accuracy: 0.6818 - val_loss: 0.6985 - val_accuracy: 0.4167
# Epoch 34/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5048 - accuracy: 0.8000
# Epoch 00034: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6700 - accuracy: 0.6591 - val_loss: 0.6989 - val_accuracy: 0.4167
# Epoch 35/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.8405 - accuracy: 0.5000
# Epoch 00035: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6475 - accuracy: 0.6591 - val_loss: 0.6993 - val_accuracy: 0.4167
# Epoch 36/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.7399 - accuracy: 0.5000
# Epoch 00036: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.7510 - accuracy: 0.6364 - val_loss: 0.6996 - val_accuracy: 0.4167
# Epoch 37/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5376 - accuracy: 0.7000
# Epoch 00037: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.7755 - accuracy: 0.5909 - val_loss: 0.6995 - val_accuracy: 0.4167
# Epoch 38/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6414 - accuracy: 0.7000
# Epoch 00038: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6535 - accuracy: 0.6364 - val_loss: 0.6989 - val_accuracy: 0.4167
# Epoch 39/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.9992 - accuracy: 0.2000
# Epoch 00039: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6406 - accuracy: 0.5455 - val_loss: 0.6984 - val_accuracy: 0.4167
# Epoch 40/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6421 - accuracy: 0.5000
# Epoch 00040: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.7358 - accuracy: 0.5455 - val_loss: 0.6980 - val_accuracy: 0.4167
# Epoch 41/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.7705 - accuracy: 0.7000
# Epoch 00041: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.7958 - accuracy: 0.6364 - val_loss: 0.6977 - val_accuracy: 0.4167
# Epoch 42/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5510 - accuracy: 0.6000
# Epoch 00042: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.7950 - accuracy: 0.5455 - val_loss: 0.6976 - val_accuracy: 0.4167
# Epoch 43/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.8194 - accuracy: 0.5000
# Epoch 00043: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6493 - accuracy: 0.6591 - val_loss: 0.6977 - val_accuracy: 0.4167
# Epoch 44/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5062 - accuracy: 0.9000
# Epoch 00044: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6686 - accuracy: 0.6818 - val_loss: 0.6979 - val_accuracy: 0.4167
# Epoch 45/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.9889 - accuracy: 0.4000
# Epoch 00045: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.7696 - accuracy: 0.5000 - val_loss: 0.6983 - val_accuracy: 0.4167
# Epoch 46/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.8436 - accuracy: 0.4000
# Epoch 00046: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6647 - accuracy: 0.6136 - val_loss: 0.6983 - val_accuracy: 0.4167
# Epoch 47/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6131 - accuracy: 0.7000
# Epoch 00047: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.7084 - accuracy: 0.5455 - val_loss: 0.6987 - val_accuracy: 0.4167
# Epoch 48/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4663 - accuracy: 0.8000
# Epoch 00048: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6014 - accuracy: 0.6818 - val_loss: 0.6987 - val_accuracy: 0.4167
# Epoch 49/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.8403 - accuracy: 0.6000
# Epoch 00049: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6493 - accuracy: 0.7045 - val_loss: 0.6983 - val_accuracy: 0.4167
# Epoch 50/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5756 - accuracy: 0.7000
# Epoch 00050: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6891 - accuracy: 0.6136 - val_loss: 0.6982 - val_accuracy: 0.4167
# Epoch 51/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5173 - accuracy: 0.8000
# Epoch 00051: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6156 - accuracy: 0.6818 - val_loss: 0.6983 - val_accuracy: 0.4167
# Epoch 52/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5886 - accuracy: 0.7000
# Epoch 00052: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6258 - accuracy: 0.6818 - val_loss: 0.6983 - val_accuracy: 0.4167
# Epoch 53/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.7159 - accuracy: 0.3000
# Epoch 00053: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6597 - accuracy: 0.5455 - val_loss: 0.6983 - val_accuracy: 0.4167
# Epoch 54/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6503 - accuracy: 0.5000
# Epoch 00054: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6246 - accuracy: 0.6591 - val_loss: 0.6984 - val_accuracy: 0.4167
# Epoch 55/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4278 - accuracy: 0.8000
# Epoch 00055: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5806 - accuracy: 0.6818 - val_loss: 0.6985 - val_accuracy: 0.4167
# Epoch 56/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4946 - accuracy: 0.8000
# Epoch 00056: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.7205 - accuracy: 0.5682 - val_loss: 0.6986 - val_accuracy: 0.4167
# Epoch 57/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3471 - accuracy: 0.9000
# Epoch 00057: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5225 - accuracy: 0.6818 - val_loss: 0.6987 - val_accuracy: 0.4167
# Epoch 58/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.8257 - accuracy: 0.4000
# Epoch 00058: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6182 - accuracy: 0.6136 - val_loss: 0.6987 - val_accuracy: 0.4167
# Epoch 59/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.7683 - accuracy: 0.8000
# Epoch 00059: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6150 - accuracy: 0.7727 - val_loss: 0.6987 - val_accuracy: 0.4167
# Epoch 60/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5062 - accuracy: 0.7000
# Epoch 00060: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5603 - accuracy: 0.7045 - val_loss: 0.6987 - val_accuracy: 0.4167
# Epoch 61/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4882 - accuracy: 0.8000
# Epoch 00061: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5577 - accuracy: 0.7273 - val_loss: 0.6986 - val_accuracy: 0.4167
# Epoch 62/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5854 - accuracy: 0.7000
# Epoch 00062: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5721 - accuracy: 0.7273 - val_loss: 0.6985 - val_accuracy: 0.4167
# Epoch 63/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6780 - accuracy: 0.6000
# Epoch 00063: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6002 - accuracy: 0.6364 - val_loss: 0.6986 - val_accuracy: 0.4167
# Epoch 64/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4067 - accuracy: 0.8000
# Epoch 00064: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6168 - accuracy: 0.6136 - val_loss: 0.6986 - val_accuracy: 0.4167
# Epoch 65/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4230 - accuracy: 0.9000
# Epoch 00065: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5578 - accuracy: 0.7045 - val_loss: 0.6988 - val_accuracy: 0.4167
# Epoch 66/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4789 - accuracy: 0.7000
# Epoch 00066: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5961 - accuracy: 0.6818 - val_loss: 0.6990 - val_accuracy: 0.4167
# Epoch 67/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4864 - accuracy: 0.8000
# Epoch 00067: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6171 - accuracy: 0.6364 - val_loss: 0.6992 - val_accuracy: 0.4167
# Epoch 68/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6060 - accuracy: 0.5000
# Epoch 00068: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6670 - accuracy: 0.5909 - val_loss: 0.6995 - val_accuracy: 0.4167
# Epoch 69/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4784 - accuracy: 0.8000
# Epoch 00069: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6494 - accuracy: 0.6136 - val_loss: 0.6995 - val_accuracy: 0.4167
# Epoch 70/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5424 - accuracy: 0.6000
# Epoch 00070: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5955 - accuracy: 0.6364 - val_loss: 0.6997 - val_accuracy: 0.4167
# Epoch 71/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4467 - accuracy: 0.7000
# Epoch 00071: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5767 - accuracy: 0.6591 - val_loss: 0.6995 - val_accuracy: 0.4167
# Epoch 72/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.8585 - accuracy: 0.4000
# Epoch 00072: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6167 - accuracy: 0.7273 - val_loss: 0.6993 - val_accuracy: 0.4167
# Epoch 73/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.7636 - accuracy: 0.5000
# Epoch 00073: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6597 - accuracy: 0.6591 - val_loss: 0.6991 - val_accuracy: 0.4167
# Epoch 74/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5560 - accuracy: 0.6000
# Epoch 00074: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5346 - accuracy: 0.7045 - val_loss: 0.6990 - val_accuracy: 0.4167
# Epoch 75/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6027 - accuracy: 0.5000
# Epoch 00075: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6214 - accuracy: 0.5682 - val_loss: 0.6989 - val_accuracy: 0.4167
# Epoch 76/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5505 - accuracy: 0.6000
# Epoch 00076: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5784 - accuracy: 0.6591 - val_loss: 0.6989 - val_accuracy: 0.4167
# Epoch 77/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5108 - accuracy: 0.8000
# Epoch 00077: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5859 - accuracy: 0.7045 - val_loss: 0.6990 - val_accuracy: 0.4167
# Epoch 78/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.7767 - accuracy: 0.7000
# Epoch 00078: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5353 - accuracy: 0.7727 - val_loss: 0.6991 - val_accuracy: 0.4167
# Epoch 79/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6674 - accuracy: 0.8000
# Epoch 00079: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5449 - accuracy: 0.8182 - val_loss: 0.6991 - val_accuracy: 0.4167
# Epoch 80/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6109 - accuracy: 0.7000
# Epoch 00080: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5553 - accuracy: 0.6818 - val_loss: 0.6994 - val_accuracy: 0.4167
# Epoch 81/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6668 - accuracy: 0.7000
# Epoch 00081: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5753 - accuracy: 0.7273 - val_loss: 0.6997 - val_accuracy: 0.4167
# Epoch 82/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5917 - accuracy: 0.6000
# Epoch 00082: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5042 - accuracy: 0.7273 - val_loss: 0.7000 - val_accuracy: 0.4167
# Epoch 83/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5092 - accuracy: 0.7000
# Epoch 00083: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6304 - accuracy: 0.6818 - val_loss: 0.6999 - val_accuracy: 0.4167
# Epoch 84/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5060 - accuracy: 0.6000
# Epoch 00084: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5261 - accuracy: 0.7045 - val_loss: 0.6997 - val_accuracy: 0.4167
# Epoch 85/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6853 - accuracy: 0.5000
# Epoch 00085: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5466 - accuracy: 0.7045 - val_loss: 0.6993 - val_accuracy: 0.4167
# Epoch 86/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.7145 - accuracy: 0.6000
# Epoch 00086: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5672 - accuracy: 0.6818 - val_loss: 0.6993 - val_accuracy: 0.4167
# Epoch 87/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.8411 - accuracy: 0.6000
# Epoch 00087: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6375 - accuracy: 0.6591 - val_loss: 0.6995 - val_accuracy: 0.4167
# Epoch 88/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4348 - accuracy: 0.9000
# Epoch 00088: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5059 - accuracy: 0.7727 - val_loss: 0.6999 - val_accuracy: 0.4167
# Epoch 89/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.8232 - accuracy: 0.5000
# Epoch 00089: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5702 - accuracy: 0.6818 - val_loss: 0.7000 - val_accuracy: 0.4167
# Epoch 90/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5422 - accuracy: 0.7000
# Epoch 00090: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5470 - accuracy: 0.7500 - val_loss: 0.7001 - val_accuracy: 0.4167
# Epoch 91/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.7407 - accuracy: 0.5000
# Epoch 00091: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5240 - accuracy: 0.7500 - val_loss: 0.7002 - val_accuracy: 0.4167
# Epoch 92/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4582 - accuracy: 0.7000
# Epoch 00092: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4942 - accuracy: 0.7273 - val_loss: 0.7004 - val_accuracy: 0.4167
# Epoch 93/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4010 - accuracy: 0.8000
# Epoch 00093: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5693 - accuracy: 0.6818 - val_loss: 0.7005 - val_accuracy: 0.4167
# Epoch 94/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3655 - accuracy: 0.9000
# Epoch 00094: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5406 - accuracy: 0.6818 - val_loss: 0.7010 - val_accuracy: 0.4167
# Epoch 95/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3709 - accuracy: 0.9000
# Epoch 00095: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5069 - accuracy: 0.7727 - val_loss: 0.7012 - val_accuracy: 0.4167
# Epoch 96/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4084 - accuracy: 0.8000
# Epoch 00096: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4377 - accuracy: 0.7955 - val_loss: 0.7012 - val_accuracy: 0.4167
# Epoch 97/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3084 - accuracy: 1.0000
# Epoch 00097: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4642 - accuracy: 0.7955 - val_loss: 0.7015 - val_accuracy: 0.4167
# Epoch 98/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3765 - accuracy: 0.8000
# Epoch 00098: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4286 - accuracy: 0.7955 - val_loss: 0.7011 - val_accuracy: 0.4167
# Epoch 99/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3834 - accuracy: 0.9000
# Epoch 00099: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5049 - accuracy: 0.7727 - val_loss: 0.7012 - val_accuracy: 0.4167
# Epoch 100/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5129 - accuracy: 0.7000
# Epoch 00100: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4398 - accuracy: 0.7727 - val_loss: 0.7010 - val_accuracy: 0.4167
# Epoch 101/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.7207 - accuracy: 0.6000
# Epoch 00101: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5982 - accuracy: 0.7045 - val_loss: 0.7004 - val_accuracy: 0.4167
# Epoch 102/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.8438 - accuracy: 0.4000
# Epoch 00102: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6129 - accuracy: 0.6818 - val_loss: 0.7003 - val_accuracy: 0.4167
# Epoch 103/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5814 - accuracy: 0.6000
# Epoch 00103: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4783 - accuracy: 0.6818 - val_loss: 0.7002 - val_accuracy: 0.4167
# Epoch 104/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6771 - accuracy: 0.5000
# Epoch 00104: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5530 - accuracy: 0.6136 - val_loss: 0.7002 - val_accuracy: 0.4167
# Epoch 105/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.7115 - accuracy: 0.5000
# Epoch 00105: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6150 - accuracy: 0.6136 - val_loss: 0.6999 - val_accuracy: 0.4167
# Epoch 106/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4359 - accuracy: 0.9000
# Epoch 00106: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5270 - accuracy: 0.7045 - val_loss: 0.6997 - val_accuracy: 0.4167
# Epoch 107/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5138 - accuracy: 0.8000
# Epoch 00107: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4589 - accuracy: 0.8182 - val_loss: 0.7000 - val_accuracy: 0.4167
# Epoch 108/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4954 - accuracy: 0.7000
# Epoch 00108: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4856 - accuracy: 0.7955 - val_loss: 0.7007 - val_accuracy: 0.4167
# Epoch 109/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4205 - accuracy: 0.8000
# Epoch 00109: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4539 - accuracy: 0.7727 - val_loss: 0.7012 - val_accuracy: 0.4167
# Epoch 110/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5728 - accuracy: 0.8000
# Epoch 00110: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5251 - accuracy: 0.7727 - val_loss: 0.7010 - val_accuracy: 0.3333
# Epoch 111/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4731 - accuracy: 0.9000
# Epoch 00111: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4808 - accuracy: 0.8182 - val_loss: 0.7002 - val_accuracy: 0.4167
# Epoch 112/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5183 - accuracy: 0.7000
# Epoch 00112: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4600 - accuracy: 0.7500 - val_loss: 0.7002 - val_accuracy: 0.3333
# Epoch 113/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5289 - accuracy: 0.7000
# Epoch 00113: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4530 - accuracy: 0.7955 - val_loss: 0.7006 - val_accuracy: 0.3333
# Epoch 114/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5603 - accuracy: 0.7000
# Epoch 00114: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4995 - accuracy: 0.7500 - val_loss: 0.7030 - val_accuracy: 0.3333
# Epoch 115/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.7122 - accuracy: 0.5000
# Epoch 00115: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5753 - accuracy: 0.6591 - val_loss: 0.7061 - val_accuracy: 0.2500
# Epoch 116/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3492 - accuracy: 0.9000
# Epoch 00116: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4720 - accuracy: 0.8182 - val_loss: 0.7067 - val_accuracy: 0.1667
# Epoch 117/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4603 - accuracy: 0.7000
# Epoch 00117: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4982 - accuracy: 0.7045 - val_loss: 0.7070 - val_accuracy: 0.1667
# Epoch 118/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6386 - accuracy: 0.6000
# Epoch 00118: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4519 - accuracy: 0.7955 - val_loss: 0.7077 - val_accuracy: 0.1667
# Epoch 119/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6184 - accuracy: 0.6000
# Epoch 00119: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5334 - accuracy: 0.6591 - val_loss: 0.7065 - val_accuracy: 0.1667
# Epoch 120/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3653 - accuracy: 0.9000
# Epoch 00120: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4273 - accuracy: 0.8409 - val_loss: 0.7055 - val_accuracy: 0.1667
# Epoch 121/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5436 - accuracy: 0.9000
# Epoch 00121: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4954 - accuracy: 0.7727 - val_loss: 0.7055 - val_accuracy: 0.1667
# Epoch 122/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.8003 - accuracy: 0.6000
# Epoch 00122: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5919 - accuracy: 0.6818 - val_loss: 0.7051 - val_accuracy: 0.1667
# Epoch 123/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4783 - accuracy: 0.8000
# Epoch 00123: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4797 - accuracy: 0.7955 - val_loss: 0.7054 - val_accuracy: 0.1667
# Epoch 124/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5286 - accuracy: 0.7000
# Epoch 00124: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4106 - accuracy: 0.8182 - val_loss: 0.7055 - val_accuracy: 0.2500
# Epoch 125/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4785 - accuracy: 0.8000
# Epoch 00125: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4843 - accuracy: 0.7500 - val_loss: 0.7076 - val_accuracy: 0.2500
# Epoch 126/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3175 - accuracy: 0.9000
# Epoch 00126: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5068 - accuracy: 0.7273 - val_loss: 0.7076 - val_accuracy: 0.2500
# Epoch 127/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2331 - accuracy: 1.0000
# Epoch 00127: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4500 - accuracy: 0.7955 - val_loss: 0.7031 - val_accuracy: 0.3333
# Epoch 128/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2094 - accuracy: 1.0000
# Epoch 00128: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4186 - accuracy: 0.7955 - val_loss: 0.6982 - val_accuracy: 0.2500
# Epoch 129/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3646 - accuracy: 0.8000
# Epoch 00129: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4888 - accuracy: 0.6591 - val_loss: 0.6969 - val_accuracy: 0.3333
# Epoch 130/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2669 - accuracy: 0.8000
# Epoch 00130: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5434 - accuracy: 0.6136 - val_loss: 0.6976 - val_accuracy: 0.3333
# Epoch 131/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3682 - accuracy: 0.8000
# Epoch 00131: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4046 - accuracy: 0.8636 - val_loss: 0.6969 - val_accuracy: 0.3333
# Epoch 132/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5862 - accuracy: 0.7000
# Epoch 00132: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3962 - accuracy: 0.8409 - val_loss: 0.6977 - val_accuracy: 0.3333
# Epoch 133/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2871 - accuracy: 1.0000
# Epoch 00133: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4654 - accuracy: 0.7955 - val_loss: 0.6958 - val_accuracy: 0.3333
# Epoch 134/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3958 - accuracy: 0.8000
# Epoch 00134: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4060 - accuracy: 0.8182 - val_loss: 0.6930 - val_accuracy: 0.3333
# Epoch 135/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3008 - accuracy: 0.9000
# Epoch 00135: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3385 - accuracy: 0.9091 - val_loss: 0.6929 - val_accuracy: 0.3333
# Epoch 136/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3732 - accuracy: 0.9000
# Epoch 00136: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4288 - accuracy: 0.7955 - val_loss: 0.6923 - val_accuracy: 0.3333
# Epoch 137/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2965 - accuracy: 1.0000
# Epoch 00137: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3989 - accuracy: 0.8409 - val_loss: 0.6945 - val_accuracy: 0.3333
# Epoch 138/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4889 - accuracy: 0.6000
# Epoch 00138: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4046 - accuracy: 0.7727 - val_loss: 0.6965 - val_accuracy: 0.4167
# Epoch 139/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5820 - accuracy: 0.6000
# Epoch 00139: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4170 - accuracy: 0.7955 - val_loss: 0.6956 - val_accuracy: 0.3333
# Epoch 140/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4531 - accuracy: 0.8000
# Epoch 00140: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5025 - accuracy: 0.7500 - val_loss: 0.6949 - val_accuracy: 0.3333
# Epoch 141/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2701 - accuracy: 0.9000
# Epoch 00141: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3537 - accuracy: 0.8409 - val_loss: 0.6912 - val_accuracy: 0.4167
# Epoch 142/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2304 - accuracy: 1.0000
# Epoch 00142: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4143 - accuracy: 0.7955 - val_loss: 0.6900 - val_accuracy: 0.4167
# Epoch 143/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4691 - accuracy: 0.7000
# Epoch 00143: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4679 - accuracy: 0.7045 - val_loss: 0.6930 - val_accuracy: 0.3333
# Epoch 144/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4273 - accuracy: 0.8000
# Epoch 00144: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4931 - accuracy: 0.8182 - val_loss: 0.6939 - val_accuracy: 0.3333
# Epoch 145/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6276 - accuracy: 0.7000
# Epoch 00145: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4338 - accuracy: 0.7727 - val_loss: 0.6882 - val_accuracy: 0.3333
# Epoch 146/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3864 - accuracy: 0.8000
# Epoch 00146: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4017 - accuracy: 0.7727 - val_loss: 0.6883 - val_accuracy: 0.3333
# Epoch 147/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4942 - accuracy: 0.7000
# Epoch 00147: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3610 - accuracy: 0.7500 - val_loss: 0.6910 - val_accuracy: 0.3333
# Epoch 148/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4317 - accuracy: 0.9000
# Epoch 00148: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4400 - accuracy: 0.7955 - val_loss: 0.6924 - val_accuracy: 0.3333
# Epoch 149/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6131 - accuracy: 0.7000
# Epoch 00149: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3860 - accuracy: 0.8182 - val_loss: 0.6914 - val_accuracy: 0.3333
# Epoch 150/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2971 - accuracy: 0.9000
# Epoch 00150: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3440 - accuracy: 0.8182 - val_loss: 0.6881 - val_accuracy: 0.3333
# Epoch 151/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2733 - accuracy: 0.9000
# Epoch 00151: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3769 - accuracy: 0.8182 - val_loss: 0.6847 - val_accuracy: 0.4167
# Epoch 152/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5283 - accuracy: 0.8000
# Epoch 00152: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4446 - accuracy: 0.7500 - val_loss: 0.6827 - val_accuracy: 0.4167
# Epoch 153/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5115 - accuracy: 0.8000
# Epoch 00153: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3841 - accuracy: 0.8182 - val_loss: 0.6780 - val_accuracy: 0.5000
# Epoch 154/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2922 - accuracy: 0.9000
# Epoch 00154: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3551 - accuracy: 0.8182 - val_loss: 0.6752 - val_accuracy: 0.5000
# Epoch 155/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2746 - accuracy: 0.8000
# Epoch 00155: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3914 - accuracy: 0.7955 - val_loss: 0.6816 - val_accuracy: 0.4167
# Epoch 156/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6207 - accuracy: 0.7000
# Epoch 00156: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3463 - accuracy: 0.8182 - val_loss: 0.6833 - val_accuracy: 0.4167
# Epoch 157/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1964 - accuracy: 0.9000
# Epoch 00157: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3318 - accuracy: 0.8636 - val_loss: 0.6825 - val_accuracy: 0.4167
# Epoch 158/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4992 - accuracy: 0.7000
# Epoch 00158: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3104 - accuracy: 0.8636 - val_loss: 0.6804 - val_accuracy: 0.4167
# Epoch 159/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5397 - accuracy: 0.6000
# Epoch 00159: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3846 - accuracy: 0.7955 - val_loss: 0.6733 - val_accuracy: 0.4167
# Epoch 160/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4009 - accuracy: 0.8000
# Epoch 00160: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3995 - accuracy: 0.7955 - val_loss: 0.6724 - val_accuracy: 0.4167
# Epoch 161/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2976 - accuracy: 1.0000
# Epoch 00161: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3962 - accuracy: 0.8409 - val_loss: 0.6783 - val_accuracy: 0.4167
# Epoch 162/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5717 - accuracy: 0.6000
# Epoch 00162: val_accuracy improved from 0.58333 to 0.66667, saving model to models/CNN2_dataset_2_no_augment_10_162.h5
# 44/44 [==============================] - 0s 2ms/sample - loss: 0.4122 - accuracy: 0.8182 - val_loss: 0.6800 - val_accuracy: 0.6667
# Epoch 163/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2578 - accuracy: 1.0000
# Epoch 00163: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3243 - accuracy: 0.8409 - val_loss: 0.6858 - val_accuracy: 0.6667
# Epoch 164/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3763 - accuracy: 0.9000
# Epoch 00164: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3793 - accuracy: 0.8409 - val_loss: 0.6785 - val_accuracy: 0.6667
# Epoch 165/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3902 - accuracy: 0.9000
# Epoch 00165: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3031 - accuracy: 0.9091 - val_loss: 0.6686 - val_accuracy: 0.4167
# Epoch 166/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1581 - accuracy: 1.0000
# Epoch 00166: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3476 - accuracy: 0.8182 - val_loss: 0.6688 - val_accuracy: 0.4167
# Epoch 167/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1840 - accuracy: 1.0000
# Epoch 00167: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4223 - accuracy: 0.8409 - val_loss: 0.6742 - val_accuracy: 0.4167
# Epoch 168/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4537 - accuracy: 0.8000
# Epoch 00168: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4560 - accuracy: 0.7500 - val_loss: 0.6749 - val_accuracy: 0.4167
# Epoch 169/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3444 - accuracy: 0.8000
# Epoch 00169: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3503 - accuracy: 0.7955 - val_loss: 0.6749 - val_accuracy: 0.4167
# Epoch 170/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5190 - accuracy: 0.6000
# ...
# Epoch 445/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4970 - accuracy: 0.8000
# Epoch 00445: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1888 - accuracy: 0.9318 - val_loss: 0.5307 - val_accuracy: 0.6667
# Epoch 446/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1524 - accuracy: 0.9000
# Epoch 00446: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1890 - accuracy: 0.8864 - val_loss: 0.5329 - val_accuracy: 0.6667
# Epoch 447/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3008 - accuracy: 0.8000
# Epoch 00447: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1638 - accuracy: 0.9091 - val_loss: 0.5309 - val_accuracy: 0.6667
# Epoch 448/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1667 - accuracy: 0.9000
# Epoch 00448: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2284 - accuracy: 0.8864 - val_loss: 0.5379 - val_accuracy: 0.6667
# Epoch 449/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1500 - accuracy: 0.9000
# Epoch 00449: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1703 - accuracy: 0.9091 - val_loss: 0.5322 - val_accuracy: 0.5833
# Epoch 450/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1403 - accuracy: 0.9000
# Epoch 00450: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2307 - accuracy: 0.8864 - val_loss: 0.5375 - val_accuracy: 0.5833
# Epoch 451/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6572 - accuracy: 0.9000
# Epoch 00451: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2746 - accuracy: 0.9318 - val_loss: 0.5455 - val_accuracy: 0.6667
# Epoch 452/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3856 - accuracy: 0.8000
# Epoch 00452: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1865 - accuracy: 0.9318 - val_loss: 0.5511 - val_accuracy: 0.5833
# Epoch 453/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1720 - accuracy: 0.9000
# Epoch 00453: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1310 - accuracy: 0.9545 - val_loss: 0.5508 - val_accuracy: 0.6667
# Epoch 454/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0358 - accuracy: 1.0000
# Epoch 00454: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1713 - accuracy: 0.9318 - val_loss: 0.5461 - val_accuracy: 0.6667
# Epoch 455/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2965 - accuracy: 0.9000
# Epoch 00455: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1907 - accuracy: 0.9318 - val_loss: 0.5367 - val_accuracy: 0.6667
# Epoch 456/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1735 - accuracy: 0.9000
# Epoch 00456: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2029 - accuracy: 0.9091 - val_loss: 0.5341 - val_accuracy: 0.5833
# Epoch 457/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1261 - accuracy: 1.0000
# Epoch 00457: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1689 - accuracy: 0.9545 - val_loss: 0.5304 - val_accuracy: 0.5833
# Epoch 458/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4813 - accuracy: 0.9000
# Epoch 00458: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2561 - accuracy: 0.9091 - val_loss: 0.5175 - val_accuracy: 0.6667
# Epoch 459/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0852 - accuracy: 1.0000
# Epoch 00459: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2114 - accuracy: 0.8864 - val_loss: 0.5325 - val_accuracy: 0.5833
# Epoch 460/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5319 - accuracy: 0.8000
# Epoch 00460: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1978 - accuracy: 0.9318 - val_loss: 0.5562 - val_accuracy: 0.6667
# Epoch 461/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1012 - accuracy: 1.0000
# Epoch 00461: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2012 - accuracy: 0.9091 - val_loss: 0.5515 - val_accuracy: 0.6667
# Epoch 462/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3444 - accuracy: 0.9000
# Epoch 00462: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2276 - accuracy: 0.8864 - val_loss: 0.5252 - val_accuracy: 0.6667
# Epoch 463/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0543 - accuracy: 1.0000
# Epoch 00463: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1928 - accuracy: 0.9091 - val_loss: 0.5275 - val_accuracy: 0.6667
# Epoch 464/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3160 - accuracy: 0.9000
# Epoch 00464: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1700 - accuracy: 0.9091 - val_loss: 0.5378 - val_accuracy: 0.6667
# Epoch 465/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0657 - accuracy: 1.0000
# Epoch 00465: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1681 - accuracy: 0.9091 - val_loss: 0.5437 - val_accuracy: 0.6667
# Epoch 466/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5036 - accuracy: 0.8000
# Epoch 00466: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2345 - accuracy: 0.8864 - val_loss: 0.5231 - val_accuracy: 0.6667
# Epoch 467/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1921 - accuracy: 0.9000
# Epoch 00467: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1769 - accuracy: 0.9318 - val_loss: 0.5173 - val_accuracy: 0.6667
# Epoch 468/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1210 - accuracy: 1.0000
# Epoch 00468: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1580 - accuracy: 0.9545 - val_loss: 0.5079 - val_accuracy: 0.6667
# Epoch 469/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2987 - accuracy: 0.9000
# Epoch 00469: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1861 - accuracy: 0.9091 - val_loss: 0.4975 - val_accuracy: 0.6667
# Epoch 470/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2685 - accuracy: 0.9000
# Epoch 00470: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1693 - accuracy: 0.9318 - val_loss: 0.4906 - val_accuracy: 0.6667
# Epoch 471/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0908 - accuracy: 1.0000
# Epoch 00471: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1667 - accuracy: 0.9318 - val_loss: 0.4908 - val_accuracy: 0.6667
# Epoch 472/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1715 - accuracy: 0.9000
# Epoch 00472: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1400 - accuracy: 0.9318 - val_loss: 0.4875 - val_accuracy: 0.6667
# Epoch 473/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1273 - accuracy: 1.0000
# Epoch 00473: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1745 - accuracy: 0.9091 - val_loss: 0.4855 - val_accuracy: 0.6667
# Epoch 474/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1185 - accuracy: 1.0000
# Epoch 00474: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1451 - accuracy: 0.9318 - val_loss: 0.4844 - val_accuracy: 0.6667
# Epoch 475/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2401 - accuracy: 0.9000
# Epoch 00475: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1719 - accuracy: 0.9091 - val_loss: 0.4891 - val_accuracy: 0.6667
# Epoch 476/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1379 - accuracy: 1.0000
# Epoch 00476: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1412 - accuracy: 0.9318 - val_loss: 0.4815 - val_accuracy: 0.6667
# Epoch 477/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1395 - accuracy: 1.0000
# Epoch 00477: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1404 - accuracy: 0.9773 - val_loss: 0.4805 - val_accuracy: 0.6667
# Epoch 478/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0109 - accuracy: 1.0000
# Epoch 00478: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2188 - accuracy: 0.8864 - val_loss: 0.4882 - val_accuracy: 0.6667
# Epoch 479/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0526 - accuracy: 1.0000
# Epoch 00479: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1394 - accuracy: 0.9318 - val_loss: 0.4832 - val_accuracy: 0.6667
# Epoch 480/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2200 - accuracy: 0.8000
# Epoch 00480: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2323 - accuracy: 0.8636 - val_loss: 0.5068 - val_accuracy: 0.7500
# Epoch 481/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1394 - accuracy: 0.9000
# Epoch 00481: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1984 - accuracy: 0.9091 - val_loss: 0.4743 - val_accuracy: 0.6667
# Epoch 482/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3303 - accuracy: 0.8000
# Epoch 00482: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1894 - accuracy: 0.8864 - val_loss: 0.4888 - val_accuracy: 0.6667
# Epoch 483/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2445 - accuracy: 0.9000
# Epoch 00483: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1657 - accuracy: 0.9318 - val_loss: 0.4779 - val_accuracy: 0.6667
# Epoch 484/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0802 - accuracy: 1.0000
# Epoch 00484: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1851 - accuracy: 0.9091 - val_loss: 0.4722 - val_accuracy: 0.6667
# Epoch 485/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4104 - accuracy: 0.9000
# Epoch 00485: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2127 - accuracy: 0.9091 - val_loss: 0.4759 - val_accuracy: 0.6667
# Epoch 486/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0931 - accuracy: 1.0000
# Epoch 00486: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2798 - accuracy: 0.9091 - val_loss: 0.4891 - val_accuracy: 0.7500
# Epoch 487/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1295 - accuracy: 1.0000
# Epoch 00487: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1321 - accuracy: 0.9773 - val_loss: 0.4817 - val_accuracy: 0.6667
# Epoch 488/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1074 - accuracy: 1.0000
# Epoch 00488: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1619 - accuracy: 0.9318 - val_loss: 0.4854 - val_accuracy: 0.6667
# Epoch 489/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0427 - accuracy: 1.0000
# Epoch 00489: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1129 - accuracy: 0.9545 - val_loss: 0.4870 - val_accuracy: 0.6667
# Epoch 490/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1812 - accuracy: 0.9000
# Epoch 00490: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1712 - accuracy: 0.9318 - val_loss: 0.4905 - val_accuracy: 0.6667
# Epoch 491/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1645 - accuracy: 0.9000
# Epoch 00491: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1770 - accuracy: 0.9318 - val_loss: 0.4840 - val_accuracy: 0.6667
# Epoch 492/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2494 - accuracy: 0.9000
# Epoch 00492: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1923 - accuracy: 0.9318 - val_loss: 0.4798 - val_accuracy: 0.6667
# Epoch 493/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1217 - accuracy: 1.0000
# Epoch 00493: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1480 - accuracy: 0.9545 - val_loss: 0.4812 - val_accuracy: 0.6667
# Epoch 494/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1110 - accuracy: 1.0000
# Epoch 00494: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1226 - accuracy: 0.9545 - val_loss: 0.4900 - val_accuracy: 0.6667
# Epoch 495/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0558 - accuracy: 1.0000
# Epoch 00495: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1371 - accuracy: 0.9545 - val_loss: 0.4972 - val_accuracy: 0.6667
# Epoch 496/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2337 - accuracy: 0.8000
# Epoch 00496: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1645 - accuracy: 0.9091 - val_loss: 0.4909 - val_accuracy: 0.6667
# Epoch 497/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0789 - accuracy: 1.0000
# Epoch 00497: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2183 - accuracy: 0.9091 - val_loss: 0.5007 - val_accuracy: 0.6667
# Epoch 498/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0944 - accuracy: 1.0000
# Epoch 00498: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1288 - accuracy: 0.9545 - val_loss: 0.5097 - val_accuracy: 0.6667
# Epoch 499/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1193 - accuracy: 1.0000
# Epoch 00499: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0983 - accuracy: 1.0000 - val_loss: 0.5484 - val_accuracy: 0.6667
# Epoch 500/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6767 - accuracy: 0.6000
# Epoch 00500: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2690 - accuracy: 0.8409 - val_loss: 0.5427 - val_accuracy: 0.6667
# Training completed in time:  0:00:29.702974

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.90909094
# Testing Accuracy:  0.75

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.40      0.67      0.50         3
#    Pneumonia       0.91      0.77      0.83        13
#
#     accuracy                           0.75        16
#    macro avg       0.65      0.72      0.67        16
# weighted avg       0.81      0.75      0.77        16

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[ 2  1]
#  [ 3 10]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])
