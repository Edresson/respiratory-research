# %% [markdown]
# # Rede CNN - Modelo 2
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - Dataset 1 - slide10

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP_TRAIN = 'slide10'
GROUP_TEST = 'slide10'
DATASET = 'dataset_1'
DURATION = 10
SIZE = 431
CSV_TRAIN = 'train1.csv'
CSV_TEST = 'test1.csv'
MODEL_NAME = f'CNN2_{DATASET}_{GROUP_TRAIN}'

# %%
train_file_paths = glob.glob(f'../datasets/{DATASET}/{GROUP_TRAIN}/train/**/*.wav', recursive=True)
train_file_names = [os.path.splitext(os.path.basename(p))[0] for p in train_file_paths]

test_file_paths = glob.glob(f'../datasets/{DATASET}/{GROUP_TEST}/test/**/*.wav', recursive=True)
test_file_names = [os.path.splitext(os.path.basename(p))[0] for p in test_file_paths]

# %%
train_p_id_in_file = [] # patient IDs corresponding to each file
test_p_id_in_file = [] # patient IDs corresponding to each file
for name in train_file_names:
    train_p_id_in_file.append(int(name[:3]))

for name in test_file_names:
    test_p_id_in_file.append(int(name[:3]))

train_p_id_in_file = np.array(train_p_id_in_file)
test_p_id_in_file = np.array(test_p_id_in_file)

# %%
max_pad_len = SIZE

os.makedirs("features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=DURATION) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
train_p_diag = pd.read_csv(f"../Respiratory_Sound_Database/Respiratory_Sound_Database_Pneumo_Healthy_Only/{CSV_TRAIN}", header=None) # patient diagnosis file
test_p_diag = pd.read_csv(f"../Respiratory_Sound_Database/Respiratory_Sound_Database_Pneumo_Healthy_Only/{CSV_TEST}", header=None) # patient diagnosis file
train_p_diag.head(5)
# Out:
#      0        1
# 0  102  Healthy
# 1  121  Healthy
# 2  123  Healthy
# 3  125  Healthy
# 4  126  Healthy

# %%
train_labels = np.array([train_p_diag[train_p_diag[0] == x][1].values[0] for x in train_p_id_in_file]) 
test_labels = np.array([test_p_diag[test_p_diag[0] == x][1].values[0] for x in test_p_id_in_file])

# %%
train_features = [] 
test_features = []

for file_name in train_file_paths:
    data = extract_features(file_name)
    train_features.append(data)

for file_name in test_file_paths:
    data = extract_features(file_name)
    test_features.append(data)

print('Finished feature extraction from ', (len(train_features)+len(train_features)), ' files')
train_features = np.array(train_features)
test_features = np.array(test_features)
# Out:
# Finished feature extraction from  976  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(train_features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
np.unique(train_labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
unique_elements, counts_elements = np.unique(train_labels, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))

unique_elements_test, counts_elements_test = np.unique(test_labels, return_counts=True)
print(np.asarray((unique_elements_test, counts_elements_test)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['256' '232']]
# [['Healthy' 'Pneumonia']
#  ['24' '64']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
le.fit(train_labels)
train_labels_cat = to_categorical(le.transform(train_labels)) 
test_labels_cat = to_categorical(le.transform(test_labels))

# %%
train_features.shape
# Out:
# (488, 40, 431)

# %%
input_dim = train_features.shape[1]*train_features.shape[2]

# %%
train_features = np.reshape(train_features, (*train_features.shape,1)) 
print(train_features.shape, train_labels_cat.shape)
test_features = np.reshape(test_features, (*test_features.shape,1)) 
print(test_features.shape, test_labels_cat.shape)
# Out:
# (488, 40, 431, 1) (488, 2)
# (88, 40, 431, 1) (88, 2)

# %%
# train test split
x_train, x_val, y_train, y_val = train_test_split(train_features, train_labels_cat, test_size=0.2, random_state = 42)
x_test, y_test = test_features, test_labels_cat

# %% [markdown]
# **CNN model architecture**

# %%
num_labels = train_labels_cat.shape[1]

num_rows = 40
num_columns = SIZE
num_channels = 1

filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(Conv2D(filters=16, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(Conv2D(filters=8, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(Conv2D(filters=4, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 430, 32)       160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 215, 32)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 215, 32)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 214, 16)       2064
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 107, 16)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 107, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 106, 8)         520
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 53, 8)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 53, 8)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 52, 4)          132
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 26, 4)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 26, 4)          0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 4)                 0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 10
# =================================================================
# Total params: 2,886
# Trainable params: 2,886
# Non-trainable params: 0
# _________________________________________________________________
# 88/88 [==============================] - 2s 26ms/sample - loss: 2.0650 - accuracy: 0.2727
# Pre-training accuracy: 27.2727%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 500
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/' + MODEL_NAME + '_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_val, y_val), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 390 samples, validate on 98 samples
# Epoch 1/500
# 370/390 [===========================>..] - ETA: 0s - loss: 4.4488 - accuracy: 0.5324
# Epoch 00001: val_accuracy improved from -inf to 0.53061, saving model to models/CNN2_dataset_1_slide10_01.h5
# 390/390 [==============================] - 1s 3ms/sample - loss: 4.2554 - accuracy: 0.5385 - val_loss: 0.6931 - val_accuracy: 0.5306
# Epoch 2/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.7311 - accuracy: 0.5595
# Epoch 00002: val_accuracy did not improve from 0.53061
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.7284 - accuracy: 0.5590 - val_loss: 0.7010 - val_accuracy: 0.5306
# Epoch 3/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.7232 - accuracy: 0.5189
# Epoch 00003: val_accuracy did not improve from 0.53061
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.7227 - accuracy: 0.5256 - val_loss: 0.6972 - val_accuracy: 0.5306
# Epoch 4/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.7164 - accuracy: 0.5351
# Epoch 00004: val_accuracy did not improve from 0.53061
# 390/390 [==============================] - 0s 998us/sample - loss: 0.7146 - accuracy: 0.5308 - val_loss: 0.6945 - val_accuracy: 0.5306
# Epoch 5/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.7094 - accuracy: 0.5243
# Epoch 00005: val_accuracy did not improve from 0.53061
# 390/390 [==============================] - 0s 996us/sample - loss: 0.7097 - accuracy: 0.5205 - val_loss: 0.6923 - val_accuracy: 0.5306
# Epoch 6/500
# 360/390 [==========================>...] - ETA: 0s - loss: 0.6837 - accuracy: 0.5750
# Epoch 00006: val_accuracy did not improve from 0.53061
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.6740 - accuracy: 0.5872 - val_loss: 0.6920 - val_accuracy: 0.5306
# Epoch 7/500
# 360/390 [==========================>...] - ETA: 0s - loss: 0.6679 - accuracy: 0.5917
# Epoch 00007: val_accuracy did not improve from 0.53061
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.6696 - accuracy: 0.5769 - val_loss: 0.6929 - val_accuracy: 0.5306
# Epoch 8/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.6539 - accuracy: 0.6000
# Epoch 00008: val_accuracy did not improve from 0.53061
# 390/390 [==============================] - 0s 983us/sample - loss: 0.6595 - accuracy: 0.5846 - val_loss: 0.6960 - val_accuracy: 0.5306
# Epoch 9/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.6552 - accuracy: 0.6027
# Epoch 00009: val_accuracy did not improve from 0.53061
# 390/390 [==============================] - 0s 979us/sample - loss: 0.6565 - accuracy: 0.6051 - val_loss: 0.6946 - val_accuracy: 0.5306
# Epoch 10/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.6498 - accuracy: 0.5703
# Epoch 00010: val_accuracy improved from 0.53061 to 0.56122, saving model to models/CNN2_dataset_1_slide10_10.h5
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.6473 - accuracy: 0.5769 - val_loss: 0.6807 - val_accuracy: 0.5612
# Epoch 11/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.5948 - accuracy: 0.6297
# Epoch 00011: val_accuracy improved from 0.56122 to 0.57143, saving model to models/CNN2_dataset_1_slide10_11.h5
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.5933 - accuracy: 0.6308 - val_loss: 0.6637 - val_accuracy: 0.5714
# Epoch 12/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.5819 - accuracy: 0.6865
# Epoch 00012: val_accuracy improved from 0.57143 to 0.68367, saving model to models/CNN2_dataset_1_slide10_12.h5
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.5757 - accuracy: 0.6897 - val_loss: 0.6233 - val_accuracy: 0.6837
# Epoch 13/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.5787 - accuracy: 0.6757
# Epoch 00013: val_accuracy improved from 0.68367 to 0.71429, saving model to models/CNN2_dataset_1_slide10_13.h5
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.5798 - accuracy: 0.6692 - val_loss: 0.6038 - val_accuracy: 0.7143
# Epoch 14/500
# 360/390 [==========================>...] - ETA: 0s - loss: 0.5333 - accuracy: 0.7028
# Epoch 00014: val_accuracy improved from 0.71429 to 0.77551, saving model to models/CNN2_dataset_1_slide10_14.h5
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.5334 - accuracy: 0.7154 - val_loss: 0.5614 - val_accuracy: 0.7755
# Epoch 15/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.5424 - accuracy: 0.7324
# Epoch 00015: val_accuracy did not improve from 0.77551
# 390/390 [==============================] - 0s 995us/sample - loss: 0.5474 - accuracy: 0.7256 - val_loss: 0.5741 - val_accuracy: 0.7143
# Epoch 16/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.5369 - accuracy: 0.7135
# Epoch 00016: val_accuracy did not improve from 0.77551
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.5383 - accuracy: 0.7128 - val_loss: 0.5931 - val_accuracy: 0.7041
# Epoch 17/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.5021 - accuracy: 0.7649
# Epoch 00017: val_accuracy did not improve from 0.77551
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.5041 - accuracy: 0.7590 - val_loss: 0.5543 - val_accuracy: 0.7041
# Epoch 18/500
# 360/390 [==========================>...] - ETA: 0s - loss: 0.5060 - accuracy: 0.7250
# Epoch 00018: val_accuracy did not improve from 0.77551
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.4991 - accuracy: 0.7308 - val_loss: 0.5576 - val_accuracy: 0.7041
# Epoch 19/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.4881 - accuracy: 0.7514
# Epoch 00019: val_accuracy did not improve from 0.77551
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.4876 - accuracy: 0.7513 - val_loss: 0.5662 - val_accuracy: 0.6837
# Epoch 20/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.4528 - accuracy: 0.7676
# Epoch 00020: val_accuracy did not improve from 0.77551
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.4487 - accuracy: 0.7744 - val_loss: 0.4859 - val_accuracy: 0.7755
# Epoch 21/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.4309 - accuracy: 0.7973
# Epoch 00021: val_accuracy did not improve from 0.77551
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.4237 - accuracy: 0.8000 - val_loss: 0.4565 - val_accuracy: 0.7755
# Epoch 22/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.3643 - accuracy: 0.8324
# Epoch 00022: val_accuracy improved from 0.77551 to 0.88776, saving model to models/CNN2_dataset_1_slide10_22.h5
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.3643 - accuracy: 0.8333 - val_loss: 0.3460 - val_accuracy: 0.8878
# Epoch 23/500
# 350/390 [=========================>....] - ETA: 0s - loss: 0.2990 - accuracy: 0.8714
# Epoch 00023: val_accuracy did not improve from 0.88776
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.2991 - accuracy: 0.8744 - val_loss: 0.3409 - val_accuracy: 0.8776
# Epoch 24/500
# 340/390 [=========================>....] - ETA: 0s - loss: 0.3391 - accuracy: 0.8412
# Epoch 00024: val_accuracy did not improve from 0.88776
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.3381 - accuracy: 0.8436 - val_loss: 0.3205 - val_accuracy: 0.8673
# Epoch 25/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.2445 - accuracy: 0.8946
# Epoch 00025: val_accuracy did not improve from 0.88776
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.2460 - accuracy: 0.8949 - val_loss: 0.3895 - val_accuracy: 0.7653
# Epoch 26/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.2995 - accuracy: 0.8432
# Epoch 00026: val_accuracy did not improve from 0.88776
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.2962 - accuracy: 0.8436 - val_loss: 0.2965 - val_accuracy: 0.8673
# Epoch 27/500
# 360/390 [==========================>...] - ETA: 0s - loss: 0.2645 - accuracy: 0.8833
# Epoch 00027: val_accuracy did not improve from 0.88776
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.2721 - accuracy: 0.8769 - val_loss: 0.2871 - val_accuracy: 0.8571
# Epoch 28/500
# 360/390 [==========================>...] - ETA: 0s - loss: 0.2288 - accuracy: 0.9028
# Epoch 00028: val_accuracy did not improve from 0.88776
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.2278 - accuracy: 0.9051 - val_loss: 0.2652 - val_accuracy: 0.8776
# Epoch 29/500
# 360/390 [==========================>...] - ETA: 0s - loss: 0.2348 - accuracy: 0.9083
# Epoch 00029: val_accuracy did not improve from 0.88776
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.2296 - accuracy: 0.9128 - val_loss: 0.2940 - val_accuracy: 0.8367
# Epoch 30/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.2253 - accuracy: 0.9135
# Epoch 00030: val_accuracy did not improve from 0.88776
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.2221 - accuracy: 0.9179 - val_loss: 0.3158 - val_accuracy: 0.8265
# Epoch 31/500
# 350/390 [=========================>....] - ETA: 0s - loss: 0.2220 - accuracy: 0.9143
# Epoch 00031: val_accuracy did not improve from 0.88776
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.2287 - accuracy: 0.9077 - val_loss: 0.2991 - val_accuracy: 0.8265
# Epoch 32/500
# 350/390 [=========================>....] - ETA: 0s - loss: 0.2027 - accuracy: 0.9229
# Epoch 00032: val_accuracy did not improve from 0.88776
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.2018 - accuracy: 0.9179 - val_loss: 0.1999 - val_accuracy: 0.8878
# Epoch 33/500
# 350/390 [=========================>....] - ETA: 0s - loss: 0.2300 - accuracy: 0.8829
# Epoch 00033: val_accuracy improved from 0.88776 to 0.89796, saving model to models/CNN2_dataset_1_slide10_33.h5
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.2467 - accuracy: 0.8744 - val_loss: 0.2015 - val_accuracy: 0.8980
# Epoch 34/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.2915 - accuracy: 0.8568
# Epoch 00034: val_accuracy did not improve from 0.89796
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.2879 - accuracy: 0.8615 - val_loss: 0.3419 - val_accuracy: 0.7959
# Epoch 35/500
# 380/390 [============================>.] - ETA: 0s - loss: 0.2437 - accuracy: 0.9000
# Epoch 00035: val_accuracy did not improve from 0.89796
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.2417 - accuracy: 0.9000 - val_loss: 0.2145 - val_accuracy: 0.8980
# Epoch 36/500
# 340/390 [=========================>....] - ETA: 0s - loss: 0.1853 - accuracy: 0.9206
# Epoch 00036: val_accuracy did not improve from 0.89796
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.1786 - accuracy: 0.9282 - val_loss: 0.2659 - val_accuracy: 0.8469
# Epoch 37/500
# 360/390 [==========================>...] - ETA: 0s - loss: 0.2103 - accuracy: 0.9167
# Epoch 00037: val_accuracy did not improve from 0.89796
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.2111 - accuracy: 0.9179 - val_loss: 0.4722 - val_accuracy: 0.7143
# Epoch 38/500
# 360/390 [==========================>...] - ETA: 0s - loss: 0.2330 - accuracy: 0.9000
# Epoch 00038: val_accuracy improved from 0.89796 to 0.90816, saving model to models/CNN2_dataset_1_slide10_38.h5
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.2331 - accuracy: 0.9000 - val_loss: 0.1861 - val_accuracy: 0.9082
# Epoch 39/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.2092 - accuracy: 0.9135
# Epoch 00039: val_accuracy did not improve from 0.90816
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.2100 - accuracy: 0.9128 - val_loss: 0.1999 - val_accuracy: 0.8878
# Epoch 40/500
# 360/390 [==========================>...] - ETA: 0s - loss: 0.2132 - accuracy: 0.9111
# Epoch 00040: val_accuracy did not improve from 0.90816
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.2028 - accuracy: 0.9179 - val_loss: 0.1924 - val_accuracy: 0.8878
# Epoch 41/500
# 340/390 [=========================>....] - ETA: 0s - loss: 0.1742 - accuracy: 0.9382
# Epoch 00041: val_accuracy did not improve from 0.90816
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.1751 - accuracy: 0.9359 - val_loss: 0.2457 - val_accuracy: 0.8469
# Epoch 42/500
# 360/390 [==========================>...] - ETA: 0s - loss: 0.1836 - accuracy: 0.9194
# Epoch 00042: val_accuracy improved from 0.90816 to 0.92857, saving model to models/CNN2_dataset_1_slide10_42.h5
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.1841 - accuracy: 0.9179 - val_loss: 0.1645 - val_accuracy: 0.9286
# Epoch 43/500
# 350/390 [=========================>....] - ETA: 0s - loss: 0.1729 - accuracy: 0.9371
# Epoch 00043: val_accuracy did not improve from 0.92857
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.1740 - accuracy: 0.9308 - val_loss: 0.2205 - val_accuracy: 0.8673
# Epoch 44/500
# 360/390 [==========================>...] - ETA: 0s - loss: 0.2293 - accuracy: 0.9028
# Epoch 00044: val_accuracy improved from 0.92857 to 0.97959, saving model to models/CNN2_dataset_1_slide10_44.h5
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.2217 - accuracy: 0.9051 - val_loss: 0.1194 - val_accuracy: 0.9796
# Epoch 45/500
# 350/390 [=========================>....] - ETA: 0s - loss: 0.1605 - accuracy: 0.9371
# Epoch 00045: val_accuracy did not improve from 0.97959
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.1791 - accuracy: 0.9256 - val_loss: 0.1768 - val_accuracy: 0.8980
# Epoch 46/500
# 360/390 [==========================>...] - ETA: 0s - loss: 0.1608 - accuracy: 0.9361
# Epoch 00046: val_accuracy did not improve from 0.97959
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.1779 - accuracy: 0.9282 - val_loss: 0.2243 - val_accuracy: 0.8673
# Epoch 47/500
# 350/390 [=========================>....] - ETA: 0s - loss: 0.1531 - accuracy: 0.9486
# Epoch 00047: val_accuracy did not improve from 0.97959
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.1557 - accuracy: 0.9462 - val_loss: 0.1161 - val_accuracy: 0.9796
# Epoch 48/500
# 360/390 [==========================>...] - ETA: 0s - loss: 0.1556 - accuracy: 0.9472
# Epoch 00048: val_accuracy did not improve from 0.97959
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.1610 - accuracy: 0.9436 - val_loss: 0.1501 - val_accuracy: 0.9286
# Epoch 49/500
# 360/390 [==========================>...] - ETA: 0s - loss: 0.1709 - accuracy: 0.9250
# Epoch 00049: val_accuracy did not improve from 0.97959
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.1734 - accuracy: 0.9256 - val_loss: 0.1411 - val_accuracy: 0.9490
# Epoch 50/500
# 360/390 [==========================>...] - ETA: 0s - loss: 0.1483 - accuracy: 0.9611
# Epoch 00050: val_accuracy did not improve from 0.97959
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.1518 - accuracy: 0.9590 - val_loss: 0.1187 - val_accuracy: 0.9796
# Epoch 51/500
# 360/390 [==========================>...] - ETA: 0s - loss: 0.1777 - accuracy: 0.9222
# Epoch 00051: val_accuracy did not improve from 0.97959
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.1673 - accuracy: 0.9282 - val_loss: 0.1174 - val_accuracy: 0.9694
# Epoch 52/500
# 360/390 [==========================>...] - ETA: 0s - loss: 0.1810 - accuracy: 0.9278
# Epoch 00052: val_accuracy did not improve from 0.97959
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.1777 - accuracy: 0.9308 - val_loss: 0.1424 - val_accuracy: 0.9388
# Epoch 53/500
# 340/390 [=========================>....] - ETA: 0s - loss: 0.1988 - accuracy: 0.9147
# Epoch 00053: val_accuracy did not improve from 0.97959
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.1962 - accuracy: 0.9154 - val_loss: 0.1528 - val_accuracy: 0.9388
# Epoch 54/500
# 360/390 [==========================>...] - ETA: 0s - loss: 0.1684 - accuracy: 0.9389
# Epoch 00054: val_accuracy did not improve from 0.97959
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.1637 - accuracy: 0.9410 - val_loss: 0.2797 - val_accuracy: 0.8265
# Epoch 55/500
# 350/390 [=========================>....] - ETA: 0s - loss: 0.1795 - accuracy: 0.9343
# Epoch 00055: val_accuracy did not improve from 0.97959
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.1763 - accuracy: 0.9385 - val_loss: 0.1876 - val_accuracy: 0.8878
# Epoch 56/500
# 360/390 [==========================>...] - ETA: 0s - loss: 0.1272 - accuracy: 0.9528
# Epoch 00056: val_accuracy did not improve from 0.97959
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.1278 - accuracy: 0.9538 - val_loss: 0.1215 - val_accuracy: 0.9592
# Epoch 57/500
# 360/390 [==========================>...] - ETA: 0s - loss: 0.1726 - accuracy: 0.9333
# Epoch 00057: val_accuracy did not improve from 0.97959
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.1754 - accuracy: 0.9333 - val_loss: 0.3777 - val_accuracy: 0.8061
# Epoch 58/500
# 350/390 [=========================>....] - ETA: 0s - loss: 0.1481 - accuracy: 0.9429
# Epoch 00058: val_accuracy did not improve from 0.97959
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.1478 - accuracy: 0.9436 - val_loss: 0.0959 - val_accuracy: 0.9796
# Epoch 59/500
# 350/390 [=========================>....] - ETA: 0s - loss: 0.1361 - accuracy: 0.9343
# Epoch 00059: val_accuracy did not improve from 0.97959
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.1386 - accuracy: 0.9333 - val_loss: 0.1494 - val_accuracy: 0.9286
# Epoch 60/500
# 350/390 [=========================>....] - ETA: 0s - loss: 0.1293 - accuracy: 0.9486
# Epoch 00060: val_accuracy did not improve from 0.97959
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.1368 - accuracy: 0.9410 - val_loss: 0.1836 - val_accuracy: 0.8980
# Epoch 61/500
# 340/390 [=========================>....] - ETA: 0s - loss: 0.1697 - accuracy: 0.9471
# Epoch 00061: val_accuracy did not improve from 0.97959
# 390/390 [==============================] - 0s 1ms/sample - loss: 0
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0834 - accuracy: 0.9744 - val_loss: 0.1373 - val_accuracy: 0.9286
# Epoch 103/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0864 - accuracy: 0.9676
# Epoch 00103: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 998us/sample - loss: 0.0841 - accuracy: 0.9692 - val_loss: 0.0586 - val_accuracy: 0.9796
# Epoch 104/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0955 - accuracy: 0.9730
# Epoch 00104: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 992us/sample - loss: 0.0934 - accuracy: 0.9718 - val_loss: 0.0535 - val_accuracy: 0.9898
# Epoch 105/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0800 - accuracy: 0.9649
# Epoch 00105: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1000us/sample - loss: 0.0807 - accuracy: 0.9641 - val_loss: 0.1043 - val_accuracy: 0.9592
# Epoch 106/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0974 - accuracy: 0.9622
# Epoch 00106: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 993us/sample - loss: 0.0936 - accuracy: 0.9641 - val_loss: 0.0473 - val_accuracy: 0.9898
# Epoch 107/500
# 350/390 [=========================>....] - ETA: 0s - loss: 0.0628 - accuracy: 0.9771
# Epoch 00107: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0583 - accuracy: 0.9795 - val_loss: 0.0526 - val_accuracy: 0.9898
# Epoch 108/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0791 - accuracy: 0.9595
# Epoch 00108: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0771 - accuracy: 0.9615 - val_loss: 0.0552 - val_accuracy: 0.9796
# Epoch 109/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0679 - accuracy: 0.9730
# Epoch 00109: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 994us/sample - loss: 0.0693 - accuracy: 0.9718 - val_loss: 0.0451 - val_accuracy: 0.9898
# Epoch 110/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0972 - accuracy: 0.9622
# Epoch 00110: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0955 - accuracy: 0.9641 - val_loss: 0.0964 - val_accuracy: 0.9592
# Epoch 111/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.1052 - accuracy: 0.9541
# Epoch 00111: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.1092 - accuracy: 0.9538 - val_loss: 0.0756 - val_accuracy: 0.9694
# Epoch 112/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0810 - accuracy: 0.9622
# Epoch 00112: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0790 - accuracy: 0.9641 - val_loss: 0.0757 - val_accuracy: 0.9694
# Epoch 113/500
# 360/390 [==========================>...] - ETA: 0s - loss: 0.0687 - accuracy: 0.9694
# Epoch 00113: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0766 - accuracy: 0.9667 - val_loss: 0.0561 - val_accuracy: 0.9796
# Epoch 114/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.1125 - accuracy: 0.9622
# Epoch 00114: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 993us/sample - loss: 0.1105 - accuracy: 0.9615 - val_loss: 0.1405 - val_accuracy: 0.9286
# Epoch 115/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0953 - accuracy: 0.9676
# Epoch 00115: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0962 - accuracy: 0.9641 - val_loss: 0.1131 - val_accuracy: 0.9592
# Epoch 116/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0692 - accuracy: 0.9703
# Epoch 00116: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0709 - accuracy: 0.9692 - val_loss: 0.1190 - val_accuracy: 0.9490
# Epoch 117/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0653 - accuracy: 0.9784
# Epoch 00117: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0646 - accuracy: 0.9795 - val_loss: 0.0481 - val_accuracy: 0.9796
# Epoch 118/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0685 - accuracy: 0.9676
# Epoch 00118: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0666 - accuracy: 0.9692 - val_loss: 0.0401 - val_accuracy: 0.9898
# Epoch 119/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0707 - accuracy: 0.9757
# Epoch 00119: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0735 - accuracy: 0.9744 - val_loss: 0.0855 - val_accuracy: 0.9694
# Epoch 120/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0752 - accuracy: 0.9649
# Epoch 00120: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 996us/sample - loss: 0.0767 - accuracy: 0.9641 - val_loss: 0.0587 - val_accuracy: 0.9796
# Epoch 121/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0939 - accuracy: 0.9622
# Epoch 00121: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.1054 - accuracy: 0.9590 - val_loss: 0.1243 - val_accuracy: 0.9388
# Epoch 122/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0687 - accuracy: 0.9757
# Epoch 00122: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0655 - accuracy: 0.9769 - val_loss: 0.0464 - val_accuracy: 0.9898
# Epoch 123/500
# 360/390 [==========================>...] - ETA: 0s - loss: 0.0975 - accuracy: 0.9528
# Epoch 00123: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0925 - accuracy: 0.9564 - val_loss: 0.0488 - val_accuracy: 0.9898
# Epoch 124/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0633 - accuracy: 0.9730
# Epoch 00124: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0612 - accuracy: 0.9744 - val_loss: 0.0539 - val_accuracy: 0.9796
# Epoch 125/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0952 - accuracy: 0.9649
# Epoch 00125: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 998us/sample - loss: 0.0999 - accuracy: 0.9615 - val_loss: 0.1572 - val_accuracy: 0.9082
# Epoch 126/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0831 - accuracy: 0.9676
# Epoch 00126: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0876 - accuracy: 0.9641 - val_loss: 0.1055 - val_accuracy: 0.9592
# Epoch 127/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0667 - accuracy: 0.9703
# Epoch 00127: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0646 - accuracy: 0.9718 - val_loss: 0.0590 - val_accuracy: 0.9796
# Epoch 128/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0750 - accuracy: 0.9703
# Epoch 00128: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0761 - accuracy: 0.9692 - val_loss: 0.0761 - val_accuracy: 0.9694
# Epoch 129/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0898 - accuracy: 0.9568
# Epoch 00129: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0866 - accuracy: 0.9590 - val_loss: 0.0481 - val_accuracy: 0.9796
# Epoch 130/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0490 - accuracy: 0.9811
# Epoch 00130: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0493 - accuracy: 0.9821 - val_loss: 0.0334 - val_accuracy: 0.9898
# Epoch 131/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0389 - accuracy: 0.9892
# Epoch 00131: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 991us/sample - loss: 0.0407 - accuracy: 0.9897 - val_loss: 0.0376 - val_accuracy: 0.9898
# Epoch 132/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0605 - accuracy: 0.9730
# Epoch 00132: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0575 - accuracy: 0.9744 - val_loss: 0.0341 - val_accuracy: 0.9898
# Epoch 133/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0944 - accuracy: 0.9514
# Epoch 00133: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 995us/sample - loss: 0.0919 - accuracy: 0.9538 - val_loss: 0.0360 - val_accuracy: 0.9898
# Epoch 134/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0636 - accuracy: 0.9757
# Epoch 00134: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0645 - accuracy: 0.9744 - val_loss: 0.0401 - val_accuracy: 0.9898
# Epoch 135/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0644 - accuracy: 0.9811
# Epoch 00135: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0669 - accuracy: 0.9795 - val_loss: 0.0821 - val_accuracy: 0.9592
# Epoch 136/500
# 350/390 [=========================>....] - ETA: 0s - loss: 0.0492 - accuracy: 0.9771
# Epoch 00136: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0488 - accuracy: 0.9795 - val_loss: 0.0425 - val_accuracy: 0.9898
# Epoch 137/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0667 - accuracy: 0.9784
# Epoch 00137: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0695 - accuracy: 0.9769 - val_loss: 0.0422 - val_accuracy: 0.9898
# Epoch 138/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0657 - accuracy: 0.9649
# Epoch 00138: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 995us/sample - loss: 0.0626 - accuracy: 0.9667 - val_loss: 0.0412 - val_accuracy: 0.9796
# Epoch 139/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0767 - accuracy: 0.9676
# Epoch 00139: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 990us/sample - loss: 0.0797 - accuracy: 0.9641 - val_loss: 0.0363 - val_accuracy: 0.9898
# Epoch 140/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0583 - accuracy: 0.9865
# Epoch 00140: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0559 - accuracy: 0.9872 - val_loss: 0.0328 - val_accuracy: 0.9898
# Epoch 141/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0497 - accuracy: 0.9838
# Epoch 00141: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 997us/sample - loss: 0.0502 - accuracy: 0.9821 - val_loss: 0.0285 - val_accuracy: 0.9898
# Epoch 142/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0805 - accuracy: 0.9676
# Epoch 00142: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 990us/sample - loss: 0.0776 - accuracy: 0.9692 - val_loss: 0.0359 - val_accuracy: 0.9898
# Epoch 143/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0446 - accuracy: 0.9838
# Epoch 00143: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0493 - accuracy: 0.9821 - val_loss: 0.0471 - val_accuracy: 0.9898
# Epoch 144/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0453 - accuracy: 0.9838
# Epoch 00144: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 999us/sample - loss: 0.0548 - accuracy: 0.9795 - val_loss: 0.0271 - val_accuracy: 0.9898
# Epoch 145/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0814 - accuracy: 0.9730
# Epoch 00145: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0868 - accuracy: 0.9718 - val_loss: 0.0566 - val_accuracy: 0.9694
# Epoch 146/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0682 - accuracy: 0.9757
# Epoch 00146: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 975us/sample - loss: 0.0659 - accuracy: 0.9769 - val_loss: 0.0315 - val_accuracy: 0.9898
# Epoch 147/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.1167 - accuracy: 0.9486
# Epoch 00147: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.1108 - accuracy: 0.9513 - val_loss: 0.0611 - val_accuracy: 0.9796
# Epoch 148/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0797 - accuracy: 0.9703
# Epoch 00148: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0776 - accuracy: 0.9718 - val_loss: 0.0650 - val_accuracy: 0.9796
# Epoch 149/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0528 - accuracy: 0.9757
# Epoch 00149: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0599 - accuracy: 0.9744 - val_loss: 0.0791 - val_accuracy: 0.9694
# Epoch 150/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0378 - accuracy: 0.9865
# Epoch 00150: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0385 - accuracy: 0.9846 - val_loss: 0.1115 - val_accuracy: 0.9490
# Epoch 151/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0593 - accuracy: 0.9784
# Epoch 00151: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 982us/sample - loss: 0.0635 - accuracy: 0.9769 - val_loss: 0.0362 - val_accuracy: 0.9898
# Epoch 152/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0595 - accuracy: 0.9703
# Epoch 00152: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0616 - accuracy: 0.9692 - val_loss: 0.0290 - val_accuracy: 0.9898
# Epoch 153/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0442 - accuracy: 0.9784
# Epoch 00153: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0487 - accuracy: 0.9769 - val_loss: 0.0574 - val_accuracy: 0.9796
# Epoch 154/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0460 - accuracy: 0.9784
# Epoch 00154: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0440 - accuracy: 0.9795 - val_loss: 0.0504 - val_accuracy: 0.9796
# Epoch 155/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0308 - accuracy: 0.9973
# Epoch 00155: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0301 - accuracy: 0.9974 - val_loss: 0.0403 - val_accuracy: 0.9898
# Epoch 156/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0416 - accuracy: 0.9838
# Epoch 00156: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 993us/sample - loss: 0.0421 - accuracy: 0.9821 - val_loss: 0.0232 - val_accuracy: 0.9898
# Epoch 157/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0920 - accuracy: 0.9676
# Epoch 00157: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 984us/sample - loss: 0.0896 - accuracy: 0.9692 - val_loss: 0.0304 - val_accuracy: 0.9898
# Epoch 158/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0664 - accuracy: 0.9757
# Epoch 00158: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0673 - accuracy: 0.9744 - val_loss: 0.0374 - val_accuracy: 0.9898
# Epoch 159/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0624 - accuracy: 0.9757
# Epoch 00159: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0602 - accuracy: 0.9769 - val_loss: 0.0450 - val_accuracy: 0.9796
# Epoch 160/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0602 - accuracy: 0.9730
# Epoch 00160: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 986us/sample - loss: 0.0589 - accuracy: 0.9744 - val_loss: 0.1015 - val_accuracy: 0.9694
# Epoch 161/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0389 - accuracy: 0.9892
# Epoch 00161: val_accuracy did not improve from 0.98980
# 390/390 [==============================] - 0s 997us/sample - loss: 0.0373 - accuracy: 0.9897 - val_loss: 0.0428 - val_accuracy: 0.9796
# Epoch 162/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.
500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0180 - accuracy: 0.9919
# Epoch 00496: val_accuracy did not improve from 1.00000
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0175 - accuracy: 0.9923 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 497/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0349 - accuracy: 0.9892
# Epoch 00497: val_accuracy did not improve from 1.00000
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0332 - accuracy: 0.9897 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 498/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0125 - accuracy: 0.9946
# Epoch 00498: val_accuracy did not improve from 1.00000
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0124 - accuracy: 0.9949 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 499/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0404 - accuracy: 0.9865
# Epoch 00499: val_accuracy did not improve from 1.00000
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0396 - accuracy: 0.9872 - val_loss: 0.0297 - val_accuracy: 0.9898
# Epoch 500/500
# 370/390 [===========================>..] - ETA: 0s - loss: 0.0239 - accuracy: 0.9919
# Epoch 00500: val_accuracy did not improve from 1.00000
# 390/390 [==============================] - 0s 1ms/sample - loss: 0.0258 - accuracy: 0.9897 - val_loss: 0.0198 - val_accuracy: 1.0000
# Training completed in time:  0:03:23.430737

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.9948718
# Testing Accuracy:  0.77272725

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.56      0.83      0.67        24
#    Pneumonia       0.92      0.75      0.83        64
#
#     accuracy                           0.77        88
#    macro avg       0.74      0.79      0.75        88
# weighted avg       0.82      0.77      0.78        88

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[20  4]
#  [16 48]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])
