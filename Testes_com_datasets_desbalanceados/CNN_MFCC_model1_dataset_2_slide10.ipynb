# %% [markdown]
# # Rede CNN - Modelo 1
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - Dataset 2 - slide10

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP_TRAIN = 'slide10'
GROUP_TEST = 'slide10'
DATASET = 'dataset_2'
DURATION = 10
SIZE = 431
CSV_TRAIN = 'train2.csv'
CSV_TEST = 'test2.csv'
MODEL_NAME = f'CNN1_{DATASET}_{GROUP_TRAIN}'

# %%
train_file_paths = glob.glob(f'../datasets/{DATASET}/{GROUP_TRAIN}/train/**/*.wav', recursive=True)
train_file_names = [os.path.splitext(os.path.basename(p))[0] for p in train_file_paths]

test_file_paths = glob.glob(f'../datasets/{DATASET}/{GROUP_TEST}/test/**/*.wav', recursive=True)
test_file_names = [os.path.splitext(os.path.basename(p))[0] for p in test_file_paths]

# %%
train_p_id_in_file = [] # patient IDs corresponding to each file
test_p_id_in_file = [] # patient IDs corresponding to each file
for name in train_file_names:
    train_p_id_in_file.append(int(name[:3]))

for name in test_file_names:
    test_p_id_in_file.append(int(name[:3]))

train_p_id_in_file = np.array(train_p_id_in_file)
test_p_id_in_file = np.array(test_p_id_in_file)

# %%
max_pad_len = SIZE

os.makedirs("features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=DURATION) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
train_p_diag = pd.read_csv(f"../Respiratory_Sound_Database/Respiratory_Sound_Database_Pneumo_Healthy_Only/{CSV_TRAIN}", header=None) # patient diagnosis file
test_p_diag = pd.read_csv(f"../Respiratory_Sound_Database/Respiratory_Sound_Database_Pneumo_Healthy_Only/{CSV_TEST}", header=None) # patient diagnosis file
train_p_diag.head(5)
# Out:
#      0        1
# 0  123  Healthy
# 1  125  Healthy
# 2  126  Healthy
# 3  127  Healthy
# 4  136  Healthy

# %%
train_labels = np.array([train_p_diag[train_p_diag[0] == x][1].values[0] for x in train_p_id_in_file]) 
test_labels = np.array([test_p_diag[test_p_diag[0] == x][1].values[0] for x in test_p_id_in_file])

# %%
train_features = [] 
test_features = []

for file_name in train_file_paths:
    data = extract_features(file_name)
    train_features.append(data)

for file_name in test_file_paths:
    data = extract_features(file_name)
    test_features.append(data)

print('Finished feature extraction from ', (len(train_features)+len(train_features)), ' files')
train_features = np.array(train_features)
test_features = np.array(test_features)
# Out:
# Finished feature extraction from  896  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(train_features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
np.unique(train_labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
unique_elements, counts_elements = np.unique(train_labels, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))

unique_elements_test, counts_elements_test = np.unique(test_labels, return_counts=True)
print(np.asarray((unique_elements_test, counts_elements_test)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['256' '192']]
# [['Healthy' 'Pneumonia']
#  ['24' '104']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
le.fit(train_labels)
train_labels_cat = to_categorical(le.transform(train_labels)) 
test_labels_cat = to_categorical(le.transform(test_labels))

# %%
train_features.shape
# Out:
# (448, 40, 431)

# %%
input_dim = train_features.shape[1]*train_features.shape[2]

# %%
train_features = np.reshape(train_features, (*train_features.shape,1)) 
print(train_features.shape, train_labels_cat.shape)
test_features = np.reshape(test_features, (*test_features.shape,1)) 
print(test_features.shape, test_labels_cat.shape)
# Out:
# (448, 40, 431, 1) (448, 2)
# (128, 40, 431, 1) (128, 2)

# %%
# train test split
x_train, x_val, y_train, y_val = train_test_split(train_features, train_labels_cat, test_size=0.2, random_state = 42)
x_test, y_test = test_features, test_labels_cat

# %% [markdown]
# **CNN model architecture**

# %%
num_labels = train_labels_cat.shape[1]

num_rows = 40
num_columns = SIZE
num_channels = 1

filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 430, 16)       80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 215, 16)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 215, 16)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 214, 32)       2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 107, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 107, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 106, 64)        8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 53, 64)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 53, 64)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 52, 128)        32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 26, 128)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 26, 128)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 258
# =================================================================
# Total params: 43,570
# Trainable params: 43,570
# Non-trainable params: 0
# _________________________________________________________________
# 128/128 [==============================] - 1s 8ms/sample - loss: 2.0692 - accuracy: 0.8125
# Pre-training accuracy: 81.2500%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 500
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/' + MODEL_NAME + '_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_val, y_val), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 358 samples, validate on 90 samples
# Epoch 1/500
# 310/358 [========================>.....] - ETA: 0s - loss: 1.8449 - accuracy: 0.6097
# Epoch 00001: val_accuracy improved from -inf to 0.65556, saving model to models/CNN1_dataset_2_slide10_01.h5
# 358/358 [==============================] - 1s 3ms/sample - loss: 1.6994 - accuracy: 0.6257 - val_loss: 0.6925 - val_accuracy: 0.6556
# Epoch 2/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0.8534 - accuracy: 0.6355
# Epoch 00002: val_accuracy improved from 0.65556 to 0.68889, saving model to models/CNN1_dataset_2_slide10_02.h5
# 358/358 [==============================] - 0s 1ms/sample - loss: 0.7964 - accuracy: 0.6620 - val_loss: 0.5329 - val_accuracy: 0.6889
# Epoch 3/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0.4227 - accuracy: 0.8129
# Epoch 00003: val_accuracy improved from 0.68889 to 0.80000, saving model to models/CNN1_dataset_2_slide10_03.h5
# 358/358 [==============================] - 0s 1ms/sample - loss: 0.4269 - accuracy: 0.8073 - val_loss: 0.4116 - val_accuracy: 0.8000
# Epoch 4/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0.4851 - accuracy: 0.7806
# Epoch 00004: val_accuracy improved from 0.80000 to 0.81111, saving model to models/CNN1_dataset_2_slide10_04.h5
# 358/358 [==============================] - 0s 1ms/sample - loss: 0.4449 - accuracy: 0.8045 - val_loss: 0.4023 - val_accuracy: 0.8111
# Epoch 5/500
# 300/358 [========================>.....] - ETA: 0s - loss: 0.3789 - accuracy: 0.8433
# Epoch 00005: val_accuracy did not improve from 0.81111
# 358/358 [==============================] - 0s 991us/sample - loss: 0.4020 - accuracy: 0.8268 - val_loss: 0.3673 - val_accuracy: 0.8111
# Epoch 6/500
# 350/358 [============================>.] - ETA: 0s - loss: 0.3070 - accuracy: 0.8571
# Epoch 00006: val_accuracy improved from 0.81111 to 0.90000, saving model to models/CNN1_dataset_2_slide10_06.h5
# 358/358 [==============================] - 0s 1ms/sample - loss: 0.3053 - accuracy: 0.8603 - val_loss: 0.3819 - val_accuracy: 0.9000
# Epoch 7/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0.2172 - accuracy: 0.9194
# Epoch 00007: val_accuracy did not improve from 0.90000
# 358/358 [==============================] - 0s 999us/sample - loss: 0.2485 - accuracy: 0.9022 - val_loss: 0.3384 - val_accuracy: 0.9000
# Epoch 8/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0.3084 - accuracy: 0.8871
# Epoch 00008: val_accuracy did not improve from 0.90000
# 358/358 [==============================] - 0s 987us/sample - loss: 0.3382 - accuracy: 0.8631 - val_loss: 0.2825 - val_accuracy: 0.8556
# Epoch 9/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0.2666 - accuracy: 0.8935
# Epoch 00009: val_accuracy did not improve from 0.90000
# 358/358 [==============================] - 0s 991us/sample - loss: 0.2687 - accuracy: 0.8911 - val_loss: 0.3742 - val_accuracy: 0.8556
# Epoch 10/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0.2041 - accuracy: 0.9000
# Epoch 00010: val_accuracy did not improve from 0.90000
# 358/358 [==============================] - 0s 986us/sample - loss: 0.2028 - accuracy: 0.8994 - val_loss: 0.4995 - val_accuracy: 0.8000
# Epoch 11/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0.1893 - accuracy: 0.9323
# Epoch 00011: val_accuracy did not improve from 0.90000
# 358/358 [==============================] - 0s 987us/sample - loss: 0.1853 - accuracy: 0.9330 - val_loss: 0.5604 - val_accuracy: 0.7111
# Epoch 12/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0.2501 - accuracy: 0.8742
# Epoch 00012: val_accuracy improved from 0.90000 to 0.92222, saving model to models/CNN1_dataset_2_slide10_12.h5
# 358/358 [==============================] - 0s 1ms/sample - loss: 0.2450 - accuracy: 0.8771 - val_loss: 0.2163 - val_accuracy: 0.9222
# Epoch 13/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0.2809 - accuracy: 0.8774
# Epoch 00013: val_accuracy did not improve from 0.92222
# 358/358 [==============================] - 0s 1ms/sample - loss: 0.2688 - accuracy: 0.8827 - val_loss: 0.4743 - val_accuracy: 0.7111
# Epoch 14/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0.1711 - accuracy: 0.9290
# Epoch 00014: val_accuracy did not improve from 0.92222
# 358/358 [==============================] - 0s 992us/sample - loss: 0.1642 - accuracy: 0.9302 - val_loss: 0.2452 - val_accuracy: 0.9000
# Epoch 15/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0.1068 - accuracy: 0.9742
# Epoch 00015: val_accuracy did not improve from 0.92222
# 358/358 [==============================] - 0s 987us/sample - loss: 0.1151 - accuracy: 0.9721 - val_loss: 0.1925 - val_accuracy: 0.9111
# Epoch 16/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0.1671 - accuracy: 0.9258
# Epoch 00016: val_accuracy improved from 0.92222 to 0.98889, saving model to models/CNN1_dataset_2_slide10_16.h5
# 358/358 [==============================] - 0s 1ms/sample - loss: 0.1504 - accuracy: 0.9330 - val_loss: 0.1162 - val_accuracy: 0.9889
# Epoch 17/500
# 350/358 [============================>.] - ETA: 0s - loss: 0.1219 - accuracy: 0.9486
# Epoch 00017: val_accuracy did not improve from 0.98889
# 358/358 [==============================] - 0s 1ms/sample - loss: 0.1214 - accuracy: 0.9497 - val_loss: 0.1901 - val_accuracy: 0.9222
# Epoch 18/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0.1127 - accuracy: 0.9516
# Epoch 00018: val_accuracy did not improve from 0.98889
# 358/358 [==============================] - 0s 993us/sample - loss: 0.1068 - accuracy: 0.9553 - val_loss: 0.1819 - val_accuracy: 0.9000
# Epoch 19/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0.0872 - accuracy: 0.9645
# Epoch 00019: val_accuracy did not improve from 0.98889
# 358/358 [==============================] - 0s 979us/sample - loss: 0.0935 - accuracy: 0.9581 - val_loss: 0.2053 - val_accuracy: 0.9111
# Epoch 20/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0
val_accuracy did not improve from 1.00000
# 358/358 [==============================] - 0s 1ms/sample - loss: 0.0143 - accuracy: 0.9944 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 120/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0.0351 - accuracy: 0.9871
# Epoch 00120: val_accuracy did not improve from 1.00000
# 358/358 [==============================] - 0s 1ms/sample - loss: 0.0713 - accuracy: 0.9749 - val_loss: 0.8422 - val_accuracy: 0.7889
# Epoch 121/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0.3729 - accuracy: 0.9065
# Epoch 00121: val_accuracy did not improve from 1.00000
# 358/358 [==============================] - 0s 1ms/sample - loss: 0.3632 - accuracy: 0.9022 - val_loss: 0.1558 - val_accuracy: 0.9111
# Epoch 122/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0.0709 - accuracy: 0.9806
# Epoch 00122: val_accuracy did not improve from 1.00000
# 358/358 [==============================] - 0s 1ms/sample - loss: 0.0624 - accuracy: 0.9832 - val_loss: 0.0208 - val_accuracy: 1.0000
# Epoch 123/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0.0076 - accuracy: 1.0000
# Epoch 00123: val_accuracy did not improve from 1.00000
# 358/358 [==============================] - 0s 994us/sample - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 1.0000
# Epoch 124/500
# 300/358 [========================>.....] - ETA: 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 00124: val_accuracy did not improve from 1.00000
# 358/358 [==============================] - 0s 1ms/sample - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 125/500
# 350/358 [============================>.] - ETA: 0s - loss: 0.0113 - accuracy: 0.9971
# Epoch 00125: val_accuracy did not improve from 1.00000
# 358/358 [==============================] - 0s 1ms/sample - loss: 0.0111 - accuracy: 0.9972 - val_loss: 0.0410 - val_accuracy: 1.0000
# Epoch 126/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 00126: val_accuracy did not improve from 1.00000
# 358/358 [==============================] - 0s 1ms/sample - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 127/500
# 300/358 [========================>.....] - ETA: 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 00127: val_accuracy did not improve from 1.00000
# 358/358 [==============================] - 0s 1ms/sample - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0138 - val_accuracy: 1.0000
# Epoch 128/500
# 310/358 [========================>.....] - ETA: 0s - loss: 8.9522e-04 - accuracy: 1.0000
# Epoch 00128: val_accuracy did not improve from 1.00000
# 358/358 [==============================] - 0s 1ms/sample - loss: 9.0738e-04 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 129/500
# 310/358 [========================>.....] - ETA: 0s - loss: 8.9835e-04 - accuracy: 1.0000
# Epoch 00129: val_accuracy did not improve from 1.00000
# 358/358 [==============================] - 0s 996us/sample - loss: 8.7272e-04 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 130/500
# 310/358 [========================>.....] - ETA: 0s - loss: 7.6477e-04 - accuracy: 1.0000
# Epoch 00130: val_accuracy did not improve from 1.00000
# 358/358 [==============================] - 0s 1ms/sample - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 131/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000
# Epoch 00131: val_accuracy did not improve from 1.00000
# 358/358 [==============================] - 0s 999us/sample - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 132/500
# 300/358 [========================>.....] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00132: val_accuracy did not improve from 1.00000
# 358/358 [==============================] - 0s 1ms/sample - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 1.0000
# Epoch 133/500
# 350/358 [============================>.] - ETA: 0s - loss: 5.9183e-04 - accuracy: 1.0000
# Epoch 00133: val_accuracy did not improve from 1.00000
# 358/358 [==============================] - 0s 1ms/sample - loss: 5.8470e-04 - accuracy: 1.0000 - val_loss: 0.0108 - val_accuracy: 1.0000
# Epoch 134/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 00134: val_accuracy did not improve from 1.00000
# 358/358 [==============================] - 0s 1ms/sample - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 135/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0.0196 - accuracy: 0.9935
# Epoch 00135: val_accuracy did not improve from 1.00000
# 358/358 [==============================] - 0s 990us/sample - loss: 0.0205 - accuracy: 0.9944 - val_loss: 0.0347 - val_accuracy: 1.0000
# Epoch 136/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0.0079 - accuracy: 1.0000
# Epoch 00136: val_accuracy did not improve from 1.00000
# 358/358 [==============================] - 0s 997us/sample - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.0192 - val_accuracy: 1.0000
# Epoch 137/500
# 300/358 [========================>.....] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000
# Epoch 00137: val_accuracy did not improve from 1.00000
# 358/358 [==============================] - 0s 1ms/sample - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0222 - val_accuracy: 1.0000
# Epoch 138/500
# 310/358 [========================>.....] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 00138: val_accuracy did not improve from 1.00000
# 358/358 [==============================] - 0s 999us/sample - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.
val_accuracy did not improve from 1.00000
# 358/358 [==============================] - 0s 1ms/sample - loss: 6.1108e-06 - accuracy: 1.0000 - val_loss: 8.3654e-04 - val_accuracy: 1.0000
# Epoch 499/500
# 310/358 [========================>.....] - ETA: 0s - loss: 5.2405e-06 - accuracy: 1.0000
# Epoch 00499: val_accuracy did not improve from 1.00000
# 358/358 [==============================] - 0s 1ms/sample - loss: 4.9951e-06 - accuracy: 1.0000 - val_loss: 8.3555e-04 - val_accuracy: 1.0000
# Epoch 500/500
# 310/358 [========================>.....] - ETA: 0s - loss: 1.1864e-05 - accuracy: 1.0000
# Epoch 00500: val_accuracy did not improve from 1.00000
# 358/358 [==============================] - 0s 1ms/sample - loss: 1.0352e-05 - accuracy: 1.0000 - val_loss: 8.4268e-04 - val_accuracy: 1.0000
# Training completed in time:  0:03:02.516425

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  1.0
# Testing Accuracy:  0.4453125

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.20      0.67      0.31        24
#    Pneumonia       0.84      0.39      0.54       104
#
#     accuracy                           0.45       128
#    macro avg       0.52      0.53      0.42       128
# weighted avg       0.72      0.45      0.49       128

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[16  8]
#  [63 41]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])
