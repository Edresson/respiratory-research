# %% [markdown]
# # Rede CNN - Modelo 1
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - Dataset 2 - no_augment_10

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP_TRAIN = 'no_augment_10'
GROUP_TEST = 'no_augment_10'
DATASET = 'dataset_2'
DURATION = 10
SIZE = 431
CSV_TRAIN = 'train2.csv'
CSV_TEST = 'test2.csv'
MODEL_NAME = f'CNN1_{DATASET}_{GROUP_TRAIN}'

# %%
train_file_paths = glob.glob(f'../datasets/{DATASET}/{GROUP_TRAIN}/train/**/*.wav', recursive=True)
train_file_names = [os.path.splitext(os.path.basename(p))[0] for p in train_file_paths]

test_file_paths = glob.glob(f'../datasets/{DATASET}/{GROUP_TEST}/test/**/*.wav', recursive=True)
test_file_names = [os.path.splitext(os.path.basename(p))[0] for p in test_file_paths]

# %%
train_p_id_in_file = [] # patient IDs corresponding to each file
test_p_id_in_file = [] # patient IDs corresponding to each file
for name in train_file_names:
    train_p_id_in_file.append(int(name[:3]))

for name in test_file_names:
    test_p_id_in_file.append(int(name[:3]))

train_p_id_in_file = np.array(train_p_id_in_file)
test_p_id_in_file = np.array(test_p_id_in_file)

# %%
max_pad_len = SIZE

os.makedirs("features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=DURATION) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
train_p_diag = pd.read_csv(f"../Respiratory_Sound_Database/Respiratory_Sound_Database_Pneumo_Healthy_Only/{CSV_TRAIN}", header=None) # patient diagnosis file
test_p_diag = pd.read_csv(f"../Respiratory_Sound_Database/Respiratory_Sound_Database_Pneumo_Healthy_Only/{CSV_TEST}", header=None) # patient diagnosis file
train_p_diag.head(5)
# Out:
#      0        1
# 0  123  Healthy
# 1  125  Healthy
# 2  126  Healthy
# 3  127  Healthy
# 4  136  Healthy

# %%
train_labels = np.array([train_p_diag[train_p_diag[0] == x][1].values[0] for x in train_p_id_in_file]) 
test_labels = np.array([test_p_diag[test_p_diag[0] == x][1].values[0] for x in test_p_id_in_file])

# %%
train_features = [] 
test_features = []

for file_name in train_file_paths:
    data = extract_features(file_name)
    train_features.append(data)

for file_name in test_file_paths:
    data = extract_features(file_name)
    test_features.append(data)

print('Finished feature extraction from ', (len(train_features)+len(train_features)), ' files')
train_features = np.array(train_features)
test_features = np.array(test_features)
# Out:
# Finished feature extraction from  112  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(train_features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
np.unique(train_labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
unique_elements, counts_elements = np.unique(train_labels, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))

unique_elements_test, counts_elements_test = np.unique(test_labels, return_counts=True)
print(np.asarray((unique_elements_test, counts_elements_test)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['32' '24']]
# [['Healthy' 'Pneumonia']
#  ['3' '13']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
le.fit(train_labels)
train_labels_cat = to_categorical(le.transform(train_labels)) 
test_labels_cat = to_categorical(le.transform(test_labels))

# %%
train_features.shape
# Out:
# (56, 40, 431)

# %%
input_dim = train_features.shape[1]*train_features.shape[2]

# %%
train_features = np.reshape(train_features, (*train_features.shape,1)) 
print(train_features.shape, train_labels_cat.shape)
test_features = np.reshape(test_features, (*test_features.shape,1)) 
print(test_features.shape, test_labels_cat.shape)
# Out:
# (56, 40, 431, 1) (56, 2)
# (16, 40, 431, 1) (16, 2)

# %%
# train test split
x_train, x_val, y_train, y_val = train_test_split(train_features, train_labels_cat, test_size=0.2, random_state = 42)
x_test, y_test = test_features, test_labels_cat

# %% [markdown]
# **CNN model architecture**

# %%
num_labels = train_labels_cat.shape[1]

num_rows = 40
num_columns = SIZE
num_channels = 1

filter_size = 2


# Construct model 
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 430, 16)       80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 215, 16)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 215, 16)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 214, 32)       2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 107, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 107, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 106, 64)        8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 53, 64)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 53, 64)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 52, 128)        32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 26, 128)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 26, 128)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 258
# =================================================================
# Total params: 43,570
# Trainable params: 43,570
# Non-trainable params: 0
# _________________________________________________________________
# 16/16 [==============================] - 1s 60ms/sample - loss: 5.0169 - accuracy: 0.8125
# Pre-training accuracy: 81.2500%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 500
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/' + MODEL_NAME + '_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_val, y_val), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 44 samples, validate on 12 samples
# Epoch 1/500
# 10/44 [=====>........................] - ETA: 2s - loss: 23.5928 - accuracy: 0.6000
# Epoch 00001: val_accuracy improved from -inf to 0.58333, saving model to models/CNN2_dataset_2_no_augment_10_01.h5
# 44/44 [==============================] - 1s 23ms/sample - loss: 11.9148 - accuracy: 0.6136 - val_loss: 3.9996 - val_accuracy: 0.5833
# Epoch 2/500
# 10/44 [=====>........................] - ETA: 0s - loss: 8.8411 - accuracy: 0.6000
# Epoch 00002: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 6.0099 - accuracy: 0.5000 - val_loss: 3.6400 - val_accuracy: 0.4167
# Epoch 3/500
# 10/44 [=====>........................] - ETA: 0s - loss: 8.6000 - accuracy: 0.3000
# Epoch 00003: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 3.8303 - accuracy: 0.4773 - val_loss: 1.5208 - val_accuracy: 0.5833
# Epoch 4/500
# 10/44 [=====>........................] - ETA: 0s - loss: 2.6482 - accuracy: 0.7000
# Epoch 00004: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 3.0967 - accuracy: 0.5682 - val_loss: 1.0919 - val_accuracy: 0.4167
# Epoch 5/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5791 - accuracy: 0.7000
# Epoch 00005: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 2.1809 - accuracy: 0.4773 - val_loss: 1.4964 - val_accuracy: 0.5000
# Epoch 6/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.8942 - accuracy: 0.4000
# Epoch 00006: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 1.0244 - accuracy: 0.5909 - val_loss: 0.8715 - val_accuracy: 0.2500
# Epoch 7/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.8408 - accuracy: 0.8000
# Epoch 00007: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 1.1869 - accuracy: 0.5682 - val_loss: 1.0069 - val_accuracy: 0.4167
# Epoch 8/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4913 - accuracy: 0.7000
# Epoch 00008: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.8240 - accuracy: 0.6136 - val_loss: 0.9350 - val_accuracy: 0.4167
# Epoch 9/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.9516 - accuracy: 0.4000
# Epoch 00009: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.7263 - accuracy: 0.5682 - val_loss: 0.8166 - val_accuracy: 0.3333
# Epoch 10/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.8494 - accuracy: 0.6000
# Epoch 00010: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6275 - accuracy: 0.7727 - val_loss: 0.8644 - val_accuracy: 0.5000
# Epoch 11/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6169 - accuracy: 0.5000
# Epoch 00011: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6441 - accuracy: 0.6136 - val_loss: 0.8411 - val_accuracy: 0.4167
# Epoch 12/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.9487 - accuracy: 0.6000
# Epoch 00012: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6474 - accuracy: 0.7045 - val_loss: 0.8010 - val_accuracy: 0.3333
# Epoch 13/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5734 - accuracy: 0.7000
# Epoch 00013: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5734 - accuracy: 0.7045 - val_loss: 0.7938 - val_accuracy: 0.3333
# Epoch 14/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5763 - accuracy: 0.8000
# Epoch 00014: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4710 - accuracy: 0.8182 - val_loss: 0.8168 - val_accuracy: 0.5000
# Epoch 15/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3632 - accuracy: 0.9000
# Epoch 00015: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6844 - accuracy: 0.6818 - val_loss: 0.7515 - val_accuracy: 0.3333
# Epoch 16/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4105 - accuracy: 0.9000
# Epoch 00016: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5173 - accuracy: 0.7500 - val_loss: 0.7972 - val_accuracy: 0.5833
# Epoch 17/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.8275 - accuracy: 0.7000
# Epoch 00017: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5478 - accuracy: 0.7045 - val_loss: 0.7353 - val_accuracy: 0.3333
# Epoch 18/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4709 - accuracy: 0.9000
# Epoch 00018: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5169 - accuracy: 0.7500 - val_loss: 0.7534 - val_accuracy: 0.5000
# Epoch 19/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6142 - accuracy: 0.5000
# Epoch 00019: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5005 - accuracy: 0.6818 - val_loss: 0.7255 - val_accuracy: 0.3333
# Epoch 20/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3219 - accuracy: 0.7000
# Epoch 00020: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4504 - accuracy: 0.7500 - val_loss: 0.7342 - val_accuracy: 0.4167
# Epoch 21/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5162 - accuracy: 0.7000
# Epoch 00021: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4614 - accuracy: 0.7727 - val_loss: 0.7297 - val_accuracy: 0.3333
# Epoch 22/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3886 - accuracy: 0.9000
# Epoch 00022: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4569 - accuracy: 0.7955 - val_loss: 0.7394 - val_accuracy: 0.3333
# Epoch 23/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4108 - accuracy: 0.8000
# Epoch 00023: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4834 - accuracy: 0.7273 - val_loss: 0.7443 - val_accuracy: 0.3333
# Epoch 24/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2966 - accuracy: 1.0000
# Epoch 00024: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3352 - accuracy: 0.9318 - val_loss: 0.7532 - val_accuracy: 0.4167
# Epoch 25/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2040 - accuracy: 0.9000
# Epoch 00025: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3844 - accuracy: 0.7955 - val_loss: 0.7363 - val_accuracy: 0.3333
# Epoch 26/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3842 - accuracy: 0.8000
# Epoch 00026: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4056 - accuracy: 0.7955 - val_loss: 0.8354 - val_accuracy: 0.5833
# Epoch 27/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4133 - accuracy: 0.8000
# Epoch 00027: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5148 - accuracy: 0.7500 - val_loss: 0.7293 - val_accuracy: 0.3333
# Epoch 28/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3279 - accuracy: 0.7000
# Epoch 00028: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5658 - accuracy: 0.6818 - val_loss: 0.8189 - val_accuracy: 0.5833
# Epoch 29/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3112 - accuracy: 0.8000
# Epoch 00029: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5984 - accuracy: 0.6818 - val_loss: 0.7414 - val_accuracy: 0.5000
# Epoch 30/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4885 - accuracy: 0.9000
# Epoch 00030: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5071 - accuracy: 0.7727 - val_loss: 0.6985 - val_accuracy: 0.4167
# Epoch 31/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4109 - accuracy: 0.7000
# Epoch 00031: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3576 - accuracy: 0.8182 - val_loss: 0.7525 - val_accuracy: 0.5833
# Epoch 32/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2448 - accuracy: 0.9000
# Epoch 00032: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2927 - accuracy: 0.9091 - val_loss: 0.6384 - val_accuracy: 0.5000
# Epoch 33/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4689 - accuracy: 0.8000
# Epoch 00033: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4063 - accuracy: 0.8409 - val_loss: 0.6557 - val_accuracy: 0.5000
# Epoch 34/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3562 - accuracy: 0.8000
# Epoch 00034: val_accuracy improved from 0.58333 to 0.66667, saving model to models/CNN2_dataset_2_no_augment_10_34.h5
# 44/44 [==============================] - 0s 2ms/sample - loss: 0.3519 - accuracy: 0.7955 - val_loss: 0.6442 - val_accuracy: 0.6667
# Epoch 35/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4584 - accuracy: 0.7000
# Epoch 00035: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3507 - accuracy: 0.8182 - val_loss: 0.6951 - val_accuracy: 0.6667
# Epoch 36/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3903 - accuracy: 0.8000
# Epoch 00036: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3371 - accuracy: 0.8636 - val_loss: 0.6422 - val_accuracy: 0.6667
# Epoch 37/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2065 - accuracy: 1.0000
# Epoch 00037: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3312 - accuracy: 0.8636 - val_loss: 0.6316 - val_accuracy: 0.6667
# Epoch 38/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2751 - accuracy: 0.8000
# Epoch 00038: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3986 - accuracy: 0.7727 - val_loss: 0.6736 - val_accuracy: 0.6667
# Epoch 39/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2644 - accuracy: 1.0000
# Epoch 00039: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3594 - accuracy: 0.8636 - val_loss: 0.6243 - val_accuracy: 0.6667
# Epoch 40/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1982 - accuracy: 0.9000
# Epoch 00040: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2860 - accuracy: 0.8636 - val_loss: 0.6047 - val_accuracy: 0.6667
# Epoch 41/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3169 - accuracy: 0.8000
# Epoch 00041: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2790 - accuracy: 0.8636 - val_loss: 0.6098 - val_accuracy: 0.6667
# Epoch 42/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0845 - accuracy: 1.0000
# Epoch 00042: val_accuracy improved from 0.66667 to 0.83333, saving model to models/CNN2_dataset_2_no_augment_10_42.h5
# 44/44 [==============================] - 0s 2ms/sample - loss: 0.3745 - accuracy: 0.8864 - val_loss: 0.5233 - val_accuracy: 0.8333
# Epoch 43/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3991 - accuracy: 0.7000
# Epoch 00043: val_accuracy did not improve from 0.83333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3464 - accuracy: 0.7727 - val_loss: 0.5985 - val_accuracy: 0.7500
# Epoch 44/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2017 - accuracy: 0.9000
# Epoch 00044: val_accuracy improved from 0.83333 to 0.91667, saving model to models/CNN2_dataset_2_no_augment_10_44.h5
# 44/44 [==============================] - 0s 2ms/sample - loss: 0.3485 - accuracy: 0.8636 - val_loss: 0.5068 - val_accuracy: 0.9167
# Epoch 45/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3079 - accuracy: 0.8000
# Epoch 00045: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5132 - accuracy: 0.7273 - val_loss: 0.6004 - val_accuracy: 0.7500
# Epoch 46/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1983 - accuracy: 0.9000
# Epoch 00046: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5813 - accuracy: 0.7273 - val_loss: 0.5602 - val_accuracy: 0.8333
# Epoch 47/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5519 - accuracy: 0.8000
# Epoch 00047: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2804 - accuracy: 0.9091 - val_loss: 0.5043 - val_accuracy: 0.5833
# Epoch 48/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5874 - accuracy: 0.7000
# Epoch 00048: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4366 - accuracy: 0.7727 - val_loss: 0.5785 - val_accuracy: 0.8333
# Epoch 49/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1003 - accuracy: 1.0000
# Epoch 00049: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3121 - accuracy: 0.8864 - val_loss: 0.4403 - val_accuracy: 0.7500
# Epoch 50/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1488 - accuracy: 0.9000
# Epoch 00050: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3749 - accuracy: 0.7727 - val_loss: 0.4280 - val_accuracy: 0.7500
# Epoch 51/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3086 - accuracy: 0.9000
# Epoch 00051: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2482 - accuracy: 0.9091 - val_loss: 0.4165 - val_accuracy: 0.9167
# Epoch 52/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1240 - accuracy: 1.0000
# Epoch 00052: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2829 - accuracy: 0.8864 - val_loss: 0.4101 - val_accuracy: 0.9167
# Epoch 53/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0490 - accuracy: 1.0000
# Epoch 00053: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2634 - accuracy: 0.8636 - val_loss: 0.4140 - val_accuracy: 0.9167
# Epoch 54/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2514 - accuracy: 0.9000
# Epoch 00054: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2336 - accuracy: 0.9318 - val_loss: 0.3972 - val_accuracy: 0.9167
# Epoch 55/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3595 - accuracy: 0.9000
# Epoch 00055: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1667 - accuracy: 0.9545 - val_loss: 0.3919 - val_accuracy: 0.7500
# Epoch 56/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3167 - accuracy: 0.9000
# Epoch 00056: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2913 - accuracy: 0.8636 - val_loss: 0.3898 - val_accuracy: 0.9167
# Epoch 57/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0710 - accuracy: 1.0000
# Epoch 00057: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4395 - accuracy: 0.7955 - val_loss: 0.3594 - val_accuracy: 0.9167
# Epoch 58/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0945 - accuracy: 1.0000
# Epoch 00058: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4117 - accuracy: 0.8636 - val_loss: 0.4262 - val_accuracy: 0.6667
# Epoch 59/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1916 - accuracy: 0.9000
# Epoch 00059: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2363 - accuracy: 0.8636 - val_loss: 0.4181 - val_accuracy: 0.9167
# Epoch 60/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3015 - accuracy: 0.9000
# Epoch 00060: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3113 - accuracy: 0.9091 - val_loss: 0.3908 - val_accuracy: 0.8333
# Epoch 61/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0931 - accuracy: 1.0000
# Epoch 00061: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 2ms/sample - loss: 0.2333 - accuracy: 0.8864 - val_loss: 0.3901 - val_accuracy: 0.8333
# Epoch 62/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1872 - accuracy: 0.9000
# Epoch 00062: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3060 - accuracy: 0.8864 - val_loss: 0.3675 - val_accuracy: 0.9167
# Epoch 63/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1813 - accuracy: 0.9000
# Epoch 00063: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2402 - accuracy: 0.8864 - val_loss: 0.3631 - val_accuracy: 0.8333
# Epoch 64/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1640 - accuracy: 1.0000
# Epoch 00064: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1811 - accuracy: 0.9545 - val_loss: 0.3545 - val_accuracy: 0.9167
# Epoch 65/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3499 - accuracy: 0.7000
# Epoch 00065: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2533 - accuracy: 0.8636 - val_loss: 0.3455 - val_accuracy: 0.9167
# Epoch 66/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0684 - accuracy: 1.0000
# Epoch 00066: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1724 - accuracy: 0.9545 - val_loss: 0.3498 - val_accuracy: 0.8333
# Epoch 67/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3944 - accuracy: 0.9000
# Epoch 00067: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1921 - accuracy: 0.9318 - val_loss: 0.3420 - val_accuracy: 0.9167
# Epoch 68/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1250 - accuracy: 1.0000
# Epoch 00068: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1578 - accuracy: 0.9545 - val_loss: 0.3306 - val_accuracy: 0.9167
# Epoch 69/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3236 - accuracy: 0.9000
# Epoch 00069: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2107 - accuracy: 0.9091 - val_loss: 0.3101 - val_accuracy: 0.9167
# Epoch 70/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0720 - accuracy: 1.0000
# Epoch 00070: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1813 - accuracy: 0.9091 - val_loss: 0.2843 - val_accuracy: 0.9167
# Epoch 71/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0660 - accuracy: 1.0000
# Epoch 00071: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2335 - accuracy: 0.8864 - val_loss: 0.2917 - val_accuracy: 0.9167
# Epoch 72/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2666 - accuracy: 0.9000
# Epoch 00072: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1253 - accuracy: 0.9773 - val_loss: 0.2735 - val_accuracy: 0.9167
# Epoch 73/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1324 - accuracy: 1.0000
# Epoch 00073: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2035 - accuracy: 0.9318 - val_loss: 0.2722 - val_accuracy: 0.9167
# Epoch 74/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0758 - accuracy: 1.0000
# Epoch 00074: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1097 - accuracy: 0.9773 - val_loss: 0.2650 - val_accuracy: 0.9167
# Epoch 75/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0732 - accuracy: 1.0000
# Epoch 00075: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1277 - accuracy: 0.9773 - val_loss: 0.2702 - val_accuracy: 0.9167
# Epoch 76/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0530 - accuracy: 1.0000
# Epoch 00076: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1943 - accuracy: 0.9318 - val_loss: 0.2757 - val_accuracy: 0.9167
# Epoch 77/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2436 - accuracy: 0.9000
# Epoch 00077: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1523 - accuracy: 0.9545 - val_loss: 0.2403 - val_accuracy: 0.9167
# Epoch 78/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2242 - accuracy: 0.8000
# Epoch 00078: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1617 - accuracy: 0.9318 - val_loss: 0.2713 - val_accuracy: 0.9167
# Epoch 79/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3229 - accuracy: 0.9000
# Epoch 00079: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1904 - accuracy: 0.9318 - val_loss: 0.2348 - val_accuracy: 0.9167
# Epoch 80/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3466 - accuracy: 0.9000
# Epoch 00080: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1536 - accuracy: 0.9545 - val_loss: 0.2306 - val_accuracy: 0.9167
# Epoch 81/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1085 - accuracy: 0.9000
# Epoch 00081: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1691 - accuracy: 0.9318 - val_loss: 0.2002 - val_accuracy: 0.9167
# Epoch 82/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2656 - accuracy: 0.9000
# Epoch 00082: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3723 - accuracy: 0.8182 - val_loss: 0.2382 - val_accuracy: 0.9167
# Epoch 83/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1722 - accuracy: 1.0000
# Epoch 00083: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2102 - accuracy: 0.9545 - val_loss: 0.4448 - val_accuracy: 0.9167
# Epoch 84/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2853 - accuracy: 0.9000
# Epoch 00084: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2710 - accuracy: 0.9091 - val_loss: 0.3253 - val_accuracy: 0.9167
# Epoch 85/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2155 - accuracy: 0.9000
# Epoch 00085: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1513 - accuracy: 0.9318 - val_loss: 0.3106 - val_accuracy: 0.9167
# Epoch 86/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1357 - accuracy: 0.9000
# Epoch 00086: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1718 - accuracy: 0.8864 - val_loss: 0.2905 - val_accuracy: 0.9167
# Epoch 87/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0547 - accuracy: 1.0000
# Epoch 00087: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1506 - accuracy: 0.9318 - val_loss: 0.2741 - val_accuracy: 0.9167
# Epoch 88/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2082 - accuracy: 0.9000
# Epoch 00088: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1713 - accuracy: 0.9318 - val_loss: 0.2385 - val_accuracy: 0.9167
# Epoch 89/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0276 - accuracy: 1.0000
# Epoch 00089: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1618 - accuracy: 0.9545 - val_loss: 0.2174 - val_accuracy: 0.9167
# Epoch 90/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0179 - accuracy: 1.0000
# Epoch 00090: val_accuracy did not improve from 0.91667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1028 - accuracy: 0.9545 - val_loss: 0.2074 - val_accuracy: 0.9167
# Epoch 91/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2634 - accuracy: 0.8000
# Epoch 00091: val_accuracy improved from 0.91667 to 1.00000, saving model to models/CNN2_dataset_2_no_augment_10_91.h5
# 44/44 [==============================] - 0s 2ms/sample - loss: 0.2088 - accuracy: 0.9091 - val_loss: 0.1628 - val_accuracy: 1.0000
# Epoch 92/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1003 - accuracy: 0.9000
# Epoch 00092: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1256 - accuracy: 0.9545 - val_loss: 0.1666 - val_accuracy: 0.9167
# Epoch 93/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2492 - accuracy: 0.8000
# Epoch 00093: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1867 - accuracy: 0.9091 - val_loss: 0.1288 - val_accuracy: 1.0000
# Epoch 94/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0847 - accuracy: 1.0000
# Epoch 00094: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1777 - accuracy: 0.9318 - val_loss: 0.1271 - val_accuracy: 1.0000
# Epoch 95/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0422 - accuracy: 1.0000
# Epoch 00095: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0782 - accuracy: 0.9773 - val_loss: 0.1348 - val_accuracy: 0.9167
# Epoch 96/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0492 - accuracy: 1.0000
# Epoch 00096: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1186 - accuracy: 0.9545 - val_loss: 0.1043 - val_accuracy: 1.0000
# Epoch 97/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1763 - accuracy: 0.9000
# Epoch 00097: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1420 - accuracy: 0.9318 - val_loss: 0.1008 - val_accuracy: 1.0000
# Epoch 98/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0718 - accuracy: 1.0000
# Epoch 00098: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1137 - accuracy: 0.9545 - val_loss: 0.0862 - val_accuracy: 1.0000
# Epoch 99/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0225 - accuracy: 1.0000
# Epoch 00099: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0910 - accuracy: 0.9545 - val_loss: 0.1175 - val_accuracy: 0.9167
# Epoch 100/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0401 - accuracy: 1.0000
# Epoch 00100: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1092 - accuracy: 0.9545 - val_loss: 0.1163 - val_accuracy: 1.0000
# Epoch 101/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1224 - accuracy: 0.9000
# Epoch 00101: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0762 - accuracy: 0.9545 - val_loss: 0.1181 - val_accuracy: 1.0000
# Epoch 102/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1832 - accuracy: 0.9000
# Epoch 00102: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1089 - accuracy: 0.9545 - val_loss: 0.1399 - val_accuracy: 0.9167
# Epoch 103/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0469 - accuracy: 1.0000
# Epoch 00103: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1048 - accuracy: 0.9545 - val_loss: 0.0982 - val_accuracy: 1.0000
# Epoch 104/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0681 - accuracy: 1.0000
# Epoch 00104: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0704 - accuracy: 0.9773 - val_loss: 0.0833 - val_accuracy: 1.0000
# Epoch 105/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0539 - accuracy: 1.0000
# Epoch 00105: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0589 - accuracy: 0.9773 - val_loss: 0.1040 - val_accuracy: 0.9167
# Epoch 106/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0683 - accuracy: 1.0000
# Epoch 00106: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1143 - accuracy: 0.9545 - val_loss: 0.0725 - val_accuracy: 1.0000
# Epoch 107/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0420 - accuracy: 1.0000
# Epoch 00107: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0936 - accuracy: 0.9773 - val_loss: 0.0918 - val_accuracy: 1.0000
# Epoch 108/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0091 - accuracy: 1.0000
# Epoch 00108: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1028 - accuracy: 0.9318 - val_loss: 0.1173 - val_accuracy: 0.9167
# Epoch 109/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0522 - accuracy: 1.0000
# Epoch 00109: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0551 - accuracy: 1.0000 - val_loss: 0.0976 - val_accuracy: 1.0000
# Epoch 110/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 00110: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1073 - accuracy: 0.9545 - val_loss: 0.0907 - val_accuracy: 1.0000
# Epoch 111/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0161 - accuracy: 1.0000
# Epoch 00111: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1159 - accuracy: 0.9318 - val_loss: 0.0875 - val_accuracy: 1.0000
# Epoch 112/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1366 - accuracy: 1.0000
# Epoch 00112: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0584 - accuracy: 1.0000 - val_loss: 0.0710 - val_accuracy: 1.0000
# Epoch 113/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0261 - accuracy: 1.0000
# Epoch 00113: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0576 - accuracy: 0.9773 - val_loss: 0.0772 - val_accuracy: 1.0000
# Epoch 114/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1183 - accuracy: 0.9000
# Epoch 00114: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 2ms/sample - loss: 0.0520 - accuracy: 0.9773 - val_loss: 0.0661 - val_accuracy: 1.0000
# Epoch 115/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0245 - accuracy: 1.0000
# Epoch 00115: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0758 - accuracy: 0.9773 - val_loss: 0.0572 - val_accuracy: 1.0000
# Epoch 116/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0180 - accuracy: 1.0000
# Epoch 00116: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0437 - accuracy: 0.9773 - val_loss: 0.0567 - val_accuracy: 1.0000
# Epoch 117/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 00117: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0531 - accuracy: 0.9773 - val_loss: 0.0588 - val_accuracy: 1.0000
# Epoch 118/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0090 - accuracy: 1.0000
# Epoch 00118: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1321 - accuracy: 0.9318 - val_loss: 0.0899 - val_accuracy: 0.9167
# Epoch 119/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1505 - accuracy: 1.0000
# Epoch 00119: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2705 - accuracy: 0.9091 - val_loss: 0.4016 - val_accuracy: 0.9167
# Epoch 120/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0644 - accuracy: 1.0000
# Epoch 00120: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0951 - accuracy: 0.9545 - val_loss: 0.3541 - val_accuracy: 0.8333
# Epoch 121/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0371 - accuracy: 1.0000
# Epoch 00121: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2392 - accuracy: 0.9091 - val_loss: 0.4216 - val_accuracy: 0.9167
# Epoch 122/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0098 - accuracy: 1.0000
# Epoch 00122: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2272 - accuracy: 0.9318 - val_loss: 0.3295 - val_accuracy: 0.9167
# Epoch 123/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1610 - accuracy: 0.9000
# Epoch 00123: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1293 - accuracy: 0.9091 - val_loss: 0.2452 - val_accuracy: 0.9167
# Epoch 124/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2366 - accuracy: 0.9000
# Epoch 00124: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1427 - accuracy: 0.9318 - val_loss: 0.2816 - val_accuracy: 0.9167
# Epoch 125/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1301 - accuracy: 0.9000
# Epoch 00125: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0904 - accuracy: 0.9318 - val_loss: 0.2133 - val_accuracy: 0.9167
# Epoch 126/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0462 - accuracy: 1.0000
# Epoch 00126: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0679 - accuracy: 0.9773 - val_loss: 0.1856 - val_accuracy: 0.9167
# Epoch 127/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0299 - accuracy: 1.0000
# Epoch 00127: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1027 - accuracy: 0.9773 - val_loss: 0.2151 - val_accuracy: 0.9167
# Epoch 128/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0264 - accuracy: 1.0000
# Epoch 00128: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0609 - accuracy: 0.9545 - val_loss: 0.1255 - val_accuracy: 0.9167
# Epoch 129/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0373 - accuracy: 1.0000
# Epoch 00129: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0762 - accuracy: 0.9773 - val_loss: 0.1093 - val_accuracy: 0.9167
# Epoch 130/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1903 - accuracy: 0.9000
# Epoch 00130: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0801 - accuracy: 0.9773 - val_loss: 0.1325 - val_accuracy: 0.9167
# Epoch 131/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1780 - accuracy: 0.9000
# Epoch 00131: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0737 - accuracy: 0.9773 - val_loss: 0.1040 - val_accuracy: 0.9167
# Epoch 132/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0522 - accuracy: 1.0000
# Epoch 00132: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0386 - accuracy: 1.0000 - val_loss: 0.0853 - val_accuracy: 1.0000
# Epoch 133/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0219 - accuracy: 1.0000
# Epoch 00133: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0457 - accuracy: 0.9773 - val_loss: 0.1118 - val_accuracy: 0.9167
# Epoch 134/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 00134: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1070 - accuracy: 0.9545 - val_loss: 0.0994 - val_accuracy: 0.9167
# Epoch 135/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0490 - accuracy: 1.0000
# Epoch 00135: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0286 - accuracy: 1.0000 - val_loss: 0.0683 - val_accuracy: 1.0000
# Epoch 136/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0802 - accuracy: 0.9000
# Epoch 00136: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0492 - accuracy: 0.9773 - val_loss: 0.0600 - val_accuracy: 1.0000
# Epoch 137/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0518 - accuracy: 1.0000
# Epoch 00137: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0427 - accuracy: 0.9773 - val_loss: 0.0504 - val_accuracy: 1.0000
# Epoch 138/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0236 - accuracy: 1.0000
# Epoch 00138: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0753 - accuracy: 0.9773 - val_loss: 0.0684 - val_accuracy: 1.0000
# Epoch 139/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1072 - accuracy: 0.9000
# Epoch 00139: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0504 - accuracy: 0.9773 - val_loss: 0.0783 - val_accuracy: 0.9167
# Epoch 140/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 00140: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0666 - accuracy: 0.9773 - val_loss: 0.0447 - val_accuracy: 1.0000
# Epoch 141/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0093 - accuracy: 1.0000
# Epoch 00141: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0987 - accuracy: 0.9545 - val_loss: 0.0653 - val_accuracy: 1.0000
# Epoch 142/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0580 - accuracy: 1.0000
# Epoch 00142: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1009 - accuracy: 0.9773 - val_loss: 0.0500 - val_accuracy: 1.0000
# Epoch 143/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0086 - accuracy: 1.0000
# Epoch 00143: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0530 - accuracy: 0.9773 - val_loss: 0.0590 - val_accuracy: 1.0000
# Epoch 144/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 00144: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0751 - accuracy: 0.9773 - val_loss: 0.0577 - val_accuracy: 1.0000
# Epoch 145/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0295 - accuracy: 1.0000
# Epoch 00145: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0406 - accuracy: 0.9773 - val_loss: 0.0399 - val_accuracy: 1.0000
# Epoch 146/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0082 - accuracy: 1.0000
# Epoch 00146: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0317 - accuracy: 1.0000 - val_loss: 0.1076 - val_accuracy: 0.9167
# Epoch 147/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0883 - accuracy: 0.9000
# Epoch 00147: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0286 - accuracy: 0.9773 - val_loss: 0.0670 - val_accuracy: 1.0000
# Epoch 148/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0265 - accuracy: 1.0000
# Epoch 00148: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0267 - accuracy: 1.0000 - val_loss: 0.0619 - val_accuracy: 1.0000
# Epoch 149/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0168 - accuracy: 1.0000
# Epoch 00149: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0199 - accuracy: 1.0000 - val_loss: 0.1003 - val_accuracy: 0.9167
# Epoch 150/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0331 - accuracy: 1.0000
# Epoch 00150: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0328 - accuracy: 1.0000 - val_loss: 0.0908 - val_accuracy: 0.9167
# Epoch 151/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1360 - accuracy: 0.9000
# Epoch 00151: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0709 - accuracy: 0.9545 - val_loss: 0.0457 - val_accuracy: 1.0000
# Epoch 152/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0524 - accuracy: 1.0000
# Epoch 00152: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0319 - accuracy: 1.0000 - val_loss: 0.1282 - val_accuracy: 0.9167
# Epoch 153/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1114 - accuracy: 1.0000
# Epoch 00153: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0425 - accuracy: 1.0000 - val_loss: 0.0347 - val_accuracy: 1.0000
# Epoch 154/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0225 - accuracy: 1.0000
# Epoch 00154: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0240 - accuracy: 1.0000 - val_loss: 0.0375 - val_accuracy: 1.0000
# Epoch 155/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0876 - accuracy: 1.0000
# Epoch 00155: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0368 - accuracy: 1.0000 - val_loss: 0.0973 - val_accuracy: 0.9167
# Epoch 156/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0281 - accuracy: 1.0000
# Epoch 00156: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0288 - accuracy: 0.9773 - val_loss: 0.0762 - val_accuracy: 1.0000
# Epoch 157/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 00157: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 2ms/sample - loss: 0.0244 - accuracy: 0.9773 - val_loss: 0.0802 - val_accuracy: 1.0000
# Epoch 158/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0093 - accuracy: 1.0000
# Epoch 00158: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0318 - accuracy: 0.9773 - val_loss: 0.0925 - val_accuracy: 0.9167
# Epoch 159/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0104 - accuracy: 1.0000
# Epoch 00159: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0419 - accuracy: 0.9773 - val_loss: 0.0430 - val_accuracy: 1.0000
# Epoch 160/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0561 - accuracy: 1.0000
# Epoch 00160: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0486 - accuracy: 0.9773 - val_loss: 0.0231 - val_accuracy: 1.0000
# Epoch 161/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0561 - accuracy: 1.0000
# Epoch 00161: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0256 - accuracy: 1.0000 - val_loss: 0.0200 - val_accuracy: 1.0000
# Epoch 162/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 00162: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0367 - accuracy: 1.0000 - val_loss: 0.0221 - val_accuracy: 1.0000
# Epoch 163/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0316 - accuracy: 1.0000
# Epoch 00163: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0231 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 164/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0435 - accuracy: 1.0000
# Epoch 00164: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0342 - accuracy: 1.0000 - val_loss: 0.0168 - val_accuracy: 1.0000
# Epoch 165/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0058 - accuracy: 1.0000
# Epoch 00165: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 1.0000
# Epoch 166/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 00166: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.0259 - val_accuracy: 1.0000
# Epoch 167/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0108 - accuracy: 1.0000
# Epoch 00167: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0306 - val_accuracy: 1.0000
# Epoch 168/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0329 - accuracy: 1.0000
# Epoch 00168: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0514 - accuracy: 0.9773 - val_loss: 0.1165 - val_accuracy: 0.9167
# Epoch 169/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0677 - accuracy: 1.0000
# Epoch 00169: val_accuracy did not improve from 1.00000
# ...
# Epoch 00445: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 6.1308e-04 - accuracy: 1.0000 - val_loss: 0.9608 - val_accuracy: 0.8333
# Epoch 446/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0080 - accuracy: 1.0000
# Epoch 00446: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.0669 - val_accuracy: 0.7500
# Epoch 447/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00447: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 8.8938e-04 - accuracy: 1.0000 - val_loss: 1.1258 - val_accuracy: 0.7500
# Epoch 448/500
# 10/44 [=====>........................] - ETA: 0s - loss: 7.4546e-04 - accuracy: 1.0000
# Epoch 00448: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 4.1016e-04 - accuracy: 1.0000 - val_loss: 1.1448 - val_accuracy: 0.7500
# Epoch 449/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 00449: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.1240 - val_accuracy: 0.7500
# Epoch 450/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 00450: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.9800 - val_accuracy: 0.8333
# Epoch 451/500
# 10/44 [=====>........................] - ETA: 0s - loss: 6.1865e-04 - accuracy: 1.0000
# Epoch 00451: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 7.5676e-04 - accuracy: 1.0000 - val_loss: 0.9054 - val_accuracy: 0.8333
# Epoch 452/500
# 10/44 [=====>........................] - ETA: 0s - loss: 3.4216e-04 - accuracy: 1.0000
# Epoch 00452: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 6.3156e-04 - accuracy: 1.0000 - val_loss: 0.8755 - val_accuracy: 0.8333
# Epoch 453/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.6726e-04 - accuracy: 1.0000
# Epoch 00453: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.9589 - val_accuracy: 0.8333
# Epoch 454/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 00454: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 7.6778e-04 - accuracy: 1.0000 - val_loss: 1.0709 - val_accuracy: 0.7500
# Epoch 455/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0078 - accuracy: 1.0000
# Epoch 00455: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.2337 - val_accuracy: 0.6667
# Epoch 456/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.8275e-04 - accuracy: 1.0000
# Epoch 00456: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.2313 - val_accuracy: 0.6667
# Epoch 457/500
# 10/44 [=====>........................] - ETA: 0s - loss: 2.7555e-04 - accuracy: 1.0000
# Epoch 00457: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 4.1575e-04 - accuracy: 1.0000 - val_loss: 1.2079 - val_accuracy: 0.6667
# Epoch 458/500
# 10/44 [=====>........................] - ETA: 0s - loss: 6.1494e-04 - accuracy: 1.0000
# Epoch 00458: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.2378 - val_accuracy: 0.6667
# Epoch 459/500
# 10/44 [=====>........................] - ETA: 0s - loss: 8.8701e-04 - accuracy: 1.0000
# Epoch 00459: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 9.6194e-04 - accuracy: 1.0000 - val_loss: 1.2461 - val_accuracy: 0.6667
# Epoch 460/500
# 10/44 [=====>........................] - ETA: 0s - loss: 7.2921e-04 - accuracy: 1.0000
# Epoch 00460: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0178 - accuracy: 0.9773 - val_loss: 0.4781 - val_accuracy: 0.8333
# Epoch 461/500
# 10/44 [=====>........................] - ETA: 0s - loss: 2.8395e-05 - accuracy: 1.0000
# Epoch 00461: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.3013 - val_accuracy: 0.9167
# Epoch 462/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0502 - accuracy: 1.0000
# Epoch 00462: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0122 - accuracy: 1.0000 - val_loss: 2.2889 - val_accuracy: 0.6667
# Epoch 463/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 00463: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0023 - accuracy: 1.0000 - val_loss: 3.6469 - val_accuracy: 0.6667
# Epoch 464/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0193 - accuracy: 1.0000
# Epoch 00464: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0193 - accuracy: 1.0000 - val_loss: 2.7526 - val_accuracy: 0.6667
# Epoch 465/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0120 - accuracy: 1.0000
# Epoch 00465: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.7909 - val_accuracy: 0.8333
# Epoch 466/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1347 - accuracy: 0.9000
# Epoch 00466: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0326 - accuracy: 0.9773 - val_loss: 1.6312 - val_accuracy: 0.6667
# Epoch 467/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 00467: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.3643 - val_accuracy: 0.6667
# Epoch 468/500
# 10/44 [=====>........................] - ETA: 0s - loss: 8.5367e-04 - accuracy: 1.0000
# Epoch 00468: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.5807 - val_accuracy: 0.6667
# Epoch 469/500
# 10/44 [=====>........................] - ETA: 0s - loss: 7.1525e-07 - accuracy: 1.0000
# Epoch 00469: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0058 - accuracy: 1.0000 - val_loss: 2.0304 - val_accuracy: 0.6667
# Epoch 470/500
# 10/44 [=====>........................] - ETA: 0s - loss: 8.4063e-05 - accuracy: 1.0000
# Epoch 00470: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.4545 - val_accuracy: 0.6667
# Epoch 471/500
# 10/44 [=====>........................] - ETA: 0s - loss: 2.3872e-04 - accuracy: 1.0000
# Epoch 00471: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.2417 - val_accuracy: 0.6667
# Epoch 472/500
# 10/44 [=====>........................] - ETA: 0s - loss: 7.0756e-04 - accuracy: 1.0000
# Epoch 00472: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 5.4122e-04 - accuracy: 1.0000 - val_loss: 1.3151 - val_accuracy: 0.6667
# Epoch 473/500
# 10/44 [=====>........................] - ETA: 0s - loss: 4.7861e-04 - accuracy: 1.0000
# Epoch 00473: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.5230 - val_accuracy: 0.6667
# Epoch 474/500
# 10/44 [=====>........................] - ETA: 0s - loss: 2.0726e-04 - accuracy: 1.0000
# Epoch 00474: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 4.5233e-04 - accuracy: 1.0000 - val_loss: 1.7828 - val_accuracy: 0.6667
# Epoch 475/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 00475: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.7444 - val_accuracy: 0.6667
# Epoch 476/500
# 10/44 [=====>........................] - ETA: 0s - loss: 2.3018e-05 - accuracy: 1.0000
# Epoch 00476: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 2.4164e-04 - accuracy: 1.0000 - val_loss: 1.7225 - val_accuracy: 0.6667
# Epoch 477/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00477: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 4.0140e-04 - accuracy: 1.0000 - val_loss: 1.7431 - val_accuracy: 0.6667
# Epoch 478/500
# 10/44 [=====>........................] - ETA: 0s - loss: 4.5325e-05 - accuracy: 1.0000
# Epoch 00478: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.8873 - val_accuracy: 0.6667
# Epoch 479/500
# 10/44 [=====>........................] - ETA: 0s - loss: 3.7606e-04 - accuracy: 1.0000
# Epoch 00479: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 4.6019e-04 - accuracy: 1.0000 - val_loss: 2.1530 - val_accuracy: 0.6667
# Epoch 480/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 00480: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.1589 - val_accuracy: 0.6667
# Epoch 481/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 00481: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0016 - accuracy: 1.0000 - val_loss: 2.0840 - val_accuracy: 0.6667
# Epoch 482/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00482: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 6.0834e-04 - accuracy: 1.0000 - val_loss: 1.9635 - val_accuracy: 0.6667
# Epoch 483/500
# 10/44 [=====>........................] - ETA: 0s - loss: 4.9670e-05 - accuracy: 1.0000
# Epoch 00483: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 4.6480e-04 - accuracy: 1.0000 - val_loss: 1.8829 - val_accuracy: 0.6667
# Epoch 484/500
# 10/44 [=====>........................] - ETA: 0s - loss: 3.8217e-04 - accuracy: 1.0000
# Epoch 00484: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.8998 - val_accuracy: 0.6667
# Epoch 485/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.2337e-04 - accuracy: 1.0000
# Epoch 00485: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 2.5072e-04 - accuracy: 1.0000 - val_loss: 1.9499 - val_accuracy: 0.6667
# Epoch 486/500
# 10/44 [=====>........................] - ETA: 0s - loss: 5.0237e-04 - accuracy: 1.0000
# Epoch 00486: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 6.0935e-04 - accuracy: 1.0000 - val_loss: 1.9665 - val_accuracy: 0.6667
# Epoch 487/500
# 10/44 [=====>........................] - ETA: 0s - loss: 2.2970e-04 - accuracy: 1.0000
# Epoch 00487: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 8.4954e-04 - accuracy: 1.0000 - val_loss: 2.0160 - val_accuracy: 0.6667
# Epoch 488/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 00488: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.2127 - val_accuracy: 0.6667
# Epoch 489/500
# 10/44 [=====>........................] - ETA: 0s - loss: 2.0553e-04 - accuracy: 1.0000
# Epoch 00489: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.6219 - val_accuracy: 0.6667
# Epoch 490/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 00490: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0482 - accuracy: 0.9773 - val_loss: 0.3822 - val_accuracy: 0.8333
# Epoch 491/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0109 - accuracy: 1.0000
# Epoch 00491: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0331 - accuracy: 0.9773 - val_loss: 1.0244 - val_accuracy: 0.6667
# Epoch 492/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 00492: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0195 - accuracy: 0.9773 - val_loss: 5.0779 - val_accuracy: 0.6667
# Epoch 493/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0181 - accuracy: 1.0000
# Epoch 00493: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0118 - accuracy: 1.0000 - val_loss: 2.1023 - val_accuracy: 0.6667
# Epoch 494/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0062 - accuracy: 1.0000
# Epoch 00494: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.8142 - val_accuracy: 0.6667
# Epoch 495/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0328 - accuracy: 1.0000
# Epoch 00495: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.8507 - val_accuracy: 0.6667
# Epoch 496/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 00496: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.4178 - val_accuracy: 0.5833
# Epoch 497/500
# 10/44 [=====>........................] - ETA: 0s - loss: 3.2732e-04 - accuracy: 1.0000
# Epoch 00497: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0140 - accuracy: 1.0000 - val_loss: 3.1189 - val_accuracy: 0.6667
# Epoch 498/500
# 10/44 [=====>........................] - ETA: 0s - loss: 3.3697e-04 - accuracy: 1.0000
# Epoch 00498: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0533 - accuracy: 0.9773 - val_loss: 0.3252 - val_accuracy: 0.9167
# Epoch 499/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 00499: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.0517 - accuracy: 0.9773 - val_loss: 0.8627 - val_accuracy: 0.8333
# Epoch 500/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0643 - accuracy: 1.0000
# Epoch 00500: val_accuracy did not improve from 1.00000
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3821 - accuracy: 0.8864 - val_loss: 5.5484 - val_accuracy: 0.6667
# Training completed in time:  0:00:29.670589

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.8863636
# Testing Accuracy:  0.25

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.20      1.00      0.33         3
#    Pneumonia       1.00      0.08      0.14        13
#
#     accuracy                           0.25        16
#    macro avg       0.60      0.54      0.24        16
# weighted avg       0.85      0.25      0.18        16

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[ 3  0]
#  [12  1]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])
