# %% [markdown]
# # Rede CNN - Modelo 2
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - Dataset 2 - no_augment_5

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP_TRAIN = 'no_augment_5'
GROUP_TEST = 'no_augment_5'
DATASET = 'dataset_2'
DURATION = 5
SIZE = 216
CSV_TRAIN = 'train2.csv'
CSV_TEST = 'test2.csv'
MODEL_NAME = f'CNN2_{DATASET}_{GROUP_TRAIN}'

# %%
train_file_paths = glob.glob(f'../datasets/{DATASET}/{GROUP_TRAIN}/train/**/*.wav', recursive=True)
train_file_names = [os.path.splitext(os.path.basename(p))[0] for p in train_file_paths]

test_file_paths = glob.glob(f'../datasets/{DATASET}/{GROUP_TEST}/test/**/*.wav', recursive=True)
test_file_names = [os.path.splitext(os.path.basename(p))[0] for p in test_file_paths]

# %%
train_p_id_in_file = [] # patient IDs corresponding to each file
test_p_id_in_file = [] # patient IDs corresponding to each file
for name in train_file_names:
    train_p_id_in_file.append(int(name[:3]))

for name in test_file_names:
    test_p_id_in_file.append(int(name[:3]))

train_p_id_in_file = np.array(train_p_id_in_file)
test_p_id_in_file = np.array(test_p_id_in_file)

# %%
max_pad_len = SIZE

os.makedirs("features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=DURATION) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
train_p_diag = pd.read_csv(f"../Respiratory_Sound_Database/Respiratory_Sound_Database_Pneumo_Healthy_Only/{CSV_TRAIN}", header=None) # patient diagnosis file
test_p_diag = pd.read_csv(f"../Respiratory_Sound_Database/Respiratory_Sound_Database_Pneumo_Healthy_Only/{CSV_TEST}", header=None) # patient diagnosis file
train_p_diag.head(5)
# Out:
#      0        1
# 0  123  Healthy
# 1  125  Healthy
# 2  126  Healthy
# 3  127  Healthy
# 4  136  Healthy

# %%
train_labels = np.array([train_p_diag[train_p_diag[0] == x][1].values[0] for x in train_p_id_in_file]) 
test_labels = np.array([test_p_diag[test_p_diag[0] == x][1].values[0] for x in test_p_id_in_file])

# %%
train_features = [] 
test_features = []

for file_name in train_file_paths:
    data = extract_features(file_name)
    train_features.append(data)

for file_name in test_file_paths:
    data = extract_features(file_name)
    test_features.append(data)

print('Finished feature extraction from ', (len(train_features)+len(train_features)), ' files')
train_features = np.array(train_features)
test_features = np.array(test_features)
# Out:
# Finished feature extraction from  112  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(train_features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
np.unique(train_labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
unique_elements, counts_elements = np.unique(train_labels, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))

unique_elements_test, counts_elements_test = np.unique(test_labels, return_counts=True)
print(np.asarray((unique_elements_test, counts_elements_test)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['32' '24']]
# [['Healthy' 'Pneumonia']
#  ['3' '13']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
le.fit(train_labels)
train_labels_cat = to_categorical(le.transform(train_labels)) 
test_labels_cat = to_categorical(le.transform(test_labels))

# %%
train_features.shape
# Out:
# (56, 40, 216)

# %%
train_features = np.reshape(train_features, (*train_features.shape,1)) 
print(train_features.shape, train_labels_cat.shape)
test_features = np.reshape(test_features, (*test_features.shape,1)) 
print(test_features.shape, test_labels_cat.shape)
# Out:
# (56, 40, 216, 1) (56, 2)
# (16, 40, 216, 1) (16, 2)

# %%
# train test split
x_train, x_val, y_train, y_val = train_test_split(train_features, train_labels_cat, test_size=0.2, random_state = 42)
x_test, y_test = test_features, test_labels_cat

# %% [markdown]
# **CNN model architecture**

# %%
num_labels = train_labels_cat.shape[1]

num_rows = 40
num_columns = SIZE
num_channels = 1

filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(Conv2D(filters=16, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(Conv2D(filters=8, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(Conv2D(filters=4, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 215, 32)       160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 107, 32)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 107, 32)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 106, 16)       2064
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 53, 16)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 53, 16)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 52, 8)          520
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 26, 8)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 26, 8)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 25, 4)          132
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 12, 4)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 12, 4)          0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 4)                 0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 10
# =================================================================
# Total params: 2,886
# Trainable params: 2,886
# Non-trainable params: 0
# _________________________________________________________________
# 16/16 [==============================] - 1s 52ms/sample - loss: 3.8157 - accuracy: 0.8125
# Pre-training accuracy: 81.2500%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 500
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/' + MODEL_NAME + '_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_val, y_val), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 44 samples, validate on 12 samples
# Epoch 1/500
# 10/44 [=====>........................] - ETA: 1s - loss: 47.3665 - accuracy: 0.4000
# Epoch 00001: val_accuracy improved from -inf to 0.41667, saving model to models/CNN2_dataset_2_no_augment_5_01.h5
# 44/44 [==============================] - 1s 17ms/sample - loss: 40.0992 - accuracy: 0.4318 - val_loss: 6.3080 - val_accuracy: 0.4167
# Epoch 2/500
# 10/44 [=====>........................] - ETA: 0s - loss: 9.2034 - accuracy: 0.6000
# Epoch 00002: val_accuracy did not improve from 0.41667
# 44/44 [==============================] - 0s 871us/sample - loss: 13.4836 - accuracy: 0.4318 - val_loss: 3.9909 - val_accuracy: 0.4167
# Epoch 3/500
# 10/44 [=====>........................] - ETA: 0s - loss: 9.5434 - accuracy: 0.3000
# Epoch 00003: val_accuracy improved from 0.41667 to 0.50000, saving model to models/CNN2_dataset_2_no_augment_5_03.h5
# 44/44 [==============================] - 0s 2ms/sample - loss: 8.7204 - accuracy: 0.3864 - val_loss: 2.4349 - val_accuracy: 0.5000
# Epoch 4/500
# 10/44 [=====>........................] - ETA: 0s - loss: 4.6287 - accuracy: 0.5000
# Epoch 00004: val_accuracy did not improve from 0.50000
# 44/44 [==============================] - 0s 920us/sample - loss: 6.0179 - accuracy: 0.5000 - val_loss: 1.3411 - val_accuracy: 0.5000
# Epoch 5/500
# 10/44 [=====>........................] - ETA: 0s - loss: 3.7987 - accuracy: 0.6000
# Epoch 00005: val_accuracy did not improve from 0.50000
# 44/44 [==============================] - 0s 1ms/sample - loss: 6.2773 - accuracy: 0.5455 - val_loss: 1.0349 - val_accuracy: 0.5000
# Epoch 6/500
# 10/44 [=====>........................] - ETA: 0s - loss: 11.6252 - accuracy: 0.3000
# Epoch 00006: val_accuracy did not improve from 0.50000
# 44/44 [==============================] - 0s 1ms/sample - loss: 6.6735 - accuracy: 0.5000 - val_loss: 0.9548 - val_accuracy: 0.5000
# Epoch 7/500
# 10/44 [=====>........................] - ETA: 0s - loss: 4.4572 - accuracy: 0.6000
# Epoch 00007: val_accuracy did not improve from 0.50000
# 44/44 [==============================] - 0s 994us/sample - loss: 4.8066 - accuracy: 0.5455 - val_loss: 0.8451 - val_accuracy: 0.4167
# Epoch 8/500
# 10/44 [=====>........................] - ETA: 0s - loss: 5.4231 - accuracy: 0.5000
# Epoch 00008: val_accuracy did not improve from 0.50000
# 44/44 [==============================] - 0s 1ms/sample - loss: 4.7588 - accuracy: 0.5000 - val_loss: 0.8149 - val_accuracy: 0.4167
# Epoch 9/500
# 10/44 [=====>........................] - ETA: 0s - loss: 2.2821 - accuracy: 0.6000
# Epoch 00009: val_accuracy did not improve from 0.50000
# 44/44 [==============================] - 0s 915us/sample - loss: 2.8513 - accuracy: 0.5000 - val_loss: 0.7996 - val_accuracy: 0.4167
# Epoch 10/500
# 10/44 [=====>........................] - ETA: 0s - loss: 4.5414 - accuracy: 0.4000
# Epoch 00010: val_accuracy did not improve from 0.50000
# 44/44 [==============================] - 0s 894us/sample - loss: 2.8159 - accuracy: 0.5227 - val_loss: 0.7897 - val_accuracy: 0.4167
# Epoch 11/500
# 10/44 [=====>........................] - ETA: 0s - loss: 2.9600 - accuracy: 0.7000
# Epoch 00011: val_accuracy did not improve from 0.50000
# 44/44 [==============================] - 0s 996us/sample - loss: 2.1588 - accuracy: 0.6591 - val_loss: 0.7825 - val_accuracy: 0.4167
# Epoch 12/500
# 10/44 [=====>........................] - ETA: 0s - loss: 4.1552 - accuracy: 0.3000
# Epoch 00012: val_accuracy did not improve from 0.50000
# 44/44 [==============================] - 0s 966us/sample - loss: 2.9018 - accuracy: 0.3409 - val_loss: 0.7800 - val_accuracy: 0.4167
# Epoch 13/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.3513 - accuracy: 0.7000
# Epoch 00013: val_accuracy did not improve from 0.50000
# 44/44 [==============================] - 0s 895us/sample - loss: 2.3420 - accuracy: 0.5455 - val_loss: 0.7813 - val_accuracy: 0.4167
# Epoch 14/500
# 10/44 [=====>........................] - ETA: 0s - loss: 2.6851 - accuracy: 0.6000
# Epoch 00014: val_accuracy did not improve from 0.50000
# 44/44 [==============================] - 0s 934us/sample - loss: 2.6048 - accuracy: 0.5909 - val_loss: 0.7728 - val_accuracy: 0.4167
# Epoch 15/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.6176 - accuracy: 0.4000
# Epoch 00015: val_accuracy did not improve from 0.50000
# 44/44 [==============================] - 0s 953us/sample - loss: 2.3541 - accuracy: 0.3864 - val_loss: 0.7646 - val_accuracy: 0.4167
# Epoch 16/500
# 10/44 [=====>........................] - ETA: 0s - loss: 2.3264 - accuracy: 0.6000
# Epoch 00016: val_accuracy did not improve from 0.50000
# 44/44 [==============================] - 0s 930us/sample - loss: 2.4236 - accuracy: 0.5227 - val_loss: 0.7498 - val_accuracy: 0.4167
# Epoch 17/500
# 10/44 [=====>........................] - ETA: 0s - loss: 2.5148 - accuracy: 0.5000
# Epoch 00017: val_accuracy did not improve from 0.50000
# 44/44 [==============================] - 0s 957us/sample - loss: 2.3386 - accuracy: 0.4773 - val_loss: 0.7386 - val_accuracy: 0.4167
# Epoch 18/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.7123 - accuracy: 0.6000
# Epoch 00018: val_accuracy did not improve from 0.50000
# 44/44 [==============================] - 0s 1ms/sample - loss: 2.0737 - accuracy: 0.4545 - val_loss: 0.7292 - val_accuracy: 0.4167
# Epoch 19/500
# 10/44 [=====>........................] - ETA: 0s - loss: 3.6499 - accuracy: 0.5000
# Epoch 00019: val_accuracy did not improve from 0.50000
# 44/44 [==============================] - 0s 937us/sample - loss: 2.0342 - accuracy: 0.5000 - val_loss: 0.7173 - val_accuracy: 0.5000
# Epoch 20/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.3498 - accuracy: 0.4000
# Epoch 00020: val_accuracy did not improve from 0.50000
# 44/44 [==============================] - 0s 947us/sample - loss: 1.5742 - accuracy: 0.4091 - val_loss: 0.7116 - val_accuracy: 0.5000
# Epoch 21/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.8245 - accuracy: 0.4000
# Epoch 00021: val_accuracy did not improve from 0.50000
# 44/44 [==============================] - 0s 888us/sample - loss: 1.5433 - accuracy: 0.3409 - val_loss: 0.7061 - val_accuracy: 0.5000
# Epoch 22/500
# 10/44 [=====>........................] - ETA: 0s - loss: 2.2706 - accuracy: 0.2000
# Epoch 00022: val_accuracy did not improve from 0.50000
# 44/44 [==============================] - 0s 874us/sample - loss: 1.5856 - accuracy: 0.5227 - val_loss: 0.6997 - val_accuracy: 0.5000
# Epoch 23/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.9904 - accuracy: 0.7000
# Epoch 00023: val_accuracy improved from 0.50000 to 0.58333, saving model to models/CNN2_dataset_2_no_augment_5_23.h5
# 44/44 [==============================] - 0s 1ms/sample - loss: 1.0088 - accuracy: 0.6364 - val_loss: 0.6968 - val_accuracy: 0.5833
# Epoch 24/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.8234 - accuracy: 0.5000
# Epoch 00024: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 891us/sample - loss: 1.4340 - accuracy: 0.4545 - val_loss: 0.6950 - val_accuracy: 0.5833
# Epoch 25/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4703 - accuracy: 0.6000
# Epoch 00025: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 868us/sample - loss: 0.8820 - accuracy: 0.5682 - val_loss: 0.6931 - val_accuracy: 0.4167
# Epoch 26/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.2595 - accuracy: 0.7000
# Epoch 00026: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 915us/sample - loss: 1.4844 - accuracy: 0.5000 - val_loss: 0.6896 - val_accuracy: 0.5000
# Epoch 27/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3168 - accuracy: 0.8000
# Epoch 00027: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 969us/sample - loss: 1.0417 - accuracy: 0.5455 - val_loss: 0.6882 - val_accuracy: 0.4167
# Epoch 28/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.8587 - accuracy: 0.3000
# Epoch 00028: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 1.2432 - accuracy: 0.5227 - val_loss: 0.6866 - val_accuracy: 0.4167
# Epoch 29/500
# 10/44 [=====>........................] - ETA: 0s - loss: 1.1182 - accuracy: 0.7000
# Epoch 00029: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s
500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4459 - accuracy: 0.7000
# Epoch 00117: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 949us/sample - loss: 0.5301 - accuracy: 0.6818 - val_loss: 0.6981 - val_accuracy: 0.2500
# Epoch 118/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.7173 - accuracy: 0.5000
# Epoch 00118: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5257 - accuracy: 0.7045 - val_loss: 0.6999 - val_accuracy: 0.2500
# Epoch 119/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5810 - accuracy: 0.7000
# Epoch 00119: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.6493 - accuracy: 0.6818 - val_loss: 0.6867 - val_accuracy: 0.5000
# Epoch 120/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6073 - accuracy: 0.8000
# Epoch 00120: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 965us/sample - loss: 0.5246 - accuracy: 0.7500 - val_loss: 0.6857 - val_accuracy: 0.2500
# Epoch 121/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3126 - accuracy: 0.9000
# Epoch 00121: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 992us/sample - loss: 0.5173 - accuracy: 0.7500 - val_loss: 0.6837 - val_accuracy: 0.2500
# Epoch 122/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5241 - accuracy: 0.7000
# Epoch 00122: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5229 - accuracy: 0.6591 - val_loss: 0.6687 - val_accuracy: 0.5000
# Epoch 123/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3957 - accuracy: 0.7000
# Epoch 00123: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4759 - accuracy: 0.7500 - val_loss: 0.6659 - val_accuracy: 0.5000
# Epoch 124/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4778 - accuracy: 0.7000
# Epoch 00124: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5769 - accuracy: 0.7955 - val_loss: 0.6785 - val_accuracy: 0.3333
# Epoch 125/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5608 - accuracy: 0.8000
# Epoch 00125: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5437 - accuracy: 0.8182 - val_loss: 0.6808 - val_accuracy: 0.3333
# Epoch 126/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4415 - accuracy: 0.8000
# Epoch 00126: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5542 - accuracy: 0.7500 - val_loss: 0.6720 - val_accuracy: 0.4167
# Epoch 127/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2880 - accuracy: 0.9000
# Epoch 00127: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4366 - accuracy: 0.7955 - val_loss: 0.6672 - val_accuracy: 0.5000
# Epoch 128/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.7187 - accuracy: 0.6000
# Epoch 00128: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5529 - accuracy: 0.6364 - val_loss: 0.6666 - val_accuracy: 0.5000
# Epoch 129/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4263 - accuracy: 0.8000
# Epoch 00129: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5063 - accuracy: 0.7045 - val_loss: 0.6704 - val_accuracy: 0.3333
# Epoch 130/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3541 - accuracy: 0.9000
# Epoch 00130: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4938 - accuracy: 0.7727 - val_loss: 0.6731 - val_accuracy: 0.4167
# Epoch 131/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2695 - accuracy: 0.9000
# Epoch 00131: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 987us/sample - loss: 0.4456 - accuracy: 0.8409 - val_loss: 0.6710 - val_accuracy: 0.3333
# Epoch 132/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3303 - accuracy: 0.8000
# Epoch 00132: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4143 - accuracy: 0.8182 - val_loss: 0.6699 - val_accuracy: 0.4167
# Epoch 133/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5385 - accuracy: 0.7000
# Epoch 00133: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5723 - accuracy: 0.7045 - val_loss: 0.6668 - val_accuracy: 0.5833
# Epoch 134/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3467 - accuracy: 0.9000
# Epoch 00134: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5469 - accuracy: 0.6591 - val_loss: 0.6668 - val_accuracy: 0.5000
# Epoch 135/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5525 - accuracy: 0.7000
# Epoch 00135: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0
500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3689 - accuracy: 0.9000
# Epoch 00154: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 975us/sample - loss: 0.5912 - accuracy: 0.7273 - val_loss: 0.6687 - val_accuracy: 0.3333
# Epoch 155/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4128 - accuracy: 0.8000
# Epoch 00155: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 935us/sample - loss: 0.4071 - accuracy: 0.7955 - val_loss: 0.6670 - val_accuracy: 0.4167
# Epoch 156/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3876 - accuracy: 0.7000
# Epoch 00156: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 990us/sample - loss: 0.4464 - accuracy: 0.7500 - val_loss: 0.6663 - val_accuracy: 0.5000
# Epoch 157/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4531 - accuracy: 0.8000
# Epoch 00157: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4769 - accuracy: 0.7500 - val_loss: 0.6659 - val_accuracy: 0.4167
# Epoch 158/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6702 - accuracy: 0.7000
# Epoch 00158: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4958 - accuracy: 0.7500 - val_loss: 0.6666 - val_accuracy: 0.3333
# Epoch 159/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4586 - accuracy: 0.7000
# Epoch 00159: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4518 - accuracy: 0.7500 - val_loss: 0.6666 - val_accuracy: 0.4167
# Epoch 160/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4973 - accuracy: 0.8000
# Epoch 00160: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5221 - accuracy: 0.7727 - val_loss: 0.6656 - val_accuracy: 0.5000
# Epoch 161/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.6135 - accuracy: 0.8000
# Epoch 00161: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.5487 - accuracy: 0.7955 - val_loss: 0.6619 - val_accuracy: 0.4167
# Epoch 162/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5447 - accuracy: 0.7000
# Epoch 00162: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 992us/sample - loss: 0.4299 - accuracy: 0.8182 - val_loss: 0.6610 - val_accuracy: 0.5000
# Epoch 163/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3835 - accuracy: 0.9000
# Epoch 00163: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3730 - accuracy: 0.8409 - val_loss: 0.6495 - val_accuracy: 0.3333
# Epoch 164/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3265 - accuracy: 0.9000
# Epoch 00164: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.4296 - accuracy: 0.7500 - val_loss: 0.6496 - val_accuracy: 0.3333
# Epoch 165/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2005 - accuracy: 0.9000
# Epoch 00165: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 974us/sample - loss: 0.4629 - accuracy: 0.7955 - val_loss: 0.6545 - val_accuracy: 0.5833
# Epoch 166/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3643 - accuracy: 0.7000
# Epoch 00166: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 988us/sample - loss: 0.3904 - accuracy: 0.8182 - val_loss: 0.6674 - val_accuracy: 0.5000
# Epoch 167/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5098 - accuracy: 0.7000
# Epoch 00167: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 963us/sample - loss: 0.4166 - accuracy: 0.7955 - val_loss: 0.6544 - val_accuracy: 0.5000
# Epoch 168/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2279 - accuracy: 0.9000
# Epoch 00168: val_accuracy did not improve from 0.58333
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.3321 - accuracy: 0.8409 - val_loss: 0.6461 - val_accuracy: 0.5833
# Epoch 169/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3819 - accuracy: 0.8000
# Epoch 00169: val_accuracy did not improve from 0.58333
# ...
# Epoch 445/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1636 - accuracy: 1.0000
# Epoch 00445: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 884us/sample - loss: 0.2777 - accuracy: 0.8636 - val_loss: 0.5049 - val_accuracy: 0.6667
# Epoch 446/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3238 - accuracy: 0.8000
# Epoch 00446: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 819us/sample - loss: 0.2137 - accuracy: 0.9091 - val_loss: 0.5084 - val_accuracy: 0.5833
# Epoch 447/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1211 - accuracy: 1.0000
# Epoch 00447: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 938us/sample - loss: 0.1849 - accuracy: 0.9318 - val_loss: 0.5093 - val_accuracy: 0.5833
# Epoch 448/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1286 - accuracy: 1.0000
# Epoch 00448: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 854us/sample - loss: 0.2534 - accuracy: 0.8864 - val_loss: 0.5081 - val_accuracy: 0.6667
# Epoch 449/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2914 - accuracy: 0.8000
# Epoch 00449: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 941us/sample - loss: 0.3197 - accuracy: 0.8636 - val_loss: 0.5133 - val_accuracy: 0.6667
# Epoch 450/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2730 - accuracy: 0.9000
# Epoch 00450: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 874us/sample - loss: 0.1867 - accuracy: 0.9318 - val_loss: 0.5140 - val_accuracy: 0.6667
# Epoch 451/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0398 - accuracy: 1.0000
# Epoch 00451: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 938us/sample - loss: 0.3053 - accuracy: 0.8182 - val_loss: 0.5115 - val_accuracy: 0.6667
# Epoch 452/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3060 - accuracy: 0.9000
# Epoch 00452: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 857us/sample - loss: 0.3009 - accuracy: 0.8864 - val_loss: 0.5431 - val_accuracy: 0.5833
# Epoch 453/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1203 - accuracy: 0.9000
# Epoch 00453: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.1914 - accuracy: 0.9091 - val_loss: 0.5373 - val_accuracy: 0.5833
# Epoch 454/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3912 - accuracy: 0.7000
# Epoch 00454: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 960us/sample - loss: 0.2698 - accuracy: 0.8864 - val_loss: 0.5154 - val_accuracy: 0.5833
# Epoch 455/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2198 - accuracy: 0.9000
# Epoch 00455: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 881us/sample - loss: 0.2388 - accuracy: 0.8864 - val_loss: 0.5021 - val_accuracy: 0.6667
# Epoch 456/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4689 - accuracy: 0.8000
# Epoch 00456: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 939us/sample - loss: 0.2460 - accuracy: 0.8864 - val_loss: 0.5016 - val_accuracy: 0.6667
# Epoch 457/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3461 - accuracy: 0.8000
# Epoch 00457: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 869us/sample - loss: 0.2795 - accuracy: 0.8182 - val_loss: 0.5043 - val_accuracy: 0.6667
# Epoch 458/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2425 - accuracy: 0.9000
# Epoch 00458: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 925us/sample - loss: 0.2135 - accuracy: 0.9318 - val_loss: 0.5147 - val_accuracy: 0.5833
# Epoch 459/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4150 - accuracy: 0.7000
# Epoch 00459: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 869us/sample - loss: 0.2741 - accuracy: 0.8409 - val_loss: 0.5555 - val_accuracy: 0.5833
# Epoch 460/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2104 - accuracy: 0.9000
# Epoch 00460: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 913us/sample - loss: 0.2216 - accuracy: 0.9091 - val_loss: 0.5686 - val_accuracy: 0.5833
# Epoch 461/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1023 - accuracy: 1.0000
# Epoch 00461: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 852us/sample - loss: 0.1820 - accuracy: 0.9318 - val_loss: 0.5182 - val_accuracy: 0.5833
# Epoch 462/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4364 - accuracy: 0.8000
# Epoch 00462: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 980us/sample - loss: 0.2160 - accuracy: 0.9318 - val_loss: 0.5104 - val_accuracy: 0.6667
# Epoch 463/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0784 - accuracy: 1.0000
# Epoch 00463: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 820us/sample - loss: 0.1943 - accuracy: 0.8864 - val_loss: 0.5094 - val_accuracy: 0.6667
# Epoch 464/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1050 - accuracy: 1.0000
# Epoch 00464: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 890us/sample - loss: 0.1835 - accuracy: 0.9318 - val_loss: 0.5173 - val_accuracy: 0.5833
# Epoch 465/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2184 - accuracy: 0.9000
# Epoch 00465: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2304 - accuracy: 0.8864 - val_loss: 0.5152 - val_accuracy: 0.5833
# Epoch 466/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1172 - accuracy: 0.9000
# Epoch 00466: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 823us/sample - loss: 0.2345 - accuracy: 0.8864 - val_loss: 0.5156 - val_accuracy: 0.5833
# Epoch 467/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2778 - accuracy: 0.9000
# Epoch 00467: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 963us/sample - loss: 0.2684 - accuracy: 0.8409 - val_loss: 0.5270 - val_accuracy: 0.5833
# Epoch 468/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4245 - accuracy: 0.7000
# Epoch 00468: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 840us/sample - loss: 0.2232 - accuracy: 0.9091 - val_loss: 0.5630 - val_accuracy: 0.6667
# Epoch 469/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0960 - accuracy: 1.0000
# Epoch 00469: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 960us/sample - loss: 0.2834 - accuracy: 0.8864 - val_loss: 0.5564 - val_accuracy: 0.5833
# Epoch 470/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1817 - accuracy: 0.9000
# Epoch 00470: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 882us/sample - loss: 0.2389 - accuracy: 0.9091 - val_loss: 0.5225 - val_accuracy: 0.6667
# Epoch 471/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1573 - accuracy: 1.0000
# Epoch 00471: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 848us/sample - loss: 0.2628 - accuracy: 0.8864 - val_loss: 0.5326 - val_accuracy: 0.6667
# Epoch 472/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2897 - accuracy: 0.9000
# Epoch 00472: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 1ms/sample - loss: 0.2426 - accuracy: 0.8636 - val_loss: 0.5235 - val_accuracy: 0.6667
# Epoch 473/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4245 - accuracy: 0.8000
# Epoch 00473: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 901us/sample - loss: 0.2176 - accuracy: 0.9091 - val_loss: 0.5258 - val_accuracy: 0.5833
# Epoch 474/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0900 - accuracy: 1.0000
# Epoch 00474: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 886us/sample - loss: 0.1816 - accuracy: 0.9091 - val_loss: 0.5432 - val_accuracy: 0.5833
# Epoch 475/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2311 - accuracy: 0.8000
# Epoch 00475: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 980us/sample - loss: 0.2834 - accuracy: 0.8636 - val_loss: 0.5319 - val_accuracy: 0.5833
# Epoch 476/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1221 - accuracy: 0.9000
# Epoch 00476: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 860us/sample - loss: 0.2706 - accuracy: 0.8409 - val_loss: 0.5045 - val_accuracy: 0.6667
# Epoch 477/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1537 - accuracy: 0.9000
# Epoch 00477: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 981us/sample - loss: 0.2130 - accuracy: 0.8409 - val_loss: 0.4975 - val_accuracy: 0.6667
# Epoch 478/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1562 - accuracy: 0.9000
# Epoch 00478: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 843us/sample - loss: 0.2026 - accuracy: 0.9545 - val_loss: 0.5022 - val_accuracy: 0.5833
# Epoch 479/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1438 - accuracy: 1.0000
# Epoch 00479: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 836us/sample - loss: 0.2991 - accuracy: 0.7955 - val_loss: 0.5066 - val_accuracy: 0.5833
# Epoch 480/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2022 - accuracy: 0.9000
# Epoch 00480: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 921us/sample - loss: 0.1995 - accuracy: 0.8864 - val_loss: 0.4944 - val_accuracy: 0.6667
# Epoch 481/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.3034 - accuracy: 0.9000
# Epoch 00481: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 836us/sample - loss: 0.2829 - accuracy: 0.8636 - val_loss: 0.5307 - val_accuracy: 0.5833
# Epoch 482/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.0946 - accuracy: 1.0000
# Epoch 00482: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 867us/sample - loss: 0.1699 - accuracy: 0.9091 - val_loss: 0.5755 - val_accuracy: 0.5833
# Epoch 483/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1757 - accuracy: 0.9000
# Epoch 00483: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 933us/sample - loss: 0.2050 - accuracy: 0.9091 - val_loss: 0.5750 - val_accuracy: 0.5833
# Epoch 484/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2865 - accuracy: 0.9000
# Epoch 00484: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 863us/sample - loss: 0.2547 - accuracy: 0.8864 - val_loss: 0.5539 - val_accuracy: 0.5833
# Epoch 485/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1944 - accuracy: 1.0000
# Epoch 00485: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 920us/sample - loss: 0.2125 - accuracy: 0.9091 - val_loss: 0.5512 - val_accuracy: 0.5833
# Epoch 486/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4100 - accuracy: 0.8000
# Epoch 00486: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 927us/sample - loss: 0.2421 - accuracy: 0.9091 - val_loss: 0.5464 - val_accuracy: 0.5833
# Epoch 487/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4972 - accuracy: 0.8000
# Epoch 00487: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 847us/sample - loss: 0.1860 - accuracy: 0.9545 - val_loss: 0.5383 - val_accuracy: 0.5833
# Epoch 488/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1703 - accuracy: 0.9000
# Epoch 00488: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 942us/sample - loss: 0.1917 - accuracy: 0.8864 - val_loss: 0.5529 - val_accuracy: 0.5833
# Epoch 489/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2941 - accuracy: 0.8000
# Epoch 00489: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 880us/sample - loss: 0.2099 - accuracy: 0.9318 - val_loss: 0.5517 - val_accuracy: 0.5833
# Epoch 490/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1606 - accuracy: 0.9000
# Epoch 00490: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 948us/sample - loss: 0.1621 - accuracy: 0.8864 - val_loss: 0.5398 - val_accuracy: 0.5833
# Epoch 491/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2108 - accuracy: 1.0000
# Epoch 00491: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 852us/sample - loss: 0.2320 - accuracy: 0.8864 - val_loss: 0.5367 - val_accuracy: 0.5833
# Epoch 492/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2321 - accuracy: 0.9000
# Epoch 00492: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 867us/sample - loss: 0.1998 - accuracy: 0.9091 - val_loss: 0.5279 - val_accuracy: 0.5833
# Epoch 493/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1210 - accuracy: 1.0000
# Epoch 00493: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 960us/sample - loss: 0.2403 - accuracy: 0.9091 - val_loss: 0.5246 - val_accuracy: 0.6667
# Epoch 494/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1070 - accuracy: 0.9000
# Epoch 00494: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 839us/sample - loss: 0.2675 - accuracy: 0.8636 - val_loss: 0.5212 - val_accuracy: 0.6667
# Epoch 495/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1260 - accuracy: 0.9000
# Epoch 00495: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 879us/sample - loss: 0.2256 - accuracy: 0.8636 - val_loss: 0.5171 - val_accuracy: 0.6667
# Epoch 496/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.1864 - accuracy: 0.9000
# Epoch 00496: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 926us/sample - loss: 0.2261 - accuracy: 0.8864 - val_loss: 0.5109 - val_accuracy: 0.6667
# Epoch 497/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2649 - accuracy: 0.9000
# Epoch 00497: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 841us/sample - loss: 0.2132 - accuracy: 0.8636 - val_loss: 0.5098 - val_accuracy: 0.6667
# Epoch 498/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.2381 - accuracy: 0.9000
# Epoch 00498: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 914us/sample - loss: 0.2196 - accuracy: 0.9091 - val_loss: 0.5092 - val_accuracy: 0.6667
# Epoch 499/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.5819 - accuracy: 0.8000
# Epoch 00499: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 923us/sample - loss: 0.2325 - accuracy: 0.9318 - val_loss: 0.5078 - val_accuracy: 0.6667
# Epoch 500/500
# 10/44 [=====>........................] - ETA: 0s - loss: 0.4667 - accuracy: 0.8000
# Epoch 00500: val_accuracy did not improve from 0.66667
# 44/44 [==============================] - 0s 861us/sample - loss: 0.2415 - accuracy: 0.9091 - val_loss: 0.5063 - val_accuracy: 0.6667
# Training completed in time:  0:00:22.177121

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.9318182
# Testing Accuracy:  0.8125

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.50      0.67      0.57         3
#    Pneumonia       0.92      0.85      0.88        13
#
#     accuracy                           0.81        16
#    macro avg       0.71      0.76      0.73        16
# weighted avg       0.84      0.81      0.82        16

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[ 2  1]
#  [ 2 11]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])
