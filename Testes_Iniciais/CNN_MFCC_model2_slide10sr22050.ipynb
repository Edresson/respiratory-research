# %% [markdown]
# # Rede CNN - Modelo 2
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - slide10sr22050

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP = 'slide10sr22050'
MAX_PAD_LEN = 431

# %%
filepaths = glob.glob(f'./datasets/{GROUP}/**/*.wav', recursive=True)
filenames = [os.path.splitext(os.path.basename(p))[0] for p in filepaths]

# %%
p_id_in_file = [] # patient IDs corresponding to each file
for name in filenames:
    p_id_in_file.append(int(name[:3]))

p_id_in_file = np.array(p_id_in_file)

# %%
max_pad_len =  MAX_PAD_LEN

os.makedirs("./Respiratory_Sound_Database/features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=10) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./Respiratory_Sound_Database/features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
p_diag = pd.read_csv("./Respiratory_Sound_Database/Respiratory_Sound_Database/patient_diagnosis.csv",header=None) # patient diagnosis file

# %%
labels = np.array([p_diag[p_diag[0] == x][1].values[0] for x in p_id_in_file]) # labels for audio files

# %%
features = [] 

# Iterate through each sound file and extract the features
for file_name in filepaths:
    data = extract_features(file_name)
    features.append(data)

print('Finished feature extraction from ', len(features), ' files')
features = np.array(features)
# Out:
# Finished feature extraction from  576  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(features[1], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
features = np.array(features) # convert to numpy array

# %%
np.unique(labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
# delete diseases
'''
features1 = features
labels1 = labels'''

features1 = np.delete(features, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0) 

labels1 = np.delete(labels, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0)

# %%
# print class counts
unique_elements, counts_elements = np.unique(labels1, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['280' '296']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(labels1)
oh_labels = to_categorical(i_labels)

# %%
features1.shape
# Out:
# (576, 40, 431)

# %%
# add channel dimension for CNN
features1 = np.reshape(features1, (*features1.shape,1)) 

# train test split
x_train, x_test, y_train, y_test = train_test_split(features1, oh_labels, stratify=oh_labels, 
                                                    test_size=0.2, random_state = 42)

# %% [markdown]
# **MLP model architecture**

# %%
num_rows = 40
num_columns = 431
num_channels = 1

num_labels = oh_labels.shape[1]
filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=16, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=8, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=4, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 430, 32)       160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 215, 32)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 215, 32)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 214, 16)       2064
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 107, 16)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 107, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 106, 8)         520
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 53, 8)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 53, 8)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 52, 4)          132
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 26, 4)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 26, 4)          0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 4)                 0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 10
# =================================================================
# Total params: 2,886
# Trainable params: 2,886
# Non-trainable params: 0
# _________________________________________________________________
# 116/116 [==============================] - 1s 10ms/sample - loss: 4.3267 - accuracy: 0.5172
# Pre-training accuracy: 51.7241%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 250
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/model2_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 460 samples, validate on 116 samples
# Epoch 1/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.0800 - accuracy: 0.4907
# Epoch 00001: val_accuracy improved from -inf to 0.48276, saving model to models/model2_01.h5
# 460/460 [==============================] - 1s 2ms/sample - loss: 1.9915 - accuracy: 0.4978 - val_loss: 0.7037 - val_accuracy: 0.4828
# Epoch 2/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.7177 - accuracy: 0.5875
# Epoch 00002: val_accuracy did not improve from 0.48276
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.7175 - accuracy: 0.5848 - val_loss: 0.7066 - val_accuracy: 0.4828
# Epoch 3/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.6504 - accuracy: 0.6250
# Epoch 00003: val_accuracy did not improve from 0.48276
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.6450 - accuracy: 0.6326 - val_loss: 0.7296 - val_accuracy: 0.4828
# Epoch 4/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.5904 - accuracy: 0.6605
# Epoch 00004: val_accuracy did not improve from 0.48276
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.5829 - accuracy: 0.6674 - val_loss: 0.7022 - val_accuracy: 0.4828
# Epoch 5/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.5719 - accuracy: 0.7256
# Epoch 00005: val_accuracy did not improve from 0.48276
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.5805 - accuracy: 0.7130 - val_loss: 0.6911 - val_accuracy: 0.4828
# Epoch 6/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.4874 - accuracy: 0.7619
# Epoch 00006: val_accuracy improved from 0.48276 to 0.51724, saving model to models/model2_06.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.4998 - accuracy: 0.7500 - val_loss: 0.6382 - val_accuracy: 0.5172
# Epoch 7/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.4774 - accuracy: 0.7581
# Epoch 00007: val_accuracy improved from 0.51724 to 0.83621, saving model to models/model2_07.h5
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.4792 - accuracy: 0.7565 - val_loss: 0.4545 - val_accuracy: 0.8362
# Epoch 8/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.4128 - accuracy: 0.7953
# Epoch 00008: val_accuracy did not improve from 0.83621
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.4202 - accuracy: 0.7870 - val_loss: 0.5205 - val_accuracy: 0.6638
# Epoch 9/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.3831 - accuracy: 0.8167
# Epoch 00009: val_accuracy improved from 0.83621 to 0.86207, saving model to models/model2_09.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.3792 - accuracy: 0.8217 - val_loss: 0.3999 - val_accuracy: 0.8621
# Epoch 10/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.3863 - accuracy: 0.8186
# Epoch 00010: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.3868 - accuracy: 0.8196 - val_loss: 0.4253 - val_accuracy: 0.8190
# Epoch 11/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.3578 - accuracy: 0.8273
# Epoch 00011: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.3540 - accuracy: 0.8304 - val_loss: 0.4075 - val_accuracy: 0.8103
# Epoch 12/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.3877 - accuracy: 0.8167
# Epoch 00012: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.3882 - accuracy: 0.8174 - val_loss: 0.3628 - val_accuracy: 0.8276
# Epoch 13/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.3127 - accuracy: 0.8622
# Epoch 00013: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.3194 - accuracy: 0.8587 - val_loss: 0.3716 - val_accuracy: 0.8621
# Epoch 14/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.3362 - accuracy: 0.8600
# Epoch 00014: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.3327 - accuracy: 0.8652 - val_loss: 0.3477 - val_accuracy: 0.8448
# Epoch 15/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.3143 - accuracy: 0.8455
# Epoch 00015: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.3241 - accuracy: 0.8391 - val_loss: 0.3424 - val_accuracy: 0.8276
# Epoch 16/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.2849 - accuracy: 0.8689
# Epoch 00016: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2863 - accuracy: 0.8696 - val_loss: 0.3332 - val_accuracy: 0.8276
# Epoch 17/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2996 - accuracy: 0.8595
# Epoch 00017: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2965 - accuracy: 0.8652 - val_loss: 0.3748 - val_accuracy: 0.8362
# Epoch 18/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.3190 - accuracy: 0.8415
# Epoch 00018: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.3111 - accuracy: 0.8457 - val_loss: 0.3485 - val_accuracy: 0.8362
# Epoch 19/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.2692 - accuracy: 0.8707
# Epoch 00019: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2686 - accuracy: 0.8717 - val_loss: 0.3203 - val_accuracy: 0.8276
# Epoch 20/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2901 - accuracy: 0.8738
# Epoch 00020: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2862 - accuracy: 0.8696 - val_loss: 0.3158 - val_accuracy: 0.8017
# Epoch 21/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2764 - accuracy: 0.8810
# Epoch 00021: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2805 - accuracy: 0.8717 - val_loss: 0.3148 - val_accuracy: 0.8362
# Epoch 22/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.2587 - accuracy: 0.8976
# Epoch 00022: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2699 - accuracy: 0.8957 - val_loss: 0.3150 - val_accuracy: 0.8448
# Epoch 23/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.2864 - accuracy: 0.8732
# Epoch 00023: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2813 - accuracy: 0.8739 - val_loss: 0.3059 - val_accuracy: 0.8448
# Epoch 24/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2793 - accuracy: 0.8690
# Epoch 00024: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2780 - accuracy: 0.8696 - val_loss: 0.3036 - val_accuracy: 0.8276
# Epoch 25/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.2429 - accuracy: 0.8878
# Epoch 00025: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2431 - accuracy: 0.8848 - val_loss: 0.2989 - val_accuracy: 0.8276
# Epoch 26/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.2589 - accuracy: 0.8756
# Epoch 00026: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2679 - accuracy: 0.8739 - val_loss: 0.2934 - val_accuracy: 0.8276
# Epoch 27/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.2535 - accuracy: 0.8844
# Epoch 00027: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2505 - accuracy: 0.8870 - val_loss: 0.2930 - val_accuracy: 0.8362
# Epoch 28/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.2792 - accuracy: 0.8844
# Epoch 00028: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2791 - accuracy: 0.8848 - val_loss: 0.2932 - val_accuracy: 0.8276
# Epoch 29/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.2615 - accuracy: 0.8659
# Epoch 00029: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2601 - accuracy: 0.8674 - val_loss: 0.3100 - val_accuracy: 0.8448
# Epoch 30/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.2910 - accuracy: 0.8610
# Epoch 00030: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2840 - accuracy: 0.8630 - val_loss: 0.3288 - val_accuracy: 0.8103
# Epoch 31/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.2701 - accuracy: 0.8814
# Epoch 00031: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2709 - accuracy: 0.8761 - val_loss: 0.3047 - val_accuracy: 0.8448
# Epoch 32/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.2799 - accuracy: 0.8725
# Epoch 00032: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2716 - accuracy: 0.8783 - val_loss: 0.2819 - val_accuracy: 0.8362
# Epoch 33/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2558 - accuracy: 0.8786
# Epoch 00033: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2475 - accuracy: 0.8870 - val_loss: 0.2766 - val_accuracy: 0.8448
# Epoch 34/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2577 - accuracy: 0.8833
# Epoch 00034: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2621 - accuracy: 0.8848 - val_loss: 0.2823 - val_accuracy: 0.8448
# Epoch 35/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.2501 - accuracy: 0.8911
# Epoch 00035: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2535 - accuracy: 0.8891 - val_loss: 0.3069 - val_accuracy: 0.8276
# Epoch 36/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2468 - accuracy: 0.8905
# Epoch 00036: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2410 - accuracy: 0.8957 - val_loss: 0.2901 - val_accuracy: 0.8276
# Epoch 37/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2448 - accuracy: 0.8833
# Epoch 00037: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2369 - accuracy: 0.8913 - val_loss: 0.2921 - val_accuracy: 0.8276
# Epoch 38/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2433 - accuracy: 0.8952
# Epoch 00038: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2411 - accuracy: 0.8978 - val_loss: 0.2736 - val_accuracy: 0.8448
# Epoch 39/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2311 - accuracy: 0.8905
# Epoch 00039: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2424 - accuracy: 0.8870 - val_loss: 0.3433 - val_accuracy: 0.8017
# Epoch 40/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.2409 - accuracy: 0.8953
# Epoch 00040: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2331 - accuracy: 0.9000 - val_loss: 0.2663 - val_accuracy: 0.8448
# Epoch 41/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.2293 - accuracy: 0.8951
# Epoch 00041: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2296 - accuracy: 0.9000 - val_loss: 0.3448 - val_accuracy: 0.8190
# Epoch 42/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.2436 - accuracy: 0.8732
# Epoch 00042: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2431 - accuracy: 0.8717 - val_loss: 0.3900 - val_accuracy: 0.8276
# Epoch 43/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2476 - accuracy: 0.8714
# Epoch 00043: val_accuracy did not improve from 0.86207
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2438 - accuracy: 0.8739 - val_loss: 0.2675 - val_accuracy: 0.8448
# Epoch 44/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2155 - accuracy: 0.9000
# Epoch 00044: val_accuracy improved from 0.86207 to 0.87069, saving model to models/model2_44.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2198 - accuracy: 0.8978 - val_loss: 0.2506 - val_accuracy: 0.8707
# Epoch 45/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.2305 - accuracy: 0.9171
# Epoch 00045: val_accuracy did not improve from 0.87069
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2232 - accuracy: 0.9196 - val_loss: 0.2512 - val_accuracy: 0.8707
# Epoch 46/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2330 - accuracy: 0.8786
# Epoch 00046: val_accuracy did not improve from 0.87069
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2284 - accuracy: 0.8826 - val_loss: 0.2605 - val_accuracy: 0.8448
# Epoch 47/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2100 - accuracy: 0.9143
# Epoch 00047: val_accuracy did not improve from 0.87069
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2118 - accuracy: 0.9130 - val_loss: 0.2673 - val_accuracy: 0.8276
# Epoch 48/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.2236 - accuracy: 0.9075
# Epoch 00048: val_accuracy improved from 0.87069 to 0.89655, saving model to models/model2_48.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2145 - accuracy: 0.9109 - val_loss: 0.2304 - val_accuracy: 0.8966
# Epoch 49/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.2261 - accuracy: 0.8825
# Epoch 00049: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2231 - accuracy: 0.8848 - val_loss: 0.2564 - val_accuracy: 0.8362
# Epoch 50/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.2052 - accuracy: 0.9098
# Epoch 00050: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2084 - accuracy: 0.9065 - val_loss: 0.2675 - val_accuracy: 0.8276
# Epoch 51/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2179 - accuracy: 0.9048
# Epoch 00051: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2136 - accuracy: 0.9065 - val_loss: 0.2262 - val_accuracy: 0.8707
# Epoch 52/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2018 - accuracy: 0.8929
# Epoch 00052: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2002 - accuracy: 0.8978 - val_loss: 0.2188 - val_accuracy: 0.8879
# Epoch 53/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.2039 - accuracy: 0.9073
# Epoch 00053: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2180 - accuracy: 0.9022 - val_loss: 0.2168 - val_accuracy: 0.8966
# Epoch 54/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.2361 - accuracy: 0.8674
# Epoch 00054: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2289 - accuracy: 0.8739 - val_loss: 0.2216 - val_accuracy: 0.8879
# Epoch 55/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.2054 - accuracy: 0.9098
# Epoch 00055: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1947 - accuracy: 0.9174 - val_loss: 0.2566 - val_accuracy: 0.8534
# Epoch 56/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.2197 - accuracy: 0.8927
# Epoch 00056: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2146 - accuracy: 0.8978 - val_loss: 0.2118 - val_accuracy: 0.8966
# Epoch 57/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.2065 - accuracy: 0.9098
# Epoch 00057: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2124 - accuracy: 0.9065 - val_loss: 0.2460 - val_accuracy: 0.8621
# Epoch 58/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.2189 - accuracy: 0.9000
# Epoch 00058: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2171 - accuracy: 0.8978 - val_loss: 0.2070 - val_accuracy: 0.8966
# Epoch 59/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2008 - accuracy: 0.9071
# Epoch 00059: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1951 - accuracy: 0.9130 - val_loss: 0.2286 - val_accuracy: 0.8707
# Epoch 60/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1953 - accuracy: 0.9262
# Epoch 00060: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1946 - accuracy: 0.9239 - val_loss: 0.2135 - val_accuracy: 0.8793
# Epoch 61/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1852 - accuracy: 0.9317
# Epoch 00061: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1916 - accuracy: 0.9283 - val_loss: 0.2771 - val_accuracy: 0.8534
# Epoch 62/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2131 - accuracy: 0.9119
# Epoch 00062: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2063 - accuracy: 0.9130 - val_loss: 0.2402 - val_accuracy: 0.8621
# Epoch 63/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2071 - accuracy: 0.9143
# Epoch 00063: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2018 - accuracy: 0.9152 - val_loss: 0.2074 - val_accuracy: 0.8966
# Epoch 64/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1766 - accuracy: 0.9186
# Epoch 00064: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1752 - accuracy: 0.9174 - val_loss: 0.2059 - val_accuracy: 0.8879
# Epoch 65/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1690 - accuracy: 0.9214
# Epoch 00065: val_accuracy improved from 0.89655 to 0.91379, saving model to models/model2_65.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1682 - accuracy: 0.9239 - val_loss: 0.1832 - val_accuracy: 0.9138
# Epoch 66/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1582 - accuracy: 0.9349
# Epoch 00066: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1623 - accuracy: 0.9348 - val_loss: 0.2044 - val_accuracy: 0.8707
# Epoch 67/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1735 - accuracy: 0.9209
# Epoch 00067: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1727 - accuracy: 0.9217 - val_loss: 0.1842 - val_accuracy: 0.8879
# Epoch 68/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1652 - accuracy: 0.9317
# Epoch 00068: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1589 - accuracy: 0.9370 - val_loss: 0.1775 - val_accuracy: 0.8879
# Epoch 69/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1552 - accuracy: 0.9366
# Epoch 00069: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1511 - accuracy: 0.9391 - val_loss: 0.2016 - val_accuracy: 0.8879
# Epoch 70/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1792 - accuracy: 0.9268
# Epoch 00070: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1801 - accuracy: 0.9217 - val_loss: 0.1710 - val_accuracy: 0.9138
# Epoch 71/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1711 - accuracy: 0.9268
# Epoch 00071: val_accuracy improved from 0.91379 to 0.92241, saving model to models/model2_71.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1667 - accuracy: 0.9304 - val_loss: 0.1523 - val_accuracy: 0.9224
# Epoch 72/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1805 - accuracy: 0.9095
# Epoch 00072: val_accuracy did not improve from 0.92241
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1837 - accuracy: 0.9065 - val_loss: 0.1941 - val_accuracy: 0.8966
# Epoch 73/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1614 - accuracy: 0.9238
# Epoch 00073: val_accuracy improved from 0.92241 to 0.93966, saving model to models/model2_73.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1667 - accuracy: 0.9196 - val_loss: 0.1501 - val_accuracy: 0.9397
# Epoch 74/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1708 - accuracy: 0.9262
# Epoch 00074: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1626 - accuracy: 0.9326 - val_loss: 0.1583 - val_accuracy: 0.9138
# Epoch 75/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1685 - accuracy: 0.9220
# Epoch 00075: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1698 - accuracy: 0.9174 - val_loss: 0.1402 - val_accuracy: 0.9397
# Epoch 76/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1587 - accuracy: 0.9286
# Epoch 00076: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1606 - accuracy: 0.9304 - val_loss: 0.2109 - val_accuracy: 0.9310
# Epoch 77/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1662 - accuracy: 0.9317
# Epoch 00077: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1644 - accuracy: 0.9348 - val_loss: 0.1514 - val_accuracy: 0.9224
# Epoch 78/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.1598 - accuracy: 0.9267
# Epoch 00078: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1581 - accuracy: 0.9283 - val_loss: 0.1557 - val_accuracy: 0.8966
# Epoch 79/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1648 - accuracy: 0.9333
# Epoch 00079: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1590 - accuracy: 0.9348 - val_loss: 0.1474 - val_accuracy: 0.9052
# Epoch 80/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1579 - accuracy: 0.9439
# Epoch 00080: val_accuracy improved from 0.93966 to 0.96552, saving model to models/model2_80.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1521 - accuracy: 0.9457 - val_loss: 0.1200 - val_accuracy: 0.9655
# Epoch 81/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1816 - accuracy: 0.9244
# Epoch 00081: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1734 - accuracy: 0.9304 - val_loss: 0.1167 - val_accuracy: 0.9655
# Epoch 82/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1507 - accuracy: 0.9381
# Epoch 00082: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1570 - accuracy: 0.9348 - val_loss: 0.1854 - val_accuracy: 0.8793
# Epoch 83/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1916 - accuracy: 0.9146
# Epoch 00083: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1893 - accuracy: 0.9130 - val_loss: 0.1278 - val_accuracy: 0.9655
# Epoch 84/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1515 - accuracy: 0.9357
# Epoch 00084: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1448 - accuracy: 0.9391 - val_loss: 0.1190 - val_accuracy: 0.9569
# Epoch 85/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1482 - accuracy: 0.9390
# Epoch 00085: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1413 - accuracy: 0.9435 - val_loss: 0.1248 - val_accuracy: 0.9397
# Epoch 86/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.1491 - accuracy: 0.9318
# Epoch 00086: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1474 - accuracy: 0.9304 - val_loss: 0.1478 - val_accuracy: 0.8879
# Epoch 87/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1683 - accuracy: 0.9463
# Epoch 00087: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1627 - accuracy: 0.9478 - val_loss: 0.1430 - val_accuracy: 0.9052
# Epoch 88/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1089 - accuracy: 0.9634
# Epoch 00088: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1114 - accuracy: 0.9630 - val_loss: 0.1060 - val_accuracy: 0.9655
# Epoch 89/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1391 - accuracy: 0.9439
# Epoch 00089: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1311 - accuracy: 0.9478 - val_loss: 0.1597 - val_accuracy: 0.8966
# Epoch 90/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1311 - accuracy: 0.9643
# Epoch 00090: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1488 - accuracy: 0.9543 - val_loss: 0.1396 - val_accuracy: 0.9397
# Epoch 91/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1340 - accuracy: 0.9488
# Epoch 00091: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1409 - accuracy: 0.9457 - val_loss: 0.1060 - val_accuracy: 0.9655
# Epoch 92/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.1243 - accuracy: 0.9500
# Epoch 00092: val_accuracy improved from 0.96552 to 0.97414, saving model to models/model2_92.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1213 - accuracy: 0.9522 - val_loss: 0.0965 - val_accuracy: 0.9741
# Epoch 93/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0974 - accuracy: 0.9690
# Epoch 00093: val_accuracy improved from 0.97414 to 0.99138, saving model to models/model2_93.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1007 - accuracy: 0.9674 - val_loss: 0.0855 - val_accuracy: 0.9914
# Epoch 94/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1047 - accuracy: 0.9537
# Epoch 00094: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1055 - accuracy: 0.9543 - val_loss: 0.0863 - val_accuracy: 0.9828
# Epoch 95/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1072 - accuracy: 0.9524
# Epoch 00095: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1101 - accuracy: 0.9478 - val_loss: 0.0813 - val_accuracy: 0.9914
# Epoch 96/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1024 - accuracy: 0.9595
# Epoch 00096: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1039 - accuracy: 0.9609 - val_loss: 0.0842 - val_accuracy: 0.9741
# Epoch 97/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1183 - accuracy: 0.9500
# Epoch 00097: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1224 - accuracy: 0.9478 - val_loss: 0.0885 - val_accuracy: 0.9828
# Epoch 98/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1055 - accuracy: 0.9659
# Epoch 00098: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1074 - accuracy: 0.9609 - val_loss: 0.0835 - val_accuracy: 0.9828
# Epoch 99/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1284 - accuracy: 0.9465
# Epoch 00099: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1290 - accuracy: 0.9457 - val_loss: 0.0867 - val_accuracy: 0.9828
# Epoch 100/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1041 - accuracy: 0.9619
# Epoch 00100: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0995 - accuracy: 0.9652 - val_loss: 0.0798 - val_accuracy: 0.9828
# Epoch 101/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0974 - accuracy: 0.9683
# Epoch 00101: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1036 - accuracy: 0.9652 - val_loss: 0.0953 - val_accuracy: 0.9741
# Epoch 102/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1307 - accuracy: 0.9488
# Epoch 00102: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1325 - accuracy: 0.9500 - val_loss: 0.0873 - val_accuracy: 0.9655
# Epoch 103/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1013 - accuracy: 0.9571
# Epoch 00103: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1025 - accuracy: 0.9543 - val_loss: 0.0844 - val_accuracy: 0.9741
# Epoch 104/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0976 - accuracy: 0.9634
# Epoch 00104: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1093 - accuracy: 0.9522 - val_loss: 0.0901 - val_accuracy: 0.9655
# Epoch 105/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1233 - accuracy: 0.9537
# Epoch 00105: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1171 - accuracy: 0.9565 - val_loss: 0.0722 - val_accuracy: 0.9828
# Epoch 106/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0858 - accuracy: 0.9690
# Epoch 00106: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0855 - accuracy: 0.9696 - val_loss: 0.0696 - val_accuracy: 0.9828
# Epoch 107/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1023 - accuracy: 0.9595
# Epoch 00107: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1043 - accuracy: 0.9565 - val_loss: 0.0788 - val_accuracy: 0.9741
# Epoch 108/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0797 - accuracy: 0.9707
# Epoch 00108: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0788 - accuracy: 0.9696 - val_loss: 0.0651 - val_accuracy: 0.9828
# Epoch 109/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0920 - accuracy: 0.9750
# Epoch 00109: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0946 - accuracy: 0.9717 - val_loss: 0.0657 - val_accuracy: 0.9914
# Epoch 110/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1358 - accuracy: 0.9442
# Epoch 00110: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1298 - accuracy: 0.9478 - val_loss: 0.0815 - val_accuracy: 0.9741
# Epoch 111/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0977 - accuracy: 0.9634
# Epoch 00111: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0928 - accuracy: 0.9674 - val_loss: 0.0610 - val_accuracy: 0.9914
# Epoch 112/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0883 - accuracy: 0.9628
# Epoch 00112: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0854 - accuracy: 0.9652 - val_loss: 0.0610 - val_accuracy: 0.9828
# Epoch 113/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1002 - accuracy: 0.9585
# Epoch 00113: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0987 - accuracy: 0.9609 - val_loss: 0.0636 - val_accuracy: 0.9914
# Epoch 114/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1228 - accuracy: 0.9585
# Epoch 00114: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1213 - accuracy: 0.9587 - val_loss: 0.0759 - val_accuracy: 0.9914
# Epoch 115/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0791 - accuracy: 0.9667
# Epoch 00115: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0845 - accuracy: 0.9652 - val_loss: 0.0814 - val_accuracy: 0.9655
# Epoch 116/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0643 - accuracy: 0.9767
# Epoch 00116: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0699 - accuracy: 0.9717 - val_loss: 0.0663 - val_accuracy: 0.9914
# Epoch 117/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0897 - accuracy: 0.9585
# Epoch 00117: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0896 - accuracy: 0.9587 - val_loss: 0.0606 - val_accuracy: 0.9914
# Epoch 118/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0869 - accuracy: 0.9721
# Epoch 00118: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0854 - accuracy: 0.9739 - val_loss: 0.0805 - val_accuracy: 0.9741
# Epoch 119/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0843 - accuracy: 0.9628
# Epoch 00119: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0790 - accuracy: 0.9652 - val_loss: 0.0540 - val_accuracy: 0.9914
# Epoch 120/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0734 - accuracy: 0.9762
# Epoch 00120: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0730 - accuracy: 0.9783 - val_loss: 0.0542 - val_accuracy: 0.9828
# Epoch 121/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1019 - accuracy: 0.9585
# Epoch 00121: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0999 - accuracy: 0.9587 - val_loss: 0.0551 - val_accuracy: 0.9828
# Epoch 122/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0631 - accuracy: 0.9900
# Epoch 00122: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0602 - accuracy: 0.9891 - val_loss: 0.0599 - val_accuracy: 0.9828
# Epoch 123/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0933 - accuracy: 0.9610
# Epoch 00123: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0854 - accuracy: 0.9652 - val_loss: 0.0503 - val_accuracy: 0.9914
# Epoch 124/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0583 - accuracy: 0.9810
# Epoch 00124: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0642 - accuracy: 0.9761 - val_loss: 0.0396 - val_accuracy: 0.9914
# Epoch 125/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0617 - accuracy: 0.9805
# Epoch 00125: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0617 - accuracy: 0.9804 - val_loss: 0.0555 - val_accuracy: 0.9828
# Epoch 126/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0644 - accuracy: 0.9805
# Epoch 00126: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0697 - accuracy: 0.9739 - val_loss: 0.0395 - val_accuracy: 0.9914
# Epoch 127/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0919 - accuracy: 0.9628
# Epoch 00127: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0891 - accuracy: 0.9630 - val_loss: 0.0495 - val_accuracy: 0.9828
# Epoch 128/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0635 - accuracy: 0.9857
# Epoch 00128: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0606 - accuracy: 0.9870 - val_loss: 0.0453 - val_accuracy: 0.9828
# Epoch 129/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0693 - accuracy: 0.9732
# Epoch 00129: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0766 - accuracy: 0.9696 - val_loss: 0.0396 - val_accuracy: 0.9914
# Epoch 130/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0668 - accuracy: 0.9725
# Epoch 00130: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0645 - accuracy: 0.9739 - val_loss: 0.0412 - val_accuracy: 0.9914
# Epoch 131/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0707 - accuracy: 0.9762
# Epoch 00131: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0658 - accuracy: 0.9783 - val_loss: 0.0761 - val_accuracy: 0.9741
# Epoch 132/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0815 - accuracy: 0.9732
# Epoch 00132: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0779 - accuracy: 0.9739 - val_loss: 0.0462 - val_accuracy: 0.9828
# Epoch 133/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0442 - accuracy: 0.9854
# Epoch 00133: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0487 - accuracy: 0.9804 - val_loss: 0.0330 - val_accuracy: 0.9914
# Epoch 134/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0603 - accuracy: 0.9810
# Epoch 00134: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0615 - accuracy: 0.9783 - val_loss: 0.0324 - val_accuracy: 0.9914
# Epoch 135/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0754 - accuracy: 0.9732
# Epoch 00135: val_accuracy improved from 0.99138 to 1.00000, saving model to models/model2_135.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0689 - accuracy: 0.9761 - val_loss: 0.0298 - val_accuracy: 1.0000
# Epoch 136/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0491 - accuracy: 0.9786
# Epoch 00136: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0470 - accuracy: 0.9804 - val_loss: 0.0355 - val_accuracy: 0.9828
# Epoch 137/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0522 - accuracy: 0.9756
# Epoch 00137: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0509 - accuracy: 0.9783 - val_loss: 0.0406 - val_accuracy: 1.0000
# Epoch 138/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0328 - accuracy: 0.9905
# Epoch 00138: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0426 - accuracy: 0.9870 - val_loss: 0.0355 - val_accuracy: 0.9828
# Epoch 139/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0584 - accuracy: 0.9833
# Epoch 00139: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0564 - accuracy: 0.9826 - val_loss: 0.0298 - val_accuracy: 1.0000
# Epoch 140/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0532 - accuracy: 0.9805
# Epoch 00140: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0676 - accuracy: 0.9739 - val_loss: 0.0352 - val_accuracy: 0.9914
# Epoch 141/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0750 - accuracy: 0.9690
# Epoch 00141: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0719 - accuracy: 0.9717 - val_loss: 0.0353 - val_accuracy: 0.9914
# Epoch 142/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0465 - accuracy: 0.9881
# Epoch 00142: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0520 - accuracy: 0.9826 - val_loss: 0.0343 - val_accuracy: 0.9914
# Epoch 143/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0570 - accuracy: 0.9837
# Epoch 00143: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0566 - accuracy: 0.9848 - val_loss: 0.0285 - val_accuracy: 0.9914
# Epoch 144/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0742 - accuracy: 0.9667
# Epoch 00144: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0726 - accuracy: 0.9674 - val_loss: 0.0375 - val_accuracy: 0.9828
# Epoch 145/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0591 - accuracy: 0.9786
# Epoch 00145: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0664 - accuracy: 0.9739 - val_loss: 0.0498 - val_accuracy: 0.9828
# Epoch 146/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0673 - accuracy: 0.9714
# Epoch 00146: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0650 - accuracy: 0.9717 - val_loss: 0.0415 - val_accuracy: 0.9828
# Epoch 147/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0408 - accuracy: 0.9857
# Epoch 00147: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0409 - accuracy: 0.9870 - val_loss: 0.0302 - val_accuracy: 1.0000
# Epoch 148/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0569 - accuracy: 0.9810
# Epoch 00148: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0561 - accuracy: 0.9804 - val_loss: 0.0295 - val_accuracy: 0.9914
# Epoch 149/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0475 - accuracy: 0.9805
# Epoch 00149: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0442 - accuracy: 0.9826 - val_loss: 0.0314 - val_accuracy: 0.9914
# Epoch 150/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0311 - accuracy: 0.9900
# Epoch 00150: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0354 - accuracy: 0.9891 - val_loss: 0.0369 - val_accuracy: 1.0000
# Epoch 151/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1020 - accuracy: 0.9610
# Epoch 00151: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0969 - accuracy: 0.9630 - val_loss: 0.0352 - val_accuracy: 1.0000
# Epoch 152/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0843 - accuracy: 0.9689
# Epoch 00152: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0853 - accuracy: 0.9696 - val_loss: 0.0399 - val_accuracy: 0.9828
# Epoch 153/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0624 - accuracy: 0.9878
# Epoch 00153: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0563 - accuracy: 0.9891 - val_loss: 0.0749 - val_accuracy: 0.9655
# Epoch 154/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0497 - accuracy: 0.9786
# Epoch 00154: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0546 - accuracy: 0.9761 - val_loss: 0.0304 - val_accuracy: 0.9914
# Epoch 155/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0538 - accuracy: 0.9857
# Epoch 00155: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0507 - accuracy: 0.9870 - val_loss: 0.0335 - val_accuracy: 0.9914
# Epoch 156/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0301 - accuracy: 0.9925
# Epoch 00156: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0285 - accuracy: 0.9935 - val_loss: 0.0328 - val_accuracy: 0.9828
# Epoch 157/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0820 - accuracy: 0.9732
# Epoch 00157: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0843 - accuracy: 0.9739 - val_loss: 0.0641 - val_accuracy: 0.9828
# Epoch 158/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0357 - accuracy: 0.9881
# Epoch 00158: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0334 - accuracy: 0.9891 - val_loss: 0.0275 - val_accuracy: 0.9914
# Epoch 159/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0282 - accuracy: 0.9976
# Epoch 00159: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0300 - accuracy: 0.9957 - val_loss: 0.0223 - val_accuracy: 1.0000
# Epoch 160/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0343 - accuracy: 0.9927
# Epoch 00160: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0324 - accuracy: 0.9935 - val_loss: 0.0304 - val_accuracy: 0.9914
# Epoch 161/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0426 - accuracy: 0.9805
# Epoch 00161: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0393 - accuracy: 0.9826 - val_loss: 0.0309 - val_accuracy: 0.9828
# Epoch 162/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0421 - accuracy: 0.9902
# Epoch 00162: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0433 - accuracy: 0.9870 - val_loss: 0.0508 - val_accuracy: 0.9741
# Epoch 163/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0948 - accuracy: 0.9714
# Epoch 00163: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0973 - accuracy: 0.9674 - val_loss: 0.0546 - val_accuracy: 0.9828
# Epoch 164/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0682 - accuracy: 0.9805
# Epoch 00164: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0666 - accuracy: 0.9804 - val_loss: 0.0428 - val_accuracy: 0.9828
# Epoch 165/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0473 - accuracy: 0.9829
# Epoch 00165: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0520 - accuracy: 0.9783 - val_loss: 0.0360 - val_accuracy: 0.9828
# Epoch 166/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0332 - accuracy: 0.9929
# Epoch 00166: val_accuracy did not improve from 1.00000
# ...
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 196/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0157 - accuracy: 0.9933
# Epoch 00196: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0154 - accuracy: 0.9935 - val_loss: 0.0204 - val_accuracy: 0.9914
# Epoch 197/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0126 - accuracy: 0.9976
# Epoch 00197: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0117 - accuracy: 0.9978 - val_loss: 0.0172 - val_accuracy: 1.0000
# Epoch 198/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0197 - accuracy: 0.9927
# Epoch 00198: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0213 - accuracy: 0.9913 - val_loss: 0.0315 - val_accuracy: 0.9828
# Epoch 199/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0205 - accuracy: 0.9975
# Epoch 00199: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0311 - accuracy: 0.9957 - val_loss: 0.0225 - val_accuracy: 0.9914
# Epoch 200/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0279 - accuracy: 0.9878
# Epoch 00200: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0309 - accuracy: 0.9870 - val_loss: 0.0162 - val_accuracy: 1.0000
# Epoch 201/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0262 - accuracy: 0.9878
# Epoch 00201: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0291 - accuracy: 0.9870 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 202/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0217 - accuracy: 0.9932
# Epoch 00202: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0219 - accuracy: 0.9935 - val_loss: 0.0104 - val_accuracy: 1.0000
# Epoch 203/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0192 - accuracy: 0.9977
# Epoch 00203: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0183 - accuracy: 0.9978 - val_loss: 0.0249 - val_accuracy: 0.9828
# Epoch 204/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0220 - accuracy: 0.9950
# Epoch 00204: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0214 - accuracy: 0.9957 - val_loss: 0.0137 - val_accuracy: 1.0000
# Epoch 205/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0151 - accuracy: 0.9976
# Epoch 00205: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0213 - accuracy: 0.9957 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 206/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0201 - accuracy: 0.9951
# Epoch 00206: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0194 - accuracy: 0.9957 - val_loss: 0.0671 - val_accuracy: 0.9483
# Epoch 207/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0209 - accuracy: 0.9977
# Epoch 00207: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0199 - accuracy: 0.9978 - val_loss: 0.0241 - val_accuracy: 0.9914
# Epoch 208/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0217 - accuracy: 0.9925
# Epoch 00208: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0191 - accuracy: 0.9935 - val_loss: 0.0205 - val_accuracy: 0.9914
# Epoch 209/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0202 - accuracy: 0.9953
# Epoch 00209: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0197 - accuracy: 0.9957 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 210/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0181 - accuracy: 0.9953
# Epoch 00210: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0171 - accuracy: 0.9957 - val_loss: 0.0176 - val_accuracy: 0.9914
# Epoch 211/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0982 - accuracy: 0.9689
# Epoch 00211: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0961 - accuracy: 0.9696 - val_loss: 0.0184 - val_accuracy: 0.9914
# Epoch 212/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0270 - accuracy: 0.9907
# Epoch 00212: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0272 - accuracy: 0.9913 - val_loss: 0.0248 - val_accuracy: 0.9914
# Epoch 213/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0285 - accuracy: 0.9909
# Epoch 00213: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0326 - accuracy: 0.9891 - val_loss: 0.0166 - val_accuracy: 1.0000
# Epoch 214/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0367 - accuracy: 0.9881
# Epoch 00214: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0346 - accuracy: 0.9891 - val_loss: 0.0169 - val_accuracy: 1.0000
# Epoch 215/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0142 - accuracy: 0.9950
# Epoch 00215: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0130 - accuracy: 0.9957 - val_loss: 0.0143 - val_accuracy: 1.0000
# Epoch 216/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0464 - accuracy: 0.9825
# Epoch 00216: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0451 - accuracy: 0.9826 - val_loss: 0.0276 - val_accuracy: 0.9828
# Epoch 217/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0517 - accuracy: 0.9844
# Epoch 00217: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0511 - accuracy: 0.9848 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 218/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1533 - accuracy: 0.9439
# Epoch 00218: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1448 - accuracy: 0.9457 - val_loss: 0.0459 - val_accuracy: 0.9741
# Epoch 219/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0555 - accuracy: 0.9867
# Epoch 00219: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0544 - accuracy: 0.9870 - val_loss: 0.0321 - val_accuracy: 0.9828
# Epoch 220/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0331 - accuracy: 0.9902
# Epoch 00220: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0314 - accuracy: 0.9913 - val_loss: 0.0227 - val_accuracy: 0.9914
# Epoch 221/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0227 - accuracy: 0.9951
# Epoch 00221: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0207 - accuracy: 0.9957 - val_loss: 0.0221 - val_accuracy: 0.9914
# Epoch 222/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0265 - accuracy: 0.9930
# Epoch 00222: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0253 - accuracy: 0.9935 - val_loss: 0.0190 - val_accuracy: 0.9914
# Epoch 223/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0265 - accuracy: 0.9905
# Epoch 00223: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0260 - accuracy: 0.9913 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 224/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0316 - accuracy: 0.9867
# Epoch 00224: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0325 - accuracy: 0.9870 - val_loss: 0.0255 - val_accuracy: 1.0000
# Epoch 225/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0185 - accuracy: 0.9975
# Epoch 00225: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0174 - accuracy: 0.9978 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 226/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0219 - accuracy: 0.9927
# Epoch 00226: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0229 - accuracy: 0.9913 - val_loss: 0.0097 - val_accuracy: 1.0000
# Epoch 227/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0160 - accuracy: 0.9925
# Epoch 00227: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0168 - accuracy: 0.9935 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 228/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0260 - accuracy: 0.9932
# Epoch 00228: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0250 - accuracy: 0.9935 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 229/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0148 - accuracy: 0.9951
# Epoch 00229: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0139 - accuracy: 0.9957 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 230/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0372 - accuracy: 0.9911
# Epoch 00230: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0369 - accuracy: 0.9913 - val_loss: 0.0200 - val_accuracy: 1.0000
# Epoch 231/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0220 - accuracy: 0.9952
# Epoch 00231: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0218 - accuracy: 0.9957 - val_loss: 0.0186 - val_accuracy: 1.0000
# Epoch 232/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0208 - accuracy: 0.9929
# Epoch 00232: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0228 - accuracy: 0.9913 - val_loss: 0.0281 - val_accuracy: 0.9828
# Epoch 233/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0198 - accuracy: 0.9953
# Epoch 00233: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0186 - accuracy: 0.9957 - val_loss: 0.0139 - val_accuracy: 1.0000
# Epoch 234/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0103 - accuracy: 0.9956
# Epoch 00234: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0101 - accuracy: 0.9957 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 235/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0129 - accuracy: 0.9953
# Epoch 00235: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0128 - accuracy: 0.9957 - val_loss: 0.0156 - val_accuracy: 1.0000
# Epoch 236/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0122 - accuracy: 0.9976
# Epoch 00236: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0123 - accuracy: 0.9978 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 237/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0084 - accuracy: 0.9978
# Epoch 00237: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0082 - accuracy: 0.9978 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 238/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0090 - accuracy: 0.9977
# Epoch 00238: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0086 - accuracy: 0.9978 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 239/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0207 - accuracy: 0.9929
# Epoch 00239: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0196 - accuracy: 0.9935 - val_loss: 0.0140 - val_accuracy: 1.0000
# Epoch 240/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0127 - accuracy: 0.9952
# Epoch 00240: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0180 - accuracy: 0.9913 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 241/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0237 - accuracy: 0.9929
# Epoch 00241: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0222 - accuracy: 0.9935 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 242/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1105 - accuracy: 0.9634
# Epoch 00242: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1016 - accuracy: 0.9652 - val_loss: 0.0264 - val_accuracy: 0.9828
# Epoch 243/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0169 - accuracy: 0.9977
# Epoch 00243: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0160 - accuracy: 0.9978 - val_loss: 0.0236 - val_accuracy: 0.9828
# Epoch 244/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0117 - accuracy: 0.9976
# Epoch 00244: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0133 - accuracy: 0.9978 - val_loss: 0.0160 - val_accuracy: 1.0000
# Epoch 245/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0178 - accuracy: 0.9909
# Epoch 00245: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0209 - accuracy: 0.9891 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 246/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0266 - accuracy: 0.9902
# Epoch 00246: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0275 - accuracy: 0.9891 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 247/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0219 - accuracy: 0.9951
# Epoch 00247: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0204 - accuracy: 0.9957 - val_loss: 0.0123 - val_accuracy: 1.0000
# Epoch 248/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0127 - accuracy: 0.9952
# Epoch 00248: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0129 - accuracy: 0.9957 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 249/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0096 - accuracy: 0.9952
# Epoch 00249: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0096 - accuracy: 0.9957 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 250/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0213 - accuracy: 0.9884
# Epoch 00250: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0205 - accuracy: 0.9891 - val_loss: 0.0248 - val_accuracy: 1.0000
# Training completed in time:  0:02:07.881855

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste
#
# Lembrando que estamos utilizando o mesmo conjunto de validacão, que a princípio, pode incluir instâncias do conjunto de treinamento: o dataset utilizado foi gerado com corte de áudio, então alguns trechos do mesmo áudio podem estar presentes em ambos os conjuntos de treinamento e teste.
# Por ora deixamos assim já que estamos realizando uma investigacão inicial.

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.98695654
# Testing Accuracy:  1.0

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       1.00      1.00      1.00        56
#    Pneumonia       1.00      1.00      1.00        60
#
#     accuracy                           1.00       116
#    macro avg       1.00      1.00      1.00       116
# weighted avg       1.00      1.00      1.00       116

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[56  0]
#  [ 0 60]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])
