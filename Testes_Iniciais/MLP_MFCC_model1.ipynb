# %%
# !unzip respiratory-sound-database.zip

# %%
# Load various imports 
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
mypath = "./Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/"
filenames = [f for f in listdir(mypath) if (isfile(join(mypath, f)) and f.endswith('.wav'))]

# %%
p_id_in_file = [] # patient IDs corresponding to each file
for name in filenames:
    p_id_in_file.append(int(name[:3]))

p_id_in_file = np.array(p_id_in_file)

# %%
max_pad_len = 862 # to make the length of all MFCC equal


os.makedirs("./Respiratory_Sound_Database/features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
    if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
        return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=20) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./Respiratory_Sound_Database/features/", feature), mfccs)
    return mfccs

# %%
filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
p_diag = pd.read_csv("./Respiratory_Sound_Database/Respiratory_Sound_Database/patient_diagnosis.csv",header=None) # patient diagnosis file

# %%
labels = np.array([p_diag[p_diag[0] == x][1].values[0] for x in p_id_in_file]) # labels for audio files

# %%
features = [] 

# Iterate through each sound file and extract the features
for file_name in filepaths:
    data = extract_features(file_name)
    features.append(data)

print('Finished feature extraction from ', len(features), ' files')
features = np.array(features)
# Out:
# Finished feature extraction from  920  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
features = np.array(features) # convert to numpy array

# %%
np.unique(labels)
# Out:
# array(['Asthma', 'Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy',
#        'LRTI', 'Pneumonia', 'URTI'], dtype='<U14')

# %%
# delete diseases
'''
features1 = features
labels1 = labels'''

features1 = np.delete(features, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0) 

labels1 = np.delete(labels, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0)

# %%
# print class counts
unique_elements, counts_elements = np.unique(labels1, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['35' '37']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(labels1)
oh_labels = to_categorical(i_labels)

# %%
features1.shape
# Out:
# (72, 40, 862)

# %%
input_dim = features1.shape[1]*features1.shape[2]
features1 = np.reshape(features1, (features1.shape[0], input_dim))
print(features1.shape, labels1.shape)
# Out:
# (72, 34480) (72,)

# %%
# train test split
x_train, x_test, y_train, y_test = train_test_split(features1, oh_labels, stratify=oh_labels, 
                                                    test_size=0.2, random_state = 42)

# %% [markdown]
# **MLP model architecture**

# %%
num_labels = oh_labels.shape[1]
# Construct model 
model = Sequential()
model.add(Dense(500, input_dim=input_dim, activation='relu'))

model.add(Dense(500, activation='relu'))
model.add(Dropout(0.15))

model.add(Dense(500, activation='relu'))
model.add(Dropout(0.15))

model.add(Dense(500, activation='relu'))
model.add(Dropout(0.15))

model.add(Dense(500, activation='relu'))
model.add(Dropout(0.15))

model.add(Dense(500, activation='relu'))
model.add(Dropout(0.15))

model.add(Dense(500, activation='relu'))

model.add(Dense(500, activation='relu'))

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 500)               17240500
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dropout (Dropout)            (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_7 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 1002
# =================================================================
# Total params: 18,995,002
# Trainable params: 18,995,002
# Non-trainable params: 0
# _________________________________________________________________
# 15/15 [==============================] - 0s 17ms/sample - loss: 1.3282 - accuracy: 0.5333
# Pre-training accuracy: 53.3333%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 250
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/model2_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 57 samples, validate on 15 samples
# Epoch 1/250
# 10/57 [====>.........................] - ETA: 2s - loss: 8.0051 - accuracy: 0.6000
# Epoch 00001: val_accuracy improved from -inf to 0.53333, saving model to models/model2_01.h5
# 57/57 [==============================] - 1s 23ms/sample - loss: 171.6881 - accuracy: 0.3860 - val_loss: 45.1926 - val_accuracy: 0.5333
# Epoch 2/250
# 50/57 [=========================>....] - ETA: 0s - loss: 36.6453 - accuracy: 0.5200
# Epoch 00002: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 2ms/sample - loss: 41.6413 - accuracy: 0.4912 - val_loss: 16.3483 - val_accuracy: 0.4667
# Epoch 3/250
# 50/57 [=========================>....] - ETA: 0s - loss: 29.9734 - accuracy: 0.5800
# Epoch 00003: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 2ms/sample - loss: 31.1912 - accuracy: 0.5614 - val_loss: 8.0113 - val_accuracy: 0.4667
# Epoch 4/250
# 50/57 [=========================>....] - ETA: 0s - loss: 21.6900 - accuracy: 0.4800
# Epoch 00004: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 2ms/sample - loss: 20.2422 - accuracy: 0.4737 - val_loss: 4.6284 - val_accuracy: 0.4667
# Epoch 5/250
# 50/57 [=========================>....] - ETA: 0s - loss: 8.7574 - accuracy: 0.5600
# Epoch 00005: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 2ms/sample - loss: 8.1545 - accuracy: 0.5789 - val_loss: 6.6689 - val_accuracy: 0.5333
# Epoch 6/250
# 50/57 [=========================>....] - ETA: 0s - loss: 8.4175 - accuracy: 0.5400
# Epoch 00006: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 2ms/sample - loss: 8.0513 - accuracy: 0.5439 - val_loss: 17.5637 - val_accuracy: 0.5333
# Epoch 7/250
# 50/57 [=========================>....] - ETA: 0s - loss: 8.7486 - accuracy: 0.5200
# Epoch 00007: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 2ms/sample - loss: 7.6916 - accuracy: 0.5614 - val_loss: 10.1779 - val_accuracy: 0.4667
# Epoch 8/250
# 50/57 [=========================>....] - ETA: 0s - loss: 7.3056 - accuracy: 0.4600
# Epoch 00008: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 1ms/sample - loss: 6.6278 - accuracy: 0.4737 - val_loss: 1.9027 - val_accuracy: 0.5333
# Epoch 9/250
# 50/57 [=========================>....] - ETA: 0s - loss: 1.2063 - accuracy: 0.5400
# Epoch 00009: val_accuracy improved from 0.53333 to 0.66667, saving model to models/model2_09.h5
# 57/57 [==============================] - 1s 14ms/sample - loss: 1.2578 - accuracy: 0.5088 - val_loss: 0.6036 - val_accuracy: 0.6667
# Epoch 10/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.8937 - accuracy: 0.5800
# Epoch 00010: val_accuracy did not improve from 0.66667
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.9486 - accuracy: 0.5614 - val_loss: 0.5934 - val_accuracy: 0.6000
# Epoch 11/250
# 50/57 [=========================>....] - ETA: 0s - loss: 1.2497 - accuracy: 0.5000
# Epoch 00011: val_accuracy did not improve from 0.66667
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.2090 - accuracy: 0.5088 - val_loss: 0.5262 - val_accuracy: 0.6000
# Epoch 12/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.1600 - accuracy: 0.3000
# Epoch 00012: val_accuracy improved from 0.66667 to 0.86667, saving model to models/model2_12.h5
# 57/57 [==============================] - 1s 15ms/sample - loss: 0.7113 - accuracy: 0.5614 - val_loss: 0.4934 - val_accuracy: 0.8667
# Epoch 13/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.7218 - accuracy: 0.6000
# Epoch 00013: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.7461 - accuracy: 0.5789 - val_loss: 0.4335 - val_accuracy: 0.8667
# Epoch 14/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5965 - accuracy: 0.7000
# Epoch 00014: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.6686 - accuracy: 0.6842 - val_loss: 0.7787 - val_accuracy: 0.5333
# Epoch 15/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.5693 - accuracy: 0.6800
# Epoch 00015: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.6477 - accuracy: 0.6667 - val_loss: 0.5797 - val_accuracy: 0.5333
# Epoch 16/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.6221 - accuracy: 0.6000
# Epoch 00016: val_accuracy improved from 0.86667 to 0.93333, saving model to models/model2_16.h5
# 57/57 [==============================] - 1s 15ms/sample - loss: 0.5763 - accuracy: 0.6842 - val_loss: 0.4558 - val_accuracy: 0.9333
# Epoch 17/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.6551 - accuracy: 0.6200
# Epoch 00017: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.6109 - accuracy: 0.6491 - val_loss: 0.5695 - val_accuracy: 0.6667
# Epoch 18/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.3714 - accuracy: 0.8600
# Epoch 00018: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3802 - accuracy: 0.8421 - val_loss: 0.3249 - val_accuracy: 0.9333
# Epoch 19/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.3618 - accuracy: 0.7800
# Epoch 00019: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3350 - accuracy: 0.8070 - val_loss: 0.3043 - val_accuracy: 0.8667
# Epoch 20/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.2179 - accuracy: 0.9000
# Epoch 00020: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3002 - accuracy: 0.8596 - val_loss: 1.1576 - val_accuracy: 0.5333
# Epoch 21/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4113 - accuracy: 0.6000
# Epoch 00021: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3950 - accuracy: 0.8070 - val_loss: 0.4672 - val_accuracy: 0.6667
# Epoch 22/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3476 - accuracy: 0.9000
# Epoch 00022: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3388 - accuracy: 0.9123 - val_loss: 0.3425 - val_accuracy: 0.8000
# Epoch 23/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1527 - accuracy: 0.9600
# Epoch 00023: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1643 - accuracy: 0.9474 - val_loss: 0.2762 - val_accuracy: 0.9333
# Epoch 24/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1439 - accuracy: 0.9600
# Epoch 00024: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1323 - accuracy: 0.9649 - val_loss: 1.2263 - val_accuracy: 0.6000
# Epoch 25/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0595 - accuracy: 1.0000
# Epoch 00025: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2009 - accuracy: 0.9123 - val_loss: 1.0393 - val_accuracy: 0.6667
# Epoch 26/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.3315 - accuracy: 0.8200
# Epoch 00026: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2954 - accuracy: 0.8421 - val_loss: 0.8586 - val_accuracy: 0.6667
# Epoch 27/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1465 - accuracy: 0.9600
# Epoch 00027: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1311 - accuracy: 0.9649 - val_loss: 0.2573 - val_accuracy: 0.9333
# Epoch 28/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1059 - accuracy: 0.9800
# Epoch 00028: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0983 - accuracy: 0.9825 - val_loss: 0.9256 - val_accuracy: 0.6000
# Epoch 29/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0542 - accuracy: 1.0000
# Epoch 00029: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0510 - accuracy: 1.0000 - val_loss: 0.2461 - val_accuracy: 0.8667
# Epoch 30/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0179 - accuracy: 1.0000
# Epoch 00030: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.1929 - val_accuracy: 0.9333
# Epoch 31/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0079 - accuracy: 1.0000
# Epoch 00031: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.7317 - val_accuracy: 0.8000
# Epoch 32/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 00032: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.7861 - val_accuracy: 0.8000
# Epoch 33/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00033: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.6788 - val_accuracy: 0.8000
# Epoch 34/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.1842e-04 - accuracy: 1.0000
# Epoch 00034: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 2.1728e-04 - accuracy: 1.0000 - val_loss: 0.4718 - val_accuracy: 0.8000
# Epoch 35/250
# 10/57 [====>.........................] - ETA: 0s - loss: 9.9275e-04 - accuracy: 1.0000
# Epoch 00035: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 5.3661e-04 - accuracy: 1.0000 - val_loss: 0.3930 - val_accuracy: 0.8667
# Epoch 36/250
# 50/57 [=========================>....] - ETA: 0s - loss: 2.2773e-04 - accuracy: 1.0000
# Epoch 00036: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.1126e-04 - accuracy: 1.0000 - val_loss: 0.3340 - val_accuracy: 0.8667
# Epoch 37/250
# 50/57 [=========================>....] - ETA: 0s - loss: 1.4852e-04 - accuracy: 1.0000
# Epoch 00037: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 1.3333e-04 - accuracy: 1.0000 - val_loss: 0.3566 - val_accuracy: 0.8667
# Epoch 38/250
# 10/57 [====>.........................] - ETA: 0s - loss: 9.4055e-06 - accuracy: 1.0000
# Epoch 00038: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 6.2083e-05 - accuracy: 1.0000 - val_loss: 0.4210 - val_accuracy: 0.8667
# Epoch 39/250
# 50/57 [=========================>....] - ETA: 0s - loss: 2.0939e-05 - accuracy: 1.0000
# Epoch 00039: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.2156e-04 - accuracy: 1.0000 - val_loss: 0.4996 - val_accuracy: 0.8000
# Epoch 40/250
# 50/57 [=========================>....] - ETA: 0s - loss: 2.8777e-05 - accuracy: 1.0000
# Epoch 00040: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.6875e-05 - accuracy: 1.0000 - val_loss: 0.6495 - val_accuracy: 0.8000
# Epoch 41/250
# 50/57 [=========================>....] - ETA: 0s - loss: 5.1855e-06 - accuracy: 1.0000
# Epoch 00041: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 4.9941e-06 - accuracy: 1.0000 - val_loss: 0.7401 - val_accuracy: 0.8000
# Epoch 42/250
# 50/57 [=========================>....] - ETA: 0s - loss: 2.7044e-04 - accuracy: 1.0000
# Epoch 00042: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.3726e-04 - accuracy: 1.0000 - val_loss: 0.6519 - val_accuracy: 0.8000
# Epoch 43/250
# 50/57 [=========================>....] - ETA: 0s - loss: 6.9045e-06 - accuracy: 1.0000
# Epoch 00043: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 5.7578e-05 - accuracy: 1.0000 - val_loss: 0.6013 - val_accuracy: 0.8000
# Epoch 44/250
# 10/57 [====>.........................] - ETA: 0s - loss: 7.3551e-06 - accuracy: 1.0000
# Epoch 00044: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 2.3044e-04 - accuracy: 1.0000 - val_loss: 0.5428 - val_accuracy: 0.8000
# Epoch 45/250
# 50/57 [=========================>....] - ETA: 0s - loss: 3.2710e-05 - accuracy: 1.0000
# Epoch 00045: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.8697e-05 - accuracy: 1.0000 - val_loss: 0.5332 - val_accuracy: 0.8000
# Epoch 46/250
# 50/57 [=========================>....] - ETA: 0s - loss: 1.3470e-05 - accuracy: 1.0000
# Epoch 00046: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.4913e-05 - accuracy: 1.0000 - val_loss: 0.5329 - val_accuracy: 0.8000
# Epoch 47/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.0943e-05 - accuracy: 1.0000
# Epoch 00047: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 9.2353e-06 - accuracy: 1.0000 - val_loss: 0.5411 - val_accuracy: 0.8000
# Epoch 48/250
# 10/57 [====>.........................] - ETA: 0s - loss: 2.1576e-05 - accuracy: 1.0000
# Epoch 00048: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 3.8875e-05 - accuracy: 1.0000 - val_loss: 0.5318 - val_accuracy: 0.8000
# Epoch 49/250
# 10/57 [====>.........................] - ETA: 0s - loss: 2.1086e-05 - accuracy: 1.0000
# Epoch 00049: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 2.5698e-05 - accuracy: 1.0000 - val_loss: 0.5234 - val_accuracy: 0.8000
# Epoch 50/250
# 10/57 [====>.........................] - ETA: 0s - loss: 9.0000e-06 - accuracy: 1.0000
# Epoch 00050: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 1.1893e-05 - accuracy: 1.0000 - val_loss: 0.5388 - val_accuracy: 0.8000
# Epoch 51/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.7643e-06 - accuracy: 1.0000
# Epoch 00051: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 8.2607e-06 - accuracy: 1.0000 - val_loss: 0.5525 - val_accuracy: 0.8000
# Epoch 52/250
# 50/57 [=========================>....] - ETA: 0s - loss: 9.5007e-05 - accuracy: 1.0000
# Epoch 00052: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 8.3704e-05 - accuracy: 1.0000 - val_loss: 0.6118 - val_accuracy: 0.8000
# Epoch 53/250
# 10/57 [====>.........................] - ETA: 0s - loss: 4.8437e-05 - accuracy: 1.0000
# Epoch 00053: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 5.2042e-05 - accuracy: 1.0000 - val_loss: 0.6407 - val_accuracy: 0.8000
# Epoch 54/250
# 50/57 [=========================>....] - ETA: 0s - loss: 7.1927e-06 - accuracy: 1.0000
# Epoch 00054: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 6.3219e-06 - accuracy: 1.0000 - val_loss: 0.6559 - val_accuracy: 0.8000
# Epoch 55/250
# 50/57 [=========================>....] - ETA: 0s - loss: 2.1841e-05 - accuracy: 1.0000
# Epoch 00055: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.9188e-05 - accuracy: 1.0000 - val_loss: 0.6775 - val_accuracy: 0.8000
# Epoch 56/250
# 10/57 [====>.........................] - ETA: 0s - loss: 6.1989e-07 - accuracy: 1.0000
# Epoch 00056: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 1.3541e-05 - accuracy: 1.0000 - val_loss: 0.6987 - val_accuracy: 0.8000
# Epoch 57/250
# 50/57 [=========================>....] - ETA: 0s - loss: 2.9287e-05 - accuracy: 1.0000
# Epoch 00057: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.6242e-05 - accuracy: 1.0000 - val_loss: 0.7431 - val_accuracy: 0.8000
# Epoch 58/250
# 50/57 [=========================>....] - ETA: 0s - loss: 6.9256e-06 - accuracy: 1.0000
# Epoch 00058: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 7.2400e-06 - accuracy: 1.0000 - val_loss: 0.7960 - val_accuracy: 0.8000
# Epoch 59/250
# 10/57 [====>.........................] - ETA: 0s - loss: 3.0728e-05 - accuracy: 1.0000
# Epoch 00059: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 4.4456e-05 - accuracy: 1.0000 - val_loss: 0.8409 - val_accuracy: 0.8000
# Epoch 60/250
# 50/57 [=========================>....] - ETA: 0s - loss: 3.8170e-06 - accuracy: 1.0000
# Epoch 00060: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 3.9338e-06 - accuracy: 1.0000 - val_loss: 0.8853 - val_accuracy: 0.8000
# Epoch 61/250
# 50/57 [=========================>....] - ETA: 0s - loss: 1.6679e-05 - accuracy: 1.0000
# Epoch 00061: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.5172e-05 - accuracy: 1.0000 - val_loss: 0.9059 - val_accuracy: 0.8000
# Epoch 62/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.7249e-05 - accuracy: 1.0000
# Epoch 00062: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 8.1331e-06 - accuracy: 1.0000 - val_loss: 0.9191 - val_accuracy: 0.8000
# Epoch 63/250
# 10/57 [====>.........................] - ETA: 0s - loss: 4.5299e-07 - accuracy: 1.0000
# Epoch 00063: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 2.6163e-06 - accuracy: 1.0000 - val_loss: 0.9337 - val_accuracy: 0.8000
# Epoch 64/250
# 50/57 [=========================>....] - ETA: 0s - loss: 1.2420e-05 - accuracy: 1.0000
# Epoch 00064: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.7437e-05 - accuracy: 1.0000 - val_loss: 0.9453 - val_accuracy: 0.8000
# Epoch 65/250
# 50/57 [=========================>....] - ETA: 0s - loss: 4.0546e-05 - accuracy: 1.0000
# Epoch 00065: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 3.5596e-05 - accuracy: 1.0000 - val_loss: 0.9013 - val_accuracy: 0.8000
# Epoch 66/250
# 10/57 [====>.........................] - ETA: 0s - loss: 2.3718e-04 - accuracy: 1.0000
# Epoch 00066: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 4.6233e-05 - accuracy: 1.0000 - val_loss: 0.7327 - val_accuracy: 0.8000
# Epoch 67/250
# 10/57 [====>.........................] - ETA: 0s - loss: 4.7684e-08 - accuracy: 1.0000
# Epoch 00067: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 2.8755e-06 - accuracy: 1.0000 - val_loss: 0.6494 - val_accuracy: 0.8000
# Epoch 68/250
# 50/57 [=========================>....] - ETA: 0s - loss: 8.1746e-06 - accuracy: 1.0000
# Epoch 00068: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 9.4481e-06 - accuracy: 1.0000 - val_loss: 0.6005 - val_accuracy: 0.8000
# Epoch 69/250
# 50/57 [=========================>....] - ETA: 0s - loss: 9.3523e-06 - accuracy: 1.0000
# Epoch 00069: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 8.2394e-06 - accuracy: 1.0000 - val_loss: 0.5698 - val_accuracy: 0.8000
# Epoch 70/250
# 50/57 [=========================>....] - ETA: 0s - loss: 8.8206e-06 - accuracy: 1.0000
# Epoch 00070: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 7.7541e-06 - accuracy: 1.0000 - val_loss: 0.5622 - val_accuracy: 0.8667
# Epoch 71/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.4186e-06 - accuracy: 1.0000
# Epoch 00071: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 8.0552e-06 - accuracy: 1.0000 - val_loss: 0.5685 - val_accuracy: 0.8667
# Epoch 72/250
# 50/57 [=========================>....] - ETA: 0s - loss: 2.6880e-05 - accuracy: 1.0000
# Epoch 00072: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.3934e-05 - accuracy: 1.0000 - val_loss: 0.5919 - val_accuracy: 0.8000
# Epoch 73/250
# 10/57 [====>.........................] - ETA: 0s - loss: 7.7006e-06 - accuracy: 1.0000
# Epoch 00073: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 5.5669e-06 - accuracy: 1.0000 - val_loss: 0.5992 - val_accuracy: 0.8000
# Epoch 74/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.6093e-06 - accuracy: 1.0000
# Epoch 00074: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 7.7811e-05 - accuracy: 1.0000 - val_loss: 0.5617 - val_accuracy: 0.8667
# Epoch 75/250
# 50/57 [=========================>....] - ETA: 0s - loss: 9.2744e-07 - accuracy: 1.0000
# Epoch 00075: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.5874e-06 - accuracy: 1.0000 - val_loss: 0.4807 - val_accuracy: 0.8667
# Epoch 76/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.3127e-04 - accuracy: 1.0000
# Epoch 00076: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 4.8917e-05 - accuracy: 1.0000 - val_loss: 0.4888 - val_accuracy: 0.8667
# Epoch 77/250
# 50/57 [=========================>....] - ETA: 0s - loss: 3.3115e-06 - accuracy: 1.0000
# Epoch 00077: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.9049e-06 - accuracy: 1.0000 - val_loss: 0.4875 - val_accuracy: 0.8667
# Epoch 78/250
# 50/57 [=========================>....] - ETA: 0s - loss: 2.9158e-06 - accuracy: 1.0000
# Epoch 00078: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.5661e-06 - accuracy: 1.0000 - val_loss: 0.4843 - val_accuracy: 0.8667
# Epoch 79/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.6920e-04 - accuracy: 1.0000
# Epoch 00079: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 5.2380e-05 - accuracy: 1.0000 - val_loss: 0.4888 - val_accuracy: 0.8667
# Epoch 80/250
# 50/57 [=========================>....] - ETA: 0s - loss: 1.0729e-06 - accuracy: 1.0000
# Epoch 00080: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.4786e-06 - accuracy: 1.0000 - val_loss: 0.4768 - val_accuracy: 0.8667
# Epoch 81/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00081: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 4.7428e-05 - accuracy: 1.0000 - val_loss: 0.4505 - val_accuracy: 0.8667
# Epoch 82/250
# 10/57 [====>.........................] - ETA: 0s - loss: 5.0381e-05 - accuracy: 1.0000
# Epoch 00082: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 4.7755e-05 - accuracy: 1.0000 - val_loss: 0.4127 - val_accuracy: 0.8667
# Epoch 83/250
# 50/57 [=========================>....] - ETA: 0s - loss: 3.1660e-06 - accuracy: 1.0000
# Epoch 00083: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.7793e-06 - accuracy: 1.0000 - val_loss: 0.3500 - val_accuracy: 0.8667
# Epoch 84/250
# 10/57 [====>.........................] - ETA: 0s - loss: 8.3446e-08 - accuracy: 1.0000
# Epoch 00084: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 1.3238e-05 - accuracy: 1.0000 - val_loss: 0.3318 - val_accuracy: 0.8000
# Epoch 85/250
# 10/57 [====>.........................] - ETA: 0s - loss: 5.4836e-07 - accuracy: 1.0000
# Epoch 00085: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 3.6765e-06 - accuracy: 1.0000 - val_loss: 0.3264 - val_accuracy: 0.8000
# Epoch 86/250
# 50/57 [=========================>....] - ETA: 0s - loss: 1.2034e-05 - accuracy: 1.0000
# Epoch 00086: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.0573e-05 - accuracy: 1.0000 - val_loss: 0.3239 - val_accuracy: 0.8000
# Epoch 87/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.6689e-07 - accuracy: 1.0000
# Epoch 00087: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 1.3908e-06 - accuracy: 1.0000 - val_loss: 0.3224 - val_accuracy: 0.8000
# Epoch 88/250
# 50/57 [=========================>....] - ETA: 0s - loss: 9.6124e-06 - accuracy: 1.0000
# Epoch 00088: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 9.0510e-06 - accuracy: 1.0000 - val_loss: 0.3292 - val_accuracy: 0.8000
# Epoch 89/250
# 10/57 [====>.........................] - ETA: 0s - loss: 4.7684e-08 - accuracy: 1.0000
# Epoch 00089: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 2.6455e-06 - accuracy: 1.0000 - val_loss: 0.3436 - val_accuracy: 0.8000
# Epoch 90/250
# 50/57 [=========================>....] - ETA: 0s - loss: 8.4158e-06 - accuracy: 1.0000
# Epoch 00090: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 7.3843e-06 - accuracy: 1.0000 - val_loss: 0.3595 - val_accuracy: 0.8667
# Epoch 91/250
# 50/57 [=========================>....] - ETA: 0s - loss: 2.6989e-06 - accuracy: 1.0000
# Epoch 00091: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.3674e-06 - accuracy: 1.0000 - val_loss: 0.3738 - val_accuracy: 0.8667
# Epoch 92/250
# 50/57 [=========================>....] - ETA: 0s - loss: 4.5061e-07 - accuracy: 1.0000
# Epoch 00092: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 4.7684e-07 - accuracy: 1.0000 - val_loss: 0.3816 - val_accuracy: 0.8667
# Epoch 93/250
# 50/57 [=========================>....] - ETA: 0s - loss: 3.8385e-07 - accuracy: 1.0000
# Epoch 00093: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 7.6963e-07 - accuracy: 1.0000 - val_loss: 0.3863 - val_accuracy: 0.8667
# Epoch 94/250
# 50/57 [=========================>....] - ETA: 0s - loss: 1.8835e-07 - accuracy: 1.0000
# Epoch 00094: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.6731e-07 - accuracy: 1.0000 - val_loss: 0.3897 - val_accuracy: 0.8667
# Epoch 95/250
# 10/57 [====>.........................] - ETA: 0s - loss: 2.3842e-08 - accuracy: 1.0000
# Epoch 00095: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 2.9174e-06 - accuracy: 1.0000 - val_loss: 0.3948 - val_accuracy: 0.8667
# Epoch 96/250
# 50/57 [=========================>....] - ETA: 0s - loss: 1.4782e-06 - accuracy: 1.0000
# Epoch 00096: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.6334e-06 - accuracy: 1.0000 - val_loss: 0.4002 - val_accuracy: 0.8667
# Epoch 97/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.4782e-06 - accuracy: 1.0000
# Epoch 00097: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 6.6120e-06 - accuracy: 1.0000 - val_loss: 0.4222 - val_accuracy: 0.8667
# Epoch 98/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.5497e-07 - accuracy: 1.0000
# Epoch 00098: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 6.3820e-06 - accuracy: 1.0000 - val_loss: 0.4318 - val_accuracy: 0.8667
# Epoch 99/250
# 10/57 [====>.........................] - ETA: 0s - loss: 2.3842e-08 - accuracy: 1.0000
# Epoch 00099: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 2.1771e-06 - accuracy: 1.0000 - val_loss: 0.4374 - val_accuracy: 0.8667
# Epoch 100/250
# 10/57 [====>.........................] - ETA: 0s - loss: 3.4571e-07 - accuracy: 1.0000
# Epoch 00100: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 6.4807e-06 - accuracy: 1.0000 - val_loss: 0.4381 - val_accuracy: 0.8667
# Epoch 101/250
# 40/57 [====================>.........] - ETA: 0s - loss: 1.6242e-06 - accuracy: 1.0000
# Epoch 00101: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.5873e-06 - accuracy: 1.0000 - val_loss: 0.4359 - val_accuracy: 0.8667
# Epoch 102/250
# 10/57 [====>.........................] - ETA: 0s - loss: 3.3736e-06 - accuracy: 1.0000
# Epoch 00102: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 9.0975e-07 - accuracy: 1.0000 - val_loss: 0.4262 - val_accuracy: 0.8667
# Epoch 103/250
# 10/57 [====>.........................] - ETA: 0s - loss: 7.1526e-08 - accuracy: 1.0000
# Epoch 00103: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 2.3276e-06 - accuracy: 1.0000 - val_loss: 0.4193 - val_accuracy: 0.8667
# Epoch 104/250
# 50/57 [=========================>....] - ETA: 0s - loss: 4.8399e-07 - accuracy: 1.0000
# Epoch 00104: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 4.2455e-07 - accuracy: 1.0000 - val_loss: 0.4140 - val_accuracy: 0.8667
# Epoch 105/250
# 50/57 [=========================>....] - ETA: 0s - loss: 4.3032e-06 - accuracy: 1.0000
# Epoch 00105: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 3.7789e-06 - accuracy: 1.0000 - val_loss: 0.4247 - val_accuracy: 0.8667
# Epoch 106/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.6451e-06 - accuracy: 1.0000
# Epoch 00106: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 5.1030e-07 - accuracy: 1.0000 - val_loss: 0.4440 - val_accuracy: 0.8667
# Epoch 107/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.2874e-05 - accuracy: 1.0000
# Epoch 00107: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 3.7741e-05 - accuracy: 1.0000 - val_loss: 0.4948 - val_accuracy: 0.8667
# Epoch 108/250
# 10/57 [====>.........................] - ETA: 0s - loss: 4.0531e-07 - accuracy: 1.0000
# Epoch 00108: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 1.5476e-06 - accuracy: 1.0000 - val_loss: 0.5534 - val_accuracy: 0.8667
# Epoch 109/250
# 10/57 [====>.........................] - ETA: 0s - loss: 8.8330e-06 - accuracy: 1.0000
# Epoch 00109: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 2.3042e-05 - accuracy: 1.0000 - val_loss: 0.6116 - val_accuracy: 0.8667
# Epoch 110/250
# 10/57 [====>.........................] - ETA: 0s - loss: 5.0068e-07 - accuracy: 1.0000
# Epoch 00110: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 1.2548e-07 - accuracy: 1.0000 - val_loss: 0.6726 - val_accuracy: 0.8667
# Epoch 111/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.4305e-07 - accuracy: 1.0000
# Epoch 00111: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 4.4546e-07 - accuracy: 1.0000 - val_loss: 0.7088 - val_accuracy: 0.8000
# Epoch 112/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.1921e-08 - accuracy: 1.0000
# Epoch 00112: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 9.7248e-07 - accuracy: 1.0000 - val_loss: 0.7305 - val_accuracy: 0.8000
# Epoch 113/250
# 10/57 [====>.........................] - ETA: 0s - loss: 4.1365e-06 - accuracy: 1.0000
# Epoch 00113: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 1.0642e-05 - accuracy: 1.0000 - val_loss: 0.7214 - val_accuracy: 0.8000
# Epoch 114/250
# 50/57 [=========================>....] - ETA: 0s - loss: 3.5047e-07 - accuracy: 1.0000
# Epoch 00114: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 3.1371e-07 - accuracy: 1.0000 - val_loss: 0.6761 - val_accuracy: 0.8667
# Epoch 115/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00115: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 1.5871e-05 - accuracy: 1.0000 - val_loss: 0.6738 - val_accuracy: 0.8667
# Epoch 116/250
# 50/57 [=========================>....] - ETA: 0s - loss: 2.4151e-06 - accuracy: 1.0000
# Epoch 00116: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.1311e-06 - accuracy: 1.0000 - val_loss: 0.6791 - val_accuracy: 0.8667
# Epoch 117/250
# 10/57 [====>.........................] - ETA: 0s - loss: 5.9605e-08 - accuracy: 1.0000
# Epoch 00117: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.2548e-07 - accuracy: 1.0000 - val_loss: 0.6550 - val_accuracy: 0.8667
# Epoch 118/250
# 50/57 [=========================>....] - ETA: 0s - loss: 2.8610e-07 - accuracy: 1.0000
# Epoch 00118: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.9279e-07 - accuracy: 1.0000 - val_loss: 0.6403 - val_accuracy: 0.8667
# Epoch 119/250
# 50/57 [=========================>....] - ETA: 0s - loss: 3.0756e-07 - accuracy: 1.0000
# Epoch 00119: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.6979e-07 - accuracy: 1.0000 - val_loss: 0.6331 - val_accuracy: 0.8667
# Epoch 120/250
# 10/57 [====>.........................] - ETA: 0s - loss: 8.8215e-07 - accuracy: 1.0000
# Epoch 00120: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 4.7265e-07 - accuracy: 1.0000 - val_loss: 0.6243 - val_accuracy: 0.8667
# Epoch 121/250
# 50/57 [=========================>....] - ETA: 0s - loss: 2.8060e-06 - accuracy: 1.0000
# Epoch 00121: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.5660e-06 - accuracy: 1.0000 - val_loss: 0.6271 - val_accuracy: 0.8667
# Epoch 122/250
# 50/57 [=========================>....] - ETA: 0s - loss: 2.5653e-06 - accuracy: 1.0000
# Epoch 00122: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.2524e-06 - accuracy: 1.0000 - val_loss: 0.6742 - val_accuracy: 0.8667
# Epoch 123/250
# 10/57 [====>.........................] - ETA: 0s - loss: 2.8014e-06 - accuracy: 1.0000
# Epoch 00123: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 7.8433e-06 - accuracy: 1.0000 - val_loss: 0.6007 - val_accuracy: 0.8667
# Epoch 124/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00124: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 3.1371e-08 - accuracy: 1.0000 - val_loss: 0.5460 - val_accuracy: 0.8667
# Epoch 125/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.7881e-07 - accuracy: 1.0000
# Epoch 00125: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 1.1251e-06 - accuracy: 1.0000 - val_loss: 0.5173 - val_accuracy: 0.8667
# Epoch 126/250
# 50/57 [=========================>....] - ETA: 0s - loss: 1.3113e-07 - accuracy: 1.0000
# Epoch 00126: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.1503e-07 - accuracy: 1.0000 - val_loss: 0.5065 - val_accuracy: 0.8667
# Epoch 127/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.1921e-08 - accuracy: 1.0000
# Epoch 00127: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 3.9736e-08 - accuracy: 1.0000 - val_loss: 0.5010 - val_accuracy: 0.8667
# Epoch 128/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.1921e-08 - accuracy: 1.0000
# Epoch 00128: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.6731e-07 - accuracy: 1.0000 - val_loss: 0.5016 - val_accuracy: 0.8667
# Epoch 129/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00129: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 6.7342e-07 - accuracy: 1.0000 - val_loss: 0.5042 - val_accuracy: 0.8667
# Epoch 130/250
# 10/57 [====>.........................] - ETA: 0s - loss: 5.7220e-07 - accuracy: 1.0000
# Epoch 00130: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 1.4012e-07 - accuracy: 1.0000 - val_loss: 0.5092 - val_accuracy: 0.8667
# Epoch 131/250
# 10/57 [====>.........................] - ETA: 0s - loss: 3.4570e-06 - accuracy: 1.0000
# Epoch 00131: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 1.7379e-06 - accuracy: 1.0000 - val_loss: 0.5335 - val_accuracy: 0.8667
# Epoch 132/250
# 50/57 [=========================>....] - ETA: 0s - loss: 2.8704e-06 - accuracy: 1.0000
# Epoch 00132: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.5388e-06 - accuracy: 1.0000 - val_loss: 0.5313 - val_accuracy: 0.8667
# Epoch 133/250
# 50/57 [=========================>....] - ETA: 0s - loss: 4.6943e-06 - accuracy: 1.0000
# Epoch 00133: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 4.1240e-06 - accuracy: 1.0000 - val_loss: 0.5738 - val_accuracy: 0.8667
# Epoch 134/250
# 50/57 [=========================>....] - ETA: 0s - loss: 2.4561e-05 - accuracy: 1.0000
# Epoch 00134: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.1576e-05 - accuracy: 1.0000 - val_loss: 0.7210 - val_accuracy: 0.8667
# Epoch 135/250
# 50/57 [=========================>....] - ETA: 0s - loss: 5.8173e-07 - accuracy: 1.0000
# Epoch 00135: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 5.1029e-07 - accuracy: 1.0000 - val_loss: 0.8065 - val_accuracy: 0.8000
# Epoch 136/250
# 10/57 [====>.........................] - ETA: 0s - loss: 2.9802e-07 - accuracy: 1.0000
# Epoch 00136: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 1.7568e-07 - accuracy: 1.0000 - val_loss: 0.8548 - val_accuracy: 0.8000
# Epoch 137/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.5497e-07 - accuracy: 1.0000
# Epoch 00137: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 5.7094e-07 - accuracy: 1.0000 - val_loss: 0.8704 - val_accuracy: 0.8000
# Epoch 138/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.7285e-06 - accuracy: 1.0000
# Epoch 00138: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 3.7854e-07 - accuracy: 1.0000 - val_loss: 0.8753 - val_accuracy: 0.8000
# Epoch 139/250
# 50/57 [=========================>....] - ETA: 0s - loss: 1.6689e-08 - accuracy: 1.0000
# Epoch 00139: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.4640e-08 - accuracy: 1.0000 - val_loss: 0.8774 - val_accuracy: 0.8000
# Epoch 140/250
# 10/57 [====>.........................] - ETA: 0s - loss: 5.2452e-07 - accuracy: 1.0000
# Epoch 00140: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 4.6429e-07 - accuracy: 1.0000 - val_loss: 0.8753 - val_accuracy: 0.8000
# Epoch 141/250
# 50/57 [=========================>....] - ETA: 0s - loss: 4.6730e-07 - accuracy: 1.0000
# Epoch 00141: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 4.0991e-07 - accuracy: 1.0000 - val_loss: 0.8558 - val_accuracy: 0.8000
# Epoch 142/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.8477e-06 - accuracy: 1.0000
# Epoch 00142: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 3.7017e-07 - accuracy: 1.0000 - val_loss: 0.8369 - val_accuracy: 0.8000
# Epoch 143/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00143: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 2.7939e-06 - accuracy: 1.0000 - val_loss: 0.8372 - val_accuracy: 0.8000
# Epoch 144/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.0610e-06 - accuracy: 1.0000
# Epoch 00144: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 6.5878e-07 - accuracy: 1.0000 - val_loss: 0.8421 - val_accuracy: 0.8000
# Epoch 145/250
# 10/57 [====>.........................] - ETA: 0s - loss: 8.2254e-07 - accuracy: 1.0000
# Epoch 00145: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 2.1332e-07 - accuracy: 1.0000 - val_loss: 0.8460 - val_accuracy: 0.8000
# Epoch 146/250
# 50/57 [=========================>....] - ETA: 0s - loss: 1.1921e-08 - accuracy: 1.0000
# Epoch 00146: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 1.0457e-08 - accuracy: 1.0000 - val_loss: 0.8480 - val_accuracy: 0.8000
# Epoch 147/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00147: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 4.5252e-06 - accuracy: 1.0000 - val_loss: 0.8718 - val_accuracy: 0.8000
# Epoch 148/250
# 50/57 [=========================>....] - ETA: 0s - loss: 4.2438e-07 - accuracy: 1.0000
# Epoch 00148: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 3.7854e-07 - accuracy: 1.0000 - val_loss: 0.8839 - val_accuracy: 0.8000
# Epoch 149/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.9193e-06 - accuracy: 1.0000
# Epoch 00149: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 3.6181e-07 - accuracy: 1.0000 - val_loss: 0.8854 - val_accuracy: 0.8000
# Epoch 150/250
# 10/57 [====>.........................] - ETA: 0s - loss: 7.1526e-08 - accuracy: 1.0000
# Epoch 00150: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 4.2664e-07 - accuracy: 1.0000 - val_loss: 0.8874 - val_accuracy: 0.8000
# Epoch 151/250
# 50/57 [=========================>....] - ETA: 0s - loss: 3.6239e-07 - accuracy: 1.0000
# Epoch 00151: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 3.1789e-07 - accuracy: 1.0000 - val_loss: 0.8761 - val_accuracy: 0.8000
# Epoch 152/250
# 50/57 [=========================>....] - ETA: 0s - loss: 6.9141e-08 - accuracy: 1.0000
# Epoch 00152: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 6.0650e-08 - accuracy: 1.0000 - val_loss: 0.8638 - val_accuracy: 0.8000
# Epoch 153/250
# 50/57 [=========================>....] - ETA: 0s - loss: 5.0067e-07 - accuracy: 1.0000
# Epoch 00153: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 4.3919e-07 - accuracy: 1.0000 - val_loss: 0.8441 - val_accuracy: 0.8000
# Epoch 154/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00154: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 8.3656e-08 - accuracy: 1.0000 - val_loss: 0.8297 - val_accuracy: 0.8000
# Epoch 155/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00155: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 7.3199e-08 - accuracy: 1.0000 - val_loss: 0.8220 - val_accuracy: 0.8000
# Epoch 156/250
# 10/57 [====>.........................] - ETA: 0s - loss: 8.3446e-08 - accuracy: 1.0000
# Epoch 00156: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 8.5745e-07 - accuracy: 1.0000 - val_loss: 0.8061 - val_accuracy: 0.8000
# Epoch 157/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00157: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 1.8404e-07 - accuracy: 1.0000 - val_loss: 0.7537 - val_accuracy: 0.8667
# Epoch 158/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00158: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 7.1107e-08 - accuracy: 1.0000 - val_loss: 0.7275 - val_accuracy: 0.8667
# Epoch 159/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.0729e-07 - accuracy: 1.0000
# Epoch 00159: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 9.6204e-08 - accuracy: 1.0000 - val_loss: 0.7143 - val_accuracy: 0.8667
# Epoch 160/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00160: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.1753e-06 - accuracy: 1.0000 - val_loss: 0.7264 - val_accuracy: 0.8667
# Epoch 161/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00161: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 8.3656e-09 - accuracy: 1.0000 - val_loss: 0.7336 - val_accuracy: 0.8667
# Epoch 162/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.6843e-05 - accuracy: 1.0000
# Epoch 00162: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 5.9391e-06 - accuracy: 1.0000 - val_loss: 0.7492 - val_accuracy: 0.8667
# Epoch 163/250
# 10/57 [====>.........................] - ETA: 0s - loss: 7.1526e-08 - accuracy: 1.0000
# Epoch 00163: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.8823e-08 - accuracy: 1.0000 - val_loss: 0.7615 - val_accuracy: 0.8667
# Epoch 164/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.1921e-08 - accuracy: 1.0000
# Epoch 00164: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 2.7188e-08 - accuracy: 1.0000 - val_loss: 0.7678 - val_accuracy: 0.8667
# Epoch 165/250
# 50/57 [=========================>....] - ETA: 0s - loss: 2.3842e-08 - accuracy: 1.0000
# Epoch 00165: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.0914e-08 - accuracy: 1.0000 - val_loss: 0.7713 - val_accuracy: 0.8667
# Epoch 166/250
# 50/57 [=========================>....] - ETA: 0s - loss: 2.7656e-07 - accuracy: 1.0000
# ...
# Epoch 00196: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.7568e-07 - accuracy: 1.0000 - val_loss: 1.0898 - val_accuracy: 0.8000
# Epoch 197/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00197: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.0457e-08 - accuracy: 1.0000 - val_loss: 1.0898 - val_accuracy: 0.8000
# Epoch 198/250
# 50/57 [=========================>....] - ETA: 0s - loss: 7.6294e-08 - accuracy: 1.0000
# Epoch 00198: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 7.3199e-08 - accuracy: 1.0000 - val_loss: 1.0903 - val_accuracy: 0.8000
# Epoch 199/250
# 50/57 [=========================>....] - ETA: 0s - loss: 6.6041e-07 - accuracy: 1.0000
# Epoch 00199: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 5.7931e-07 - accuracy: 1.0000 - val_loss: 1.0946 - val_accuracy: 0.8000
# Epoch 200/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00200: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.0496e-07 - accuracy: 1.0000 - val_loss: 1.0985 - val_accuracy: 0.8000
# Epoch 201/250
# 50/57 [=========================>....] - ETA: 0s - loss: 7.1526e-09 - accuracy: 1.0000
# Epoch 00201: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 6.2742e-09 - accuracy: 1.0000 - val_loss: 1.1010 - val_accuracy: 0.8000
# Epoch 202/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00202: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 3.7645e-08 - accuracy: 1.0000 - val_loss: 1.1014 - val_accuracy: 0.8000
# Epoch 203/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00203: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 2.1960e-07 - accuracy: 1.0000 - val_loss: 1.1004 - val_accuracy: 0.8000
# Epoch 204/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.1921e-08 - accuracy: 1.0000
# Epoch 00204: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 5.0410e-05 - accuracy: 1.0000 - val_loss: 0.8840 - val_accuracy: 0.8000
# Epoch 205/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00205: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.0914e-09 - accuracy: 1.0000 - val_loss: 0.5395 - val_accuracy: 0.8667
# Epoch 206/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00206: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 8.9719e-07 - accuracy: 1.0000 - val_loss: 0.4055 - val_accuracy: 0.8000
# Epoch 207/250
# 10/57 [====>.........................] - ETA: 0s - loss: 8.3446e-08 - accuracy: 1.0000
# Epoch 00207: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 6.9433e-07 - accuracy: 1.0000 - val_loss: 0.3559 - val_accuracy: 0.8000
# Epoch 208/250
# 50/57 [=========================>....] - ETA: 0s - loss: 5.4597e-07 - accuracy: 1.0000
# Epoch 00208: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 4.7892e-07 - accuracy: 1.0000 - val_loss: 0.3380 - val_accuracy: 0.8667
# Epoch 209/250
# 50/57 [=========================>....] - ETA: 0s - loss: 1.0014e-07 - accuracy: 1.0000
# Epoch 00209: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 8.9930e-08 - accuracy: 1.0000 - val_loss: 0.3299 - val_accuracy: 0.8667
# Epoch 210/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00210: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3259 - val_accuracy: 0.8667
# Epoch 211/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.2398e-06 - accuracy: 1.0000
# Epoch 00211: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.1959e-07 - accuracy: 1.0000 - val_loss: 0.3237 - val_accuracy: 0.8667
# Epoch 212/250
# 50/57 [=========================>....] - ETA: 0s - loss: 2.3051e-05 - accuracy: 1.0000
# Epoch 00212: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.0221e-05 - accuracy: 1.0000 - val_loss: 0.3050 - val_accuracy: 0.8667
# Epoch 213/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00213: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 4.4755e-07 - accuracy: 1.0000 - val_loss: 0.2974 - val_accuracy: 0.8667
# Epoch 214/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00214: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 1.2548e-08 - accuracy: 1.0000 - val_loss: 0.2945 - val_accuracy: 0.8667
# Epoch 215/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00215: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 3.5554e-08 - accuracy: 1.0000 - val_loss: 0.2932 - val_accuracy: 0.8667
# Epoch 216/250
# 50/57 [=========================>....] - ETA: 0s - loss: 1.5497e-07 - accuracy: 1.0000
# Epoch 00216: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.4618e-06 - accuracy: 1.0000 - val_loss: 0.2933 - val_accuracy: 0.8667
# Epoch 217/250
# 10/57 [====>.........................] - ETA: 0s - loss: 5.4836e-07 - accuracy: 1.0000
# Epoch 00217: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.0666e-07 - accuracy: 1.0000 - val_loss: 0.2955 - val_accuracy: 0.8667
# Epoch 218/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00218: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 5.8140e-07 - accuracy: 1.0000 - val_loss: 0.2981 - val_accuracy: 0.8667
# Epoch 219/250
# 50/57 [=========================>....] - ETA: 0s - loss: 6.6280e-07 - accuracy: 1.0000
# Epoch 00219: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 5.9395e-07 - accuracy: 1.0000 - val_loss: 0.3003 - val_accuracy: 0.8667
# Epoch 220/250
# 50/57 [=========================>....] - ETA: 0s - loss: 4.2915e-08 - accuracy: 1.0000
# Epoch 00220: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 4.6011e-08 - accuracy: 1.0000 - val_loss: 0.3016 - val_accuracy: 0.8667
# Epoch 221/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00221: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 4.1828e-09 - accuracy: 1.0000 - val_loss: 0.3023 - val_accuracy: 0.8667
# Epoch 222/250
# 10/57 [====>.........................] - ETA: 0s - loss: 2.0266e-07 - accuracy: 1.0000
# Epoch 00222: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 8.8444e-06 - accuracy: 1.0000 - val_loss: 0.2995 - val_accuracy: 0.8667
# Epoch 223/250
# 10/57 [====>.........................] - ETA: 0s - loss: 3.5763e-08 - accuracy: 1.0000
# Epoch 00223: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 4.4964e-07 - accuracy: 1.0000 - val_loss: 0.3652 - val_accuracy: 0.9333
# Epoch 224/250
# 10/57 [====>.........................] - ETA: 0s - loss: 3.5763e-08 - accuracy: 1.0000
# Epoch 00224: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 6.2742e-09 - accuracy: 1.0000 - val_loss: 0.4198 - val_accuracy: 0.9333
# Epoch 225/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.3947e-06 - accuracy: 1.0000
# Epoch 00225: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.7606e-07 - accuracy: 1.0000 - val_loss: 0.4487 - val_accuracy: 0.9333
# Epoch 226/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.1921e-08 - accuracy: 1.0000
# Epoch 00226: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 3.1162e-07 - accuracy: 1.0000 - val_loss: 0.4640 - val_accuracy: 0.9333
# Epoch 227/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00227: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 8.0308e-07 - accuracy: 1.0000 - val_loss: 0.4691 - val_accuracy: 0.9333
# Epoch 228/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00228: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 3.7645e-08 - accuracy: 1.0000 - val_loss: 0.4706 - val_accuracy: 0.9333
# Epoch 229/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00229: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 3.1789e-07 - accuracy: 1.0000 - val_loss: 0.4737 - val_accuracy: 0.9333
# Epoch 230/250
# 10/57 [====>.........................] - ETA: 0s - loss: 2.3842e-08 - accuracy: 1.0000
# Epoch 00230: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.0457e-08 - accuracy: 1.0000 - val_loss: 0.4767 - val_accuracy: 0.9333
# Epoch 231/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.2159e-06 - accuracy: 1.0000
# Epoch 00231: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.2169e-07 - accuracy: 1.0000 - val_loss: 0.4743 - val_accuracy: 0.9333
# Epoch 232/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00232: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4730 - val_accuracy: 0.9333
# Epoch 233/250
# 10/57 [====>.........................] - ETA: 0s - loss: 4.7071e-04 - accuracy: 1.0000
# Epoch 00233: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 8.2760e-05 - accuracy: 1.0000 - val_loss: 0.4546 - val_accuracy: 0.8000
# Epoch 234/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00234: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 2.7188e-07 - accuracy: 1.0000 - val_loss: 0.9397 - val_accuracy: 0.8667
# Epoch 235/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00235: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 2.4279e-06 - accuracy: 1.0000 - val_loss: 1.2887 - val_accuracy: 0.8000
# Epoch 236/250
# 10/57 [====>.........................] - ETA: 0s - loss: 3.9339e-07 - accuracy: 1.0000
# Epoch 00236: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 3.1998e-07 - accuracy: 1.0000 - val_loss: 1.4905 - val_accuracy: 0.8000
# Epoch 237/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00237: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 6.9016e-08 - accuracy: 1.0000 - val_loss: 1.5960 - val_accuracy: 0.8000
# Epoch 238/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00238: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 4.3919e-08 - accuracy: 1.0000 - val_loss: 1.6518 - val_accuracy: 0.8000
# Epoch 239/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.3113e-07 - accuracy: 1.0000
# Epoch 00239: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.3005e-08 - accuracy: 1.0000 - val_loss: 1.6812 - val_accuracy: 0.8000
# Epoch 240/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00240: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 6.0650e-08 - accuracy: 1.0000 - val_loss: 1.6965 - val_accuracy: 0.8000
# Epoch 241/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00241: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 9.8084e-07 - accuracy: 1.0000 - val_loss: 1.7027 - val_accuracy: 0.8000
# Epoch 242/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00242: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.4221e-07 - accuracy: 1.0000 - val_loss: 1.7061 - val_accuracy: 0.8000
# Epoch 243/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.1921e-08 - accuracy: 1.0000
# Epoch 00243: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.1503e-07 - accuracy: 1.0000 - val_loss: 1.7084 - val_accuracy: 0.8000
# Epoch 244/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.1921e-08 - accuracy: 1.0000
# Epoch 00244: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 2.3214e-07 - accuracy: 1.0000 - val_loss: 1.7112 - val_accuracy: 0.8000
# Epoch 245/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00245: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 7.1107e-08 - accuracy: 1.0000 - val_loss: 1.7139 - val_accuracy: 0.8000
# Epoch 246/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00246: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 5.8559e-08 - accuracy: 1.0000 - val_loss: 1.7153 - val_accuracy: 0.8000
# Epoch 247/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.3529e-04 - accuracy: 1.0000
# Epoch 00247: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 2.7523e-05 - accuracy: 1.0000 - val_loss: 1.5293 - val_accuracy: 0.8000
# Epoch 248/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00248: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 2.5097e-08 - accuracy: 1.0000 - val_loss: 1.4144 - val_accuracy: 0.8000
# Epoch 249/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.2159e-06 - accuracy: 1.0000
# Epoch 00249: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.1332e-07 - accuracy: 1.0000 - val_loss: 1.3543 - val_accuracy: 0.8000
# Epoch 250/250
# 10/57 [====>.........................] - ETA: 0s - loss: 3.5763e-08 - accuracy: 1.0000
# Epoch 00250: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 6.2742e-09 - accuracy: 1.0000 - val_loss: 1.3227 - val_accuracy: 0.8000
# Training completed in time:  0:00:25.510636

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# **Test the model**
#
# Here we will review the accuracy of the model on both the training and test data sets.

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  1.0
# Testing Accuracy:  0.8

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       1.00      0.57      0.73         7
#    Pneumonia       0.73      1.00      0.84         8
#
#     accuracy                           0.80        15
#    macro avg       0.86      0.79      0.78        15
# weighted avg       0.85      0.80      0.79        15

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[4 3]
#  [0 8]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])
