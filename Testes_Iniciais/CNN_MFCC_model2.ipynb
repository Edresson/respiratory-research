# %%
# !unzip respiratory-sound-database.zip

# %%
# Load various imports 
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
mypath = "./Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/"
filenames = [f for f in listdir(mypath) if (isfile(join(mypath, f)) and f.endswith('.wav'))]

# %%
p_id_in_file = [] # patient IDs corresponding to each file
for name in filenames:
    p_id_in_file.append(int(name[:3]))

p_id_in_file = np.array(p_id_in_file)

# %%
max_pad_len = 862 # to make the length of all MFCC equal


os.makedirs("./Respiratory_Sound_Database/features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
    if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
        return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=20) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./Respiratory_Sound_Database/features/", feature), mfccs)
    return mfccs

# %%
filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
p_diag = pd.read_csv("./Respiratory_Sound_Database/Respiratory_Sound_Database/patient_diagnosis.csv",header=None) # patient diagnosis file

# %%
labels = np.array([p_diag[p_diag[0] == x][1].values[0] for x in p_id_in_file]) # labels for audio files

# %%
features = [] 

# Iterate through each sound file and extract the features
for file_name in filepaths:
    data = extract_features(file_name)
    features.append(data)

print('Finished feature extraction from ', len(features), ' files')
features = np.array(features)
# Out:
# Finished feature extraction from  920  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
features = np.array(features) # convert to numpy array

# %%
np.unique(labels)
# Out:
# array(['Asthma', 'Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy',
#        'LRTI', 'Pneumonia', 'URTI'], dtype='<U14')

# %%
# delete diseases
'''
features1 = features
labels1 = labels'''

features1 = np.delete(features, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0) 

labels1 = np.delete(labels, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0)

# %%
# print class counts
unique_elements, counts_elements = np.unique(labels1, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['35' '37']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(labels1)
oh_labels = to_categorical(i_labels)

# %%
# add channel dimension for CNN
features1 = np.reshape(features1, (*features1.shape,1))

# %%
# train test split
x_train, x_test, y_train, y_test = train_test_split(features1, oh_labels, stratify=oh_labels, 
                                                    test_size=0.2, random_state = 42)

# %% [markdown]
# **Convolutional Neural Network (CNN) model architecture**
#
# Our model will be a Convolutional Neural Network (CNN) using Keras and a Tensorflow backend.
#
# We will use a sequential model, with a simple model architecture, consisting of four Conv2D convolution layers, with our final output layer being a dense layer.
#
# The convolution layers are designed for feature detection. It works by sliding a filter window over the input and performing a matrix multiplication and storing the result in a feature map. This operation is known as a convolution.
#
# The filter parameter specifies the number of nodes in each layer. Each layer will increase in size from 16, 32, 64 to 128, while the kernel_size parameter specifies the size of the kernel window which in this case is 2 resulting in a 2x2 filter matrix.
#
# The first layer will receive the input shape of (40, 862, 1) where 40 is the number of MFCC's, 862 is the number of frames taking padding into account and the 1 signifying that the audio is mono.
#
# The activation function we will be using for our convolutional layers is ReLU. We will use a small Dropout value of 20% on our convolutional layers.
#
# Each convolutional layer has an associated pooling layer of MaxPooling2D type with the final convolutional layer having a GlobalAveragePooling2D type. The pooling layer is to reduce the dimensionality of the model (by reducing the parameters and subsquent computation requirements) which serves to shorten the training time and reduce overfitting. The Max Pooling type takes the maximum size for each window and the Global Average Pooling type takes the average which is suitable for feeding into our dense output layer.
#
# Our output layer will have 6 nodes (num_labels) which matches the number of possible classifications. The activation is for our output layer is softmax. Softmax makes the output sum up to 1 so the output can be interpreted as probabilities. The model will then make its prediction based on which option has the highest probability.

# %%
num_rows = 40
num_columns = 862
num_channels = 1

num_labels = oh_labels.shape[1]
filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=16, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=8, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=4, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 39, 861, 32)       160
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 19, 430, 32)       0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 19, 430, 32)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 18, 429, 16)       2064
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 9, 214, 16)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 9, 214, 16)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 213, 8)         520
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 4, 106, 8)         0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 4, 106, 8)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 3, 105, 4)         132
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 1, 52, 4)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 1, 52, 4)          0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 4)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 10
# =================================================================
# Total params: 2,886
# Trainable params: 2,886
# Non-trainable params: 0
# _________________________________________________________________
# 15/15 [==============================] - 1s 62ms/sample - loss: 4.9969 - accuracy: 0.4667
# Pre-training accuracy: 46.6667%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 250
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/model2_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 57 samples, validate on 15 samples
# Epoch 1/250
# 40/57 [====================>.........] - ETA: 0s - loss: 8.7783 - accuracy: 0.4750
# Epoch 00001: val_accuracy improved from -inf to 0.53333, saving model to models/model2_01.h5
# 57/57 [==============================] - 1s 17ms/sample - loss: 6.9449 - accuracy: 0.4912 - val_loss: 0.7664 - val_accuracy: 0.5333
# Epoch 2/250
# 40/57 [====================>.........] - ETA: 0s - loss: 1.5832 - accuracy: 0.4250
# Epoch 00002: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 2ms/sample - loss: 2.2090 - accuracy: 0.4211 - val_loss: 0.8880 - val_accuracy: 0.5333
# Epoch 3/250
# 50/57 [=========================>....] - ETA: 0s - loss: 1.4916 - accuracy: 0.5400
# Epoch 00003: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.5825 - accuracy: 0.5088 - val_loss: 0.7419 - val_accuracy: 0.5333
# Epoch 4/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.9022 - accuracy: 0.5000
# Epoch 00004: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.0296 - accuracy: 0.4737 - val_loss: 0.6989 - val_accuracy: 0.5333
# Epoch 5/250
# 40/57 [====================>.........] - ETA: 0s - loss: 1.1368 - accuracy: 0.5250
# Epoch 00005: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.2085 - accuracy: 0.5088 - val_loss: 0.6954 - val_accuracy: 0.5333
# Epoch 6/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.9279 - accuracy: 0.5000
# Epoch 00006: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.9305 - accuracy: 0.4912 - val_loss: 0.7071 - val_accuracy: 0.5333
# Epoch 7/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.9417 - accuracy: 0.5000
# Epoch 00007: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.9495 - accuracy: 0.4912 - val_loss: 0.7055 - val_accuracy: 0.5333
# Epoch 8/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.7347 - accuracy: 0.5750
# Epoch 00008: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.7800 - accuracy: 0.5088 - val_loss: 0.6950 - val_accuracy: 0.5333
# Epoch 9/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.8522 - accuracy: 0.4750
# Epoch 00009: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.8422 - accuracy: 0.4737 - val_loss: 0.6909 - val_accuracy: 0.5333
# Epoch 10/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.6786 - accuracy: 0.6500
# Epoch 00010: val_accuracy improved from 0.53333 to 0.60000, saving model to models/model2_10.h5
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.6077 - accuracy: 0.6842 - val_loss: 0.6915 - val_accuracy: 0.6000
# Epoch 11/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.7474 - accuracy: 0.5750
# Epoch 00011: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.7067 - accuracy: 0.5965 - val_loss: 0.6924 - val_accuracy: 0.4667
# Epoch 12/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.7907 - accuracy: 0.5000
# Epoch 00012: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.7586 - accuracy: 0.5088 - val_loss: 0.6913 - val_accuracy: 0.4667
# Epoch 13/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.5002 - accuracy: 0.7750
# Epoch 00013: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.5497 - accuracy: 0.7544 - val_loss: 0.6912 - val_accuracy: 0.6000
# Epoch 14/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.6298 - accuracy: 0.7250
# Epoch 00014: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.6419 - accuracy: 0.7368 - val_loss: 0.6960 - val_accuracy: 0.5333
# Epoch 15/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.5812 - accuracy: 0.6750
# Epoch 00015: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.6309 - accuracy: 0.6667 - val_loss: 0.6932 - val_accuracy: 0.4667
# Epoch 16/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.6801 - accuracy: 0.5750
# Epoch 00016: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.6757 - accuracy: 0.5439 - val_loss: 0.6886 - val_accuracy: 0.5333
# Epoch 17/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.6073 - accuracy: 0.6250
# Epoch 00017: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.6122 - accuracy: 0.5965 - val_loss: 0.6919 - val_accuracy: 0.6000
# Epoch 18/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.6829 - accuracy: 0.6200
# Epoch 00018: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.6599 - accuracy: 0.6491 - val_loss: 0.6929 - val_accuracy: 0.6000
# Epoch 19/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.7326 - accuracy: 0.5500
# Epoch 00019: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.6654 - accuracy: 0.5965 - val_loss: 0.6912 - val_accuracy: 0.6000
# Epoch 20/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.6648 - accuracy: 0.7250
# Epoch 00020: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.6803 - accuracy: 0.6667 - val_loss: 0.6833 - val_accuracy: 0.6000
# Epoch 21/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.7543 - accuracy: 0.5000
# Epoch 00021: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.7459 - accuracy: 0.5263 - val_loss: 0.6794 - val_accuracy: 0.6000
# Epoch 22/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.4681 - accuracy: 0.7750
# Epoch 00022: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.5327 - accuracy: 0.7368 - val_loss: 0.6783 - val_accuracy: 0.6000
# Epoch 23/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.5898 - accuracy: 0.7000
# Epoch 00023: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.5679 - accuracy: 0.7193 - val_loss: 0.6817 - val_accuracy: 0.6000
# Epoch 24/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.6453 - accuracy: 0.5750
# Epoch 00024: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.5912 - accuracy: 0.6316 - val_loss: 0.6836 - val_accuracy: 0.6000
# Epoch 25/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.6258 - accuracy: 0.6500
# Epoch 00025: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.5692 - accuracy: 0.6842 - val_loss: 0.6763 - val_accuracy: 0.6000
# Epoch 26/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.5351 - accuracy: 0.7500
# Epoch 00026: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.5820 - accuracy: 0.7193 - val_loss: 0.6710 - val_accuracy: 0.6000
# Epoch 27/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.4293 - accuracy: 0.8000
# Epoch 00027: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4276 - accuracy: 0.8246 - val_loss: 0.6679 - val_accuracy: 0.6000
# Epoch 28/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.5955 - accuracy: 0.5600
# Epoch 00028: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.5747 - accuracy: 0.5965 - val_loss: 0.6667 - val_accuracy: 0.6000
# Epoch 29/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.5200 - accuracy: 0.7500
# Epoch 00029: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.5668 - accuracy: 0.7018 - val_loss: 0.6845 - val_accuracy: 0.6000
# Epoch 30/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.6100 - accuracy: 0.6750
# Epoch 00030: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.5643 - accuracy: 0.7193 - val_loss: 0.6743 - val_accuracy: 0.6000
# Epoch 31/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.5486 - accuracy: 0.7250
# Epoch 00031: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.5137 - accuracy: 0.7719 - val_loss: 0.6579 - val_accuracy: 0.6000
# Epoch 32/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.4832 - accuracy: 0.8500
# Epoch 00032: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.5291 - accuracy: 0.7895 - val_loss: 0.6746 - val_accuracy: 0.6000
# Epoch 33/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.4983 - accuracy: 0.7500
# Epoch 00033: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4867 - accuracy: 0.7368 - val_loss: 0.6913 - val_accuracy: 0.6000
# Epoch 34/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.4834 - accuracy: 0.7500
# Epoch 00034: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4507 - accuracy: 0.7719 - val_loss: 0.6598 - val_accuracy: 0.6000
# Epoch 35/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.5217 - accuracy: 0.7000
# Epoch 00035: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.5292 - accuracy: 0.7193 - val_loss: 0.6828 - val_accuracy: 0.6000
# Epoch 36/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.4644 - accuracy: 0.7250
# Epoch 00036: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4810 - accuracy: 0.7544 - val_loss: 0.7066 - val_accuracy: 0.6000
# Epoch 37/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.4311 - accuracy: 0.8000
# Epoch 00037: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4071 - accuracy: 0.8246 - val_loss: 0.6462 - val_accuracy: 0.6000
# Epoch 38/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.3702 - accuracy: 0.7750
# Epoch 00038: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4563 - accuracy: 0.7193 - val_loss: 0.6674 - val_accuracy: 0.6000
# Epoch 39/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.3506 - accuracy: 0.8250
# Epoch 00039: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4351 - accuracy: 0.7895 - val_loss: 0.6269 - val_accuracy: 0.6000
# Epoch 40/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.4098 - accuracy: 0.7800
# Epoch 00040: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4076 - accuracy: 0.7895 - val_loss: 0.7515 - val_accuracy: 0.6000
# Epoch 41/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.3977 - accuracy: 0.8000
# Epoch 00041: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3684 - accuracy: 0.7895 - val_loss: 0.6663 - val_accuracy: 0.6000
# Epoch 42/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.4186 - accuracy: 0.7600
# Epoch 00042: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4526 - accuracy: 0.7368 - val_loss: 0.6303 - val_accuracy: 0.6000
# Epoch 43/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.4174 - accuracy: 0.8400
# Epoch 00043: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3873 - accuracy: 0.8596 - val_loss: 0.7191 - val_accuracy: 0.6000
# Epoch 44/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.5154 - accuracy: 0.7000
# Epoch 00044: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4352 - accuracy: 0.7719 - val_loss: 0.7257 - val_accuracy: 0.6000
# Epoch 45/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.4205 - accuracy: 0.7500
# Epoch 00045: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4139 - accuracy: 0.7544 - val_loss: 0.6313 - val_accuracy: 0.6000
# Epoch 46/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2989 - accuracy: 0.8250
# Epoch 00046: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3644 - accuracy: 0.7544 - val_loss: 0.7475 - val_accuracy: 0.6000
# Epoch 47/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.4501 - accuracy: 0.7500
# Epoch 00047: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3888 - accuracy: 0.7895 - val_loss: 0.6083 - val_accuracy: 0.6000
# Epoch 48/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.4387 - accuracy: 0.8000
# Epoch 00048: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4541 - accuracy: 0.7895 - val_loss: 0.6619 - val_accuracy: 0.6000
# Epoch 49/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.3195 - accuracy: 0.7750
# Epoch 00049: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4287 - accuracy: 0.7544 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 50/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.4381 - accuracy: 0.7800
# Epoch 00050: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4206 - accuracy: 0.7895 - val_loss: 0.6177 - val_accuracy: 0.6000
# Epoch 51/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.3452 - accuracy: 0.8600
# Epoch 00051: val_accuracy improved from 0.60000 to 0.73333, saving model to models/model2_51.h5
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3699 - accuracy: 0.8246 - val_loss: 0.4839 - val_accuracy: 0.7333
# Epoch 52/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.3644 - accuracy: 0.7750
# Epoch 00052: val_accuracy did not improve from 0.73333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3857 - accuracy: 0.7719 - val_loss: 0.5874 - val_accuracy: 0.6000
# Epoch 53/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.3537 - accuracy: 0.8000
# Epoch 00053: val_accuracy did not improve from 0.73333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3491 - accuracy: 0.8246 - val_loss: 0.6887 - val_accuracy: 0.5333
# Epoch 54/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.4116 - accuracy: 0.8000
# Epoch 00054: val_accuracy did not improve from 0.73333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3924 - accuracy: 0.8070 - val_loss: 0.6130 - val_accuracy: 0.6000
# Epoch 55/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.3866 - accuracy: 0.8000
# Epoch 00055: val_accuracy did not improve from 0.73333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3567 - accuracy: 0.8421 - val_loss: 0.6371 - val_accuracy: 0.6000
# Epoch 56/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.3742 - accuracy: 0.8250
# Epoch 00056: val_accuracy did not improve from 0.73333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3285 - accuracy: 0.8596 - val_loss: 0.7254 - val_accuracy: 0.5333
# Epoch 57/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2896 - accuracy: 0.8750
# Epoch 00057: val_accuracy did not improve from 0.73333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3453 - accuracy: 0.8421 - val_loss: 0.6539 - val_accuracy: 0.6000
# Epoch 58/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.3413 - accuracy: 0.8600
# Epoch 00058: val_accuracy did not improve from 0.73333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3429 - accuracy: 0.8421 - val_loss: 0.6372 - val_accuracy: 0.6000
# Epoch 59/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.1776 - accuracy: 0.9250
# Epoch 00059: val_accuracy did not improve from 0.73333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3316 - accuracy: 0.8421 - val_loss: 0.6437 - val_accuracy: 0.6000
# Epoch 60/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.4306 - accuracy: 0.7250
# Epoch 00060: val_accuracy did not improve from 0.73333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4787 - accuracy: 0.7018 - val_loss: 0.8243 - val_accuracy: 0.5333
# Epoch 61/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.3970 - accuracy: 0.8000
# Epoch 00061: val_accuracy improved from 0.73333 to 0.80000, saving model to models/model2_61.h5
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4457 - accuracy: 0.8070 - val_loss: 0.4392 - val_accuracy: 0.8000
# Epoch 62/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.4874 - accuracy: 0.7750
# Epoch 00062: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4277 - accuracy: 0.8070 - val_loss: 0.7739 - val_accuracy: 0.5333
# Epoch 63/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.4774 - accuracy: 0.7750
# Epoch 00063: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4293 - accuracy: 0.7719 - val_loss: 0.7323 - val_accuracy: 0.5333
# Epoch 64/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.3967 - accuracy: 0.8500
# Epoch 00064: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3686 - accuracy: 0.8772 - val_loss: 0.5945 - val_accuracy: 0.7333
# Epoch 65/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.3597 - accuracy: 0.9000
# Epoch 00065: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3190 - accuracy: 0.8947 - val_loss: 0.7165 - val_accuracy: 0.5333
# Epoch 66/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.3386 - accuracy: 0.8250
# Epoch 00066: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3668 - accuracy: 0.7895 - val_loss: 0.7076 - val_accuracy: 0.5333
# Epoch 67/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.3579 - accuracy: 0.8400
# Epoch 00067: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3438 - accuracy: 0.8421 - val_loss: 0.6392 - val_accuracy: 0.6000
# Epoch 68/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.4186 - accuracy: 0.8000
# Epoch 00068: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3897 - accuracy: 0.8246 - val_loss: 0.8402 - val_accuracy: 0.5333
# Epoch 69/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.4159 - accuracy: 0.8000
# Epoch 00069: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3699 - accuracy: 0.8246 - val_loss: 0.6929 - val_accuracy: 0.6000
# Epoch 70/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2873 - accuracy: 0.8750
# Epoch 00070: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3821 - accuracy: 0.8596 - val_loss: 0.6436 - val_accuracy: 0.6000
# Epoch 71/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.3756 - accuracy: 0.7750
# Epoch 00071: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3308 - accuracy: 0.7895 - val_loss: 0.8157 - val_accuracy: 0.5333
# Epoch 72/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.3260 - accuracy: 0.8250
# Epoch 00072: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2980 - accuracy: 0.8246 - val_loss: 0.5915 - val_accuracy: 0.7333
# Epoch 73/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.3384 - accuracy: 0.8250
# Epoch 00073: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3209 - accuracy: 0.8596 - val_loss: 0.6491 - val_accuracy: 0.6000
# Epoch 74/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2989 - accuracy: 0.8500
# Epoch 00074: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2911 - accuracy: 0.8596 - val_loss: 0.7443 - val_accuracy: 0.5333
# Epoch 75/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.3737 - accuracy: 0.7750
# Epoch 00075: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3271 - accuracy: 0.7895 - val_loss: 0.6982 - val_accuracy: 0.5333
# Epoch 76/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.3241 - accuracy: 0.8400
# Epoch 00076: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3513 - accuracy: 0.8246 - val_loss: 0.6952 - val_accuracy: 0.5333
# Epoch 77/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2964 - accuracy: 0.8750
# Epoch 00077: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2806 - accuracy: 0.8772 - val_loss: 0.8602 - val_accuracy: 0.4667
# Epoch 78/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2780 - accuracy: 0.8500
# Epoch 00078: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2922 - accuracy: 0.8246 - val_loss: 0.6457 - val_accuracy: 0.5333
# Epoch 79/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.3323 - accuracy: 0.8500
# Epoch 00079: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3492 - accuracy: 0.8421 - val_loss: 0.6578 - val_accuracy: 0.5333
# Epoch 80/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2272 - accuracy: 0.8500
# Epoch 00080: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3606 - accuracy: 0.7719 - val_loss: 0.8971 - val_accuracy: 0.5333
# Epoch 81/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.4178 - accuracy: 0.8000
# Epoch 00081: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3190 - accuracy: 0.8596 - val_loss: 0.5450 - val_accuracy: 0.6667
# Epoch 82/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2783 - accuracy: 0.8750
# Epoch 00082: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3515 - accuracy: 0.8246 - val_loss: 0.7202 - val_accuracy: 0.5333
# Epoch 83/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.3274 - accuracy: 0.8250
# Epoch 00083: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3320 - accuracy: 0.8421 - val_loss: 0.8450 - val_accuracy: 0.4667
# Epoch 84/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.3108 - accuracy: 0.9000
# Epoch 00084: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2912 - accuracy: 0.9123 - val_loss: 0.6592 - val_accuracy: 0.5333
# Epoch 85/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2756 - accuracy: 0.8750
# Epoch 00085: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2930 - accuracy: 0.8421 - val_loss: 0.6437 - val_accuracy: 0.5333
# Epoch 86/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2774 - accuracy: 0.8500
# Epoch 00086: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2703 - accuracy: 0.8421 - val_loss: 0.8605 - val_accuracy: 0.5333
# Epoch 87/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2951 - accuracy: 0.8250
# Epoch 00087: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2847 - accuracy: 0.8421 - val_loss: 0.6373 - val_accuracy: 0.5333
# Epoch 88/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2950 - accuracy: 0.8500
# Epoch 00088: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2609 - accuracy: 0.8772 - val_loss: 0.6294 - val_accuracy: 0.5333
# Epoch 89/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2697 - accuracy: 0.8750
# Epoch 00089: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2528 - accuracy: 0.8596 - val_loss: 0.7631 - val_accuracy: 0.5333
# Epoch 90/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2631 - accuracy: 0.8750
# Epoch 00090: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2399 - accuracy: 0.8947 - val_loss: 0.8772 - val_accuracy: 0.5333
# Epoch 91/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2195 - accuracy: 0.9000
# Epoch 00091: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2591 - accuracy: 0.8772 - val_loss: 0.7894 - val_accuracy: 0.5333
# Epoch 92/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2361 - accuracy: 0.9000
# Epoch 00092: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2442 - accuracy: 0.8947 - val_loss: 0.6839 - val_accuracy: 0.5333
# Epoch 93/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.3202 - accuracy: 0.8750
# Epoch 00093: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3054 - accuracy: 0.8947 - val_loss: 0.6636 - val_accuracy: 0.6000
# Epoch 94/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2871 - accuracy: 0.8750
# Epoch 00094: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2968 - accuracy: 0.8596 - val_loss: 0.8107 - val_accuracy: 0.6000
# Epoch 95/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2449 - accuracy: 0.8750
# Epoch 00095: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2424 - accuracy: 0.8772 - val_loss: 0.8837 - val_accuracy: 0.6000
# Epoch 96/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.1803 - accuracy: 0.9250
# Epoch 00096: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2104 - accuracy: 0.8947 - val_loss: 0.7358 - val_accuracy: 0.6000
# Epoch 97/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2384 - accuracy: 0.9000
# Epoch 00097: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2167 - accuracy: 0.9298 - val_loss: 0.7770 - val_accuracy: 0.6000
# Epoch 98/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2686 - accuracy: 0.8750
# Epoch 00098: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2565 - accuracy: 0.8947 - val_loss: 0.9427 - val_accuracy: 0.6000
# Epoch 99/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2645 - accuracy: 0.9000
# Epoch 00099: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2829 - accuracy: 0.8596 - val_loss: 0.6827 - val_accuracy: 0.6000
# Epoch 100/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2823 - accuracy: 0.8500
# Epoch 00100: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2494 - accuracy: 0.8596 - val_loss: 0.7076 - val_accuracy: 0.6000
# Epoch 101/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.3147 - accuracy: 0.8750
# Epoch 00101: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2925 - accuracy: 0.8596 - val_loss: 0.6508 - val_accuracy: 0.6000
# Epoch 102/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2734 - accuracy: 0.8250
# Epoch 00102: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2281 - accuracy: 0.8596 - val_loss: 0.7602 - val_accuracy: 0.6000
# Epoch 103/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.1756 - accuracy: 0.9250
# Epoch 00103: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2118 - accuracy: 0.9123 - val_loss: 0.6687 - val_accuracy: 0.6000
# Epoch 104/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.1996 - accuracy: 0.9250
# Epoch 00104: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2048 - accuracy: 0.9123 - val_loss: 0.7206 - val_accuracy: 0.6000
# Epoch 105/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2978 - accuracy: 0.8750
# Epoch 00105: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2393 - accuracy: 0.8947 - val_loss: 0.6462 - val_accuracy: 0.6000
# Epoch 106/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2630 - accuracy: 0.8500
# Epoch 00106: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2675 - accuracy: 0.8596 - val_loss: 0.6830 - val_accuracy: 0.6000
# Epoch 107/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.3102 - accuracy: 0.8250
# Epoch 00107: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2563 - accuracy: 0.8772 - val_loss: 0.8265 - val_accuracy: 0.6000
# Epoch 108/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2161 - accuracy: 0.9000
# Epoch 00108: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2150 - accuracy: 0.9123 - val_loss: 0.8368 - val_accuracy: 0.6000
# Epoch 109/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2548 - accuracy: 0.8750
# Epoch 00109: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2732 - accuracy: 0.8596 - val_loss: 0.5742 - val_accuracy: 0.7333
# Epoch 110/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.3635 - accuracy: 0.8500
# Epoch 00110: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3441 - accuracy: 0.8596 - val_loss: 0.8917 - val_accuracy: 0.6000
# Epoch 111/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2663 - accuracy: 0.8500
# Epoch 00111: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2801 - accuracy: 0.8421 - val_loss: 0.5058 - val_accuracy: 0.7333
# Epoch 112/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2832 - accuracy: 0.8500
# Epoch 00112: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2830 - accuracy: 0.8421 - val_loss: 0.8804 - val_accuracy: 0.6000
# Epoch 113/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2496 - accuracy: 0.9000
# Epoch 00113: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2031 - accuracy: 0.9298 - val_loss: 0.6651 - val_accuracy: 0.6000
# Epoch 114/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2382 - accuracy: 0.8750
# Epoch 00114: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2596 - accuracy: 0.8772 - val_loss: 0.7107 - val_accuracy: 0.6000
# Epoch 115/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.1277 - accuracy: 0.9750
# Epoch 00115: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1928 - accuracy: 0.9298 - val_loss: 0.7959 - val_accuracy: 0.6000
# Epoch 116/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2149 - accuracy: 0.8750
# Epoch 00116: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1936 - accuracy: 0.8947 - val_loss: 0.9634 - val_accuracy: 0.6000
# Epoch 117/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.1743 - accuracy: 0.9000
# Epoch 00117: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1524 - accuracy: 0.9298 - val_loss: 0.7570 - val_accuracy: 0.6000
# Epoch 118/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.1686 - accuracy: 0.9250
# Epoch 00118: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1816 - accuracy: 0.8947 - val_loss: 1.1113 - val_accuracy: 0.6000
# Epoch 119/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2945 - accuracy: 0.8500
# Epoch 00119: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2614 - accuracy: 0.8772 - val_loss: 0.9619 - val_accuracy: 0.6000
# Epoch 120/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2743 - accuracy: 0.9000
# Epoch 00120: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2162 - accuracy: 0.9298 - val_loss: 0.9574 - val_accuracy: 0.6000
# Epoch 121/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2117 - accuracy: 0.9000
# Epoch 00121: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2032 - accuracy: 0.8947 - val_loss: 0.9214 - val_accuracy: 0.6000
# Epoch 122/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.1288 - accuracy: 0.9500
# Epoch 00122: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1961 - accuracy: 0.9123 - val_loss: 0.7256 - val_accuracy: 0.6000
# Epoch 123/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2530 - accuracy: 0.8250
# Epoch 00123: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2078 - accuracy: 0.8772 - val_loss: 1.2621 - val_accuracy: 0.5333
# Epoch 124/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2791 - accuracy: 0.8750
# Epoch 00124: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2289 - accuracy: 0.9123 - val_loss: 0.7356 - val_accuracy: 0.6000
# Epoch 125/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2151 - accuracy: 0.9250
# Epoch 00125: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2317 - accuracy: 0.9123 - val_loss: 0.6606 - val_accuracy: 0.6000
# Epoch 126/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2215 - accuracy: 0.8750
# Epoch 00126: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2174 - accuracy: 0.8947 - val_loss: 1.0221 - val_accuracy: 0.6000
# Epoch 127/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2260 - accuracy: 0.8750
# Epoch 00127: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2349 - accuracy: 0.8772 - val_loss: 0.7568 - val_accuracy: 0.6000
# Epoch 128/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.1882 - accuracy: 0.9250
# Epoch 00128: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1837 - accuracy: 0.9123 - val_loss: 0.8552 - val_accuracy: 0.6000
# Epoch 129/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.1949 - accuracy: 0.9500
# Epoch 00129: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2098 - accuracy: 0.9298 - val_loss: 0.9680 - val_accuracy: 0.6000
# Epoch 130/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2166 - accuracy: 0.8750
# Epoch 00130: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2299 - accuracy: 0.8596 - val_loss: 1.0176 - val_accuracy: 0.6000
# Epoch 131/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.1739 - accuracy: 0.9500
# Epoch 00131: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1684 - accuracy: 0.9474 - val_loss: 0.8912 - val_accuracy: 0.6000
# Epoch 132/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.1405 - accuracy: 0.9750
# Epoch 00132: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1633 - accuracy: 0.9649 - val_loss: 0.7714 - val_accuracy: 0.6000
# Epoch 133/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.1653 - accuracy: 0.9000
# Epoch 00133: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1745 - accuracy: 0.8947 - val_loss: 1.0056 - val_accuracy: 0.6000
# Epoch 134/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.2337 - accuracy: 0.8750
# Epoch 00134: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2116 - accuracy: 0.8772 - val_loss: 0.9829 - val_accuracy: 0.6000
# Epoch 135/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.2263 - accuracy: 0.9200
# Epoch 00135: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2147 - accuracy: 0.9123 - val_loss: 0.8232 - val_accuracy: 0.6000
# Epoch 136/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1137 - accuracy: 0.9800
# Epoch 00136: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1111 - accuracy: 0.9825 - val_loss: 0.9601 - val_accuracy: 0.6000
# Epoch 137/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1035 - accuracy: 1.0000
# Epoch 00137: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1295 - accuracy: 0.9649 - val_loss: 0.8585 - val_accuracy: 0.6000
# Epoch 138/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.2034 - accuracy: 0.9000
# Epoch 00138: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1857 - accuracy: 0.9123 - val_loss: 0.8458 - val_accuracy: 0.6000
# Epoch 139/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1394 - accuracy: 0.9400
# Epoch 00139: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1595 - accuracy: 0.9123 - val_loss: 1.2994 - val_accuracy: 0.6000
# Epoch 140/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.2110 - accuracy: 0.8800
# Epoch 00140: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1977 - accuracy: 0.8947 - val_loss: 0.6059 - val_accuracy: 0.6667
# Epoch 141/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.2346 - accuracy: 0.9200
# Epoch 00141: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2314 - accuracy: 0.9123 - val_loss: 1.0593 - val_accuracy: 0.6000
# Epoch 142/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1525 - accuracy: 0.9600
# Epoch 00142: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1699 - accuracy: 0.9474 - val_loss: 1.1431 - val_accuracy: 0.6000
# Epoch 143/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1305 - accuracy: 0.9600
# Epoch 00143: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1494 - accuracy: 0.9474 - val_loss: 0.7961 - val_accuracy: 0.6000
# Epoch 144/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.1231 - accuracy: 0.9750
# Epoch 00144: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1646 - accuracy: 0.9474 - val_loss: 0.6682 - val_accuracy: 0.6667
# Epoch 145/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.1083 - accuracy: 0.9750
# Epoch 00145: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1342 - accuracy: 0.9649 - val_loss: 1.1989 - val_accuracy: 0.6000
# Epoch 146/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.1742 - accuracy: 0.9000
# Epoch 00146: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1927 - accuracy: 0.9123 - val_loss: 0.7541 - val_accuracy: 0.6000
# Epoch 147/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.1315 - accuracy: 0.9500
# Epoch 00147: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1409 - accuracy: 0.9298 - val_loss: 0.9424 - val_accuracy: 0.6000
# Epoch 148/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1463 - accuracy: 0.9200
# Epoch 00148: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1489 - accuracy: 0.9123 - val_loss: 1.0194 - val_accuracy: 0.6000
# Epoch 149/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1755 - accuracy: 0.9400
# Epoch 00149: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1552 - accuracy: 0.9474 - val_loss: 0.9272 - val_accuracy: 0.6000
# Epoch 150/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1065 - accuracy: 0.9600
# Epoch 00150: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1206 - accuracy: 0.9474 - val_loss: 0.8395 - val_accuracy: 0.6000
# Epoch 151/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1302 - accuracy: 0.9400
# Epoch 00151: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1415 - accuracy: 0.9474 - val_loss: 1.1331 - val_accuracy: 0.6000
# Epoch 152/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.1309 - accuracy: 0.9500
# Epoch 00152: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1383 - accuracy: 0.9474 - val_loss: 0.9921 - val_accuracy: 0.6000
# Epoch 153/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.0946 - accuracy: 0.9750
# Epoch 00153: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1013 - accuracy: 0.9825 - val_loss: 1.1468 - val_accuracy: 0.6000
# Epoch 154/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1142 - accuracy: 0.9600
# Epoch 00154: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1268 - accuracy: 0.9474 - val_loss: 0.9034 - val_accuracy: 0.6000
# Epoch 155/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1055 - accuracy: 0.9800
# Epoch 00155: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1003 - accuracy: 0.9825 - val_loss: 1.2792 - val_accuracy: 0.6000
# Epoch 156/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1572 - accuracy: 0.9200
# Epoch 00156: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1479 - accuracy: 0.9298 - val_loss: 1.0440 - val_accuracy: 0.6000
# Epoch 157/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1356 - accuracy: 0.9400
# Epoch 00157: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1219 - accuracy: 0.9474 - val_loss: 1.1991 - val_accuracy: 0.6000
# Epoch 158/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1406 - accuracy: 0.9400
# Epoch 00158: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1354 - accuracy: 0.9474 - val_loss: 1.1510 - val_accuracy: 0.6000
# Epoch 159/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1206 - accuracy: 0.9600
# Epoch 00159: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1124 - accuracy: 0.9649 - val_loss: 0.9016 - val_accuracy: 0.6000
# Epoch 160/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0844 - accuracy: 0.9600
# Epoch 00160: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0978 - accuracy: 0.9649 - val_loss: 1.1670 - val_accuracy: 0.6000
# Epoch 161/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1642 - accuracy: 0.9200
# Epoch 00161: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1570 - accuracy: 0.9298 - val_loss: 0.8316 - val_accuracy: 0.6667
# Epoch 162/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1682 - accuracy: 0.9600
# Epoch 00162: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1502 - accuracy: 0.9649 - val_loss: 1.0780 - val_accuracy: 0.6000
# Epoch 163/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1301 - accuracy: 0.9400
# Epoch 00163: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1312 - accuracy: 0.9474 - val_loss: 1.1013 - val_accuracy: 0.6000
# Epoch 164/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1245 - accuracy: 0.9400
# Epoch 00164: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1376 - accuracy: 0.9298 - val_loss: 0.7569 - val_accuracy: 0.6667
# Epoch 165/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.1859 - accuracy: 0.9000
# Epoch 00165: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1631 - accuracy: 0.9123 - val_loss: 0.9580 - val_accuracy: 0.6667
# Epoch 166/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.0891 - accuracy: 0.9750
# Epoch 00166: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1091 - accuracy: 0.9474 - val_loss: 0.9877 - val_accuracy: 0.6000
# Epoch 167/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.1098 - accuracy: 0.9750
# Epoch 00167: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1268 - accuracy: 0.9474 - val_loss: 0.9288 - val_accuracy: 0.6667
# Epoch 168/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.0923 - accuracy: 0.9750
# Epoch 00168: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1057 - accuracy: 0.9649 - val_loss: 0.9228 - val_accuracy: 0.6000
# Epoch 169/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.2424 - accuracy: 0.90 - ETA: 0s - loss: 0.1338 - accuracy: 0.9600
# Epoch 00169: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1511 - accuracy: 0.9474 - val_loss: 0.9670 - val_accuracy: 0.6000
# Epoch 170/250
# ...
# Epoch 195/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1425 - accuracy: 0.9400
# Epoch 00195: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1293 - accuracy: 0.9474 - val_loss: 0.9069 - val_accuracy: 0.6667
# Epoch 196/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1061 - accuracy: 0.9800
# Epoch 00196: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0970 - accuracy: 0.9825 - val_loss: 1.3396 - val_accuracy: 0.6000
# Epoch 197/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1010 - accuracy: 0.9800
# Epoch 00197: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0927 - accuracy: 0.9825 - val_loss: 0.8766 - val_accuracy: 0.6667
# Epoch 198/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1055 - accuracy: 0.9800
# Epoch 00198: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0997 - accuracy: 0.9825 - val_loss: 1.1861 - val_accuracy: 0.6000
# Epoch 199/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0756 - accuracy: 0.9800
# Epoch 00199: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0862 - accuracy: 0.9649 - val_loss: 1.1256 - val_accuracy: 0.6667
# Epoch 200/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0748 - accuracy: 0.9800
# Epoch 00200: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0822 - accuracy: 0.9825 - val_loss: 0.8823 - val_accuracy: 0.6667
# Epoch 201/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0587 - accuracy: 1.0000
# Epoch 00201: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0642 - accuracy: 1.0000 - val_loss: 1.3742 - val_accuracy: 0.6000
# Epoch 202/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0971 - accuracy: 0.9600
# Epoch 00202: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1192 - accuracy: 0.9474 - val_loss: 0.8407 - val_accuracy: 0.6667
# Epoch 203/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1053 - accuracy: 0.9400
# Epoch 00203: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0932 - accuracy: 0.9474 - val_loss: 0.7046 - val_accuracy: 0.6667
# Epoch 204/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0926 - accuracy: 0.9600
# Epoch 00204: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1023 - accuracy: 0.9474 - val_loss: 1.7819 - val_accuracy: 0.6000
# Epoch 205/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1833 - accuracy: 0.9000
# Epoch 00205: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1658 - accuracy: 0.9123 - val_loss: 1.3254 - val_accuracy: 0.6000
# Epoch 206/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0824 - accuracy: 0.9800
# Epoch 00206: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0927 - accuracy: 0.9649 - val_loss: 0.4382 - val_accuracy: 0.7333
# Epoch 207/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1505 - accuracy: 0.9800
# Epoch 00207: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1487 - accuracy: 0.9825 - val_loss: 0.9791 - val_accuracy: 0.6667
# Epoch 208/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0885 - accuracy: 0.9600
# Epoch 00208: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0972 - accuracy: 0.9474 - val_loss: 1.1194 - val_accuracy: 0.6000
# Epoch 209/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1346 - accuracy: 0.9800
# Epoch 00209: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1248 - accuracy: 0.9825 - val_loss: 0.5208 - val_accuracy: 0.7333
# Epoch 210/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1553 - accuracy: 0.8800
# Epoch 00210: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1613 - accuracy: 0.8772 - val_loss: 0.5739 - val_accuracy: 0.7333
# Epoch 211/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1086 - accuracy: 0.9600
# Epoch 00211: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0956 - accuracy: 0.9649 - val_loss: 1.7586 - val_accuracy: 0.6000
# Epoch 212/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1726 - accuracy: 0.9000
# Epoch 00212: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1709 - accuracy: 0.9123 - val_loss: 0.9423 - val_accuracy: 0.6667
# Epoch 213/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0721 - accuracy: 0.9800
# Epoch 00213: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0648 - accuracy: 0.9825 - val_loss: 0.4478 - val_accuracy: 0.7333
# Epoch 214/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1177 - accuracy: 0.9600
# Epoch 00214: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1294 - accuracy: 0.9474 - val_loss: 0.7644 - val_accuracy: 0.6667
# Epoch 215/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0537 - accuracy: 1.0000
# Epoch 00215: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0567 - accuracy: 1.0000 - val_loss: 1.3391 - val_accuracy: 0.6000
# Epoch 216/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0862 - accuracy: 1.0000
# Epoch 00216: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0793 - accuracy: 1.0000 - val_loss: 1.1444 - val_accuracy: 0.6667
# Epoch 217/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0707 - accuracy: 0.9800
# Epoch 00217: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0695 - accuracy: 0.9825 - val_loss: 0.7806 - val_accuracy: 0.6667
# Epoch 218/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0977 - accuracy: 0.9600
# Epoch 00218: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0953 - accuracy: 0.9649 - val_loss: 1.1098 - val_accuracy: 0.6667
# Epoch 219/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1174 - accuracy: 0.9600
# Epoch 00219: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1157 - accuracy: 0.9649 - val_loss: 1.3472 - val_accuracy: 0.6000
# Epoch 220/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1147 - accuracy: 0.9400
# Epoch 00220: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1121 - accuracy: 0.9474 - val_loss: 1.0863 - val_accuracy: 0.6667
# Epoch 221/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0677 - accuracy: 1.0000
# Epoch 00221: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0603 - accuracy: 1.0000 - val_loss: 1.3152 - val_accuracy: 0.6000
# Epoch 222/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0558 - accuracy: 0.9800
# Epoch 00222: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0556 - accuracy: 0.9825 - val_loss: 1.3068 - val_accuracy: 0.6000
# Epoch 223/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0735 - accuracy: 0.9800
# Epoch 00223: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0737 - accuracy: 0.9825 - val_loss: 0.9991 - val_accuracy: 0.6667
# Epoch 224/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0665 - accuracy: 0.9600
# Epoch 00224: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0635 - accuracy: 0.9649 - val_loss: 1.2396 - val_accuracy: 0.6667
# Epoch 225/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0898 - accuracy: 0.9400
# Epoch 00225: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0842 - accuracy: 0.9474 - val_loss: 1.4368 - val_accuracy: 0.6000
# Epoch 226/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1254 - accuracy: 0.9600
# Epoch 00226: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1174 - accuracy: 0.9649 - val_loss: 1.1893 - val_accuracy: 0.6667
# Epoch 227/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0547 - accuracy: 1.0000
# Epoch 00227: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0495 - accuracy: 1.0000 - val_loss: 1.4112 - val_accuracy: 0.6667
# Epoch 228/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0712 - accuracy: 1.0000
# Epoch 00228: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0715 - accuracy: 1.0000 - val_loss: 1.1472 - val_accuracy: 0.6667
# Epoch 229/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0669 - accuracy: 0.9800
# Epoch 00229: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0698 - accuracy: 0.9825 - val_loss: 1.3723 - val_accuracy: 0.6667
# Epoch 230/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0511 - accuracy: 1.0000
# Epoch 00230: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0623 - accuracy: 0.9825 - val_loss: 1.5774 - val_accuracy: 0.6667
# Epoch 231/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0530 - accuracy: 0.9800
# Epoch 00231: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0482 - accuracy: 0.9825 - val_loss: 1.0968 - val_accuracy: 0.6667
# Epoch 232/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0646 - accuracy: 0.9600
# Epoch 00232: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0661 - accuracy: 0.9649 - val_loss: 1.1923 - val_accuracy: 0.6667
# Epoch 233/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.0557 - accuracy: 1.0000
# Epoch 00233: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0521 - accuracy: 1.0000 - val_loss: 1.1521 - val_accuracy: 0.6667
# Epoch 234/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0961 - accuracy: 0.9600
# Epoch 00234: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0910 - accuracy: 0.9649 - val_loss: 1.7062 - val_accuracy: 0.6000
# Epoch 235/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1088 - accuracy: 0.9400
# Epoch 00235: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0969 - accuracy: 0.9474 - val_loss: 1.2307 - val_accuracy: 0.6667
# Epoch 236/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0839 - accuracy: 0.9600
# Epoch 00236: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0738 - accuracy: 0.9649 - val_loss: 0.6749 - val_accuracy: 0.7333
# Epoch 237/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.0608 - accuracy: 1.0000
# Epoch 00237: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0497 - accuracy: 1.0000 - val_loss: 1.1113 - val_accuracy: 0.6667
# Epoch 238/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0397 - accuracy: 1.0000
# Epoch 00238: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0487 - accuracy: 1.0000 - val_loss: 1.3955 - val_accuracy: 0.6667
# Epoch 239/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0585 - accuracy: 0.9800
# Epoch 00239: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0994 - accuracy: 0.9649 - val_loss: 0.8278 - val_accuracy: 0.6667
# Epoch 240/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0427 - accuracy: 0.9800
# Epoch 00240: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0734 - accuracy: 0.9649 - val_loss: 0.8512 - val_accuracy: 0.6667
# Epoch 241/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0582 - accuracy: 0.9800
# Epoch 00241: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0542 - accuracy: 0.9825 - val_loss: 1.3375 - val_accuracy: 0.6667
# Epoch 242/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.1377 - accuracy: 0.9400
# Epoch 00242: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1288 - accuracy: 0.9474 - val_loss: 1.1654 - val_accuracy: 0.6667
# Epoch 243/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0443 - accuracy: 1.0000
# Epoch 00243: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0396 - accuracy: 1.0000 - val_loss: 1.0289 - val_accuracy: 0.6667
# Epoch 244/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0697 - accuracy: 0.9600
# Epoch 00244: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0631 - accuracy: 0.9649 - val_loss: 1.2660 - val_accuracy: 0.6667
# Epoch 245/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0636 - accuracy: 0.9600
# Epoch 00245: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0569 - accuracy: 0.9649 - val_loss: 1.4748 - val_accuracy: 0.6667
# Epoch 246/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0410 - accuracy: 0.9800
# Epoch 00246: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0407 - accuracy: 0.9825 - val_loss: 1.1859 - val_accuracy: 0.7333
# Epoch 247/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0981 - accuracy: 0.9600
# Epoch 00247: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0879 - accuracy: 0.9649 - val_loss: 1.2572 - val_accuracy: 0.6667
# Epoch 248/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.0393 - accuracy: 1.0000
# Epoch 00248: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0328 - accuracy: 1.0000 - val_loss: 1.2220 - val_accuracy: 0.6667
# Epoch 249/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0488 - accuracy: 1.0000
# Epoch 00249: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0429 - accuracy: 1.0000 - val_loss: 1.2690 - val_accuracy: 0.6667
# Epoch 250/250
# 50/57 [=========================>....] - ETA: 0s - loss: 0.0304 - accuracy: 1.0000
# Epoch 00250: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0293 - accuracy: 1.0000 - val_loss: 1.1225 - val_accuracy: 0.6667
# Training completed in time:  0:00:29.175007

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# **Test the model**
#
# Here we will review the accuracy of the model on both the training and test data sets.

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.98245615
# Testing Accuracy:  0.6666667

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       1.00      0.29      0.44         7
#    Pneumonia       0.62      1.00      0.76         8
#
#     accuracy                           0.67        15
#    macro avg       0.81      0.64      0.60        15
# weighted avg       0.79      0.67      0.61        15

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[2 5]
#  [0 8]]
