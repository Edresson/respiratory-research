# %%
# !unzip respiratory-sound-database.zip

# %%
# Load various imports 
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
mypath = "./Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/"
filenames = [f for f in listdir(mypath) if (isfile(join(mypath, f)) and f.endswith('.wav'))]

# %%
p_id_in_file = [] # patient IDs corresponding to each file
for name in filenames:
    p_id_in_file.append(int(name[:3]))

p_id_in_file = np.array(p_id_in_file)

# %%
max_pad_len = 862 # to make the length of all MFCC equal


os.makedirs("./Respiratory_Sound_Database/features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
    if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
        return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=20) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./Respiratory_Sound_Database/features/", feature), mfccs)
    return mfccs

# %%
filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
p_diag = pd.read_csv("./Respiratory_Sound_Database/Respiratory_Sound_Database/patient_diagnosis.csv",header=None) # patient diagnosis file

# %%
labels = np.array([p_diag[p_diag[0] == x][1].values[0] for x in p_id_in_file]) # labels for audio files

# %%
features = [] 

# Iterate through each sound file and extract the features
for file_name in filepaths:
    data = extract_features(file_name)
    features.append(data)

print('Finished feature extraction from ', len(features), ' files')
features = np.array(features)
# Out:
# Finished feature extraction from  920  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
features = np.array(features) # convert to numpy array

# %%
np.unique(labels)
# Out:
# array(['Asthma', 'Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy',
#        'LRTI', 'Pneumonia', 'URTI'], dtype='<U14')

# %%
# delete diseases
'''
features1 = features
labels1 = labels'''

features1 = np.delete(features, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0) 

labels1 = np.delete(labels, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0)

# %%
# print class counts
unique_elements, counts_elements = np.unique(labels1, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['35' '37']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(labels1)
oh_labels = to_categorical(i_labels)

# %%
# add channel dimension for CNN
features1 = np.reshape(features1, (*features1.shape,1))

# %%
# train test split
x_train, x_test, y_train, y_test = train_test_split(features1, oh_labels, stratify=oh_labels, 
                                                    test_size=0.2, random_state = 42)

# %% [markdown]
# **Convolutional Neural Network (CNN) model architecture**
#
# Our model will be a Convolutional Neural Network (CNN) using Keras and a Tensorflow backend.
#
# We will use a sequential model, with a simple model architecture, consisting of four Conv2D convolution layers, with our final output layer being a dense layer.
#
# The convolution layers are designed for feature detection. It works by sliding a filter window over the input and performing a matrix multiplication and storing the result in a feature map. This operation is known as a convolution.
#
# The filter parameter specifies the number of nodes in each layer. Each layer will increase in size from 16, 32, 64 to 128, while the kernel_size parameter specifies the size of the kernel window which in this case is 2 resulting in a 2x2 filter matrix.
#
# The first layer will receive the input shape of (40, 862, 1) where 40 is the number of MFCC's, 862 is the number of frames taking padding into account and the 1 signifying that the audio is mono.
#
# The activation function we will be using for our convolutional layers is ReLU. We will use a small Dropout value of 20% on our convolutional layers.
#
# Each convolutional layer has an associated pooling layer of MaxPooling2D type with the final convolutional layer having a GlobalAveragePooling2D type. The pooling layer is to reduce the dimensionality of the model (by reducing the parameters and subsquent computation requirements) which serves to shorten the training time and reduce overfitting. The Max Pooling type takes the maximum size for each window and the Global Average Pooling type takes the average which is suitable for feeding into our dense output layer.
#
# Our output layer will have 6 nodes (num_labels) which matches the number of possible classifications. The activation is for our output layer is softmax. Softmax makes the output sum up to 1 so the output can be interpreted as probabilities. The model will then make its prediction based on which option has the highest probability.

# %%
num_rows = 40
num_columns = 862
num_channels = 1

num_labels = oh_labels.shape[1]
filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 861, 16)       80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 430, 16)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 430, 16)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 429, 32)       2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 214, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 214, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 213, 64)        8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 106, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 106, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 105, 128)       32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 52, 128)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 52, 128)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 258
# =================================================================
# Total params: 43,570
# Trainable params: 43,570
# Non-trainable params: 0
# _________________________________________________________________
# 15/15 [==============================] - 2s 137ms/sample - loss: 6.4496 - accuracy: 0.5333
# Pre-training accuracy: 53.3333%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 250
num_batch_size = 5

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/model1_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 57 samples, validate on 15 samples
# Epoch 1/250
# 35/57 [=================>............] - ETA: 0s - loss: 7.2240 - accuracy: 0.3714
# Epoch 00001: val_accuracy improved from -inf to 0.46667, saving model to models/model1_01.h5
# 57/57 [==============================] - 1s 26ms/sample - loss: 5.9756 - accuracy: 0.4211 - val_loss: 1.4972 - val_accuracy: 0.4667
# Epoch 2/250
# 35/57 [=================>............] - ETA: 0s - loss: 1.8082 - accuracy: 0.5429
# Epoch 00002: val_accuracy did not improve from 0.46667
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.6529 - accuracy: 0.5439 - val_loss: 0.9375 - val_accuracy: 0.4667
# Epoch 3/250
# 35/57 [=================>............] - ETA: 0s - loss: 1.3340 - accuracy: 0.5429
# Epoch 00003: val_accuracy did not improve from 0.46667
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.5459 - accuracy: 0.5789 - val_loss: 0.7327 - val_accuracy: 0.4667
# Epoch 4/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.8778 - accuracy: 0.6000
# Epoch 00004: val_accuracy did not improve from 0.46667
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.7666 - accuracy: 0.6316 - val_loss: 1.2415 - val_accuracy: 0.4667
# Epoch 5/250
# 35/57 [=================>............] - ETA: 0s - loss: 1.5930 - accuracy: 0.5143
# Epoch 00005: val_accuracy did not improve from 0.46667
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.3793 - accuracy: 0.5614 - val_loss: 1.1007 - val_accuracy: 0.4667
# Epoch 6/250
# 35/57 [=================>............] - ETA: 0s - loss: 1.0280 - accuracy: 0.6286
# Epoch 00006: val_accuracy did not improve from 0.46667
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.1069 - accuracy: 0.6316 - val_loss: 0.7045 - val_accuracy: 0.4667
# Epoch 7/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.7102 - accuracy: 0.6000
# Epoch 00007: val_accuracy improved from 0.46667 to 0.60000, saving model to models/model1_07.h5
# 57/57 [==============================] - 0s 3ms/sample - loss: 0.7129 - accuracy: 0.5789 - val_loss: 0.6224 - val_accuracy: 0.6000
# Epoch 8/250
# 35/57 [=================>............] - ETA: 0s - loss: 1.1309 - accuracy: 0.4857
# Epoch 00008: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.9355 - accuracy: 0.5439 - val_loss: 0.6384 - val_accuracy: 0.5333
# Epoch 9/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.9710 - accuracy: 0.6727
# Epoch 00009: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.9454 - accuracy: 0.6842 - val_loss: 0.6827 - val_accuracy: 0.5333
# Epoch 10/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.6048 - accuracy: 0.7091
# Epoch 00010: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.5944 - accuracy: 0.7193 - val_loss: 0.6422 - val_accuracy: 0.5333
# Epoch 11/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.5187 - accuracy: 0.6909
# Epoch 00011: val_accuracy improved from 0.60000 to 0.66667, saving model to models/model1_11.h5
# 57/57 [==============================] - 0s 3ms/sample - loss: 0.5487 - accuracy: 0.6842 - val_loss: 0.5782 - val_accuracy: 0.6667
# Epoch 12/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.9160 - accuracy: 0.6727
# Epoch 00012: val_accuracy improved from 0.66667 to 0.93333, saving model to models/model1_12.h5
# 57/57 [==============================] - 0s 3ms/sample - loss: 0.9319 - accuracy: 0.6491 - val_loss: 0.5521 - val_accuracy: 0.9333
# Epoch 13/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.6676 - accuracy: 0.6333
# Epoch 00013: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.5589 - accuracy: 0.7193 - val_loss: 0.5919 - val_accuracy: 0.5333
# Epoch 14/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.9605 - accuracy: 0.5667
# Epoch 00014: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.9027 - accuracy: 0.5614 - val_loss: 0.6021 - val_accuracy: 0.6667
# Epoch 15/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.4507 - accuracy: 0.8000
# Epoch 00015: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4766 - accuracy: 0.7895 - val_loss: 0.5348 - val_accuracy: 0.9333
# Epoch 16/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.4180 - accuracy: 0.8000
# Epoch 00016: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4834 - accuracy: 0.7368 - val_loss: 0.5251 - val_accuracy: 0.9333
# Epoch 17/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.3845 - accuracy: 0.8667
# Epoch 00017: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4127 - accuracy: 0.8246 - val_loss: 0.5044 - val_accuracy: 0.8000
# Epoch 18/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.3708 - accuracy: 0.8000
# Epoch 00018: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4102 - accuracy: 0.8070 - val_loss: 0.4891 - val_accuracy: 0.8000
# Epoch 19/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.2897 - accuracy: 0.8667
# Epoch 00019: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3266 - accuracy: 0.8246 - val_loss: 0.4706 - val_accuracy: 0.8000
# Epoch 20/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.3565 - accuracy: 0.8571
# Epoch 00020: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3202 - accuracy: 0.8947 - val_loss: 0.4554 - val_accuracy: 0.7333
# Epoch 21/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.4919 - accuracy: 0.7667
# Epoch 00021: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.5110 - accuracy: 0.7544 - val_loss: 0.4716 - val_accuracy: 0.8667
# Epoch 22/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.3360 - accuracy: 0.8286
# Epoch 00022: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3265 - accuracy: 0.8246 - val_loss: 0.8011 - val_accuracy: 0.5333
# Epoch 23/250
# 30/57 [==============>...............] - ETA: 0s - loss: 1.2155 - accuracy: 0.6333
# Epoch 00023: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.8508 - accuracy: 0.7193 - val_loss: 0.4816 - val_accuracy: 0.7333
# Epoch 24/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.5154 - accuracy: 0.7333
# Epoch 00024: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4115 - accuracy: 0.8070 - val_loss: 0.5624 - val_accuracy: 0.6000
# Epoch 25/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.3301 - accuracy: 0.8857
# Epoch 00025: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3488 - accuracy: 0.8421 - val_loss: 0.4649 - val_accuracy: 0.8667
# Epoch 26/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.2854 - accuracy: 0.9000
# Epoch 00026: val_accuracy improved from 0.93333 to 1.00000, saving model to models/model1_26.h5
# 57/57 [==============================] - 0s 3ms/sample - loss: 0.3061 - accuracy: 0.8772 - val_loss: 0.4588 - val_accuracy: 1.0000
# Epoch 27/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.3030 - accuracy: 0.8667
# Epoch 00027: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3262 - accuracy: 0.8596 - val_loss: 0.4899 - val_accuracy: 0.6667
# Epoch 28/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.2431 - accuracy: 0.9333
# Epoch 00028: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2699 - accuracy: 0.9298 - val_loss: 0.4802 - val_accuracy: 0.6667
# Epoch 29/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.3463 - accuracy: 0.8333
# Epoch 00029: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2641 - accuracy: 0.8947 - val_loss: 0.5241 - val_accuracy: 0.6667
# Epoch 30/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.2647 - accuracy: 0.8545
# Epoch 00030: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2555 - accuracy: 0.8596 - val_loss: 0.4772 - val_accuracy: 0.7333
# Epoch 31/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.2638 - accuracy: 0.8909
# Epoch 00031: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2661 - accuracy: 0.8947 - val_loss: 0.6516 - val_accuracy: 0.6000
# Epoch 32/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.2142 - accuracy: 0.8909
# Epoch 00032: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2216 - accuracy: 0.8772 - val_loss: 0.9988 - val_accuracy: 0.6000
# Epoch 33/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.5182 - accuracy: 0.7714
# Epoch 00033: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4733 - accuracy: 0.7719 - val_loss: 0.4132 - val_accuracy: 0.8000
# Epoch 34/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.2752 - accuracy: 0.8286
# Epoch 00034: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2887 - accuracy: 0.8421 - val_loss: 0.4036 - val_accuracy: 0.9333
# Epoch 35/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.3602 - accuracy: 0.8571
# Epoch 00035: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3192 - accuracy: 0.8596 - val_loss: 0.5079 - val_accuracy: 0.6667
# Epoch 36/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.2392 - accuracy: 0.8857
# Epoch 00036: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2252 - accuracy: 0.9123 - val_loss: 0.5552 - val_accuracy: 0.7333
# Epoch 37/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.2220 - accuracy: 0.8571
# Epoch 00037: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2012 - accuracy: 0.8947 - val_loss: 0.6817 - val_accuracy: 0.6000
# Epoch 38/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.2915 - accuracy: 0.8571
# Epoch 00038: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2659 - accuracy: 0.8772 - val_loss: 0.4169 - val_accuracy: 0.8667
# Epoch 39/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.2417 - accuracy: 0.8571
# Epoch 00039: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2231 - accuracy: 0.8947 - val_loss: 0.5084 - val_accuracy: 0.8000
# Epoch 40/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.1938 - accuracy: 0.9333
# Epoch 00040: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1947 - accuracy: 0.9123 - val_loss: 0.6288 - val_accuracy: 0.6000
# Epoch 41/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.2594 - accuracy: 0.8286
# Epoch 00041: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2492 - accuracy: 0.8596 - val_loss: 0.5027 - val_accuracy: 0.6667
# Epoch 42/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.2694 - accuracy: 0.9143
# Epoch 00042: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2079 - accuracy: 0.9298 - val_loss: 0.6097 - val_accuracy: 0.7333
# Epoch 43/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.2389 - accuracy: 0.8571
# Epoch 00043: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2021 - accuracy: 0.8947 - val_loss: 0.5448 - val_accuracy: 0.8000
# Epoch 44/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.1626 - accuracy: 0.9143
# Epoch 00044: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1546 - accuracy: 0.9123 - val_loss: 0.5313 - val_accuracy: 0.8000
# Epoch 45/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.2185 - accuracy: 0.8667
# Epoch 00045: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1469 - accuracy: 0.9298 - val_loss: 0.4756 - val_accuracy: 0.8000
# Epoch 46/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.1777 - accuracy: 0.9667
# Epoch 00046: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1802 - accuracy: 0.9123 - val_loss: 0.5082 - val_accuracy: 0.7333
# Epoch 47/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.1967 - accuracy: 0.8286
# Epoch 00047: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1791 - accuracy: 0.8421 - val_loss: 0.5982 - val_accuracy: 0.8000
# Epoch 48/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.1234 - accuracy: 0.9714
# Epoch 00048: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1449 - accuracy: 0.9474 - val_loss: 0.5436 - val_accuracy: 0.6667
# Epoch 49/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.4279 - accuracy: 0.8667
# Epoch 00049: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2776 - accuracy: 0.9298 - val_loss: 0.7966 - val_accuracy: 0.6000
# Epoch 50/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.1410 - accuracy: 0.9429
# Epoch 00050: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1768 - accuracy: 0.9123 - val_loss: 0.9400 - val_accuracy: 0.6667
# Epoch 51/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.2919 - accuracy: 0.9000
# Epoch 00051: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2966 - accuracy: 0.8947 - val_loss: 0.4254 - val_accuracy: 0.8000
# Epoch 52/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.3023 - accuracy: 0.8333
# Epoch 00052: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2830 - accuracy: 0.8421 - val_loss: 0.4676 - val_accuracy: 0.8667
# Epoch 53/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.1526 - accuracy: 0.9333
# Epoch 00053: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1500 - accuracy: 0.9649 - val_loss: 0.7408 - val_accuracy: 0.6667
# Epoch 54/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.2081 - accuracy: 0.8571
# Epoch 00054: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1886 - accuracy: 0.8772 - val_loss: 0.8746 - val_accuracy: 0.6667
# Epoch 55/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.1070 - accuracy: 1.0000
# Epoch 00055: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1056 - accuracy: 0.9825 - val_loss: 0.8054 - val_accuracy: 0.6667
# Epoch 56/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0722 - accuracy: 1.0000
# Epoch 00056: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1093 - accuracy: 0.9649 - val_loss: 0.9546 - val_accuracy: 0.6667
# Epoch 57/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.1340 - accuracy: 0.9714
# Epoch 00057: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1397 - accuracy: 0.9474 - val_loss: 0.6802 - val_accuracy: 0.8000
# Epoch 58/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.1212 - accuracy: 0.9636
# Epoch 00058: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1169 - accuracy: 0.9649 - val_loss: 0.8804 - val_accuracy: 0.6667
# Epoch 59/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.1383 - accuracy: 0.9091
# Epoch 00059: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1516 - accuracy: 0.8947 - val_loss: 1.0045 - val_accuracy: 0.6667
# Epoch 60/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.0627 - accuracy: 1.0000
# Epoch 00060: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1725 - accuracy: 0.8947 - val_loss: 1.0603 - val_accuracy: 0.6000
# Epoch 61/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.1593 - accuracy: 0.9429
# Epoch 00061: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1995 - accuracy: 0.9298 - val_loss: 0.7005 - val_accuracy: 0.8000
# Epoch 62/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.1065 - accuracy: 0.9333
# Epoch 00062: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1288 - accuracy: 0.9474 - val_loss: 1.0602 - val_accuracy: 0.6667
# Epoch 63/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.1659 - accuracy: 0.9091
# Epoch 00063: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1640 - accuracy: 0.9123 - val_loss: 0.6042 - val_accuracy: 0.8000
# Epoch 64/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0836 - accuracy: 0.9818
# Epoch 00064: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 3ms/sample - loss: 0.0857 - accuracy: 0.9825 - val_loss: 1.2541 - val_accuracy: 0.6000
# Epoch 65/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0753 - accuracy: 0.9818
# Epoch 00065: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0729 - accuracy: 0.9825 - val_loss: 1.1512 - val_accuracy: 0.6667
# Epoch 66/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0712 - accuracy: 1.0000
# Epoch 00066: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0759 - accuracy: 0.9825 - val_loss: 1.0799 - val_accuracy: 0.6667
# Epoch 67/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0912 - accuracy: 1.0000
# Epoch 00067: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0931 - accuracy: 0.9825 - val_loss: 1.0747 - val_accuracy: 0.6667
# Epoch 68/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.0471 - accuracy: 1.0000
# Epoch 00068: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0706 - accuracy: 1.0000 - val_loss: 0.9377 - val_accuracy: 0.6667
# Epoch 69/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.0967 - accuracy: 1.0000
# Epoch 00069: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0855 - accuracy: 1.0000 - val_loss: 1.2162 - val_accuracy: 0.6667
# Epoch 70/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0834 - accuracy: 0.9636
# Epoch 00070: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0804 - accuracy: 0.9649 - val_loss: 0.8953 - val_accuracy: 0.6667
# Epoch 71/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0705 - accuracy: 0.9636
# Epoch 00071: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 3ms/sample - loss: 0.0688 - accuracy: 0.9649 - val_loss: 0.8317 - val_accuracy: 0.7333
# Epoch 72/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0789 - accuracy: 0.9714
# Epoch 00072: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0670 - accuracy: 0.9825 - val_loss: 1.4519 - val_accuracy: 0.6667
# Epoch 73/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.0559 - accuracy: 1.0000
# Epoch 00073: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0491 - accuracy: 1.0000 - val_loss: 1.2450 - val_accuracy: 0.6667
# Epoch 74/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.0420 - accuracy: 1.0000
# Epoch 00074: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0608 - accuracy: 1.0000 - val_loss: 1.1149 - val_accuracy: 0.7333
# Epoch 75/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0946 - accuracy: 0.9429
# Epoch 00075: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0711 - accuracy: 0.9649 - val_loss: 1.8970 - val_accuracy: 0.6667
# Epoch 76/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0490 - accuracy: 0.9818
# Epoch 00076: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0498 - accuracy: 0.9825 - val_loss: 1.6291 - val_accuracy: 0.6667
# Epoch 77/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.0329 - accuracy: 1.0000
# Epoch 00077: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0356 - accuracy: 1.0000 - val_loss: 1.5675 - val_accuracy: 0.6667
# Epoch 78/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.0266 - accuracy: 1.0000
# Epoch 00078: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0356 - accuracy: 1.0000 - val_loss: 1.9133 - val_accuracy: 0.6667
# Epoch 79/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0420 - accuracy: 1.0000
# Epoch 00079: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0405 - accuracy: 1.0000 - val_loss: 0.8970 - val_accuracy: 0.7333
# Epoch 80/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0832 - accuracy: 0.9429
# Epoch 00080: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0829 - accuracy: 0.9474 - val_loss: 2.2285 - val_accuracy: 0.6000
# Epoch 81/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.1255 - accuracy: 0.9429
# Epoch 00081: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1169 - accuracy: 0.9474 - val_loss: 1.1490 - val_accuracy: 0.6667
# Epoch 82/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.1912 - accuracy: 0.9273
# Epoch 00082: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2092 - accuracy: 0.9123 - val_loss: 0.6775 - val_accuracy: 0.7333
# Epoch 83/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0784 - accuracy: 0.9636
# Epoch 00083: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0757 - accuracy: 0.9649 - val_loss: 1.6468 - val_accuracy: 0.6000
# Epoch 84/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.0911 - accuracy: 0.9333
# Epoch 00084: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0637 - accuracy: 0.9649 - val_loss: 0.8185 - val_accuracy: 0.7333
# Epoch 85/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.1068 - accuracy: 0.9714
# Epoch 00085: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0978 - accuracy: 0.9649 - val_loss: 1.8056 - val_accuracy: 0.6667
# Epoch 86/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0461 - accuracy: 1.0000
# Epoch 00086: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0507 - accuracy: 0.9825 - val_loss: 0.8783 - val_accuracy: 0.7333
# Epoch 87/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0548 - accuracy: 0.9818
# Epoch 00087: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0531 - accuracy: 0.9825 - val_loss: 1.8196 - val_accuracy: 0.6667
# Epoch 88/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0401 - accuracy: 0.9714
# Epoch 00088: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0369 - accuracy: 0.9825 - val_loss: 1.8605 - val_accuracy: 0.6667
# Epoch 89/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0334 - accuracy: 1.0000
# Epoch 00089: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0300 - accuracy: 1.0000 - val_loss: 1.7246 - val_accuracy: 0.6667
# Epoch 90/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0439 - accuracy: 1.0000
# Epoch 00090: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0343 - accuracy: 1.0000 - val_loss: 2.1408 - val_accuracy: 0.6667
# Epoch 91/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.0300 - accuracy: 1.0000
# Epoch 00091: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0213 - accuracy: 1.0000 - val_loss: 1.6234 - val_accuracy: 0.6667
# Epoch 92/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.0166 - accuracy: 1.0000
# Epoch 00092: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0299 - accuracy: 1.0000 - val_loss: 2.5324 - val_accuracy: 0.6667
# Epoch 93/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0858 - accuracy: 0.9636
# Epoch 00093: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0828 - accuracy: 0.9649 - val_loss: 0.8103 - val_accuracy: 0.7333
# Epoch 94/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0500 - accuracy: 0.9818
# Epoch 00094: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 3ms/sample - loss: 0.0482 - accuracy: 0.9825 - val_loss: 1.8679 - val_accuracy: 0.6667
# Epoch 95/250
# 40/57 [====================>.........] - ETA: 0s - loss: 0.0320 - accuracy: 1.0000
# Epoch 00095: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0274 - accuracy: 1.0000 - val_loss: 1.7629 - val_accuracy: 0.6667
# Epoch 96/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0478 - accuracy: 0.9714
# Epoch 00096: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0314 - accuracy: 0.9825 - val_loss: 2.3382 - val_accuracy: 0.6667
# Epoch 97/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.0207 - accuracy: 1.0000
# Epoch 00097: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0174 - accuracy: 1.0000 - val_loss: 1.6085 - val_accuracy: 0.6667
# Epoch 98/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0403 - accuracy: 0.9714
# Epoch 00098: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0288 - accuracy: 0.9825 - val_loss: 2.5899 - val_accuracy: 0.6000
# Epoch 99/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.0309 - accuracy: 1.0000
# Epoch 00099: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0253 - accuracy: 1.0000 - val_loss: 2.3421 - val_accuracy: 0.6000
# Epoch 100/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0870 - accuracy: 0.9714
# Epoch 00100: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0546 - accuracy: 0.9825 - val_loss: 2.3532 - val_accuracy: 0.6000
# Epoch 101/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.0642 - accuracy: 0.9667
# Epoch 00101: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0554 - accuracy: 0.9825 - val_loss: 0.9516 - val_accuracy: 0.7333
# Epoch 102/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0571 - accuracy: 0.9714
# Epoch 00102: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0556 - accuracy: 0.9825 - val_loss: 3.0328 - val_accuracy: 0.6000
# Epoch 103/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.3883 - accuracy: 0.8286
# Epoch 00103: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3710 - accuracy: 0.8421 - val_loss: 2.5483 - val_accuracy: 0.6000
# Epoch 104/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.4276 - accuracy: 0.8286
# Epoch 00104: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3386 - accuracy: 0.8596 - val_loss: 0.5617 - val_accuracy: 0.7333
# Epoch 105/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.2559 - accuracy: 0.8571
# Epoch 00105: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2771 - accuracy: 0.8772 - val_loss: 0.5665 - val_accuracy: 0.7333
# Epoch 106/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0875 - accuracy: 0.9714
# Epoch 00106: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1440 - accuracy: 0.9474 - val_loss: 1.2266 - val_accuracy: 0.6667
# Epoch 107/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.2102 - accuracy: 0.9429
# Epoch 00107: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2939 - accuracy: 0.9123 - val_loss: 0.4614 - val_accuracy: 0.8667
# Epoch 108/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0737 - accuracy: 0.9714
# Epoch 00108: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0936 - accuracy: 0.9474 - val_loss: 0.9345 - val_accuracy: 0.7333
# Epoch 109/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0424 - accuracy: 1.0000
# Epoch 00109: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0735 - accuracy: 0.9825 - val_loss: 1.4341 - val_accuracy: 0.6667
# Epoch 110/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0759 - accuracy: 0.9714
# Epoch 00110: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0640 - accuracy: 0.9825 - val_loss: 1.0089 - val_accuracy: 0.8000
# Epoch 111/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.0831 - accuracy: 0.9333
# Epoch 00111: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0618 - accuracy: 0.9649 - val_loss: 1.3102 - val_accuracy: 0.7333
# Epoch 112/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0438 - accuracy: 1.0000
# Epoch 00112: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0383 - accuracy: 1.0000 - val_loss: 1.6599 - val_accuracy: 0.6667
# Epoch 113/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0606 - accuracy: 0.9714
# Epoch 00113: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0400 - accuracy: 0.9825 - val_loss: 1.9758 - val_accuracy: 0.6667
# Epoch 114/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.0150 - accuracy: 1.0000
# Epoch 00114: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0304 - accuracy: 1.0000 - val_loss: 1.7243 - val_accuracy: 0.6667
# Epoch 115/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0145 - accuracy: 1.0000
# Epoch 00115: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0304 - accuracy: 1.0000 - val_loss: 1.9854 - val_accuracy: 0.6667
# Epoch 116/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0407 - accuracy: 1.0000
# Epoch 00116: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0291 - accuracy: 1.0000 - val_loss: 1.2808 - val_accuracy: 0.7333
# Epoch 117/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0393 - accuracy: 1.0000
# Epoch 00117: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0339 - accuracy: 1.0000 - val_loss: 2.4140 - val_accuracy: 0.6000
# Epoch 118/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0627 - accuracy: 0.9429
# Epoch 00118: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0408 - accuracy: 0.9649 - val_loss: 1.3730 - val_accuracy: 0.7333
# Epoch 119/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0926 - accuracy: 0.9429
# Epoch 00119: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0861 - accuracy: 0.9649 - val_loss: 1.3004 - val_accuracy: 0.7333
# Epoch 120/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0419 - accuracy: 1.0000
# Epoch 00120: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0381 - accuracy: 1.0000 - val_loss: 1.4487 - val_accuracy: 0.7333
# Epoch 121/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0235 - accuracy: 1.0000
# Epoch 00121: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0192 - accuracy: 1.0000 - val_loss: 2.1451 - val_accuracy: 0.6667
# Epoch 122/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0659 - accuracy: 0.9714
# Epoch 00122: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0424 - accuracy: 0.9825 - val_loss: 2.1886 - val_accuracy: 0.6667
# Epoch 123/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0252 - accuracy: 1.0000
# Epoch 00123: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0183 - accuracy: 1.0000 - val_loss: 2.3934 - val_accuracy: 0.6667
# Epoch 124/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0134 - accuracy: 1.0000
# Epoch 00124: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0170 - accuracy: 1.0000 - val_loss: 2.7909 - val_accuracy: 0.6000
# Epoch 125/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0201 - accuracy: 1.0000
# Epoch 00125: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0177 - accuracy: 1.0000 - val_loss: 2.4264 - val_accuracy: 0.6667
# Epoch 126/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0118 - accuracy: 1.0000
# Epoch 00126: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0150 - accuracy: 1.0000 - val_loss: 1.9259 - val_accuracy: 0.7333
# Epoch 127/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.0063 - accuracy: 1.0000
# Epoch 00127: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0103 - accuracy: 1.0000 - val_loss: 1.9897 - val_accuracy: 0.7333
# Epoch 128/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 00128: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0072 - accuracy: 1.0000 - val_loss: 2.1444 - val_accuracy: 0.6667
# Epoch 129/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0063 - accuracy: 1.0000
# Epoch 00129: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0075 - accuracy: 1.0000 - val_loss: 2.2928 - val_accuracy: 0.6667
# Epoch 130/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0080 - accuracy: 1.0000
# Epoch 00130: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0104 - accuracy: 1.0000 - val_loss: 2.0306 - val_accuracy: 0.7333
# Epoch 131/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0501 - accuracy: 0.9714
# Epoch 00131: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0350 - accuracy: 0.9825 - val_loss: 2.3186 - val_accuracy: 0.6000
# Epoch 132/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0093 - accuracy: 1.0000
# Epoch 00132: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0254 - accuracy: 1.0000 - val_loss: 2.1116 - val_accuracy: 0.7333
# Epoch 133/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0206 - accuracy: 1.0000
# Epoch 00133: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0179 - accuracy: 1.0000 - val_loss: 1.8805 - val_accuracy: 0.7333
# Epoch 134/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0301 - accuracy: 0.9714
# Epoch 00134: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0201 - accuracy: 0.9825 - val_loss: 3.0163 - val_accuracy: 0.6000
# Epoch 135/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0184 - accuracy: 1.0000
# Epoch 00135: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0134 - accuracy: 1.0000 - val_loss: 2.4401 - val_accuracy: 0.6667
# Epoch 136/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0110 - accuracy: 1.0000
# Epoch 00136: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0078 - accuracy: 1.0000 - val_loss: 2.5925 - val_accuracy: 0.6667
# Epoch 137/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 00137: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0080 - accuracy: 1.0000 - val_loss: 2.5682 - val_accuracy: 0.6667
# Epoch 138/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.0155 - accuracy: 1.0000
# Epoch 00138: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0092 - accuracy: 1.0000 - val_loss: 3.1450 - val_accuracy: 0.6667
# Epoch 139/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 00139: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0077 - accuracy: 1.0000 - val_loss: 2.8004 - val_accuracy: 0.6667
# Epoch 140/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0066 - accuracy: 1.0000
# Epoch 00140: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0063 - accuracy: 1.0000 - val_loss: 2.8904 - val_accuracy: 0.6667
# Epoch 141/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0168 - accuracy: 1.0000
# Epoch 00141: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0110 - accuracy: 1.0000 - val_loss: 3.0871 - val_accuracy: 0.6667
# Epoch 142/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 00142: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0060 - accuracy: 1.0000 - val_loss: 2.6337 - val_accuracy: 0.6667
# Epoch 143/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0077 - accuracy: 1.0000
# Epoch 00143: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0053 - accuracy: 1.0000 - val_loss: 2.5740 - val_accuracy: 0.6667
# Epoch 144/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 00144: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0069 - accuracy: 1.0000 - val_loss: 2.6660 - val_accuracy: 0.6667
# Epoch 145/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 00145: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 3ms/sample - loss: 0.0039 - accuracy: 1.0000 - val_loss: 2.3254 - val_accuracy: 0.7333
# Epoch 146/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 00146: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.6159 - val_accuracy: 0.6667
# Epoch 147/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 00147: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0038 - accuracy: 1.0000 - val_loss: 3.1327 - val_accuracy: 0.6667
# Epoch 148/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 00148: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0040 - accuracy: 1.0000 - val_loss: 3.0332 - val_accuracy: 0.6667
# Epoch 149/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 00149: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0028 - accuracy: 1.0000 - val_loss: 2.7131 - val_accuracy: 0.6667
# Epoch 150/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0167 - accuracy: 0.9818
# Epoch 00150: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0162 - accuracy: 0.9825 - val_loss: 3.4597 - val_accuracy: 0.6667
# Epoch 151/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0517 - accuracy: 0.9714
# Epoch 00151: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0665 - accuracy: 0.9649 - val_loss: 1.6192 - val_accuracy: 0.7333
# Epoch 152/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.4422 - accuracy: 0.8857
# Epoch 00152: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.3049 - accuracy: 0.9123 - val_loss: 0.5885 - val_accuracy: 0.8667
# Epoch 153/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.1964 - accuracy: 0.9429
# Epoch 00153: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1919 - accuracy: 0.8947 - val_loss: 1.1516 - val_accuracy: 0.8000
# Epoch 154/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0567 - accuracy: 0.9636
# Epoch 00154: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0547 - accuracy: 0.9649 - val_loss: 2.8086 - val_accuracy: 0.6667
# Epoch 155/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.1972 - accuracy: 0.9714
# Epoch 00155: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.1834 - accuracy: 0.9649 - val_loss: 0.8190 - val_accuracy: 0.8667
# Epoch 156/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.1133 - accuracy: 0.9143
# Epoch 00156: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0848 - accuracy: 0.9474 - val_loss: 0.9800 - val_accuracy: 0.7333
# Epoch 157/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0591 - accuracy: 0.9429
# Epoch 00157: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0681 - accuracy: 0.9474 - val_loss: 1.2775 - val_accuracy: 0.7333
# Epoch 158/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0175 - accuracy: 1.0000
# Epoch 00158: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0176 - accuracy: 1.0000 - val_loss: 1.3556 - val_accuracy: 0.7333
# Epoch 159/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 00159: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0111 - accuracy: 1.0000 - val_loss: 1.4576 - val_accuracy: 0.7333
# Epoch 160/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0134 - accuracy: 1.0000
# Epoch 00160: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0184 - accuracy: 1.0000 - val_loss: 1.3618 - val_accuracy: 0.7333
# Epoch 161/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0106 - accuracy: 1.0000
# Epoch 00161: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0091 - accuracy: 1.0000 - val_loss: 1.8514 - val_accuracy: 0.7333
# Epoch 162/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 00162: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0085 - accuracy: 1.0000 - val_loss: 1.7135 - val_accuracy: 0.7333
# Epoch 163/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 00163: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.6469 - val_accuracy: 0.7333
# Epoch 164/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 00164: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0052 - accuracy: 1.0000 - val_loss: 1.6566 - val_accuracy: 0.7333
# Epoch 165/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0206 - accuracy: 1.0000
# Epoch 00165: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0193 - accuracy: 1.0000 - val_loss: 1.7868 - val_accuracy: 0.7333
# Epoch 166/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0157 - accuracy: 1.0000
# Epoch 00166: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0153 - accuracy: 1.0000 - val_loss: 1.6278 - val_accuracy: 0.7333
# Epoch 167/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0089 - accuracy: 1.0000
# Epoch 00167: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0141 - accuracy: 1.0000 - val_loss: 1.4730 - val_accuracy: 0.7333
# Epoch 168/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 00168: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0180 - accuracy: 1.0000 - val_loss: 1.3667 - val_accuracy: 0.7333
# Epoch 169/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0212 - accuracy: 1.0000
# Epoch 00169: val_accuracy did not improve from 1.00000
# ...
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0024 - accuracy: 1.0000 - val_loss: 2.6190 - val_accuracy: 0.7333
# Epoch 196/250
# 35/57 [=================>............] - ETA: 0s - loss: 5.7317e-04 - accuracy: 1.0000
# Epoch 00196: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.6652 - val_accuracy: 0.7333
# Epoch 197/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 00197: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0028 - accuracy: 1.0000 - val_loss: 2.9788 - val_accuracy: 0.7333
# Epoch 198/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00198: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0016 - accuracy: 1.0000 - val_loss: 2.9734 - val_accuracy: 0.7333
# Epoch 199/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00199: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0014 - accuracy: 1.0000 - val_loss: 3.0637 - val_accuracy: 0.7333
# Epoch 200/250
# 35/57 [=================>............] - ETA: 0s - loss: 9.7835e-04 - accuracy: 1.0000
# Epoch 00200: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0014 - accuracy: 1.0000 - val_loss: 3.0125 - val_accuracy: 0.7333
# Epoch 201/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00201: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0017 - accuracy: 1.0000 - val_loss: 3.0230 - val_accuracy: 0.7333
# Epoch 202/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 00202: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0022 - accuracy: 1.0000 - val_loss: 3.0725 - val_accuracy: 0.7333
# Epoch 203/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00203: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0014 - accuracy: 1.0000 - val_loss: 3.2694 - val_accuracy: 0.7333
# Epoch 204/250
# 30/57 [==============>...............] - ETA: 0s - loss: 7.3525e-04 - accuracy: 1.0000
# Epoch 00204: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0022 - accuracy: 1.0000 - val_loss: 3.0426 - val_accuracy: 0.7333
# Epoch 205/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00205: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0022 - accuracy: 1.0000 - val_loss: 2.7601 - val_accuracy: 0.7333
# Epoch 206/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 00206: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0024 - accuracy: 1.0000 - val_loss: 3.0025 - val_accuracy: 0.7333
# Epoch 207/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00207: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0020 - accuracy: 1.0000 - val_loss: 3.2289 - val_accuracy: 0.7333
# Epoch 208/250
# 35/57 [=================>............] - ETA: 0s - loss: 9.1714e-04 - accuracy: 1.0000
# Epoch 00208: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0014 - accuracy: 1.0000 - val_loss: 3.1321 - val_accuracy: 0.7333
# Epoch 209/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 00209: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0070 - accuracy: 1.0000 - val_loss: 3.3053 - val_accuracy: 0.7333
# Epoch 210/250
# 35/57 [=================>............] - ETA: 0s - loss: 7.3446e-04 - accuracy: 1.0000
# Epoch 00210: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0016 - accuracy: 1.0000 - val_loss: 4.0172 - val_accuracy: 0.6667
# Epoch 211/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00211: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0053 - accuracy: 1.0000 - val_loss: 2.8303 - val_accuracy: 0.7333
# Epoch 212/250
# 30/57 [==============>...............] - ETA: 0s - loss: 9.8644e-04 - accuracy: 1.0000
# Epoch 00212: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0016 - accuracy: 1.0000 - val_loss: 2.3121 - val_accuracy: 0.7333
# Epoch 213/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000
# Epoch 00213: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0032 - accuracy: 1.0000 - val_loss: 3.0784 - val_accuracy: 0.7333
# Epoch 214/250
# 35/57 [=================>............] - ETA: 0s - loss: 8.6089e-04 - accuracy: 1.0000
# Epoch 00214: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0025 - accuracy: 1.0000 - val_loss: 3.2376 - val_accuracy: 0.7333
# Epoch 215/250
# 35/57 [=================>............] - ETA: 0s - loss: 8.8495e-04 - accuracy: 1.0000
# Epoch 00215: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 7.1245e-04 - accuracy: 1.0000 - val_loss: 2.9364 - val_accuracy: 0.7333
# Epoch 216/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00216: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.9296 - val_accuracy: 0.7333
# Epoch 217/250
# 35/57 [=================>............] - ETA: 0s - loss: 9.8495e-04 - accuracy: 1.0000
# Epoch 00217: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 7.7526e-04 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.7333
# Epoch 218/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 00218: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.0095 - val_accuracy: 0.7333
# Epoch 219/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 00219: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0015 - accuracy: 1.0000 - val_loss: 3.1898 - val_accuracy: 0.7333
# Epoch 220/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00220: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0012 - accuracy: 1.0000 - val_loss: 3.3633 - val_accuracy: 0.7333
# Epoch 221/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 00221: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0015 - accuracy: 1.0000 - val_loss: 3.2667 - val_accuracy: 0.7333
# Epoch 222/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 00222: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0012 - accuracy: 1.0000 - val_loss: 3.0807 - val_accuracy: 0.7333
# Epoch 223/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 00223: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0022 - accuracy: 1.0000 - val_loss: 3.0704 - val_accuracy: 0.7333
# Epoch 224/250
# 35/57 [=================>............] - ETA: 0s - loss: 4.9191e-04 - accuracy: 1.0000
# Epoch 00224: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 8.3019e-04 - accuracy: 1.0000 - val_loss: 2.9873 - val_accuracy: 0.7333
# Epoch 225/250
# 35/57 [=================>............] - ETA: 0s - loss: 9.0018e-04 - accuracy: 1.0000
# Epoch 00225: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 6.8807e-04 - accuracy: 1.0000 - val_loss: 3.0953 - val_accuracy: 0.7333
# Epoch 226/250
# 35/57 [=================>............] - ETA: 0s - loss: 5.1396e-04 - accuracy: 1.0000
# Epoch 00226: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 4.7940e-04 - accuracy: 1.0000 - val_loss: 3.1180 - val_accuracy: 0.7333
# Epoch 227/250
# 35/57 [=================>............] - ETA: 0s - loss: 9.9526e-04 - accuracy: 1.0000
# Epoch 00227: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.1890 - val_accuracy: 0.7333
# Epoch 228/250
# 35/57 [=================>............] - ETA: 0s - loss: 6.9823e-04 - accuracy: 1.0000
# Epoch 00228: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 6.6188e-04 - accuracy: 1.0000 - val_loss: 3.1667 - val_accuracy: 0.7333
# Epoch 229/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00229: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 9.3546e-04 - accuracy: 1.0000 - val_loss: 3.0739 - val_accuracy: 0.7333
# Epoch 230/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00230: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0015 - accuracy: 1.0000 - val_loss: 3.2074 - val_accuracy: 0.7333
# Epoch 231/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00231: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0010 - accuracy: 1.0000 - val_loss: 3.2690 - val_accuracy: 0.7333
# Epoch 232/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 00232: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.4302 - val_accuracy: 0.7333
# Epoch 233/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00233: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.3683 - val_accuracy: 0.7333
# Epoch 234/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00234: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 7.9150e-04 - accuracy: 1.0000 - val_loss: 3.2647 - val_accuracy: 0.7333
# Epoch 235/250
# 35/57 [=================>............] - ETA: 0s - loss: 7.6489e-04 - accuracy: 1.0000
# Epoch 00235: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.2980 - val_accuracy: 0.7333
# Epoch 236/250
# 35/57 [=================>............] - ETA: 0s - loss: 9.5289e-04 - accuracy: 1.0000
# Epoch 00236: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0010 - accuracy: 1.0000 - val_loss: 3.3788 - val_accuracy: 0.7333
# Epoch 237/250
# 30/57 [==============>...............] - ETA: 0s - loss: 5.3735e-04 - accuracy: 1.0000
# Epoch 00237: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 9.1673e-04 - accuracy: 1.0000 - val_loss: 3.5272 - val_accuracy: 0.7333
# Epoch 238/250
# 30/57 [==============>...............] - ETA: 0s - loss: 2.4933e-04 - accuracy: 1.0000
# Epoch 00238: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 5.7311e-04 - accuracy: 1.0000 - val_loss: 3.6121 - val_accuracy: 0.7333
# Epoch 239/250
# 35/57 [=================>............] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00239: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 8.7692e-04 - accuracy: 1.0000 - val_loss: 3.5274 - val_accuracy: 0.7333
# Epoch 240/250
# 30/57 [==============>...............] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00240: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0012 - accuracy: 1.0000 - val_loss: 3.3660 - val_accuracy: 0.7333
# Epoch 241/250
# 35/57 [=================>............] - ETA: 0s - loss: 4.8057e-04 - accuracy: 1.0000
# Epoch 00241: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 5.1490e-04 - accuracy: 1.0000 - val_loss: 3.3064 - val_accuracy: 0.7333
# Epoch 242/250
# 55/57 [===========================>..] - ETA: 0s - loss: 3.0220e-04 - accuracy: 1.0000
# Epoch 00242: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 3ms/sample - loss: 2.9160e-04 - accuracy: 1.0000 - val_loss: 3.3532 - val_accuracy: 0.7333
# Epoch 243/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00243: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0016 - accuracy: 1.0000 - val_loss: 3.6623 - val_accuracy: 0.7333
# Epoch 244/250
# 30/57 [==============>...............] - ETA: 0s - loss: 9.2082e-04 - accuracy: 1.0000
# Epoch 00244: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0012 - accuracy: 1.0000 - val_loss: 3.6079 - val_accuracy: 0.7333
# Epoch 245/250
# 55/57 [===========================>..] - ETA: 0s - loss: 5.9896e-04 - accuracy: 1.0000
# Epoch 00245: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 6.2069e-04 - accuracy: 1.0000 - val_loss: 3.4300 - val_accuracy: 0.7333
# Epoch 246/250
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 00246: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.4378 - val_accuracy: 0.7333
# Epoch 247/250
# 55/57 [===========================>..] - ETA: 0s - loss: 9.8513e-04 - accuracy: 1.0000
# Epoch 00247: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 9.5072e-04 - accuracy: 1.0000 - val_loss: 3.4736 - val_accuracy: 0.7333
# Epoch 248/250
# 30/57 [==============>...............] - ETA: 0s - loss: 5.5845e-04 - accuracy: 1.0000
# Epoch 00248: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 6.4360e-04 - accuracy: 1.0000 - val_loss: 3.5814 - val_accuracy: 0.7333
# Epoch 249/250
# 35/57 [=================>............] - ETA: 0s - loss: 6.9108e-04 - accuracy: 1.0000
# Epoch 00249: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 6.3459e-04 - accuracy: 1.0000 - val_loss: 3.7505 - val_accuracy: 0.7333
# Epoch 250/250
# 55/57 [===========================>..] - ETA: 0s - loss: 6.0066e-04 - accuracy: 1.0000
# Epoch 00250: val_accuracy did not improve from 1.00000
# 57/57 [==============================] - 0s 2ms/sample - loss: 7.6398e-04 - accuracy: 1.0000 - val_loss: 3.8107 - val_accuracy: 0.7333
# Training completed in time:  0:00:33.848921

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# **Test the model**
#
# Here we will review the accuracy of the model on both the training and test data sets.

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.98245615
# Testing Accuracy:  0.73333335

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       1.00      0.43      0.60         7
#    Pneumonia       0.67      1.00      0.80         8
#
#     accuracy                           0.73        15
#    macro avg       0.83      0.71      0.70        15
# weighted avg       0.82      0.73      0.71        15

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[3 4]
#  [0 8]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])
