# %% [markdown]
# # Rede CNN - Modelo 2
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - slide5

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP = 'slide5'
MAX_PAD_LEN = 216

# %%
filepaths = glob.glob(f'./datasets/{GROUP}/**/*.wav', recursive=True)
filenames = [os.path.splitext(os.path.basename(p))[0] for p in filepaths]

# %%
p_id_in_file = [] # patient IDs corresponding to each file
for name in filenames:
    p_id_in_file.append(int(name[:3]))

p_id_in_file = np.array(p_id_in_file)

# %%
max_pad_len =  MAX_PAD_LEN

os.makedirs("./Respiratory_Sound_Database/features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=5) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./Respiratory_Sound_Database/features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
p_diag = pd.read_csv("./Respiratory_Sound_Database/Respiratory_Sound_Database/patient_diagnosis.csv",header=None) # patient diagnosis file

# %%
labels = np.array([p_diag[p_diag[0] == x][1].values[0] for x in p_id_in_file]) # labels for audio files

# %%
features = [] 

# Iterate through each sound file and extract the features
for file_name in filepaths:
    data = extract_features(file_name)
    features.append(data)

print('Finished feature extraction from ', len(features), ' files')
features = np.array(features)
# Out:
# Finished feature extraction from  576  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
features = np.array(features) # convert to numpy array

# %%
np.unique(labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
# delete diseases
'''
features1 = features
labels1 = labels'''

features1 = np.delete(features, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0) 

labels1 = np.delete(labels, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0)

# %%
# print class counts
unique_elements, counts_elements = np.unique(labels1, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['280' '296']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(labels1)
oh_labels = to_categorical(i_labels)

# %%
features1.shape
# Out:
# (576, 40, 216)

# %%
# add channel dimension for CNN
features1 = np.reshape(features1, (*features1.shape,1)) 

# train test split
x_train, x_test, y_train, y_test = train_test_split(features1, oh_labels, stratify=oh_labels, 
                                                    test_size=0.2, random_state = 42)

# %% [markdown]
# **MLP model architecture**

# %%
num_rows = 40
num_columns = 216
num_channels = 1

num_labels = oh_labels.shape[1]
filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=16, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=8, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=4, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 215, 32)       160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 107, 32)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 107, 32)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 106, 16)       2064
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 53, 16)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 53, 16)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 52, 8)          520
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 26, 8)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 26, 8)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 25, 4)          132
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 12, 4)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 12, 4)          0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 4)                 0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 10
# =================================================================
# Total params: 2,886
# Trainable params: 2,886
# Non-trainable params: 0
# _________________________________________________________________
# 116/116 [==============================] - 1s 10ms/sample - loss: 5.6853 - accuracy: 0.4828
# Pre-training accuracy: 48.2759%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 250
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/model2_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 460 samples, validate on 116 samples
# Epoch 1/250
# 450/460 [============================>.] - ETA: 0s - loss: 1.9752 - accuracy: 0.5000
# Epoch 00001: val_accuracy improved from -inf to 0.48276, saving model to models/model2_01.h5
# 460/460 [==============================] - 1s 2ms/sample - loss: 1.9475 - accuracy: 0.5000 - val_loss: 0.7225 - val_accuracy: 0.4828
# Epoch 2/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.8426 - accuracy: 0.5676
# Epoch 00002: val_accuracy improved from 0.48276 to 0.55172, saving model to models/model2_02.h5
# 460/460 [==============================] - 0s 743us/sample - loss: 0.7961 - accuracy: 0.5891 - val_loss: 0.6306 - val_accuracy: 0.5517
# Epoch 3/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.6793 - accuracy: 0.6267
# Epoch 00003: val_accuracy improved from 0.55172 to 0.57759, saving model to models/model2_03.h5
# 460/460 [==============================] - 0s 744us/sample - loss: 0.6811 - accuracy: 0.6239 - val_loss: 0.6371 - val_accuracy: 0.5776
# Epoch 4/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.6221 - accuracy: 0.6511
# Epoch 00004: val_accuracy did not improve from 0.57759
# 460/460 [==============================] - 0s 711us/sample - loss: 0.6289 - accuracy: 0.6478 - val_loss: 0.6285 - val_accuracy: 0.4828
# Epoch 5/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.5344 - accuracy: 0.7432
# Epoch 00005: val_accuracy did not improve from 0.57759
# 460/460 [==============================] - 0s 669us/sample - loss: 0.5424 - accuracy: 0.7391 - val_loss: 0.5966 - val_accuracy: 0.5086
# Epoch 6/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.5594 - accuracy: 0.7081
# Epoch 00006: val_accuracy improved from 0.57759 to 0.78448, saving model to models/model2_06.h5
# 460/460 [==============================] - 0s 747us/sample - loss: 0.5840 - accuracy: 0.6891 - val_loss: 0.6044 - val_accuracy: 0.7845
# Epoch 7/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.5120 - accuracy: 0.7311
# Epoch 00007: val_accuracy improved from 0.78448 to 0.80172, saving model to models/model2_07.h5
# 460/460 [==============================] - 0s 742us/sample - loss: 0.5112 - accuracy: 0.7326 - val_loss: 0.5355 - val_accuracy: 0.8017
# Epoch 8/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.4644 - accuracy: 0.7911
# Epoch 00008: val_accuracy improved from 0.80172 to 0.81034, saving model to models/model2_08.h5
# 460/460 [==============================] - 0s 768us/sample - loss: 0.4621 - accuracy: 0.7913 - val_loss: 0.4783 - val_accuracy: 0.8103
# Epoch 9/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.3968 - accuracy: 0.8091
# Epoch 00009: val_accuracy improved from 0.81034 to 0.84483, saving model to models/model2_09.h5
# 460/460 [==============================] - 0s 752us/sample - loss: 0.3985 - accuracy: 0.8087 - val_loss: 0.4222 - val_accuracy: 0.8448
# Epoch 10/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.4071 - accuracy: 0.8159
# Epoch 00010: val_accuracy did not improve from 0.84483
# 460/460 [==============================] - 0s 709us/sample - loss: 0.4070 - accuracy: 0.8152 - val_loss: 0.3998 - val_accuracy: 0.8103
# Epoch 11/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.4251 - accuracy: 0.8023
# Epoch 00011: val_accuracy did not improve from 0.84483
# 460/460 [==============================] - 0s 708us/sample - loss: 0.4182 - accuracy: 0.8043 - val_loss: 0.3935 - val_accuracy: 0.8276
# Epoch 12/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.4128 - accuracy: 0.8000
# Epoch 00012: val_accuracy did not improve from 0.84483
# 460/460 [==============================] - 0s 699us/sample - loss: 0.4110 - accuracy: 0.8022 - val_loss: 0.3897 - val_accuracy: 0.8276
# Epoch 13/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.3487 - accuracy: 0.8419
# Epoch 00013: val_accuracy did not improve from 0.84483
# 460/460 [==============================] - 0s 714us/sample - loss: 0.3471 - accuracy: 0.8435 - val_loss: 0.3648 - val_accuracy: 0.8276
# Epoch 14/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.3292 - accuracy: 0.8676
# Epoch 00014: val_accuracy did not improve from 0.84483
# 460/460 [==============================] - 0s 690us/sample - loss: 0.3244 - accuracy: 0.8674 - val_loss: 0.3899 - val_accuracy: 0.8276
# Epoch 15/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.3365 - accuracy: 0.8523
# Epoch 00015: val_accuracy did not improve from 0.84483
# 460/460 [==============================] - 0s 713us/sample - loss: 0.3341 - accuracy: 0.8543 - val_loss: 0.3316 - val_accuracy: 0.8362
# Epoch 16/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.3273 - accuracy: 0.8511
# Epoch 00016: val_accuracy did not improve from 0.84483
# 460/460 [==============================] - 0s 699us/sample - loss: 0.3315 - accuracy: 0.8478 - val_loss: 0.3269 - val_accuracy: 0.8448
# Epoch 17/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.2930 - accuracy: 0.8773
# Epoch 00017: val_accuracy did not improve from 0.84483
# 460/460 [==============================] - 0s 700us/sample - loss: 0.2894 - accuracy: 0.8804 - val_loss: 0.3110 - val_accuracy: 0.8362
# Epoch 18/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.3095 - accuracy: 0.8486
# Epoch 00018: val_accuracy did not improve from 0.84483
# 460/460 [==============================] - 0s 695us/sample - loss: 0.3052 - accuracy: 0.8500 - val_loss: 0.3709 - val_accuracy: 0.8362
# Epoch 19/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.3119 - accuracy: 0.8523
# Epoch 00019: val_accuracy did not improve from 0.84483
# 460/460 [==============================] - 0s 686us/sample - loss: 0.3162 - accuracy: 0.8500 - val_loss: 0.3169 - val_accuracy: 0.8448
# Epoch 20/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.2704 - accuracy: 0.8946
# Epoch 00020: val_accuracy did not improve from 0.84483
# 460/460 [==============================] - 0s 686us/sample - loss: 0.2788 - accuracy: 0.8783 - val_loss: 0.3028 - val_accuracy: 0.8448
# Epoch 21/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2801 - accuracy: 0.8786
# Epoch 00021: val_accuracy improved from 0.84483 to 0.87931, saving model to models/model2_21.h5
# 460/460 [==============================] - 0s 836us/sample - loss: 0.2843 - accuracy: 0.8717 - val_loss: 0.2843 - val_accuracy: 0.8793
# Epoch 22/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.2653 - accuracy: 0.8721
# Epoch 00022: val_accuracy did not improve from 0.87931
# 460/460 [==============================] - 0s 725us/sample - loss: 0.2574 - accuracy: 0.8783 - val_loss: 0.2761 - val_accuracy: 0.8707
# Epoch 23/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.2490 - accuracy: 0.8955
# Epoch 00023: val_accuracy did not improve from 0.87931
# 460/460 [==============================] - 0s 714us/sample - loss: 0.2560 - accuracy: 0.8935 - val_loss: 0.3000 - val_accuracy: 0.8534
# Epoch 24/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.2587 - accuracy: 0.8841
# Epoch 00024: val_accuracy did not improve from 0.87931
# 460/460 [==============================] - 0s 714us/sample - loss: 0.2608 - accuracy: 0.8826 - val_loss: 0.2706 - val_accuracy: 0.8534
# Epoch 25/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2254 - accuracy: 0.9048
# Epoch 00025: val_accuracy did not improve from 0.87931
# 460/460 [==============================] - 0s 715us/sample - loss: 0.2336 - accuracy: 0.8935 - val_loss: 0.2620 - val_accuracy: 0.8448
# Epoch 26/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.2777 - accuracy: 0.8730
# Epoch 00026: val_accuracy did not improve from 0.87931
# 460/460 [==============================] - 0s 683us/sample - loss: 0.2666 - accuracy: 0.8783 - val_loss: 0.2657 - val_accuracy: 0.8793
# Epoch 27/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.2606 - accuracy: 0.8795
# Epoch 00027: val_accuracy did not improve from 0.87931
# 460/460 [==============================] - 0s 705us/sample - loss: 0.2664 - accuracy: 0.8804 - val_loss: 0.2508 - val_accuracy: 0.8621
# Epoch 28/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.2434 - accuracy: 0.8844
# Epoch 00028: val_accuracy improved from 0.87931 to 0.88793, saving model to models/model2_28.h5
# 460/460 [==============================] - 0s 774us/sample - loss: 0.2436 - accuracy: 0.8826 - val_loss: 0.2612 - val_accuracy: 0.8879
# Epoch 29/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.2159 - accuracy: 0.9044
# Epoch 00029: val_accuracy improved from 0.88793 to 0.91379, saving model to models/model2_29.h5
# 460/460 [==============================] - 0s 759us/sample - loss: 0.2195 - accuracy: 0.9043 - val_loss: 0.2337 - val_accuracy: 0.9138
# Epoch 30/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.2247 - accuracy: 0.9114
# Epoch 00030: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 700us/sample - loss: 0.2257 - accuracy: 0.9087 - val_loss: 0.3146 - val_accuracy: 0.8448
# Epoch 31/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.2290 - accuracy: 0.9081
# Epoch 00031: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 682us/sample - loss: 0.2258 - accuracy: 0.9087 - val_loss: 0.2276 - val_accuracy: 0.8966
# Epoch 32/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.2383 - accuracy: 0.8956
# Epoch 00032: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 691us/sample - loss: 0.2344 - accuracy: 0.8978 - val_loss: 0.2312 - val_accuracy: 0.9052
# Epoch 33/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.2038 - accuracy: 0.9000
# Epoch 00033: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 692us/sample - loss: 0.2041 - accuracy: 0.9000 - val_loss: 0.2262 - val_accuracy: 0.9138
# Epoch 34/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.2405 - accuracy: 0.8892
# Epoch 00034: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 683us/sample - loss: 0.2392 - accuracy: 0.8891 - val_loss: 0.2568 - val_accuracy: 0.8966
# Epoch 35/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.2011 - accuracy: 0.9067
# Epoch 00035: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 707us/sample - loss: 0.2061 - accuracy: 0.9043 - val_loss: 0.3608 - val_accuracy: 0.8534
# Epoch 36/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0
250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.1117 - accuracy: 0.9591
# Epoch 00078: val_accuracy did not improve from 0.97414
# 460/460 [==============================] - 0s 702us/sample - loss: 0.1112 - accuracy: 0.9609 - val_loss: 0.1043 - val_accuracy: 0.9741
# Epoch 79/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.1236 - accuracy: 0.9578
# Epoch 00079: val_accuracy did not improve from 0.97414
# 460/460 [==============================] - 0s 692us/sample - loss: 0.1216 - accuracy: 0.9587 - val_loss: 0.1009 - val_accuracy: 0.9569
# Epoch 80/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.1285 - accuracy: 0.9486
# Epoch 00080: val_accuracy did not improve from 0.97414
# 460/460 [==============================] - 0s 688us/sample - loss: 0.1254 - accuracy: 0.9500 - val_loss: 0.1764 - val_accuracy: 0.8966
# Epoch 81/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.1472 - accuracy: 0.9444
# Epoch 00081: val_accuracy did not improve from 0.97414
# 460/460 [==============================] - 0s 683us/sample - loss: 0.1444 - accuracy: 0.9457 - val_loss: 0.1154 - val_accuracy: 0.9569
# Epoch 82/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.1244 - accuracy: 0.9667
# Epoch 00082: val_accuracy did not improve from 0.97414
# 460/460 [==============================] - 0s 693us/sample - loss: 0.1222 - accuracy: 0.9674 - val_loss: 0.1679 - val_accuracy: 0.9483
# Epoch 83/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0981 - accuracy: 0.9636
# Epoch 00083: val_accuracy did not improve from 0.97414
# 460/460 [==============================] - 0s 716us/sample - loss: 0.0973 - accuracy: 0.9630 - val_loss: 0.1734 - val_accuracy: 0.9310
# Epoch 84/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.1464 - accuracy: 0.9467
# Epoch 00084: val_accuracy did not improve from 0.97414
# 460/460 [==============================] - 0s 714us/sample - loss: 0.1459 - accuracy: 0.9457 - val_loss: 0.1506 - val_accuracy: 0.9224
# Epoch 85/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.1408 - accuracy: 0.9400
# Epoch 00085: val_accuracy did not improve from 0.97414
# 460/460 [==============================] - 0s 704us/sample - loss: 0.1392 - accuracy: 0.9413 - val_loss: 0.1081 - val_accuracy: 0.9655
# Epoch 86/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.1564 - accuracy: 0.9318
# Epoch 00086: val_accuracy did not improve from 0.97414
# 460/460 [==============================] - 0s 709us/sample - loss: 0.1512 - accuracy: 0.9348 - val_loss: 0.1153 - val_accuracy: 0.9569
# Epoch 87/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0958 - accuracy: 0.9571
# Epoch 00087: val_accuracy did not improve from 0.97414
# 460/460 [==============================] - 0s 711us/sample - loss: 0.1028 - accuracy: 0.9565 - val_loss: 0.1235 - val_accuracy: 0.9569
# Epoch 88/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.1240 - accuracy: 0.9568
# Epoch 00088: val_accuracy improved from 0.97414 to 0.98276, saving model to models/model2_88.h5
# 460/460 [==============================] - 0s 769us/sample - loss: 0.1377 - accuracy: 0.9522 - val_loss: 0.0931 - val_accuracy: 0.9828
# Epoch 89/250
# 450/460 [============================>.] - ETA: 0s - loss: 0
val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 712us/sample - loss: 0.0281 - accuracy: 0.9891 - val_loss: 0.0525 - val_accuracy: 0.9828
# Epoch 249/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0664 - accuracy: 0.9778
# Epoch 00249: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 707us/sample - loss: 0.0650 - accuracy: 0.9783 - val_loss: 0.0540 - val_accuracy: 0.9914
# Epoch 250/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0730 - accuracy: 0.9733
# Epoch 00250: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 697us/sample - loss: 0.0725 - accuracy: 0.9739 - val_loss: 0.0640 - val_accuracy: 0.9828
# Training completed in time:  0:01:22.895280

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste
#
# Lembrando que estamos utilizando o mesmo conjunto de validacão, que a princípio, pode incluir instâncias do conjunto de treinamento: o dataset utilizado foi gerado com corte de áudio, então alguns trechos do mesmo áudio podem estar presentes em ambos os conjuntos de treinamento e teste.
# Por ora deixamos assim já que estamos realizando uma investigacão inicial.

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.9956522
# Testing Accuracy:  0.98275864

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.97      1.00      0.98        56
#    Pneumonia       1.00      0.97      0.98        60
#
#     accuracy                           0.98       116
#    macro avg       0.98      0.98      0.98       116
# weighted avg       0.98      0.98      0.98       116

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[56  0]
#  [ 2 58]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])
