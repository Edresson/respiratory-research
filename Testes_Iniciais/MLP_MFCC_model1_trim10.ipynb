# %% [markdown]
# # Rede MLP - Modelo 1
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - trim10

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP = 'trim10'
MAX_PAD_LEN = 431

# %%
filepaths = glob.glob(f'./datasets/{GROUP}/**/*.wav', recursive=True)
filenames = [os.path.splitext(os.path.basename(p))[0] for p in filepaths]

# %%
p_id_in_file = [] # patient IDs corresponding to each file
for name in filenames:
    p_id_in_file.append(int(name[:3]))

p_id_in_file = np.array(p_id_in_file)

# %%
max_pad_len =  MAX_PAD_LEN

os.makedirs("./Respiratory_Sound_Database/features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=10) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./Respiratory_Sound_Database/features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
p_diag = pd.read_csv("./Respiratory_Sound_Database/Respiratory_Sound_Database/patient_diagnosis.csv",header=None) # patient diagnosis file

# %%
labels = np.array([p_diag[p_diag[0] == x][1].values[0] for x in p_id_in_file]) # labels for audio files

# %%
features = [] 

# Iterate through each sound file and extract the features
for file_name in filepaths:
    data = extract_features(file_name)
    features.append(data)

print('Finished feature extraction from ', len(features), ' files')
features = np.array(features)
# Out:
# Finished feature extraction from  72  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
features = np.array(features) # convert to numpy array

# %%
np.unique(labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
# delete diseases
'''
features1 = features
labels1 = labels'''

features1 = np.delete(features, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0) 

labels1 = np.delete(labels, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0)

# %%
# print class counts
unique_elements, counts_elements = np.unique(labels1, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['35' '37']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(labels1)
oh_labels = to_categorical(i_labels)

# %%
features1.shape
# Out:
# (72, 40, 431)

# %%
input_dim = features1.shape[1]*features1.shape[2]
features1 = np.reshape(features1, (features1.shape[0], input_dim))
print(features1.shape, labels1.shape)
# Out:
# (72, 17240) (72,)

# %%
# train test split
x_train, x_test, y_train, y_test = train_test_split(features1, oh_labels, stratify=oh_labels, 
                                                    test_size=0.2, random_state = 42)

# %% [markdown]
# **MLP model architecture**

# %%
num_labels = oh_labels.shape[1]
# Construct model 
model = Sequential()
model.add(Dense(500, input_dim=input_dim, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 500)               8620500
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_2 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_3 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_4 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_5 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_6 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_7 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 1002
# =================================================================
# Total params: 10,375,002
# Trainable params: 10,375,002
# Non-trainable params: 0
# _________________________________________________________________
# 15/15 [==============================] - 0s 18ms/sample - loss: 3.3914 - accuracy: 0.5333
# Pre-training accuracy: 53.3333%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 250
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/model2_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 57 samples, validate on 15 samples
# Epoch 1/250
# 10/57 [====>.........................] - ETA: 1s - loss: 2.6379 - accuracy: 0.6000
# Epoch 00001: val_accuracy improved from -inf to 0.46667, saving model to models/model2_01.h5
# 57/57 [==============================] - 1s 12ms/sample - loss: 76.2622 - accuracy: 0.5263 - val_loss: 3.8132 - val_accuracy: 0.4667
# Epoch 2/250
# 10/57 [====>.........................] - ETA: 0s - loss: 3.9753 - accuracy: 0.4000
# Epoch 00002: val_accuracy improved from 0.46667 to 0.53333, saving model to models/model2_02.h5
# 57/57 [==============================] - 1s 11ms/sample - loss: 29.4227 - accuracy: 0.5263 - val_loss: 10.3734 - val_accuracy: 0.5333
# Epoch 3/250
# 10/57 [====>.........................] - ETA: 0s - loss: 8.0948 - accuracy: 0.6000
# Epoch 00003: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 1ms/sample - loss: 19.7428 - accuracy: 0.4737 - val_loss: 14.4495 - val_accuracy: 0.5333
# Epoch 4/250
# 10/57 [====>.........................] - ETA: 0s - loss: 10.7629 - accuracy: 0.6000
# Epoch 00004: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 939us/sample - loss: 10.6416 - accuracy: 0.4035 - val_loss: 5.8705 - val_accuracy: 0.4667
# Epoch 5/250
# 10/57 [====>.........................] - ETA: 0s - loss: 7.2969 - accuracy: 0.3000
# Epoch 00005: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 950us/sample - loss: 3.1937 - accuracy: 0.5789 - val_loss: 2.0786 - val_accuracy: 0.5333
# Epoch 6/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.3100 - accuracy: 0.7000
# Epoch 00006: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 959us/sample - loss: 2.9951 - accuracy: 0.5263 - val_loss: 2.7057 - val_accuracy: 0.4667
# Epoch 7/250
# 10/57 [====>.........................] - ETA: 0s - loss: 3.3462 - accuracy: 0.3000
# Epoch 00007: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 945us/sample - loss: 2.5190 - accuracy: 0.4035 - val_loss: 0.7498 - val_accuracy: 0.5333
# Epoch 8/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.7509 - accuracy: 0.5000
# Epoch 00008: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 971us/sample - loss: 0.7550 - accuracy: 0.5965 - val_loss: 1.5609 - val_accuracy: 0.4667
# Epoch 9/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5209 - accuracy: 0.8000
# Epoch 00009: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 919us/sample - loss: 0.9316 - accuracy: 0.5614 - val_loss: 0.7797 - val_accuracy: 0.4667
# Epoch 10/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5787 - accuracy: 0.6000
# Epoch 00010: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.5014 - accuracy: 0.8070 - val_loss: 0.7175 - val_accuracy: 0.5333
# Epoch 11/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.7256 - accuracy: 0.4000
# Epoch 00011: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 928us/sample - loss: 0.4921 - accuracy: 0.7368 - val_loss: 1.0040 - val_accuracy: 0.5333
# Epoch 12/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.7766 - accuracy: 0.5000
# Epoch 00012: val_accuracy improved from 0.53333 to 0.80000, saving model to models/model2_12.h5
# 57/57 [==============================] - 1s 15ms/sample - loss: 0.5347 - accuracy: 0.6842 - val_loss: 0.5058 - val_accuracy: 0.8000
# Epoch 13/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2300 - accuracy: 0.9000
# Epoch 00013: val_accuracy improved from 0.80000 to 0.86667, saving model to models/model2_13.h5
# 57/57 [==============================] - 1s 15ms/sample - loss: 0.3601 - accuracy: 0.8246 - val_loss: 0.4850 - val_accuracy: 0.8667
# Epoch 14/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1582 - accuracy: 1.0000
# Epoch 00014: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1482 - accuracy: 0.9649 - val_loss: 1.1930 - val_accuracy: 0.6000
# Epoch 15/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2552 - accuracy: 0.9000
# Epoch 00015: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4173 - accuracy: 0.8596 - val_loss: 1.4323 - val_accuracy: 0.6000
# Epoch 16/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5638 - accuracy: 0.8000
# Epoch 00016: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 963us/sample - loss: 0.2133 - accuracy: 0.9123 - val_loss: 1.0012 - val_accuracy: 0.6000
# Epoch 17/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3618 - accuracy: 0.8000
# Epoch 00017: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1488 - accuracy: 0.9474 - val_loss: 0.4785 - val_accuracy: 0.8667
# Epoch 18/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0358 - accuracy: 1.0000
# Epoch 00018: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0548 - accuracy: 0.9825 - val_loss: 0.6389 - val_accuracy: 0.7333
# Epoch 19/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0552 - accuracy: 1.0000
# Epoch 00019: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0383 - accuracy: 0.9825 - val_loss: 4.1672 - val_accuracy: 0.6000
# Epoch 20/250
# 10/57 [====>.........................] - ETA: 0s - loss: 2.3983 - accuracy: 0.6000
# Epoch 00020: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 1.7108 - accuracy: 0.5263 - val_loss: 0.8710 - val_accuracy: 0.5333
# Epoch 21/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.6943 - accuracy: 0.4000
# Epoch 00021: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 938us/sample - loss: 0.4325 - accuracy: 0.7193 - val_loss: 1.0663 - val_accuracy: 0.5333
# Epoch 22/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0546 - accuracy: 1.0000
# Epoch 00022: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2785 - accuracy: 0.8947 - val_loss: 0.6920 - val_accuracy: 0.6000
# Epoch 23/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 00023: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0558 - accuracy: 0.9649 - val_loss: 0.9299 - val_accuracy: 0.8667
# Epoch 24/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0590 - accuracy: 1.0000
# Epoch 00024: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1566 - accuracy: 0.9649 - val_loss: 5.6002 - val_accuracy: 0.4667
# Epoch 25/250
# 10/57 [====>.........................] - ETA: 0s - loss: 3.4606 - accuracy: 0.6000
# Epoch 00025: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.9401 - accuracy: 0.7895 - val_loss: 0.5479 - val_accuracy: 0.8667
# Epoch 26/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0541 - accuracy: 1.0000
# Epoch 00026: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2980 - accuracy: 0.8596 - val_loss: 0.8216 - val_accuracy: 0.6000
# Epoch 27/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2175 - accuracy: 0.9000
# Epoch 00027: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0742 - accuracy: 0.9649 - val_loss: 0.6274 - val_accuracy: 0.8667
# Epoch 28/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 00028: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 9.5620e-04 - accuracy: 1.0000 - val_loss: 0.8679 - val_accuracy: 0.8667
# Epoch 29/250
# 10/57 [====>.........................] - ETA: 0s - loss: 3.4556e-05 - accuracy: 1.0000
# Epoch 00029: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 1.4231e-05 - accuracy: 1.0000 - val_loss: 1.5446 - val_accuracy: 0.6667
# Epoch 30/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.5947e-04 - accuracy: 1.0000
# Epoch 00030: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 3.9947e-05 - accuracy: 1.0000 - val_loss: 2.3856 - val_accuracy: 0.6667
# Epoch 31/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00031: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 2.9279e-08 - accuracy: 1.0000 - val_loss: 2.5606 - val_accuracy: 0.8000
# Epoch 32/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00032: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.6846 - val_accuracy: 0.8000
# Epoch 33/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00033: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.7817 - val_accuracy: 0.8667
# Epoch 34/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00034: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.8442 - val_accuracy: 0.8667
# Epoch 35/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00035: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.8807 - val_accuracy: 0.8667
# Epoch 36/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00036: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9009 - val_accuracy: 0.8667
# Epoch 37/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00037: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9119 - val_accuracy: 0.8667
# Epoch 38/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00038: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9180 - val_accuracy: 0.8667
# Epoch 39/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00039: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9212 - val_accuracy: 0.8667
# Epoch 40/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00040: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9230 - val_accuracy: 0.8667
# Epoch 41/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00041: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9240 - val_accuracy: 0.8667
# Epoch 42/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00042: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9245 - val_accuracy: 0.8667
# Epoch 43/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00043: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9248 - val_accuracy: 0.8667
# Epoch 44/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00044: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9249 - val_accuracy: 0.8667
# Epoch 45/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00045: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9250 - val_accuracy: 0.8667
# Epoch 46/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00046: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 47/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00047: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 961us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 48/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00048: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 49/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00049: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 50/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00050: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 51/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00051: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 52/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00052: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 53/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00053: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 54/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00054: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 55/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00055: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 56/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00056: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 57/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00057: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 986us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 58/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00058: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 59/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00059: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 60/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00060: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 61/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00061: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 62/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00062: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 63/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00063: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 64/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00064: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 65/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00065: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 66/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00066: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 67/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00067: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 68/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00068: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 69/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00069: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 70/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00070: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 71/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00071: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 72/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00072: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 73/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00073: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 74/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00074: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 75/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00075: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 76/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00076: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 977us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 77/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00077: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 78/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00078: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 79/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00079: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 80/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00080: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 81/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00081: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 82/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00082: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 83/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00083: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 84/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00084: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 85/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00085: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 86/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00086: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 87/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00087: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 88/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00088: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 89/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00089: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 90/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00090: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 91/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00091: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 92/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00092: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 93/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00093: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 94/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00094: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 95/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00095: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 96/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00096: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 97/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00097: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 98/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00098: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 99/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00099: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 100/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00100: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 101/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00101: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 102/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00102: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 103/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00103: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 104/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00104: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 105/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00105: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 106/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00106: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 107/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00107: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 108/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00108: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 109/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00109: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 110/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00110: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 111/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00111: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 112/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00112: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 113/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00113: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 114/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00114: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 115/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00115: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 116/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00116: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 117/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00117: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 118/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00118: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 119/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00119: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 120/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00120: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 121/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00121: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 122/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00122: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 123/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00123: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 124/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00124: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 125/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00125: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 126/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00126: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 127/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00127: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 128/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00128: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 995us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 129/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00129: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 130/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00130: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 131/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00131: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 132/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00132: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 133/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00133: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 986us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 134/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00134: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 135/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00135: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 136/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00136: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 137/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00137: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 138/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00138: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 139/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00139: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 140/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00140: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 141/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00141: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 142/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00142: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 143/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00143: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 144/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00144: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 145/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00145: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 146/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00146: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 147/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00147: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 148/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00148: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 149/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00149: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 995us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 150/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00150: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 151/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00151: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 152/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00152: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 153/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00153: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 982us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 154/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00154: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 155/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00155: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 156/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00156: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 157/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00157: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 158/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00158: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 159/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00159: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 160/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00160: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 161/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00161: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 162/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00162: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 163/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00163: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 164/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00164: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 165/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00165: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9251 - val_accuracy: 0.8667
# Epoch 166/250
# ...
# Epoch 00196: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 999us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 197/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00197: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 198/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00198: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 199/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00199: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 200/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00200: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 201/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00201: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 202/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00202: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 203/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00203: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 204/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00204: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 205/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00205: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 995us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 206/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00206: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 207/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00207: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 208/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00208: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 993us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 209/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00209: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 210/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00210: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 211/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00211: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 212/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00212: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 213/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00213: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 214/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00214: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 215/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00215: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 216/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00216: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 217/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00217: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 218/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00218: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 989us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 219/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00219: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 220/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00220: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 221/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00221: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 222/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00222: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 223/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00223: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 224/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00224: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 225/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00225: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 226/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00226: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 988us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 227/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00227: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 228/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00228: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 229/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00229: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 230/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00230: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 231/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00231: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 232/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00232: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 233/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00233: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 234/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00234: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 235/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00235: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 236/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00236: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 237/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00237: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 238/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00238: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 239/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00239: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 240/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00240: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 983us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 241/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00241: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 242/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00242: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 243/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00243: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 976us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 244/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00244: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 245/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00245: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 246/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00246: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 995us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 247/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00247: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 248/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00248: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 988us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 249/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00249: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Epoch 250/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00250: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 961us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 0.8667
# Training completed in time:  0:00:18.597232

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste
#
# Lembrando que estamos utilizando o mesmo conjunto de validacão, que a princípio, pode incluir instâncias do conjunto de treinamento: o dataset utilizado foi gerado com corte de áudio, então alguns trechos do mesmo áudio podem estar presentes em ambos os conjuntos de treinamento e teste.
# Por ora deixamos assim já que estamos realizando uma investigacão inicial.

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  1.0
# Testing Accuracy:  0.8666667

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.86      0.86      0.86         7
#    Pneumonia       0.88      0.88      0.88         8
#
#     accuracy                           0.87        15
#    macro avg       0.87      0.87      0.87        15
# weighted avg       0.87      0.87      0.87        15

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[6 1]
#  [1 7]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])
