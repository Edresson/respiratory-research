# %% [markdown]
# # Rede CNN - Modelo 1
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - slide10sr22050

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP = 'slide10sr22050'
MAX_PAD_LEN = 431

# %%
filepaths = glob.glob(f'./datasets/{GROUP}/**/*.wav', recursive=True)
filenames = [os.path.splitext(os.path.basename(p))[0] for p in filepaths]

# %%
p_id_in_file = [] # patient IDs corresponding to each file
for name in filenames:
    p_id_in_file.append(int(name[:3]))

p_id_in_file = np.array(p_id_in_file)

# %%
max_pad_len =  MAX_PAD_LEN

os.makedirs("./Respiratory_Sound_Database/features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=10) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./Respiratory_Sound_Database/features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
p_diag = pd.read_csv("./Respiratory_Sound_Database/Respiratory_Sound_Database/patient_diagnosis.csv",header=None) # patient diagnosis file

# %%
labels = np.array([p_diag[p_diag[0] == x][1].values[0] for x in p_id_in_file]) # labels for audio files

# %%
features = [] 

# Iterate through each sound file and extract the features
for file_name in filepaths:
    data = extract_features(file_name)
    features.append(data)

print('Finished feature extraction from ', len(features), ' files')
features = np.array(features)
# Out:
# Finished feature extraction from  576  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(features[1], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
features = np.array(features) # convert to numpy array

# %%
np.unique(labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
# delete diseases
'''
features1 = features
labels1 = labels'''

features1 = np.delete(features, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0) 

labels1 = np.delete(labels, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0)

# %%
# print class counts
unique_elements, counts_elements = np.unique(labels1, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['280' '296']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(labels1)
oh_labels = to_categorical(i_labels)

# %%
features1.shape
# Out:
# (576, 40, 431)

# %%
# add channel dimension for CNN
features1 = np.reshape(features1, (*features1.shape,1)) 

# train test split
x_train, x_test, y_train, y_test = train_test_split(features1, oh_labels, stratify=oh_labels, 
                                                    test_size=0.2, random_state = 42)

# %% [markdown]
# **MLP model architecture**

# %%
num_rows = 40
num_columns = 431
num_channels = 1

num_labels = oh_labels.shape[1]
filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 430, 16)       80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 215, 16)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 215, 16)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 214, 32)       2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 107, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 107, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 106, 64)        8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 53, 64)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 53, 64)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 52, 128)        32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 26, 128)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 26, 128)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 258
# =================================================================
# Total params: 43,570
# Trainable params: 43,570
# Non-trainable params: 0
# _________________________________________________________________
# 116/116 [==============================] - 1s 11ms/sample - loss: 8.9168 - accuracy: 0.5172
# Pre-training accuracy: 51.7241%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 250
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/model2_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 460 samples, validate on 116 samples
# Epoch 1/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.8505 - accuracy: 0.5581
# Epoch 00001: val_accuracy improved from -inf to 0.56034, saving model to models/model2_01.h5
# 460/460 [==============================] - 1s 3ms/sample - loss: 2.7270 - accuracy: 0.5609 - val_loss: 0.7017 - val_accuracy: 0.5603
# Epoch 2/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.7339 - accuracy: 0.6372
# Epoch 00002: val_accuracy did not improve from 0.56034
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.7187 - accuracy: 0.6435 - val_loss: 0.6095 - val_accuracy: 0.5603
# Epoch 3/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.6766 - accuracy: 0.6907
# Epoch 00003: val_accuracy improved from 0.56034 to 0.61207, saving model to models/model2_03.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.6604 - accuracy: 0.6978 - val_loss: 0.5704 - val_accuracy: 0.6121
# Epoch 4/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.4803 - accuracy: 0.7651
# Epoch 00004: val_accuracy did not improve from 0.61207
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.4840 - accuracy: 0.7652 - val_loss: 0.5475 - val_accuracy: 0.6121
# Epoch 5/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.4793 - accuracy: 0.7698
# Epoch 00005: val_accuracy improved from 0.61207 to 0.68103, saving model to models/model2_05.h5
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.4647 - accuracy: 0.7804 - val_loss: 0.5238 - val_accuracy: 0.6810
# Epoch 6/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.4130 - accuracy: 0.8140
# Epoch 00006: val_accuracy improved from 0.68103 to 0.75000, saving model to models/model2_06.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.4113 - accuracy: 0.8130 - val_loss: 0.4841 - val_accuracy: 0.7500
# Epoch 7/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.3625 - accuracy: 0.8256
# Epoch 00007: val_accuracy improved from 0.75000 to 0.80172, saving model to models/model2_07.h5
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.3606 - accuracy: 0.8261 - val_loss: 0.4407 - val_accuracy: 0.8017
# Epoch 8/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.2919 - accuracy: 0.8744
# Epoch 00008: val_accuracy improved from 0.80172 to 0.87931, saving model to models/model2_08.h5
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2875 - accuracy: 0.8761 - val_loss: 0.3334 - val_accuracy: 0.8793
# Epoch 9/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.3765 - accuracy: 0.8186
# Epoch 00009: val_accuracy did not improve from 0.87931
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.3665 - accuracy: 0.8239 - val_loss: 0.3441 - val_accuracy: 0.8621
# Epoch 10/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.2336 - accuracy: 0.9070
# Epoch 00010: val_accuracy improved from 0.87931 to 0.88793, saving model to models/model2_10.h5
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2314 - accuracy: 0.9087 - val_loss: 0.3188 - val_accuracy: 0.8879
# Epoch 11/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.2598 - accuracy: 0.8884
# Epoch 00011: val_accuracy improved from 0.88793 to 0.90517, saving model to models/model2_11.h5
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2574 - accuracy: 0.8891 - val_loss: 0.2999 - val_accuracy: 0.9052
# Epoch 12/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.2689 - accuracy: 0.8791
# Epoch 00012: val_accuracy improved from 0.90517 to 0.91379, saving model to models/model2_12.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2779 - accuracy: 0.8739 - val_loss: 0.2899 - val_accuracy: 0.9138
# Epoch 13/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.2553 - accuracy: 0.8930
# Epoch 00013: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2678 - accuracy: 0.8891 - val_loss: 0.2807 - val_accuracy: 0.9052
# Epoch 14/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.3005 - accuracy: 0.8442
# Epoch 00014: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2910 - accuracy: 0.8522 - val_loss: 0.2869 - val_accuracy: 0.8966
# Epoch 15/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.2447 - accuracy: 0.8953
# Epoch 00015: val_accuracy improved from 0.91379 to 0.93103, saving model to models/model2_15.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2385 - accuracy: 0.8978 - val_loss: 0.2732 - val_accuracy: 0.9310
# Epoch 16/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.2748 - accuracy: 0.8744
# Epoch 00016: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2697 - accuracy: 0.8783 - val_loss: 0.2598 - val_accuracy: 0.9138
# Epoch 17/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.2136 - accuracy: 0.9279
# Epoch 00017: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2176 - accuracy: 0.9217 - val_loss: 0.2688 - val_accuracy: 0.9138
# Epoch 18/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1797 - accuracy: 0.9163
# Epoch 00018: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1737 - accuracy: 0.9217 - val_loss: 0.2193 - val_accuracy: 0.9310
# Epoch 19/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1883 - accuracy: 0.9233
# Epoch 00019: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1890 - accuracy: 0.9217 - val_loss: 0.2119 - val_accuracy: 0.9310
# Epoch 20/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1716 - accuracy: 0.9279
# Epoch 00020: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1748 - accuracy: 0.9261 - val_loss: 0.2914 - val_accuracy: 0.8793
# Epoch 21/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1638 - accuracy: 0.9302
# Epoch 00021: val_accuracy improved from 0.93103 to 0.93966, saving model to models/model2_21.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1626 - accuracy: 0.9326 - val_loss: 0.1792 - val_accuracy: 0.9397
# Epoch 22/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1707 - accuracy: 0.9349
# Epoch 00022: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1699 - accuracy: 0.9326 - val_loss: 0.1723 - val_accuracy: 0.9397
# Epoch 23/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1855 - accuracy: 0.9116
# Epoch 00023: val_accuracy improved from 0.93966 to 0.96552, saving model to models/model2_23.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1902 - accuracy: 0.9109 - val_loss: 0.1604 - val_accuracy: 0.9655
# Epoch 24/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1652 - accuracy: 0.9395
# Epoch 00024: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1646 - accuracy: 0.9391 - val_loss: 0.2362 - val_accuracy: 0.9224
# Epoch 25/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1340 - accuracy: 0.9512
# Epoch 00025: val_accuracy improved from 0.96552 to 0.97414, saving model to models/model2_25.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1465 - accuracy: 0.9435 - val_loss: 0.1349 - val_accuracy: 0.9741
# Epoch 26/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1409 - accuracy: 0.9419
# Epoch 00026: val_accuracy did not improve from 0.97414
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1447 - accuracy: 0.9391 - val_loss: 0.1343 - val_accuracy: 0.9655
# Epoch 27/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1750 - accuracy: 0.9116
# Epoch 00027: val_accuracy did not improve from 0.97414
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1713 - accuracy: 0.9152 - val_loss: 0.1390 - val_accuracy: 0.9655
# Epoch 28/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1210 - accuracy: 0.9535
# Epoch 00028: val_accuracy did not improve from 0.97414
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1234 - accuracy: 0.9522 - val_loss: 0.1045 - val_accuracy: 0.9741
# Epoch 29/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1097 - accuracy: 0.9512
# Epoch 00029: val_accuracy improved from 0.97414 to 0.99138, saving model to models/model2_29.h5
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1097 - accuracy: 0.9500 - val_loss: 0.0873 - val_accuracy: 0.9914
# Epoch 30/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1099 - accuracy: 0.9581
# Epoch 00030: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1186 - accuracy: 0.9543 - val_loss: 0.0855 - val_accuracy: 0.9914
# Epoch 31/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1017 - accuracy: 0.9558
# Epoch 00031: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1083 - accuracy: 0.9522 - val_loss: 0.0864 - val_accuracy: 0.9914
# Epoch 32/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1693 - accuracy: 0.9163
# Epoch 00032: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1620 - accuracy: 0.9196 - val_loss: 0.0996 - val_accuracy: 0.9655
# Epoch 33/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1055 - accuracy: 0.9628
# Epoch 00033: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1105 - accuracy: 0.9565 - val_loss: 0.0812 - val_accuracy: 0.9828
# Epoch 34/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1138 - accuracy: 0.9535
# Epoch 00034: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1161 - accuracy: 0.9500 - val_loss: 0.1062 - val_accuracy: 0.9483
# Epoch 35/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0874 - accuracy: 0.9698
# Epoch 00035: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0850 - accuracy: 0.9717 - val_loss: 0.0843 - val_accuracy: 0.9741
# Epoch 36/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0958 - accuracy: 0.9535
# Epoch 00036: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0916 - accuracy: 0.9565 - val_loss: 0.0977 - val_accuracy: 0.9655
# Epoch 37/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1373 - accuracy: 0.9349
# Epoch 00037: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1352 - accuracy: 0.9370 - val_loss: 0.1708 - val_accuracy: 0.9310
# Epoch 38/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0889 - accuracy: 0.9628
# Epoch 00038: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0935 - accuracy: 0.9609 - val_loss: 0.0975 - val_accuracy: 0.9483
# Epoch 39/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1310 - accuracy: 0.9395
# Epoch 00039: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1284 - accuracy: 0.9413 - val_loss: 0.0613 - val_accuracy: 0.9828
# Epoch 40/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0906 - accuracy: 0.9698
# Epoch 00040: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0874 - accuracy: 0.9717 - val_loss: 0.0860 - val_accuracy: 0.9655
# Epoch 41/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0559 - accuracy: 0.9850
# Epoch 00041: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0670 - accuracy: 0.9804 - val_loss: 0.0431 - val_accuracy: 0.9914
# Epoch 42/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0571 - accuracy: 0.9786
# Epoch 00042: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0762 - accuracy: 0.9717 - val_loss: 0.0614 - val_accuracy: 0.9828
# Epoch 43/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0749 - accuracy: 0.9744
# Epoch 00043: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0728 - accuracy: 0.9761 - val_loss: 0.0696 - val_accuracy: 0.9569
# Epoch 44/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0519 - accuracy: 0.9837
# Epoch 00044: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0504 - accuracy: 0.9848 - val_loss: 0.0422 - val_accuracy: 0.9914
# Epoch 45/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0578 - accuracy: 0.9767
# Epoch 00045: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0569 - accuracy: 0.9783 - val_loss: 0.0278 - val_accuracy: 0.9914
# Epoch 46/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0544 - accuracy: 0.9860
# Epoch 00046: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0512 - accuracy: 0.9870 - val_loss: 0.0454 - val_accuracy: 0.9914
# Epoch 47/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0890 - accuracy: 0.9721
# Epoch 00047: val_accuracy improved from 0.99138 to 1.00000, saving model to models/model2_47.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0913 - accuracy: 0.9696 - val_loss: 0.0204 - val_accuracy: 1.0000
# Epoch 48/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0330 - accuracy: 0.9953
# Epoch 00048: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0322 - accuracy: 0.9957 - val_loss: 0.0195 - val_accuracy: 1.0000
# Epoch 49/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0548 - accuracy: 0.9767
# Epoch 00049: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0521 - accuracy: 0.9783 - val_loss: 0.0262 - val_accuracy: 1.0000
# Epoch 50/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0473 - accuracy: 0.9814
# Epoch 00050: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0454 - accuracy: 0.9826 - val_loss: 0.0282 - val_accuracy: 1.0000
# Epoch 51/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0382 - accuracy: 0.9884
# Epoch 00051: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0414 - accuracy: 0.9870 - val_loss: 0.0298 - val_accuracy: 1.0000
# Epoch 52/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0348 - accuracy: 0.9907
# Epoch 00052: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0330 - accuracy: 0.9913 - val_loss: 0.0162 - val_accuracy: 1.0000
# Epoch 53/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0295 - accuracy: 0.9907
# Epoch 00053: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0292 - accuracy: 0.9913 - val_loss: 0.0208 - val_accuracy: 1.0000
# Epoch 54/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0245 - accuracy: 0.9884
# Epoch 00054: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0233 - accuracy: 0.9891 - val_loss: 0.1645 - val_accuracy: 0.9397
# Epoch 55/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1705 - accuracy: 0.9419
# Epoch 00055: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1609 - accuracy: 0.9457 - val_loss: 0.0571 - val_accuracy: 0.9914
# Epoch 56/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0661 - accuracy: 0.9767
# Epoch 00056: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0679 - accuracy: 0.9761 - val_loss: 0.0440 - val_accuracy: 0.9914
# Epoch 57/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0242 - accuracy: 0.9977
# Epoch 00057: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0232 - accuracy: 0.9978 - val_loss: 0.0213 - val_accuracy: 1.0000
# Epoch 58/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0541 - accuracy: 0.9791
# Epoch 00058: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0589 - accuracy: 0.9761 - val_loss: 0.0156 - val_accuracy: 1.0000
# Epoch 59/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0406 - accuracy: 0.9810
# Epoch 00059: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0439 - accuracy: 0.9804 - val_loss: 0.0293 - val_accuracy: 0.9914
# Epoch 60/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0237 - accuracy: 0.9953
# Epoch 00060: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0243 - accuracy: 0.9935 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 61/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0204 - accuracy: 0.9953
# Epoch 00061: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0207 - accuracy: 0.9957 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 62/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0293 - accuracy: 0.9930
# Epoch 00062: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0279 - accuracy: 0.9935 - val_loss: 0.0631 - val_accuracy: 0.9828
# Epoch 63/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0403 - accuracy: 0.9884
# Epoch 00063: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0387 - accuracy: 0.9891 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 64/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0538 - accuracy: 0.9744
# Epoch 00064: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0582 - accuracy: 0.9739 - val_loss: 0.0135 - val_accuracy: 1.0000
# Epoch 65/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1165 - accuracy: 0.9651
# Epoch 00065: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.1124 - accuracy: 0.9674 - val_loss: 0.0666 - val_accuracy: 0.9828
# Epoch 66/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0574 - accuracy: 0.9767
# Epoch 00066: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0561 - accuracy: 0.9783 - val_loss: 0.0194 - val_accuracy: 0.9914
# Epoch 67/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0473 - accuracy: 0.9767
# Epoch 00067: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0527 - accuracy: 0.9761 - val_loss: 0.0137 - val_accuracy: 1.0000
# Epoch 68/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0352 - accuracy: 0.9902
# Epoch 00068: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0335 - accuracy: 0.9913 - val_loss: 0.0108 - val_accuracy: 1.0000
# Epoch 69/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0203 - accuracy: 0.9907
# Epoch 00069: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0196 - accuracy: 0.9913 - val_loss: 0.0182 - val_accuracy: 1.0000
# Epoch 70/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0561 - accuracy: 0.9791
# Epoch 00070: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0526 - accuracy: 0.9804 - val_loss: 0.0151 - val_accuracy: 1.0000
# Epoch 71/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0211 - accuracy: 0.9953
# Epoch 00071: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 999us/sample - loss: 0.0205 - accuracy: 0.9957 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 72/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0276 - accuracy: 0.9907
# Epoch 00072: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 997us/sample - loss: 0.0311 - accuracy: 0.9891 - val_loss: 0.0243 - val_accuracy: 0.9914
# Epoch 73/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0472 - accuracy: 0.9860
# Epoch 00073: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 979us/sample - loss: 0.0446 - accuracy: 0.9870 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 74/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0281 - accuracy: 0.9925
# Epoch 00074: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0274 - accuracy: 0.9913 - val_loss: 0.3058 - val_accuracy: 0.9569
# Epoch 75/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0583 - accuracy: 0.9767
# Epoch 00075: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0550 - accuracy: 0.9783 - val_loss: 0.0354 - val_accuracy: 0.9914
# Epoch 76/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0456 - accuracy: 0.9732
# Epoch 00076: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0423 - accuracy: 0.9761 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 77/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0171 - accuracy: 0.9976
# Epoch 00077: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0177 - accuracy: 0.9978 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 78/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0241 - accuracy: 0.9905
# Epoch 00078: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0283 - accuracy: 0.9870 - val_loss: 0.0684 - val_accuracy: 0.9655
# Epoch 79/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.1063 - accuracy: 0.9750
# Epoch 00079: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1024 - accuracy: 0.9761 - val_loss: 0.0185 - val_accuracy: 0.9914
# Epoch 80/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0266 - accuracy: 0.9952
# Epoch 00080: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0314 - accuracy: 0.9935 - val_loss: 0.0371 - val_accuracy: 0.9914
# Epoch 81/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0187 - accuracy: 0.9929
# Epoch 00081: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0208 - accuracy: 0.9935 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 82/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0133 - accuracy: 0.9952
# Epoch 00082: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0127 - accuracy: 0.9957 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 83/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0129 - accuracy: 0.9951
# Epoch 00083: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0220 - accuracy: 0.9913 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 84/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0341 - accuracy: 0.9911
# Epoch 00084: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0340 - accuracy: 0.9913 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 85/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0213 - accuracy: 0.9950
# Epoch 00085: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0190 - accuracy: 0.9957 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 86/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0249 - accuracy: 0.9953
# Epoch 00086: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0238 - accuracy: 0.9957 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 87/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0098 - accuracy: 0.9951
# Epoch 00087: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0109 - accuracy: 0.9957 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 88/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0081 - accuracy: 0.9976
# Epoch 00088: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0087 - accuracy: 0.9978 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 89/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0356 - accuracy: 0.9905
# Epoch 00089: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0329 - accuracy: 0.9913 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 90/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0077 - accuracy: 1.0000
# Epoch 00090: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 91/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 00091: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 92/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0058 - accuracy: 0.9952
# Epoch 00092: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0055 - accuracy: 0.9957 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 93/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 00093: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 94/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0229 - accuracy: 0.9905
# Epoch 00094: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0214 - accuracy: 0.9913 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 95/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0078 - accuracy: 1.0000
# Epoch 00095: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 96/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0079 - accuracy: 0.9977
# Epoch 00096: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0080 - accuracy: 0.9978 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 97/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0842 - accuracy: 0.9683
# Epoch 00097: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1225 - accuracy: 0.9587 - val_loss: 0.0784 - val_accuracy: 0.9741
# Epoch 98/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1665 - accuracy: 0.9390
# Epoch 00098: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1566 - accuracy: 0.9435 - val_loss: 0.0270 - val_accuracy: 1.0000
# Epoch 99/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0128 - accuracy: 0.9977
# Epoch 00099: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0123 - accuracy: 0.9978 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 100/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0120 - accuracy: 0.9951
# Epoch 00100: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0156 - accuracy: 0.9935 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 101/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0063 - accuracy: 1.0000
# Epoch 00101: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 102/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0148 - accuracy: 0.9976
# Epoch 00102: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0156 - accuracy: 0.9978 - val_loss: 0.0874 - val_accuracy: 0.9741
# Epoch 103/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0195 - accuracy: 0.9929
# Epoch 00103: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0234 - accuracy: 0.9913 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 104/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0097 - accuracy: 0.9977
# Epoch 00104: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0093 - accuracy: 0.9978 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 105/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0087 - accuracy: 0.9976
# Epoch 00105: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0080 - accuracy: 0.9978 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 106/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0311 - accuracy: 0.9860
# Epoch 00106: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0298 - accuracy: 0.9870 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 107/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0134 - accuracy: 0.9952
# Epoch 00107: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0126 - accuracy: 0.9957 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 108/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0115 - accuracy: 0.9952
# Epoch 00108: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0109 - accuracy: 0.9957 - val_loss: 0.0130 - val_accuracy: 1.0000
# Epoch 109/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0121 - accuracy: 0.9977
# Epoch 00109: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0116 - accuracy: 0.9978 - val_loss: 0.0111 - val_accuracy: 0.9914
# Epoch 110/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0061 - accuracy: 1.0000
# Epoch 00110: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 111/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0071 - accuracy: 0.9976
# Epoch 00111: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0066 - accuracy: 0.9978 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 112/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0107 - accuracy: 0.9950
# Epoch 00112: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0128 - accuracy: 0.9935 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 113/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0185 - accuracy: 0.9907
# Epoch 00113: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0194 - accuracy: 0.9913 - val_loss: 0.0101 - val_accuracy: 1.0000
# Epoch 114/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0322 - accuracy: 0.9902
# Epoch 00114: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0298 - accuracy: 0.9913 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 115/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0326 - accuracy: 0.9857
# Epoch 00115: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0334 - accuracy: 0.9848 - val_loss: 0.0101 - val_accuracy: 1.0000
# Epoch 116/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0108 - accuracy: 0.9952
# Epoch 00116: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0102 - accuracy: 0.9957 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 117/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 00117: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 118/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0065 - accuracy: 0.9976
# Epoch 00118: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0065 - accuracy: 0.9978 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 119/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 00119: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 120/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0036 - accuracy: 0.9977
# Epoch 00120: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0038 - accuracy: 0.9978 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 121/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00121: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 122/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0113 - accuracy: 0.9951
# Epoch 00122: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0101 - accuracy: 0.9957 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 123/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 00123: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 124/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0080 - accuracy: 0.9976
# Epoch 00124: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0073 - accuracy: 0.9978 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 125/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00125: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 126/250
# 400/460 [=========================>....] - ETA: 0s - loss: 5.9284e-04 - accuracy: 1.0000
# Epoch 00126: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 6.9034e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 127/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00127: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 128/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0069 - accuracy: 0.9976
# Epoch 00128: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0064 - accuracy: 0.9978 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 129/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1601 - accuracy: 0.9667
# Epoch 00129: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2564 - accuracy: 0.9652 - val_loss: 0.0310 - val_accuracy: 0.9914
# Epoch 130/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0749 - accuracy: 0.9721
# Epoch 00130: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0739 - accuracy: 0.9717 - val_loss: 0.0259 - val_accuracy: 1.0000
# Epoch 131/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0165 - accuracy: 0.9976
# Epoch 00131: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0153 - accuracy: 0.9978 - val_loss: 0.0131 - val_accuracy: 1.0000
# Epoch 132/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0492 - accuracy: 0.9837
# Epoch 00132: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0478 - accuracy: 0.9848 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 133/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0333 - accuracy: 0.9860
# Epoch 00133: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0313 - accuracy: 0.9870 - val_loss: 0.0141 - val_accuracy: 0.9914
# Epoch 134/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0260 - accuracy: 0.9927
# Epoch 00134: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0236 - accuracy: 0.9935 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 135/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 00135: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 136/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0092 - accuracy: 1.0000
# Epoch 00136: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 137/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0121 - accuracy: 0.9977
# Epoch 00137: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0118 - accuracy: 0.9978 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 138/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0092 - accuracy: 0.9976
# Epoch 00138: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0087 - accuracy: 0.9978 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 139/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 00139: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 140/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00140: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 141/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00141: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 142/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00142: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 143/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00143: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 144/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000
# Epoch 00144: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 145/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0223 - accuracy: 0.9881
# Epoch 00145: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0204 - accuracy: 0.9891 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 146/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0108 - accuracy: 0.9953
# Epoch 00146: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0102 - accuracy: 0.9957 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 147/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 00147: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 148/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0047 - accuracy: 0.9976
# Epoch 00148: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0044 - accuracy: 0.9978 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 149/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0249 - accuracy: 0.9907
# Epoch 00149: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0235 - accuracy: 0.9913 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 150/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0069 - accuracy: 0.9976
# Epoch 00150: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0065 - accuracy: 0.9978 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 151/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0137 - accuracy: 0.9951
# Epoch 00151: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0123 - accuracy: 0.9957 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 152/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 00152: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 153/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 00153: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 154/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1038 - accuracy: 0.9744
# Epoch 00154: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0997 - accuracy: 0.9739 - val_loss: 0.5317 - val_accuracy: 0.8534
# Epoch 155/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.1999 - accuracy: 0.9400
# Epoch 00155: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1765 - accuracy: 0.9478 - val_loss: 0.0236 - val_accuracy: 1.0000
# Epoch 156/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0166 - accuracy: 0.9952
# Epoch 00156: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0207 - accuracy: 0.9913 - val_loss: 0.0400 - val_accuracy: 0.9914
# Epoch 157/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0193 - accuracy: 0.9976
# Epoch 00157: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0319 - accuracy: 0.9935 - val_loss: 0.0141 - val_accuracy: 1.0000
# Epoch 158/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0120 - accuracy: 0.9976
# Epoch 00158: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0113 - accuracy: 0.9978 - val_loss: 0.0105 - val_accuracy: 1.0000
# Epoch 159/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 00159: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 160/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0091 - accuracy: 0.9977
# Epoch 00160: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0085 - accuracy: 0.9978 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 161/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 00161: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 162/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00162: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 163/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 00163: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 164/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 00164: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 165/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 00165: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 166/250
# ...
# Epoch 197/250
# 410/460 [=========================>....] - ETA: 0s - loss: 2.0258e-04 - accuracy: 1.0000
# Epoch 00197: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 2.3946e-04 - accuracy: 1.0000 - val_loss: 5.2948e-04 - val_accuracy: 1.0000
# Epoch 198/250
# 420/460 [==========================>...] - ETA: 0s - loss: 4.2386e-04 - accuracy: 1.0000
# Epoch 00198: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 8.0516e-04 - accuracy: 1.0000 - val_loss: 6.4018e-04 - val_accuracy: 1.0000
# Epoch 199/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 00199: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0021 - accuracy: 1.0000 - val_loss: 3.0080e-04 - val_accuracy: 1.0000
# Epoch 200/250
# 420/460 [==========================>...] - ETA: 0s - loss: 4.6923e-04 - accuracy: 1.0000
# Epoch 00200: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 5.1232e-04 - accuracy: 1.0000 - val_loss: 4.6413e-04 - val_accuracy: 1.0000
# Epoch 201/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.1841e-04 - accuracy: 1.0000
# Epoch 00201: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 2.0488e-04 - accuracy: 1.0000 - val_loss: 2.7520e-04 - val_accuracy: 1.0000
# Epoch 202/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 00202: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0032 - accuracy: 1.0000 - val_loss: 5.0497e-04 - val_accuracy: 1.0000
# Epoch 203/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 00203: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0026 - accuracy: 1.0000 - val_loss: 3.2648e-04 - val_accuracy: 1.0000
# Epoch 204/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 00204: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 9.5560e-04 - accuracy: 1.0000 - val_loss: 3.0362e-04 - val_accuracy: 1.0000
# Epoch 205/250
# 430/460 [===========================>..] - ETA: 0s - loss: 4.4085e-04 - accuracy: 1.0000
# Epoch 00205: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 4.4160e-04 - accuracy: 1.0000 - val_loss: 6.1048e-04 - val_accuracy: 1.0000
# Epoch 206/250
# 410/460 [=========================>....] - ETA: 0s - loss: 3.1878e-04 - accuracy: 1.0000
# Epoch 00206: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 3.3819e-04 - accuracy: 1.0000 - val_loss: 6.8782e-04 - val_accuracy: 1.0000
# Epoch 207/250
# 430/460 [===========================>..] - ETA: 0s - loss: 3.2254e-04 - accuracy: 1.0000
# Epoch 00207: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 3.7341e-04 - accuracy: 1.0000 - val_loss: 3.7411e-04 - val_accuracy: 1.0000
# Epoch 208/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.2157e-04 - accuracy: 1.0000
# Epoch 00208: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 1.1460e-04 - accuracy: 1.0000 - val_loss: 3.0246e-04 - val_accuracy: 1.0000
# Epoch 209/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 00209: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 210/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0417 - accuracy: 0.9905
# Epoch 00210: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0382 - accuracy: 0.9913 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 211/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0064 - accuracy: 0.9976
# Epoch 00211: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0059 - accuracy: 0.9978 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 212/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00212: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 213/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00213: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 9.4679e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 214/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0086 - accuracy: 0.9951
# Epoch 00214: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0078 - accuracy: 0.9957 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 215/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0027 - accuracy: 1.0000
# Epoch 00215: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 216/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 00216: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 217/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 00217: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0026 - accuracy: 1.0000 - val_loss: 7.0778e-04 - val_accuracy: 1.0000
# Epoch 218/250
# 410/460 [=========================>....] - ETA: 0s - loss: 2.1544e-04 - accuracy: 1.0000
# Epoch 00218: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 2.3957e-04 - accuracy: 1.0000 - val_loss: 4.3929e-04 - val_accuracy: 1.0000
# Epoch 219/250
# 420/460 [==========================>...] - ETA: 0s - loss: 1.0923e-04 - accuracy: 1.0000
# Epoch 00219: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 1.0218e-04 - accuracy: 1.0000 - val_loss: 3.9947e-04 - val_accuracy: 1.0000
# Epoch 220/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.3525e-04 - accuracy: 1.0000
# Epoch 00220: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 1.4548e-04 - accuracy: 1.0000 - val_loss: 3.4997e-04 - val_accuracy: 1.0000
# Epoch 221/250
# 420/460 [==========================>...] - ETA: 0s - loss: 5.0129e-04 - accuracy: 1.0000
# Epoch 00221: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 5.3148e-04 - accuracy: 1.0000 - val_loss: 7.2342e-04 - val_accuracy: 1.0000
# Epoch 222/250
# 420/460 [==========================>...] - ETA: 0s - loss: 7.7396e-04 - accuracy: 1.0000
# Epoch 00222: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 7.0711e-04 - accuracy: 1.0000 - val_loss: 3.3534e-04 - val_accuracy: 1.0000
# Epoch 223/250
# 430/460 [===========================>..] - ETA: 0s - loss: 3.5612e-04 - accuracy: 1.0000
# Epoch 00223: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 3.3472e-04 - accuracy: 1.0000 - val_loss: 2.9555e-04 - val_accuracy: 1.0000
# Epoch 224/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.0975e-04 - accuracy: 1.0000
# Epoch 00224: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 1.0547e-04 - accuracy: 1.0000 - val_loss: 3.0801e-04 - val_accuracy: 1.0000
# Epoch 225/250
# 420/460 [==========================>...] - ETA: 0s - loss: 9.0930e-04 - accuracy: 1.0000
# Epoch 00225: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 8.3082e-04 - accuracy: 1.0000 - val_loss: 3.7837e-04 - val_accuracy: 1.0000
# Epoch 226/250
# 420/460 [==========================>...] - ETA: 0s - loss: 1.5926e-04 - accuracy: 1.0000
# Epoch 00226: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 4.2580e-04 - accuracy: 1.0000 - val_loss: 2.8690e-04 - val_accuracy: 1.0000
# Epoch 227/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.2803e-04 - accuracy: 1.0000
# Epoch 00227: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 2.2313e-04 - accuracy: 1.0000 - val_loss: 5.1223e-04 - val_accuracy: 1.0000
# Epoch 228/250
# 450/460 [============================>.] - ETA: 0s - loss: 1.4755e-04 - accuracy: 1.0000
# Epoch 00228: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 1.4434e-04 - accuracy: 1.0000 - val_loss: 4.7536e-04 - val_accuracy: 1.0000
# Epoch 229/250
# 400/460 [=========================>....] - ETA: 0s - loss: 2.8345e-04 - accuracy: 1.0000
# Epoch 00229: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 2.4712e-04 - accuracy: 1.0000 - val_loss: 4.3003e-04 - val_accuracy: 1.0000
# Epoch 230/250
# 420/460 [==========================>...] - ETA: 0s - loss: 8.0455e-05 - accuracy: 1.0000
# Epoch 00230: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 9.2507e-05 - accuracy: 1.0000 - val_loss: 2.8106e-04 - val_accuracy: 1.0000
# Epoch 231/250
# 420/460 [==========================>...] - ETA: 0s - loss: 1.1207e-04 - accuracy: 1.0000
# Epoch 00231: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 1.5782e-04 - accuracy: 1.0000 - val_loss: 2.7879e-04 - val_accuracy: 1.0000
# Epoch 232/250
# 420/460 [==========================>...] - ETA: 0s - loss: 7.5658e-05 - accuracy: 1.0000
# Epoch 00232: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 6.9917e-05 - accuracy: 1.0000 - val_loss: 2.4853e-04 - val_accuracy: 1.0000
# Epoch 233/250
# 410/460 [=========================>....] - ETA: 0s - loss: 6.3767e-05 - accuracy: 1.0000
# Epoch 00233: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 5.7895e-05 - accuracy: 1.0000 - val_loss: 2.5586e-04 - val_accuracy: 1.0000
# Epoch 234/250
# 420/460 [==========================>...] - ETA: 0s - loss: 8.2434e-05 - accuracy: 1.0000
# Epoch 00234: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 8.0153e-05 - accuracy: 1.0000 - val_loss: 2.7943e-04 - val_accuracy: 1.0000
# Epoch 235/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.4341e-04 - accuracy: 1.0000
# Epoch 00235: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 1.4999e-04 - accuracy: 1.0000 - val_loss: 1.8267e-04 - val_accuracy: 1.0000
# Epoch 236/250
# 410/460 [=========================>....] - ETA: 0s - loss: 1.4343e-04 - accuracy: 1.0000
# Epoch 00236: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 1.2900e-04 - accuracy: 1.0000 - val_loss: 2.6022e-04 - val_accuracy: 1.0000
# Epoch 237/250
# 420/460 [==========================>...] - ETA: 0s - loss: 7.7172e-05 - accuracy: 1.0000
# Epoch 00237: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 7.0626e-05 - accuracy: 1.0000 - val_loss: 2.2130e-04 - val_accuracy: 1.0000
# Epoch 238/250
# 420/460 [==========================>...] - ETA: 0s - loss: 2.8513e-04 - accuracy: 1.0000
# Epoch 00238: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 2.7213e-04 - accuracy: 1.0000 - val_loss: 2.3478e-04 - val_accuracy: 1.0000
# Epoch 239/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0349 - accuracy: 0.9884
# Epoch 00239: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0355 - accuracy: 0.9870 - val_loss: 0.1303 - val_accuracy: 0.9655
# Epoch 240/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2271 - accuracy: 0.9548
# Epoch 00240: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2100 - accuracy: 0.9587 - val_loss: 0.0332 - val_accuracy: 1.0000
# Epoch 241/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0123 - accuracy: 0.9977
# Epoch 00241: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0127 - accuracy: 0.9978 - val_loss: 0.0128 - val_accuracy: 1.0000
# Epoch 242/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 00242: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 243/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0099 - accuracy: 0.9952
# Epoch 00243: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0100 - accuracy: 0.9957 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 244/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0056 - accuracy: 0.9977
# Epoch 00244: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0053 - accuracy: 0.9978 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 245/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00245: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 246/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0035 - accuracy: 0.9976
# Epoch 00246: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0046 - accuracy: 0.9978 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 247/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0100 - accuracy: 0.9953
# Epoch 00247: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0093 - accuracy: 0.9957 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 248/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 00248: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 249/250
# 430/460 [===========================>..] - ETA: 0s - loss: 7.6097e-04 - accuracy: 1.0000
# Epoch 00249: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 7.4296e-04 - accuracy: 1.0000 - val_loss: 8.7596e-04 - val_accuracy: 1.0000
# Epoch 250/250
# 430/460 [===========================>..] - ETA: 0s - loss: 7.3848e-04 - accuracy: 1.0000
# Epoch 00250: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 0s 1ms/sample - loss: 7.0252e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Training completed in time:  0:02:02.859832

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste
#
# Lembrando que estamos utilizando o mesmo conjunto de validacão, que a princípio, pode incluir instâncias do conjunto de treinamento: o dataset utilizado foi gerado com corte de áudio, então alguns trechos do mesmo áudio podem estar presentes em ambos os conjuntos de treinamento e teste.
# Por ora deixamos assim já que estamos realizando uma investigacão inicial.

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  1.0
# Testing Accuracy:  1.0

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       1.00      1.00      1.00        56
#    Pneumonia       1.00      1.00      1.00        60
#
#     accuracy                           1.00       116
#    macro avg       1.00      1.00      1.00       116
# weighted avg       1.00      1.00      1.00       116

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[56  0]
#  [ 0 60]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])
