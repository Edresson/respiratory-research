# %% [markdown]
# # Rede CNN - Modelo 2
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - trim5

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP = 'trim5'
MAX_PAD_LEN = 216

# %%
filepaths = glob.glob(f'./datasets/{GROUP}/**/*.wav', recursive=True)
filenames = [os.path.splitext(os.path.basename(p))[0] for p in filepaths]

# %%
p_id_in_file = [] # patient IDs corresponding to each file
for name in filenames:
    p_id_in_file.append(int(name[:3]))

p_id_in_file = np.array(p_id_in_file)

# %%
max_pad_len =  MAX_PAD_LEN

os.makedirs("./Respiratory_Sound_Database/features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=5) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./Respiratory_Sound_Database/features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
p_diag = pd.read_csv("./Respiratory_Sound_Database/Respiratory_Sound_Database/patient_diagnosis.csv",header=None) # patient diagnosis file

# %%
labels = np.array([p_diag[p_diag[0] == x][1].values[0] for x in p_id_in_file]) # labels for audio files

# %%
features = [] 

# Iterate through each sound file and extract the features
for file_name in filepaths:
    data = extract_features(file_name)
    features.append(data)

print('Finished feature extraction from ', len(features), ' files')
features = np.array(features)
# Out:
# Finished feature extraction from  216  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
features = np.array(features) # convert to numpy array

# %%
np.unique(labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
# delete diseases
'''
features1 = features
labels1 = labels'''

features1 = np.delete(features, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0) 

labels1 = np.delete(labels, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0)

# %%
# print class counts
unique_elements, counts_elements = np.unique(labels1, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['105' '111']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(labels1)
oh_labels = to_categorical(i_labels)

# %%
features1.shape
# Out:
# (216, 40, 216)

# %%
# add channel dimension for CNN
features1 = np.reshape(features1, (*features1.shape,1)) 

# train test split
x_train, x_test, y_train, y_test = train_test_split(features1, oh_labels, stratify=oh_labels, 
                                                    test_size=0.2, random_state = 42)

# %% [markdown]
# **MLP model architecture**

# %%
num_rows = 40
num_columns = 216
num_channels = 1

num_labels = oh_labels.shape[1]
filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=16, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=8, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=4, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 215, 32)       160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 107, 32)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 107, 32)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 106, 16)       2064
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 53, 16)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 53, 16)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 52, 8)          520
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 26, 8)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 26, 8)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 25, 4)          132
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 12, 4)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 12, 4)          0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 4)                 0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 10
# =================================================================
# Total params: 2,886
# Trainable params: 2,886
# Non-trainable params: 0
# _________________________________________________________________
# 44/44 [==============================] - 1s 25ms/sample - loss: 2.7918 - accuracy: 0.4773
# Pre-training accuracy: 47.7273%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 250
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/model2_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 172 samples, validate on 44 samples
# Epoch 1/250
#  90/172 [==============>...............] - ETA: 0s - loss: 6.5703 - accuracy: 0.5444
# Epoch 00001: val_accuracy improved from -inf to 0.52273, saving model to models/model2_01.h5
# 172/172 [==============================] - 1s 5ms/sample - loss: 4.5584 - accuracy: 0.5000 - val_loss: 0.8285 - val_accuracy: 0.5227
# Epoch 2/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.9287 - accuracy: 0.5000
# Epoch 00002: val_accuracy did not improve from 0.52273
# 172/172 [==============================] - 0s 785us/sample - loss: 0.9262 - accuracy: 0.5000 - val_loss: 0.8438 - val_accuracy: 0.5227
# Epoch 3/250
# 160/172 [==========================>...] - ETA: 0s - loss: 0.7461 - accuracy: 0.5188
# Epoch 00003: val_accuracy improved from 0.52273 to 0.54545, saving model to models/model2_03.h5
# 172/172 [==============================] - 0s 982us/sample - loss: 0.7450 - accuracy: 0.5174 - val_loss: 0.6928 - val_accuracy: 0.5455
# Epoch 4/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.6598 - accuracy: 0.5941
# Epoch 00004: val_accuracy did not improve from 0.54545
# 172/172 [==============================] - 0s 807us/sample - loss: 0.6599 - accuracy: 0.5930 - val_loss: 0.6780 - val_accuracy: 0.5455
# Epoch 5/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.6498 - accuracy: 0.5824
# Epoch 00005: val_accuracy improved from 0.54545 to 0.59091, saving model to models/model2_05.h5
# 172/172 [==============================] - 0s 979us/sample - loss: 0.6511 - accuracy: 0.5756 - val_loss: 0.6682 - val_accuracy: 0.5909
# Epoch 6/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.6362 - accuracy: 0.5941
# Epoch 00006: val_accuracy improved from 0.59091 to 0.61364, saving model to models/model2_06.h5
# 172/172 [==============================] - 0s 970us/sample - loss: 0.6340 - accuracy: 0.5930 - val_loss: 0.6478 - val_accuracy: 0.6136
# Epoch 7/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.6403 - accuracy: 0.6000
# Epoch 00007: val_accuracy did not improve from 0.61364
# 172/172 [==============================] - 0s 791us/sample - loss: 0.6418 - accuracy: 0.5988 - val_loss: 0.6318 - val_accuracy: 0.6136
# Epoch 8/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.5888 - accuracy: 0.6400
# Epoch 00008: val_accuracy did not improve from 0.61364
# 172/172 [==============================] - 0s 740us/sample - loss: 0.6038 - accuracy: 0.6047 - val_loss: 0.6182 - val_accuracy: 0.6136
# Epoch 9/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.5636 - accuracy: 0.6588
# Epoch 00009: val_accuracy did not improve from 0.61364
# 172/172 [==============================] - 0s 1ms/sample - loss: 0.5661 - accuracy: 0.6570 - val_loss: 0.6164 - val_accuracy: 0.5909
# Epoch 10/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.5713 - accuracy: 0.6444
# Epoch 00010: val_accuracy improved from 0.61364 to 0.65909, saving model to models/model2_10.h5
# 172/172 [==============================] - 0s 913us/sample - loss: 0.5834 - accuracy: 0.6570 - val_loss: 0.6143 - val_accuracy: 0.6591
# Epoch 11/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.5494 - accuracy: 0.7118
# Epoch 00011: val_accuracy did not improve from 0.65909
# 172/172 [==============================] - 0s 844us/sample - loss: 0.5509 - accuracy: 0.7093 - val_loss: 0.6085 - val_accuracy: 0.6136
# Epoch 12/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.5563 - accuracy: 0.6765
# Epoch 00012: val_accuracy did not improve from 0.65909
# 172/172 [==============================] - 0s 803us/sample - loss: 0.5548 - accuracy: 0.6744 - val_loss: 0.5983 - val_accuracy: 0.6364
# Epoch 13/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.5739 - accuracy: 0.6889
# Epoch 00013: val_accuracy did not improve from 0.65909
# 172/172 [==============================] - 0s 783us/sample - loss: 0.5374 - accuracy: 0.7209 - val_loss: 0.5877 - val_accuracy: 0.6591
# Epoch 14/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.5596 - accuracy: 0.7091
# Epoch 00014: val_accuracy improved from 0.65909 to 0.68182, saving model to models/model2_14.h5
# 172/172 [==============================] - 0s 1ms/sample - loss: 0.5607 - accuracy: 0.7151 - val_loss: 0.5884 - val_accuracy: 0.6818
# Epoch 15/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.5652 - accuracy: 0.6882
# Epoch 00015: val_accuracy did not improve from 0.68182
# 172/172 [==============================] - 0s 806us/sample - loss: 0.5663 - accuracy: 0.6860 - val_loss: 0.5841 - val_accuracy: 0.6818
# Epoch 16/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.5628 - accuracy: 0.6647
# Epoch 00016: val_accuracy did not improve from 0.68182
# 172/172 [==============================] - 0s 819us/sample - loss: 0.5656 - accuracy: 0.6628 - val_loss: 0.5662 - val_accuracy: 0.6818
# Epoch 17/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.5236 - accuracy: 0.7118
# Epoch 00017: val_accuracy improved from 0.68182 to 0.77273, saving model to models/model2_17.h5
# 172/172 [==============================] - 0s 917us/sample - loss: 0.5262 - accuracy: 0.7093 - val_loss: 0.5565 - val_accuracy: 0.7727
# Epoch 18/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.4731 - accuracy: 0.8000
# Epoch 00018: val_accuracy did not improve from 0.77273
# 172/172 [==============================] - 0s 760us/sample - loss: 0.4681 - accuracy: 0.8256 - val_loss: 0.5520 - val_accuracy: 0.7045
# Epoch 19/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.4941 - accuracy: 0.7333
# Epoch 00019: val_accuracy did not improve from 0.77273
# 172/172 [==============================] - 0s 768us/sample - loss: 0.4909 - accuracy: 0.7326 - val_loss: 0.5372 - val_accuracy: 0.7500
# Epoch 20/250
# 150/172 [=========================>....] - ETA: 0s - loss: 0.5075 - accuracy: 0.7133
# Epoch 00020: val_accuracy did not improve from 0.77273
# 172/172 [==============================] - 0s 853us/sample - loss: 0.4935 - accuracy: 0.7442 - val_loss: 0.5287 - val_accuracy: 0.7500
# Epoch 21/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.4489 - accuracy: 0.7667
# Epoch 00021: val_accuracy did not improve from 0.77273
# 172/172 [==============================] - 0s 755us/sample - loss: 0.4923 - accuracy: 0.7326 - val_loss: 0.5547 - val_accuracy: 0.6364
# Epoch 22/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.5301 - accuracy: 0.7176
# Epoch 00022: val_accuracy did not improve from 0.77273
# 172/172 [==============================] - 0s 775us/sample - loss: 0.5271 - accuracy: 0.7209 - val_loss: 0.5318 - val_accuracy: 0.7500
# Epoch 23/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.4738 - accuracy: 0.8222
# Epoch 00023: val_accuracy did not improve from 0.77273
# 172/172 [==============================] - 0s 745us/sample - loss: 0.4626 - accuracy: 0.7907 - val_loss: 0.5198 - val_accuracy: 0.7045
# Epoch 24/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.4211 - accuracy: 0.8444
# Epoch 00024: val_accuracy did not improve from 0.77273
# 172/172 [==============================] - 0s 745us/sample - loss: 0.4492 - accuracy: 0.8023 - val_loss: 0.5053 - val_accuracy: 0.7273
# Epoch 25/250
# 170/172 [============================>.] - ETA: 0s - loss: 0
250
# 170/172 [============================>.] - ETA: 0s - loss: 0.3422 - accuracy: 0.8529
# Epoch 00036: val_accuracy did not improve from 0.77273
# 172/172 [==============================] - 0s 772us/sample - loss: 0.3433 - accuracy: 0.8547 - val_loss: 0.4079 - val_accuracy: 0.7500
# Epoch 37/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.3944 - accuracy: 0.8000
# Epoch 00037: val_accuracy improved from 0.77273 to 0.79545, saving model to models/model2_37.h5
# 172/172 [==============================] - 0s 926us/sample - loss: 0.3918 - accuracy: 0.8023 - val_loss: 0.3915 - val_accuracy: 0.7955
# Epoch 38/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.3493 - accuracy: 0.8588
# Epoch 00038: val_accuracy did not improve from 0.79545
# 172/172 [==============================] - 0s 796us/sample - loss: 0.3467 - accuracy: 0.8605 - val_loss: 0.3862 - val_accuracy: 0.7727
# Epoch 39/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.3477 - accuracy: 0.8444
# Epoch 00039: val_accuracy did not improve from 0.79545
# 172/172 [==============================] - 0s 767us/sample - loss: 0.3754 - accuracy: 0.7965 - val_loss: 0.3813 - val_accuracy: 0.7955
# Epoch 40/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.3399 - accuracy: 0.8706
# Epoch 00040: val_accuracy did not improve from 0.79545
# 172/172 [==============================] - 0s 788us/sample - loss: 0.3372 - accuracy: 0.8721 - val_loss: 0.4088 - val_accuracy: 0.7727
# Epoch 41/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.3313 - accuracy: 0.8529
# Epoch 00041: val_accuracy did not improve from 0.79545
# 172/172 [==============================] - 0s 764us/sample - loss: 0.3300 - accuracy: 0.8547 - val_loss: 0.3792 - val_accuracy: 0.7727
# Epoch 42/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.3229 - accuracy: 0.8667
# Epoch 00042: val_accuracy did not improve from 0.79545
# 172/172 [==============================] - 0s 739us/sample - loss: 0.3280 - accuracy: 0.8721 - val_loss: 0.4077 - val_accuracy: 0.7955
# Epoch 43/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.3728 - accuracy: 0.8706
# Epoch 00043: val_accuracy did not improve from 0.79545
# 172/172 [==============================] - 0s 796us/sample - loss: 0.3776 - accuracy: 0.8663 - val_loss: 0.3939 - val_accuracy: 0.7727
# Epoch 44/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.3330 - accuracy: 0.8444
# Epoch 00044: val_accuracy did not improve from 0.79545
# 172/172 [==============================] - 0s 765us/sample - loss: 0.3304 - accuracy: 0.8430 - val_loss: 0.4679 - val_accuracy: 0.7273
# Epoch 45/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.3608 - accuracy: 0.8353
# Epoch 00045: val_accuracy did not improve from 0.79545
# 172/172 [==============================] - 0s 795us/sample - loss: 0.3626 - accuracy: 0.8372 - val_loss: 0.3856 - val_accuracy: 0.7727
# Epoch 46/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.2782 - accuracy: 0.9000
# Epoch 00046: val_accuracy improved from 0.79545 to 0.81818, saving model to models/model2_46.h5
# 172/172 [==============================] - 0s 886us/sample - loss: 0.2736 - accuracy: 0.8953 - val_loss: 0.3667 - val_accuracy: 0.8182
# Epoch 47/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.2907 - accuracy: 0.8588
# Epoch 00047: val_accuracy did not improve from 0.81818
# 172/172 [==============================] - 0s 785us/sample - loss: 0.2890 - accuracy: 0.8605 - val_loss: 0.3681 - val_accuracy: 0.8182
# Epoch 48/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.3112 - accuracy: 0.8588
# Epoch 00048: val_accuracy did not improve from 0.81818
# 172/172 [==============================] - 0s 781us/sample - loss: 0.3106 - accuracy: 0.8605 - val_loss: 0.3485 - val_accuracy: 0.8182
# Epoch 49/250
# 160/172 [==========================>...] - ETA: 0s - loss: 0.2636 - accuracy: 0.8813
# Epoch 00049: val_accuracy did not improve from 0.81818
# 172/172 [==============================] - 0s 813us/sample - loss: 0.2646 - accuracy: 0.8779 - val_loss: 0.3431 - val_accuracy: 0.7955
# Epoch 50/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.3033 - accuracy: 0.8700
# Epoch 00050: val_accuracy did not improve from 0.81818
# 172/172 [==============================] - 0s 742us/sample - loss: 0.3237 - accuracy: 0.8721 - val_loss: 0.3428 - val_accuracy: 0.8182
# Epoch 51/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.2791 - accuracy: 0.8765
# Epoch 00051: val_accuracy improved from 0.81818 to 0.84091, saving model to models/model2_51.h5
# 172/172 [==============================] - 0s 919us/sample - loss: 0.2781 - accuracy: 0.8779 - val_loss: 0.3405 - val_accuracy: 0.8409
# Epoch 52/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.2828 - accuracy: 0.8882
# Epoch 00052: val_accuracy did not improve from 0.84091
# 172/172 [==============================] - 0s 786us/sample - loss: 0.2831 - accuracy: 0.8895 - val_loss: 0.3391 - val_accuracy: 0.8182
# Epoch 53/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.2537 - accuracy: 0.8882
# Epoch 00053: val_accuracy did not improve from 0.84091
# 172/172 [==============================] - 0s 767us/sample - loss: 0.2553 - accuracy: 0.8837 - val_loss: 0.3652 - val_accuracy: 0.8182
# Epoch 54/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.2425 - accuracy: 0.9176
# Epoch 00054: val_accuracy did not improve from 0.84091
# 172/172 [==============================] - 0s 778us/sample - loss: 0.2401 - accuracy: 0.9186 - val_loss: 0.3387 - val_accuracy: 0.8182
# Epoch 55/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.2832 - accuracy: 0.8700
# Epoch 00055: val_accuracy did not improve from 0.84091
# 172/172 [==============================] - 0s 730us/sample - loss: 0.2879 - accuracy: 0.8837 - val_loss: 0.3258 - val_accuracy: 0.8182
# Epoch 56/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.1937 - accuracy: 0.9222
# Epoch 00056: val_accuracy did not improve from 0.84091
# 172/172 [==============================] - 0s 752us/sample - loss: 0.2261 - accuracy: 0.9128 - val_loss: 0.3260 - val_accuracy: 0.8409
# Epoch 57/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.2188 - accuracy: 0.9118
# Epoch 00057: val_accuracy did not improve from 0.84091
# 172/172 [==============================] - 0s 782us/sample - loss: 0.2174 - accuracy: 0.9128 - val_loss: 0.3226 - val_accuracy: 0.8409
# Epoch 58/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.2452 - accuracy: 0.8900
# Epoch 00058: val_accuracy did not improve from 0.84091
# 172/172 [==============================] - 0s 752us/sample - loss: 0.2308 - accuracy: 0.8953 - val_loss: 0.3373 - val_accuracy: 0.8409
# Epoch 59/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.1972 - accuracy: 0.9176
# Epoch 00059: val_accuracy improved from 0.84091 to 0.86364, saving model to models/model2_59.h5
# 172/172 [==============================] - 0s 949us/sample - loss: 0.1950 - accuracy: 0.9186 - val_loss: 0.3430 - val_accuracy: 0.8636
# Epoch 60/250
# 170/172 [============================>.] - ETA: 0s - loss: 0
250
# 170/172 [============================>.] - ETA: 0s - loss: 0.1361 - accuracy: 0.9471
# Epoch 00227: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 849us/sample - loss: 0.1345 - accuracy: 0.9477 - val_loss: 0.3697 - val_accuracy: 0.8409
# Epoch 228/250
# 160/172 [==========================>...] - ETA: 0s - loss: 0.0895 - accuracy: 0.9563
# Epoch 00228: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 841us/sample - loss: 0.0904 - accuracy: 0.9593 - val_loss: 0.3215 - val_accuracy: 0.8864
# Epoch 229/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.1011 - accuracy: 0.9765
# Epoch 00229: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 856us/sample - loss: 0.0999 - accuracy: 0.9767 - val_loss: 0.3921 - val_accuracy: 0.9091
# Epoch 230/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.1197 - accuracy: 0.9471
# Epoch 00230: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 854us/sample - loss: 0.1183 - accuracy: 0.9477 - val_loss: 0.4214 - val_accuracy: 0.9091
# Epoch 231/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0724 - accuracy: 0.9765
# Epoch 00231: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 828us/sample - loss: 0.0716 - accuracy: 0.9767 - val_loss: 0.3564 - val_accuracy: 0.8409
# Epoch 232/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0687 - accuracy: 0.9647
# Epoch 00232: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 831us/sample - loss: 0.0763 - accuracy: 0.9593 - val_loss: 0.3364 - val_accuracy: 0.8409
# Epoch 233/250
# 160/172 [==========================>...] - ETA: 0s - loss: 0.1900 - accuracy: 0.9438
# Epoch 00233: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 868us/sample - loss: 0.1779 - accuracy: 0.9477 - val_loss: 0.4789 - val_accuracy: 0.9091
# Epoch 234/250
# 160/172 [==========================>...] - ETA: 0s - loss: 0.1450 - accuracy: 0.9375
# Epoch 00234: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 899us/sample - loss: 0.1380 - accuracy: 0.9419 - val_loss: 0.4211 - val_accuracy: 0.9091
# Epoch 235/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0971 - accuracy: 0.9529
# Epoch 00235: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 860us/sample - loss: 0.0960 - accuracy: 0.9535 - val_loss: 0.2908 - val_accuracy: 0.8409
# Epoch 236/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.1578 - accuracy: 0.9294
# Epoch 00236: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 853us/sample - loss: 0.1617 - accuracy: 0.9302 - val_loss: 0.3626 - val_accuracy: 0.9091
# Epoch 237/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.1357 - accuracy: 0.9529
# Epoch 00237: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 851us/sample - loss: 0.1341 - accuracy: 0.9535 - val_loss: 0.3905 - val_accuracy: 0.9091
# Epoch 238/250
# 160/172 [==========================>...] - ETA: 0s - loss: 0.1193 - accuracy: 0.9438
# Epoch 00238: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 835us/sample - loss: 0.1179 - accuracy: 0.9419 - val_loss: 0.3247 - val_accuracy: 0.8409
# Epoch 239/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0613 - accuracy: 0.9647
# Epoch 00239: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 829us/sample - loss: 0.0618 - accuracy: 0.9651 - val_loss: 0.3507 - val_accuracy: 0.9091
# Epoch 240/250
# 150/172 [=========================>....] - ETA: 0s - loss: 0.0736 - accuracy: 0.9867
# Epoch 00240: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 874us/sample - loss: 0.1061 - accuracy: 0.9767 - val_loss: 0.3208 - val_accuracy: 0.8864
# Epoch 241/250
# 150/172 [=========================>....] - ETA: 0s - loss: 0.0807 - accuracy: 0.9600
# Epoch 00241: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 882us/sample - loss: 0.0838 - accuracy: 0.9593 - val_loss: 0.3713 - val_accuracy: 0.9091
# Epoch 242/250
# 160/172 [==========================>...] - ETA: 0s - loss: 0.0634 - accuracy: 0.9750
# Epoch 00242: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 895us/sample - loss: 0.0717 - accuracy: 0.9709 - val_loss: 0.3545 - val_accuracy: 0.8864
# Epoch 243/250
# 150/172 [=========================>....] - ETA: 0s - loss: 0.1049 - accuracy: 0.9600
# Epoch 00243: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 838us/sample - loss: 0.0983 - accuracy: 0.9651 - val_loss: 0.3019 - val_accuracy: 0.8864
# Epoch 244/250
# 160/172 [==========================>...] - ETA: 0s - loss: 0.0577 - accuracy: 0.9812
# Epoch 00244: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 885us/sample - loss: 0.0547 - accuracy: 0.9826 - val_loss: 0.3123 - val_accuracy: 0.8864
# Epoch 245/250
# 160/172 [==========================>...] - ETA: 0s - loss: 0.0861 - accuracy: 0.9563
# Epoch 00245: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 855us/sample - loss: 0.0805 - accuracy: 0.9593 - val_loss: 0.4123 - val_accuracy: 0.9318
# Epoch 246/250
# 160/172 [==========================>...] - ETA: 0s - loss: 0.0651 - accuracy: 0.9812
# Epoch 00246: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 826us/sample - loss: 0.0834 - accuracy: 0.9709 - val_loss: 0.4008 - val_accuracy: 0.9091
# Epoch 247/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.1091 - accuracy: 0.9412
# Epoch 00247: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 811us/sample - loss: 0.1094 - accuracy: 0.9419 - val_loss: 0.3810 - val_accuracy: 0.9318
# Epoch 248/250
# 160/172 [==========================>...] - ETA: 0s - loss: 0.0838 - accuracy: 0.9625
# Epoch 00248: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 858us/sample - loss: 0.0897 - accuracy: 0.9593 - val_loss: 0.3408 - val_accuracy: 0.9318
# Epoch 249/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0743 - accuracy: 0.9765
# Epoch 00249: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 845us/sample - loss: 0.0734 - accuracy: 0.9767 - val_loss: 0.4294 - val_accuracy: 0.9091
# Epoch 250/250
# 160/172 [==========================>...] - ETA: 0s - loss: 0.0814 - accuracy: 0.9688
# Epoch 00250: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 848us/sample - loss: 0.0779 - accuracy: 0.9709 - val_loss: 0.3411 - val_accuracy: 0.8864
# Training completed in time:  0:00:37.221524

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste
#
# Lembrando que estamos utilizando o mesmo conjunto de validacão, que a princípio, pode incluir instâncias do conjunto de treinamento: o dataset utilizado foi gerado com corte de áudio, então alguns trechos do mesmo áudio podem estar presentes em ambos os conjuntos de treinamento e teste.
# Por ora deixamos assim já que estamos realizando uma investigacão inicial.

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.9883721
# Testing Accuracy:  0.8863636

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.86      0.90      0.88        21
#    Pneumonia       0.91      0.87      0.89        23
#
#     accuracy                           0.89        44
#    macro avg       0.89      0.89      0.89        44
# weighted avg       0.89      0.89      0.89        44

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[19  2]
#  [ 3 20]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])
