# %% [markdown]
# # Rede CNN - Modelo 1
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - slide10phone

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP = 'slide10phone'
MAX_PAD_LEN = 431

# %%
filepaths = glob.glob(f'./datasets/{GROUP}/**/*.wav', recursive=True)
filenames = [os.path.splitext(os.path.basename(p))[0] for p in filepaths]

# %%
p_id_in_file = [] # patient IDs corresponding to each file
for name in filenames:
    p_id_in_file.append(int(name[:3]))

p_id_in_file = np.array(p_id_in_file)

# %%
max_pad_len =  MAX_PAD_LEN

os.makedirs("./Respiratory_Sound_Database/features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=10) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./Respiratory_Sound_Database/features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
p_diag = pd.read_csv("./Respiratory_Sound_Database/Respiratory_Sound_Database/patient_diagnosis.csv",header=None) # patient diagnosis file

# %%
labels = np.array([p_diag[p_diag[0] == x][1].values[0] for x in p_id_in_file]) # labels for audio files

# %%
features = [] 

# Iterate through each sound file and extract the features
for file_name in filepaths:
    data = extract_features(file_name)
    features.append(data)

print('Finished feature extraction from ', len(features), ' files')
features = np.array(features)
# Out:
# Finished feature extraction from  1152  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(features[1], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
features = np.array(features) # convert to numpy array

# %%
np.unique(labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
# delete diseases
'''
features1 = features
labels1 = labels'''

features1 = np.delete(features, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0) 

labels1 = np.delete(labels, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0)

# %%
# print class counts
unique_elements, counts_elements = np.unique(labels1, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['560' '592']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(labels1)
oh_labels = to_categorical(i_labels)

# %%
features1.shape
# Out:
# (1152, 40, 431)

# %%
# add channel dimension for CNN
features1 = np.reshape(features1, (*features1.shape,1)) 

# train test split
x_train, x_test, y_train, y_test = train_test_split(features1, oh_labels, stratify=oh_labels, 
                                                    test_size=0.2, random_state = 42)

# %% [markdown]
# **MLP model architecture**

# %%
num_rows = 40
num_columns = 431
num_channels = 1

num_labels = oh_labels.shape[1]
filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 430, 16)       80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 215, 16)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 215, 16)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 214, 32)       2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 107, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 107, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 106, 64)        8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 53, 64)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 53, 64)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 52, 128)        32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 26, 128)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 26, 128)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 258
# =================================================================
# Total params: 43,570
# Trainable params: 43,570
# Non-trainable params: 0
# _________________________________________________________________
# 231/231 [==============================] - 1s 6ms/sample - loss: 4.1017 - accuracy: 0.5152
# Pre-training accuracy: 51.5152%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 250
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/model2_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 921 samples, validate on 231 samples
# Epoch 1/250
# 880/921 [===========================>..] - ETA: 0s - loss: 2.5304 - accuracy: 0.5443
# Epoch 00001: val_accuracy improved from -inf to 0.66234, saving model to models/model2_01.h5
# 921/921 [==============================] - 2s 2ms/sample - loss: 2.4504 - accuracy: 0.5516 - val_loss: 0.5958 - val_accuracy: 0.6623
# Epoch 2/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.5682 - accuracy: 0.7088
# Epoch 00002: val_accuracy did not improve from 0.66234
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.5699 - accuracy: 0.7058 - val_loss: 0.6503 - val_accuracy: 0.6017
# Epoch 3/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.4682 - accuracy: 0.7681
# Epoch 00003: val_accuracy improved from 0.66234 to 0.72294, saving model to models/model2_03.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.4682 - accuracy: 0.7666 - val_loss: 0.5013 - val_accuracy: 0.7229
# Epoch 4/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.3839 - accuracy: 0.8233
# Epoch 00004: val_accuracy improved from 0.72294 to 0.85281, saving model to models/model2_04.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.3817 - accuracy: 0.8230 - val_loss: 0.3803 - val_accuracy: 0.8528
# Epoch 5/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.4405 - accuracy: 0.7923
# Epoch 00005: val_accuracy improved from 0.85281 to 0.87446, saving model to models/model2_05.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.4394 - accuracy: 0.7937 - val_loss: 0.3424 - val_accuracy: 0.8745
# Epoch 6/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.3173 - accuracy: 0.8554
# Epoch 00006: val_accuracy did not improve from 0.87446
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.3170 - accuracy: 0.8556 - val_loss: 0.3370 - val_accuracy: 0.8182
# Epoch 7/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.2970 - accuracy: 0.8629
# Epoch 00007: val_accuracy did not improve from 0.87446
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.2961 - accuracy: 0.8632 - val_loss: 0.3728 - val_accuracy: 0.7792
# Epoch 8/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.3244 - accuracy: 0.8600
# Epoch 00008: val_accuracy improved from 0.87446 to 0.89610, saving model to models/model2_08.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.3193 - accuracy: 0.8632 - val_loss: 0.2522 - val_accuracy: 0.8961
# Epoch 9/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.2497 - accuracy: 0.8854
# Epoch 00009: val_accuracy improved from 0.89610 to 0.90043, saving model to models/model2_09.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.2463 - accuracy: 0.8882 - val_loss: 0.2386 - val_accuracy: 0.9004
# Epoch 10/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.2422 - accuracy: 0.8848
# Epoch 00010: val_accuracy improved from 0.90043 to 0.91775, saving model to models/model2_10.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.2421 - accuracy: 0.8849 - val_loss: 0.2180 - val_accuracy: 0.9177
# Epoch 11/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.2711 - accuracy: 0.8722
# Epoch 00011: val_accuracy did not improve from 0.91775
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.2685 - accuracy: 0.8730 - val_loss: 0.2405 - val_accuracy: 0.8961
# Epoch 12/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.2029 - accuracy: 0.9080
# Epoch 00012: val_accuracy improved from 0.91775 to 0.92641, saving model to models/model2_12.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.2049 - accuracy: 0.9055 - val_loss: 0.1863 - val_accuracy: 0.9264
# Epoch 13/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.2634 - accuracy: 0.8846
# Epoch 00013: val_accuracy did not improve from 0.92641
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.2638 - accuracy: 0.8838 - val_loss: 0.3860 - val_accuracy: 0.8398
# Epoch 14/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.2049 - accuracy: 0.9182
# Epoch 00014: val_accuracy did not improve from 0.92641
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.2043 - accuracy: 0.9186 - val_loss: 0.2154 - val_accuracy: 0.9177
# Epoch 15/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.1677 - accuracy: 0.9258
# Epoch 00015: val_accuracy did not improve from 0.92641
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.1664 - accuracy: 0.9273 - val_loss: 0.2085 - val_accuracy: 0.9091
# Epoch 16/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.1959 - accuracy: 0.9198
# Epoch 00016: val_accuracy did not improve from 0.92641
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.1960 - accuracy: 0.9197 - val_loss: 0.3209 - val_accuracy: 0.8485
# Epoch 17/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.1501 - accuracy: 0.9382
# Epoch 00017: val_accuracy improved from 0.92641 to 0.94805, saving model to models/model2_17.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.1493 - accuracy: 0.9392 - val_loss: 0.1567 - val_accuracy: 0.9481
# Epoch 18/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.1469 - accuracy: 0.9284
# Epoch 00018: val_accuracy improved from 0.94805 to 0.95671, saving model to models/model2_18.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.1455 - accuracy: 0.9283 - val_loss: 0.1183 - val_accuracy: 0.9567
# Epoch 19/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.1314 - accuracy: 0.9432
# Epoch 00019: val_accuracy did not improve from 0.95671
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.1284 - accuracy: 0.9446 - val_loss: 0.4391 - val_accuracy: 0.8139
# Epoch 20/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.1301 - accuracy: 0.9543
# Epoch 00020: val_accuracy did not improve from 0.95671
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.1300 - accuracy: 0.9544 - val_loss: 0.1168 - val_accuracy: 0.9567
# Epoch 21/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.1309 - accuracy: 0.9389
# Epoch 00021: val_accuracy did not improve from 0.95671
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.1315 - accuracy: 0.9392 - val_loss: 0.1564 - val_accuracy: 0.9524
# Epoch 22/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.1013 - accuracy: 0.9656
# Epoch 00022: val_accuracy improved from 0.95671 to 0.96537, saving model to models/model2_22.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.1040 - accuracy: 0.9642 - val_loss: 0.1084 - val_accuracy: 0.9654
# Epoch 23/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.2802 - accuracy: 0.9022
# Epoch 00023: val_accuracy did not improve from 0.96537
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.2758 - accuracy: 0.9034 - val_loss: 0.1628 - val_accuracy: 0.9221
# Epoch 24/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.1029 - accuracy: 0.9571
# Epoch 00024: val_accuracy improved from 0.96537 to 0.97403, saving model to models/model2_24.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.1033 - accuracy: 0.9566 - val_loss: 0.0901 - val_accuracy: 0.9740
# Epoch 25/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0839 - accuracy: 0.9693
# Epoch 00025: val_accuracy did not improve from 0.97403
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0837 - accuracy: 0.9696 - val_loss: 0.1117 - val_accuracy: 0.9567
# Epoch 26/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0895 - accuracy: 0.9629
# Epoch 00026: val_accuracy improved from 0.97403 to 0.97835, saving model to models/model2_26.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0925 - accuracy: 0.9620 - val_loss: 0.1091 - val_accuracy: 0.9784
# Epoch 27/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.1132 - accuracy: 0.9557
# Epoch 00027: val_accuracy did not improve from 0.97835
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.1151 - accuracy: 0.9533 - val_loss: 0.1258 - val_accuracy: 0.9437
# Epoch 28/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0856 - accuracy: 0.9663
# Epoch 00028: val_accuracy did not improve from 0.97835
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0973 - accuracy: 0.9598 - val_loss: 0.1391 - val_accuracy: 0.9307
# Epoch 29/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.1599 - accuracy: 0.9326
# Epoch 00029: val_accuracy improved from 0.97835 to 0.98268, saving model to models/model2_29.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.1597 - accuracy: 0.9327 - val_loss: 0.0782 - val_accuracy: 0.9827
# Epoch 30/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0674 - accuracy: 0.9775
# Epoch 00030: val_accuracy improved from 0.98268 to 0.98701, saving model to models/model2_30.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0667 - accuracy: 0.9772 - val_loss: 0.0504 - val_accuracy: 0.9870
# Epoch 31/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0783 - accuracy: 0.9644
# Epoch 00031: val_accuracy did not improve from 0.98701
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0788 - accuracy: 0.9631 - val_loss: 0.1325 - val_accuracy: 0.9524
# Epoch 32/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0503 - accuracy: 0.9843
# Epoch 00032: val_accuracy did not improve from 0.98701
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0487 - accuracy: 0.9848 - val_loss: 0.0892 - val_accuracy: 0.9697
# Epoch 33/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0715 - accuracy: 0.9689
# Epoch 00033: val_accuracy did not improve from 0.98701
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0708 - accuracy: 0.9696 - val_loss: 0.1460 - val_accuracy: 0.9394
# Epoch 34/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0402 - accuracy: 0.9843
# Epoch 00034: val_accuracy did not improve from 0.98701
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0420 - accuracy: 0.9837 - val_loss: 0.0612 - val_accuracy: 0.9740
# Epoch 35/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.1372 - accuracy: 0.9471
# Epoch 00035: val_accuracy did not improve from 0.98701
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.1358 - accuracy: 0.9479 - val_loss: 0.1066 - val_accuracy: 0.9654
# Epoch 36/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0650 - accuracy: 0.9761
# Epoch 00036: val_accuracy did not improve from 0.98701
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0649 - accuracy: 0.9761 - val_loss: 0.2543 - val_accuracy: 0.9481
# Epoch 37/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0869 - accuracy: 0.9640
# Epoch 00037: val_accuracy did not improve from 0.98701
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0849 - accuracy: 0.9653 - val_loss: 0.2071 - val_accuracy: 0.8961
# Epoch 38/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0719 - accuracy: 0.9750
# Epoch 00038: val_accuracy did not improve from 0.98701
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0704 - accuracy: 0.9761 - val_loss: 0.2038 - val_accuracy: 0.8961
# Epoch 39/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0818 - accuracy: 0.9667
# Epoch 00039: val_accuracy did not improve from 0.98701
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0814 - accuracy: 0.9663 - val_loss: 0.1252 - val_accuracy: 0.9437
# Epoch 40/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0736 - accuracy: 0.9773
# Epoch 00040: val_accuracy did not improve from 0.98701
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0725 - accuracy: 0.9772 - val_loss: 0.0406 - val_accuracy: 0.9870
# Epoch 41/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0341 - accuracy: 0.9841
# Epoch 00041: val_accuracy did not improve from 0.98701
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0344 - accuracy: 0.9837 - val_loss: 0.0632 - val_accuracy: 0.9784
# Epoch 42/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0346 - accuracy: 0.9800
# Epoch 00042: val_accuracy improved from 0.98701 to 0.99134, saving model to models/model2_42.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0357 - accuracy: 0.9794 - val_loss: 0.0317 - val_accuracy: 0.9913
# Epoch 43/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.1361 - accuracy: 0.9554
# Epoch 00043: val_accuracy did not improve from 0.99134
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.1362 - accuracy: 0.9555 - val_loss: 0.0708 - val_accuracy: 0.9740
# Epoch 44/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0326 - accuracy: 0.9909
# Epoch 00044: val_accuracy did not improve from 0.99134
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0335 - accuracy: 0.9902 - val_loss: 0.0370 - val_accuracy: 0.9913
# Epoch 45/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0911 - accuracy: 0.9648
# Epoch 00045: val_accuracy did not improve from 0.99134
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0905 - accuracy: 0.9653 - val_loss: 0.0652 - val_accuracy: 0.9740
# Epoch 46/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0339 - accuracy: 0.9898
# Epoch 00046: val_accuracy did not improve from 0.99134
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0329 - accuracy: 0.9902 - val_loss: 0.0269 - val_accuracy: 0.9913
# Epoch 47/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0334 - accuracy: 0.9886
# Epoch 00047: val_accuracy did not improve from 0.99134
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0323 - accuracy: 0.9891 - val_loss: 0.0264 - val_accuracy: 0.9913
# Epoch 48/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0317 - accuracy: 0.9880
# Epoch 00048: val_accuracy did not improve from 0.99134
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0316 - accuracy: 0.9881 - val_loss: 0.0625 - val_accuracy: 0.9827
# Epoch 49/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.1523 - accuracy: 0.9538
# Epoch 00049: val_accuracy did not improve from 0.99134
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.1507 - accuracy: 0.9544 - val_loss: 0.0833 - val_accuracy: 0.9697
# Epoch 50/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0704 - accuracy: 0.9739
# Epoch 00050: val_accuracy did not improve from 0.99134
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0707 - accuracy: 0.9739 - val_loss: 0.1015 - val_accuracy: 0.9784
# Epoch 51/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0291 - accuracy: 0.9923
# Epoch 00051: val_accuracy did not improve from 0.99134
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0288 - accuracy: 0.9924 - val_loss: 0.0272 - val_accuracy: 0.9913
# Epoch 52/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0229 - accuracy: 0.9935
# Epoch 00052: val_accuracy did not improve from 0.99134
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0228 - accuracy: 0.9935 - val_loss: 0.0438 - val_accuracy: 0.9870
# Epoch 53/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0341 - accuracy: 0.9844
# Epoch 00053: val_accuracy did not improve from 0.99134
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0340 - accuracy: 0.9848 - val_loss: 0.0523 - val_accuracy: 0.9913
# Epoch 54/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0223 - accuracy: 0.9944
# Epoch 00054: val_accuracy did not improve from 0.99134
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0223 - accuracy: 0.9946 - val_loss: 0.1442 - val_accuracy: 0.9567
# Epoch 55/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0613 - accuracy: 0.9807
# Epoch 00055: val_accuracy did not improve from 0.99134
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0601 - accuracy: 0.9805 - val_loss: 0.0737 - val_accuracy: 0.9740
# Epoch 56/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0258 - accuracy: 0.9935
# Epoch 00056: val_accuracy did not improve from 0.99134
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0258 - accuracy: 0.9935 - val_loss: 0.1637 - val_accuracy: 0.9740
# Epoch 57/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0421 - accuracy: 0.9889
# Epoch 00057: val_accuracy did not improve from 0.99134
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0412 - accuracy: 0.9891 - val_loss: 0.0349 - val_accuracy: 0.9913
# Epoch 58/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0323 - accuracy: 0.9864
# Epoch 00058: val_accuracy did not improve from 0.99134
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0310 - accuracy: 0.9870 - val_loss: 0.0471 - val_accuracy: 0.9784
# Epoch 59/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0175 - accuracy: 0.9944
# Epoch 00059: val_accuracy did not improve from 0.99134
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0218 - accuracy: 0.9935 - val_loss: 0.0706 - val_accuracy: 0.9784
# Epoch 60/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0436 - accuracy: 0.9852
# Epoch 00060: val_accuracy did not improve from 0.99134
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0441 - accuracy: 0.9848 - val_loss: 0.0722 - val_accuracy: 0.9697
# Epoch 61/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0465 - accuracy: 0.9843
# Epoch 00061: val_accuracy did not improve from 0.99134
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0452 - accuracy: 0.9848 - val_loss: 0.0238 - val_accuracy: 0.9913
# Epoch 62/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0582 - accuracy: 0.9798
# Epoch 00062: val_accuracy improved from 0.99134 to 1.00000, saving model to models/model2_62.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0567 - accuracy: 0.9805 - val_loss: 0.0289 - val_accuracy: 1.0000
# Epoch 63/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0330 - accuracy: 0.9886
# Epoch 00063: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0365 - accuracy: 0.9859 - val_loss: 0.0296 - val_accuracy: 0.9913
# Epoch 64/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0775 - accuracy: 0.9733
# Epoch 00064: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0791 - accuracy: 0.9718 - val_loss: 0.0325 - val_accuracy: 0.9957
# Epoch 65/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0379 - accuracy: 0.9901
# Epoch 00065: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 998us/sample - loss: 0.0382 - accuracy: 0.9902 - val_loss: 0.0192 - val_accuracy: 0.9957
# Epoch 66/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0102 - accuracy: 0.9978
# Epoch 00066: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0102 - accuracy: 0.9978 - val_loss: 0.0160 - val_accuracy: 0.9957
# Epoch 67/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0299 - accuracy: 0.9932
# Epoch 00067: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0310 - accuracy: 0.9924 - val_loss: 0.0372 - val_accuracy: 0.9870
# Epoch 68/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0117 - accuracy: 0.9956
# Epoch 00068: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0116 - accuracy: 0.9957 - val_loss: 0.0324 - val_accuracy: 0.9913
# Epoch 69/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0159 - accuracy: 0.9966
# Epoch 00069: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0162 - accuracy: 0.9967 - val_loss: 0.0407 - val_accuracy: 0.9827
# Epoch 70/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0275 - accuracy: 0.9898
# Epoch 00070: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0265 - accuracy: 0.9902 - val_loss: 0.0110 - val_accuracy: 0.9957
# Epoch 71/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 00071: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 0.9957
# Epoch 72/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 00072: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 73/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 00073: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0179 - val_accuracy: 0.9957
# Epoch 74/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.1001 - accuracy: 0.9703
# Epoch 00074: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0989 - accuracy: 0.9707 - val_loss: 0.0571 - val_accuracy: 0.9740
# Epoch 75/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.2121 - accuracy: 0.9422
# Epoch 00075: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.2086 - accuracy: 0.9435 - val_loss: 0.1187 - val_accuracy: 0.9351
# Epoch 76/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0329 - accuracy: 0.9933
# Epoch 00076: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0329 - accuracy: 0.9935 - val_loss: 0.0364 - val_accuracy: 0.9870
# Epoch 77/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0131 - accuracy: 0.9955
# Epoch 00077: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0129 - accuracy: 0.9957 - val_loss: 0.0312 - val_accuracy: 0.9913
# Epoch 78/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0303 - accuracy: 0.9888
# Epoch 00078: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0298 - accuracy: 0.9891 - val_loss: 0.0261 - val_accuracy: 0.9957
# Epoch 79/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0190 - accuracy: 0.9944
# Epoch 00079: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0186 - accuracy: 0.9946 - val_loss: 0.0250 - val_accuracy: 0.9913
# Epoch 80/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0267 - accuracy: 0.9920
# Epoch 00080: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0262 - accuracy: 0.9924 - val_loss: 0.0640 - val_accuracy: 0.9610
# Epoch 81/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0316 - accuracy: 0.9875
# Epoch 00081: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0303 - accuracy: 0.9881 - val_loss: 0.0291 - val_accuracy: 0.9913
# Epoch 82/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0171 - accuracy: 0.9944
# Epoch 00082: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0175 - accuracy: 0.9946 - val_loss: 0.0101 - val_accuracy: 1.0000
# Epoch 83/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0190 - accuracy: 0.9944
# Epoch 00083: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0191 - accuracy: 0.9946 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 84/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0205 - accuracy: 0.9943
# Epoch 00084: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0205 - accuracy: 0.9946 - val_loss: 0.0209 - val_accuracy: 0.9913
# Epoch 85/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0098 - accuracy: 0.9978
# Epoch 00085: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0104 - accuracy: 0.9967 - val_loss: 0.0244 - val_accuracy: 0.9913
# Epoch 86/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0265 - accuracy: 0.9912
# Epoch 00086: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0262 - accuracy: 0.9913 - val_loss: 0.0133 - val_accuracy: 0.9957
# Epoch 87/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 00087: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 88/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0428 - accuracy: 0.9857
# Epoch 00088: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0423 - accuracy: 0.9859 - val_loss: 0.0351 - val_accuracy: 0.9870
# Epoch 89/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0912 - accuracy: 0.9744
# Epoch 00089: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0892 - accuracy: 0.9750 - val_loss: 0.0595 - val_accuracy: 0.9697
# Epoch 90/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0265 - accuracy: 0.9923
# Epoch 00090: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0262 - accuracy: 0.9924 - val_loss: 0.0263 - val_accuracy: 0.9913
# Epoch 91/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0108 - accuracy: 0.9967
# Epoch 00091: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0107 - accuracy: 0.9967 - val_loss: 0.0176 - val_accuracy: 0.9957
# Epoch 92/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0143 - accuracy: 0.9954
# Epoch 00092: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0142 - accuracy: 0.9957 - val_loss: 0.0120 - val_accuracy: 1.0000
# Epoch 93/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0217 - accuracy: 0.9933
# Epoch 00093: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0210 - accuracy: 0.9935 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 94/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0147 - accuracy: 0.9946
# Epoch 00094: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0147 - accuracy: 0.9946 - val_loss: 0.0195 - val_accuracy: 0.9870
# Epoch 95/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0684 - accuracy: 0.9787
# Epoch 00095: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0678 - accuracy: 0.9794 - val_loss: 0.0347 - val_accuracy: 0.9913
# Epoch 96/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0438 - accuracy: 0.9870
# Epoch 00096: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0438 - accuracy: 0.9870 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 97/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0080 - accuracy: 0.9978
# Epoch 00097: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0089 - accuracy: 0.9967 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 98/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0331 - accuracy: 0.9901
# Epoch 00098: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0327 - accuracy: 0.9902 - val_loss: 0.0184 - val_accuracy: 0.9913
# Epoch 99/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0073 - accuracy: 0.9989
# Epoch 00099: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0071 - accuracy: 0.9989 - val_loss: 0.0202 - val_accuracy: 0.9957
# Epoch 100/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0462 - accuracy: 0.9851
# Epoch 00100: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0441 - accuracy: 0.9859 - val_loss: 0.0171 - val_accuracy: 0.9957
# Epoch 101/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 00101: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0133 - val_accuracy: 0.9957
# Epoch 102/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0304 - accuracy: 0.9848
# Epoch 00102: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0303 - accuracy: 0.9848 - val_loss: 0.1369 - val_accuracy: 0.9524
# Epoch 103/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0119 - accuracy: 0.9956
# Epoch 00103: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0116 - accuracy: 0.9957 - val_loss: 0.0351 - val_accuracy: 0.9740
# Epoch 104/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 00104: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0223 - val_accuracy: 0.9913
# Epoch 105/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 00105: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 106/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0067 - accuracy: 0.9977
# Epoch 00106: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0064 - accuracy: 0.9978 - val_loss: 0.3311 - val_accuracy: 0.9827
# Epoch 107/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0075 - accuracy: 0.9966
# Epoch 00107: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0071 - accuracy: 0.9967 - val_loss: 0.0084 - val_accuracy: 0.9957
# Epoch 108/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0419 - accuracy: 0.9890
# Epoch 00108: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0420 - accuracy: 0.9891 - val_loss: 0.0131 - val_accuracy: 0.9957
# Epoch 109/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0173 - accuracy: 0.9920
# Epoch 00109: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0166 - accuracy: 0.9924 - val_loss: 0.0232 - val_accuracy: 0.9913
# Epoch 110/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0157 - accuracy: 0.9920
# Epoch 00110: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0151 - accuracy: 0.9924 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 111/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0063 - accuracy: 0.9989
# Epoch 00111: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0062 - accuracy: 0.9989 - val_loss: 0.0083 - val_accuracy: 0.9957
# Epoch 112/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000
# Epoch 00112: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0140 - val_accuracy: 0.9957
# Epoch 113/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0164 - accuracy: 0.9954
# Epoch 00113: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0188 - accuracy: 0.9946 - val_loss: 0.0689 - val_accuracy: 0.9784
# Epoch 114/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0415 - accuracy: 0.9899
# Epoch 00114: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0438 - accuracy: 0.9891 - val_loss: 0.0151 - val_accuracy: 0.9957
# Epoch 115/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0224 - accuracy: 0.9922
# Epoch 00115: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0223 - accuracy: 0.9924 - val_loss: 0.0187 - val_accuracy: 0.9957
# Epoch 116/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.1016 - accuracy: 0.9689
# Epoch 00116: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.1010 - accuracy: 0.9685 - val_loss: 0.0326 - val_accuracy: 0.9957
# Epoch 117/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0355 - accuracy: 0.9852
# Epoch 00117: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0341 - accuracy: 0.9859 - val_loss: 0.0217 - val_accuracy: 0.9957
# Epoch 118/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0052 - accuracy: 0.9989
# Epoch 00118: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0051 - accuracy: 0.9989 - val_loss: 0.0582 - val_accuracy: 0.9870
# Epoch 119/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0297 - accuracy: 0.9908
# Epoch 00119: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0283 - accuracy: 0.9913 - val_loss: 0.0561 - val_accuracy: 0.9740
# Epoch 120/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 00120: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 121/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0037 - accuracy: 0.9989
# Epoch 00121: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 122/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0068 - accuracy: 0.9978
# Epoch 00122: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0068 - accuracy: 0.9978 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 123/250
# 880/921 [===========================>..] - ETA: 0s - loss: 8.2853e-04 - accuracy: 1.0000
# Epoch 00123: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 8.0497e-04 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 124/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0124 - accuracy: 0.9957
# Epoch 00124: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0124 - accuracy: 0.9957 - val_loss: 0.0243 - val_accuracy: 0.9913
# Epoch 125/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0199 - accuracy: 0.9908
# Epoch 00125: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0215 - accuracy: 0.9891 - val_loss: 0.0174 - val_accuracy: 0.9957
# Epoch 126/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0116 - accuracy: 0.9977
# Epoch 00126: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0144 - accuracy: 0.9967 - val_loss: 0.0451 - val_accuracy: 0.9913
# Epoch 127/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0343 - accuracy: 0.9868
# Epoch 00127: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0340 - accuracy: 0.9870 - val_loss: 0.0178 - val_accuracy: 0.9913
# Epoch 128/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0081 - accuracy: 0.9978
# Epoch 00128: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0080 - accuracy: 0.9978 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 129/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0195 - accuracy: 0.9901
# Epoch 00129: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0194 - accuracy: 0.9902 - val_loss: 0.0086 - val_accuracy: 0.9957
# Epoch 130/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0186 - accuracy: 0.9934
# Epoch 00130: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0184 - accuracy: 0.9935 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 131/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0572 - accuracy: 0.9826
# Epoch 00131: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0571 - accuracy: 0.9826 - val_loss: 0.0157 - val_accuracy: 0.9957
# Epoch 132/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0271 - accuracy: 0.9913
# Epoch 00132: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0271 - accuracy: 0.9913 - val_loss: 0.0200 - val_accuracy: 0.9957
# Epoch 133/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0578 - accuracy: 0.9793
# Epoch 00133: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0554 - accuracy: 0.9805 - val_loss: 0.0317 - val_accuracy: 0.9913
# Epoch 134/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0249 - accuracy: 0.9943
# Epoch 00134: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0240 - accuracy: 0.9946 - val_loss: 0.0163 - val_accuracy: 0.9957
# Epoch 135/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0294 - accuracy: 0.9922
# Epoch 00135: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0290 - accuracy: 0.9924 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 136/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0109 - accuracy: 0.9978
# Epoch 00136: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0128 - accuracy: 0.9967 - val_loss: 0.0113 - val_accuracy: 0.9957
# Epoch 137/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0266 - accuracy: 0.9875
# Epoch 00137: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0255 - accuracy: 0.9881 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 138/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 00138: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0163 - val_accuracy: 0.9957
# Epoch 139/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00139: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 0.9957
# Epoch 140/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 00140: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9957
# Epoch 141/250
# 920/921 [============================>.] - ETA: 0s - loss: 3.5242e-04 - accuracy: 1.0000
# Epoch 00141: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 3.5204e-04 - accuracy: 1.0000 - val_loss: 0.0115 - val_accuracy: 0.9957
# Epoch 142/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00142: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0165 - val_accuracy: 0.9957
# Epoch 143/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0228 - accuracy: 0.9913
# Epoch 00143: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0230 - accuracy: 0.9913 - val_loss: 0.0153 - val_accuracy: 0.9957
# Epoch 144/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0152 - accuracy: 0.9934
# Epoch 00144: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0151 - accuracy: 0.9935 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 145/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000
# Epoch 00145: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 146/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0049 - accuracy: 0.9989
# Epoch 00146: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0049 - accuracy: 0.9989 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 147/250
# 890/921 [===========================>..] - ETA: 0s - loss: 8.1714e-04 - accuracy: 1.0000
# Epoch 00147: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 7.9861e-04 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 148/250
# 910/921 [============================>.] - ETA: 0s - loss: 3.1680e-04 - accuracy: 1.0000
# Epoch 00148: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 3.1565e-04 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 149/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0052 - accuracy: 0.9967
# Epoch 00149: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0051 - accuracy: 0.9967 - val_loss: 0.0305 - val_accuracy: 0.9827
# Epoch 150/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.1976 - accuracy: 0.9529
# Epoch 00150: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.2001 - accuracy: 0.9511 - val_loss: 0.1683 - val_accuracy: 0.9221
# Epoch 151/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0849 - accuracy: 0.9596
# Epoch 00151: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0941 - accuracy: 0.9577 - val_loss: 0.0317 - val_accuracy: 0.9913
# Epoch 152/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0303 - accuracy: 0.9888
# Epoch 00152: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0308 - accuracy: 0.9881 - val_loss: 0.0125 - val_accuracy: 0.9957
# Epoch 153/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0097 - accuracy: 0.9955
# Epoch 00153: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0099 - accuracy: 0.9957 - val_loss: 0.0464 - val_accuracy: 0.9913
# Epoch 154/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0157 - accuracy: 0.9921
# Epoch 00154: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0152 - accuracy: 0.9924 - val_loss: 0.0081 - val_accuracy: 0.9957
# Epoch 155/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0163 - accuracy: 0.9977
# Epoch 00155: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0159 - accuracy: 0.9978 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 156/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0060 - accuracy: 0.9978
# Epoch 00156: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0059 - accuracy: 0.9978 - val_loss: 0.0207 - val_accuracy: 0.9957
# Epoch 157/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0494 - accuracy: 0.9879
# Epoch 00157: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0488 - accuracy: 0.9881 - val_loss: 0.0145 - val_accuracy: 0.9957
# Epoch 158/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0276 - accuracy: 0.9934
# Epoch 00158: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0273 - accuracy: 0.9935 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 159/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00159: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 160/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 00160: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 161/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0054 - accuracy: 0.9978
# Epoch 00161: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0053 - accuracy: 0.9978 - val_loss: 0.0101 - val_accuracy: 0.9957
# Epoch 162/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0055 - accuracy: 0.9989
# Epoch 00162: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0054 - accuracy: 0.9989 - val_loss: 0.0150 - val_accuracy: 0.9957
# Epoch 163/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0167 - accuracy: 0.9966
# Epoch 00163: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0161 - accuracy: 0.9967 - val_loss: 0.0132 - val_accuracy: 0.9957
# Epoch 164/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 00164: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9957
# Epoch 165/250
# 890/921 [===========================>..] - ETA: 0s - loss: 7.8629e-04 - accuracy: 1.0000
# Epoch 00165: val_accuracy did not improve from 1.00000
# ...
# 910/921 [============================>.] - ETA: 0s - loss: 7.0716e-04 - accuracy: 1.0000
# Epoch 00196: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 6.9888e-04 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 0.9957
# Epoch 197/250
# 880/921 [===========================>..] - ETA: 0s - loss: 2.6455e-04 - accuracy: 1.0000
# Epoch 00197: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 2.5350e-04 - accuracy: 1.0000 - val_loss: 7.6685e-04 - val_accuracy: 1.0000
# Epoch 198/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0320 - accuracy: 0.9891
# Epoch 00198: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0320 - accuracy: 0.9891 - val_loss: 0.0248 - val_accuracy: 0.9913
# Epoch 199/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0313 - accuracy: 0.9909
# Epoch 00199: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0346 - accuracy: 0.9891 - val_loss: 0.0800 - val_accuracy: 0.9740
# Epoch 200/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0264 - accuracy: 0.9934
# Epoch 00200: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0261 - accuracy: 0.9935 - val_loss: 0.0150 - val_accuracy: 0.9957
# Epoch 201/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 00201: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 0.9957
# Epoch 202/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 00202: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 0.9957
# Epoch 203/250
# 910/921 [============================>.] - ETA: 0s - loss: 7.2042e-04 - accuracy: 1.0000
# Epoch 00203: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 7.5690e-04 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9957
# Epoch 204/250
# 890/921 [===========================>..] - ETA: 0s - loss: 4.2137e-04 - accuracy: 1.0000
# Epoch 00204: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 4.0910e-04 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 0.9957
# Epoch 205/250
# 900/921 [============================>.] - ETA: 0s - loss: 2.2173e-04 - accuracy: 1.0000
# Epoch 00205: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 2.2259e-04 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 206/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00206: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 207/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0032 - accuracy: 0.9989
# Epoch 00207: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0073 - accuracy: 0.9978 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 208/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0254 - accuracy: 0.9900
# Epoch 00208: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0323 - accuracy: 0.9891 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 209/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0293 - accuracy: 0.9824
# Epoch 00209: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0290 - accuracy: 0.9826 - val_loss: 0.0115 - val_accuracy: 0.9913
# Epoch 210/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0189 - accuracy: 0.9943
# Epoch 00210: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0181 - accuracy: 0.9946 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 211/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0085 - accuracy: 0.9978
# Epoch 00211: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0083 - accuracy: 0.9978 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 212/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0530 - accuracy: 0.9854
# Epoch 00212: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0512 - accuracy: 0.9859 - val_loss: 0.0361 - val_accuracy: 0.9870
# Epoch 213/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0283 - accuracy: 0.9921
# Epoch 00213: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0274 - accuracy: 0.9924 - val_loss: 0.0080 - val_accuracy: 0.9957
# Epoch 214/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0089 - accuracy: 0.9966
# Epoch 00214: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0084 - accuracy: 0.9967 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 215/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00215: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 216/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00216: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 217/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9989
# Epoch 00217: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0013 - accuracy: 0.9989 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 218/250
# 870/921 [===========================>..] - ETA: 0s - loss: 4.7272e-04 - accuracy: 1.0000
# Epoch 00218: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 4.5025e-04 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 219/250
# 890/921 [===========================>..] - ETA: 0s - loss: 2.7266e-04 - accuracy: 1.0000
# Epoch 00219: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 2.6617e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 220/250
# 920/921 [============================>.] - ETA: 0s - loss: 3.9028e-04 - accuracy: 1.0000
# Epoch 00220: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 3.8985e-04 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 221/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0022 - accuracy: 0.9989
# Epoch 00221: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0022 - accuracy: 0.9989 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 222/250
# 910/921 [============================>.] - ETA: 0s - loss: 4.3289e-04 - accuracy: 1.0000
# Epoch 00222: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 4.3358e-04 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 223/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00223: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0142 - val_accuracy: 0.9957
# Epoch 224/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0338 - accuracy: 0.9844
# Epoch 00224: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0330 - accuracy: 0.9848 - val_loss: 0.0198 - val_accuracy: 0.9913
# Epoch 225/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0186 - accuracy: 0.9920
# Epoch 00225: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0178 - accuracy: 0.9924 - val_loss: 0.0424 - val_accuracy: 0.9784
# Epoch 226/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0052 - accuracy: 0.9989
# Epoch 00226: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0050 - accuracy: 0.9989 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 227/250
# 890/921 [===========================>..] - ETA: 0s - loss: 4.6066e-04 - accuracy: 1.0000
# Epoch 00227: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 4.4641e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 228/250
# 880/921 [===========================>..] - ETA: 0s - loss: 2.5373e-04 - accuracy: 1.0000
# Epoch 00228: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 2.4792e-04 - accuracy: 1.0000 - val_loss: 9.6446e-04 - val_accuracy: 1.0000
# Epoch 229/250
# 910/921 [============================>.] - ETA: 0s - loss: 3.4147e-04 - accuracy: 1.0000
# Epoch 00229: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 3.3739e-04 - accuracy: 1.0000 - val_loss: 7.7651e-04 - val_accuracy: 1.0000
# Epoch 230/250
# 910/921 [============================>.] - ETA: 0s - loss: 1.5370e-04 - accuracy: 1.0000
# Epoch 00230: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 1.5186e-04 - accuracy: 1.0000 - val_loss: 7.1417e-04 - val_accuracy: 1.0000
# Epoch 231/250
# 880/921 [===========================>..] - ETA: 0s - loss: 1.8477e-04 - accuracy: 1.0000
# Epoch 00231: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 5.0844e-04 - accuracy: 1.0000 - val_loss: 6.7513e-04 - val_accuracy: 1.0000
# Epoch 232/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0987 - accuracy: 0.9670
# Epoch 00232: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0976 - accuracy: 0.9674 - val_loss: 0.0409 - val_accuracy: 0.9913
# Epoch 233/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0203 - accuracy: 0.9931
# Epoch 00233: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0192 - accuracy: 0.9935 - val_loss: 0.0374 - val_accuracy: 0.9957
# Epoch 234/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0055 - accuracy: 0.9967
# Epoch 00234: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0055 - accuracy: 0.9967 - val_loss: 0.0080 - val_accuracy: 0.9957
# Epoch 235/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 00235: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 236/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0263 - accuracy: 0.9909
# Epoch 00236: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0252 - accuracy: 0.9913 - val_loss: 0.0163 - val_accuracy: 0.9913
# Epoch 237/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0167 - accuracy: 0.9933
# Epoch 00237: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0165 - accuracy: 0.9935 - val_loss: 0.0079 - val_accuracy: 0.9957
# Epoch 238/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0056 - accuracy: 0.9989
# Epoch 00238: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0055 - accuracy: 0.9989 - val_loss: 0.0059 - val_accuracy: 0.9957
# Epoch 239/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0031 - accuracy: 0.9989
# Epoch 00239: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 240/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0040 - accuracy: 0.9989
# Epoch 00240: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 241/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00241: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 242/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 00242: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0017 - accuracy: 1.0000 - val_loss: 9.2395e-04 - val_accuracy: 1.0000
# Epoch 243/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 00243: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 9.8249e-04 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 0.9957
# Epoch 244/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9989
# Epoch 00244: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0012 - accuracy: 0.9989 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 245/250
# 900/921 [============================>.] - ETA: 0s - loss: 9.5273e-04 - accuracy: 1.0000
# Epoch 00245: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 9.3806e-04 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 0.9957
# Epoch 246/250
# 890/921 [===========================>..] - ETA: 0s - loss: 1.5323e-04 - accuracy: 1.0000
# Epoch 00246: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 1.6985e-04 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 0.9957
# Epoch 247/250
# 890/921 [===========================>..] - ETA: 0s - loss: 4.6572e-04 - accuracy: 1.0000
# Epoch 00247: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 4.5007e-04 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 0.9957
# Epoch 248/250
# 880/921 [===========================>..] - ETA: 0s - loss: 8.0887e-05 - accuracy: 1.0000
# Epoch 00248: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 9.9630e-05 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 0.9957
# Epoch 249/250
# 890/921 [===========================>..] - ETA: 0s - loss: 9.9414e-04 - accuracy: 1.0000
# Epoch 00249: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 9.6878e-04 - accuracy: 1.0000 - val_loss: 0.0136 - val_accuracy: 0.9957
# Epoch 250/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0125 - accuracy: 0.9943
# Epoch 00250: val_accuracy did not improve from 1.00000
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0119 - accuracy: 0.9946 - val_loss: 0.0012 - val_accuracy: 1.0000
# Training completed in time:  0:04:20.829516

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste
#
# Lembrando que estamos utilizando o mesmo conjunto de validacão, que a princípio, pode incluir instâncias do conjunto de treinamento: o dataset utilizado foi gerado com corte de áudio, então alguns trechos do mesmo áudio podem estar presentes em ambos os conjuntos de treinamento e teste.
# Por ora deixamos assim já que estamos realizando uma investigacão inicial.

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  1.0
# Testing Accuracy:  1.0

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       1.00      1.00      1.00       112
#    Pneumonia       1.00      1.00      1.00       119
#
#     accuracy                           1.00       231
#    macro avg       1.00      1.00      1.00       231
# weighted avg       1.00      1.00      1.00       231

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[112   0]
#  [  0 119]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])
