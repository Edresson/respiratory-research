# %% [markdown]
# # Rede MLP - Modelo 1
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - slide5

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP = 'slide5'
MAX_PAD_LEN = 216

# %%
filepaths = glob.glob(f'./datasets/{GROUP}/**/*.wav', recursive=True)
filenames = [os.path.splitext(os.path.basename(p))[0] for p in filepaths]

# %%
p_id_in_file = [] # patient IDs corresponding to each file
for name in filenames:
    p_id_in_file.append(int(name[:3]))

p_id_in_file = np.array(p_id_in_file)

# %%
max_pad_len =  MAX_PAD_LEN

os.makedirs("./Respiratory_Sound_Database/features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
    if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
        return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=5) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./Respiratory_Sound_Database/features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
p_diag = pd.read_csv("./Respiratory_Sound_Database/Respiratory_Sound_Database/patient_diagnosis.csv",header=None) # patient diagnosis file

# %%
labels = np.array([p_diag[p_diag[0] == x][1].values[0] for x in p_id_in_file]) # labels for audio files

# %%
features = [] 

# Iterate through each sound file and extract the features
for file_name in filepaths:
    data = extract_features(file_name)
    features.append(data)

print('Finished feature extraction from ', len(features), ' files')
features = np.array(features)
# Out:
# Finished feature extraction from  576  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
features = np.array(features) # convert to numpy array

# %%
np.unique(labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
# delete diseases
'''
features1 = features
labels1 = labels'''

features1 = np.delete(features, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0) 

labels1 = np.delete(labels, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0)

# %%
# print class counts
unique_elements, counts_elements = np.unique(labels1, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['280' '296']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(labels1)
oh_labels = to_categorical(i_labels)

# %%
features1.shape
# Out:
# (576, 40, 216)

# %%
input_dim = features1.shape[1]*features1.shape[2]
features1 = np.reshape(features1, (features1.shape[0], input_dim))
print(features1.shape, labels1.shape)
# Out:
# (576, 8640) (576,)

# %%
# train test split
x_train, x_test, y_train, y_test = train_test_split(features1, oh_labels, stratify=oh_labels, 
                                                    test_size=0.2, random_state = 42)

# %% [markdown]
# **MLP model architecture**

# %%
num_labels = oh_labels.shape[1]
# Construct model 
model = Sequential()
model.add(Dense(500, input_dim=input_dim, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 500)               4320500
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_2 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_3 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_4 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_5 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_6 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_7 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 1002
# =================================================================
# Total params: 6,075,002
# Trainable params: 6,075,002
# Non-trainable params: 0
# _________________________________________________________________
# 116/116 [==============================] - 1s 6ms/sample - loss: 4.6381 - accuracy: 0.5172
# Pre-training accuracy: 51.7241%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 250
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/model2_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 460 samples, validate on 116 samples
# Epoch 1/250
# 440/460 [===========================>..] - ETA: 0s - loss: 11.8968 - accuracy: 0.5091
# Epoch 00001: val_accuracy improved from -inf to 0.48276, saving model to models/model2_01.h5
# 460/460 [==============================] - 1s 2ms/sample - loss: 11.4123 - accuracy: 0.5130 - val_loss: 0.8219 - val_accuracy: 0.4828
# Epoch 2/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.8624 - accuracy: 0.4789
# Epoch 00002: val_accuracy improved from 0.48276 to 0.83621, saving model to models/model2_02.h5
# 460/460 [==============================] - 1s 2ms/sample - loss: 0.8533 - accuracy: 0.4696 - val_loss: 0.6325 - val_accuracy: 0.8362
# Epoch 3/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.7381 - accuracy: 0.5923
# Epoch 00003: val_accuracy did not improve from 0.83621
# 460/460 [==============================] - 0s 629us/sample - loss: 0.7077 - accuracy: 0.6174 - val_loss: 0.4051 - val_accuracy: 0.8362
# Epoch 4/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.4440 - accuracy: 0.7727
# Epoch 00004: val_accuracy improved from 0.83621 to 0.87931, saving model to models/model2_04.h5
# 460/460 [==============================] - 0s 794us/sample - loss: 0.4439 - accuracy: 0.7739 - val_loss: 0.2681 - val_accuracy: 0.8793
# Epoch 5/250
# 360/460 [======================>.......] - ETA: 0s - loss: 0.4263 - accuracy: 0.8306
# Epoch 00005: val_accuracy improved from 0.87931 to 0.88793, saving model to models/model2_05.h5
# 460/460 [==============================] - 0s 1000us/sample - loss: 0.4048 - accuracy: 0.8326 - val_loss: 0.2386 - val_accuracy: 0.8879
# Epoch 6/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.3637 - accuracy: 0.8415
# Epoch 00006: val_accuracy improved from 0.88793 to 0.89655, saving model to models/model2_06.h5
# 460/460 [==============================] - 1s 2ms/sample - loss: 0.3490 - accuracy: 0.8457 - val_loss: 0.2196 - val_accuracy: 0.8966
# Epoch 7/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.4356 - accuracy: 0.8500
# Epoch 00007: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 0s 588us/sample - loss: 0.4178 - accuracy: 0.8500 - val_loss: 0.2033 - val_accuracy: 0.8966
# Epoch 8/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.3279 - accuracy: 0.8500
# Epoch 00008: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 0s 598us/sample - loss: 0.3222 - accuracy: 0.8587 - val_loss: 0.2237 - val_accuracy: 0.8793
# Epoch 9/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.3362 - accuracy: 0.8667
# Epoch 00009: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 0s 589us/sample - loss: 0.3465 - accuracy: 0.8587 - val_loss: 0.5201 - val_accuracy: 0.7241
# Epoch 10/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.2747 - accuracy: 0.8953
# Epoch 00010: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 0s 603us/sample - loss: 0.2589 - accuracy: 0.9000 - val_loss: 1.9135 - val_accuracy: 0.7500
# Epoch 11/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.9174 - accuracy: 0.7857
# Epoch 00011: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 0s 584us/sample - loss: 0.8898 - accuracy: 0.7739 - val_loss: 0.5162 - val_accuracy: 0.7328
# Epoch 12/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.4549 - accuracy: 0.8643
# Epoch 00012: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 0s 583us/sample - loss: 0.4313 - accuracy: 0.8717 - val_loss: 0.2999 - val_accuracy: 0.8966
# Epoch 13/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.2688 - accuracy: 0.9073
# Epoch 00013: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 0s 594us/sample - loss: 0.2737 - accuracy: 0.9065 - val_loss: 1.0726 - val_accuracy: 0.7500
# Epoch 14/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.3925 - accuracy: 0.7190
# Epoch 00014: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 0s 587us/sample - loss: 0.4163 - accuracy: 0.7152 - val_loss: 0.6629 - val_accuracy: 0.5603
# Epoch 15/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.6017 - accuracy: 0.6689
# Epoch 00015: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 0s 565us/sample - loss: 0.6039 - accuracy: 0.6652 - val_loss: 0.6949 - val_accuracy: 0.5345
# Epoch 16/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.6631 - accuracy: 0.5500
# Epoch 00016: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 0s 557us/sample - loss: 0.6593 - accuracy: 0.5630 - val_loss: 0.5665 - val_accuracy: 0.6810
# Epoch 17/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.8549 - accuracy: 0.5595
# Epoch 00017: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 0s 574us/sample - loss: 0.8417 - accuracy: 0.5478 - val_loss: 0.6770 - val_accuracy: 0.5603
# Epoch 18/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.6193 - accuracy: 0.6182
# Epoch 00018: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 0s 553us/sample - loss: 0.6099 - accuracy: 0.6348 - val_loss: 1.1840 - val_accuracy: 0.8534
# Epoch 19/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.5691 - accuracy: 0.6886
# Epoch 00019: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 0s 557us/sample - loss: 0.5740 - accuracy: 0.6804 - val_loss: 0.5157 - val_accuracy: 0.7414
# Epoch 20/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.5417 - accuracy: 0.7289
# Epoch 00020: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 0s 536us/sample - loss: 0.5382 - accuracy: 0.7326 - val_loss: 0.4642 - val_accuracy: 0.8966
# Epoch 21/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.3290 - accuracy: 0.8978
# Epoch 00021: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 0s 547us/sample - loss: 0.3237 - accuracy: 0.9000 - val_loss: 0.4507 - val_accuracy: 0.8448
# Epoch 22/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.3068 - accuracy: 0.8805
# Epoch 00022: val_accuracy did not improve from 0.89655
# 460/460 [==============================] - 0s 568us/sample - loss: 0.2834 - accuracy: 0.8913 - val_loss: 0.3088 - val_accuracy: 0.8793
# Epoch 23/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2585 - accuracy: 0.9119
# Epoch 00023: val_accuracy improved from 0.89655 to 0.91379, saving model to models/model2_23.h5
# 460/460 [==============================] - 0s 815us/sample - loss: 0.2734 - accuracy: 0.9065 - val_loss: 0.2716 - val_accuracy: 0.9138
# Epoch 24/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.3053 - accuracy: 0.8512
# Epoch 00024: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 569us/sample - loss: 0.3757 - accuracy: 0.8348 - val_loss: 0.2593 - val_accuracy: 0.8966
# Epoch 25/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.2500 - accuracy: 0.9067
# Epoch 00025: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 537us/sample - loss: 0.2527 - accuracy: 0.9065 - val_loss: 0.5282 - val_accuracy: 0.8276
# Epoch 26/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.3102 - accuracy: 0.8769
# Epoch 00026: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 607us/sample - loss: 0.3352 - accuracy: 0.8674 - val_loss: 0.3054 - val_accuracy: 0.8793
# Epoch 27/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.3309 - accuracy: 0.8822
# Epoch 00027: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 545us/sample - loss: 0.3258 - accuracy: 0.8848 - val_loss: 0.3042 - val_accuracy: 0.8879
# Epoch 28/250
# 350/460 [=====================>........] - ETA: 0s - loss: 0.2069 - accuracy: 0.9257
# Epoch 00028: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 544us/sample - loss: 0.2119 - accuracy: 0.9283 - val_loss: 0.2967 - val_accuracy: 0.8879
# Epoch 29/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.1329 - accuracy: 0.9649
# Epoch 00029: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 643us/sample - loss: 0.2065 - accuracy: 0.9348 - val_loss: 0.7789 - val_accuracy: 0.7328
# Epoch 30/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.2977 - accuracy: 0.8860
# Epoch 00030: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 547us/sample - loss: 0.2934 - accuracy: 0.8913 - val_loss: 0.2784 - val_accuracy: 0.8966
# Epoch 31/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.4438 - accuracy: 0.8326
# Epoch 00031: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 557us/sample - loss: 0.4467 - accuracy: 0.8283 - val_loss: 0.3922 - val_accuracy: 0.8707
# Epoch 32/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.2236 - accuracy: 0.9175
# Epoch 00032: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 608us/sample - loss: 0.2080 - accuracy: 0.9217 - val_loss: 0.3180 - val_accuracy: 0.8966
# Epoch 33/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1711 - accuracy: 0.9524
# Epoch 00033: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 573us/sample - loss: 0.1642 - accuracy: 0.9543 - val_loss: 0.4974 - val_accuracy: 0.8621
# Epoch 34/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1178 - accuracy: 0.9535
# Epoch 00034: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 563us/sample - loss: 0.1130 - accuracy: 0.9565 - val_loss: 0.2829 - val_accuracy: 0.8966
# Epoch 35/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1824 - accuracy: 0.9372
# Epoch 00035: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 568us/sample - loss: 0.1817 - accuracy: 0.9348 - val_loss: 0.3174 - val_accuracy: 0.8879
# Epoch 36/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0613 - accuracy: 0.9818
# Epoch 00036: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 559us/sample - loss: 0.0595 - accuracy: 0.9826 - val_loss: 0.3201 - val_accuracy: 0.8966
# Epoch 37/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.2236 - accuracy: 0.9395
# Epoch 00037: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 569us/sample - loss: 0.2214 - accuracy: 0.9391 - val_loss: 0.2311 - val_accuracy: 0.8793
# Epoch 38/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2302 - accuracy: 0.9095
# Epoch 00038: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 583us/sample - loss: 0.2111 - accuracy: 0.9174 - val_loss: 0.2641 - val_accuracy: 0.9052
# Epoch 39/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0910 - accuracy: 0.9833
# Epoch 00039: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 583us/sample - loss: 0.0898 - accuracy: 0.9848 - val_loss: 0.3118 - val_accuracy: 0.8966
# Epoch 40/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0927 - accuracy: 0.9833
# Epoch 00040: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 577us/sample - loss: 0.1395 - accuracy: 0.9696 - val_loss: 1.1893 - val_accuracy: 0.5862
# Epoch 41/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.5443 - accuracy: 0.8395
# Epoch 00041: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 571us/sample - loss: 0.5266 - accuracy: 0.8435 - val_loss: 0.2966 - val_accuracy: 0.9138
# Epoch 42/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0802 - accuracy: 0.9818
# Epoch 00042: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 559us/sample - loss: 0.0769 - accuracy: 0.9826 - val_loss: 0.2460 - val_accuracy: 0.9052
# Epoch 43/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0603 - accuracy: 0.9854
# Epoch 00043: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 582us/sample - loss: 0.0767 - accuracy: 0.9783 - val_loss: 0.4125 - val_accuracy: 0.8879
# Epoch 44/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1207 - accuracy: 0.9690
# Epoch 00044: val_accuracy improved from 0.91379 to 0.93103, saving model to models/model2_44.h5
# 460/460 [==============================] - 0s 868us/sample - loss: 0.1115 - accuracy: 0.9717 - val_loss: 0.2099 - val_accuracy: 0.9310
# Epoch 45/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 00045: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 571us/sample - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.2946 - val_accuracy: 0.9052
# Epoch 46/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0155 - accuracy: 0.9977
# Epoch 00046: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 581us/sample - loss: 0.0146 - accuracy: 0.9978 - val_loss: 0.3575 - val_accuracy: 0.9138
# Epoch 47/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 00047: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 575us/sample - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3489 - val_accuracy: 0.9310
# Epoch 48/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1838 - accuracy: 0.9732
# Epoch 00048: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 592us/sample - loss: 0.1784 - accuracy: 0.9696 - val_loss: 0.2256 - val_accuracy: 0.9224
# Epoch 49/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1299 - accuracy: 0.9619
# Epoch 00049: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s
val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 622us/sample - loss: 3.2444e-07 - accuracy: 1.0000 - val_loss: 0.8434 - val_accuracy: 0.9138
# Epoch 116/250
# 380/460 [=======================>......] - ETA: 0s - loss: 3.7832e-07 - accuracy: 1.0000
# Epoch 00116: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 640us/sample - loss: 3.1252e-07 - accuracy: 1.0000 - val_loss: 0.8442 - val_accuracy: 0.9138
# Epoch 117/250
# 400/460 [=========================>....] - ETA: 0s - loss: 2.8758e-07 - accuracy: 1.0000
# Epoch 00117: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 643us/sample - loss: 2.7287e-07 - accuracy: 1.0000 - val_loss: 0.8465 - val_accuracy: 0.9138
# Epoch 118/250
# 410/460 [=========================>....] - ETA: 0s - loss: 2.7621e-07 - accuracy: 1.0000
# Epoch 00118: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 587us/sample - loss: 2.6018e-07 - accuracy: 1.0000 - val_loss: 0.8567 - val_accuracy: 0.9138
# Epoch 119/250
# 410/460 [=========================>....] - ETA: 0s - loss: 2.7708e-07 - accuracy: 1.0000
# Epoch 00119: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 581us/sample - loss: 2.4696e-07 - accuracy: 1.0000 - val_loss: 0.8589 - val_accuracy: 0.9138
# Epoch 120/250
# 390/460 [========================>.....] - ETA: 0s - loss: 2.5278e-07 - accuracy: 1.0000
# Epoch 00120: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 637us/sample - loss: 2.2208e-07 - accuracy: 1.0000 - val_loss: 0.8601 - val_accuracy: 0.9138
# Epoch 121/250
# 400/460 [=========================>....] - ETA: 0s - loss: 2.2500e-07 - accuracy: 1.0000
# Epoch 00121: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 624us/sample - loss: 2.0731e-07 - accuracy: 1.0000 - val_loss: 0.8643 - val_accuracy: 0.9138
# Epoch 122/250
# 400/460 [=========================>....] - ETA: 0s - loss: 2.3275e-07 - accuracy: 1.0000
# Epoch 00122: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 658us/sample - loss: 2.0239e-07 - accuracy: 1.0000 - val_loss: 0.8719 - val_accuracy: 0.9138
# Epoch 123/250
# 390/460 [========================>.....] - ETA: 0s - loss: 2.3260e-07 - accuracy: 1.0000
# Epoch 00123: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 626us/sample - loss: 1.9721e-07 - accuracy: 1.0000 - val_loss: 0.8751 - val_accuracy: 0.9138
# Epoch 124/250
# 380/460 [=======================>......] - ETA: 0s - loss: 4.3292e-08 - accuracy: 1.0000
# Epoch 00124: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 646us/sample - loss: 1.8140e-07 - accuracy: 1.0000 - val_loss: 0.8747 - val_accuracy: 0.9138
# Epoch 125/250
# 400/460 [=========================>....] - ETA: 0s - loss: 3.5763e-08 - accuracy: 1.0000
# Epoch 00125: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 623us/sample - loss: 1.6637e-07 - accuracy: 1.0000 - val_loss: 0.8776 - val_accuracy: 0.9138
# Epoch 126/250
# 400/460 [=========================>....] - ETA: 0s - loss: 3.6359e-08 - accuracy: 1.0000
# Epoch 00126: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 616us/sample - loss: 1.6352e-07 - accuracy: 1.0000 - val_loss: 0.8810 - val_accuracy: 0.9138
# Epoch 127/250
# 400/460 [=========================>....] - ETA: 0s - loss: 1.7434e-07 - accuracy: 1.0000
# Epoch 00127: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 628us/sample - loss: 1.5160e-07 - accuracy: 1.0000 - val_loss: 0.8808 - val_accuracy: 0.9138
# Epoch 128/250
# 390/460 [========================>.....] - ETA: 0s - loss: 2.9344e-08 - accuracy: 1.0000
# Epoch 00128: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 656us/sample - loss: 1.5678e-07 - accuracy: 1.0000 - val_loss: 0.8910 - val_accuracy: 0.9138
# Epoch 129/250
# 390/460 [========================>.....] - ETA: 0s - loss: 2.5370e-08 - accuracy: 1.0000
# Epoch 00129: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 641us/sample - loss: 1.5445e-07 - accuracy: 1.0000 - val_loss: 0.8973 - val_accuracy: 0.9138
# Epoch 130/250
# 400/460 [=========================>....] - ETA: 0s - loss: 3.4869e-08 - accuracy: 1.0000
# Epoch 00130: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 633us/sample - loss: 1.4383e-07 - accuracy: 1.0000 - val_loss: 0.8972 - val_accuracy: 0.9138
# Epoch 131/250
# 390/460 [========================>.....] - ETA: 0s - loss: 1.4488e-07 - accuracy: 1.0000
# Epoch 00131: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 637us/sample - loss: 1.3242e-07 - accuracy: 1.0000 - val_loss: 0.8985 - val_accuracy: 0.9138
# Epoch 132/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.3307e-07 - accuracy: 1.0000
# Epoch 00132: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 598us/sample - loss: 1.2465e-07 - accuracy: 1.0000 - val_loss: 0.9008 - val_accuracy: 0.9138
# Epoch 133/250
# 400/460 [=========================>....] - ETA: 0s - loss: 1.4245e-07 - accuracy: 1.0000
# Epoch 00133: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 600us/sample - loss: 1.2387e-07 - accuracy: 1.0000 - val_loss: 0.9066 - val_accuracy: 0.9138
# Epoch 134/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.2143e-07 - accuracy: 1.0000
# Epoch 00134: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 558us/sample - loss: 1.1351e-07 - accuracy: 1.0000 - val_loss: 0.9071 - val_accuracy: 0.9138
# Epoch 135/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.1366e-07 - accuracy: 1.0000
# Epoch 00135: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 572us/sample - loss: 1.0625e-07 - accuracy: 1.0000 - val_loss: 0.9079 - val_accuracy: 0.9138
# Epoch 136/250
# 410/460 [=========================>....] - ETA: 0s - loss: 1.1717e-07 - accuracy: 1.0000
# Epoch 00136: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 602us/sample - loss: 1.0470e-07 - accuracy: 1.0000 - val_loss: 0.9170 - val_accuracy: 0.9138
# Epoch 137/250
# 400/460 [=========================>....] - ETA: 0s - loss: 2.5034e-08 - accuracy: 1.0000
# Epoch 00137: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 594us/sample - loss: 1.0418e-07 - accuracy: 1.0000 - val_loss: 0.9165 - val_accuracy: 0.9138
# Epoch 138/250
# 420/460 [==========================>...] - ETA: 0s - loss: 1.0530e-07 - accuracy: 1.0000
# Epoch 00138: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 581us/sample - loss: 9.6143e-08 - accuracy: 1.0000 - val_loss: 0.9166 - val_accuracy: 0.9138
# Epoch 139/250
# 410/460 [=========================>....] - ETA: 0s - loss: 1.0438e-07 - accuracy: 1.0000
# Epoch 00139: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 585us/sample - loss: 9.3034e-08 - accuracy: 1.0000 - val_loss: 0.9232 - val_accuracy: 0.9138
# Epoch 140/250
# 420/460 [==========================>...] - ETA: 0s - loss: 9.9624e-08 - accuracy: 1.0000
# Epoch 00140: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s
val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 573us/sample - loss: 1.2958e-08 - accuracy: 1.0000 - val_loss: 1.0629 - val_accuracy: 0.9138
# Epoch 199/250
# 440/460 [===========================>..] - ETA: 0s - loss: 1.1921e-08 - accuracy: 1.0000
# Epoch 00199: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 549us/sample - loss: 1.2439e-08 - accuracy: 1.0000 - val_loss: 1.0632 - val_accuracy: 0.9138
# Epoch 200/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.2475e-08 - accuracy: 1.0000
# Epoch 00200: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 562us/sample - loss: 1.1662e-08 - accuracy: 1.0000 - val_loss: 1.0604 - val_accuracy: 0.9138
# Epoch 201/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.3307e-08 - accuracy: 1.0000
# Epoch 00201: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 557us/sample - loss: 1.2439e-08 - accuracy: 1.0000 - val_loss: 1.0710 - val_accuracy: 0.9138
# Epoch 202/250
# 410/460 [=========================>....] - ETA: 0s - loss: 1.2212e-08 - accuracy: 1.0000
# Epoch 00202: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 584us/sample - loss: 1.1921e-08 - accuracy: 1.0000 - val_loss: 1.0745 - val_accuracy: 0.9138
# Epoch 203/250
# 410/460 [=========================>....] - ETA: 0s - loss: 1.2502e-08 - accuracy: 1.0000
# Epoch 00203: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 590us/sample - loss: 1.1143e-08 - accuracy: 1.0000 - val_loss: 1.0722 - val_accuracy: 0.9138
# Epoch 204/250
# 410/460 [=========================>....] - ETA: 0s - loss: 1.1921e-08 - accuracy: 1.0000
# Epoch 00204: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 597us/sample - loss: 1.0625e-08 - accuracy: 1.0000 - val_loss: 1.0700 - val_accuracy: 0.9138
# Epoch 205/250
# 420/460 [==========================>...] - ETA: 0s - loss: 1.2205e-08 - accuracy: 1.0000
# Epoch 00205: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 606us/sample - loss: 1.1143e-08 - accuracy: 1.0000 - val_loss: 1.0840 - val_accuracy: 0.9138
# Epoch 206/250
# 410/460 [=========================>....] - ETA: 0s - loss: 1.1630e-08 - accuracy: 1.0000
# Epoch 00206: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 596us/sample - loss: 1.0884e-08 - accuracy: 1.0000 - val_loss: 1.0828 - val_accuracy: 0.9138
# Epoch 207/250
# 420/460 [==========================>...] - ETA: 0s - loss: 2.2707e-09 - accuracy: 1.0000
# Epoch 00207: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 576us/sample - loss: 1.0107e-08 - accuracy: 1.0000 - val_loss: 1.0806 - val_accuracy: 0.9138
# Epoch 208/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.0535e-08 - accuracy: 1.0000
# Epoch 00208: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 560us/sample - loss: 9.8477e-09 - accuracy: 1.0000 - val_loss: 1.0803 - val_accuracy: 0.9138
# Epoch 209/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.9406e-09 - accuracy: 1.0000
# Epoch 00209: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 573us/sample - loss: 9.5886e-09 - accuracy: 1.0000 - val_loss: 1.0790 - val_accuracy: 0.9138
# Epoch 210/250
# 430/460 [===========================>..] - ETA: 0s - loss: 9.9803e-09 - accuracy: 1.0000
# Epoch 00210: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 568us/sample - loss: 9.3294e-09 - accuracy: 1.0000 - val_loss: 1.0884 - val_accuracy: 0.9138
# Epoch 211/250
# 410/460 [=========================>....] - ETA: 0s - loss: 2.3260e-09 - accuracy: 1.0000
# Epoch 00211: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 584us/sample - loss: 9.0703e-09 - accuracy: 1.0000 - val_loss: 1.0839 - val_accuracy: 0.9138
# Epoch 212/250
# 420/460 [==========================>...] - ETA: 0s - loss: 9.3664e-09 - accuracy: 1.0000
# Epoch 00212: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 590us/sample - loss: 8.5520e-09 - accuracy: 1.0000 - val_loss: 1.0904 - val_accuracy: 0.9138
# Epoch 213/250
# 440/460 [===========================>..] - ETA: 0s - loss: 8.9407e-09 - accuracy: 1.0000
# Epoch 00213: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 557us/sample - loss: 8.5520e-09 - accuracy: 1.0000 - val_loss: 1.0926 - val_accuracy: 0.9138
# Epoch 214/250
# 440/460 [===========================>..] - ETA: 0s - loss: 8.3988e-09 - accuracy: 1.0000
# Epoch 00214: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 559us/sample - loss: 8.0337e-09 - accuracy: 1.0000 - val_loss: 1.0912 - val_accuracy: 0.9138
# Epoch 215/250
# 430/460 [===========================>..] - ETA: 0s - loss: 8.0397e-09 - accuracy: 1.0000
# Epoch 00215: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 571us/sample - loss: 7.5154e-09 - accuracy: 1.0000 - val_loss: 1.0897 - val_accuracy: 0.9138
# Epoch 216/250
# 340/460 [=====================>........] - ETA: 0s - loss: 1.0518e-08 - accuracy: 1.0000
# Epoch 00216: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 542us/sample - loss: 7.7745e-09 - accuracy: 1.0000 - val_loss: 1.1006 - val_accuracy: 0.9138
# Epoch 217/250
# 430/460 [===========================>..] - ETA: 0s - loss: 7.7625e-09 - accuracy: 1.0000
# Epoch 00217: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 565us/sample - loss: 7.5154e-09 - accuracy: 1.0000 - val_loss: 1.0984 - val_accuracy: 0.9138
# Epoch 218/250
# 430/460 [===========================>..] - ETA: 0s - loss: 7.7625e-09 - accuracy: 1.0000
# Epoch 00218: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 565us/sample - loss: 7.2562e-09 - accuracy: 1.0000 - val_loss: 1.0990 - val_accuracy: 0.9138
# Epoch 219/250
# 420/460 [==========================>...] - ETA: 0s - loss: 7.6634e-09 - accuracy: 1.0000
# Epoch 00219: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 564us/sample - loss: 6.9971e-09 - accuracy: 1.0000 - val_loss: 1.1017 - val_accuracy: 0.9138
# Epoch 220/250
# 420/460 [==========================>...] - ETA: 0s - loss: 7.0958e-09 - accuracy: 1.0000
# Epoch 00220: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 591us/sample - loss: 6.9971e-09 - accuracy: 1.0000 - val_loss: 1.1047 - val_accuracy: 0.9138
# Epoch 221/250
# 430/460 [===========================>..] - ETA: 0s - loss: 6.6535e-09 - accuracy: 1.0000
# Epoch 00221: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 566us/sample - loss: 6.7379e-09 - accuracy: 1.0000 - val_loss: 1.1022 - val_accuracy: 0.9138
# Epoch 222/250
# 420/460 [==========================>...] - ETA: 0s - loss: 6.5281e-09 - accuracy: 1.0000
# Epoch 00222: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 570us/sample - loss: 6.4788e-09 - accuracy: 1.0000 - val_loss: 1.1015 - val_accuracy: 0.9138
# Epoch 223/250
# 430/460 [===========================>..] - ETA: 0s - loss: 7.7625e-09 - accuracy: 1.0000
# Epoch 00223: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 560us/sample - loss: 7.2562e-09 - accuracy: 1.0000 - val_loss: 1.1167 - val_accuracy: 0.9138
# Epoch 224/250
# 430/460 [===========================>..] - ETA: 0s - loss: 7.4852e-09 - accuracy: 1.0000
# Epoch 00224: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 568us/sample - loss: 6.9971e-09 - accuracy: 1.0000 - val_loss: 1.1205 - val_accuracy: 0.9138
# Epoch 225/250
# 440/460 [===========================>..] - ETA: 0s - loss: 6.5023e-09 - accuracy: 1.0000
# Epoch 00225: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 540us/sample - loss: 6.2196e-09 - accuracy: 1.0000 - val_loss: 1.1181 - val_accuracy: 0.9138
# Epoch 226/250
# 450/460 [============================>.] - ETA: 0s - loss: 6.3578e-09 - accuracy: 1.0000
# Epoch 00226: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 556us/sample - loss: 6.2196e-09 - accuracy: 1.0000 - val_loss: 1.1173 - val_accuracy: 0.9138
# Epoch 227/250
# 410/460 [=========================>....] - ETA: 0s - loss: 6.6873e-09 - accuracy: 1.0000
# Epoch 00227: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 566us/sample - loss: 5.9605e-09 - accuracy: 1.0000 - val_loss: 1.1129 - val_accuracy: 0.9138
# Epoch 228/250
# 440/460 [===========================>..] - ETA: 0s - loss: 5.9605e-09 - accuracy: 1.0000
# Epoch 00228: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 553us/sample - loss: 5.7013e-09 - accuracy: 1.0000 - val_loss: 1.1240 - val_accuracy: 0.9138
# Epoch 229/250
# 420/460 [==========================>...] - ETA: 0s - loss: 6.2443e-09 - accuracy: 1.0000
# Epoch 00229: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 596us/sample - loss: 5.7013e-09 - accuracy: 1.0000 - val_loss: 1.1216 - val_accuracy: 0.9138
# Epoch 230/250
# 430/460 [===========================>..] - ETA: 0s - loss: 6.0991e-09 - accuracy: 1.0000
# Epoch 00230: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 569us/sample - loss: 5.7013e-09 - accuracy: 1.0000 - val_loss: 1.1189 - val_accuracy: 0.9138
# Epoch 231/250
# 440/460 [===========================>..] - ETA: 0s - loss: 5.6895e-09 - accuracy: 1.0000
# Epoch 00231: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 555us/sample - loss: 5.4422e-09 - accuracy: 1.0000 - val_loss: 1.1242 - val_accuracy: 0.9138
# Epoch 232/250
# 430/460 [===========================>..] - ETA: 0s - loss: 5.5446e-09 - accuracy: 1.0000
# Epoch 00232: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 553us/sample - loss: 5.1830e-09 - accuracy: 1.0000 - val_loss: 1.1221 - val_accuracy: 0.9138
# Epoch 233/250
# 420/460 [==========================>...] - ETA: 0s - loss: 5.3928e-09 - accuracy: 1.0000
# Epoch 00233: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 566us/sample - loss: 4.9239e-09 - accuracy: 1.0000 - val_loss: 1.1273 - val_accuracy: 0.9138
# Epoch 234/250
# 420/460 [==========================>...] - ETA: 0s - loss: 8.5149e-10 - accuracy: 1.0000
# Epoch 00234: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 581us/sample - loss: 4.6647e-09 - accuracy: 1.0000 - val_loss: 1.1250 - val_accuracy: 0.9138
# Epoch 235/250
# 410/460 [=========================>....] - ETA: 0s - loss: 5.2336e-09 - accuracy: 1.0000
# Epoch 00235: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 601us/sample - loss: 4.6647e-09 - accuracy: 1.0000 - val_loss: 1.1357 - val_accuracy: 0.9138
# Epoch 236/250
# 430/460 [===========================>..] - ETA: 0s - loss: 4.7129e-09 - accuracy: 1.0000
# Epoch 00236: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s
val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 568us/sample - loss: 3.6281e-09 - accuracy: 1.0000 - val_loss: 1.1543 - val_accuracy: 0.9138
# Epoch 249/250
# 420/460 [==========================>...] - ETA: 0s - loss: 3.9736e-09 - accuracy: 1.0000
# Epoch 00249: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 568us/sample - loss: 3.6281e-09 - accuracy: 1.0000 - val_loss: 1.1549 - val_accuracy: 0.9138
# Epoch 250/250
# 430/460 [===========================>..] - ETA: 0s - loss: 3.3268e-09 - accuracy: 1.0000
# Epoch 00250: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 562us/sample - loss: 3.1098e-09 - accuracy: 1.0000 - val_loss: 1.1546 - val_accuracy: 0.9138
# Training completed in time:  0:01:10.851328

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste
#
# Lembrando que estamos utilizando o mesmo conjunto de validacão, que a princípio, pode incluir instâncias do conjunto de treinamento: o dataset utilizado foi gerado com corte de áudio, então alguns trechos do mesmo áudio podem estar presentes em ambos os conjuntos de treinamento e teste.
# Por ora deixamos assim já que estamos realizando uma investigacão inicial.

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  1.0
# Testing Accuracy:  0.9137931

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.87      0.96      0.92        56
#    Pneumonia       0.96      0.87      0.91        60
#
#     accuracy                           0.91       116
#    macro avg       0.92      0.92      0.91       116
# weighted avg       0.92      0.91      0.91       116

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[54  2]
#  [ 8 52]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])
