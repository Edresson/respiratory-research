# %% [markdown]
# # Rede MLP - Modelo 1
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - slide10phone

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP = 'slide10sr22050'
MAX_PAD_LEN = 431

# %%
filepaths = glob.glob(f'./datasets/{GROUP}/**/*.wav', recursive=True)
filenames = [os.path.splitext(os.path.basename(p))[0] for p in filepaths]

# %%
p_id_in_file = [] # patient IDs corresponding to each file
for name in filenames:
    p_id_in_file.append(int(name[:3]))

p_id_in_file = np.array(p_id_in_file)

# %%
max_pad_len =  MAX_PAD_LEN

os.makedirs("./Respiratory_Sound_Database/features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=10) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./Respiratory_Sound_Database/features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
p_diag = pd.read_csv("./Respiratory_Sound_Database/Respiratory_Sound_Database/patient_diagnosis.csv",header=None) # patient diagnosis file

# %%
labels = np.array([p_diag[p_diag[0] == x][1].values[0] for x in p_id_in_file]) # labels for audio files

# %%
features = [] 

# Iterate through each sound file and extract the features
for file_name in filepaths:
    data = extract_features(file_name)
    features.append(data)

print('Finished feature extraction from ', len(features), ' files')
features = np.array(features)
# Out:
# Finished feature extraction from  576  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(features[1], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
features = np.array(features) # convert to numpy array

# %%
np.unique(labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
# delete diseases
'''
features1 = features
labels1 = labels'''

features1 = np.delete(features, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0) 

labels1 = np.delete(labels, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0)

# %%
# print class counts
unique_elements, counts_elements = np.unique(labels1, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['280' '296']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(labels1)
oh_labels = to_categorical(i_labels)

# %%
features1.shape
# Out:
# (576, 40, 431)

# %%
input_dim = features1.shape[1]*features1.shape[2]
features1 = np.reshape(features1, (features1.shape[0], input_dim))
print(features1.shape, labels1.shape)
# Out:
# (576, 17240) (576,)

# %%
# train test split
x_train, x_test, y_train, y_test = train_test_split(features1, oh_labels, stratify=oh_labels, 
                                                    test_size=0.2, random_state = 42)

# %% [markdown]
# **MLP model architecture**

# %%
num_labels = oh_labels.shape[1]
# Construct model 
model = Sequential()
model.add(Dense(500, input_dim=input_dim, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 500)               8620500
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_2 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_3 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_4 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_5 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_6 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_7 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 1002
# =================================================================
# Total params: 10,375,002
# Trainable params: 10,375,002
# Non-trainable params: 0
# _________________________________________________________________
# 116/116 [==============================] - 0s 3ms/sample - loss: 11.1310 - accuracy: 0.5172
# Pre-training accuracy: 51.7241%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 250
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/model2_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 460 samples, validate on 116 samples
# Epoch 1/250
# 430/460 [===========================>..] - ETA: 0s - loss: 23.7888 - accuracy: 0.5209
# Epoch 00001: val_accuracy improved from -inf to 0.51724, saving model to models/model2_01.h5
# 460/460 [==============================] - 1s 3ms/sample - loss: 22.2967 - accuracy: 0.5304 - val_loss: 0.7063 - val_accuracy: 0.5172
# Epoch 2/250
# 420/460 [==========================>...] - ETA: 0s - loss: 1.0813 - accuracy: 0.5071
# Epoch 00002: val_accuracy did not improve from 0.51724
# 460/460 [==============================] - 0s 897us/sample - loss: 1.0475 - accuracy: 0.5152 - val_loss: 0.8735 - val_accuracy: 0.5172
# Epoch 3/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.7339 - accuracy: 0.6238
# Epoch 00003: val_accuracy improved from 0.51724 to 0.81034, saving model to models/model2_03.h5
# 460/460 [==============================] - 1s 2ms/sample - loss: 0.7106 - accuracy: 0.6326 - val_loss: 0.3945 - val_accuracy: 0.8103
# Epoch 4/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.4931 - accuracy: 0.7659
# Epoch 00004: val_accuracy improved from 0.81034 to 0.84483, saving model to models/model2_04.h5
# 460/460 [==============================] - 1s 2ms/sample - loss: 0.4905 - accuracy: 0.7674 - val_loss: 0.3044 - val_accuracy: 0.8448
# Epoch 5/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.3403 - accuracy: 0.8634
# Epoch 00005: val_accuracy did not improve from 0.84483
# 460/460 [==============================] - 0s 890us/sample - loss: 0.3932 - accuracy: 0.8522 - val_loss: 0.4602 - val_accuracy: 0.8276
# Epoch 6/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.4580 - accuracy: 0.7951
# Epoch 00006: val_accuracy improved from 0.84483 to 0.90517, saving model to models/model2_06.h5
# 460/460 [==============================] - 1s 2ms/sample - loss: 0.4401 - accuracy: 0.8065 - val_loss: 0.2238 - val_accuracy: 0.9052
# Epoch 7/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.2387 - accuracy: 0.8846
# Epoch 00007: val_accuracy did not improve from 0.90517
# 460/460 [==============================] - 0s 958us/sample - loss: 0.2491 - accuracy: 0.8739 - val_loss: 0.2160 - val_accuracy: 0.8966
# Epoch 8/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.4039 - accuracy: 0.8537
# Epoch 00008: val_accuracy improved from 0.90517 to 0.91379, saving model to models/model2_08.h5
# 460/460 [==============================] - 1s 2ms/sample - loss: 0.3802 - accuracy: 0.8630 - val_loss: 0.2876 - val_accuracy: 0.9138
# Epoch 9/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2485 - accuracy: 0.9048
# Epoch 00009: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.2332 - accuracy: 0.9109 - val_loss: 0.6342 - val_accuracy: 0.7845
# Epoch 10/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.2720 - accuracy: 0.8683
# Epoch 00010: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 917us/sample - loss: 0.2738 - accuracy: 0.8739 - val_loss: 0.7626 - val_accuracy: 0.7931
# Epoch 11/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.3945 - accuracy: 0.8810
# Epoch 00011: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 894us/sample - loss: 0.4232 - accuracy: 0.8609 - val_loss: 0.3435 - val_accuracy: 0.8621
# Epoch 12/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.5020 - accuracy: 0.8186
# Epoch 00012: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 908us/sample - loss: 0.4958 - accuracy: 0.8130 - val_loss: 0.3193 - val_accuracy: 0.9138
# Epoch 13/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.5016 - accuracy: 0.8558
# Epoch 00013: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 890us/sample - loss: 0.5159 - accuracy: 0.8283 - val_loss: 0.5442 - val_accuracy: 0.8190
# Epoch 14/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2913 - accuracy: 0.8762
# Epoch 00014: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 901us/sample - loss: 0.2807 - accuracy: 0.8804 - val_loss: 0.3838 - val_accuracy: 0.8707
# Epoch 15/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.3201 - accuracy: 0.8585
# Epoch 00015: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 876us/sample - loss: 0.3107 - accuracy: 0.8609 - val_loss: 0.2421 - val_accuracy: 0.9052
# Epoch 16/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.4364 - accuracy: 0.8395
# Epoch 00016: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 887us/sample - loss: 0.4229 - accuracy: 0.8435 - val_loss: 0.3372 - val_accuracy: 0.8966
# Epoch 17/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.2721 - accuracy: 0.8841
# Epoch 00017: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 878us/sample - loss: 0.2623 - accuracy: 0.8891 - val_loss: 0.2138 - val_accuracy: 0.9052
# Epoch 18/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.1768 - accuracy: 0.9289
# Epoch 00018: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 836us/sample - loss: 0.1741 - accuracy: 0.9304 - val_loss: 0.2294 - val_accuracy: 0.8879
# Epoch 19/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.2406 - accuracy: 0.9295
# Epoch 00019: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 838us/sample - loss: 0.2306 - accuracy: 0.9326 - val_loss: 0.2650 - val_accuracy: 0.8966
# Epoch 20/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.1041 - accuracy: 0.9553
# Epoch 00020: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 819us/sample - loss: 0.0983 - accuracy: 0.9565 - val_loss: 0.5883 - val_accuracy: 0.8793
# Epoch 21/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0342 - accuracy: 0.9837
# Epoch 00021: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 841us/sample - loss: 0.0320 - accuracy: 0.9848 - val_loss: 0.5897 - val_accuracy: 0.8966
# Epoch 22/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0707 - accuracy: 0.9714
# Epoch 00022: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 922us/sample - loss: 0.0896 - accuracy: 0.9652 - val_loss: 0.6515 - val_accuracy: 0.8017
# Epoch 23/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0461 - accuracy: 0.9881
# Epoch 00023: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 858us/sample - loss: 0.0424 - accuracy: 0.9891 - val_loss: 1.8573 - val_accuracy: 0.8707
# Epoch 24/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.1031 - accuracy: 0.9600
# Epoch 00024: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 941us/sample - loss: 0.0922 - accuracy: 0.9652 - val_loss: 0.2581 - val_accuracy: 0.8879
# Epoch 25/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0207 - accuracy: 0.9860
# Epoch 00025: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 891us/sample - loss: 0.0193 - accuracy: 0.9870 - val_loss: 0.6672 - val_accuracy: 0.9052
# Epoch 26/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.5844 - accuracy: 0.7465
# Epoch 00026: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 880us/sample - loss: 1.4828 - accuracy: 0.7630 - val_loss: 0.4969 - val_accuracy: 0.8621
# Epoch 27/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.3298 - accuracy: 0.9357
# Epoch 00027: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 0s 864us/sample - loss: 0.3566 - accuracy: 0.9283 - val_loss: 0.4268 - val_accuracy: 0.8190
# Epoch 28/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2196 - accuracy: 0.9310
# Epoch 00028: val_accuracy improved from 0.91379 to 0.94828, saving model to models/model2_28.h5
# 460/460 [==============================] - 1s 2ms/sample - loss: 0.2014 - accuracy: 0.9370 - val_loss: 0.1578 - val_accuracy: 0.9483
# Epoch 29/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0587 - accuracy: 0.9875
# Epoch 00029: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 967us/sample - loss: 0.0590 - accuracy: 0.9848 - val_loss: 0.2299 - val_accuracy: 0.8966
# Epoch 30/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0788 - accuracy: 0.9810
# Epoch 00030: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 888us/sample - loss: 0.0783 - accuracy: 0.9804 - val_loss: 1.5911 - val_accuracy: 0.7672
# Epoch 31/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0532 - accuracy: 0.9814
# Epoch 00031: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 884us/sample - loss: 0.0499 - accuracy: 0.9826 - val_loss: 0.3718 - val_accuracy: 0.9052
# Epoch 32/250
# 420/460 [==========================>...] - ETA: 0s - loss: 3.3108e-04 - accuracy: 1.0000
# Epoch 00032: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 864us/sample - loss: 3.0454e-04 - accuracy: 1.0000 - val_loss: 0.2707 - val_accuracy: 0.9310
# Epoch 33/250
# 420/460 [==========================>...] - ETA: 0s - loss: 7.3935e-05 - accuracy: 1.0000
# Epoch 00033: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 874us/sample - loss: 7.8382e-05 - accuracy: 1.0000 - val_loss: 0.3034 - val_accuracy: 0.9397
# Epoch 34/250
# 420/460 [==========================>...] - ETA: 0s - loss: 4.3382e-05 - accuracy: 1.0000
# Epoch 00034: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 890us/sample - loss: 5.1802e-05 - accuracy: 1.0000 - val_loss: 0.3096 - val_accuracy: 0.9310
# Epoch 35/250
# 420/460 [==========================>...] - ETA: 0s - loss: 4.2190e-05 - accuracy: 1.0000
# Epoch 00035: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 878us/sample - loss: 3.8977e-05 - accuracy: 1.0000 - val_loss: 0.3202 - val_accuracy: 0.9310
# Epoch 36/250
# 430/460 [===========================>..] - ETA: 0s - loss: 3.0905e-05 - accuracy: 1.0000
# Epoch 00036: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 856us/sample - loss: 2.9057e-05 - accuracy: 1.0000 - val_loss: 0.3999 - val_accuracy: 0.9397
# Epoch 37/250
# 420/460 [==========================>...] - ETA: 0s - loss: 1.9627e-05 - accuracy: 1.0000
# Epoch 00037: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 855us/sample - loss: 1.8585e-05 - accuracy: 1.0000 - val_loss: 0.4276 - val_accuracy: 0.9310
# Epoch 38/250
# 410/460 [=========================>....] - ETA: 0s - loss: 7.1005e-06 - accuracy: 1.0000
# Epoch 00038: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 895us/sample - loss: 6.3549e-06 - accuracy: 1.0000 - val_loss: 0.4541 - val_accuracy: 0.9310
# Epoch 39/250
# 420/460 [==========================>...] - ETA: 0s - loss: 1.7390e-06 - accuracy: 1.0000
# Epoch 00039: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 875us/sample - loss: 1.6191e-06 - accuracy: 1.0000 - val_loss: 0.4845 - val_accuracy: 0.9310
# Epoch 40/250
# 410/460 [=========================>....] - ETA: 0s - loss: 9.2835e-07 - accuracy: 1.0000
# Epoch 00040: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 882us/sample - loss: 8.8056e-07 - accuracy: 1.0000 - val_loss: 0.4979 - val_accuracy: 0.9310
# Epoch 41/250
# 420/460 [==========================>...] - ETA: 0s - loss: 4.9783e-07 - accuracy: 1.0000
# Epoch 00041: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 916us/sample - loss: 5.3410e-07 - accuracy: 1.0000 - val_loss: 0.5099 - val_accuracy: 0.9310
# Epoch 42/250
# 420/460 [==========================>...] - ETA: 0s - loss: 3.8884e-07 - accuracy: 1.0000
# Epoch 00042: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 890us/sample - loss: 3.6073e-07 - accuracy: 1.0000 - val_loss: 0.5252 - val_accuracy: 0.9310
# Epoch 43/250
# 410/460 [=========================>....] - ETA: 0s - loss: 2.5412e-07 - accuracy: 1.0000
# Epoch 00043: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 921us/sample - loss: 2.4360e-07 - accuracy: 1.0000 - val_loss: 0.5353 - val_accuracy: 0.9310
# Epoch 44/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.8685e-07 - accuracy: 1.0000
# Epoch 00044: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 883us/sample - loss: 1.7700e-07 - accuracy: 1.0000 - val_loss: 0.5411 - val_accuracy: 0.9310
# Epoch 45/250
# 420/460 [==========================>...] - ETA: 0s - loss: 1.5242e-07 - accuracy: 1.0000
# Epoch 00045: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 905us/sample - loss: 1.4150e-07 - accuracy: 1.0000 - val_loss: 0.5498 - val_accuracy: 0.9310
# Epoch 46/250
# 450/460 [============================>.] - ETA: 0s - loss: 9.6162e-08 - accuracy: 1.0000
# Epoch 00046: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 945us/sample - loss: 9.4071e-08 - accuracy: 1.0000 - val_loss: 0.5624 - val_accuracy: 0.9310
# Epoch 47/250
# 430/460 [===========================>..] - ETA: 0s - loss: 4.7684e-08 - accuracy: 1.0000
# Epoch 00047: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 882us/sample - loss: 6.2973e-08 - accuracy: 1.0000 - val_loss: 0.5699 - val_accuracy: 0.9310
# Epoch 48/250
# 420/460 [==========================>...] - ETA: 0s - loss: 4.6264e-08 - accuracy: 1.0000
# Epoch 00048: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 866us/sample - loss: 4.8720e-08 - accuracy: 1.0000 - val_loss: 0.5766 - val_accuracy: 0.9310
# Epoch 49/250
# 410/460 [=========================>....] - ETA: 0s - loss: 3.3437e-08 - accuracy: 1.0000
# Epoch 00049: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 865us/sample - loss: 3.7577e-08 - accuracy: 1.0000 - val_loss: 0.5833 - val_accuracy: 0.9310
# Epoch 50/250
# 430/460 [===========================>..] - ETA: 0s - loss: 3.3268e-08 - accuracy: 1.0000
# Epoch 00050: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 867us/sample - loss: 3.1357e-08 - accuracy: 1.0000 - val_loss: 0.5884 - val_accuracy: 0.9310
# Epoch 51/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.4119e-08 - accuracy: 1.0000
# Epoch 00051: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 872us/sample - loss: 2.6433e-08 - accuracy: 1.0000 - val_loss: 0.5929 - val_accuracy: 0.9310
# Epoch 52/250
# 420/460 [==========================>...] - ETA: 0s - loss: 2.5829e-08 - accuracy: 1.0000
# Epoch 00052: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 866us/sample - loss: 2.3583e-08 - accuracy: 1.0000 - val_loss: 0.5976 - val_accuracy: 0.9310
# Epoch 53/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.0792e-08 - accuracy: 1.0000
# Epoch 00053: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 881us/sample - loss: 2.0214e-08 - accuracy: 1.0000 - val_loss: 0.6007 - val_accuracy: 0.9310
# Epoch 54/250
# 410/460 [=========================>....] - ETA: 0s - loss: 2.0353e-08 - accuracy: 1.0000
# Epoch 00054: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 871us/sample - loss: 1.8141e-08 - accuracy: 1.0000 - val_loss: 0.6049 - val_accuracy: 0.9310
# Epoch 55/250
# 410/460 [=========================>....] - ETA: 0s - loss: 1.3956e-08 - accuracy: 1.0000
# Epoch 00055: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 920us/sample - loss: 1.6326e-08 - accuracy: 1.0000 - val_loss: 0.6081 - val_accuracy: 0.9310
# Epoch 56/250
# 390/460 [========================>.....] - ETA: 0s - loss: 1.6200e-08 - accuracy: 1.0000
# Epoch 00056: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 933us/sample - loss: 1.4512e-08 - accuracy: 1.0000 - val_loss: 0.6117 - val_accuracy: 0.9310
# Epoch 57/250
# 410/460 [=========================>....] - ETA: 0s - loss: 1.4538e-08 - accuracy: 1.0000
# Epoch 00057: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 913us/sample - loss: 1.2958e-08 - accuracy: 1.0000 - val_loss: 0.6149 - val_accuracy: 0.9310
# Epoch 58/250
# 450/460 [============================>.] - ETA: 0s - loss: 1.2451e-08 - accuracy: 1.0000
# Epoch 00058: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 988us/sample - loss: 1.2180e-08 - accuracy: 1.0000 - val_loss: 0.6178 - val_accuracy: 0.9310
# Epoch 59/250
# 420/460 [==========================>...] - ETA: 0s - loss: 1.2489e-08 - accuracy: 1.0000
# Epoch 00059: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 898us/sample - loss: 1.1403e-08 - accuracy: 1.0000 - val_loss: 0.6204 - val_accuracy: 0.9310
# Epoch 60/250
# 420/460 [==========================>...] - ETA: 0s - loss: 1.1353e-08 - accuracy: 1.0000
# Epoch 00060: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 899us/sample - loss: 1.0366e-08 - accuracy: 1.0000 - val_loss: 0.6229 - val_accuracy: 0.9310
# Epoch 61/250
# 420/460 [==========================>...] - ETA: 0s - loss: 1.0218e-08 - accuracy: 1.0000
# Epoch 00061: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 875us/sample - loss: 9.3294e-09 - accuracy: 1.0000 - val_loss: 0.6256 - val_accuracy: 0.9310
# Epoch 62/250
# 430/460 [===========================>..] - ETA: 0s - loss: 9.9803e-09 - accuracy: 1.0000
# Epoch 00062: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 1ms/sample - loss: 9.3294e-09 - accuracy: 1.0000 - val_loss: 0.6280 - val_accuracy: 0.9310
# Epoch 63/250
# 390/460 [========================>.....] - ETA: 0s - loss: 1.0087e-08 - accuracy: 1.0000
# Epoch 00063: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 915us/sample - loss: 8.5520e-09 - accuracy: 1.0000 - val_loss: 0.6309 - val_accuracy: 0.9310
# Epoch 64/250
# 420/460 [==========================>...] - ETA: 0s - loss: 7.3796e-09 - accuracy: 1.0000
# Epoch 00064: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 868us/sample - loss: 8.0337e-09 - accuracy: 1.0000 - val_loss: 0.6331 - val_accuracy: 0.9310
# Epoch 65/250
# 420/460 [==========================>...] - ETA: 0s - loss: 8.5149e-09 - accuracy: 1.0000
# Epoch 00065: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 878us/sample - loss: 7.7745e-09 - accuracy: 1.0000 - val_loss: 0.6355 - val_accuracy: 0.9310
# Epoch 66/250
# 410/460 [=========================>....] - ETA: 0s - loss: 4.0706e-09 - accuracy: 1.0000
# Epoch 00066: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 860us/sample - loss: 7.5154e-09 - accuracy: 1.0000 - val_loss: 0.6376 - val_accuracy: 0.9310
# Epoch 67/250
# 420/460 [==========================>...] - ETA: 0s - loss: 4.5413e-09 - accuracy: 1.0000
# Epoch 00067: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 863us/sample - loss: 6.7379e-09 - accuracy: 1.0000 - val_loss: 0.6398 - val_accuracy: 0.9310
# Epoch 68/250
# 420/460 [==========================>...] - ETA: 0s - loss: 6.8120e-09 - accuracy: 1.0000
# Epoch 00068: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 878us/sample - loss: 6.2196e-09 - accuracy: 1.0000 - val_loss: 0.6419 - val_accuracy: 0.9310
# Epoch 69/250
# 430/460 [===========================>..] - ETA: 0s - loss: 6.0991e-09 - accuracy: 1.0000
# Epoch 00069: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 878us/sample - loss: 5.7013e-09 - accuracy: 1.0000 - val_loss: 0.6436 - val_accuracy: 0.9310
# Epoch 70/250
# 430/460 [===========================>..] - ETA: 0s - loss: 3.8812e-09 - accuracy: 1.0000
# Epoch 00070: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 881us/sample - loss: 5.4422e-09 - accuracy: 1.0000 - val_loss: 0.6456 - val_accuracy: 0.9310
# Epoch 71/250
# 420/460 [==========================>...] - ETA: 0s - loss: 5.6766e-09 - accuracy: 1.0000
# Epoch 00071: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 875us/sample - loss: 5.1830e-09 - accuracy: 1.0000 - val_loss: 0.6477 - val_accuracy: 0.9310
# Epoch 72/250
# 420/460 [==========================>...] - ETA: 0s - loss: 5.1090e-09 - accuracy: 1.0000
# Epoch 00072: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 870us/sample - loss: 4.6647e-09 - accuracy: 1.0000 - val_loss: 0.6490 - val_accuracy: 0.9310
# Epoch 73/250
# 390/460 [========================>.....] - ETA: 0s - loss: 4.2793e-09 - accuracy: 1.0000
# Epoch 00073: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 932us/sample - loss: 4.6647e-09 - accuracy: 1.0000 - val_loss: 0.6505 - val_accuracy: 0.9310
# Epoch 74/250
# 420/460 [==========================>...] - ETA: 0s - loss: 3.1221e-09 - accuracy: 1.0000
# Epoch 00074: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 872us/sample - loss: 4.6647e-09 - accuracy: 1.0000 - val_loss: 0.6529 - val_accuracy: 0.9310
# Epoch 75/250
# 410/460 [=========================>....] - ETA: 0s - loss: 4.9428e-09 - accuracy: 1.0000
# Epoch 00075: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 914us/sample - loss: 4.4056e-09 - accuracy: 1.0000 - val_loss: 0.6549 - val_accuracy: 0.9310
# Epoch 76/250
# 450/460 [============================>.] - ETA: 0s - loss: 4.2386e-09 - accuracy: 1.0000
# Epoch 00076: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 977us/sample - loss: 4.1464e-09 - accuracy: 1.0000 - val_loss: 0.6566 - val_accuracy: 0.9310
# Epoch 77/250
# 400/460 [=========================>....] - ETA: 0s - loss: 3.5763e-09 - accuracy: 1.0000
# Epoch 00077: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 962us/sample - loss: 3.8873e-09 - accuracy: 1.0000 - val_loss: 0.6577 - val_accuracy: 0.9310
# Epoch 78/250
# 400/460 [=========================>....] - ETA: 0s - loss: 3.5763e-09 - accuracy: 1.0000
# Epoch 00078: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 932us/sample - loss: 3.8873e-09 - accuracy: 1.0000 - val_loss: 0.6599 - val_accuracy: 0.9310
# Epoch 79/250
# 450/460 [============================>.] - ETA: 0s - loss: 3.9736e-09 - accuracy: 1.0000
# Epoch 00079: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 980us/sample - loss: 3.8873e-09 - accuracy: 1.0000 - val_loss: 0.6617 - val_accuracy: 0.9310
# Epoch 80/250
# 400/460 [=========================>....] - ETA: 0s - loss: 3.8743e-09 - accuracy: 1.0000
# Epoch 00080: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 964us/sample - loss: 3.3690e-09 - accuracy: 1.0000 - val_loss: 0.6634 - val_accuracy: 0.9310
# Epoch 81/250
# 440/460 [===========================>..] - ETA: 0s - loss: 3.5221e-09 - accuracy: 1.0000
# Epoch 00081: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 979us/sample - loss: 3.3690e-09 - accuracy: 1.0000 - val_loss: 0.6649 - val_accuracy: 0.9310
# Epoch 82/250
# 400/460 [=========================>....] - ETA: 0s - loss: 3.8743e-09 - accuracy: 1.0000
# Epoch 00082: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 957us/sample - loss: 3.3690e-09 - accuracy: 1.0000 - val_loss: 0.6666 - val_accuracy: 0.9310
# Epoch 83/250
# 450/460 [============================>.] - ETA: 0s - loss: 3.4438e-09 - accuracy: 1.0000
# Epoch 00083: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 956us/sample - loss: 3.3690e-09 - accuracy: 1.0000 - val_loss: 0.6680 - val_accuracy: 0.9310
# Epoch 84/250
# 440/460 [===========================>..] - ETA: 0s - loss: 3.5221e-09 - accuracy: 1.0000
# Epoch 00084: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 983us/sample - loss: 3.3690e-09 - accuracy: 1.0000 - val_loss: 0.6699 - val_accuracy: 0.9310
# Epoch 85/250
# 430/460 [===========================>..] - ETA: 0s - loss: 3.3268e-09 - accuracy: 1.0000
# Epoch 00085: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 870us/sample - loss: 3.1098e-09 - accuracy: 1.0000 - val_loss: 0.6715 - val_accuracy: 0.9310
# Epoch 86/250
# 410/460 [=========================>....] - ETA: 0s - loss: 3.4891e-09 - accuracy: 1.0000
# Epoch 00086: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 898us/sample - loss: 3.1098e-09 - accuracy: 1.0000 - val_loss: 0.6730 - val_accuracy: 0.9310
# Epoch 87/250
# 420/460 [==========================>...] - ETA: 0s - loss: 3.1221e-09 - accuracy: 1.0000
# Epoch 00087: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 885us/sample - loss: 2.8507e-09 - accuracy: 1.0000 - val_loss: 0.6747 - val_accuracy: 0.9310
# Epoch 88/250
# 420/460 [==========================>...] - ETA: 0s - loss: 3.1221e-09 - accuracy: 1.0000
# Epoch 00088: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 886us/sample - loss: 2.8507e-09 - accuracy: 1.0000 - val_loss: 0.6762 - val_accuracy: 0.9310
# Epoch 89/250
# 420/460 [==========================>...] - ETA: 0s - loss: 2.8383e-09 - accuracy: 1.0000
# Epoch 00089: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 920us/sample - loss: 2.8507e-09 - accuracy: 1.0000 - val_loss: 0.6773 - val_accuracy: 0.9310
# Epoch 90/250
# 430/460 [===========================>..] - ETA: 0s - loss: 3.0495e-09 - accuracy: 1.0000
# Epoch 00090: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 893us/sample - loss: 2.8507e-09 - accuracy: 1.0000 - val_loss: 0.6789 - val_accuracy: 0.9310
# Epoch 91/250
# 440/460 [===========================>..] - ETA: 0s - loss: 2.7093e-09 - accuracy: 1.0000
# Epoch 00091: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 833us/sample - loss: 2.5915e-09 - accuracy: 1.0000 - val_loss: 0.6807 - val_accuracy: 0.9310
# Epoch 92/250
# 380/460 [=======================>......] - ETA: 0s - loss: 2.5097e-09 - accuracy: 1.0000
# Epoch 00092: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 812us/sample - loss: 2.3324e-09 - accuracy: 1.0000 - val_loss: 0.6824 - val_accuracy: 0.9310
# Epoch 93/250
# 420/460 [==========================>...] - ETA: 0s - loss: 2.2707e-09 - accuracy: 1.0000
# Epoch 00093: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 872us/sample - loss: 2.0732e-09 - accuracy: 1.0000 - val_loss: 0.6837 - val_accuracy: 0.9310
# Epoch 94/250
# 440/460 [===========================>..] - ETA: 0s - loss: 1.6256e-09 - accuracy: 1.0000
# Epoch 00094: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 826us/sample - loss: 1.8141e-09 - accuracy: 1.0000 - val_loss: 0.6852 - val_accuracy: 0.9310
# Epoch 95/250
# 450/460 [============================>.] - ETA: 0s - loss: 1.8544e-09 - accuracy: 1.0000
# Epoch 00095: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 836us/sample - loss: 1.8141e-09 - accuracy: 1.0000 - val_loss: 0.6865 - val_accuracy: 0.9310
# Epoch 96/250
# 410/460 [=========================>....] - ETA: 0s - loss: 1.1630e-09 - accuracy: 1.0000
# Epoch 00096: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 905us/sample - loss: 1.8141e-09 - accuracy: 1.0000 - val_loss: 0.6878 - val_accuracy: 0.9310
# Epoch 97/250
# 440/460 [===========================>..] - ETA: 0s - loss: 1.0837e-09 - accuracy: 1.0000
# Epoch 00097: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 843us/sample - loss: 1.8141e-09 - accuracy: 1.0000 - val_loss: 0.6890 - val_accuracy: 0.9310
# Epoch 98/250
# 440/460 [===========================>..] - ETA: 0s - loss: 1.6256e-09 - accuracy: 1.0000
# Epoch 00098: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 833us/sample - loss: 1.8141e-09 - accuracy: 1.0000 - val_loss: 0.6901 - val_accuracy: 0.9310
# Epoch 99/250
# 450/460 [============================>.] - ETA: 0s - loss: 1.5895e-09 - accuracy: 1.0000
# Epoch 00099: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 816us/sample - loss: 1.5549e-09 - accuracy: 1.0000 - val_loss: 0.6915 - val_accuracy: 0.9310
# Epoch 100/250
# 440/460 [===========================>..] - ETA: 0s - loss: 1.6256e-09 - accuracy: 1.0000
# Epoch 00100: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 852us/sample - loss: 1.5549e-09 - accuracy: 1.0000 - val_loss: 0.6927 - val_accuracy: 0.9310
# Epoch 101/250
# 410/460 [=========================>....] - ETA: 0s - loss: 1.7445e-09 - accuracy: 1.0000
# Epoch 00101: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 929us/sample - loss: 1.5549e-09 - accuracy: 1.0000 - val_loss: 0.6936 - val_accuracy: 0.9310
# Epoch 102/250
# 420/460 [==========================>...] - ETA: 0s - loss: 1.7030e-09 - accuracy: 1.0000
# Epoch 00102: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 908us/sample - loss: 1.5549e-09 - accuracy: 1.0000 - val_loss: 0.6947 - val_accuracy: 0.9310
# Epoch 103/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.6634e-09 - accuracy: 1.0000
# Epoch 00103: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 881us/sample - loss: 1.5549e-09 - accuracy: 1.0000 - val_loss: 0.6957 - val_accuracy: 0.9310
# Epoch 104/250
# 420/460 [==========================>...] - ETA: 0s - loss: 1.4192e-09 - accuracy: 1.0000
# Epoch 00104: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 878us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.6963 - val_accuracy: 0.9310
# Epoch 105/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.3862e-09 - accuracy: 1.0000
# Epoch 00105: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 869us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.6974 - val_accuracy: 0.9310
# Epoch 106/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.3862e-09 - accuracy: 1.0000
# Epoch 00106: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 896us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.6986 - val_accuracy: 0.9310
# Epoch 107/250
# 420/460 [==========================>...] - ETA: 0s - loss: 1.1353e-09 - accuracy: 1.0000
# Epoch 00107: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 889us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.6993 - val_accuracy: 0.9310
# Epoch 108/250
# 420/460 [==========================>...] - ETA: 0s - loss: 1.4192e-09 - accuracy: 1.0000
# Epoch 00108: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 889us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.7004 - val_accuracy: 0.9310
# Epoch 109/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.3862e-09 - accuracy: 1.0000
# Epoch 00109: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 858us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.7014 - val_accuracy: 0.9310
# Epoch 110/250
# 420/460 [==========================>...] - ETA: 0s - loss: 1.4192e-09 - accuracy: 1.0000
# Epoch 00110: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 890us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.7024 - val_accuracy: 0.9310
# Epoch 111/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.3862e-09 - accuracy: 1.0000
# Epoch 00111: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 867us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.7034 - val_accuracy: 0.9310
# Epoch 112/250
# 420/460 [==========================>...] - ETA: 0s - loss: 1.4192e-09 - accuracy: 1.0000
# Epoch 00112: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 875us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.7043 - val_accuracy: 0.9310
# Epoch 113/250
# 390/460 [========================>.....] - ETA: 0s - loss: 1.2227e-09 - accuracy: 1.0000
# Epoch 00113: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 939us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.7052 - val_accuracy: 0.9310
# Epoch 114/250
# 420/460 [==========================>...] - ETA: 0s - loss: 1.4192e-09 - accuracy: 1.0000
# Epoch 00114: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 882us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.7062 - val_accuracy: 0.9310
# Epoch 115/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.3862e-09 - accuracy: 1.0000
# Epoch 00115: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 875us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.7072 - val_accuracy: 0.9310
# Epoch 116/250
# 430/460 [===========================>..] - ETA: 0s - loss: 8.3169e-10 - accuracy: 1.0000
# Epoch 00116: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 874us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.7079 - val_accuracy: 0.9310
# Epoch 117/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.3862e-09 - accuracy: 1.0000
# Epoch 00117: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 863us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.7089 - val_accuracy: 0.9310
# Epoch 118/250
# 430/460 [===========================>..] - ETA: 0s - loss: 8.3169e-10 - accuracy: 1.0000
# Epoch 00118: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 871us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.7099 - val_accuracy: 0.9310
# Epoch 119/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.3862e-09 - accuracy: 1.0000
# Epoch 00119: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 851us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.7109 - val_accuracy: 0.9310
# Epoch 120/250
# 420/460 [==========================>...] - ETA: 0s - loss: 8.5149e-10 - accuracy: 1.0000
# Epoch 00120: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 860us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.7118 - val_accuracy: 0.9310
# Epoch 121/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.3862e-09 - accuracy: 1.0000
# Epoch 00121: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 891us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.7127 - val_accuracy: 0.9310
# Epoch 122/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.3862e-09 - accuracy: 1.0000
# Epoch 00122: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 879us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.7138 - val_accuracy: 0.9310
# Epoch 123/250
# 430/460 [===========================>..] - ETA: 0s - loss: 8.3169e-10 - accuracy: 1.0000
# Epoch 00123: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 886us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.7147 - val_accuracy: 0.9310
# Epoch 124/250
# 430/460 [===========================>..] - ETA: 0s - loss: 8.3169e-10 - accuracy: 1.0000
# Epoch 00124: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 872us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.7155 - val_accuracy: 0.9310
# Epoch 125/250
# 420/460 [==========================>...] - ETA: 0s - loss: 8.5149e-10 - accuracy: 1.0000
# Epoch 00125: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 878us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.7164 - val_accuracy: 0.9310
# Epoch 126/250
# 420/460 [==========================>...] - ETA: 0s - loss: 8.5149e-10 - accuracy: 1.0000
# Epoch 00126: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 893us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.7171 - val_accuracy: 0.9310
# Epoch 127/250
# 430/460 [===========================>..] - ETA: 0s - loss: 5.5446e-10 - accuracy: 1.0000
# Epoch 00127: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 860us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.7177 - val_accuracy: 0.9310
# Epoch 128/250
# 430/460 [===========================>..] - ETA: 0s - loss: 8.3169e-10 - accuracy: 1.0000
# Epoch 00128: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 881us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.7188 - val_accuracy: 0.9310
# Epoch 129/250
# 430/460 [===========================>..] - ETA: 0s - loss: 8.3169e-10 - accuracy: 1.0000
# Epoch 00129: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 884us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.7197 - val_accuracy: 0.9310
# Epoch 130/250
# 430/460 [===========================>..] - ETA: 0s - loss: 5.5446e-10 - accuracy: 1.0000
# Epoch 00130: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 887us/sample - loss: 5.1830e-10 - accuracy: 1.0000 - val_loss: 0.7205 - val_accuracy: 0.9310
# Epoch 131/250
# 430/460 [===========================>..] - ETA: 0s - loss: 5.5446e-10 - accuracy: 1.0000
# Epoch 00131: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 871us/sample - loss: 5.1830e-10 - accuracy: 1.0000 - val_loss: 0.7211 - val_accuracy: 0.9310
# Epoch 132/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.7723e-10 - accuracy: 1.0000
# Epoch 00132: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 868us/sample - loss: 5.1830e-10 - accuracy: 1.0000 - val_loss: 0.7219 - val_accuracy: 0.9310
# Epoch 133/250
# 420/460 [==========================>...] - ETA: 0s - loss: 2.8383e-10 - accuracy: 1.0000
# Epoch 00133: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 890us/sample - loss: 5.1830e-10 - accuracy: 1.0000 - val_loss: 0.7226 - val_accuracy: 0.9310
# Epoch 134/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.7723e-10 - accuracy: 1.0000
# Epoch 00134: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 878us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7233 - val_accuracy: 0.9310
# Epoch 135/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.7723e-10 - accuracy: 1.0000
# Epoch 00135: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 900us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7240 - val_accuracy: 0.9310
# Epoch 136/250
# 420/460 [==========================>...] - ETA: 0s - loss: 2.8383e-10 - accuracy: 1.0000
# Epoch 00136: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 899us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7247 - val_accuracy: 0.9310
# Epoch 137/250
# 420/460 [==========================>...] - ETA: 0s - loss: 2.8383e-10 - accuracy: 1.0000
# Epoch 00137: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 903us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7253 - val_accuracy: 0.9310
# Epoch 138/250
# 410/460 [=========================>....] - ETA: 0s - loss: 2.9075e-10 - accuracy: 1.0000
# Epoch 00138: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 905us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7260 - val_accuracy: 0.9310
# Epoch 139/250
# 420/460 [==========================>...] - ETA: 0s - loss: 2.8383e-10 - accuracy: 1.0000
# Epoch 00139: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 890us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7266 - val_accuracy: 0.9310
# Epoch 140/250
# 420/460 [==========================>...] - ETA: 0s - loss: 2.8383e-10 - accuracy: 1.0000
# Epoch 00140: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 862us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7273 - val_accuracy: 0.9310
# Epoch 141/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.7723e-10 - accuracy: 1.0000
# Epoch 00141: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 868us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7278 - val_accuracy: 0.9310
# Epoch 142/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.7723e-10 - accuracy: 1.0000
# Epoch 00142: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 874us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7285 - val_accuracy: 0.9310
# Epoch 143/250
# 420/460 [==========================>...] - ETA: 0s - loss: 2.8383e-10 - accuracy: 1.0000
# Epoch 00143: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 877us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7291 - val_accuracy: 0.9310
# Epoch 144/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.7723e-10 - accuracy: 1.0000
# Epoch 00144: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 866us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7300 - val_accuracy: 0.9310
# Epoch 145/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.7723e-10 - accuracy: 1.0000
# Epoch 00145: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 875us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7306 - val_accuracy: 0.9310
# Epoch 146/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.7723e-10 - accuracy: 1.0000
# Epoch 00146: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 881us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7312 - val_accuracy: 0.9310
# Epoch 147/250
# 420/460 [==========================>...] - ETA: 0s - loss: 2.8383e-10 - accuracy: 1.0000
# Epoch 00147: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 880us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7316 - val_accuracy: 0.9310
# Epoch 148/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.7723e-10 - accuracy: 1.0000
# Epoch 00148: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 887us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7325 - val_accuracy: 0.9310
# Epoch 149/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.7723e-10 - accuracy: 1.0000
# Epoch 00149: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 880us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7329 - val_accuracy: 0.9310
# Epoch 150/250
# 420/460 [==========================>...] - ETA: 0s - loss: 2.8383e-10 - accuracy: 1.0000
# Epoch 00150: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 872us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7339 - val_accuracy: 0.9310
# Epoch 151/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00151: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 929us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7344 - val_accuracy: 0.9310
# Epoch 152/250
# 410/460 [=========================>....] - ETA: 0s - loss: 2.9075e-10 - accuracy: 1.0000
# Epoch 00152: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 914us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7351 - val_accuracy: 0.9310
# Epoch 153/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.7723e-10 - accuracy: 1.0000
# Epoch 00153: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 900us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7358 - val_accuracy: 0.9310
# Epoch 154/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.7723e-10 - accuracy: 1.0000
# Epoch 00154: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 883us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7364 - val_accuracy: 0.9310
# Epoch 155/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.7723e-10 - accuracy: 1.0000
# Epoch 00155: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 864us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7369 - val_accuracy: 0.9310
# Epoch 156/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.7723e-10 - accuracy: 1.0000
# Epoch 00156: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 893us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7378 - val_accuracy: 0.9310
# Epoch 157/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.7723e-10 - accuracy: 1.0000
# Epoch 00157: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 886us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7382 - val_accuracy: 0.9310
# Epoch 158/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.7723e-10 - accuracy: 1.0000
# Epoch 00158: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 876us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7389 - val_accuracy: 0.9310
# Epoch 159/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.7723e-10 - accuracy: 1.0000
# Epoch 00159: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 873us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7397 - val_accuracy: 0.9310
# Epoch 160/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.7723e-10 - accuracy: 1.0000
# Epoch 00160: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 879us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7403 - val_accuracy: 0.9310
# Epoch 161/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.7723e-10 - accuracy: 1.0000
# Epoch 00161: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 871us/sample - loss: 2.5915e-10 - accuracy: 1.0000 - val_loss: 0.7410 - val_accuracy: 0.9310
# Epoch 162/250
# 430/460 [===========================>..] - ETA: 0s - loss: 2.7723e-10 - accuracy: 1.0000
# Epoch 00162: val_accuracy did not improve from 0.94828
# ...
# Epoch 00197: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 919us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7628 - val_accuracy: 0.9310
# Epoch 198/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00198: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 874us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7633 - val_accuracy: 0.9310
# Epoch 199/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00199: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 962us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7637 - val_accuracy: 0.9310
# Epoch 200/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00200: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 875us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7642 - val_accuracy: 0.9310
# Epoch 201/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00201: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 919us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7647 - val_accuracy: 0.9310
# Epoch 202/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00202: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 882us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7652 - val_accuracy: 0.9310
# Epoch 203/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00203: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 868us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7656 - val_accuracy: 0.9310
# Epoch 204/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00204: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 883us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7660 - val_accuracy: 0.9310
# Epoch 205/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00205: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 873us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7665 - val_accuracy: 0.9397
# Epoch 206/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00206: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 856us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7670 - val_accuracy: 0.9397
# Epoch 207/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00207: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 865us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7674 - val_accuracy: 0.9397
# Epoch 208/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00208: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 861us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7679 - val_accuracy: 0.9397
# Epoch 209/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00209: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 862us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7681 - val_accuracy: 0.9397
# Epoch 210/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00210: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 920us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7685 - val_accuracy: 0.9397
# Epoch 211/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00211: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 895us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7692 - val_accuracy: 0.9397
# Epoch 212/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00212: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 896us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7696 - val_accuracy: 0.9397
# Epoch 213/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00213: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 900us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7701 - val_accuracy: 0.9397
# Epoch 214/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00214: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 868us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7705 - val_accuracy: 0.9397
# Epoch 215/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00215: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 865us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7709 - val_accuracy: 0.9397
# Epoch 216/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00216: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 911us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7712 - val_accuracy: 0.9397
# Epoch 217/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00217: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 898us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7718 - val_accuracy: 0.9397
# Epoch 218/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00218: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 911us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7722 - val_accuracy: 0.9397
# Epoch 219/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00219: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 878us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7727 - val_accuracy: 0.9397
# Epoch 220/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00220: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 878us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7731 - val_accuracy: 0.9397
# Epoch 221/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00221: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 873us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7735 - val_accuracy: 0.9397
# Epoch 222/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00222: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 867us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7738 - val_accuracy: 0.9397
# Epoch 223/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00223: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 877us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7744 - val_accuracy: 0.9397
# Epoch 224/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00224: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 894us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7748 - val_accuracy: 0.9397
# Epoch 225/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00225: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 871us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7753 - val_accuracy: 0.9397
# Epoch 226/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00226: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 863us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7756 - val_accuracy: 0.9397
# Epoch 227/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00227: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 839us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7761 - val_accuracy: 0.9397
# Epoch 228/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00228: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 852us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7766 - val_accuracy: 0.9397
# Epoch 229/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00229: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 835us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7769 - val_accuracy: 0.9397
# Epoch 230/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00230: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 878us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7774 - val_accuracy: 0.9397
# Epoch 231/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00231: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 912us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7778 - val_accuracy: 0.9397
# Epoch 232/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00232: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 851us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7782 - val_accuracy: 0.9397
# Epoch 233/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00233: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 860us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7786 - val_accuracy: 0.9397
# Epoch 234/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00234: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 874us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7788 - val_accuracy: 0.9397
# Epoch 235/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00235: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 860us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7794 - val_accuracy: 0.9397
# Epoch 236/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00236: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 880us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7799 - val_accuracy: 0.9397
# Epoch 237/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00237: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 873us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7803 - val_accuracy: 0.9397
# Epoch 238/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00238: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 894us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7807 - val_accuracy: 0.9397
# Epoch 239/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00239: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 899us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7811 - val_accuracy: 0.9397
# Epoch 240/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00240: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 862us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7815 - val_accuracy: 0.9397
# Epoch 241/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00241: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 864us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7818 - val_accuracy: 0.9397
# Epoch 242/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00242: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 867us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7824 - val_accuracy: 0.9397
# Epoch 243/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00243: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 868us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7828 - val_accuracy: 0.9397
# Epoch 244/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00244: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 897us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7831 - val_accuracy: 0.9397
# Epoch 245/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00245: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 873us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7834 - val_accuracy: 0.9397
# Epoch 246/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00246: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 894us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7839 - val_accuracy: 0.9397
# Epoch 247/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00247: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 904us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7843 - val_accuracy: 0.9397
# Epoch 248/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00248: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 894us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7846 - val_accuracy: 0.9397
# Epoch 249/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00249: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 896us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7851 - val_accuracy: 0.9397
# Epoch 250/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00250: val_accuracy did not improve from 0.94828
# 460/460 [==============================] - 0s 888us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.7856 - val_accuracy: 0.9397
# Training completed in time:  0:01:45.331214

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste
#
# Lembrando que estamos utilizando o mesmo conjunto de validacão, que a princípio, pode incluir instâncias do conjunto de treinamento: o dataset utilizado foi gerado com corte de áudio, então alguns trechos do mesmo áudio podem estar presentes em ambos os conjuntos de treinamento e teste.
# Por ora deixamos assim já que estamos realizando uma investigacão inicial.

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  1.0
# Testing Accuracy:  0.9396552

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.96      0.91      0.94        56
#    Pneumonia       0.92      0.97      0.94        60
#
#     accuracy                           0.94       116
#    macro avg       0.94      0.94      0.94       116
# weighted avg       0.94      0.94      0.94       116

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[51  5]
#  [ 2 58]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])
