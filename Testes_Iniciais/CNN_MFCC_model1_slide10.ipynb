# %% [markdown]
# # Rede CNN - Modelo 1
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - slide10

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP = 'slide10'
MAX_PAD_LEN = 431

# %%
filepaths = glob.glob(f'./datasets/{GROUP}/**/*.wav', recursive=True)
filenames = [os.path.splitext(os.path.basename(p))[0] for p in filepaths]

# %%
p_id_in_file = [] # patient IDs corresponding to each file
for name in filenames:
    p_id_in_file.append(int(name[:3]))

p_id_in_file = np.array(p_id_in_file)

# %%
max_pad_len =  MAX_PAD_LEN

os.makedirs("./Respiratory_Sound_Database/features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=10) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./Respiratory_Sound_Database/features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
p_diag = pd.read_csv("./Respiratory_Sound_Database/Respiratory_Sound_Database/patient_diagnosis.csv",header=None) # patient diagnosis file

# %%
labels = np.array([p_diag[p_diag[0] == x][1].values[0] for x in p_id_in_file]) # labels for audio files

# %%
features = [] 

# Iterate through each sound file and extract the features
for file_name in filepaths:
    data = extract_features(file_name)
    features.append(data)

print('Finished feature extraction from ', len(features), ' files')
features = np.array(features)
# Out:
# Finished feature extraction from  576  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(features[1], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
features = np.array(features) # convert to numpy array

# %%
np.unique(labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
# delete diseases
'''
features1 = features
labels1 = labels'''

features1 = np.delete(features, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0) 

labels1 = np.delete(labels, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0)

# %%
# print class counts
unique_elements, counts_elements = np.unique(labels1, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['280' '296']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(labels1)
oh_labels = to_categorical(i_labels)

# %%
features1.shape
# Out:
# (576, 40, 431)

# %%
# add channel dimension for CNN
features1 = np.reshape(features1, (*features1.shape,1)) 

# train test split
x_train, x_test, y_train, y_test = train_test_split(features1, oh_labels, stratify=oh_labels, 
                                                    test_size=0.2, random_state = 42)

# %% [markdown]
# **MLP model architecture**

# %%
num_rows = 40
num_columns = 431
num_channels = 1

num_labels = oh_labels.shape[1]
filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 430, 16)       80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 215, 16)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 215, 16)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 214, 32)       2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 107, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 107, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 106, 64)        8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 53, 64)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 53, 64)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 52, 128)        32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 26, 128)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 26, 128)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 258
# =================================================================
# Total params: 43,570
# Trainable params: 43,570
# Non-trainable params: 0
# _________________________________________________________________
# 116/116 [==============================] - 1s 13ms/sample - loss: 1.2487 - accuracy: 0.5172
# Pre-training accuracy: 51.7241%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 250
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/model2_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 460 samples, validate on 116 samples
# Epoch 1/250
# 450/460 [============================>.] - ETA: 0s - loss: 2.1311 - accuracy: 0.5756
# Epoch 00001: val_accuracy improved from -inf to 0.48276, saving model to models/model2_01.h5
# 460/460 [==============================] - 1s 3ms/sample - loss: 2.0973 - accuracy: 0.5804 - val_loss: 0.8534 - val_accuracy: 0.4828
# Epoch 2/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.7766 - accuracy: 0.6244
# Epoch 00002: val_accuracy improved from 0.48276 to 0.56034, saving model to models/model2_02.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.7626 - accuracy: 0.6304 - val_loss: 0.6923 - val_accuracy: 0.5603
# Epoch 3/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.5755 - accuracy: 0.7091
# Epoch 00003: val_accuracy improved from 0.56034 to 0.77586, saving model to models/model2_03.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.5706 - accuracy: 0.7109 - val_loss: 0.5408 - val_accuracy: 0.7759
# Epoch 4/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.5454 - accuracy: 0.7415
# Epoch 00004: val_accuracy improved from 0.77586 to 0.84483, saving model to models/model2_04.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.5505 - accuracy: 0.7370 - val_loss: 0.4368 - val_accuracy: 0.8448
# Epoch 5/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.4653 - accuracy: 0.7800
# Epoch 00005: val_accuracy did not improve from 0.84483
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.4658 - accuracy: 0.7804 - val_loss: 0.4084 - val_accuracy: 0.8276
# Epoch 6/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.3544 - accuracy: 0.8429
# Epoch 00006: val_accuracy improved from 0.84483 to 0.87069, saving model to models/model2_06.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.3485 - accuracy: 0.8435 - val_loss: 0.3647 - val_accuracy: 0.8707
# Epoch 7/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.3358 - accuracy: 0.8429
# Epoch 00007: val_accuracy did not improve from 0.87069
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.3457 - accuracy: 0.8435 - val_loss: 0.4206 - val_accuracy: 0.8362
# Epoch 8/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.2789 - accuracy: 0.8829
# Epoch 00008: val_accuracy did not improve from 0.87069
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2682 - accuracy: 0.8848 - val_loss: 0.3398 - val_accuracy: 0.8707
# Epoch 9/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.2650 - accuracy: 0.8791
# Epoch 00009: val_accuracy improved from 0.87069 to 0.87931, saving model to models/model2_09.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2664 - accuracy: 0.8783 - val_loss: 0.3153 - val_accuracy: 0.8793
# Epoch 10/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.2856 - accuracy: 0.8773
# Epoch 00010: val_accuracy did not improve from 0.87931
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2838 - accuracy: 0.8783 - val_loss: 0.3143 - val_accuracy: 0.8793
# Epoch 11/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.2330 - accuracy: 0.8976
# Epoch 00011: val_accuracy did not improve from 0.87931
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2327 - accuracy: 0.8957 - val_loss: 0.2863 - val_accuracy: 0.8448
# Epoch 12/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2322 - accuracy: 0.8929
# Epoch 00012: val_accuracy improved from 0.87931 to 0.88793, saving model to models/model2_12.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2285 - accuracy: 0.8935 - val_loss: 0.2522 - val_accuracy: 0.8879
# Epoch 13/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.3000 - accuracy: 0.8814
# Epoch 00013: val_accuracy did not improve from 0.88793
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2954 - accuracy: 0.8826 - val_loss: 0.2559 - val_accuracy: 0.8621
# Epoch 14/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1766 - accuracy: 0.9262
# Epoch 00014: val_accuracy did not improve from 0.88793
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1746 - accuracy: 0.9261 - val_loss: 0.2762 - val_accuracy: 0.8621
# Epoch 15/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.2456 - accuracy: 0.8805
# Epoch 00015: val_accuracy improved from 0.88793 to 0.91379, saving model to models/model2_15.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2465 - accuracy: 0.8804 - val_loss: 0.2524 - val_accuracy: 0.9138
# Epoch 16/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1881 - accuracy: 0.9143
# Epoch 00016: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1914 - accuracy: 0.9152 - val_loss: 0.2394 - val_accuracy: 0.8966
# Epoch 17/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1854 - accuracy: 0.9190
# Epoch 00017: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1809 - accuracy: 0.9217 - val_loss: 0.1923 - val_accuracy: 0.8879
# Epoch 18/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.3045 - accuracy: 0.8705
# Epoch 00018: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.3218 - accuracy: 0.8674 - val_loss: 0.2443 - val_accuracy: 0.8793
# Epoch 19/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.1693 - accuracy: 0.9273
# Epoch 00019: val_accuracy did not improve from 0.91379
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1657 - accuracy: 0.9283 - val_loss: 0.2345 - val_accuracy: 0.9052
# Epoch 20/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.1581 - accuracy: 0.9273
# Epoch 00020: val_accuracy improved from 0.91379 to 0.93966, saving model to models/model2_20.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1563 - accuracy: 0.9283 - val_loss: 0.1845 - val_accuracy: 0.9397
# Epoch 21/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1151 - accuracy: 0.9500
# Epoch 00021: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1290 - accuracy: 0.9370 - val_loss: 0.1721 - val_accuracy: 0.9397
# Epoch 22/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1293 - accuracy: 0.9419
# Epoch 00022: val_accuracy improved from 0.93966 to 0.97414, saving model to models/model2_22.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1220 - accuracy: 0.9457 - val_loss: 0.1220 - val_accuracy: 0.9741
# Epoch 23/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1191 - accuracy: 0.9634
# Epoch 00023: val_accuracy did not improve from 0.97414
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1233 - accuracy: 0.9565 - val_loss: 0.1084 - val_accuracy: 0.9569
# Epoch 24/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1179 - accuracy: 0.9429
# Epoch 00024: val_accuracy did not improve from 0.97414
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1158 - accuracy: 0.9457 - val_loss: 0.1428 - val_accuracy: 0.9483
# Epoch 25/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1038 - accuracy: 0.9595
# Epoch 00025: val_accuracy improved from 0.97414 to 0.98276, saving model to models/model2_25.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1490 - accuracy: 0.9522 - val_loss: 0.1002 - val_accuracy: 0.9828
# Epoch 26/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1560 - accuracy: 0.9372
# Epoch 00026: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1533 - accuracy: 0.9391 - val_loss: 0.1231 - val_accuracy: 0.9569
# Epoch 27/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.1112 - accuracy: 0.9622
# Epoch 00027: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1094 - accuracy: 0.9630 - val_loss: 0.1263 - val_accuracy: 0.9483
# Epoch 28/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0582 - accuracy: 0.9829
# Epoch 00028: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0578 - accuracy: 0.9848 - val_loss: 0.1234 - val_accuracy: 0.9310
# Epoch 29/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0668 - accuracy: 0.9786
# Epoch 00029: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0698 - accuracy: 0.9761 - val_loss: 0.2031 - val_accuracy: 0.9397
# Epoch 30/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0742 - accuracy: 0.9732
# Epoch 00030: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0838 - accuracy: 0.9674 - val_loss: 0.1424 - val_accuracy: 0.9397
# Epoch 31/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1073 - accuracy: 0.9500
# Epoch 00031: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1000 - accuracy: 0.9543 - val_loss: 0.0833 - val_accuracy: 0.9655
# Epoch 32/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0646 - accuracy: 0.9732
# Epoch 00032: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0643 - accuracy: 0.9761 - val_loss: 0.1405 - val_accuracy: 0.9569
# Epoch 33/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0659 - accuracy: 0.9721
# Epoch 00033: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0637 - accuracy: 0.9739 - val_loss: 0.2310 - val_accuracy: 0.9397
# Epoch 34/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0658 - accuracy: 0.9738
# Epoch 00034: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0663 - accuracy: 0.9739 - val_loss: 0.2647 - val_accuracy: 0.9138
# Epoch 35/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0745 - accuracy: 0.9683
# Epoch 00035: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0806 - accuracy: 0.9652 - val_loss: 0.1102 - val_accuracy: 0.9483
# Epoch 36/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0627 - accuracy: 0.9786
# Epoch 00036: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0615 - accuracy: 0.9783 - val_loss: 0.0694 - val_accuracy: 0.9655
# Epoch 37/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0489 - accuracy: 0.9878
# Epoch 00037: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0512 - accuracy: 0.9826 - val_loss: 0.1841 - val_accuracy: 0.9138
# Epoch 38/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0667 - accuracy: 0.9690
# Epoch 00038: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0639 - accuracy: 0.9717 - val_loss: 0.1170 - val_accuracy: 0.9397
# Epoch 39/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1182 - accuracy: 0.9512
# Epoch 00039: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1159 - accuracy: 0.9500 - val_loss: 0.5622 - val_accuracy: 0.9052
# Epoch 40/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0308 - accuracy: 0.9878
# Epoch 00040: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0321 - accuracy: 0.9891 - val_loss: 0.1012 - val_accuracy: 0.9483
# Epoch 41/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0319 - accuracy: 0.9907
# Epoch 00041: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0372 - accuracy: 0.9870 - val_loss: 0.3080 - val_accuracy: 0.8879
# Epoch 42/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0438 - accuracy: 0.9867
# Epoch 00042: val_accuracy improved from 0.98276 to 1.00000, saving model to models/model2_42.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0432 - accuracy: 0.9870 - val_loss: 0.0382 - val_accuracy: 1.0000
# Epoch 43/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0377 - accuracy: 0.9875
# Epoch 00043: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0386 - accuracy: 0.9870 - val_loss: 0.1858 - val_accuracy: 0.9224
# Epoch 44/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0169 - accuracy: 0.9976
# Epoch 00044: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0157 - accuracy: 0.9978 - val_loss: 0.0633 - val_accuracy: 0.9655
# Epoch 45/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0213 - accuracy: 0.9951
# Epoch 00045: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0204 - accuracy: 0.9957 - val_loss: 0.0825 - val_accuracy: 0.9655
# Epoch 46/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0212 - accuracy: 0.9929
# Epoch 00046: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0202 - accuracy: 0.9935 - val_loss: 0.1440 - val_accuracy: 0.9569
# Epoch 47/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0989 - accuracy: 0.9585
# Epoch 00047: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0925 - accuracy: 0.9630 - val_loss: 0.1285 - val_accuracy: 0.9655
# Epoch 48/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0340 - accuracy: 0.9951
# Epoch 00048: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0311 - accuracy: 0.9957 - val_loss: 0.0525 - val_accuracy: 0.9828
# Epoch 49/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0320 - accuracy: 0.9833
# Epoch 00049: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0337 - accuracy: 0.9826 - val_loss: 0.0818 - val_accuracy: 0.9741
# Epoch 50/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0219 - accuracy: 0.9911
# Epoch 00050: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0240 - accuracy: 0.9891 - val_loss: 0.0480 - val_accuracy: 0.9828
# Epoch 51/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0283 - accuracy: 0.9929
# Epoch 00051: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0429 - accuracy: 0.9870 - val_loss: 0.0807 - val_accuracy: 0.9655
# Epoch 52/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1332 - accuracy: 0.9537
# Epoch 00052: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1217 - accuracy: 0.9565 - val_loss: 0.1056 - val_accuracy: 0.9655
# Epoch 53/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0263 - accuracy: 0.9929
# Epoch 00053: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0310 - accuracy: 0.9913 - val_loss: 0.0559 - val_accuracy: 0.9828
# Epoch 54/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0203 - accuracy: 0.9951
# Epoch 00054: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0223 - accuracy: 0.9957 - val_loss: 0.1783 - val_accuracy: 0.9483
# Epoch 55/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0434 - accuracy: 0.9829
# Epoch 00055: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0471 - accuracy: 0.9804 - val_loss: 0.0568 - val_accuracy: 0.9655
# Epoch 56/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0649 - accuracy: 0.9698
# Epoch 00056: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0701 - accuracy: 0.9674 - val_loss: 0.1326 - val_accuracy: 0.9569
# Epoch 57/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0419 - accuracy: 0.9829
# Epoch 00057: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0428 - accuracy: 0.9826 - val_loss: 0.0536 - val_accuracy: 0.9828
# Epoch 58/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0161 - accuracy: 0.9952
# Epoch 00058: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0184 - accuracy: 0.9935 - val_loss: 0.1248 - val_accuracy: 0.9655
# Epoch 59/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0161 - accuracy: 0.9955
# Epoch 00059: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0156 - accuracy: 0.9957 - val_loss: 0.0393 - val_accuracy: 0.9914
# Epoch 60/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0158 - accuracy: 0.9953
# Epoch 00060: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0150 - accuracy: 0.9957 - val_loss: 0.1694 - val_accuracy: 0.9569
# Epoch 61/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0108 - accuracy: 0.9976
# Epoch 00061: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0118 - accuracy: 0.9978 - val_loss: 0.0645 - val_accuracy: 0.9741
# Epoch 62/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0177 - accuracy: 0.9976
# Epoch 00062: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0174 - accuracy: 0.9978 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 63/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0118 - accuracy: 0.9976
# Epoch 00063: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0120 - accuracy: 0.9978 - val_loss: 0.0252 - val_accuracy: 1.0000
# Epoch 64/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0255 - accuracy: 0.9905
# Epoch 00064: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0242 - accuracy: 0.9913 - val_loss: 0.0813 - val_accuracy: 0.9655
# Epoch 65/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0537 - accuracy: 0.9756
# Epoch 00065: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0535 - accuracy: 0.9739 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 66/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0498 - accuracy: 0.9810
# Epoch 00066: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0466 - accuracy: 0.9826 - val_loss: 0.1158 - val_accuracy: 0.9569
# Epoch 67/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0226 - accuracy: 0.9927
# Epoch 00067: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0217 - accuracy: 0.9935 - val_loss: 0.0486 - val_accuracy: 0.9655
# Epoch 68/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0202 - accuracy: 0.9933
# Epoch 00068: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0204 - accuracy: 0.9935 - val_loss: 0.1659 - val_accuracy: 0.9569
# Epoch 69/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0125 - accuracy: 0.9976
# Epoch 00069: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0128 - accuracy: 0.9978 - val_loss: 0.0235 - val_accuracy: 0.9914
# Epoch 70/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0098 - accuracy: 0.9976
# Epoch 00070: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0092 - accuracy: 0.9978 - val_loss: 0.0561 - val_accuracy: 0.9741
# Epoch 71/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0412 - accuracy: 0.9829
# Epoch 00071: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0372 - accuracy: 0.9848 - val_loss: 0.0836 - val_accuracy: 0.9741
# Epoch 72/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0552 - accuracy: 0.9780
# Epoch 00072: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0500 - accuracy: 0.9804 - val_loss: 0.0263 - val_accuracy: 1.0000
# Epoch 73/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0297 - accuracy: 0.9905
# Epoch 00073: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0276 - accuracy: 0.9913 - val_loss: 0.0277 - val_accuracy: 1.0000
# Epoch 74/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0202 - accuracy: 0.9929
# Epoch 00074: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0193 - accuracy: 0.9935 - val_loss: 0.0282 - val_accuracy: 0.9828
# Epoch 75/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 00075: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0523 - val_accuracy: 0.9655
# Epoch 76/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0117 - accuracy: 0.9976
# Epoch 00076: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0106 - accuracy: 0.9978 - val_loss: 0.0948 - val_accuracy: 0.9655
# Epoch 77/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0172 - accuracy: 0.9929
# Epoch 00077: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0167 - accuracy: 0.9935 - val_loss: 0.1607 - val_accuracy: 0.9397
# Epoch 78/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0612 - accuracy: 0.9829
# Epoch 00078: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0573 - accuracy: 0.9826 - val_loss: 0.0159 - val_accuracy: 1.0000
# Epoch 79/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0636 - accuracy: 0.9810
# Epoch 00079: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0602 - accuracy: 0.9826 - val_loss: 0.1612 - val_accuracy: 0.9052
# Epoch 80/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0233 - accuracy: 0.9927
# Epoch 00080: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0261 - accuracy: 0.9913 - val_loss: 0.0145 - val_accuracy: 1.0000
# Epoch 81/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0093 - accuracy: 0.9976
# Epoch 00081: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0085 - accuracy: 0.9978 - val_loss: 0.0572 - val_accuracy: 0.9741
# Epoch 82/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0168 - accuracy: 0.9951
# Epoch 00082: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0177 - accuracy: 0.9935 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 83/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0453 - accuracy: 0.9867
# Epoch 00083: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0498 - accuracy: 0.9848 - val_loss: 0.0450 - val_accuracy: 0.9741
# Epoch 84/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0584 - accuracy: 0.9829
# Epoch 00084: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0565 - accuracy: 0.9826 - val_loss: 0.0251 - val_accuracy: 1.0000
# Epoch 85/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0295 - accuracy: 0.9867
# Epoch 00085: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0291 - accuracy: 0.9870 - val_loss: 0.0182 - val_accuracy: 1.0000
# Epoch 86/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0086 - accuracy: 1.0000
# Epoch 00086: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 1.0000
# Epoch 87/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 00087: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0070 - accuracy: 0.9978 - val_loss: 0.0283 - val_accuracy: 0.9914
# Epoch 88/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 00088: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0580 - val_accuracy: 0.9569
# Epoch 89/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0269 - accuracy: 0.9884
# Epoch 00089: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0384 - accuracy: 0.9848 - val_loss: 0.0364 - val_accuracy: 0.9828
# Epoch 90/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1077 - accuracy: 0.9683
# Epoch 00090: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1171 - accuracy: 0.9674 - val_loss: 0.1603 - val_accuracy: 0.9310
# Epoch 91/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0377 - accuracy: 0.9905
# Epoch 00091: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0348 - accuracy: 0.9913 - val_loss: 0.0166 - val_accuracy: 1.0000
# Epoch 92/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 00092: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 1.0000
# Epoch 93/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 00093: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0226 - val_accuracy: 1.0000
# Epoch 94/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0061 - accuracy: 1.0000
# Epoch 00094: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0154 - val_accuracy: 1.0000
# Epoch 95/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0146 - accuracy: 0.9952
# Epoch 00095: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0140 - accuracy: 0.9957 - val_loss: 0.0360 - val_accuracy: 0.9828
# Epoch 96/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0112 - accuracy: 0.9952
# Epoch 00096: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0110 - accuracy: 0.9957 - val_loss: 0.0105 - val_accuracy: 1.0000
# Epoch 97/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 00097: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0061 - accuracy: 0.9978 - val_loss: 0.0185 - val_accuracy: 0.9914
# Epoch 98/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0481 - accuracy: 0.9833
# Epoch 00098: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0567 - accuracy: 0.9761 - val_loss: 0.0293 - val_accuracy: 0.9828
# Epoch 99/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0305 - accuracy: 0.9857
# Epoch 00099: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0282 - accuracy: 0.9870 - val_loss: 0.0342 - val_accuracy: 0.9828
# Epoch 100/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0058 - accuracy: 1.0000
# Epoch 00100: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 1.0000
# Epoch 101/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 00101: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 102/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 00102: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 103/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 00103: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 104/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0098 - accuracy: 0.9953
# Epoch 00104: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0093 - accuracy: 0.9957 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 105/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 00105: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 106/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 00106: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 107/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0143 - accuracy: 0.9927
# Epoch 00107: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0128 - accuracy: 0.9935 - val_loss: 0.0150 - val_accuracy: 0.9914
# Epoch 108/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000
# Epoch 00108: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 109/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 00109: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 110/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0128 - accuracy: 0.9956
# Epoch 00110: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0126 - accuracy: 0.9957 - val_loss: 0.0330 - val_accuracy: 0.9741
# Epoch 111/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 00111: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 112/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0153 - accuracy: 0.9952
# Epoch 00112: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0142 - accuracy: 0.9957 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 113/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0743 - accuracy: 0.9714
# Epoch 00113: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0719 - accuracy: 0.9717 - val_loss: 0.0128 - val_accuracy: 1.0000
# Epoch 114/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1924 - accuracy: 0.9442
# Epoch 00114: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1827 - accuracy: 0.9457 - val_loss: 0.1444 - val_accuracy: 0.9741
# Epoch 115/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0247 - accuracy: 0.9951
# Epoch 00115: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0263 - accuracy: 0.9935 - val_loss: 0.0277 - val_accuracy: 0.9741
# Epoch 116/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0439 - accuracy: 0.9810
# Epoch 00116: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0402 - accuracy: 0.9826 - val_loss: 0.0324 - val_accuracy: 1.0000
# Epoch 117/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0207 - accuracy: 0.9929
# Epoch 00117: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0191 - accuracy: 0.9935 - val_loss: 0.0107 - val_accuracy: 1.0000
# Epoch 118/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0069 - accuracy: 0.9976
# Epoch 00118: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0070 - accuracy: 0.9978 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 119/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0075 - accuracy: 0.9976
# Epoch 00119: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0067 - accuracy: 0.9978 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 120/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0056 - accuracy: 1.0000
# Epoch 00120: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0133 - val_accuracy: 0.9914
# Epoch 121/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 00121: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 122/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 00122: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 123/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000
# Epoch 00123: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 124/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0349 - accuracy: 0.9905
# Epoch 00124: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0352 - accuracy: 0.9891 - val_loss: 0.1060 - val_accuracy: 0.9741
# Epoch 125/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0125 - accuracy: 0.9976
# Epoch 00125: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0129 - accuracy: 0.9978 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 126/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 00126: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 127/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 00127: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 128/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 00128: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0044 - accuracy: 0.9978 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 129/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0062 - accuracy: 0.9955
# Epoch 00129: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0061 - accuracy: 0.9957 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 130/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0251 - accuracy: 0.9905
# Epoch 00130: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0295 - accuracy: 0.9891 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 131/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0191 - accuracy: 0.9909
# Epoch 00131: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0183 - accuracy: 0.9913 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 132/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 00132: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 133/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 00133: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 134/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000
# Epoch 00134: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 135/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 00135: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 136/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00136: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 137/250
# 420/460 [==========================>...] - ETA: 0s - loss: 9.9097e-04 - accuracy: 1.0000
# Epoch 00137: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 9.3165e-04 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 138/250
# 430/460 [===========================>..] - ETA: 0s - loss: 6.8986e-04 - accuracy: 1.0000
# Epoch 00138: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 6.5792e-04 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 139/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0103 - accuracy: 0.9953
# Epoch 00139: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0109 - accuracy: 0.9957 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 140/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0073 - accuracy: 0.9977
# Epoch 00140: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0069 - accuracy: 0.9978 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 141/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0060 - accuracy: 0.9976
# Epoch 00141: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0055 - accuracy: 0.9978 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 142/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 00142: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 143/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00143: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 144/250
# 420/460 [==========================>...] - ETA: 0s - loss: 9.2487e-04 - accuracy: 1.0000
# Epoch 00144: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 8.7121e-04 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 145/250
# 420/460 [==========================>...] - ETA: 0s - loss: 5.2479e-04 - accuracy: 1.0000
# Epoch 00145: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 146/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 00146: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0064 - accuracy: 0.9978 - val_loss: 0.0588 - val_accuracy: 0.9741
# Epoch 147/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0179 - accuracy: 0.9951
# Epoch 00147: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0185 - accuracy: 0.9935 - val_loss: 0.0160 - val_accuracy: 0.9914
# Epoch 148/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.1737 - accuracy: 0.9595
# Epoch 00148: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2106 - accuracy: 0.9565 - val_loss: 0.4361 - val_accuracy: 0.9224
# Epoch 149/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.1123 - accuracy: 0.9628
# Epoch 00149: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1053 - accuracy: 0.9652 - val_loss: 0.0660 - val_accuracy: 0.9655
# Epoch 150/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0093 - accuracy: 1.0000
# Epoch 00150: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 151/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0078 - accuracy: 0.9978
# Epoch 00151: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0077 - accuracy: 0.9978 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 152/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 00152: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 153/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 00153: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 154/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0027 - accuracy: 1.0000
# Epoch 00154: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 155/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00155: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 1.0000
# Epoch 156/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000
# Epoch 00156: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 157/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 00157: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 158/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 00158: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 159/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0107 - accuracy: 0.9976
# Epoch 00159: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0099 - accuracy: 0.9978 - val_loss: 0.0269 - val_accuracy: 0.9914
# Epoch 160/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0586 - accuracy: 0.9762
# Epoch 00160: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0572 - accuracy: 0.9739 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 161/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 00161: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 162/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 00162: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 163/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 00163: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 164/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000
# Epoch 00164: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 165/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00165: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 166/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00166: val_accuracy did not improve from 1.00000
# ...
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 197/250
# 450/460 [============================>.] - ETA: 0s - loss: 7.4898e-04 - accuracy: 1.0000
# Epoch 00197: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 7.3342e-04 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 198/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00198: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0016 - accuracy: 1.0000 - val_loss: 7.4678e-04 - val_accuracy: 1.0000
# Epoch 199/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00199: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0015 - accuracy: 1.0000 - val_loss: 7.5108e-04 - val_accuracy: 1.0000
# Epoch 200/250
# 420/460 [==========================>...] - ETA: 0s - loss: 5.7615e-04 - accuracy: 1.0000
# Epoch 00200: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 5.4987e-04 - accuracy: 1.0000 - val_loss: 9.3420e-04 - val_accuracy: 1.0000
# Epoch 201/250
# 410/460 [=========================>....] - ETA: 0s - loss: 7.4516e-04 - accuracy: 1.0000
# Epoch 00201: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 7.9135e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 202/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00202: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 203/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00203: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 9.7845e-04 - accuracy: 1.0000 - val_loss: 8.8494e-04 - val_accuracy: 1.0000
# Epoch 204/250
# 450/460 [============================>.] - ETA: 0s - loss: 1.6912e-04 - accuracy: 1.0000
# Epoch 00204: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 1.6555e-04 - accuracy: 1.0000 - val_loss: 6.1400e-04 - val_accuracy: 1.0000
# Epoch 205/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0040 - accuracy: 0.9978
# Epoch 00205: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0040 - accuracy: 0.9978 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 206/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.1112 - accuracy: 0.9644
# Epoch 00206: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1088 - accuracy: 0.9652 - val_loss: 0.0430 - val_accuracy: 0.9741
# Epoch 207/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0394 - accuracy: 0.9878
# Epoch 00207: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0356 - accuracy: 0.9891 - val_loss: 0.0108 - val_accuracy: 1.0000
# Epoch 208/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0115 - accuracy: 0.9955
# Epoch 00208: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0111 - accuracy: 0.9957 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 209/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 00209: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 210/250
# 420/460 [==========================>...] - ETA: 0s - loss: 8.9061e-04 - accuracy: 1.0000
# Epoch 00210: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 8.8576e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 211/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0144 - accuracy: 0.9951
# Epoch 00211: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0153 - accuracy: 0.9957 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 212/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 00212: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 213/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 00213: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 214/250
# 450/460 [============================>.] - ETA: 0s - loss: 8.7497e-04 - accuracy: 1.0000
# Epoch 00214: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 8.6446e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 215/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 00215: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0012 - accuracy: 1.0000 - val_loss: 9.2901e-04 - val_accuracy: 1.0000
# Epoch 216/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 00216: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 8.8451e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 217/250
# 430/460 [===========================>..] - ETA: 0s - loss: 5.9347e-04 - accuracy: 1.0000
# Epoch 00217: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 5.7051e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 218/250
# 430/460 [===========================>..] - ETA: 0s - loss: 7.5243e-04 - accuracy: 1.0000
# Epoch 00218: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 7.0432e-04 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 219/250
# 420/460 [==========================>...] - ETA: 0s - loss: 3.0001e-04 - accuracy: 1.0000
# Epoch 00219: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 2.8482e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 220/250
# 430/460 [===========================>..] - ETA: 0s - loss: 8.3546e-04 - accuracy: 1.0000
# Epoch 00220: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 7.8170e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 221/250
# 420/460 [==========================>...] - ETA: 0s - loss: 1.0560e-04 - accuracy: 1.0000
# Epoch 00221: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 1.1496e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 222/250
# 440/460 [===========================>..] - ETA: 0s - loss: 4.6478e-04 - accuracy: 1.0000
# Epoch 00222: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 4.5018e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 223/250
# 450/460 [============================>.] - ETA: 0s - loss: 2.4706e-04 - accuracy: 1.0000
# Epoch 00223: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 2.4288e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 224/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 00224: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0019 - accuracy: 1.0000 - val_loss: 7.1481e-04 - val_accuracy: 1.0000
# Epoch 225/250
# 420/460 [==========================>...] - ETA: 0s - loss: 4.3424e-04 - accuracy: 1.0000
# Epoch 00225: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 6.7367e-04 - accuracy: 1.0000 - val_loss: 8.4381e-04 - val_accuracy: 1.0000
# Epoch 226/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0165 - accuracy: 0.9929
# Epoch 00226: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0152 - accuracy: 0.9935 - val_loss: 0.0222 - val_accuracy: 0.9914
# Epoch 227/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0581 - accuracy: 0.9810
# Epoch 00227: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0578 - accuracy: 0.9804 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 228/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0080 - accuracy: 0.9976
# Epoch 00228: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0082 - accuracy: 0.9978 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 229/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 00229: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 230/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00230: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 231/250
# 410/460 [=========================>....] - ETA: 0s - loss: 8.7728e-04 - accuracy: 1.0000
# Epoch 00231: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 7.9110e-04 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 232/250
# 410/460 [=========================>....] - ETA: 0s - loss: 5.9043e-04 - accuracy: 1.0000
# Epoch 00232: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 6.3386e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 233/250
# 440/460 [===========================>..] - ETA: 0s - loss: 8.8748e-04 - accuracy: 1.0000
# Epoch 00233: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 9.4253e-04 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 234/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0176 - accuracy: 0.9907
# Epoch 00234: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0222 - accuracy: 0.9891 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 235/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0188 - accuracy: 0.9911
# Epoch 00235: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0184 - accuracy: 0.9913 - val_loss: 0.0136 - val_accuracy: 1.0000
# Epoch 236/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0103 - accuracy: 0.9952
# Epoch 00236: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0097 - accuracy: 0.9957 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 237/250
# 410/460 [=========================>....] - ETA: 0s - loss: 4.2489e-04 - accuracy: 1.0000
# Epoch 00237: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 3.8651e-04 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 238/250
# 430/460 [===========================>..] - ETA: 0s - loss: 8.2422e-04 - accuracy: 1.0000
# Epoch 00238: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 7.7129e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 239/250
# 440/460 [===========================>..] - ETA: 0s - loss: 9.4582e-04 - accuracy: 1.0000
# Epoch 00239: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 240/250
# 420/460 [==========================>...] - ETA: 0s - loss: 4.0052e-04 - accuracy: 1.0000
# Epoch 00240: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 3.7165e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 241/250
# 440/460 [===========================>..] - ETA: 0s - loss: 2.8782e-04 - accuracy: 1.0000
# Epoch 00241: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 2.7538e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 242/250
# 420/460 [==========================>...] - ETA: 0s - loss: 6.8711e-04 - accuracy: 1.0000
# Epoch 00242: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 6.2870e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 243/250
# 430/460 [===========================>..] - ETA: 0s - loss: 6.8236e-04 - accuracy: 1.0000
# Epoch 00243: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 6.4053e-04 - accuracy: 1.0000 - val_loss: 9.3234e-04 - val_accuracy: 1.0000
# Epoch 244/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 00244: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 245/250
# 420/460 [==========================>...] - ETA: 0s - loss: 2.9212e-04 - accuracy: 1.0000
# Epoch 00245: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 2.6890e-04 - accuracy: 1.0000 - val_loss: 9.6920e-04 - val_accuracy: 1.0000
# Epoch 246/250
# 420/460 [==========================>...] - ETA: 0s - loss: 1.8646e-04 - accuracy: 1.0000
# Epoch 00246: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 2.1313e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 247/250
# 440/460 [===========================>..] - ETA: 0s - loss: 3.0689e-04 - accuracy: 1.0000
# Epoch 00247: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 4.5322e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 248/250
# 440/460 [===========================>..] - ETA: 0s - loss: 3.1389e-04 - accuracy: 1.0000
# Epoch 00248: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 3.0369e-04 - accuracy: 1.0000 - val_loss: 7.7520e-04 - val_accuracy: 1.0000
# Epoch 249/250
# 410/460 [=========================>....] - ETA: 0s - loss: 4.2595e-04 - accuracy: 1.0000
# Epoch 00249: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 3.9130e-04 - accuracy: 1.0000 - val_loss: 7.9579e-04 - val_accuracy: 1.0000
# Epoch 250/250
# 420/460 [==========================>...] - ETA: 0s - loss: 2.2993e-04 - accuracy: 1.0000
# Epoch 00250: val_accuracy did not improve from 1.00000
# 460/460 [==============================] - 1s 1ms/sample - loss: 2.1303e-04 - accuracy: 1.0000 - val_loss: 8.9140e-04 - val_accuracy: 1.0000
# Training completed in time:  0:02:21.020877

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste
#
# Lembrando que estamos utilizando o mesmo conjunto de validacão, que a princípio, pode incluir instâncias do conjunto de treinamento: o dataset utilizado foi gerado com corte de áudio, então alguns trechos do mesmo áudio podem estar presentes em ambos os conjuntos de treinamento e teste.
# Por ora deixamos assim já que estamos realizando uma investigacão inicial.

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  1.0
# Testing Accuracy:  1.0

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       1.00      1.00      1.00        56
#    Pneumonia       1.00      1.00      1.00        60
#
#     accuracy                           1.00       116
#    macro avg       1.00      1.00      1.00       116
# weighted avg       1.00      1.00      1.00       116

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[56  0]
#  [ 0 60]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])
