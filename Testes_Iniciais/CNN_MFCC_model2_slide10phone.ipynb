# %% [markdown]
# # Rede CNN - Modelo 2
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - slide10phone

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP = 'slide10phone'
MAX_PAD_LEN = 431

# %%
filepaths = glob.glob(f'./datasets/{GROUP}/**/*.wav', recursive=True)
filenames = [os.path.splitext(os.path.basename(p))[0] for p in filepaths]

# %%
p_id_in_file = [] # patient IDs corresponding to each file
for name in filenames:
    p_id_in_file.append(int(name[:3]))

p_id_in_file = np.array(p_id_in_file)

# %%
max_pad_len =  MAX_PAD_LEN

os.makedirs("./Respiratory_Sound_Database/features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=10) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./Respiratory_Sound_Database/features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
p_diag = pd.read_csv("./Respiratory_Sound_Database/Respiratory_Sound_Database/patient_diagnosis.csv",header=None) # patient diagnosis file

# %%
labels = np.array([p_diag[p_diag[0] == x][1].values[0] for x in p_id_in_file]) # labels for audio files

# %%
features = [] 

# Iterate through each sound file and extract the features
for file_name in filepaths:
    data = extract_features(file_name)
    features.append(data)

print('Finished feature extraction from ', len(features), ' files')
features = np.array(features)
# Out:
# Finished feature extraction from  1152  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(features[1], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
features = np.array(features) # convert to numpy array

# %%
np.unique(labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
# delete diseases
'''
features1 = features
labels1 = labels'''

features1 = np.delete(features, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0) 

labels1 = np.delete(labels, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0)

# %%
# print class counts
unique_elements, counts_elements = np.unique(labels1, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['560' '592']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(labels1)
oh_labels = to_categorical(i_labels)

# %%
features1.shape
# Out:
# (1152, 40, 431)

# %%
# add channel dimension for CNN
features1 = np.reshape(features1, (*features1.shape,1)) 

# train test split
x_train, x_test, y_train, y_test = train_test_split(features1, oh_labels, stratify=oh_labels, 
                                                    test_size=0.2, random_state = 42)

# %% [markdown]
# **MLP model architecture**

# %%
num_rows = 40
num_columns = 431
num_channels = 1

num_labels = oh_labels.shape[1]
filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=16, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=8, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=4, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 430, 32)       160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 215, 32)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 215, 32)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 214, 16)       2064
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 107, 16)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 107, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 106, 8)         520
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 53, 8)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 53, 8)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 52, 4)          132
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 26, 4)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 26, 4)          0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 4)                 0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 10
# =================================================================
# Total params: 2,886
# Trainable params: 2,886
# Non-trainable params: 0
# _________________________________________________________________
# 231/231 [==============================] - 1s 5ms/sample - loss: 8.4232 - accuracy: 0.5152
# Pre-training accuracy: 51.5152%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 250
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/model2_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 921 samples, validate on 231 samples
# Epoch 1/250
# 900/921 [============================>.] - ETA: 0s - loss: 1.6001 - accuracy: 0.5856
# Epoch 00001: val_accuracy improved from -inf to 0.52381, saving model to models/model2_01.h5
# 921/921 [==============================] - 2s 2ms/sample - loss: 1.5773 - accuracy: 0.5874 - val_loss: 0.6669 - val_accuracy: 0.5238
# Epoch 2/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.6218 - accuracy: 0.6750
# Epoch 00002: val_accuracy improved from 0.52381 to 0.61039, saving model to models/model2_02.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.6216 - accuracy: 0.6754 - val_loss: 0.6175 - val_accuracy: 0.6104
# Epoch 3/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.5646 - accuracy: 0.6978
# Epoch 00003: val_accuracy improved from 0.61039 to 0.79654, saving model to models/model2_03.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.5655 - accuracy: 0.6971 - val_loss: 0.5778 - val_accuracy: 0.7965
# Epoch 4/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.4895 - accuracy: 0.7416
# Epoch 00004: val_accuracy did not improve from 0.79654
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.4850 - accuracy: 0.7459 - val_loss: 0.5143 - val_accuracy: 0.7532
# Epoch 5/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.4719 - accuracy: 0.7846
# Epoch 00005: val_accuracy did not improve from 0.79654
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.4693 - accuracy: 0.7861 - val_loss: 0.4872 - val_accuracy: 0.7662
# Epoch 6/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.4143 - accuracy: 0.8000
# Epoch 00006: val_accuracy improved from 0.79654 to 0.80952, saving model to models/model2_06.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.4128 - accuracy: 0.7980 - val_loss: 0.4238 - val_accuracy: 0.8095
# Epoch 7/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.4073 - accuracy: 0.8091
# Epoch 00007: val_accuracy improved from 0.80952 to 0.81818, saving model to models/model2_07.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.4084 - accuracy: 0.8067 - val_loss: 0.4190 - val_accuracy: 0.8182
# Epoch 8/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.3640 - accuracy: 0.8185
# Epoch 00008: val_accuracy did not improve from 0.81818
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.3637 - accuracy: 0.8187 - val_loss: 0.4176 - val_accuracy: 0.8052
# Epoch 9/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.3475 - accuracy: 0.8239
# Epoch 00009: val_accuracy improved from 0.81818 to 0.82251, saving model to models/model2_09.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.3472 - accuracy: 0.8241 - val_loss: 0.3718 - val_accuracy: 0.8225
# Epoch 10/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.3540 - accuracy: 0.8409
# Epoch 00010: val_accuracy improved from 0.82251 to 0.83117, saving model to models/model2_10.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.3530 - accuracy: 0.8415 - val_loss: 0.3808 - val_accuracy: 0.8312
# Epoch 11/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.3186 - accuracy: 0.8378
# Epoch 00011: val_accuracy improved from 0.83117 to 0.84416, saving model to models/model2_11.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.3191 - accuracy: 0.8393 - val_loss: 0.3328 - val_accuracy: 0.8442
# Epoch 12/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.3308 - accuracy: 0.8528
# Epoch 00012: val_accuracy did not improve from 0.84416
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.3292 - accuracy: 0.8534 - val_loss: 0.4166 - val_accuracy: 0.7706
# Epoch 13/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.3283 - accuracy: 0.8471
# Epoch 00013: val_accuracy improved from 0.84416 to 0.85281, saving model to models/model2_13.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.3300 - accuracy: 0.8447 - val_loss: 0.3120 - val_accuracy: 0.8528
# Epoch 14/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.3088 - accuracy: 0.8591
# Epoch 00014: val_accuracy did not improve from 0.85281
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.3064 - accuracy: 0.8610 - val_loss: 0.3050 - val_accuracy: 0.8528
# Epoch 15/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.2887 - accuracy: 0.8689
# Epoch 00015: val_accuracy improved from 0.85281 to 0.87879, saving model to models/model2_15.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.2877 - accuracy: 0.8697 - val_loss: 0.2999 - val_accuracy: 0.8788
# Epoch 16/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.3189 - accuracy: 0.8500
# Epoch 00016: val_accuracy did not improve from 0.87879
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.3154 - accuracy: 0.8523 - val_loss: 0.3033 - val_accuracy: 0.8571
# Epoch 17/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.2831 - accuracy: 0.8716
# Epoch 00017: val_accuracy did not improve from 0.87879
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.2850 - accuracy: 0.8686 - val_loss: 0.3223 - val_accuracy: 0.8788
# Epoch 18/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.2732 - accuracy: 0.8835
# Epoch 00018: val_accuracy improved from 0.87879 to 0.88745, saving model to models/model2_18.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.2724 - accuracy: 0.8838 - val_loss: 0.2669 - val_accuracy: 0.8874
# Epoch 19/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.2775 - accuracy: 0.8764
# Epoch 00019: val_accuracy did not improve from 0.88745
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.2777 - accuracy: 0.8762 - val_loss: 0.3061 - val_accuracy: 0.8658
# Epoch 20/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.2588 - accuracy: 0.8880
# Epoch 00020: val_accuracy did not improve from 0.88745
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.2586 - accuracy: 0.8882 - val_loss: 0.2605 - val_accuracy: 0.8831
# Epoch 21/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.2605 - accuracy: 0.8879
# Epoch 00021: val_accuracy improved from 0.88745 to 0.89610, saving model to models/model2_21.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.2590 - accuracy: 0.8893 - val_loss: 0.2570 - val_accuracy: 0.8961
# Epoch 22/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.2512 - accuracy: 0.8910
# Epoch 00022: val_accuracy improved from 0.89610 to 0.90043, saving model to models/model2_22.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.2496 - accuracy: 0.8914 - val_loss: 0.2351 - val_accuracy: 0.9004
# Epoch 23/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.2167 - accuracy: 0.9080
# Epoch 00023: val_accuracy did not improve from 0.90043
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.2236 - accuracy: 0.9045 - val_loss: 0.2540 - val_accuracy: 0.8918
# Epoch 24/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.2346 - accuracy: 0.8910
# Epoch 00024: val_accuracy did not improve from 0.90043
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.2324 - accuracy: 0.8925 - val_loss: 0.2386 - val_accuracy: 0.8961
# Epoch 25/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.2183 - accuracy: 0.9045
# Epoch 00025: val_accuracy did not improve from 0.90043
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.2171 - accuracy: 0.9045 - val_loss: 0.2455 - val_accuracy: 0.8961
# Epoch 26/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.2242 - accuracy: 0.9057
# Epoch 00026: val_accuracy improved from 0.90043 to 0.92641, saving model to models/model2_26.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0
val_accuracy did not improve from 0.99567
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0434 - accuracy: 0.9848 - val_loss: 0.0330 - val_accuracy: 0.9870
# Epoch 250/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0278 - accuracy: 0.9909
# Epoch 00250: val_accuracy did not improve from 0.99567
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0276 - accuracy: 0.9913 - val_loss: 0.0399 - val_accuracy: 0.9870
# Training completed in time:  0:04:26.950381

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste
#
# Lembrando que estamos utilizando o mesmo conjunto de validacão, que a princípio, pode incluir instâncias do conjunto de treinamento: o dataset utilizado foi gerado com corte de áudio, então alguns trechos do mesmo áudio podem estar presentes em ambos os conjuntos de treinamento e teste.
# Por ora deixamos assim já que estamos realizando uma investigacão inicial.

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.99674267
# Testing Accuracy:  0.987013

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       1.00      0.97      0.99       112
#    Pneumonia       0.98      1.00      0.99       119
#
#     accuracy                           0.99       231
#    macro avg       0.99      0.99      0.99       231
# weighted avg       0.99      0.99      0.99       231

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[109   3]
#  [  0 119]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])
