# %% [markdown]
# # Rede MLP - Modelo 1
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - trim5

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP = 'trim5'
MAX_PAD_LEN = 216

# %%
filepaths = glob.glob(f'./datasets/{GROUP}/**/*.wav', recursive=True)
filenames = [os.path.splitext(os.path.basename(p))[0] for p in filepaths]

# %%
p_id_in_file = [] # patient IDs corresponding to each file
for name in filenames:
    p_id_in_file.append(int(name[:3]))

p_id_in_file = np.array(p_id_in_file)

# %%
max_pad_len =  MAX_PAD_LEN

os.makedirs("./Respiratory_Sound_Database/features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=20) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./Respiratory_Sound_Database/features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
p_diag = pd.read_csv("./Respiratory_Sound_Database/Respiratory_Sound_Database/patient_diagnosis.csv",header=None) # patient diagnosis file

# %%
labels = np.array([p_diag[p_diag[0] == x][1].values[0] for x in p_id_in_file]) # labels for audio files

# %%
features = [] 

# Iterate through each sound file and extract the features
for file_name in filepaths:
    data = extract_features(file_name)
    features.append(data)

print('Finished feature extraction from ', len(features), ' files')
features = np.array(features)
# Out:
# Finished feature extraction from  216  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
features = np.array(features) # convert to numpy array

# %%
np.unique(labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
# delete diseases
'''
features1 = features
labels1 = labels'''

features1 = np.delete(features, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0) 

labels1 = np.delete(labels, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0)

# %%
# print class counts
unique_elements, counts_elements = np.unique(labels1, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['105' '111']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(labels1)
oh_labels = to_categorical(i_labels)

# %%
features1.shape
# Out:
# (216, 40, 216)

# %%
input_dim = features1.shape[1]*features1.shape[2]
features1 = np.reshape(features1, (features1.shape[0], input_dim))
print(features1.shape, labels1.shape)
# Out:
# (216, 8640) (216,)

# %%
# train test split
x_train, x_test, y_train, y_test = train_test_split(features1, oh_labels, stratify=oh_labels, 
                                                    test_size=0.2, random_state = 42)

# %% [markdown]
# **MLP model architecture**

# %%
num_labels = oh_labels.shape[1]
# Construct model 
model = Sequential()
model.add(Dense(500, input_dim=input_dim, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 500)               4320500
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_2 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_3 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_4 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_5 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_6 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_7 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 1002
# =================================================================
# Total params: 6,075,002
# Trainable params: 6,075,002
# Non-trainable params: 0
# _________________________________________________________________
# 44/44 [==============================] - 0s 6ms/sample - loss: 8.1322 - accuracy: 0.5227
# Pre-training accuracy: 52.2727%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 250
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/model2_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 172 samples, validate on 44 samples
# Epoch 1/250
# 100/172 [================>.............] - ETA: 0s - loss: 37.0345 - accuracy: 0.5000
# Epoch 00001: val_accuracy improved from -inf to 0.52273, saving model to models/model2_01.h5
# 172/172 [==============================] - 1s 4ms/sample - loss: 25.0073 - accuracy: 0.4884 - val_loss: 1.0941 - val_accuracy: 0.5227
# Epoch 2/250
# 160/172 [==========================>...] - ETA: 0s - loss: 1.9560 - accuracy: 0.5375
# Epoch 00002: val_accuracy did not improve from 0.52273
# 172/172 [==============================] - 0s 809us/sample - loss: 1.9450 - accuracy: 0.5233 - val_loss: 1.9185 - val_accuracy: 0.5227
# Epoch 3/250
# 100/172 [================>.............] - ETA: 0s - loss: 1.1960 - accuracy: 0.5100
# Epoch 00003: val_accuracy did not improve from 0.52273
# 172/172 [==============================] - 0s 625us/sample - loss: 1.0483 - accuracy: 0.5233 - val_loss: 1.5289 - val_accuracy: 0.5227
# Epoch 4/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.9814 - accuracy: 0.5091
# Epoch 00004: val_accuracy did not improve from 0.52273
# 172/172 [==============================] - 0s 624us/sample - loss: 0.9033 - accuracy: 0.5116 - val_loss: 0.7198 - val_accuracy: 0.4773
# Epoch 5/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.6966 - accuracy: 0.5364
# Epoch 00005: val_accuracy improved from 0.52273 to 0.54545, saving model to models/model2_05.h5
# 172/172 [==============================] - 0s 2ms/sample - loss: 0.7144 - accuracy: 0.5233 - val_loss: 0.6618 - val_accuracy: 0.5455
# Epoch 6/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.7285 - accuracy: 0.6111
# Epoch 00006: val_accuracy improved from 0.54545 to 0.77273, saving model to models/model2_06.h5
# 172/172 [==============================] - 0s 2ms/sample - loss: 0.6298 - accuracy: 0.7267 - val_loss: 0.4914 - val_accuracy: 0.7727
# Epoch 7/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.8462 - accuracy: 0.6273
# Epoch 00007: val_accuracy did not improve from 0.77273
# 172/172 [==============================] - 0s 1ms/sample - loss: 0.7411 - accuracy: 0.6453 - val_loss: 0.5714 - val_accuracy: 0.7273
# Epoch 8/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.3413 - accuracy: 0.8545
# Epoch 00008: val_accuracy did not improve from 0.77273
# 172/172 [==============================] - 0s 631us/sample - loss: 0.3326 - accuracy: 0.8605 - val_loss: 0.9312 - val_accuracy: 0.6364
# Epoch 9/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.4248 - accuracy: 0.7800
# Epoch 00009: val_accuracy improved from 0.77273 to 0.79545, saving model to models/model2_09.h5
# 172/172 [==============================] - 0s 2ms/sample - loss: 0.3880 - accuracy: 0.8023 - val_loss: 0.4144 - val_accuracy: 0.7955
# Epoch 10/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.4972 - accuracy: 0.8889
# Epoch 00010: val_accuracy improved from 0.79545 to 0.84091, saving model to models/model2_10.h5
# 172/172 [==============================] - 0s 2ms/sample - loss: 0.5432 - accuracy: 0.8372 - val_loss: 0.4414 - val_accuracy: 0.8409
# Epoch 11/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.2629 - accuracy: 0.9222
# Epoch 00011: val_accuracy improved from 0.84091 to 0.86364, saving model to models/model2_11.h5
# 172/172 [==============================] - 0s 2ms/sample - loss: 0.2485 - accuracy: 0.9070 - val_loss: 0.3250 - val_accuracy: 0.8636
# Epoch 12/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.2333 - accuracy: 0.8667
# Epoch 00012: val_accuracy improved from 0.86364 to 0.88636, saving model to models/model2_12.h5
# 172/172 [==============================] - 0s 2ms/sample - loss: 0.2865 - accuracy: 0.8721 - val_loss: 0.3090 - val_accuracy: 0.8864
# Epoch 13/250
# 130/172 [=====================>........] - ETA: 0s - loss: 0.2344 - accuracy: 0.9077
# Epoch 00013: val_accuracy did not improve from 0.88636
# 172/172 [==============================] - 0s 952us/sample - loss: 0.2212 - accuracy: 0.9244 - val_loss: 0.3429 - val_accuracy: 0.8864
# Epoch 14/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.1310 - accuracy: 0.9500
# Epoch 00014: val_accuracy did not improve from 0.88636
# 172/172 [==============================] - 0s 693us/sample - loss: 0.1129 - accuracy: 0.9593 - val_loss: 0.8801 - val_accuracy: 0.7955
# Epoch 15/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.4890 - accuracy: 0.7909
# Epoch 00015: val_accuracy did not improve from 0.88636
# 172/172 [==============================] - 0s 626us/sample - loss: 0.5127 - accuracy: 0.7616 - val_loss: 0.4374 - val_accuracy: 0.7727
# Epoch 16/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.1676 - accuracy: 0.9455
# Epoch 00016: val_accuracy did not improve from 0.88636
# 172/172 [==============================] - 0s 651us/sample - loss: 0.2974 - accuracy: 0.8895 - val_loss: 1.5348 - val_accuracy: 0.5682
# Epoch 17/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.4900 - accuracy: 0.8000
# Epoch 00017: val_accuracy did not improve from 0.88636
# 172/172 [==============================] - 0s 706us/sample - loss: 0.3649 - accuracy: 0.8547 - val_loss: 0.5757 - val_accuracy: 0.7500
# Epoch 18/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.2037 - accuracy: 0.9400
# Epoch 00018: val_accuracy did not improve from 0.88636
# 172/172 [==============================] - 0s 672us/sample - loss: 0.1574 - accuracy: 0.9535 - val_loss: 1.3134 - val_accuracy: 0.7955
# Epoch 19/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.8400 - accuracy: 0.7600
# Epoch 00019: val_accuracy improved from 0.88636 to 0.90909, saving model to models/model2_19.h5
# 172/172 [==============================] - 0s 2ms/sample - loss: 0.5962 - accuracy: 0.8198 - val_loss: 0.3714 - val_accuracy: 0.9091
# Epoch 20/250
# 100/172 [================>.............] - ETA: 0s - loss: 0
- ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00154: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 637us/sample - loss: 1.3862e-09 - accuracy: 1.0000 - val_loss: 1.8700 - val_accuracy: 0.8636
# Epoch 155/250
# 120/172 [===================>..........] - ETA: 0s - loss: 1.9868e-09 - accuracy: 1.0000
# Epoch 00155: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 626us/sample - loss: 1.3862e-09 - accuracy: 1.0000 - val_loss: 1.8714 - val_accuracy: 0.8636
# Epoch 156/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00156: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 657us/sample - loss: 1.3862e-09 - accuracy: 1.0000 - val_loss: 1.8723 - val_accuracy: 0.8636
# Epoch 157/250
# 110/172 [==================>...........] - ETA: 0s - loss: 2.1674e-09 - accuracy: 1.0000
# Epoch 00157: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 640us/sample - loss: 1.3862e-09 - accuracy: 1.0000 - val_loss: 1.8736 - val_accuracy: 0.8636
# Epoch 158/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00158: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 670us/sample - loss: 1.3862e-09 - accuracy: 1.0000 - val_loss: 1.8744 - val_accuracy: 0.8636
# Epoch 159/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00159: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 675us/sample - loss: 1.3862e-09 - accuracy: 1.0000 - val_loss: 1.8752 - val_accuracy: 0.8636
# Epoch 160/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00160: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 642us/sample - loss: 1.3862e-09 - accuracy: 1.0000 - val_loss: 1.8762 - val_accuracy: 0.8636
# Epoch 161/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00161: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 679us/sample - loss: 1.3862e-09 - accuracy: 1.0000 - val_loss: 1.8773 - val_accuracy: 0.8636
# Epoch 162/250
# 110/172 [==================>...........] - ETA: 0s - loss: 1.0837e-09 - accuracy: 1.0000
# Epoch 00162: val_accuracy did not improve from 0.90909
# ...
# Epoch 00197: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 651us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9055 - val_accuracy: 0.8636
# Epoch 198/250
# 100/172 [================>.............] - ETA: 0s - loss: 1.1921e-09 - accuracy: 1.0000
# Epoch 00198: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 689us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9064 - val_accuracy: 0.8636
# Epoch 199/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00199: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 669us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9069 - val_accuracy: 0.8636
# Epoch 200/250
# 110/172 [==================>...........] - ETA: 0s - loss: 1.0837e-09 - accuracy: 1.0000
# Epoch 00200: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 665us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9079 - val_accuracy: 0.8636
# Epoch 201/250
# 100/172 [================>.............] - ETA: 0s - loss: 1.1921e-09 - accuracy: 1.0000
# Epoch 00201: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 723us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9086 - val_accuracy: 0.8636
# Epoch 202/250
# 110/172 [==================>...........] - ETA: 0s - loss: 1.0837e-09 - accuracy: 1.0000
# Epoch 00202: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 664us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9092 - val_accuracy: 0.8636
# Epoch 203/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00203: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 673us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9095 - val_accuracy: 0.8636
# Epoch 204/250
# 110/172 [==================>...........] - ETA: 0s - loss: 1.0837e-09 - accuracy: 1.0000
# Epoch 00204: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 642us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9105 - val_accuracy: 0.8636
# Epoch 205/250
# 100/172 [================>.............] - ETA: 0s - loss: 1.1921e-09 - accuracy: 1.0000
# Epoch 00205: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 668us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9113 - val_accuracy: 0.8636
# Epoch 206/250
# 110/172 [==================>...........] - ETA: 0s - loss: 1.0837e-09 - accuracy: 1.0000
# Epoch 00206: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 656us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9121 - val_accuracy: 0.8636
# Epoch 207/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00207: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 676us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9127 - val_accuracy: 0.8636
# Epoch 208/250
# 110/172 [==================>...........] - ETA: 0s - loss: 1.0837e-09 - accuracy: 1.0000
# Epoch 00208: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 654us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9136 - val_accuracy: 0.8636
# Epoch 209/250
# 110/172 [==================>...........] - ETA: 0s - loss: 1.0837e-09 - accuracy: 1.0000
# Epoch 00209: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 685us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9143 - val_accuracy: 0.8636
# Epoch 210/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00210: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 665us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9146 - val_accuracy: 0.8636
# Epoch 211/250
# 100/172 [================>.............] - ETA: 0s - loss: 1.1921e-09 - accuracy: 1.0000
# Epoch 00211: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 656us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9158 - val_accuracy: 0.8636
# Epoch 212/250
# 110/172 [==================>...........] - ETA: 0s - loss: 1.0837e-09 - accuracy: 1.0000
# Epoch 00212: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 724us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9165 - val_accuracy: 0.8636
# Epoch 213/250
# 100/172 [================>.............] - ETA: 0s - loss: 1.1921e-09 - accuracy: 1.0000
# Epoch 00213: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 708us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9173 - val_accuracy: 0.8636
# Epoch 214/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00214: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 685us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9176 - val_accuracy: 0.8636
# Epoch 215/250
# 110/172 [==================>...........] - ETA: 0s - loss: 1.0837e-09 - accuracy: 1.0000
# Epoch 00215: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 763us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9187 - val_accuracy: 0.8636
# Epoch 216/250
# 100/172 [================>.............] - ETA: 0s - loss: 1.1921e-09 - accuracy: 1.0000
# Epoch 00216: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 715us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9194 - val_accuracy: 0.8636
# Epoch 217/250
# 110/172 [==================>...........] - ETA: 0s - loss: 1.0837e-09 - accuracy: 1.0000
# Epoch 00217: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 659us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9201 - val_accuracy: 0.8636
# Epoch 218/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00218: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 723us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9206 - val_accuracy: 0.8636
# Epoch 219/250
# 110/172 [==================>...........] - ETA: 0s - loss: 1.0837e-09 - accuracy: 1.0000
# Epoch 00219: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 671us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9216 - val_accuracy: 0.8636
# Epoch 220/250
# 110/172 [==================>...........] - ETA: 0s - loss: 1.0837e-09 - accuracy: 1.0000
# Epoch 00220: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 675us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9225 - val_accuracy: 0.8636
# Epoch 221/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00221: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 680us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9230 - val_accuracy: 0.8636
# Epoch 222/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00222: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 687us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9237 - val_accuracy: 0.8636
# Epoch 223/250
# 110/172 [==================>...........] - ETA: 0s - loss: 1.0837e-09 - accuracy: 1.0000
# Epoch 00223: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 639us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9247 - val_accuracy: 0.8636
# Epoch 224/250
# 100/172 [================>.............] - ETA: 0s - loss: 1.1921e-09 - accuracy: 1.0000
# Epoch 00224: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 712us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9254 - val_accuracy: 0.8636
# Epoch 225/250
# 110/172 [==================>...........] - ETA: 0s - loss: 1.0837e-09 - accuracy: 1.0000
# Epoch 00225: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 707us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9263 - val_accuracy: 0.8636
# Epoch 226/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00226: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 652us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9268 - val_accuracy: 0.8636
# Epoch 227/250
# 100/172 [================>.............] - ETA: 0s - loss: 1.1921e-09 - accuracy: 1.0000
# Epoch 00227: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 696us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9277 - val_accuracy: 0.8636
# Epoch 228/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00228: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 646us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9283 - val_accuracy: 0.8636
# Epoch 229/250
# 110/172 [==================>...........] - ETA: 0s - loss: 1.0837e-09 - accuracy: 1.0000
# Epoch 00229: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 663us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9318 - val_accuracy: 0.8636
# Epoch 230/250
# 110/172 [==================>...........] - ETA: 0s - loss: 1.0837e-09 - accuracy: 1.0000
# Epoch 00230: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 642us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9329 - val_accuracy: 0.8636
# Epoch 231/250
# 110/172 [==================>...........] - ETA: 0s - loss: 1.0837e-09 - accuracy: 1.0000
# Epoch 00231: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 750us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9339 - val_accuracy: 0.8636
# Epoch 232/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00232: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 673us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9342 - val_accuracy: 0.8636
# Epoch 233/250
# 100/172 [================>.............] - ETA: 0s - loss: 1.1921e-09 - accuracy: 1.0000
# Epoch 00233: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 667us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9352 - val_accuracy: 0.8636
# Epoch 234/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00234: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 676us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9359 - val_accuracy: 0.8636
# Epoch 235/250
# 110/172 [==================>...........] - ETA: 0s - loss: 1.0837e-09 - accuracy: 1.0000
# Epoch 00235: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 682us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9369 - val_accuracy: 0.8636
# Epoch 236/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00236: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 655us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9374 - val_accuracy: 0.8864
# Epoch 237/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00237: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 661us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9382 - val_accuracy: 0.8864
# Epoch 238/250
# 110/172 [==================>...........] - ETA: 0s - loss: 1.0837e-09 - accuracy: 1.0000
# Epoch 00238: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 656us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9392 - val_accuracy: 0.8864
# Epoch 239/250
# 110/172 [==================>...........] - ETA: 0s - loss: 1.0837e-09 - accuracy: 1.0000
# Epoch 00239: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 649us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9401 - val_accuracy: 0.8864
# Epoch 240/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00240: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 695us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9404 - val_accuracy: 0.8864
# Epoch 241/250
# 110/172 [==================>...........] - ETA: 0s - loss: 1.0837e-09 - accuracy: 1.0000
# Epoch 00241: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 674us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9416 - val_accuracy: 0.8864
# Epoch 242/250
# 110/172 [==================>...........] - ETA: 0s - loss: 1.0837e-09 - accuracy: 1.0000
# Epoch 00242: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 666us/sample - loss: 6.9308e-10 - accuracy: 1.0000 - val_loss: 1.9423 - val_accuracy: 0.8864
# Epoch 243/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00243: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 677us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.9427 - val_accuracy: 0.8864
# Epoch 244/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00244: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 671us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.9429 - val_accuracy: 0.8864
# Epoch 245/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00245: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 692us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.9431 - val_accuracy: 0.8864
# Epoch 246/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00246: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 691us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.9433 - val_accuracy: 0.8864
# Epoch 247/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00247: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 717us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.9435 - val_accuracy: 0.8864
# Epoch 248/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00248: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 678us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.9437 - val_accuracy: 0.8864
# Epoch 249/250
# 110/172 [==================>...........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00249: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 657us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.9440 - val_accuracy: 0.8864
# Epoch 250/250
# 120/172 [===================>..........] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00250: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 646us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.9441 - val_accuracy: 0.8864
# Training completed in time:  0:00:31.213173

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste
#
# Lembrando que estamos utilizando o mesmo conjunto de validacão, que a princípio, pode incluir instâncias do conjunto de treinamento: o dataset utilizado foi gerado com corte de áudio, então alguns trechos do mesmo áudio podem estar presentes em ambos os conjuntos de treinamento e teste.
# Por ora deixamos assim já que estamos realizando uma investigacão inicial.

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  1.0
# Testing Accuracy:  0.8863636

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.90      0.86      0.88        21
#    Pneumonia       0.88      0.91      0.89        23
#
#     accuracy                           0.89        44
#    macro avg       0.89      0.89      0.89        44
# weighted avg       0.89      0.89      0.89        44

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[18  3]
#  [ 2 21]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])
