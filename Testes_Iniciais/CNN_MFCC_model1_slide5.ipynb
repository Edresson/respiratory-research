# %% [markdown]
# # Rede CNN - Modelo 1
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - slide5

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP = 'slide5'
MAX_PAD_LEN = 216

# %%
filepaths = glob.glob(f'./datasets/{GROUP}/**/*.wav', recursive=True)
filenames = [os.path.splitext(os.path.basename(p))[0] for p in filepaths]

# %%
p_id_in_file = [] # patient IDs corresponding to each file
for name in filenames:
    p_id_in_file.append(int(name[:3]))

p_id_in_file = np.array(p_id_in_file)

# %%
max_pad_len =  MAX_PAD_LEN

os.makedirs("./Respiratory_Sound_Database/features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=20) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./Respiratory_Sound_Database/features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
p_diag = pd.read_csv("./Respiratory_Sound_Database/Respiratory_Sound_Database/patient_diagnosis.csv",header=None) # patient diagnosis file

# %%
labels = np.array([p_diag[p_diag[0] == x][1].values[0] for x in p_id_in_file]) # labels for audio files

# %%
features = [] 

# Iterate through each sound file and extract the features
for file_name in filepaths:
    data = extract_features(file_name)
    features.append(data)

print('Finished feature extraction from ', len(features), ' files')
features = np.array(features)
# Out:
# Finished feature extraction from  576  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
features = np.array(features) # convert to numpy array

# %%
np.unique(labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
# delete diseases
'''
features1 = features
labels1 = labels'''

features1 = np.delete(features, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0) 

labels1 = np.delete(labels, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0)

# %%
# print class counts
unique_elements, counts_elements = np.unique(labels1, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['280' '296']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(labels1)
oh_labels = to_categorical(i_labels)

# %%
features1.shape
# Out:
# (576, 40, 216)

# %%
# add channel dimension for CNN
features1 = np.reshape(features1, (*features1.shape,1)) 

# train test split
x_train, x_test, y_train, y_test = train_test_split(features1, oh_labels, stratify=oh_labels, 
                                                    test_size=0.2, random_state = 42)

# %% [markdown]
# **MLP model architecture**

# %%
num_rows = 40
num_columns = 216
num_channels = 1

num_labels = oh_labels.shape[1]
filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 215, 16)       80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 107, 16)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 107, 16)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 106, 32)       2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 53, 32)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 53, 32)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 52, 64)         8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 26, 64)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 26, 64)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 25, 128)        32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 12, 128)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 12, 128)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 258
# =================================================================
# Total params: 43,570
# Trainable params: 43,570
# Non-trainable params: 0
# _________________________________________________________________
# 116/116 [==============================] - 1s 10ms/sample - loss: 2.1766 - accuracy: 0.4828
# Pre-training accuracy: 48.2759%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 250
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/model2_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 460 samples, validate on 116 samples
# Epoch 1/250
# 380/460 [=======================>......] - ETA: 0s - loss: 2.8425 - accuracy: 0.4974
# Epoch 00001: val_accuracy improved from -inf to 0.62069, saving model to models/model2_01.h5
# 460/460 [==============================] - 1s 2ms/sample - loss: 2.5432 - accuracy: 0.5130 - val_loss: 0.6305 - val_accuracy: 0.6207
# Epoch 2/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.8925 - accuracy: 0.5718
# Epoch 00002: val_accuracy did not improve from 0.62069
# 460/460 [==============================] - 0s 647us/sample - loss: 0.8775 - accuracy: 0.5652 - val_loss: 0.6418 - val_accuracy: 0.4828
# Epoch 3/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.6360 - accuracy: 0.6649
# Epoch 00003: val_accuracy did not improve from 0.62069
# 460/460 [==============================] - 0s 650us/sample - loss: 0.6196 - accuracy: 0.6848 - val_loss: 0.6241 - val_accuracy: 0.5000
# Epoch 4/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.5451 - accuracy: 0.7162
# Epoch 00004: val_accuracy did not improve from 0.62069
# 460/460 [==============================] - 0s 656us/sample - loss: 0.5479 - accuracy: 0.7239 - val_loss: 0.5916 - val_accuracy: 0.5862
# Epoch 5/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.4697 - accuracy: 0.7459
# Epoch 00005: val_accuracy improved from 0.62069 to 0.81034, saving model to models/model2_05.h5
# 460/460 [==============================] - 0s 713us/sample - loss: 0.4708 - accuracy: 0.7543 - val_loss: 0.4184 - val_accuracy: 0.8103
# Epoch 6/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.3862 - accuracy: 0.8162
# Epoch 00006: val_accuracy did not improve from 0.81034
# 460/460 [==============================] - 0s 681us/sample - loss: 0.3920 - accuracy: 0.8152 - val_loss: 0.4417 - val_accuracy: 0.7759
# Epoch 7/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.3414 - accuracy: 0.8421
# Epoch 00007: val_accuracy did not improve from 0.81034
# 460/460 [==============================] - 0s 664us/sample - loss: 0.3446 - accuracy: 0.8391 - val_loss: 0.4944 - val_accuracy: 0.7759
# Epoch 8/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.2975 - accuracy: 0.8892
# Epoch 00008: val_accuracy did not improve from 0.81034
# 460/460 [==============================] - 0s 665us/sample - loss: 0.3193 - accuracy: 0.8696 - val_loss: 0.4241 - val_accuracy: 0.8103
# Epoch 9/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.2960 - accuracy: 0.8676
# Epoch 00009: val_accuracy improved from 0.81034 to 0.87069, saving model to models/model2_09.h5
# 460/460 [==============================] - 0s 771us/sample - loss: 0.2921 - accuracy: 0.8739 - val_loss: 0.3090 - val_accuracy: 0.8707
# Epoch 10/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.3333 - accuracy: 0.8605
# Epoch 00010: val_accuracy improved from 0.87069 to 0.87931, saving model to models/model2_10.h5
# 460/460 [==============================] - 0s 706us/sample - loss: 0.3182 - accuracy: 0.8630 - val_loss: 0.3074 - val_accuracy: 0.8793
# Epoch 11/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.2852 - accuracy: 0.8649
# Epoch 00011: val_accuracy did not improve from 0.87931
# 460/460 [==============================] - 0s 678us/sample - loss: 0.2928 - accuracy: 0.8652 - val_loss: 0.3503 - val_accuracy: 0.8190
# Epoch 12/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.2421 - accuracy: 0.8973
# Epoch 00012: val_accuracy did not improve from 0.87931
# 460/460 [==============================] - 0s 663us/sample - loss: 0.2507 - accuracy: 0.8935 - val_loss: 0.3729 - val_accuracy: 0.8103
# Epoch 13/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.3063 - accuracy: 0.8462
# Epoch 00013: val_accuracy did not improve from 0.87931
# 460/460 [==============================] - 0s 648us/sample - loss: 0.3051 - accuracy: 0.8543 - val_loss: 0.3246 - val_accuracy: 0.8707
# Epoch 14/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.2343 - accuracy: 0.8974
# Epoch 00014: val_accuracy did not improve from 0.87931
# 460/460 [==============================] - 0s 646us/sample - loss: 0.2420 - accuracy: 0.8913 - val_loss: 0.3083 - val_accuracy: 0.8621
# Epoch 15/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.2358 - accuracy: 0.9044
# Epoch 00015: val_accuracy did not improve from 0.87931
# 460/460 [==============================] - 0s 700us/sample - loss: 0.2354 - accuracy: 0.9043 - val_loss: 0.2958 - val_accuracy: 0.8793
# Epoch 16/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.2555 - accuracy: 0.8892
# Epoch 00016: val_accuracy did not improve from 0.87931
# 460/460 [==============================] - 0s 669us/sample - loss: 0.2758 - accuracy: 0.8717 - val_loss: 0.4451 - val_accuracy: 0.7931
# Epoch 17/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.3344 - accuracy: 0.8622
# Epoch 00017: val_accuracy did not improve from 0.87931
# 460/460 [==============================] - 0s 676us/sample - loss: 0.3349 - accuracy: 0.8587 - val_loss: 0.3119 - val_accuracy: 0.8276
# Epoch 18/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.2815 - accuracy: 0.8784
# Epoch 00018: val_accuracy improved from 0.87931 to 0.90517, saving model to models/model2_18.h5
# 460/460 [==============================] - 0s 757us/sample - loss: 0.2645 - accuracy: 0.8870 - val_loss: 0.2571 - val_accuracy: 0.9052
# Epoch 19/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.1929 - accuracy: 0.9282
# Epoch 00019: val_accuracy did not improve from 0.90517
# 460/460 [==============================] - 0s 648us/sample - loss: 0.1978 - accuracy: 0.9304 - val_loss: 0.2627 - val_accuracy: 0.8966
# Epoch 20/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.1767 - accuracy: 0.9421
# Epoch 00020: val_accuracy did not improve from 0.90517
# 460/460 [==============================] - 0s 674us/sample - loss: 0.1843 - accuracy: 0.9370 - val_loss: 0.3203 - val_accuracy: 0.8707
# Epoch 21/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.2155 - accuracy: 0.9044
# Epoch 00021: val_accuracy improved from 0.90517 to 0.92241, saving model to models/model2_21.h5
# 460/460 [==============================] - 0s 748us/sample - loss: 0.2141 - accuracy: 0.9043 - val_loss: 0.2218 - val_accuracy: 0.9224
# Epoch 22/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.1903 - accuracy: 0.9108
# Epoch 00022: val_accuracy did not improve from 0.92241
# 460/460 [==============================] - 0s 668us/sample - loss: 0.1849 - accuracy: 0.9174 - val_loss: 0.2416 - val_accuracy: 0.9224
# Epoch 23/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.2041 - accuracy: 0.9156
# Epoch 00023: val_accuracy did not improve from 0.92241
# 460/460 [==============================] - 0s 673us/sample - loss: 0.2017 - accuracy: 0.9174 - val_loss: 0.2241 - val_accuracy: 0.9052
# Epoch 24/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.1585 - accuracy: 0.9400
# Epoch 00024: val_accuracy did not improve from 0.92241
# 460/460 [==============================] - 0s 700us/sample - loss: 0.1610 - accuracy: 0.9391 - val_loss: 0.3470 - val_accuracy: 0.8879
# Epoch 25/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.1667 - accuracy: 0.9523
# Epoch 00025: val_accuracy did not improve from 0.92241
# 460/460 [==============================] - 0s 691us/sample - loss: 0.1662 - accuracy: 0.9500 - val_loss: 0.3773 - val_accuracy: 0.8793
# Epoch 26/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.1476 - accuracy: 0.9432
# Epoch 00026: val_accuracy did not improve from 0.92241
# 460/460 [==============================] - 0s 670us/sample - loss: 0.1479 - accuracy: 0.9435 - val_loss: 0.4802 - val_accuracy: 0.8621
# Epoch 27/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.1855 - accuracy: 0.9342
# Epoch 00027: val_accuracy did not improve from 0.92241
# 460/460 [==============================] - 0s 676us/sample - loss: 0.1800 - accuracy: 0.9348 - val_loss: 0.3065 - val_accuracy: 0.8966
# Epoch 28/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.1611 - accuracy: 0.9356
# Epoch 00028: val_accuracy did not improve from 0.92241
# 460/460 [==============================] - 0s 682us/sample - loss: 0.1627 - accuracy: 0.9348 - val_loss: 0.2883 - val_accuracy: 0.9138
# Epoch 29/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.1599 - accuracy: 0.9500
# Epoch 00029: val_accuracy improved from 0.92241 to 0.93966, saving model to models/model2_29.h5
# 460/460 [==============================] - 0s 732us/sample - loss: 0.1460 - accuracy: 0.9543 - val_loss: 0.3000 - val_accuracy: 0.9397
# Epoch 30/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.1648 - accuracy: 0.9378
# Epoch 00030: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 0s 685us/sample - loss: 0.1681 - accuracy: 0.9348 - val_loss: 0.3102 - val_accuracy: 0.9052
# Epoch 31/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.1209 - accuracy: 0.9556
# Epoch 00031: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 0s 691us/sample - loss: 0.1296 - accuracy: 0.9543 - val_loss: 0.3005 - val_accuracy: 0.9310
# Epoch 32/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.1109 - accuracy: 0.9659
# Epoch 00032: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 0s 688us/sample - loss: 0.1153 - accuracy: 0.9652 - val_loss: 0.2303 - val_accuracy: 0.9224
# Epoch 33/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.1050 - accuracy: 0.9658
# Epoch 00033: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 0s 666us/sample - loss: 0.0977 - accuracy: 0.9696 - val_loss: 0.5130 - val_accuracy: 0.8793
# Epoch 34/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.1163 - accuracy: 0.9579
# Epoch 00034: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 0s 660us/sample - loss: 0.1361 - accuracy: 0.9522 - val_loss: 0.1850 - val_accuracy: 0.9310
# Epoch 35/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.2520 - accuracy: 0.9081
# Epoch 00035: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 0s 648us/sample - loss: 0.2185 - accuracy: 0.9261 - val_loss: 0.2203 - val_accuracy: 0.9310
# Epoch 36/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0942 - accuracy: 0.9632
# Epoch 00036: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 0s 640us/sample - loss: 0.0923 - accuracy: 0.9652 - val_loss: 0.1637 - val_accuracy: 0.9310
# Epoch 37/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0917 - accuracy: 0.9684
# Epoch 00037: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 0s 666us/sample - loss: 0.0931 - accuracy: 0.9696 - val_loss: 0.2897 - val_accuracy: 0.9310
# Epoch 38/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.0992 - accuracy: 0.9622
# Epoch 00038: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 0s 671us/sample - loss: 0.0925 - accuracy: 0.9652 - val_loss: 0.2895 - val_accuracy: 0.9310
# Epoch 39/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.1160 - accuracy: 0.9632
# Epoch 00039: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 0s 658us/sample - loss: 0.1057 - accuracy: 0.9674 - val_loss: 0.4676 - val_accuracy: 0.9052
# Epoch 40/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.0713 - accuracy: 0.9784
# Epoch 00040: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 0s 683us/sample - loss: 0.0898 - accuracy: 0.9717 - val_loss: 0.2696 - val_accuracy: 0.9224
# Epoch 41/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.1305 - accuracy: 0.9526
# Epoch 00041: val_accuracy improved from 0.93966 to 0.95690, saving model to models/model2_41.h5
# 460/460 [==============================] - 0s 706us/sample - loss: 0.1216 - accuracy: 0.9587 - val_loss: 0.1627 - val_accuracy: 0.9569
# Epoch 42/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.1183 - accuracy: 0.9553
# Epoch 00042: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 667us/sample - loss: 0.1126 - accuracy: 0.9587 - val_loss: 0.2966 - val_accuracy: 0.9224
# Epoch 43/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.1792 - accuracy: 0.9351
# Epoch 00043: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 671us/sample - loss: 0.1531 - accuracy: 0.9478 - val_loss: 0.1324 - val_accuracy: 0.9483
# Epoch 44/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0641 - accuracy: 0.9822
# Epoch 00044: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 680us/sample - loss: 0.0687 - accuracy: 0.9804 - val_loss: 0.2458 - val_accuracy: 0.9483
# Epoch 45/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.0621 - accuracy: 0.9757
# Epoch 00045: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 666us/sample - loss: 0.0738 - accuracy: 0.9739 - val_loss: 0.4542 - val_accuracy: 0.9052
# Epoch 46/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.1123 - accuracy: 0.9568
# Epoch 00046: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 674us/sample - loss: 0.1030 - accuracy: 0.9609 - val_loss: 0.3549 - val_accuracy: 0.9310
# Epoch 47/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.1234 - accuracy: 0.9514
# Epoch 00047: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 669us/sample - loss: 0.1128 - accuracy: 0.9543 - val_loss: 0.3455 - val_accuracy: 0.9138
# Epoch 48/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0556 - accuracy: 0.9844
# Epoch 00048: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 675us/sample - loss: 0.0547 - accuracy: 0.9848 - val_loss: 0.3164 - val_accuracy: 0.9310
# Epoch 49/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.1478 - accuracy: 0.9459
# Epoch 00049: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 683us/sample - loss: 0.1419 - accuracy: 0.9478 - val_loss: 0.3878 - val_accuracy: 0.9052
# Epoch 50/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0770 - accuracy: 0.9689
# Epoch 00050: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 678us/sample - loss: 0.0758 - accuracy: 0.9696 - val_loss: 0.2641 - val_accuracy: 0.9397
# Epoch 51/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.0672 - accuracy: 0.9811
# Epoch 00051: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 670us/sample - loss: 0.0804 - accuracy: 0.9739 - val_loss: 0.2374 - val_accuracy: 0.9397
# Epoch 52/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.1466 - accuracy: 0.9486
# Epoch 00052: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 688us/sample - loss: 0.1571 - accuracy: 0.9457 - val_loss: 0.3333 - val_accuracy: 0.8879
# Epoch 53/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.1170 - accuracy: 0.9730
# Epoch 00053: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 660us/sample - loss: 0.1003 - accuracy: 0.9783 - val_loss: 0.1669 - val_accuracy: 0.9569
# Epoch 54/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.0663 - accuracy: 0.9846
# Epoch 00054: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 648us/sample - loss: 0.0755 - accuracy: 0.9783 - val_loss: 0.1781 - val_accuracy: 0.9397
# Epoch 55/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.0738 - accuracy: 0.9811
# Epoch 00055: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 651us/sample - loss: 0.0700 - accuracy: 0.9804 - val_loss: 0.1300 - val_accuracy: 0.9483
# Epoch 56/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0929 - accuracy: 0.9737
# Epoch 00056: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 633us/sample - loss: 0.0818 - accuracy: 0.9761 - val_loss: 0.2716 - val_accuracy: 0.9397
# Epoch 57/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.0703 - accuracy: 0.9784
# Epoch 00057: val_accuracy improved from 0.95690 to 0.96552, saving model to models/model2_57.h5
# 460/460 [==============================] - 0s 752us/sample - loss: 0.0712 - accuracy: 0.9739 - val_loss: 0.1211 - val_accuracy: 0.9655
# Epoch 58/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.1555 - accuracy: 0.9270
# Epoch 00058: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 659us/sample - loss: 0.1295 - accuracy: 0.9413 - val_loss: 0.3812 - val_accuracy: 0.8966
# Epoch 59/250
# 360/460 [======================>.......] - ETA: 0s - loss: 0.0649 - accuracy: 0.9722
# Epoch 00059: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 663us/sample - loss: 0.0653 - accuracy: 0.9739 - val_loss: 0.3075 - val_accuracy: 0.9397
# Epoch 60/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.1076 - accuracy: 0.9556
# Epoch 00060: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 680us/sample - loss: 0.1057 - accuracy: 0.9565 - val_loss: 0.2262 - val_accuracy: 0.9310
# Epoch 61/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.0608 - accuracy: 0.9865
# Epoch 00061: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 672us/sample - loss: 0.0543 - accuracy: 0.9891 - val_loss: 0.1588 - val_accuracy: 0.9569
# Epoch 62/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.1026 - accuracy: 0.9676
# Epoch 00062: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 681us/sample - loss: 0.0993 - accuracy: 0.9674 - val_loss: 0.2440 - val_accuracy: 0.9310
# Epoch 63/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.0874 - accuracy: 0.9641
# Epoch 00063: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 643us/sample - loss: 0.0833 - accuracy: 0.9674 - val_loss: 0.2035 - val_accuracy: 0.9224
# Epoch 64/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0611 - accuracy: 0.9778
# Epoch 00064: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 676us/sample - loss: 0.0626 - accuracy: 0.9783 - val_loss: 0.2878 - val_accuracy: 0.9310
# Epoch 65/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.0732 - accuracy: 0.9730
# Epoch 00065: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 673us/sample - loss: 0.0995 - accuracy: 0.9652 - val_loss: 0.0857 - val_accuracy: 0.9569
# Epoch 66/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.0596 - accuracy: 0.9757
# Epoch 00066: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 665us/sample - loss: 0.0574 - accuracy: 0.9761 - val_loss: 0.1420 - val_accuracy: 0.9655
# Epoch 67/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.0372 - accuracy: 0.9872
# Epoch 00067: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 638us/sample - loss: 0.0466 - accuracy: 0.9848 - val_loss: 0.1311 - val_accuracy: 0.9569
# Epoch 68/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.1145 - accuracy: 0.9649
# Epoch 00068: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 674us/sample - loss: 0.1134 - accuracy: 0.9630 - val_loss: 0.2241 - val_accuracy: 0.9310
# Epoch 69/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0473 - accuracy: 0.9844
# Epoch 00069: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 666us/sample - loss: 0.0463 - accuracy: 0.9848 - val_loss: 0.3751 - val_accuracy: 0.9310
# Epoch 70/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.0373 - accuracy: 0.9872
# Epoch 00070: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 649us/sample - loss: 0.0349 - accuracy: 0.9891 - val_loss: 0.3090 - val_accuracy: 0.9138
# Epoch 71/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.0872 - accuracy: 0.9718
# Epoch 00071: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 643us/sample - loss: 0.0839 - accuracy: 0.9717 - val_loss: 0.1202 - val_accuracy: 0.9483
# Epoch 72/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.0593 - accuracy: 0.9757
# Epoch 00072: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 674us/sample - loss: 0.0539 - accuracy: 0.9783 - val_loss: 0.2085 - val_accuracy: 0.9397
# Epoch 73/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0461 - accuracy: 0.9844
# Epoch 00073: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 680us/sample - loss: 0.0460 - accuracy: 0.9848 - val_loss: 0.1956 - val_accuracy: 0.9483
# Epoch 74/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.0673 - accuracy: 0.9784
# Epoch 00074: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 668us/sample - loss: 0.0660 - accuracy: 0.9761 - val_loss: 0.1242 - val_accuracy: 0.9655
# Epoch 75/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0462 - accuracy: 0.9844
# Epoch 00075: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 675us/sample - loss: 0.0454 - accuracy: 0.9848 - val_loss: 0.2435 - val_accuracy: 0.9397
# Epoch 76/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0339 - accuracy: 0.9868
# Epoch 00076: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 658us/sample - loss: 0.0347 - accuracy: 0.9870 - val_loss: 0.2548 - val_accuracy: 0.9397
# Epoch 77/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0509 - accuracy: 0.9789
# Epoch 00077: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 637us/sample - loss: 0.0678 - accuracy: 0.9804 - val_loss: 0.1449 - val_accuracy: 0.9655
# Epoch 78/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0353 - accuracy: 0.9842
# Epoch 00078: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 659us/sample - loss: 0.0550 - accuracy: 0.9826 - val_loss: 0.0974 - val_accuracy: 0.9569
# Epoch 79/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0652 - accuracy: 0.9795
# Epoch 00079: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 690us/sample - loss: 0.0693 - accuracy: 0.9783 - val_loss: 0.1312 - val_accuracy: 0.9569
# Epoch 80/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0364 - accuracy: 0.9889
# Epoch 00080: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 672us/sample - loss: 0.0356 - accuracy: 0.9891 - val_loss: 0.1089 - val_accuracy: 0.9655
# Epoch 81/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0518 - accuracy: 0.9844
# Epoch 00081: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 673us/sample - loss: 0.0508 - accuracy: 0.9848 - val_loss: 0.2926 - val_accuracy: 0.9397
# Epoch 82/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.0293 - accuracy: 0.9892
# Epoch 00082: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 652us/sample - loss: 0.0373 - accuracy: 0.9848 - val_loss: 0.3231 - val_accuracy: 0.9397
# Epoch 83/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.0274 - accuracy: 0.9892
# Epoch 00083: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 660us/sample - loss: 0.0268 - accuracy: 0.9891 - val_loss: 0.4234 - val_accuracy: 0.9224
# Epoch 84/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.1305 - accuracy: 0.9622
# Epoch 00084: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 675us/sample - loss: 0.1526 - accuracy: 0.9565 - val_loss: 0.1430 - val_accuracy: 0.9483
# Epoch 85/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0735 - accuracy: 0.9667
# Epoch 00085: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 683us/sample - loss: 0.0720 - accuracy: 0.9674 - val_loss: 0.1468 - val_accuracy: 0.9483
# Epoch 86/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0321 - accuracy: 0.9889
# Epoch 00086: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 674us/sample - loss: 0.0316 - accuracy: 0.9891 - val_loss: 0.0937 - val_accuracy: 0.9655
# Epoch 87/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.0234 - accuracy: 0.9919
# Epoch 00087: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 672us/sample - loss: 0.0336 - accuracy: 0.9870 - val_loss: 0.1011 - val_accuracy: 0.9655
# Epoch 88/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0636 - accuracy: 0.9818
# Epoch 00088: val_accuracy did not improve from 0.96552
# 460/460 [==============================] - 0s 696us/sample - loss: 0.0632 - accuracy: 0.9804 - val_loss: 0.0863 - val_accuracy: 0.9655
# Epoch 89/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0476 - accuracy: 0.9822
# Epoch 00089: val_accuracy improved from 0.96552 to 0.97414, saving model to models/model2_89.h5
# 460/460 [==============================] - 0s 731us/sample - loss: 0.0468 - accuracy: 0.9826 - val_loss: 0.0661 - val_accuracy: 0.9741
# Epoch 90/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0667 - accuracy: 0.9733
# Epoch 00090: val_accuracy did not improve from 0.97414
# 460/460 [==============================] - 0s 689us/sample - loss: 0.0665 - accuracy: 0.9739 - val_loss: 0.1187 - val_accuracy: 0.9655
# Epoch 91/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.0393 - accuracy: 0.9865
# Epoch 00091: val_accuracy improved from 0.97414 to 0.98276, saving model to models/model2_91.h5
# 460/460 [==============================] - 0s 740us/sample - loss: 0.0336 - accuracy: 0.9891 - val_loss: 0.0845 - val_accuracy: 0.9828
# Epoch 92/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0195 - accuracy: 0.9933
# Epoch 00092: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 690us/sample - loss: 0.0206 - accuracy: 0.9935 - val_loss: 0.1057 - val_accuracy: 0.9741
# Epoch 93/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0749 - accuracy: 0.9800
# Epoch 00093: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 723us/sample - loss: 0.0821 - accuracy: 0.9783 - val_loss: 0.1202 - val_accuracy: 0.9569
# Epoch 94/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0851 - accuracy: 0.9780
# Epoch 00094: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 720us/sample - loss: 0.0772 - accuracy: 0.9804 - val_loss: 0.2546 - val_accuracy: 0.9397
# Epoch 95/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0582 - accuracy: 0.9814
# Epoch 00095: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 710us/sample - loss: 0.0553 - accuracy: 0.9826 - val_loss: 0.0632 - val_accuracy: 0.9828
# Epoch 96/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0315 - accuracy: 0.9886
# Epoch 00096: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 683us/sample - loss: 0.0302 - accuracy: 0.9891 - val_loss: 0.2252 - val_accuracy: 0.9397
# Epoch 97/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0575 - accuracy: 0.9773
# Epoch 00097: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 687us/sample - loss: 0.0569 - accuracy: 0.9783 - val_loss: 0.2194 - val_accuracy: 0.9397
# Epoch 98/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0548 - accuracy: 0.9818
# Epoch 00098: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 684us/sample - loss: 0.0530 - accuracy: 0.9826 - val_loss: 0.0700 - val_accuracy: 0.9741
# Epoch 99/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.0334 - accuracy: 0.9892
# Epoch 00099: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 670us/sample - loss: 0.0308 - accuracy: 0.9891 - val_loss: 0.1196 - val_accuracy: 0.9655
# Epoch 100/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0159 - accuracy: 0.9955
# Epoch 00100: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 688us/sample - loss: 0.0163 - accuracy: 0.9957 - val_loss: 0.2672 - val_accuracy: 0.9397
# Epoch 101/250
# 360/460 [======================>.......] - ETA: 0s - loss: 0.0369 - accuracy: 0.9917
# Epoch 00101: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 667us/sample - loss: 0.0298 - accuracy: 0.9935 - val_loss: 0.1226 - val_accuracy: 0.9655
# Epoch 102/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.0216 - accuracy: 0.9949
# Epoch 00102: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 646us/sample - loss: 0.0252 - accuracy: 0.9913 - val_loss: 0.1201 - val_accuracy: 0.9655
# Epoch 103/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.0749 - accuracy: 0.9769
# Epoch 00103: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 638us/sample - loss: 0.0671 - accuracy: 0.9804 - val_loss: 0.1826 - val_accuracy: 0.9483
# Epoch 104/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.0539 - accuracy: 0.9811
# Epoch 00104: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 678us/sample - loss: 0.0565 - accuracy: 0.9804 - val_loss: 0.5052 - val_accuracy: 0.9310
# Epoch 105/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0341 - accuracy: 0.9842
# Epoch 00105: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 647us/sample - loss: 0.0312 - accuracy: 0.9870 - val_loss: 0.3683 - val_accuracy: 0.9310
# Epoch 106/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0256 - accuracy: 0.9884
# Epoch 00106: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 744us/sample - loss: 0.0249 - accuracy: 0.9891 - val_loss: 0.1152 - val_accuracy: 0.9741
# Epoch 107/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.0477 - accuracy: 0.9872
# Epoch 00107: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 648us/sample - loss: 0.0510 - accuracy: 0.9848 - val_loss: 0.0516 - val_accuracy: 0.9828
# Epoch 108/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0670 - accuracy: 0.9786
# Epoch 00108: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 734us/sample - loss: 0.0695 - accuracy: 0.9761 - val_loss: 0.0990 - val_accuracy: 0.9569
# Epoch 109/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0273 - accuracy: 0.9955
# Epoch 00109: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 696us/sample - loss: 0.0264 - accuracy: 0.9957 - val_loss: 0.1898 - val_accuracy: 0.9397
# Epoch 110/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0165 - accuracy: 0.9956
# Epoch 00110: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 666us/sample - loss: 0.0169 - accuracy: 0.9957 - val_loss: 0.1350 - val_accuracy: 0.9483
# Epoch 111/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0189 - accuracy: 0.9932
# Epoch 00111: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 704us/sample - loss: 0.0195 - accuracy: 0.9935 - val_loss: 0.0671 - val_accuracy: 0.9828
# Epoch 112/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.0172 - accuracy: 0.9946
# Epoch 00112: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 675us/sample - loss: 0.0158 - accuracy: 0.9957 - val_loss: 0.0928 - val_accuracy: 0.9741
# Epoch 113/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0086 - accuracy: 1.0000
# Epoch 00113: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 723us/sample - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9569
# Epoch 114/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 00114: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 732us/sample - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1332 - val_accuracy: 0.9569
# Epoch 115/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.0665 - accuracy: 0.9838
# Epoch 00115: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 659us/sample - loss: 0.0744 - accuracy: 0.9783 - val_loss: 0.0975 - val_accuracy: 0.9741
# Epoch 116/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0925 - accuracy: 0.9632
# Epoch 00116: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 662us/sample - loss: 0.1014 - accuracy: 0.9630 - val_loss: 0.5983 - val_accuracy: 0.8879
# Epoch 117/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0654 - accuracy: 0.9805
# Epoch 00117: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 762us/sample - loss: 0.0631 - accuracy: 0.9804 - val_loss: 0.0925 - val_accuracy: 0.9741
# Epoch 118/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0219 - accuracy: 0.9927
# Epoch 00118: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 781us/sample - loss: 0.0198 - accuracy: 0.9935 - val_loss: 0.0629 - val_accuracy: 0.9828
# Epoch 119/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0229 - accuracy: 0.9902
# Epoch 00119: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 770us/sample - loss: 0.0215 - accuracy: 0.9913 - val_loss: 0.1199 - val_accuracy: 0.9655
# Epoch 120/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0115 - accuracy: 0.9976
# Epoch 00120: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 775us/sample - loss: 0.0113 - accuracy: 0.9978 - val_loss: 0.1182 - val_accuracy: 0.9741
# Epoch 121/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0310 - accuracy: 0.9902
# Epoch 00121: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 760us/sample - loss: 0.0282 - accuracy: 0.9913 - val_loss: 0.1403 - val_accuracy: 0.9655
# Epoch 122/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0176 - accuracy: 0.9950
# Epoch 00122: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 758us/sample - loss: 0.0179 - accuracy: 0.9935 - val_loss: 0.1188 - val_accuracy: 0.9655
# Epoch 123/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.0167 - accuracy: 0.9897
# Epoch 00123: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 786us/sample - loss: 0.0161 - accuracy: 0.9913 - val_loss: 0.0647 - val_accuracy: 0.9741
# Epoch 124/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0179 - accuracy: 0.9902
# Epoch 00124: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 782us/sample - loss: 0.0164 - accuracy: 0.9913 - val_loss: 0.1465 - val_accuracy: 0.9655
# Epoch 125/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0393 - accuracy: 0.9878
# Epoch 00125: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 764us/sample - loss: 0.0612 - accuracy: 0.9848 - val_loss: 0.0866 - val_accuracy: 0.9655
# Epoch 126/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0469 - accuracy: 0.9854
# Epoch 00126: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 754us/sample - loss: 0.0436 - accuracy: 0.9870 - val_loss: 0.1474 - val_accuracy: 0.9569
# Epoch 127/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0117 - accuracy: 0.9978
# Epoch 00127: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 808us/sample - loss: 0.0115 - accuracy: 0.9978 - val_loss: 0.3702 - val_accuracy: 0.9397
# Epoch 128/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0178 - accuracy: 0.9975
# Epoch 00128: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 773us/sample - loss: 0.0161 - accuracy: 0.9978 - val_loss: 0.2862 - val_accuracy: 0.9397
# Epoch 129/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0245 - accuracy: 0.9925
# Epoch 00129: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 848us/sample - loss: 0.0218 - accuracy: 0.9935 - val_loss: 0.1339 - val_accuracy: 0.9741
# Epoch 130/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0083 - accuracy: 0.9976
# Epoch 00130: val_accuracy did not improve from 0.98276
# 460/460 [==============================] - 0s 758us/sample - loss: 0.0143 - accuracy: 0.9957 - val_loss: 0.1026 - val_accuracy: 0.9828
# Epoch 131/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0700 - accuracy: 0.9732
# Epoch 00131: val_accuracy improved from 0.98276 to 0.99138, saving model to models/model2_131.h5
# 460/460 [==============================] - 0s 857us/sample - loss: 0.0699 - accuracy: 0.9739 - val_loss: 0.0520 - val_accuracy: 0.9914
# Epoch 132/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.0426 - accuracy: 0.9923
# Epoch 00132: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 773us/sample - loss: 0.0388 - accuracy: 0.9913 - val_loss: 0.0596 - val_accuracy: 0.9741
# Epoch 133/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0121 - accuracy: 1.0000
# Epoch 00133: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 763us/sample - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.1227 - val_accuracy: 0.9741
# Epoch 134/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0105 - accuracy: 0.9950
# Epoch 00134: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 759us/sample - loss: 0.0095 - accuracy: 0.9957 - val_loss: 0.0778 - val_accuracy: 0.9828
# Epoch 135/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0500 - accuracy: 0.9857
# Epoch 00135: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 775us/sample - loss: 0.0564 - accuracy: 0.9848 - val_loss: 0.2244 - val_accuracy: 0.9397
# Epoch 136/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.1785 - accuracy: 0.9463
# Epoch 00136: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 765us/sample - loss: 0.1619 - accuracy: 0.9522 - val_loss: 0.0736 - val_accuracy: 0.9741
# Epoch 137/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0693 - accuracy: 0.9875
# Epoch 00137: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 771us/sample - loss: 0.0638 - accuracy: 0.9891 - val_loss: 0.2533 - val_accuracy: 0.9569
# Epoch 138/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0350 - accuracy: 0.9905
# Epoch 00138: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 788us/sample - loss: 0.0334 - accuracy: 0.9913 - val_loss: 0.0803 - val_accuracy: 0.9741
# Epoch 139/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.0184 - accuracy: 0.9974
# Epoch 00139: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 696us/sample - loss: 0.0180 - accuracy: 0.9978 - val_loss: 0.0693 - val_accuracy: 0.9741
# Epoch 140/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0090 - accuracy: 0.9976
# Epoch 00140: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 941us/sample - loss: 0.0102 - accuracy: 0.9957 - val_loss: 0.0755 - val_accuracy: 0.9741
# Epoch 141/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 00141: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 992us/sample - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0878 - val_accuracy: 0.9741
# Epoch 142/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0399 - accuracy: 0.9814
# Epoch 00142: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 980us/sample - loss: 0.0379 - accuracy: 0.9826 - val_loss: 0.1729 - val_accuracy: 0.9397
# Epoch 143/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0427 - accuracy: 0.9857
# Epoch 00143: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0415 - accuracy: 0.9870 - val_loss: 0.0846 - val_accuracy: 0.9741
# Epoch 144/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0278 - accuracy: 0.9933
# Epoch 00144: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0289 - accuracy: 0.9913 - val_loss: 0.2911 - val_accuracy: 0.9310
# Epoch 145/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0523 - accuracy: 0.9822
# Epoch 00145: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 997us/sample - loss: 0.0513 - accuracy: 0.9826 - val_loss: 0.6296 - val_accuracy: 0.9138
# Epoch 146/250
# 410/460 [=========================>....] - ETA: 0s - loss: 0.0482 - accuracy: 0.9829
# Epoch 00146: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0475 - accuracy: 0.9826 - val_loss: 0.1874 - val_accuracy: 0.9569
# Epoch 147/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0388 - accuracy: 0.9833
# Epoch 00147: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 955us/sample - loss: 0.0372 - accuracy: 0.9848 - val_loss: 0.1270 - val_accuracy: 0.9569
# Epoch 148/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0095 - accuracy: 0.9976
# Epoch 00148: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 853us/sample - loss: 0.0090 - accuracy: 0.9978 - val_loss: 0.0481 - val_accuracy: 0.9828
# Epoch 149/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0123 - accuracy: 0.9956
# Epoch 00149: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 833us/sample - loss: 0.0120 - accuracy: 0.9957 - val_loss: 0.2284 - val_accuracy: 0.9483
# Epoch 150/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0176 - accuracy: 0.9974
# Epoch 00150: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 810us/sample - loss: 0.0194 - accuracy: 0.9935 - val_loss: 0.0905 - val_accuracy: 0.9741
# Epoch 151/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0119 - accuracy: 0.9921
# Epoch 00151: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 805us/sample - loss: 0.0103 - accuracy: 0.9935 - val_loss: 0.1351 - val_accuracy: 0.9569
# Epoch 152/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0121 - accuracy: 0.9953
# Epoch 00152: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 873us/sample - loss: 0.0145 - accuracy: 0.9935 - val_loss: 0.1792 - val_accuracy: 0.9483
# Epoch 153/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0077 - accuracy: 0.9978
# Epoch 00153: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 829us/sample - loss: 0.0076 - accuracy: 0.9978 - val_loss: 0.0973 - val_accuracy: 0.9741
# Epoch 154/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0069 - accuracy: 0.9956
# Epoch 00154: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 854us/sample - loss: 0.0069 - accuracy: 0.9957 - val_loss: 0.0973 - val_accuracy: 0.9828
# Epoch 155/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0041 - accuracy: 0.9977
# Epoch 00155: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 863us/sample - loss: 0.0040 - accuracy: 0.9978 - val_loss: 0.0952 - val_accuracy: 0.9828
# Epoch 156/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0093 - accuracy: 0.9977
# Epoch 00156: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 890us/sample - loss: 0.0087 - accuracy: 0.9978 - val_loss: 0.1035 - val_accuracy: 0.9828
# Epoch 157/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0100 - accuracy: 0.9956
# Epoch 00157: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 991us/sample - loss: 0.0099 - accuracy: 0.9957 - val_loss: 1.0152 - val_accuracy: 0.9138
# Epoch 158/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0591 - accuracy: 0.9762
# Epoch 00158: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 981us/sample - loss: 0.0583 - accuracy: 0.9761 - val_loss: 0.4265 - val_accuracy: 0.9397
# Epoch 159/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0066 - accuracy: 1.0000
# Epoch 00159: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.1339 - val_accuracy: 0.9655
# Epoch 160/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0137 - accuracy: 0.9933
# Epoch 00160: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0134 - accuracy: 0.9935 - val_loss: 0.2284 - val_accuracy: 0.9655
# Epoch 161/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0229 - accuracy: 0.9953
# Epoch 00161: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 1ms/sample - loss: 0.0217 - accuracy: 0.9957 - val_loss: 0.1252 - val_accuracy: 0.9655
# Epoch 162/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 00162: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 781us/sample - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0491 - val_accuracy: 0.9828
# Epoch 163/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0140 - accuracy: 0.9950
# Epoch 00163: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 778us/sample - loss: 0.0292 - accuracy: 0.9935 - val_loss: 0.1272 - val_accuracy: 0.9741
# Epoch 164/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0703 - accuracy: 0.9895
# Epoch 00164: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 806us/sample - loss: 0.0583 - accuracy: 0.9913 - val_loss: 0.1384 - val_accuracy: 0.9741
# Epoch 165/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.0106 - accuracy: 0.9974
# Epoch 00165: val_accuracy did not improve from 0.99138
# ...
# Epoch 196/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 00196: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 842us/sample - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1281 - val_accuracy: 0.9655
# Epoch 197/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 00197: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 795us/sample - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1777 - val_accuracy: 0.9655
# Epoch 198/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 00198: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 829us/sample - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1164 - val_accuracy: 0.9828
# Epoch 199/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00199: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 814us/sample - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2017 - val_accuracy: 0.9655
# Epoch 200/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0086 - accuracy: 0.9952
# Epoch 00200: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 891us/sample - loss: 0.0079 - accuracy: 0.9957 - val_loss: 0.3576 - val_accuracy: 0.9483
# Epoch 201/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 00201: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 782us/sample - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.2207 - val_accuracy: 0.9655
# Epoch 202/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 00202: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 747us/sample - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1654 - val_accuracy: 0.9655
# Epoch 203/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000
# Epoch 00203: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 656us/sample - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2189 - val_accuracy: 0.9483
# Epoch 204/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.0027 - accuracy: 1.0000
# Epoch 00204: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 641us/sample - loss: 0.0046 - accuracy: 0.9978 - val_loss: 0.2107 - val_accuracy: 0.9483
# Epoch 205/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 00205: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 640us/sample - loss: 0.0121 - accuracy: 0.9978 - val_loss: 0.3930 - val_accuracy: 0.9397
# Epoch 206/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 00206: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 641us/sample - loss: 0.0365 - accuracy: 0.9935 - val_loss: 0.0841 - val_accuracy: 0.9828
# Epoch 207/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0621 - accuracy: 0.9816
# Epoch 00207: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 630us/sample - loss: 0.0528 - accuracy: 0.9848 - val_loss: 0.1775 - val_accuracy: 0.9655
# Epoch 208/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 00208: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 644us/sample - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.3085 - val_accuracy: 0.9569
# Epoch 209/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 00209: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 645us/sample - loss: 0.0100 - accuracy: 0.9957 - val_loss: 0.1487 - val_accuracy: 0.9655
# Epoch 210/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 00210: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 643us/sample - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1194 - val_accuracy: 0.9741
# Epoch 211/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 00211: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 638us/sample - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1272 - val_accuracy: 0.9741
# Epoch 212/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 00212: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 645us/sample - loss: 0.0053 - accuracy: 0.9978 - val_loss: 0.0998 - val_accuracy: 0.9741
# Epoch 213/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.0423 - accuracy: 0.9872
# Epoch 00213: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 638us/sample - loss: 0.0428 - accuracy: 0.9870 - val_loss: 0.2973 - val_accuracy: 0.9397
# Epoch 214/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0563 - accuracy: 0.9868
# Epoch 00214: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 655us/sample - loss: 0.0486 - accuracy: 0.9870 - val_loss: 0.1415 - val_accuracy: 0.9741
# Epoch 215/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0260 - accuracy: 0.9947
# Epoch 00215: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 647us/sample - loss: 0.0230 - accuracy: 0.9957 - val_loss: 0.0955 - val_accuracy: 0.9828
# Epoch 216/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0273 - accuracy: 0.9868
# Epoch 00216: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 641us/sample - loss: 0.0358 - accuracy: 0.9826 - val_loss: 0.2585 - val_accuracy: 0.9224
# Epoch 217/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0633 - accuracy: 0.9868
# Epoch 00217: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 664us/sample - loss: 0.0702 - accuracy: 0.9804 - val_loss: 0.1550 - val_accuracy: 0.9569
# Epoch 218/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.0335 - accuracy: 0.9923
# Epoch 00218: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 640us/sample - loss: 0.0294 - accuracy: 0.9935 - val_loss: 0.0898 - val_accuracy: 0.9741
# Epoch 219/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0084 - accuracy: 0.9977
# Epoch 00219: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 843us/sample - loss: 0.0138 - accuracy: 0.9957 - val_loss: 0.1053 - val_accuracy: 0.9828
# Epoch 220/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0116 - accuracy: 0.9947
# Epoch 00220: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 643us/sample - loss: 0.0105 - accuracy: 0.9957 - val_loss: 0.1890 - val_accuracy: 0.9569
# Epoch 221/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 00221: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 647us/sample - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1104 - val_accuracy: 0.9828
# Epoch 222/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0056 - accuracy: 0.9974
# Epoch 00222: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 650us/sample - loss: 0.0049 - accuracy: 0.9978 - val_loss: 0.1242 - val_accuracy: 0.9828
# Epoch 223/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 00223: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 644us/sample - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1365 - val_accuracy: 0.9828
# Epoch 224/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00224: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 650us/sample - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1115 - val_accuracy: 0.9741
# Epoch 225/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0569 - accuracy: 0.9850
# Epoch 00225: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 633us/sample - loss: 0.0500 - accuracy: 0.9870 - val_loss: 0.2118 - val_accuracy: 0.9569
# Epoch 226/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0062 - accuracy: 0.9975
# Epoch 00226: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 638us/sample - loss: 0.0104 - accuracy: 0.9957 - val_loss: 0.0638 - val_accuracy: 0.9828
# Epoch 227/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0070 - accuracy: 0.9974
# Epoch 00227: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 639us/sample - loss: 0.0067 - accuracy: 0.9978 - val_loss: 0.0680 - val_accuracy: 0.9828
# Epoch 228/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 00228: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 661us/sample - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1605 - val_accuracy: 0.9828
# Epoch 229/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 00229: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 656us/sample - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9741
# Epoch 230/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 00230: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 641us/sample - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1285 - val_accuracy: 0.9828
# Epoch 231/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 00231: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 649us/sample - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.3255 - val_accuracy: 0.9655
# Epoch 232/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.0449 - accuracy: 0.9892
# Epoch 00232: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 659us/sample - loss: 0.0488 - accuracy: 0.9848 - val_loss: 0.0630 - val_accuracy: 0.9828
# Epoch 233/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.0409 - accuracy: 0.9872
# Epoch 00233: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 638us/sample - loss: 0.0522 - accuracy: 0.9848 - val_loss: 0.0744 - val_accuracy: 0.9655
# Epoch 234/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.0190 - accuracy: 0.9946
# Epoch 00234: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 642us/sample - loss: 0.0156 - accuracy: 0.9957 - val_loss: 0.0988 - val_accuracy: 0.9828
# Epoch 235/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0063 - accuracy: 0.9975
# Epoch 00235: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 636us/sample - loss: 0.0059 - accuracy: 0.9978 - val_loss: 0.0889 - val_accuracy: 0.9828
# Epoch 236/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 00236: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 644us/sample - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1099 - val_accuracy: 0.9828
# Epoch 237/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0125 - accuracy: 0.9950
# Epoch 00237: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 624us/sample - loss: 0.0110 - accuracy: 0.9957 - val_loss: 0.2769 - val_accuracy: 0.9655
# Epoch 238/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000
# Epoch 00238: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 627us/sample - loss: 0.0101 - accuracy: 0.9957 - val_loss: 0.0834 - val_accuracy: 0.9741
# Epoch 239/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 00239: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 664us/sample - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9569
# Epoch 240/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.0066 - accuracy: 0.9952
# Epoch 00240: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 837us/sample - loss: 0.0062 - accuracy: 0.9957 - val_loss: 0.1832 - val_accuracy: 0.9569
# Epoch 241/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.0050 - accuracy: 0.9977
# Epoch 00241: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 993us/sample - loss: 0.0086 - accuracy: 0.9957 - val_loss: 0.1211 - val_accuracy: 0.9741
# Epoch 242/250
# 370/460 [=======================>......] - ETA: 0s - loss: 0.0067 - accuracy: 0.9973
# Epoch 00242: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 887us/sample - loss: 0.0061 - accuracy: 0.9978 - val_loss: 0.0780 - val_accuracy: 0.9828
# Epoch 243/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000
# Epoch 00243: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 659us/sample - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1071 - val_accuracy: 0.9828
# Epoch 244/250
# 360/460 [======================>.......] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 00244: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 656us/sample - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0619 - val_accuracy: 0.9828
# Epoch 245/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 00245: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 658us/sample - loss: 0.0083 - accuracy: 0.9978 - val_loss: 0.1027 - val_accuracy: 0.9741
# Epoch 246/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.1385 - accuracy: 0.9692
# Epoch 00246: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 769us/sample - loss: 0.1331 - accuracy: 0.9696 - val_loss: 0.0280 - val_accuracy: 0.9914
# Epoch 247/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0089 - accuracy: 0.9978
# Epoch 00247: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 683us/sample - loss: 0.0090 - accuracy: 0.9978 - val_loss: 0.0272 - val_accuracy: 0.9914
# Epoch 248/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 00248: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 877us/sample - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0338 - val_accuracy: 0.9914
# Epoch 249/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.0058 - accuracy: 0.9974
# Epoch 00249: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 916us/sample - loss: 0.0053 - accuracy: 0.9978 - val_loss: 0.0335 - val_accuracy: 0.9914
# Epoch 250/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00250: val_accuracy did not improve from 0.99138
# 460/460 [==============================] - 0s 641us/sample - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0368 - val_accuracy: 0.9914
# Training completed in time:  0:01:25.276165

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste
#
# Lembrando que estamos utilizando o mesmo conjunto de validacão, que a princípio, pode incluir instâncias do conjunto de treinamento: o dataset utilizado foi gerado com corte de áudio, então alguns trechos do mesmo áudio podem estar presentes em ambos os conjuntos de treinamento e teste.
# Por ora deixamos assim já que estamos realizando uma investigacão inicial.

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  1.0
# Testing Accuracy:  0.9913793

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.98      1.00      0.99        56
#    Pneumonia       1.00      0.98      0.99        60
#
#     accuracy                           0.99       116
#    macro avg       0.99      0.99      0.99       116
# weighted avg       0.99      0.99      0.99       116

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[56  0]
#  [ 1 59]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])
