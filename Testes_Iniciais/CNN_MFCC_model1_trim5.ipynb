# %% [markdown]
# # Rede CNN - Modelo 1
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - trim5

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP = 'trim5'
MAX_PAD_LEN = 216

# %%
filepaths = glob.glob(f'./datasets/{GROUP}/**/*.wav', recursive=True)
filenames = [os.path.splitext(os.path.basename(p))[0] for p in filepaths]

# %%
p_id_in_file = [] # patient IDs corresponding to each file
for name in filenames:
    p_id_in_file.append(int(name[:3]))

p_id_in_file = np.array(p_id_in_file)

# %%
max_pad_len =  MAX_PAD_LEN

os.makedirs("./Respiratory_Sound_Database/features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=5) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./Respiratory_Sound_Database/features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
p_diag = pd.read_csv("./Respiratory_Sound_Database/Respiratory_Sound_Database/patient_diagnosis.csv",header=None) # patient diagnosis file

# %%
labels = np.array([p_diag[p_diag[0] == x][1].values[0] for x in p_id_in_file]) # labels for audio files

# %%
features = [] 

# Iterate through each sound file and extract the features
for file_name in filepaths:
    data = extract_features(file_name)
    features.append(data)

print('Finished feature extraction from ', len(features), ' files')
features = np.array(features)
# Out:
# Finished feature extraction from  216  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
features = np.array(features) # convert to numpy array

# %%
np.unique(labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
# delete diseases
'''
features1 = features
labels1 = labels'''

features1 = np.delete(features, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0) 

labels1 = np.delete(labels, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0)

# %%
# print class counts
unique_elements, counts_elements = np.unique(labels1, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['105' '111']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(labels1)
oh_labels = to_categorical(i_labels)

# %%
features1.shape
# Out:
# (216, 40, 216)

# %%
# add channel dimension for CNN
features1 = np.reshape(features1, (*features1.shape,1)) 

# train test split
x_train, x_test, y_train, y_test = train_test_split(features1, oh_labels, stratify=oh_labels, 
                                                    test_size=0.2, random_state = 42)

# %% [markdown]
# **MLP model architecture**

# %%
num_rows = 40
num_columns = 216
num_channels = 1

num_labels = oh_labels.shape[1]
filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 215, 16)       80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 107, 16)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 107, 16)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 106, 32)       2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 53, 32)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 53, 32)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 52, 64)         8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 26, 64)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 26, 64)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 25, 128)        32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 12, 128)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 12, 128)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 258
# =================================================================
# Total params: 43,570
# Trainable params: 43,570
# Non-trainable params: 0
# _________________________________________________________________
# 44/44 [==============================] - 1s 25ms/sample - loss: 2.2195 - accuracy: 0.5227
# Pre-training accuracy: 52.2727%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 250
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/model2_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 172 samples, validate on 44 samples
# Epoch 1/250
# 170/172 [============================>.] - ETA: 0s - loss: 3.2199 - accuracy: 0.5588
# Epoch 00001: val_accuracy improved from -inf to 0.47727, saving model to models/model2_01.h5
# 172/172 [==============================] - 1s 5ms/sample - loss: 3.1973 - accuracy: 0.5581 - val_loss: 0.7867 - val_accuracy: 0.4773
# Epoch 2/250
#  90/172 [==============>...............] - ETA: 0s - loss: 1.5343 - accuracy: 0.4778
# Epoch 00002: val_accuracy improved from 0.47727 to 0.56818, saving model to models/model2_02.h5
# 172/172 [==============================] - 0s 926us/sample - loss: 1.3732 - accuracy: 0.5349 - val_loss: 0.6565 - val_accuracy: 0.5682
# Epoch 3/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.7838 - accuracy: 0.5667
# Epoch 00003: val_accuracy did not improve from 0.56818
# 172/172 [==============================] - 0s 743us/sample - loss: 0.8640 - accuracy: 0.5640 - val_loss: 0.6770 - val_accuracy: 0.4773
# Epoch 4/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.9165 - accuracy: 0.6000
# Epoch 00004: val_accuracy did not improve from 0.56818
# 172/172 [==============================] - 0s 706us/sample - loss: 0.7930 - accuracy: 0.6221 - val_loss: 0.6279 - val_accuracy: 0.5455
# Epoch 5/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.6140 - accuracy: 0.6667
# Epoch 00005: val_accuracy improved from 0.56818 to 0.79545, saving model to models/model2_05.h5
# 172/172 [==============================] - 0s 867us/sample - loss: 0.6044 - accuracy: 0.6512 - val_loss: 0.5834 - val_accuracy: 0.7955
# Epoch 6/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.5882 - accuracy: 0.6800
# Epoch 00006: val_accuracy did not improve from 0.79545
# 172/172 [==============================] - 0s 729us/sample - loss: 0.5634 - accuracy: 0.7151 - val_loss: 0.5699 - val_accuracy: 0.6818
# Epoch 7/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.5485 - accuracy: 0.6778
# Epoch 00007: val_accuracy improved from 0.79545 to 0.86364, saving model to models/model2_07.h5
# 172/172 [==============================] - 0s 1ms/sample - loss: 0.5378 - accuracy: 0.6802 - val_loss: 0.5333 - val_accuracy: 0.8636
# Epoch 8/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.4960 - accuracy: 0.7889
# Epoch 00008: val_accuracy did not improve from 0.86364
# 172/172 [==============================] - 0s 740us/sample - loss: 0.4770 - accuracy: 0.7849 - val_loss: 0.5538 - val_accuracy: 0.6591
# Epoch 9/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.5725 - accuracy: 0.7100
# Epoch 00009: val_accuracy did not improve from 0.86364
# 172/172 [==============================] - 0s 743us/sample - loss: 0.5775 - accuracy: 0.7093 - val_loss: 0.5322 - val_accuracy: 0.7955
# Epoch 10/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.4823 - accuracy: 0.7588
# Epoch 00010: val_accuracy did not improve from 0.86364
# 172/172 [==============================] - 0s 776us/sample - loss: 0.4799 - accuracy: 0.7616 - val_loss: 0.5821 - val_accuracy: 0.6136
# Epoch 11/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.4348 - accuracy: 0.8000
# Epoch 00011: val_accuracy did not improve from 0.86364
# 172/172 [==============================] - 0s 702us/sample - loss: 0.4246 - accuracy: 0.7965 - val_loss: 0.5250 - val_accuracy: 0.7273
# Epoch 12/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.4241 - accuracy: 0.7900
# Epoch 00012: val_accuracy did not improve from 0.86364
# 172/172 [==============================] - 0s 687us/sample - loss: 0.4301 - accuracy: 0.7674 - val_loss: 0.5661 - val_accuracy: 0.6364
# Epoch 13/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.5021 - accuracy: 0.7556
# Epoch 00013: val_accuracy did not improve from 0.86364
# 172/172 [==============================] - 0s 717us/sample - loss: 0.4358 - accuracy: 0.7674 - val_loss: 0.4759 - val_accuracy: 0.7955
# Epoch 14/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.4642 - accuracy: 0.7700
# Epoch 00014: val_accuracy did not improve from 0.86364
# 172/172 [==============================] - 0s 704us/sample - loss: 0.4616 - accuracy: 0.7849 - val_loss: 0.4648 - val_accuracy: 0.8409
# Epoch 15/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.4354 - accuracy: 0.7889
# Epoch 00015: val_accuracy did not improve from 0.86364
# 172/172 [==============================] - 0s 714us/sample - loss: 0.3852 - accuracy: 0.8198 - val_loss: 0.5173 - val_accuracy: 0.7500
# Epoch 16/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.3297 - accuracy: 0.8222
# Epoch 00016: val_accuracy did not improve from 0.86364
# 172/172 [==============================] - 0s 719us/sample - loss: 0.3289 - accuracy: 0.8314 - val_loss: 0.5887 - val_accuracy: 0.6591
# Epoch 17/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.4098 - accuracy: 0.8222
# Epoch 00017: val_accuracy did not improve from 0.86364
# 172/172 [==============================] - 0s 734us/sample - loss: 0.3930 - accuracy: 0.8256 - val_loss: 0.4383 - val_accuracy: 0.7727
# Epoch 18/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.5020 - accuracy: 0.7111
# Epoch 00018: val_accuracy did not improve from 0.86364
# 172/172 [==============================] - 0s 737us/sample - loss: 0.4116 - accuracy: 0.7616 - val_loss: 0.4619 - val_accuracy: 0.8182
# Epoch 19/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.3018 - accuracy: 0.8667
# Epoch 00019: val_accuracy did not improve from 0.86364
# 172/172 [==============================] - 0s 779us/sample - loss: 0.3292 - accuracy: 0.8488 - val_loss: 0.4755 - val_accuracy: 0.8182
# Epoch 20/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.3325 - accuracy: 0.8588
# Epoch 00020: val_accuracy did not improve from 0.86364
# 172/172 [==============================] - 0s 819us/sample - loss: 0.3287 - accuracy: 0.8605 - val_loss: 0.4253 - val_accuracy: 0.8409
# Epoch 21/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.3119 - accuracy: 0.8667
# Epoch 00021: val_accuracy did not improve from 0.86364
# 172/172 [==============================] - 0s 713us/sample - loss: 0.2713 - accuracy: 0.8895 - val_loss: 0.4070 - val_accuracy: 0.8409
# Epoch 22/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.3011 - accuracy: 0.8800
# Epoch 00022: val_accuracy did not improve from 0.86364
# 172/172 [==============================] - 0s 730us/sample - loss: 0.2905 - accuracy: 0.8953 - val_loss: 0.4729 - val_accuracy: 0.7727
# Epoch 23/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.4088 - accuracy: 0.7889
# Epoch 00023: val_accuracy did not improve from 0.86364
# 172/172 [==============================] - 0s 712us/sample - loss: 0.4241 - accuracy: 0.7965 - val_loss: 0.3918 - val_accuracy: 0.8409
# Epoch 24/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.3015 - accuracy: 0.8444
# Epoch 00024: val_accuracy did not improve from 0.86364
# 172/172 [==============================] - 0s 746us/sample - loss: 0.2793 - accuracy: 0.8779 - val_loss: 0.4459 - val_accuracy: 0.8182
# Epoch 25/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.3016 - accuracy: 0.8667
# Epoch 00025: val_accuracy did not improve from 0.86364
# 172/172 [==============================] - 0s 758us/sample - loss: 0.2879 - accuracy: 0.8837 - val_loss: 0.3814 - val_accuracy: 0.8409
# Epoch 26/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.2693 - accuracy: 0.8889
# Epoch 00026: val_accuracy did not improve from 0.86364
# 172/172 [==============================] - 0s 707us/sample - loss: 0.2292 - accuracy: 0.9128 - val_loss: 0.4475 - val_accuracy: 0.7955
# Epoch 27/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.3526 - accuracy: 0.8667
# Epoch 00027: val_accuracy did not improve from 0.86364
# 172/172 [==============================] - 0s 723us/sample - loss: 0.2733 - accuracy: 0.8953 - val_loss: 0.3832 - val_accuracy: 0.8182
# Epoch 28/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.2734 - accuracy: 0.8889
# Epoch 00028: val_accuracy did not improve from 0.86364
# 172/172 [==============================] - 0s 730us/sample - loss: 0.2518 - accuracy: 0.8953 - val_loss: 0.4460 - val_accuracy: 0.8409
# Epoch 29/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.2434 - accuracy: 0.8600
# Epoch 00029: val_accuracy did not improve from 0.86364
# 172/172 [==============================] - 0s 712us/sample - loss: 0.2315 - accuracy: 0.8721 - val_loss: 0.3883 - val_accuracy: 0.8409
# Epoch 30/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.2519 - accuracy: 0.8889
# Epoch 00030: val_accuracy did not improve from 0.86364
# 172/172 [==============================] - 0s 728us/sample - loss: 0.2111 - accuracy: 0.9070 - val_loss: 0.3530 - val_accuracy: 0.8409
# Epoch 31/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.2165 - accuracy: 0.9000
# Epoch 00031: val_accuracy improved from 0.86364 to 0.88636, saving model to models/model2_31.h5
# 172/172 [==============================] - 0s 899us/sample - loss: 0.2285 - accuracy: 0.8953 - val_loss: 0.3675 - val_accuracy: 0.8864
# Epoch 32/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.2039 - accuracy: 0.9235
# Epoch 00032: val_accuracy did not improve from 0.88636
# 172/172 [==============================] - 0s 774us/sample - loss: 0.2016 - accuracy: 0.9244 - val_loss: 0.3328 - val_accuracy: 0.8636
# Epoch 33/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.2014 - accuracy: 0.9000
# Epoch 00033: val_accuracy did not improve from 0.88636
# 172/172 [==============================] - 0s 729us/sample - loss: 0.2116 - accuracy: 0.8953 - val_loss: 0.3271 - val_accuracy: 0.8636
# Epoch 34/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.1529 - accuracy: 0.9556
# Epoch 00034: val_accuracy did not improve from 0.88636
# 172/172 [==============================] - 0s 719us/sample - loss: 0.2514 - accuracy: 0.8895 - val_loss: 0.3858 - val_accuracy: 0.7727
# Epoch 35/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.2262 - accuracy: 0.8667
# Epoch 00035: val_accuracy did not improve from 0.88636
# 172/172 [==============================] - 0s 726us/sample - loss: 0.2385 - accuracy: 0.8837 - val_loss: 0.3275 - val_accuracy: 0.8864
# Epoch 36/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.1487 - accuracy: 0.9222
# Epoch 00036: val_accuracy did not improve from 0.88636
# 172/172 [==============================] - 0s 707us/sample - loss: 0.2122 - accuracy: 0.8895 - val_loss: 0.3058 - val_accuracy: 0.8864
# Epoch 37/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.1715 - accuracy: 0.9111
# Epoch 00037: val_accuracy did not improve from 0.88636
# 172/172 [==============================] - 0s 729us/sample - loss: 0.2181 - accuracy: 0.8779 - val_loss: 0.4834 - val_accuracy: 0.8409
# Epoch 38/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.3064 - accuracy: 0.8889
# Epoch 00038: val_accuracy did not improve from 0.88636
# 172/172 [==============================] - 0s 724us/sample - loss: 0.3070 - accuracy: 0.8779 - val_loss: 0.4100 - val_accuracy: 0.8864
# Epoch 39/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.2338 - accuracy: 0.8778
# Epoch 00039: val_accuracy did not improve from 0.88636
# 172/172 [==============================] - 0s 732us/sample - loss: 0.2685 - accuracy: 0.8663 - val_loss: 0.3703 - val_accuracy: 0.8182
# Epoch 40/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.2723 - accuracy: 0.8667
# Epoch 00040: val_accuracy did not improve from 0.88636
# 172/172 [==============================] - 0s 717us/sample - loss: 0.2207 - accuracy: 0.9070 - val_loss: 0.3588 - val_accuracy: 0.8409
# Epoch 41/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.2544 - accuracy: 0.8889
# Epoch 00041: val_accuracy did not improve from 0.88636
# 172/172 [==============================] - 0s 750us/sample - loss: 0.2349 - accuracy: 0.9012 - val_loss: 0.3687 - val_accuracy: 0.8182
# Epoch 42/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.1928 - accuracy: 0.9111
# Epoch 00042: val_accuracy did not improve from 0.88636
# 172/172 [==============================] - 0s 740us/sample - loss: 0.1958 - accuracy: 0.9128 - val_loss: 0.3033 - val_accuracy: 0.8864
# Epoch 43/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.1748 - accuracy: 0.9200
# Epoch 00043: val_accuracy did not improve from 0.88636
# 172/172 [==============================] - 0s 724us/sample - loss: 0.1894 - accuracy: 0.9128 - val_loss: 0.4742 - val_accuracy: 0.7955
# Epoch 44/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.3414 - accuracy: 0.8333
# Epoch 00044: val_accuracy did not improve from 0.88636
# 172/172 [==============================] - 0s 740us/sample - loss: 0.2707 - accuracy: 0.8721 - val_loss: 0.3374 - val_accuracy: 0.8636
# Epoch 45/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.1785 - accuracy: 0.9333
# Epoch 00045: val_accuracy did not improve from 0.88636
# 172/172 [==============================] - 0s 737us/sample - loss: 0.2129 - accuracy: 0.9012 - val_loss: 0.2874 - val_accuracy: 0.8636
# Epoch 46/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.1558 - accuracy: 0.9100
# Epoch 00046: val_accuracy improved from 0.88636 to 0.90909, saving model to models/model2_46.h5
# 172/172 [==============================] - 0s 858us/sample - loss: 0.1667 - accuracy: 0.9070 - val_loss: 0.2602 - val_accuracy: 0.9091
# Epoch 47/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.1536 - accuracy: 0.9400
# Epoch 00047: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 763us/sample - loss: 0.1541 - accuracy: 0.9419 - val_loss: 0.2481 - val_accuracy: 0.8864
# Epoch 48/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.1654 - accuracy: 0.9333
# Epoch 00048: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 757us/sample - loss: 0.1752 - accuracy: 0.9360 - val_loss: 0.2453 - val_accuracy: 0.9091
# Epoch 49/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.1683 - accuracy: 0.9222
# Epoch 00049: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 752us/sample - loss: 0.1593 - accuracy: 0.9302 - val_loss: 0.2576 - val_accuracy: 0.8636
# Epoch 50/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.4105 - accuracy: 0.8444
# Epoch 00050: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 733us/sample - loss: 0.3831 - accuracy: 0.8488 - val_loss: 0.2656 - val_accuracy: 0.8864
# Epoch 51/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.2434 - accuracy: 0.8778
# Epoch 00051: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 712us/sample - loss: 0.1919 - accuracy: 0.9186 - val_loss: 0.2537 - val_accuracy: 0.8864
# Epoch 52/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.2122 - accuracy: 0.9111
# Epoch 00052: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 731us/sample - loss: 0.1747 - accuracy: 0.9360 - val_loss: 0.2550 - val_accuracy: 0.9091
# Epoch 53/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.1563 - accuracy: 0.9300
# Epoch 00053: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 699us/sample - loss: 0.1611 - accuracy: 0.9302 - val_loss: 0.2445 - val_accuracy: 0.9091
# Epoch 54/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.1112 - accuracy: 0.9556
# Epoch 00054: val_accuracy did not improve from 0.90909
# 172/172 [==============================] - 0s 744us/sample - loss: 0.1554 - accuracy: 0.9244 - val_loss: 0.2394 - val_accuracy: 0.8636
# Epoch 55/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.2387 - accuracy: 0.9000
# Epoch 00055: val_accuracy improved from 0.90909 to 0.93182, saving model to models/model2_55.h5
# 172/172 [==============================] - 0s 927us/sample - loss: 0.1886 - accuracy: 0.9244 - val_loss: 0.2321 - val_accuracy: 0.9318
# Epoch 56/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.2641 - accuracy: 0.8800
# Epoch 00056: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 720us/sample - loss: 0.2446 - accuracy: 0.8663 - val_loss: 0.2725 - val_accuracy: 0.9318
# Epoch 57/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.1560 - accuracy: 0.9412
# Epoch 00057: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 783us/sample - loss: 0.1606 - accuracy: 0.9360 - val_loss: 0.2786 - val_accuracy: 0.9318
# Epoch 58/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.1696 - accuracy: 0.9235
# Epoch 00058: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 794us/sample - loss: 0.1676 - accuracy: 0.9244 - val_loss: 0.2370 - val_accuracy: 0.9318
# Epoch 59/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.1716 - accuracy: 0.9300
# Epoch 00059: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 695us/sample - loss: 0.1481 - accuracy: 0.9360 - val_loss: 0.2141 - val_accuracy: 0.8864
# Epoch 60/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.1564 - accuracy: 0.9412
# Epoch 00060: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 774us/sample - loss: 0.1563 - accuracy: 0.9419 - val_loss: 0.2742 - val_accuracy: 0.9091
# Epoch 61/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.1487 - accuracy: 0.9500
# Epoch 00061: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 713us/sample - loss: 0.1559 - accuracy: 0.9360 - val_loss: 0.2955 - val_accuracy: 0.9091
# Epoch 62/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.2718 - accuracy: 0.8600
# Epoch 00062: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 693us/sample - loss: 0.2216 - accuracy: 0.8779 - val_loss: 0.2454 - val_accuracy: 0.9318
# Epoch 63/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.1973 - accuracy: 0.9222
# Epoch 00063: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 755us/sample - loss: 0.1920 - accuracy: 0.9302 - val_loss: 0.2367 - val_accuracy: 0.9091
# Epoch 64/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.1726 - accuracy: 0.9444
# Epoch 00064: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 779us/sample - loss: 0.1504 - accuracy: 0.9419 - val_loss: 0.2115 - val_accuracy: 0.8864
# Epoch 65/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.1169 - accuracy: 0.9556
# Epoch 00065: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 738us/sample - loss: 0.1530 - accuracy: 0.9419 - val_loss: 0.2080 - val_accuracy: 0.8864
# Epoch 66/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.1910 - accuracy: 0.9333
# Epoch 00066: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 756us/sample - loss: 0.1747 - accuracy: 0.9360 - val_loss: 0.2184 - val_accuracy: 0.9091
# Epoch 67/250
# 160/172 [==========================>...] - ETA: 0s - loss: 0.1404 - accuracy: 0.9312
# Epoch 00067: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 840us/sample - loss: 0.1480 - accuracy: 0.9244 - val_loss: 0.1985 - val_accuracy: 0.8864
# Epoch 68/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.0985 - accuracy: 0.9556
# Epoch 00068: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 739us/sample - loss: 0.1605 - accuracy: 0.9302 - val_loss: 0.2317 - val_accuracy: 0.8409
# Epoch 69/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.1711 - accuracy: 0.9600
# Epoch 00069: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 712us/sample - loss: 0.1725 - accuracy: 0.9419 - val_loss: 0.2281 - val_accuracy: 0.9091
# Epoch 70/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.2228 - accuracy: 0.9000
# Epoch 00070: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 715us/sample - loss: 0.2276 - accuracy: 0.8895 - val_loss: 0.2413 - val_accuracy: 0.9318
# Epoch 71/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.1665 - accuracy: 0.9111
# Epoch 00071: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 715us/sample - loss: 0.1508 - accuracy: 0.9302 - val_loss: 0.1944 - val_accuracy: 0.8864
# Epoch 72/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.1754 - accuracy: 0.9444
# Epoch 00072: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 757us/sample - loss: 0.1606 - accuracy: 0.9477 - val_loss: 0.1918 - val_accuracy: 0.9091
# Epoch 73/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.0895 - accuracy: 0.9667
# Epoch 00073: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 751us/sample - loss: 0.1104 - accuracy: 0.9593 - val_loss: 0.2056 - val_accuracy: 0.9091
# Epoch 74/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.0964 - accuracy: 0.9556
# Epoch 00074: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 715us/sample - loss: 0.1382 - accuracy: 0.9593 - val_loss: 0.1838 - val_accuracy: 0.8864
# Epoch 75/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.1069 - accuracy: 0.9444
# Epoch 00075: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 724us/sample - loss: 0.1121 - accuracy: 0.9419 - val_loss: 0.1693 - val_accuracy: 0.9318
# Epoch 76/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.1371 - accuracy: 0.9444
# Epoch 00076: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 734us/sample - loss: 0.1184 - accuracy: 0.9477 - val_loss: 0.1749 - val_accuracy: 0.9318
# Epoch 77/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.1785 - accuracy: 0.9412
# Epoch 00077: val_accuracy did not improve from 0.93182
# 172/172 [==============================] - 0s 755us/sample - loss: 0.1786 - accuracy: 0.9419 - val_loss: 0.2443 - val_accuracy: 0.9091
# Epoch 78/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.3011 - accuracy: 0.8400
# Epoch 00078: val_accuracy improved from 0.93182 to 0.95455, saving model to models/model2_78.h5
# 172/172 [==============================] - 0s 888us/sample - loss: 0.2665 - accuracy: 0.8663 - val_loss: 0.1771 - val_accuracy: 0.9545
# Epoch 79/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.1669 - accuracy: 0.9412
# Epoch 00079: val_accuracy did not improve from 0.95455
# 172/172 [==============================] - 0s 789us/sample - loss: 0.1686 - accuracy: 0.9419 - val_loss: 0.1867 - val_accuracy: 0.9545
# Epoch 80/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.2453 - accuracy: 0.8778
# Epoch 00080: val_accuracy did not improve from 0.95455
# 172/172 [==============================] - 0s 755us/sample - loss: 0.1725 - accuracy: 0.9186 - val_loss: 0.2420 - val_accuracy: 0.9091
# Epoch 81/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.1276 - accuracy: 0.9444
# Epoch 00081: val_accuracy did not improve from 0.95455
# 172/172 [==============================] - 0s 721us/sample - loss: 0.1610 - accuracy: 0.9302 - val_loss: 0.2116 - val_accuracy: 0.9318
# Epoch 82/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.1225 - accuracy: 0.9444
# Epoch 00082: val_accuracy did not improve from 0.95455
# 172/172 [==============================] - 0s 743us/sample - loss: 0.1290 - accuracy: 0.9477 - val_loss: 0.1743 - val_accuracy: 0.9545
# Epoch 83/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.0815 - accuracy: 0.9778
# Epoch 00083: val_accuracy did not improve from 0.95455
# 172/172 [==============================] - 0s 715us/sample - loss: 0.0887 - accuracy: 0.9767 - val_loss: 0.1608 - val_accuracy: 0.9318
# Epoch 84/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.1301 - accuracy: 0.9500
# Epoch 00084: val_accuracy did not improve from 0.95455
# 172/172 [==============================] - 0s 708us/sample - loss: 0.1381 - accuracy: 0.9419 - val_loss: 0.1662 - val_accuracy: 0.9091
# Epoch 85/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.1598 - accuracy: 0.9500
# Epoch 00085: val_accuracy did not improve from 0.95455
# 172/172 [==============================] - 0s 687us/sample - loss: 0.1465 - accuracy: 0.9593 - val_loss: 0.1528 - val_accuracy: 0.9318
# Epoch 86/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0981 - accuracy: 0.9500
# Epoch 00086: val_accuracy did not improve from 0.95455
# 172/172 [==============================] - 0s 699us/sample - loss: 0.0971 - accuracy: 0.9593 - val_loss: 0.1495 - val_accuracy: 0.9545
# Epoch 87/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.0542 - accuracy: 0.9889
# Epoch 00087: val_accuracy did not improve from 0.95455
# 172/172 [==============================] - 0s 732us/sample - loss: 0.0854 - accuracy: 0.9651 - val_loss: 0.1943 - val_accuracy: 0.9318
# Epoch 88/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.0459 - accuracy: 1.0000
# Epoch 00088: val_accuracy did not improve from 0.95455
# 172/172 [==============================] - 0s 746us/sample - loss: 0.0853 - accuracy: 0.9709 - val_loss: 0.2233 - val_accuracy: 0.9318
# Epoch 89/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.1564 - accuracy: 0.9300
# Epoch 00089: val_accuracy did not improve from 0.95455
# 172/172 [==============================] - 0s 687us/sample - loss: 0.1439 - accuracy: 0.9360 - val_loss: 0.1615 - val_accuracy: 0.9318
# Epoch 90/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.1410 - accuracy: 0.9444
# Epoch 00090: val_accuracy did not improve from 0.95455
# 172/172 [==============================] - 0s 732us/sample - loss: 0.1147 - accuracy: 0.9593 - val_loss: 0.1416 - val_accuracy: 0.9318
# Epoch 91/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0654 - accuracy: 0.9824
# Epoch 00091: val_accuracy did not improve from 0.95455
# 172/172 [==============================] - 0s 765us/sample - loss: 0.0687 - accuracy: 0.9826 - val_loss: 0.1787 - val_accuracy: 0.9091
# Epoch 92/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.2261 - accuracy: 0.9300
# Epoch 00092: val_accuracy did not improve from 0.95455
# 172/172 [==============================] - 0s 726us/sample - loss: 0.2259 - accuracy: 0.9302 - val_loss: 0.2160 - val_accuracy: 0.9318
# Epoch 93/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.1705 - accuracy: 0.9400
# Epoch 00093: val_accuracy did not improve from 0.95455
# 172/172 [==============================] - 0s 744us/sample - loss: 0.1450 - accuracy: 0.9477 - val_loss: 0.1611 - val_accuracy: 0.9545
# Epoch 94/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.1750 - accuracy: 0.9400
# Epoch 00094: val_accuracy did not improve from 0.95455
# 172/172 [==============================] - 0s 756us/sample - loss: 0.1654 - accuracy: 0.9419 - val_loss: 0.1733 - val_accuracy: 0.9318
# Epoch 95/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.1205 - accuracy: 0.9647
# Epoch 00095: val_accuracy did not improve from 0.95455
# 172/172 [==============================] - 0s 795us/sample - loss: 0.1196 - accuracy: 0.9651 - val_loss: 0.2734 - val_accuracy: 0.9091
# Epoch 96/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.1358 - accuracy: 0.9353
# Epoch 00096: val_accuracy did not improve from 0.95455
# 172/172 [==============================] - 0s 769us/sample - loss: 0.1343 - accuracy: 0.9360 - val_loss: 0.1424 - val_accuracy: 0.9545
# Epoch 97/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.1036 - accuracy: 0.9471
# Epoch 00097: val_accuracy improved from 0.95455 to 0.97727, saving model to models/model2_97.h5
# 172/172 [==============================] - 0s 964us/sample - loss: 0.1143 - accuracy: 0.9419 - val_loss: 0.1650 - val_accuracy: 0.9773
# Epoch 98/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.1173 - accuracy: 0.9647
# Epoch 00098: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 790us/sample - loss: 0.1249 - accuracy: 0.9593 - val_loss: 0.1782 - val_accuracy: 0.9318
# Epoch 99/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.1064 - accuracy: 0.9333
# Epoch 00099: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 765us/sample - loss: 0.1816 - accuracy: 0.9070 - val_loss: 0.1930 - val_accuracy: 0.9091
# Epoch 100/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.0846 - accuracy: 0.9667
# Epoch 00100: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 755us/sample - loss: 0.0874 - accuracy: 0.9651 - val_loss: 0.1478 - val_accuracy: 0.9318
# Epoch 101/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.1052 - accuracy: 0.9700
# Epoch 00101: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 763us/sample - loss: 0.1064 - accuracy: 0.9709 - val_loss: 0.1417 - val_accuracy: 0.9318
# Epoch 102/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0956 - accuracy: 0.9588
# Epoch 00102: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 789us/sample - loss: 0.0946 - accuracy: 0.9593 - val_loss: 0.1216 - val_accuracy: 0.9773
# Epoch 103/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.1232 - accuracy: 0.9333
# Epoch 00103: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 788us/sample - loss: 0.0965 - accuracy: 0.9535 - val_loss: 0.1662 - val_accuracy: 0.9545
# Epoch 104/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0800 - accuracy: 0.9706
# Epoch 00104: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 820us/sample - loss: 0.0790 - accuracy: 0.9709 - val_loss: 0.1942 - val_accuracy: 0.9318
# Epoch 105/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.1426 - accuracy: 0.9600
# Epoch 00105: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 783us/sample - loss: 0.0941 - accuracy: 0.9767 - val_loss: 0.1267 - val_accuracy: 0.9318
# Epoch 106/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0762 - accuracy: 0.9647
# Epoch 00106: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 797us/sample - loss: 0.0757 - accuracy: 0.9651 - val_loss: 0.1902 - val_accuracy: 0.9318
# Epoch 107/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.1172 - accuracy: 0.9647
# Epoch 00107: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 779us/sample - loss: 0.1159 - accuracy: 0.9651 - val_loss: 0.1587 - val_accuracy: 0.9318
# Epoch 108/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0774 - accuracy: 0.9800
# Epoch 00108: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 772us/sample - loss: 0.0699 - accuracy: 0.9767 - val_loss: 0.1168 - val_accuracy: 0.9545
# Epoch 109/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.0684 - accuracy: 0.9667
# Epoch 00109: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 749us/sample - loss: 0.0694 - accuracy: 0.9709 - val_loss: 0.1159 - val_accuracy: 0.9773
# Epoch 110/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.1363 - accuracy: 0.9333
# Epoch 00110: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 741us/sample - loss: 0.0911 - accuracy: 0.9593 - val_loss: 0.1809 - val_accuracy: 0.9318
# Epoch 111/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.1091 - accuracy: 0.9647
# Epoch 00111: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 798us/sample - loss: 0.1080 - accuracy: 0.9651 - val_loss: 0.1951 - val_accuracy: 0.9318
# Epoch 112/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.1232 - accuracy: 0.9400
# Epoch 00112: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 710us/sample - loss: 0.0967 - accuracy: 0.9593 - val_loss: 0.1531 - val_accuracy: 0.9318
# Epoch 113/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0768 - accuracy: 0.9800
# Epoch 00113: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 714us/sample - loss: 0.0775 - accuracy: 0.9709 - val_loss: 0.1191 - val_accuracy: 0.9773
# Epoch 114/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0841 - accuracy: 0.9700
# Epoch 00114: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 737us/sample - loss: 0.0723 - accuracy: 0.9709 - val_loss: 0.1244 - val_accuracy: 0.9318
# Epoch 115/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0954 - accuracy: 0.9500
# Epoch 00115: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 727us/sample - loss: 0.0786 - accuracy: 0.9593 - val_loss: 0.1313 - val_accuracy: 0.9318
# Epoch 116/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0572 - accuracy: 0.9900
# Epoch 00116: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 705us/sample - loss: 0.0532 - accuracy: 0.9884 - val_loss: 0.1188 - val_accuracy: 0.9545
# Epoch 117/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0555 - accuracy: 0.9800
# Epoch 00117: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 730us/sample - loss: 0.0517 - accuracy: 0.9826 - val_loss: 0.1067 - val_accuracy: 0.9545
# Epoch 118/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.1199 - accuracy: 0.9588
# Epoch 00118: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 748us/sample - loss: 0.1185 - accuracy: 0.9593 - val_loss: 0.1019 - val_accuracy: 0.9545
# Epoch 119/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.1193 - accuracy: 0.9500
# Epoch 00119: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 724us/sample - loss: 0.0909 - accuracy: 0.9593 - val_loss: 0.1072 - val_accuracy: 0.9545
# Epoch 120/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0625 - accuracy: 0.9824
# Epoch 00120: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 805us/sample - loss: 0.0619 - accuracy: 0.9826 - val_loss: 0.1259 - val_accuracy: 0.9318
# Epoch 121/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0872 - accuracy: 0.9800
# Epoch 00121: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 745us/sample - loss: 0.0679 - accuracy: 0.9767 - val_loss: 0.1525 - val_accuracy: 0.9318
# Epoch 122/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0230 - accuracy: 1.0000
# Epoch 00122: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 731us/sample - loss: 0.0676 - accuracy: 0.9767 - val_loss: 0.1199 - val_accuracy: 0.9545
# Epoch 123/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.1011 - accuracy: 0.9600
# Epoch 00123: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 732us/sample - loss: 0.0755 - accuracy: 0.9709 - val_loss: 0.0921 - val_accuracy: 0.9318
# Epoch 124/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0336 - accuracy: 0.9900
# Epoch 00124: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 743us/sample - loss: 0.0550 - accuracy: 0.9767 - val_loss: 0.1150 - val_accuracy: 0.9545
# Epoch 125/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0556 - accuracy: 0.9800
# Epoch 00125: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 741us/sample - loss: 0.0483 - accuracy: 0.9826 - val_loss: 0.1642 - val_accuracy: 0.9545
# Epoch 126/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0784 - accuracy: 0.9700
# Epoch 00126: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 779us/sample - loss: 0.0934 - accuracy: 0.9651 - val_loss: 0.1107 - val_accuracy: 0.9318
# Epoch 127/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0476 - accuracy: 1.0000
# Epoch 00127: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 748us/sample - loss: 0.0740 - accuracy: 0.9826 - val_loss: 0.0843 - val_accuracy: 0.9773
# Epoch 128/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0527 - accuracy: 0.9800
# Epoch 00128: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 719us/sample - loss: 0.0752 - accuracy: 0.9651 - val_loss: 0.0903 - val_accuracy: 0.9773
# Epoch 129/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0733 - accuracy: 0.9700
# Epoch 00129: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 744us/sample - loss: 0.0810 - accuracy: 0.9709 - val_loss: 0.1566 - val_accuracy: 0.9318
# Epoch 130/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.0728 - accuracy: 0.9778
# Epoch 00130: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 751us/sample - loss: 0.0667 - accuracy: 0.9826 - val_loss: 0.0966 - val_accuracy: 0.9773
# Epoch 131/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.0547 - accuracy: 0.9889
# Epoch 00131: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 749us/sample - loss: 0.0792 - accuracy: 0.9767 - val_loss: 0.1566 - val_accuracy: 0.9318
# Epoch 132/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0679 - accuracy: 0.9900
# Epoch 00132: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 738us/sample - loss: 0.0636 - accuracy: 0.9767 - val_loss: 0.1099 - val_accuracy: 0.9545
# Epoch 133/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0889 - accuracy: 0.9700
# Epoch 00133: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 748us/sample - loss: 0.0647 - accuracy: 0.9826 - val_loss: 0.0890 - val_accuracy: 0.9773
# Epoch 134/250
# 160/172 [==========================>...] - ETA: 0s - loss: 0.0981 - accuracy: 0.9500
# Epoch 00134: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 896us/sample - loss: 0.1174 - accuracy: 0.9477 - val_loss: 0.1534 - val_accuracy: 0.9545
# Epoch 135/250
# 140/172 [=======================>......] - ETA: 0s - loss: 0.0844 - accuracy: 0.9643
# Epoch 00135: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 932us/sample - loss: 0.0776 - accuracy: 0.9709 - val_loss: 0.0730 - val_accuracy: 0.9773
# Epoch 136/250
# 160/172 [==========================>...] - ETA: 0s - loss: 0.0639 - accuracy: 0.9750
# Epoch 00136: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 909us/sample - loss: 0.0611 - accuracy: 0.9767 - val_loss: 0.0938 - val_accuracy: 0.9773
# Epoch 137/250
# 150/172 [=========================>....] - ETA: 0s - loss: 0.0843 - accuracy: 0.9667
# Epoch 00137: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 892us/sample - loss: 0.0757 - accuracy: 0.9709 - val_loss: 0.0773 - val_accuracy: 0.9545
# Epoch 138/250
# 130/172 [=====================>........] - ETA: 0s - loss: 0.0544 - accuracy: 0.9846
# Epoch 00138: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 1ms/sample - loss: 0.0502 - accuracy: 0.9884 - val_loss: 0.0815 - val_accuracy: 0.9545
# Epoch 139/250
# 120/172 [===================>..........] - ETA: 0s - loss: 0.0688 - accuracy: 0.9833
# Epoch 00139: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 1ms/sample - loss: 0.0788 - accuracy: 0.9709 - val_loss: 0.0933 - val_accuracy: 0.9545
# Epoch 140/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.1353 - accuracy: 0.9333
# Epoch 00140: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 768us/sample - loss: 0.1256 - accuracy: 0.9360 - val_loss: 0.2640 - val_accuracy: 0.9318
# Epoch 141/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0948 - accuracy: 0.9647
# Epoch 00141: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 865us/sample - loss: 0.0937 - accuracy: 0.9651 - val_loss: 0.0841 - val_accuracy: 0.9773
# Epoch 142/250
# 150/172 [=========================>....] - ETA: 0s - loss: 0.0416 - accuracy: 0.9867
# Epoch 00142: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 1ms/sample - loss: 0.0374 - accuracy: 0.9884 - val_loss: 0.0956 - val_accuracy: 0.9545
# Epoch 143/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0573 - accuracy: 0.9706
# Epoch 00143: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 800us/sample - loss: 0.0566 - accuracy: 0.9709 - val_loss: 0.0902 - val_accuracy: 0.9545
# Epoch 144/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0236 - accuracy: 0.9900
# Epoch 00144: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 784us/sample - loss: 0.0575 - accuracy: 0.9767 - val_loss: 0.0672 - val_accuracy: 0.9773
# Epoch 145/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.0231 - accuracy: 1.0000
# Epoch 00145: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 766us/sample - loss: 0.0486 - accuracy: 0.9884 - val_loss: 0.0698 - val_accuracy: 0.9773
# Epoch 146/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0499 - accuracy: 0.9765
# Epoch 00146: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 795us/sample - loss: 0.0502 - accuracy: 0.9767 - val_loss: 0.1070 - val_accuracy: 0.9545
# Epoch 147/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0429 - accuracy: 0.9800
# Epoch 00147: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 854us/sample - loss: 0.0807 - accuracy: 0.9709 - val_loss: 0.0810 - val_accuracy: 0.9773
# Epoch 148/250
# 160/172 [==========================>...] - ETA: 0s - loss: 0.0813 - accuracy: 0.9500
# Epoch 00148: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 881us/sample - loss: 0.0757 - accuracy: 0.9535 - val_loss: 0.1059 - val_accuracy: 0.9545
# Epoch 149/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0699 - accuracy: 0.9706
# Epoch 00149: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 821us/sample - loss: 0.0703 - accuracy: 0.9709 - val_loss: 0.0762 - val_accuracy: 0.9773
# Epoch 150/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0312 - accuracy: 0.9900
# Epoch 00150: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 747us/sample - loss: 0.0394 - accuracy: 0.9884 - val_loss: 0.0677 - val_accuracy: 0.9773
# Epoch 151/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0604 - accuracy: 0.9700
# Epoch 00151: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 763us/sample - loss: 0.0682 - accuracy: 0.9593 - val_loss: 0.1235 - val_accuracy: 0.9545
# Epoch 152/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0654 - accuracy: 0.9800
# Epoch 00152: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 758us/sample - loss: 0.0641 - accuracy: 0.9767 - val_loss: 0.1196 - val_accuracy: 0.9545
# Epoch 153/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.0232 - accuracy: 1.0000
# Epoch 00153: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 698us/sample - loss: 0.0300 - accuracy: 0.9942 - val_loss: 0.0800 - val_accuracy: 0.9545
# Epoch 154/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0484 - accuracy: 0.9700
# Epoch 00154: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 739us/sample - loss: 0.0401 - accuracy: 0.9826 - val_loss: 0.0949 - val_accuracy: 0.9545
# Epoch 155/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0248 - accuracy: 1.0000
# Epoch 00155: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 697us/sample - loss: 0.0254 - accuracy: 0.9942 - val_loss: 0.0757 - val_accuracy: 0.9545
# Epoch 156/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0278 - accuracy: 0.9900
# Epoch 00156: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 709us/sample - loss: 0.0670 - accuracy: 0.9709 - val_loss: 0.1299 - val_accuracy: 0.9545
# Epoch 157/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0755 - accuracy: 0.9706
# Epoch 00157: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 763us/sample - loss: 0.0749 - accuracy: 0.9709 - val_loss: 0.2404 - val_accuracy: 0.9091
# Epoch 158/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0814 - accuracy: 0.9800
# Epoch 00158: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 764us/sample - loss: 0.0529 - accuracy: 0.9884 - val_loss: 0.1384 - val_accuracy: 0.9318
# Epoch 159/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0595 - accuracy: 0.9700
# Epoch 00159: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 754us/sample - loss: 0.0398 - accuracy: 0.9826 - val_loss: 0.0579 - val_accuracy: 0.9545
# Epoch 160/250
# 160/172 [==========================>...] - ETA: 0s - loss: 0.0276 - accuracy: 0.9937
# Epoch 00160: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 864us/sample - loss: 0.0259 - accuracy: 0.9942 - val_loss: 0.0544 - val_accuracy: 0.9545
# Epoch 161/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0409 - accuracy: 0.9824
# Epoch 00161: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 883us/sample - loss: 0.0404 - accuracy: 0.9826 - val_loss: 0.0649 - val_accuracy: 0.9545
# Epoch 162/250
# 160/172 [==========================>...] - ETA: 0s - loss: 0.0555 - accuracy: 0.9812
# Epoch 00162: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 888us/sample - loss: 0.0597 - accuracy: 0.9767 - val_loss: 0.1286 - val_accuracy: 0.9318
# Epoch 163/250
# 150/172 [=========================>....] - ETA: 0s - loss: 0.0354 - accuracy: 0.9733
# Epoch 00163: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 913us/sample - loss: 0.0343 - accuracy: 0.9767 - val_loss: 0.1645 - val_accuracy: 0.9318
# Epoch 164/250
# 160/172 [==========================>...] - ETA: 0s - loss: 0.0374 - accuracy: 0.9812
# Epoch 00164: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 860us/sample - loss: 0.0357 - accuracy: 0.9826 - val_loss: 0.0877 - val_accuracy: 0.9545
# Epoch 165/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0445 - accuracy: 0.9765
# Epoch 00165: val_accuracy did not improve from 0.97727
# 172/172 [==============================] - 0s 772us/sample - loss: 0.0440 - accuracy: 0.9767 - val_loss: 0.0427 - val_accuracy: 0.9773
# Epoch 166/250
# ...
# Epoch 196/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0586 - accuracy: 0.9800
# Epoch 00196: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 754us/sample - loss: 0.0366 - accuracy: 0.9884 - val_loss: 0.0595 - val_accuracy: 0.9545
# Epoch 197/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0342 - accuracy: 0.9800
# Epoch 00197: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 740us/sample - loss: 0.0336 - accuracy: 0.9826 - val_loss: 0.1439 - val_accuracy: 0.9545
# Epoch 198/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0175 - accuracy: 1.0000
# Epoch 00198: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 787us/sample - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.1125 - val_accuracy: 0.9545
# Epoch 199/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0208 - accuracy: 0.9900
# Epoch 00199: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 722us/sample - loss: 0.0177 - accuracy: 0.9942 - val_loss: 0.2471 - val_accuracy: 0.9545
# Epoch 200/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 0.9824
# Epoch 00200: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 775us/sample - loss: 0.0243 - accuracy: 0.9826 - val_loss: 0.1163 - val_accuracy: 0.9545
# Epoch 201/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0412 - accuracy: 0.9900
# Epoch 00201: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 737us/sample - loss: 0.0453 - accuracy: 0.9826 - val_loss: 0.0753 - val_accuracy: 0.9773
# Epoch 202/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0333 - accuracy: 0.9800
# Epoch 00202: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 731us/sample - loss: 0.0246 - accuracy: 0.9884 - val_loss: 0.0471 - val_accuracy: 0.9773
# Epoch 203/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0124 - accuracy: 1.0000
# Epoch 00203: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 809us/sample - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.0581 - val_accuracy: 0.9545
# Epoch 204/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0139 - accuracy: 0.9900
# Epoch 00204: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 758us/sample - loss: 0.0118 - accuracy: 0.9942 - val_loss: 0.0587 - val_accuracy: 0.9545
# Epoch 205/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0636 - accuracy: 0.9800
# Epoch 00205: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 723us/sample - loss: 0.0588 - accuracy: 0.9767 - val_loss: 0.1416 - val_accuracy: 0.9318
# Epoch 206/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0687 - accuracy: 0.9800
# Epoch 00206: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 703us/sample - loss: 0.0467 - accuracy: 0.9884 - val_loss: 0.0564 - val_accuracy: 0.9773
# Epoch 207/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0321 - accuracy: 0.9882
# Epoch 00207: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 780us/sample - loss: 0.0344 - accuracy: 0.9884 - val_loss: 0.0348 - val_accuracy: 1.0000
# Epoch 208/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0393 - accuracy: 0.9800
# Epoch 00208: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 748us/sample - loss: 0.0312 - accuracy: 0.9884 - val_loss: 0.2567 - val_accuracy: 0.9318
# Epoch 209/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0338 - accuracy: 0.9800
# Epoch 00209: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 718us/sample - loss: 0.0229 - accuracy: 0.9884 - val_loss: 0.1248 - val_accuracy: 0.9773
# Epoch 210/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0195 - accuracy: 0.9882
# Epoch 00210: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 771us/sample - loss: 0.0194 - accuracy: 0.9884 - val_loss: 0.0590 - val_accuracy: 0.9545
# Epoch 211/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0104 - accuracy: 1.0000
# Epoch 00211: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 759us/sample - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.0310 - val_accuracy: 1.0000
# Epoch 212/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 00212: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 693us/sample - loss: 0.0079 - accuracy: 0.9942 - val_loss: 0.0292 - val_accuracy: 1.0000
# Epoch 213/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 00213: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 758us/sample - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0324 - val_accuracy: 1.0000
# Epoch 214/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 00214: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 795us/sample - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9773
# Epoch 215/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0184 - accuracy: 0.9900
# Epoch 00215: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 817us/sample - loss: 0.0203 - accuracy: 0.9884 - val_loss: 0.1941 - val_accuracy: 0.9545
# Epoch 216/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0294 - accuracy: 0.9900
# Epoch 00216: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 776us/sample - loss: 0.0202 - accuracy: 0.9942 - val_loss: 0.0589 - val_accuracy: 0.9773
# Epoch 217/250
# 160/172 [==========================>...] - ETA: 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 00217: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 908us/sample - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1116 - val_accuracy: 0.9773
# Epoch 218/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0186 - accuracy: 0.9882
# Epoch 00218: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 854us/sample - loss: 0.0184 - accuracy: 0.9884 - val_loss: 0.1813 - val_accuracy: 0.9545
# Epoch 219/250
# 160/172 [==========================>...] - ETA: 0s - loss: 0.0190 - accuracy: 0.9937
# Epoch 00219: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 822us/sample - loss: 0.0178 - accuracy: 0.9942 - val_loss: 0.1067 - val_accuracy: 0.9773
# Epoch 220/250
# 160/172 [==========================>...] - ETA: 0s - loss: 0.0244 - accuracy: 0.9875
# Epoch 00220: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 818us/sample - loss: 0.0231 - accuracy: 0.9884 - val_loss: 0.0960 - val_accuracy: 0.9773
# Epoch 221/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0088 - accuracy: 1.0000
# Epoch 00221: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 758us/sample - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0780 - val_accuracy: 0.9773
# Epoch 222/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0187 - accuracy: 1.0000
# Epoch 00222: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 803us/sample - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.0667 - val_accuracy: 0.9773
# Epoch 223/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0058 - accuracy: 1.0000
# Epoch 00223: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 766us/sample - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.1147 - val_accuracy: 0.9318
# Epoch 224/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0138 - accuracy: 0.9900
# Epoch 00224: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 749us/sample - loss: 0.0235 - accuracy: 0.9884 - val_loss: 0.0496 - val_accuracy: 0.9773
# Epoch 225/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0164 - accuracy: 0.9941
# Epoch 00225: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 773us/sample - loss: 0.0163 - accuracy: 0.9942 - val_loss: 0.1117 - val_accuracy: 0.9545
# Epoch 226/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0090 - accuracy: 1.0000
# Epoch 00226: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 755us/sample - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.1746 - val_accuracy: 0.9773
# Epoch 227/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0162 - accuracy: 0.9941
# Epoch 00227: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 780us/sample - loss: 0.0161 - accuracy: 0.9942 - val_loss: 0.1404 - val_accuracy: 0.9773
# Epoch 228/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0149 - accuracy: 1.0000
# Epoch 00228: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 729us/sample - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.0539 - val_accuracy: 0.9773
# Epoch 229/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 00229: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 774us/sample - loss: 0.0102 - accuracy: 0.9942 - val_loss: 0.0955 - val_accuracy: 0.9773
# Epoch 230/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0220 - accuracy: 0.9900
# Epoch 00230: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 742us/sample - loss: 0.0161 - accuracy: 0.9942 - val_loss: 0.0313 - val_accuracy: 0.9773
# Epoch 231/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0078 - accuracy: 1.0000
# Epoch 00231: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 814us/sample - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 0.9773
# Epoch 232/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0715 - accuracy: 0.9800
# Epoch 00232: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 749us/sample - loss: 0.1084 - accuracy: 0.9651 - val_loss: 0.6029 - val_accuracy: 0.9091
# Epoch 233/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.1421 - accuracy: 0.9647
# Epoch 00233: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 796us/sample - loss: 0.1405 - accuracy: 0.9651 - val_loss: 0.1645 - val_accuracy: 0.9545
# Epoch 234/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0726 - accuracy: 0.9800
# Epoch 00234: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 720us/sample - loss: 0.0624 - accuracy: 0.9826 - val_loss: 0.1066 - val_accuracy: 0.9545
# Epoch 235/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.0299 - accuracy: 0.9889
# Epoch 00235: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 761us/sample - loss: 0.0322 - accuracy: 0.9884 - val_loss: 0.2252 - val_accuracy: 0.9545
# Epoch 236/250
#  90/172 [==============>...............] - ETA: 0s - loss: 0.0087 - accuracy: 1.0000
# Epoch 00236: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 773us/sample - loss: 0.0236 - accuracy: 0.9884 - val_loss: 0.0941 - val_accuracy: 0.9545
# Epoch 237/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0136 - accuracy: 1.0000
# Epoch 00237: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 751us/sample - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.0860 - val_accuracy: 0.9545
# Epoch 238/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0151 - accuracy: 0.9941
# Epoch 00238: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 783us/sample - loss: 0.0149 - accuracy: 0.9942 - val_loss: 0.0844 - val_accuracy: 0.9773
# Epoch 239/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0095 - accuracy: 1.0000
# Epoch 00239: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 758us/sample - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.0670 - val_accuracy: 0.9545
# Epoch 240/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 00240: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 746us/sample - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0650 - val_accuracy: 0.9773
# Epoch 241/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0214 - accuracy: 0.9800
# Epoch 00241: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 779us/sample - loss: 0.0385 - accuracy: 0.9826 - val_loss: 0.0723 - val_accuracy: 0.9545
# Epoch 242/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0342 - accuracy: 0.9800
# Epoch 00242: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 785us/sample - loss: 0.0364 - accuracy: 0.9767 - val_loss: 0.0583 - val_accuracy: 0.9545
# Epoch 243/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0288 - accuracy: 0.9900
# Epoch 00243: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 788us/sample - loss: 0.0172 - accuracy: 0.9942 - val_loss: 0.0534 - val_accuracy: 0.9773
# Epoch 244/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00244: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 714us/sample - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.0600 - val_accuracy: 0.9773
# Epoch 245/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0125 - accuracy: 0.9941
# Epoch 00245: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 758us/sample - loss: 0.0124 - accuracy: 0.9942 - val_loss: 0.1659 - val_accuracy: 0.9545
# Epoch 246/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0322 - accuracy: 0.9800
# Epoch 00246: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 766us/sample - loss: 0.0326 - accuracy: 0.9826 - val_loss: 0.0815 - val_accuracy: 0.9773
# Epoch 247/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 00247: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 741us/sample - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0761 - val_accuracy: 0.9545
# Epoch 248/250
# 170/172 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 00248: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 782us/sample - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0858 - val_accuracy: 0.9545
# Epoch 249/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0106 - accuracy: 0.9900
# Epoch 00249: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 729us/sample - loss: 0.0092 - accuracy: 0.9942 - val_loss: 0.0875 - val_accuracy: 0.9773
# Epoch 250/250
# 100/172 [================>.............] - ETA: 0s - loss: 0.0142 - accuracy: 0.9900
# Epoch 00250: val_accuracy did not improve from 1.00000
# 172/172 [==============================] - 0s 749us/sample - loss: 0.0134 - accuracy: 0.9942 - val_loss: 0.0946 - val_accuracy: 0.9773
# Training completed in time:  0:00:34.222583

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste
#
# Lembrando que estamos utilizando o mesmo conjunto de validacão, que a princípio, pode incluir instâncias do conjunto de treinamento: o dataset utilizado foi gerado com corte de áudio, então alguns trechos do mesmo áudio podem estar presentes em ambos os conjuntos de treinamento e teste.
# Por ora deixamos assim já que estamos realizando uma investigacão inicial.

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  1.0
# Testing Accuracy:  0.97727275

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       1.00      0.95      0.98        21
#    Pneumonia       0.96      1.00      0.98        23
#
#     accuracy                           0.98        44
#    macro avg       0.98      0.98      0.98        44
# weighted avg       0.98      0.98      0.98        44

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[20  1]
#  [ 0 23]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])
