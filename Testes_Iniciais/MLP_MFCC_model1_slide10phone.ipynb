# %% [markdown]
# # Rede MLP - Modelo 1
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - slide10phone

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP = 'slide10phone'
MAX_PAD_LEN = 431

# %%
filepaths = glob.glob(f'./datasets/{GROUP}/**/*.wav', recursive=True)
filenames = [os.path.splitext(os.path.basename(p))[0] for p in filepaths]

# %%
p_id_in_file = [] # patient IDs corresponding to each file
for name in filenames:
    p_id_in_file.append(int(name[:3]))

p_id_in_file = np.array(p_id_in_file)

# %%
max_pad_len =  MAX_PAD_LEN

os.makedirs("./Respiratory_Sound_Database/features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=10) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./Respiratory_Sound_Database/features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
p_diag = pd.read_csv("./Respiratory_Sound_Database/Respiratory_Sound_Database/patient_diagnosis.csv",header=None) # patient diagnosis file

# %%
labels = np.array([p_diag[p_diag[0] == x][1].values[0] for x in p_id_in_file]) # labels for audio files

# %%
features = [] 

# Iterate through each sound file and extract the features
for file_name in filepaths:
    data = extract_features(file_name)
    features.append(data)

print('Finished feature extraction from ', len(features), ' files')
features = np.array(features)
# Out:
# Finished feature extraction from  1152  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
features = np.array(features) # convert to numpy array

# %%
np.unique(labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
# delete diseases
'''
features1 = features
labels1 = labels'''

features1 = np.delete(features, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0) 

labels1 = np.delete(labels, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0)

# %%
# print class counts
unique_elements, counts_elements = np.unique(labels1, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['560' '592']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(labels1)
oh_labels = to_categorical(i_labels)

# %%
features1.shape
# Out:
# (1152, 40, 431)

# %%
input_dim = features1.shape[1]*features1.shape[2]
features1 = np.reshape(features1, (features1.shape[0], input_dim))
print(features1.shape, labels1.shape)
# Out:
# (1152, 17240) (1152,)

# %%
# train test split
x_train, x_test, y_train, y_test = train_test_split(features1, oh_labels, stratify=oh_labels, 
                                                    test_size=0.2, random_state = 42)

# %% [markdown]
# **MLP model architecture**

# %%
num_labels = oh_labels.shape[1]
# Construct model 
model = Sequential()
model.add(Dense(500, input_dim=input_dim, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 500)               8620500
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_2 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_3 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_4 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_5 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_6 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_7 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 1002
# =================================================================
# Total params: 10,375,002
# Trainable params: 10,375,002
# Non-trainable params: 0
# _________________________________________________________________
# 231/231 [==============================] - 0s 2ms/sample - loss: 2.7617 - accuracy: 0.4935
# Pre-training accuracy: 49.3506%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 250
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/model2_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 921 samples, validate on 231 samples
# Epoch 1/250
# 910/921 [============================>.] - ETA: 0s - loss: 7.2305 - accuracy: 0.6066
# Epoch 00001: val_accuracy improved from -inf to 0.61905, saving model to models/model2_01.h5
# 921/921 [==============================] - 2s 2ms/sample - loss: 7.1485 - accuracy: 0.6091 - val_loss: 0.7121 - val_accuracy: 0.6190
# Epoch 2/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.3690 - accuracy: 0.8424
# Epoch 00002: val_accuracy improved from 0.61905 to 0.73593, saving model to models/model2_02.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.3703 - accuracy: 0.8415 - val_loss: 0.7255 - val_accuracy: 0.7359
# Epoch 3/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.5104 - accuracy: 0.8080
# Epoch 00003: val_accuracy did not improve from 0.73593
# 921/921 [==============================] - 1s 935us/sample - loss: 0.5088 - accuracy: 0.8122 - val_loss: 1.2689 - val_accuracy: 0.6970
# Epoch 4/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.3656 - accuracy: 0.8622
# Epoch 00004: val_accuracy improved from 0.73593 to 0.91342, saving model to models/model2_04.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.3691 - accuracy: 0.8610 - val_loss: 0.2826 - val_accuracy: 0.9134
# Epoch 5/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.2429 - accuracy: 0.9247
# Epoch 00005: val_accuracy did not improve from 0.91342
# 921/921 [==============================] - 1s 896us/sample - loss: 0.2403 - accuracy: 0.9262 - val_loss: 0.5524 - val_accuracy: 0.8095
# Epoch 6/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.4661 - accuracy: 0.8607
# Epoch 00006: val_accuracy did not improve from 0.91342
# 921/921 [==============================] - 1s 912us/sample - loss: 0.4529 - accuracy: 0.8643 - val_loss: 0.2618 - val_accuracy: 0.8961
# Epoch 7/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.3256 - accuracy: 0.8828
# Epoch 00007: val_accuracy did not improve from 0.91342
# 921/921 [==============================] - 1s 903us/sample - loss: 0.3172 - accuracy: 0.8860 - val_loss: 0.6268 - val_accuracy: 0.7835
# Epoch 8/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.6141 - accuracy: 0.8484
# Epoch 00008: val_accuracy did not improve from 0.91342
# 921/921 [==============================] - 1s 881us/sample - loss: 0.6084 - accuracy: 0.8491 - val_loss: 0.6169 - val_accuracy: 0.7186
# Epoch 9/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.2649 - accuracy: 0.8886
# Epoch 00009: val_accuracy improved from 0.91342 to 0.93939, saving model to models/model2_09.h5
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.2580 - accuracy: 0.8925 - val_loss: 0.1455 - val_accuracy: 0.9394
# Epoch 10/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.2125 - accuracy: 0.9284
# Epoch 00010: val_accuracy did not improve from 0.93939
# 921/921 [==============================] - 1s 907us/sample - loss: 0.2241 - accuracy: 0.9218 - val_loss: 0.3282 - val_accuracy: 0.8658
# Epoch 11/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.3249 - accuracy: 0.8910
# Epoch 00011: val_accuracy did not improve from 0.93939
# 921/921 [==============================] - 1s 932us/sample - loss: 0.3236 - accuracy: 0.8903 - val_loss: 0.7212 - val_accuracy: 0.7662
# Epoch 12/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.2034 - accuracy: 0.9216
# Epoch 00012: val_accuracy did not improve from 0.93939
# 921/921 [==============================] - 1s 910us/sample - loss: 0.1986 - accuracy: 0.9229 - val_loss: 1.9228 - val_accuracy: 0.6234
# Epoch 13/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.9865 - accuracy: 0.6034
# Epoch 00013: val_accuracy did not improve from 0.93939
# 921/921 [==============================] - 1s 898us/sample - loss: 0.9648 - accuracy: 0.6113 - val_loss: 0.3158 - val_accuracy: 0.8745
# Epoch 14/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.3635 - accuracy: 0.8528
# Epoch 00014: val_accuracy did not improve from 0.93939
# 921/921 [==============================] - 1s 901us/sample - loss: 0.4039 - accuracy: 0.8426 - val_loss: 0.5240 - val_accuracy: 0.6104
# Epoch 15/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.2607 - accuracy: 0.8876
# Epoch 00015: val_accuracy did not improve from 0.93939
# 921/921 [==============================] - 1s 902us/sample - loss: 0.2657 - accuracy: 0.8860 - val_loss: 0.3689 - val_accuracy: 0.7879
# Epoch 16/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.3893 - accuracy: 0.8141
# Epoch 00016: val_accuracy did not improve from 0.93939
# 921/921 [==============================] - 1s 888us/sample - loss: 0.3889 - accuracy: 0.8143 - val_loss: 0.2290 - val_accuracy: 0.9221
# Epoch 17/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.1869 - accuracy: 0.9242
# Epoch 00017: val_accuracy did not improve from 0.93939
# 921/921 [==============================] - 1s 891us/sample - loss: 0.1854 - accuracy: 0.9251 - val_loss: 0.2807 - val_accuracy: 0.9134
# Epoch 18/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0922 - accuracy: 0.9733
# Epoch 00018: val_accuracy did not improve from 0.93939
# 921/921 [==============================] - 1s 945us/sample - loss: 0.1167 - accuracy: 0.9663 - val_loss: 0.0968 - val_accuracy: 0.9394
# Epoch 19/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.1415 - accuracy: 0.9511
# Epoch 00019: val_accuracy improved from 0.93939 to 0.96970, saving model to models/model2_19.h5
# 921/921 [==============================] - 2s 2ms/sample - loss: 0.1389 - accuracy: 0.9522 - val_loss: 0.0795 - val_accuracy: 0.9697
# Epoch 20/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0342 - accuracy: 0.9839
# Epoch 00020: val_accuracy improved from 0.96970 to 0.97403, saving model to models/model2_20.h5
# 921/921 [==============================] - 2s 2ms/sample - loss: 0.0341 - accuracy: 0.9837 - val_loss: 0.0906 - val_accuracy: 0.9740
# Epoch 21/250
# 860/921 [===========================>..] - ETA: 0s - loss: 0.1145 - accuracy: 0.9547
# Epoch 00021: val_accuracy did not improve from 0.97403
# 921/921 [==============================] - 1s 995us/sample - loss: 0.1076 - accuracy: 0.9577 - val_loss: 0.1139 - val_accuracy: 0.9654
# Epoch 22/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.1026 - accuracy: 0.9663
# Epoch 00022: val_accuracy did not improve from 0.97403
# 921/921 [==============================] - 1s 909us/sample - loss: 0.0998 - accuracy: 0.9674 - val_loss: 0.1511 - val_accuracy: 0.9394
# Epoch 23/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0603 - accuracy: 0.9813
# Epoch 00023: val_accuracy improved from 0.97403 to 0.97835, saving model to models/model2_23.h5
# 921/921 [==============================] - 2s 2ms/sample - loss: 0.0599 - accuracy: 0.9815 - val_loss: 0.0748 - val_accuracy: 0.9784
# Epoch 24/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0383 - accuracy: 0.9922
# Epoch 00024: val_accuracy did not improve from 0.97835
# 921/921 [==============================] - 1s 892us/sample - loss: 0.0380 - accuracy: 0.9924 - val_loss: 0.1094 - val_accuracy: 0.9654
# Epoch 25/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0285 - accuracy: 0.9910
# Epoch 00025: val_accuracy did not improve from 0.97835
# 921/921 [==============================] - 1s 866us/sample - loss: 0.0293 - accuracy: 0.9902 - val_loss: 0.2664 - val_accuracy: 0.9351
# Epoch 26/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.2649 - accuracy: 0.9402
# Epoch 00026: val_accuracy did not improve from 0.97835
# 921/921 [==============================] - 1s 908us/sample - loss: 0.2762 - accuracy: 0.9370 - val_loss: 0.3509 - val_accuracy: 0.8658
# Epoch 27/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.1212 - accuracy: 0.9593
# Epoch 00027: val_accuracy did not improve from 0.97835
# 921/921 [==============================] - 1s 934us/sample - loss: 0.1198 - accuracy: 0.9598 - val_loss: 0.2408 - val_accuracy: 0.9697
# Epoch 28/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.5655 - accuracy: 0.8880
# Epoch 00028: val_accuracy did not improve from 0.97835
# 921/921 [==============================] - 1s 878us/sample - loss: 0.5660 - accuracy: 0.8871 - val_loss: 0.6663 - val_accuracy: 0.5931
# Epoch 29/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.4679 - accuracy: 0.8154
# Epoch 00029: val_accuracy did not improve from 0.97835
# 921/921 [==============================] - 1s 859us/sample - loss: 0.4672 - accuracy: 0.8143 - val_loss: 0.7053 - val_accuracy: 0.7273
# Epoch 30/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.3728 - accuracy: 0.8527
# Epoch 00030: val_accuracy did not improve from 0.97835
# 921/921 [==============================] - 1s 861us/sample - loss: 0.3733 - accuracy: 0.8545 - val_loss: 0.4328 - val_accuracy: 0.9437
# Epoch 31/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.1052 - accuracy: 0.9736
# Epoch 00031: val_accuracy did not improve from 0.97835
# 921/921 [==============================] - 1s 906us/sample - loss: 0.1011 - accuracy: 0.9750 - val_loss: 0.1364 - val_accuracy: 0.9654
# Epoch 32/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0
val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 1ms/sample - loss: 9.0604e-10 - accuracy: 1.0000 - val_loss: 0.3385 - val_accuracy: 0.9784
# Epoch 82/250
# 860/921 [===========================>..] - ETA: 0s - loss: 9.7031e-10 - accuracy: 1.0000
# Epoch 00082: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 956us/sample - loss: 9.0604e-10 - accuracy: 1.0000 - val_loss: 0.3402 - val_accuracy: 0.9784
# Epoch 83/250
# 910/921 [============================>.] - ETA: 0s - loss: 9.1699e-10 - accuracy: 1.0000
# Epoch 00083: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 972us/sample - loss: 9.0604e-10 - accuracy: 1.0000 - val_loss: 0.3416 - val_accuracy: 0.9784
# Epoch 84/250
# 910/921 [============================>.] - ETA: 0s - loss: 9.1699e-10 - accuracy: 1.0000
# Epoch 00084: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 939us/sample - loss: 9.0604e-10 - accuracy: 1.0000 - val_loss: 0.3428 - val_accuracy: 0.9784
# Epoch 85/250
# 890/921 [===========================>..] - ETA: 0s - loss: 8.0366e-10 - accuracy: 1.0000
# Epoch 00085: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 957us/sample - loss: 7.7661e-10 - accuracy: 1.0000 - val_loss: 0.3442 - val_accuracy: 0.9784
# Epoch 86/250
# 910/921 [============================>.] - ETA: 0s - loss: 5.2400e-10 - accuracy: 1.0000
# Epoch 00086: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 935us/sample - loss: 5.1774e-10 - accuracy: 1.0000 - val_loss: 0.3453 - val_accuracy: 0.9784
# Epoch 87/250
# 900/921 [============================>.] - ETA: 0s - loss: 3.9736e-10 - accuracy: 1.0000
# Epoch 00087: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 944us/sample - loss: 3.8830e-10 - accuracy: 1.0000 - val_loss: 0.3463 - val_accuracy: 0.9784
# Epoch 88/250
# 880/921 [===========================>..] - ETA: 0s - loss: 4.0640e-10 - accuracy: 1.0000
# Epoch 00088: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 961us/sample - loss: 3.8830e-10 - accuracy: 1.0000 - val_loss: 0.3471 - val_accuracy: 0.9784
# Epoch 89/250
# 890/921 [===========================>..] - ETA: 0s - loss: 4.0183e-10 - accuracy: 1.0000
# Epoch 00089: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 957us/sample - loss: 3.8830e-10 - accuracy: 1.0000 - val_loss: 0.3483 - val_accuracy: 0.9784
# Epoch 90/250
# 910/921 [============================>.] - ETA: 0s - loss: 3.9300e-10 - accuracy: 1.0000
# Epoch 00090: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 953us/sample - loss: 3.8830e-10 - accuracy: 1.0000 - val_loss: 0.3492 - val_accuracy: 0.9784
# Epoch 91/250
# 880/921 [===========================>..] - ETA: 0s - loss: 4.0640e-10 - accuracy: 1.0000
# Epoch 00091: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 944us/sample - loss: 3.8830e-10 - accuracy: 1.0000 - val_loss: 0.3503 - val_accuracy: 0.9784
# Epoch 92/250
# 920/921 [============================>.] - ETA: 0s - loss: 3.8873e-10 - accuracy: 1.0000
# Epoch 00092: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 943us/sample - loss: 3.8830e-10 - accuracy: 1.0000 - val_loss: 0.3512 - val_accuracy: 0.9784
# Epoch 93/250
# 920/921 [============================>.] - ETA: 0s - loss: 3.8873e-10 - accuracy: 1.0000
# Epoch 00093: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 933us/sample - loss: 3.8830e-10 - accuracy: 1.0000 - val_loss: 0.3522 - val_accuracy: 0.9784
# Epoch 94/250
# 920/921 [============================>.] - ETA: 0s - loss: 2.5915e-10 - accuracy: 1.0000
# Epoch 00094: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 936us/sample - loss: 3.8830e-10 - accuracy: 1.0000 - val_loss: 0.3532 - val_accuracy: 0.9784
# Epoch 95/250
# 860/921 [===========================>..] - ETA: 0s - loss: 2.7723e-10 - accuracy: 1.0000
# Epoch 00095: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 926us/sample - loss: 3.8830e-10 - accuracy: 1.0000 - val_loss: 0.3558 - val_accuracy: 0.9784
# Epoch 96/250
# 900/921 [============================>.] - ETA: 0s - loss: 2.6491e-10 - accuracy: 1.0000
# Epoch 00096: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 942us/sample - loss: 2.5887e-10 - accuracy: 1.0000 - val_loss: 0.3568 - val_accuracy: 0.9784
# Epoch 97/250
# 920/921 [============================>.] - ETA: 0s - loss: 2.5915e-10 - accuracy: 1.0000
# Epoch 00097: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 965us/sample - loss: 2.5887e-10 - accuracy: 1.0000 - val_loss: 0.3576 - val_accuracy: 0.9784
# Epoch 98/250
# 900/921 [============================>.] - ETA: 0s - loss: 2.6491e-10 - accuracy: 1.0000
# Epoch 00098: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 949us/sample - loss: 2.5887e-10 - accuracy: 1.0000 - val_loss: 0.3585 - val_accuracy: 0.9784
# Epoch 99/250
# 870/921 [===========================>..] - ETA: 0s - loss: 1.3702e-10 - accuracy: 1.0000
# Epoch 00099: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 962us/sample - loss: 1.2943e-10 - accuracy: 1.0000 - val_loss: 0.3592 - val_accuracy: 0.9784
# Epoch 100/250
# 920/921 [============================>.] - ETA: 0s - loss: 1.2958e-10 - accuracy: 1.0000
# Epoch 00100: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 942us/sample - loss: 1.2943e-10 - accuracy: 1.0000 - val_loss: 0.3599 - val_accuracy: 0.9784
# Epoch 101/250
# 880/921 [===========================>..] - ETA: 0s - loss: 1.3547e-10 - accuracy: 1.0000
# Epoch 00101: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 955us/sample - loss: 1.2943e-10 - accuracy: 1.0000 - val_loss: 0.3605 - val_accuracy: 0.9784
# Epoch 102/250
# 910/921 [============================>.] - ETA: 0s - loss: 1.3100e-10 - accuracy: 1.0000
# Epoch 00102: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 1ms/sample - loss: 1.2943e-10 - accuracy: 1.0000 - val_loss: 0.3612 - val_accuracy: 0.9784
# Epoch 103/250
# 890/921 [===========================>..] - ETA: 0s - loss: 1.3394e-10 - accuracy: 1.0000
# Epoch 00103: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 940us/sample - loss: 1.2943e-10 - accuracy: 1.0000 - val_loss: 0.3619 - val_accuracy: 0.9784
# Epoch 104/250
# 920/921 [============================>.] - ETA: 0s - loss: 1.2958e-10 - accuracy: 1.0000
# Epoch 00104: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 950us/sample - loss: 1.2943e-10 - accuracy: 1.0000 - val_loss: 0.3626 - val_accuracy: 0.9784
# Epoch 105/250
# 920/921 [============================>.] - ETA: 0s - loss: 1.2958e-10 - accuracy: 1.0000
# Epoch 00105: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 928us/sample - loss: 1.2943e-10 - accuracy: 1.0000 - val_loss: 0.3633 - val_accuracy: 0.9784
# Epoch 106/250
# 870/921 [===========================>..] - ETA: 0s - loss: 1.3702e-10 - accuracy: 1.0000
# Epoch 00106: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 900us/sample - loss: 1.2943e-10 - accuracy: 1.0000 - val_loss: 0.3641 - val_accuracy: 0.9784
# Epoch 107/250
# 910/921 [============================>.] - ETA: 0s - loss: 1.3100e-10 - accuracy: 1.0000
# Epoch 00107: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 879us/sample - loss: 1.2943e-10 - accuracy: 1.0000 - val_loss: 0.3647 - val_accuracy: 0.9784
# Epoch 108/250
# 870/921 [===========================>..] - ETA: 0s - loss: 1.3702e-10 - accuracy: 1.0000
# Epoch 00108: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 914us/sample - loss: 1.2943e-10 - accuracy: 1.0000 - val_loss: 0.3655 - val_accuracy: 0.9784
# Epoch 109/250
# 870/921 [===========================>..] - ETA: 0s - loss: 1.3702e-10 - accuracy: 1.0000
# Epoch 00109: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 926us/sample - loss: 1.2943e-10 - accuracy: 1.0000 - val_loss: 0.3662 - val_accuracy: 0.9784
# Epoch 110/250
# 900/921 [============================>.] - ETA: 0s - loss: 1.3245e-10 - accuracy: 1.0000
# Epoch 00110: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 948us/sample - loss: 1.2943e-10 - accuracy: 1.0000 - val_loss: 0.3667 - val_accuracy: 0.9784
# Epoch 111/250
# 900/921 [============================>.] - ETA: 0s - loss: 1.3245e-10 - accuracy: 1.0000
# Epoch 00111: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 939us/sample - loss: 1.2943e-10 - accuracy: 1.0000 - val_loss: 0.3676 - val_accuracy: 0.9784
# Epoch 112/250
# 890/921 [===========================>..] - ETA: 0s - loss: 1.3394e-10 - accuracy: 1.0000
# Epoch 00112: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 951us/sample - loss: 1.2943e-10 - accuracy: 1.0000 - val_loss: 0.3683 - val_accuracy: 0.9784
# Epoch 113/250
# 900/921 [============================>.] - ETA: 0s - loss: 1.3245e-10 - accuracy: 1.0000
# Epoch 00113: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 947us/sample - loss: 1.2943e-10 - accuracy: 1.0000 - val_loss: 0.3689 - val_accuracy: 0.9784
# Epoch 114/250
# 910/921 [============================>.] - ETA: 0s - loss: 1.3100e-10 - accuracy: 1.0000
# Epoch 00114: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 953us/sample - loss: 1.2943e-10 - accuracy: 1.0000 - val_loss: 0.3697 - val_accuracy: 0.9784
# Epoch 115/250
# 890/921 [===========================>..] - ETA: 0s - loss: 1.3394e-10 - accuracy: 1.0000
# Epoch 00115: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 956us/sample - loss: 1.2943e-10 - accuracy: 1.0000 - val_loss: 0.3704 - val_accuracy: 0.9784
# Epoch 116/250
# 920/921 [============================>.] - ETA: 0s - loss: 1.2958e-10 - accuracy: 1.0000
# Epoch 00116: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 937us/sample - loss: 1.2943e-10 - accuracy: 1.0000 - val_loss: 0.3711 - val_accuracy: 0.9784
# Epoch 117/250
# 890/921 [===========================>..] - ETA: 0s - loss: 1.3394e-10 - accuracy: 1.0000
# Epoch 00117: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 947us/sample - loss: 1.2943e-10 - accuracy: 1.0000 - val_loss: 0.3717 - val_accuracy: 0.9784
# Epoch 118/250
# 870/921 [===========================>..] - ETA: 0s - loss: 1.3702e-10 - accuracy: 1.0000
# Epoch 00118: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 957us/sample - loss: 1.2943e-10 - accuracy: 1.0000 - val_loss: 0.3726 - val_accuracy: 0.9784
# Epoch 119/250
# 880/921 [===========================>..] - ETA: 0s - loss: 1.3547e-10 - accuracy: 1.0000
# Epoch 00119: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 951us/sample - loss: 1.2943e-10 - accuracy: 1.0000 - val_loss: 0.3733 - val_accuracy: 0.9784
# Epoch 120/250
# 910/921 [============================>.] - ETA: 0s - loss: 1.3100e-10 - accuracy: 1.0000
# Epoch 00120: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 976us/sample - loss: 1.2943e-10 - accuracy: 1.0000 - val_loss: 0.3739 - val_accuracy: 0.9784
# Epoch 121/250
# 890/921 [===========================>..] - ETA: 0s - loss: 1.3394e-10 - accuracy: 1.0000
# Epoch 00121: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 969us/sample - loss: 1.2943e-10 - accuracy: 1.0000 - val_loss: 0.3746 - val_accuracy: 0.9784
# Epoch 122/250
# 910/921 [============================>.] - ETA: 0s - loss: 1.3100e-10 - accuracy: 1.0000
# Epoch 00122: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 949us/sample - loss: 1.2943e-10 - accuracy: 1.0000 - val_loss: 0.3751 - val_accuracy: 0.9784
# Epoch 123/250
# 870/921 [===========================>..] - ETA: 0s - loss: 1.3702e-10 - accuracy: 1.0000
# Epoch 00123: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 968us/sample - loss: 1.2943e-10 - accuracy: 1.0000 - val_loss: 0.3761 - val_accuracy: 0.9784
# Epoch 124/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00124: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 961us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3765 - val_accuracy: 0.9784
# Epoch 125/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00125: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 951us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3771 - val_accuracy: 0.9784
# Epoch 126/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00126: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 949us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3776 - val_accuracy: 0.9784
# Epoch 127/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00127: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 955us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3780 - val_accuracy: 0.9784
# Epoch 128/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00128: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 967us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3786 - val_accuracy: 0.9784
# Epoch 129/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00129: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 952us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3791 - val_accuracy: 0.9784
# Epoch 130/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00130: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 955us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3795 - val_accuracy: 0.9784
# Epoch 131/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00131: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 957us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3801 - val_accuracy: 0.9784
# Epoch 132/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00132: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 947us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3805 - val_accuracy: 0.9784
# Epoch 133/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00133: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 949us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3810 - val_accuracy: 0.9784
# Epoch 134/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00134: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 948us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3815 - val_accuracy: 0.9784
# Epoch 135/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00135: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 962us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3821 - val_accuracy: 0.9784
# Epoch 136/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00136: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 959us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3826 - val_accuracy: 0.9784
# Epoch 137/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00137: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 948us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3831 - val_accuracy: 0.9784
# Epoch 138/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00138: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 950us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3835 - val_accuracy: 0.9784
# Epoch 139/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00139: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 949us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3841 - val_accuracy: 0.9784
# Epoch 140/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00140: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 943us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3846 - val_accuracy: 0.9784
# Epoch 141/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00141: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 945us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3851 - val_accuracy: 0.9784
# Epoch 142/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00142: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 948us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3856 - val_accuracy: 0.9784
# Epoch 143/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00143: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 954us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3861 - val_accuracy: 0.9784
# Epoch 144/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00144: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 952us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3866 - val_accuracy: 0.9784
# Epoch 145/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00145: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 953us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3871 - val_accuracy: 0.9784
# Epoch 146/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00146: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 947us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3875 - val_accuracy: 0.9784
# Epoch 147/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00147: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 944us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3880 - val_accuracy: 0.9784
# Epoch 148/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00148: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 968us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3885 - val_accuracy: 0.9784
# Epoch 149/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00149: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 979us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3890 - val_accuracy: 0.9784
# Epoch 150/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00150: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 988us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3895 - val_accuracy: 0.9784
# Epoch 151/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00151: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 916us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3900 - val_accuracy: 0.9784
# Epoch 152/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00152: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 915us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3904 - val_accuracy: 0.9784
# Epoch 153/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00153: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 918us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3909 - val_accuracy: 0.9784
# Epoch 154/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00154: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 917us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3915 - val_accuracy: 0.9784
# Epoch 155/250
# 860/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00155: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 929us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3919 - val_accuracy: 0.9784
# Epoch 156/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00156: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 939us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3924 - val_accuracy: 0.9784
# Epoch 157/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00157: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 919us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3929 - val_accuracy: 0.9784
# Epoch 158/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00158: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 927us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3934 - val_accuracy: 0.9784
# Epoch 159/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00159: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 926us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3939 - val_accuracy: 0.9784
# Epoch 160/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00160: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 912us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3944 - val_accuracy: 0.9784
# Epoch 161/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00161: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 800us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3947 - val_accuracy: 0.9784
# Epoch 162/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00162: val_accuracy did not improve from 0.98268
# ...
# Epoch 00197: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 951us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4109 - val_accuracy: 0.9784
# Epoch 198/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00198: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 974us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4113 - val_accuracy: 0.9784
# Epoch 199/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00199: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 977us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4117 - val_accuracy: 0.9784
# Epoch 200/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00200: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 958us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4121 - val_accuracy: 0.9784
# Epoch 201/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00201: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 993us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4124 - val_accuracy: 0.9784
# Epoch 202/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00202: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 975us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4130 - val_accuracy: 0.9784
# Epoch 203/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00203: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 976us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4134 - val_accuracy: 0.9784
# Epoch 204/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00204: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 952us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4138 - val_accuracy: 0.9784
# Epoch 205/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00205: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 951us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4142 - val_accuracy: 0.9784
# Epoch 206/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00206: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 936us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4146 - val_accuracy: 0.9784
# Epoch 207/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00207: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 961us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4150 - val_accuracy: 0.9784
# Epoch 208/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00208: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 948us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4154 - val_accuracy: 0.9784
# Epoch 209/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00209: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 969us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4158 - val_accuracy: 0.9784
# Epoch 210/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00210: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 960us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4161 - val_accuracy: 0.9784
# Epoch 211/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00211: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 974us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4166 - val_accuracy: 0.9784
# Epoch 212/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00212: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 964us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4170 - val_accuracy: 0.9784
# Epoch 213/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00213: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 946us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4173 - val_accuracy: 0.9784
# Epoch 214/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00214: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 933us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4178 - val_accuracy: 0.9784
# Epoch 215/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00215: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 938us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4182 - val_accuracy: 0.9784
# Epoch 216/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00216: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 948us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4186 - val_accuracy: 0.9784
# Epoch 217/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00217: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 946us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4190 - val_accuracy: 0.9784
# Epoch 218/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00218: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 955us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4193 - val_accuracy: 0.9784
# Epoch 219/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00219: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 974us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4198 - val_accuracy: 0.9784
# Epoch 220/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00220: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 964us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4201 - val_accuracy: 0.9784
# Epoch 221/250
# 900/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00221: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 937us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4205 - val_accuracy: 0.9784
# Epoch 222/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00222: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 961us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4209 - val_accuracy: 0.9784
# Epoch 223/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00223: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 936us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4213 - val_accuracy: 0.9784
# Epoch 224/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00224: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 957us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4217 - val_accuracy: 0.9784
# Epoch 225/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00225: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 951us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4220 - val_accuracy: 0.9784
# Epoch 226/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00226: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 985us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4224 - val_accuracy: 0.9784
# Epoch 227/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00227: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 970us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4229 - val_accuracy: 0.9784
# Epoch 228/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00228: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 987us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4232 - val_accuracy: 0.9784
# Epoch 229/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00229: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 950us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4236 - val_accuracy: 0.9784
# Epoch 230/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00230: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 946us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4239 - val_accuracy: 0.9784
# Epoch 231/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00231: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 1ms/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4244 - val_accuracy: 0.9784
# Epoch 232/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00232: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 927us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4247 - val_accuracy: 0.9784
# Epoch 233/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00233: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 989us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4250 - val_accuracy: 0.9784
# Epoch 234/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00234: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 978us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4255 - val_accuracy: 0.9784
# Epoch 235/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00235: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 944us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4259 - val_accuracy: 0.9784
# Epoch 236/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00236: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 930us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4262 - val_accuracy: 0.9784
# Epoch 237/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00237: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 920us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4266 - val_accuracy: 0.9784
# Epoch 238/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00238: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 938us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4269 - val_accuracy: 0.9784
# Epoch 239/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00239: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 946us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4273 - val_accuracy: 0.9784
# Epoch 240/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00240: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 950us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4277 - val_accuracy: 0.9784
# Epoch 241/250
# 860/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00241: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 928us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4281 - val_accuracy: 0.9784
# Epoch 242/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00242: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 923us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4284 - val_accuracy: 0.9784
# Epoch 243/250
# 910/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00243: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 903us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4288 - val_accuracy: 0.9784
# Epoch 244/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00244: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 910us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4291 - val_accuracy: 0.9784
# Epoch 245/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00245: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 959us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4295 - val_accuracy: 0.9784
# Epoch 246/250
# 860/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00246: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 943us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4303 - val_accuracy: 0.9784
# Epoch 247/250
# 880/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00247: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 923us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4307 - val_accuracy: 0.9784
# Epoch 248/250
# 890/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00248: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 949us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4310 - val_accuracy: 0.9784
# Epoch 249/250
# 870/921 [===========================>..] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00249: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 929us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4314 - val_accuracy: 0.9784
# Epoch 250/250
# 920/921 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 00250: val_accuracy did not improve from 0.98268
# 921/921 [==============================] - 1s 902us/sample - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4317 - val_accuracy: 0.9784
# Training completed in time:  0:03:38.886522

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste
#
# Lembrando que estamos utilizando o mesmo conjunto de validacão, que a princípio, pode incluir instâncias do conjunto de treinamento: o dataset utilizado foi gerado com corte de áudio, então alguns trechos do mesmo áudio podem estar presentes em ambos os conjuntos de treinamento e teste.
# Por ora deixamos assim já que estamos realizando uma investigacão inicial.

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  1.0
# Testing Accuracy:  0.978355

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.98      0.97      0.98       112
#    Pneumonia       0.97      0.98      0.98       119
#
#     accuracy                           0.98       231
#    macro avg       0.98      0.98      0.98       231
# weighted avg       0.98      0.98      0.98       231

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[109   3]
#  [  2 117]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])
