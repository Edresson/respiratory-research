# %% [markdown]
# # Rede MLP - Modelo 1
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - slide10

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP = 'slide10'
MAX_PAD_LEN = 431

# %%
filepaths = glob.glob(f'./datasets/{GROUP}/**/*.wav', recursive=True)
filenames = [os.path.splitext(os.path.basename(p))[0] for p in filepaths]

# %%
p_id_in_file = [] # patient IDs corresponding to each file
for name in filenames:
    p_id_in_file.append(int(name[:3]))

p_id_in_file = np.array(p_id_in_file)

# %%
max_pad_len =  MAX_PAD_LEN

os.makedirs("./Respiratory_Sound_Database/features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
    if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
        return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=10) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./Respiratory_Sound_Database/features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
p_diag = pd.read_csv("./Respiratory_Sound_Database/Respiratory_Sound_Database/patient_diagnosis.csv",header=None) # patient diagnosis file

# %%
labels = np.array([p_diag[p_diag[0] == x][1].values[0] for x in p_id_in_file]) # labels for audio files

# %%
features = [] 

# Iterate through each sound file and extract the features
for file_name in filepaths:
    data = extract_features(file_name)
    features.append(data)

print('Finished feature extraction from ', len(features), ' files')
features = np.array(features)
# Out:
# Finished feature extraction from  576  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
features = np.array(features) # convert to numpy array

# %%
np.unique(labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
# delete diseases
'''
features1 = features
labels1 = labels'''

features1 = np.delete(features, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0) 

labels1 = np.delete(labels, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0)

# %%
# print class counts
unique_elements, counts_elements = np.unique(labels1, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['280' '296']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(labels1)
oh_labels = to_categorical(i_labels)

# %%
features1.shape
# Out:
# (576, 40, 431)

# %%
input_dim = features1.shape[1]*features1.shape[2]
features1 = np.reshape(features1, (features1.shape[0], input_dim))
print(features1.shape, labels1.shape)
# Out:
# (576, 17240) (576,)

# %%
# train test split
x_train, x_test, y_train, y_test = train_test_split(features1, oh_labels, stratify=oh_labels, 
                                                    test_size=0.2, random_state = 42)

# %% [markdown]
# **MLP model architecture**

# %%
num_labels = oh_labels.shape[1]
# Construct model 
model = Sequential()
model.add(Dense(500, input_dim=input_dim, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 500)               8620500
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_2 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_3 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_4 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_5 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_6 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_7 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 1002
# =================================================================
# Total params: 10,375,002
# Trainable params: 10,375,002
# Non-trainable params: 0
# _________________________________________________________________
# 116/116 [==============================] - 0s 3ms/sample - loss: 11.0607 - accuracy: 0.4828
# Pre-training accuracy: 48.2759%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 250
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/model2_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 460 samples, validate on 116 samples
# Epoch 1/250
# 440/460 [===========================>..] - ETA: 0s - loss: 14.7163 - accuracy: 0.5023
# Epoch 00001: val_accuracy improved from -inf to 0.46552, saving model to models/model2_01.h5
# 460/460 [==============================] - 1s 2ms/sample - loss: 14.1068 - accuracy: 0.5087 - val_loss: 0.7202 - val_accuracy: 0.4655
# Epoch 2/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.8605 - accuracy: 0.5053
# Epoch 00002: val_accuracy improved from 0.46552 to 0.68103, saving model to models/model2_02.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.8450 - accuracy: 0.5065 - val_loss: 0.5567 - val_accuracy: 0.6810
# Epoch 3/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.7480 - accuracy: 0.6525
# Epoch 00003: val_accuracy did not improve from 0.68103
# 460/460 [==============================] - 0s 772us/sample - loss: 0.7497 - accuracy: 0.6630 - val_loss: 0.5688 - val_accuracy: 0.6466
# Epoch 4/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.4900 - accuracy: 0.7651
# Epoch 00004: val_accuracy improved from 0.68103 to 0.75000, saving model to models/model2_04.h5
# 460/460 [==============================] - 1s 2ms/sample - loss: 0.4935 - accuracy: 0.7652 - val_loss: 0.4111 - val_accuracy: 0.7500
# Epoch 5/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.4586 - accuracy: 0.7822
# Epoch 00005: val_accuracy improved from 0.75000 to 0.78448, saving model to models/model2_05.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.4611 - accuracy: 0.7783 - val_loss: 0.4338 - val_accuracy: 0.7845
# Epoch 6/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.3258 - accuracy: 0.8641
# Epoch 00006: val_accuracy improved from 0.78448 to 0.82759, saving model to models/model2_06.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.3531 - accuracy: 0.8674 - val_loss: 0.3696 - val_accuracy: 0.8276
# Epoch 7/250
# 390/460 [========================>.....] - ETA: 0s - loss: 0.4064 - accuracy: 0.8051
# Epoch 00007: val_accuracy improved from 0.82759 to 0.91379, saving model to models/model2_07.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.3882 - accuracy: 0.8130 - val_loss: 0.2403 - val_accuracy: 0.9138
# Epoch 8/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.3876 - accuracy: 0.8400
# Epoch 00008: val_accuracy improved from 0.91379 to 0.92241, saving model to models/model2_08.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.3816 - accuracy: 0.8435 - val_loss: 0.2139 - val_accuracy: 0.9224
# Epoch 9/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.3377 - accuracy: 0.8658
# Epoch 00009: val_accuracy improved from 0.92241 to 0.93103, saving model to models/model2_09.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.3226 - accuracy: 0.8717 - val_loss: 0.2045 - val_accuracy: 0.9310
# Epoch 10/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.1392 - accuracy: 0.9421
# Epoch 00010: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 804us/sample - loss: 0.1392 - accuracy: 0.9478 - val_loss: 0.9038 - val_accuracy: 0.8103
# Epoch 11/250
# 400/460 [=========================>....] - ETA: 0s - loss: 0.4548 - accuracy: 0.7700
# Epoch 00011: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s 770us/sample - loss: 0.4546 - accuracy: 0.7696 - val_loss: 0.6207 - val_accuracy: 0.5603
# Epoch 12/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.5656 - accuracy: 0.6089
# Epoch 00012: val_accuracy did not improve from 0.93103
# 460/460 [==============================] - 0s
250
# 450/460 [============================>.] - ETA: 0s - loss: 0.2012 - accuracy: 0.9467
# Epoch 00061: val_accuracy improved from 0.93103 to 0.93966, saving model to models/model2_61.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.1990 - accuracy: 0.9478 - val_loss: 0.1817 - val_accuracy: 0.9397
# Epoch 62/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.1226 - accuracy: 0.9545
# Epoch 00062: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 0s 850us/sample - loss: 0.1374 - accuracy: 0.9478 - val_loss: 0.4301 - val_accuracy: 0.8621
# Epoch 63/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.2065 - accuracy: 0.9116
# Epoch 00063: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 0s 857us/sample - loss: 0.1939 - accuracy: 0.9174 - val_loss: 0.1388 - val_accuracy: 0.9310
# Epoch 64/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.2851 - accuracy: 0.9070
# Epoch 00064: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 0s 875us/sample - loss: 0.2831 - accuracy: 0.9087 - val_loss: 0.2205 - val_accuracy: 0.9310
# Epoch 65/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0.3051 - accuracy: 0.9409
# Epoch 00065: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 0s 823us/sample - loss: 0.3068 - accuracy: 0.9370 - val_loss: 0.6291 - val_accuracy: 0.5172
# Epoch 66/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.3310 - accuracy: 0.8116
# Epoch 00066: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 0s 806us/sample - loss: 0.3805 - accuracy: 0.8130 - val_loss: 1.1170 - val_accuracy: 0.7414
# Epoch 67/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.6041 - accuracy: 0.6711
# Epoch 00067: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 0s 784us/sample - loss: 0.6169 - accuracy: 0.6457 - val_loss: 0.6540 - val_accuracy: 0.5690
# Epoch 68/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.6283 - accuracy: 0.5690
# Epoch 00068: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 0s 827us/sample - loss: 0.6252 - accuracy: 0.5804 - val_loss: 0.5347 - val_accuracy: 0.7069
# Epoch 69/250
# 450/460 [============================>.] - ETA: 0s - loss: 0.5676 - accuracy: 0.6978
# Epoch 00069: val_accuracy did not improve from 0.93966
# 460/460 [==============================] - 0s 791us/sample - loss: 0.5595 - accuracy: 0.7043 - val_loss: 0.3976 - val_accuracy: 0.9397
# Epoch 70/250
# 380/460 [=======================>......] - ETA: 0s - loss: 0.2212 - accuracy: 0.9868
# Epoch 00070: val_accuracy improved from 0.93966 to 0.95690, saving model to models/model2_70.h5
# 460/460 [==============================] - 1s 1ms/sample - loss: 0.2066 - accuracy: 0.9870 - val_loss: 0.3299 - val_accuracy: 0.9569
# Epoch 71/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0817 - accuracy: 0.9907
# Epoch 00071: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 868us/sample - loss: 0.0803 - accuracy: 0.9891 - val_loss: 0.3436 - val_accuracy: 0.9138
# Epoch 72/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.6904 - accuracy: 0.8047
# Epoch 00072: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 865us/sample - loss: 0.6634 - accuracy: 0.8109 - val_loss: 0.3053 - val_accuracy: 0.8879
# Epoch 73/250
# 420/460 [==========================>...] - ETA: 0s - loss: 0.2186 - accuracy: 0.9405
# Epoch 00073: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 857us/sample - loss: 0.2114 - accuracy: 0.9435 - val_loss: 0.1973 - val_accuracy: 0.9483
# Epoch 74/250
# 430/460 [===========================>..] - ETA: 0s - loss: 0.0408 - accuracy: 1.0000
# Epoch 00074: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 829us/sample - loss: 0.0388 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9483
# Epoch 75/250
# 440/460 [===========================>..] - ETA: 0s - loss: 0
val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 878us/sample - loss: 1.8141e-09 - accuracy: 1.0000 - val_loss: 0.6361 - val_accuracy: 0.9483
# Epoch 199/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.6634e-09 - accuracy: 1.0000
# Epoch 00199: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 858us/sample - loss: 1.5549e-09 - accuracy: 1.0000 - val_loss: 0.6371 - val_accuracy: 0.9483
# Epoch 200/250
# 440/460 [===========================>..] - ETA: 0s - loss: 1.6256e-09 - accuracy: 1.0000
# Epoch 00200: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 824us/sample - loss: 1.5549e-09 - accuracy: 1.0000 - val_loss: 0.6378 - val_accuracy: 0.9483
# Epoch 201/250
# 440/460 [===========================>..] - ETA: 0s - loss: 1.3547e-09 - accuracy: 1.0000
# Epoch 00201: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 815us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.6387 - val_accuracy: 0.9483
# Epoch 202/250
# 440/460 [===========================>..] - ETA: 0s - loss: 1.3547e-09 - accuracy: 1.0000
# Epoch 00202: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 821us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.6394 - val_accuracy: 0.9483
# Epoch 203/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.3862e-09 - accuracy: 1.0000
# Epoch 00203: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 816us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.6403 - val_accuracy: 0.9483
# Epoch 204/250
# 420/460 [==========================>...] - ETA: 0s - loss: 1.4192e-09 - accuracy: 1.0000
# Epoch 00204: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 893us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.6412 - val_accuracy: 0.9483
# Epoch 205/250
# 410/460 [=========================>....] - ETA: 0s - loss: 2.9075e-10 - accuracy: 1.0000
# Epoch 00205: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 881us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.6415 - val_accuracy: 0.9483
# Epoch 206/250
# 440/460 [===========================>..] - ETA: 0s - loss: 1.3547e-09 - accuracy: 1.0000
# Epoch 00206: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 832us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.6425 - val_accuracy: 0.9483
# Epoch 207/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.3862e-09 - accuracy: 1.0000
# Epoch 00207: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 825us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.6436 - val_accuracy: 0.9483
# Epoch 208/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.3862e-09 - accuracy: 1.0000
# Epoch 00208: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 853us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.6444 - val_accuracy: 0.9483
# Epoch 209/250
# 440/460 [===========================>..] - ETA: 0s - loss: 1.3547e-09 - accuracy: 1.0000
# Epoch 00209: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 835us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.6452 - val_accuracy: 0.9483
# Epoch 210/250
# 390/460 [========================>.....] - ETA: 0s - loss: 1.5283e-09 - accuracy: 1.0000
# Epoch 00210: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 789us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.6459 - val_accuracy: 0.9483
# Epoch 211/250
# 380/460 [=======================>......] - ETA: 0s - loss: 1.2548e-09 - accuracy: 1.0000
# Epoch 00211: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 784us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.6468 - val_accuracy: 0.9483
# Epoch 212/250
# 380/460 [=======================>......] - ETA: 0s - loss: 3.1371e-10 - accuracy: 1.0000
# Epoch 00212: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 811us/sample - loss: 1.2958e-09 - accuracy: 1.0000 - val_loss: 0.6473 - val_accuracy: 0.9483
# Epoch 213/250
# 420/460 [==========================>...] - ETA: 0s - loss: 1.1353e-09 - accuracy: 1.0000
# Epoch 00213: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 894us/sample - loss: 1.0366e-09 - accuracy: 1.0000 - val_loss: 0.6486 - val_accuracy: 0.9483
# Epoch 214/250
# 440/460 [===========================>..] - ETA: 0s - loss: 1.0837e-09 - accuracy: 1.0000
# Epoch 00214: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 845us/sample - loss: 1.0366e-09 - accuracy: 1.0000 - val_loss: 0.6493 - val_accuracy: 0.9483
# Epoch 215/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.1089e-09 - accuracy: 1.0000
# Epoch 00215: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 827us/sample - loss: 1.0366e-09 - accuracy: 1.0000 - val_loss: 0.6499 - val_accuracy: 0.9483
# Epoch 216/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.1089e-09 - accuracy: 1.0000
# Epoch 00216: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 915us/sample - loss: 1.0366e-09 - accuracy: 1.0000 - val_loss: 0.6509 - val_accuracy: 0.9483
# Epoch 217/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.1089e-09 - accuracy: 1.0000
# Epoch 00217: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 838us/sample - loss: 1.0366e-09 - accuracy: 1.0000 - val_loss: 0.6517 - val_accuracy: 0.9483
# Epoch 218/250
# 390/460 [========================>.....] - ETA: 0s - loss: 9.1699e-10 - accuracy: 1.0000
# Epoch 00218: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 775us/sample - loss: 1.0366e-09 - accuracy: 1.0000 - val_loss: 0.6524 - val_accuracy: 0.9483
# Epoch 219/250
# 390/460 [========================>.....] - ETA: 0s - loss: 1.2227e-09 - accuracy: 1.0000
# Epoch 00219: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 771us/sample - loss: 1.0366e-09 - accuracy: 1.0000 - val_loss: 0.6532 - val_accuracy: 0.9483
# Epoch 220/250
# 420/460 [==========================>...] - ETA: 0s - loss: 1.1353e-09 - accuracy: 1.0000
# Epoch 00220: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 871us/sample - loss: 1.0366e-09 - accuracy: 1.0000 - val_loss: 0.6541 - val_accuracy: 0.9483
# Epoch 221/250
# 380/460 [=======================>......] - ETA: 0s - loss: 1.2548e-09 - accuracy: 1.0000
# Epoch 00221: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 782us/sample - loss: 1.0366e-09 - accuracy: 1.0000 - val_loss: 0.6550 - val_accuracy: 0.9483
# Epoch 222/250
# 390/460 [========================>.....] - ETA: 0s - loss: 9.1699e-10 - accuracy: 1.0000
# Epoch 00222: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 770us/sample - loss: 1.0366e-09 - accuracy: 1.0000 - val_loss: 0.6557 - val_accuracy: 0.9483
# Epoch 223/250
# 450/460 [============================>.] - ETA: 0s - loss: 1.0596e-09 - accuracy: 1.0000
# Epoch 00223: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 801us/sample - loss: 1.0366e-09 - accuracy: 1.0000 - val_loss: 0.6565 - val_accuracy: 0.9483
# Epoch 224/250
# 380/460 [=======================>......] - ETA: 0s - loss: 1.2548e-09 - accuracy: 1.0000
# Epoch 00224: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 790us/sample - loss: 1.0366e-09 - accuracy: 1.0000 - val_loss: 0.6574 - val_accuracy: 0.9483
# Epoch 225/250
# 380/460 [=======================>......] - ETA: 0s - loss: 1.2548e-09 - accuracy: 1.0000
# Epoch 00225: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 796us/sample - loss: 1.0366e-09 - accuracy: 1.0000 - val_loss: 0.6583 - val_accuracy: 0.9483
# Epoch 226/250
# 430/460 [===========================>..] - ETA: 0s - loss: 1.1089e-09 - accuracy: 1.0000
# Epoch 00226: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 837us/sample - loss: 1.0366e-09 - accuracy: 1.0000 - val_loss: 0.6591 - val_accuracy: 0.9483
# Epoch 227/250
# 390/460 [========================>.....] - ETA: 0s - loss: 1.2227e-09 - accuracy: 1.0000
# Epoch 00227: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 782us/sample - loss: 1.0366e-09 - accuracy: 1.0000 - val_loss: 0.6599 - val_accuracy: 0.9483
# Epoch 228/250
# 430/460 [===========================>..] - ETA: 0s - loss: 8.3169e-10 - accuracy: 1.0000
# Epoch 00228: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 862us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.6608 - val_accuracy: 0.9483
# Epoch 229/250
# 450/460 [============================>.] - ETA: 0s - loss: 7.9473e-10 - accuracy: 1.0000
# Epoch 00229: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 808us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.6614 - val_accuracy: 0.9483
# Epoch 230/250
# 450/460 [============================>.] - ETA: 0s - loss: 7.9473e-10 - accuracy: 1.0000
# Epoch 00230: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 806us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.6623 - val_accuracy: 0.9483
# Epoch 231/250
# 430/460 [===========================>..] - ETA: 0s - loss: 8.3169e-10 - accuracy: 1.0000
# Epoch 00231: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 898us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.6630 - val_accuracy: 0.9483
# Epoch 232/250
# 450/460 [============================>.] - ETA: 0s - loss: 7.9473e-10 - accuracy: 1.0000
# Epoch 00232: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 819us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.6637 - val_accuracy: 0.9483
# Epoch 233/250
# 430/460 [===========================>..] - ETA: 0s - loss: 8.3169e-10 - accuracy: 1.0000
# Epoch 00233: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 862us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.6645 - val_accuracy: 0.9483
# Epoch 234/250
# 440/460 [===========================>..] - ETA: 0s - loss: 8.1279e-10 - accuracy: 1.0000
# Epoch 00234: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 837us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.6652 - val_accuracy: 0.9483
# Epoch 235/250
# 440/460 [===========================>..] - ETA: 0s - loss: 8.1279e-10 - accuracy: 1.0000
# Epoch 00235: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 808us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.6661 - val_accuracy: 0.9483
# Epoch 236/250
# 440/460 [===========================>..] - ETA: 0s - loss: 8.1279e-10 - accuracy: 1.0000
# Epoch 00236: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 833us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.6669 - val_accuracy: 0.9483
# Epoch 237/250
# 430/460 [===========================>..] - ETA: 0s - loss: 8.3169e-10 - accuracy: 1.0000
# Epoch 00237: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 837us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.6678 - val_accuracy: 0.9483
# Epoch 238/250
# 430/460 [===========================>..] - ETA: 0s - loss: 8.3169e-10 - accuracy: 1.0000
# Epoch 00238: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 842us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.6684 - val_accuracy: 0.9483
# Epoch 239/250
# 440/460 [===========================>..] - ETA: 0s - loss: 8.1279e-10 - accuracy: 1.0000
# Epoch 00239: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 839us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.6693 - val_accuracy: 0.9483
# Epoch 240/250
# 440/460 [===========================>..] - ETA: 0s - loss: 8.1279e-10 - accuracy: 1.0000
# Epoch 00240: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 822us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.6701 - val_accuracy: 0.9483
# Epoch 241/250
# 430/460 [===========================>..] - ETA: 0s - loss: 8.3169e-10 - accuracy: 1.0000
# Epoch 00241: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 835us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.6709 - val_accuracy: 0.9483
# Epoch 242/250
# 430/460 [===========================>..] - ETA: 0s - loss: 5.5446e-10 - accuracy: 1.0000
# Epoch 00242: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 862us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.6715 - val_accuracy: 0.9483
# Epoch 243/250
# 440/460 [===========================>..] - ETA: 0s - loss: 8.1279e-10 - accuracy: 1.0000
# Epoch 00243: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 823us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.6725 - val_accuracy: 0.9483
# Epoch 244/250
# 430/460 [===========================>..] - ETA: 0s - loss: 8.3169e-10 - accuracy: 1.0000
# Epoch 00244: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 825us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.6735 - val_accuracy: 0.9483
# Epoch 245/250
# 440/460 [===========================>..] - ETA: 0s - loss: 8.1279e-10 - accuracy: 1.0000
# Epoch 00245: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 822us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.6742 - val_accuracy: 0.9483
# Epoch 246/250
# 430/460 [===========================>..] - ETA: 0s - loss: 8.3169e-10 - accuracy: 1.0000
# Epoch 00246: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 852us/sample - loss: 7.7745e-10 - accuracy: 1.0000 - val_loss: 0.6750 - val_accuracy: 0.9483
# Epoch 247/250
# 430/460 [===========================>..] - ETA: 0s - loss: 5.5446e-10 - accuracy: 1.0000
# Epoch 00247: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 821us/sample - loss: 5.1830e-10 - accuracy: 1.0000 - val_loss: 0.6757 - val_accuracy: 0.9483
# Epoch 248/250
# 450/460 [============================>.] - ETA: 0s - loss: 5.2982e-10 - accuracy: 1.0000
# Epoch 00248: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 821us/sample - loss: 5.1830e-10 - accuracy: 1.0000 - val_loss: 0.6764 - val_accuracy: 0.9483
# Epoch 249/250
# 440/460 [===========================>..] - ETA: 0s - loss: 5.4186e-10 - accuracy: 1.0000
# Epoch 00249: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 813us/sample - loss: 5.1830e-10 - accuracy: 1.0000 - val_loss: 0.6771 - val_accuracy: 0.9483
# Epoch 250/250
# 430/460 [===========================>..] - ETA: 0s - loss: 5.5446e-10 - accuracy: 1.0000
# Epoch 00250: val_accuracy did not improve from 0.95690
# 460/460 [==============================] - 0s 807us/sample - loss: 5.1830e-10 - accuracy: 1.0000 - val_loss: 0.6779 - val_accuracy: 0.9483
# Training completed in time:  0:01:39.521591

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste
#
# Lembrando que estamos utilizando o mesmo conjunto de validacão, que a princípio, pode incluir instâncias do conjunto de treinamento: o dataset utilizado foi gerado com corte de áudio, então alguns trechos do mesmo áudio podem estar presentes em ambos os conjuntos de treinamento e teste.
# Por ora deixamos assim já que estamos realizando uma investigacão inicial.

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  1.0
# Testing Accuracy:  0.94827586

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.93      0.96      0.95        56
#    Pneumonia       0.97      0.93      0.95        60
#
#     accuracy                           0.95       116
#    macro avg       0.95      0.95      0.95       116
# weighted avg       0.95      0.95      0.95       116

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[54  2]
#  [ 4 56]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])
