# %% [markdown]
# # Rede CNN - Modelo 1
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - trim10

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP = 'trim10'
MAX_PAD_LEN = 431

# %%
filepaths = glob.glob(f'./datasets/{GROUP}/**/*.wav', recursive=True)
filenames = [os.path.splitext(os.path.basename(p))[0] for p in filepaths]

# %%
p_id_in_file = [] # patient IDs corresponding to each file
for name in filenames:
    p_id_in_file.append(int(name[:3]))

p_id_in_file = np.array(p_id_in_file)

# %%
max_pad_len =  MAX_PAD_LEN

os.makedirs("./Respiratory_Sound_Database/features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=10) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./Respiratory_Sound_Database/features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
p_diag = pd.read_csv("./Respiratory_Sound_Database/Respiratory_Sound_Database/patient_diagnosis.csv",header=None) # patient diagnosis file

# %%
labels = np.array([p_diag[p_diag[0] == x][1].values[0] for x in p_id_in_file]) # labels for audio files

# %%
features = [] 

# Iterate through each sound file and extract the features
for file_name in filepaths:
    data = extract_features(file_name)
    features.append(data)

print('Finished feature extraction from ', len(features), ' files')
features = np.array(features)
# Out:
# Finished feature extraction from  72  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
features = np.array(features) # convert to numpy array

# %%
np.unique(labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
# delete diseases
'''
features1 = features
labels1 = labels'''

features1 = np.delete(features, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0) 

labels1 = np.delete(labels, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0)

# %%
# print class counts
unique_elements, counts_elements = np.unique(labels1, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['35' '37']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(labels1)
oh_labels = to_categorical(i_labels)

# %%
features1.shape
# Out:
# (72, 40, 431)

# %%
# add channel dimension for CNN
features1 = np.reshape(features1, (*features1.shape,1)) 

# train test split
x_train, x_test, y_train, y_test = train_test_split(features1, oh_labels, stratify=oh_labels, 
                                                    test_size=0.2, random_state = 42)

# %% [markdown]
# **MLP model architecture**

# %%
num_rows = 40
num_columns = 431
num_channels = 1

num_labels = oh_labels.shape[1]
filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 430, 16)       80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 215, 16)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 215, 16)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 214, 32)       2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 107, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 107, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 106, 64)        8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 53, 64)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 53, 64)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 52, 128)        32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 26, 128)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 26, 128)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 258
# =================================================================
# Total params: 43,570
# Trainable params: 43,570
# Non-trainable params: 0
# _________________________________________________________________
# 15/15 [==============================] - 1s 59ms/sample - loss: 3.1588 - accuracy: 0.5333
# Pre-training accuracy: 53.3333%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 250
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/model2_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 57 samples, validate on 15 samples
# Epoch 1/250
# 10/57 [====>.........................] - ETA: 2s - loss: 1.5177 - accuracy: 0.6000
# Epoch 00001: val_accuracy improved from -inf to 0.53333, saving model to models/model2_01.h5
# 57/57 [==============================] - 1s 18ms/sample - loss: 10.0885 - accuracy: 0.5263 - val_loss: 5.7709 - val_accuracy: 0.5333
# Epoch 2/250
# 10/57 [====>.........................] - ETA: 0s - loss: 7.4245 - accuracy: 0.5000
# Epoch 00002: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 1ms/sample - loss: 3.6151 - accuracy: 0.5088 - val_loss: 2.9239 - val_accuracy: 0.5333
# Epoch 3/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.4637 - accuracy: 0.6000
# Epoch 00003: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 1ms/sample - loss: 2.1145 - accuracy: 0.5614 - val_loss: 0.8399 - val_accuracy: 0.4667
# Epoch 4/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.7946 - accuracy: 0.6000
# Epoch 00004: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 1ms/sample - loss: 1.8322 - accuracy: 0.5614 - val_loss: 2.5863 - val_accuracy: 0.5333
# Epoch 5/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.6506 - accuracy: 0.3000
# Epoch 00005: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 1ms/sample - loss: 1.5423 - accuracy: 0.4737 - val_loss: 1.2790 - val_accuracy: 0.5333
# Epoch 6/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.0041 - accuracy: 0.5000
# Epoch 00006: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 1ms/sample - loss: 1.0596 - accuracy: 0.5439 - val_loss: 1.7978 - val_accuracy: 0.5333
# Epoch 7/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.3350 - accuracy: 0.5000
# Epoch 00007: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.9357 - accuracy: 0.6316 - val_loss: 1.5396 - val_accuracy: 0.5333
# Epoch 8/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4908 - accuracy: 0.8000
# Epoch 00008: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.7918 - accuracy: 0.6842 - val_loss: 0.9479 - val_accuracy: 0.4667
# Epoch 9/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.8949 - accuracy: 0.7000
# Epoch 00009: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.6511 - accuracy: 0.7544 - val_loss: 1.2304 - val_accuracy: 0.5333
# Epoch 10/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.7015 - accuracy: 0.7000
# Epoch 00010: val_accuracy did not improve from 0.53333
# 57/57 [==============================] - 0s 1ms/sample - loss: 1.1319 - accuracy: 0.5789 - val_loss: 1.2148 - val_accuracy: 0.5333
# Epoch 11/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5341 - accuracy: 0.8000
# Epoch 00011: val_accuracy improved from 0.53333 to 0.60000, saving model to models/model2_11.h5
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.8939 - accuracy: 0.6140 - val_loss: 0.6942 - val_accuracy: 0.6000
# Epoch 12/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.9356 - accuracy: 0.5000
# Epoch 00012: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.6858 - accuracy: 0.6491 - val_loss: 0.9637 - val_accuracy: 0.4667
# Epoch 13/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2213 - accuracy: 0.9000
# Epoch 00013: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.6386 - accuracy: 0.7719 - val_loss: 0.6677 - val_accuracy: 0.6000
# Epoch 14/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4506 - accuracy: 0.8000
# Epoch 00014: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.7120 - accuracy: 0.7544 - val_loss: 0.6877 - val_accuracy: 0.6000
# Epoch 15/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2292 - accuracy: 1.0000
# Epoch 00015: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.7936 - accuracy: 0.7193 - val_loss: 1.0387 - val_accuracy: 0.4667
# Epoch 16/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.2268 - accuracy: 0.7000
# Epoch 00016: val_accuracy improved from 0.60000 to 0.73333, saving model to models/model2_16.h5
# 57/57 [==============================] - 0s 2ms/sample - loss: 1.0126 - accuracy: 0.6491 - val_loss: 0.6356 - val_accuracy: 0.7333
# Epoch 17/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.0059 - accuracy: 0.7000
# Epoch 00017: val_accuracy did not improve from 0.73333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.9486 - accuracy: 0.6316 - val_loss: 0.9403 - val_accuracy: 0.4667
# Epoch 18/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.3313 - accuracy: 0.5000
# Epoch 00018: val_accuracy improved from 0.73333 to 0.80000, saving model to models/model2_18.h5
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.7930 - accuracy: 0.6140 - val_loss: 0.6034 - val_accuracy: 0.8000
# Epoch 19/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2580 - accuracy: 0.8000
# Epoch 00019: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.6280 - accuracy: 0.7018 - val_loss: 0.6601 - val_accuracy: 0.6000
# Epoch 20/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3008 - accuracy: 0.9000
# Epoch 00020: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4432 - accuracy: 0.7719 - val_loss: 0.6872 - val_accuracy: 0.7333
# Epoch 21/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.6365 - accuracy: 0.8000
# Epoch 00021: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.9088 - accuracy: 0.6491 - val_loss: 0.6488 - val_accuracy: 0.6000
# Epoch 22/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.6509 - accuracy: 0.7000
# Epoch 00022: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.9254 - accuracy: 0.6491 - val_loss: 0.6955 - val_accuracy: 0.6667
# Epoch 23/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.8414 - accuracy: 0.6000
# Epoch 00023: val_accuracy improved from 0.80000 to 0.86667, saving model to models/model2_23.h5
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.6433 - accuracy: 0.7368 - val_loss: 0.5756 - val_accuracy: 0.8667
# Epoch 24/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5024 - accuracy: 0.8000
# Epoch 00024: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4120 - accuracy: 0.8421 - val_loss: 0.6266 - val_accuracy: 0.7333
# Epoch 25/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4471 - accuracy: 0.7000
# Epoch 00025: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4624 - accuracy: 0.7719 - val_loss: 0.5651 - val_accuracy: 0.7333
# Epoch 26/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5352 - accuracy: 0.8000
# Epoch 00026: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4736 - accuracy: 0.7719 - val_loss: 0.7048 - val_accuracy: 0.6000
# Epoch 27/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2674 - accuracy: 0.9000
# Epoch 00027: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3684 - accuracy: 0.8421 - val_loss: 0.5763 - val_accuracy: 0.7333
# Epoch 28/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5711 - accuracy: 0.7000
# Epoch 00028: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4996 - accuracy: 0.7719 - val_loss: 0.6730 - val_accuracy: 0.7333
# Epoch 29/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2587 - accuracy: 0.9000
# Epoch 00029: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4952 - accuracy: 0.7719 - val_loss: 0.5906 - val_accuracy: 0.8000
# Epoch 30/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1903 - accuracy: 1.0000
# Epoch 00030: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4632 - accuracy: 0.7719 - val_loss: 0.6450 - val_accuracy: 0.8000
# Epoch 31/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5192 - accuracy: 0.8000
# Epoch 00031: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.5127 - accuracy: 0.7895 - val_loss: 0.5741 - val_accuracy: 0.8000
# Epoch 32/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1925 - accuracy: 0.9000
# Epoch 00032: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4062 - accuracy: 0.8070 - val_loss: 0.6239 - val_accuracy: 0.8000
# Epoch 33/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4628 - accuracy: 0.8000
# Epoch 00033: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3475 - accuracy: 0.8596 - val_loss: 0.5784 - val_accuracy: 0.8000
# Epoch 34/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4529 - accuracy: 0.7000
# Epoch 00034: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3629 - accuracy: 0.8070 - val_loss: 0.5634 - val_accuracy: 0.8667
# Epoch 35/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3994 - accuracy: 0.9000
# Epoch 00035: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4112 - accuracy: 0.8246 - val_loss: 0.6072 - val_accuracy: 0.8000
# Epoch 36/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.6377 - accuracy: 0.6000
# Epoch 00036: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3514 - accuracy: 0.8246 - val_loss: 0.5772 - val_accuracy: 0.8000
# Epoch 37/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3951 - accuracy: 0.9000
# Epoch 00037: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4050 - accuracy: 0.8070 - val_loss: 0.6442 - val_accuracy: 0.7333
# Epoch 38/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3937 - accuracy: 0.7000
# Epoch 00038: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3868 - accuracy: 0.7895 - val_loss: 0.6462 - val_accuracy: 0.7333
# Epoch 39/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3271 - accuracy: 0.8000
# Epoch 00039: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3171 - accuracy: 0.8596 - val_loss: 0.6669 - val_accuracy: 0.7333
# Epoch 40/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4933 - accuracy: 0.8000
# Epoch 00040: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4308 - accuracy: 0.8070 - val_loss: 0.6026 - val_accuracy: 0.7333
# Epoch 41/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1931 - accuracy: 0.9000
# Epoch 00041: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.6022 - accuracy: 0.7193 - val_loss: 0.8590 - val_accuracy: 0.5333
# Epoch 42/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3614 - accuracy: 0.8000
# Epoch 00042: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.7528 - accuracy: 0.6842 - val_loss: 0.5512 - val_accuracy: 0.8667
# Epoch 43/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2055 - accuracy: 0.9000
# Epoch 00043: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.5761 - accuracy: 0.7368 - val_loss: 0.6332 - val_accuracy: 0.6667
# Epoch 44/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2969 - accuracy: 0.8000
# Epoch 00044: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4353 - accuracy: 0.8070 - val_loss: 0.6061 - val_accuracy: 0.8000
# Epoch 45/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2512 - accuracy: 0.9000
# Epoch 00045: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3845 - accuracy: 0.7895 - val_loss: 0.5617 - val_accuracy: 0.7333
# Epoch 46/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2638 - accuracy: 0.9000
# Epoch 00046: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2501 - accuracy: 0.9123 - val_loss: 0.6433 - val_accuracy: 0.6667
# Epoch 47/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1156 - accuracy: 1.0000
# Epoch 00047: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3307 - accuracy: 0.8421 - val_loss: 0.5682 - val_accuracy: 0.7333
# Epoch 48/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2504 - accuracy: 1.0000
# Epoch 00048: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3292 - accuracy: 0.8596 - val_loss: 0.5663 - val_accuracy: 0.7333
# Epoch 49/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2045 - accuracy: 0.9000
# Epoch 00049: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2725 - accuracy: 0.8947 - val_loss: 0.5908 - val_accuracy: 0.8000
# Epoch 50/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3497 - accuracy: 0.7000
# Epoch 00050: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3000 - accuracy: 0.8246 - val_loss: 0.5361 - val_accuracy: 0.7333
# Epoch 51/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2175 - accuracy: 0.9000
# Epoch 00051: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2942 - accuracy: 0.8596 - val_loss: 0.5875 - val_accuracy: 0.6667
# Epoch 52/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2126 - accuracy: 1.0000
# Epoch 00052: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2453 - accuracy: 0.9298 - val_loss: 0.5500 - val_accuracy: 0.7333
# Epoch 53/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2700 - accuracy: 0.9000
# Epoch 00053: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3106 - accuracy: 0.8421 - val_loss: 0.5601 - val_accuracy: 0.7333
# Epoch 54/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3895 - accuracy: 0.8000
# Epoch 00054: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3115 - accuracy: 0.8246 - val_loss: 0.5830 - val_accuracy: 0.6667
# Epoch 55/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5309 - accuracy: 0.6000
# Epoch 00055: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2536 - accuracy: 0.8596 - val_loss: 0.5375 - val_accuracy: 0.7333
# Epoch 56/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1526 - accuracy: 0.9000
# Epoch 00056: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2794 - accuracy: 0.8596 - val_loss: 0.5555 - val_accuracy: 0.6667
# Epoch 57/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1533 - accuracy: 1.0000
# Epoch 00057: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2415 - accuracy: 0.8772 - val_loss: 0.5177 - val_accuracy: 0.6667
# Epoch 58/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2569 - accuracy: 0.8000
# Epoch 00058: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2672 - accuracy: 0.8772 - val_loss: 0.5661 - val_accuracy: 0.6667
# Epoch 59/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3269 - accuracy: 0.8000
# Epoch 00059: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2201 - accuracy: 0.8947 - val_loss: 0.4473 - val_accuracy: 0.8000
# Epoch 60/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1182 - accuracy: 0.9000
# Epoch 00060: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2469 - accuracy: 0.8421 - val_loss: 0.6048 - val_accuracy: 0.6667
# Epoch 61/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0994 - accuracy: 1.0000
# Epoch 00061: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2900 - accuracy: 0.8596 - val_loss: 0.4075 - val_accuracy: 0.8000
# Epoch 62/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1901 - accuracy: 1.0000
# Epoch 00062: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2645 - accuracy: 0.9123 - val_loss: 0.4898 - val_accuracy: 0.6667
# Epoch 63/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2259 - accuracy: 0.9000
# Epoch 00063: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2133 - accuracy: 0.9123 - val_loss: 0.3635 - val_accuracy: 0.8000
# Epoch 64/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0604 - accuracy: 1.0000
# Epoch 00064: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3293 - accuracy: 0.8596 - val_loss: 0.5974 - val_accuracy: 0.6667
# Epoch 65/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4099 - accuracy: 0.8000
# Epoch 00065: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2485 - accuracy: 0.9123 - val_loss: 0.3813 - val_accuracy: 0.8667
# Epoch 66/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3050 - accuracy: 0.8000
# Epoch 00066: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2920 - accuracy: 0.8421 - val_loss: 0.5393 - val_accuracy: 0.6667
# Epoch 67/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2598 - accuracy: 0.9000
# Epoch 00067: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2499 - accuracy: 0.8947 - val_loss: 0.4209 - val_accuracy: 0.8667
# Epoch 68/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2641 - accuracy: 0.9000
# Epoch 00068: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2745 - accuracy: 0.8421 - val_loss: 0.4829 - val_accuracy: 0.6667
# Epoch 69/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0721 - accuracy: 1.0000
# Epoch 00069: val_accuracy improved from 0.86667 to 0.93333, saving model to models/model2_69.h5
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2616 - accuracy: 0.8596 - val_loss: 0.3722 - val_accuracy: 0.9333
# Epoch 70/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4504 - accuracy: 0.7000
# Epoch 00070: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2583 - accuracy: 0.8421 - val_loss: 0.4002 - val_accuracy: 0.7333
# Epoch 71/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1220 - accuracy: 1.0000
# Epoch 00071: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2478 - accuracy: 0.8772 - val_loss: 0.3696 - val_accuracy: 0.8667
# Epoch 72/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2258 - accuracy: 0.9000
# Epoch 00072: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2216 - accuracy: 0.9123 - val_loss: 0.3655 - val_accuracy: 0.8667
# Epoch 73/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3123 - accuracy: 0.8000
# Epoch 00073: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2199 - accuracy: 0.9123 - val_loss: 0.3488 - val_accuracy: 0.8667
# Epoch 74/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1442 - accuracy: 0.9000
# Epoch 00074: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1637 - accuracy: 0.9123 - val_loss: 0.3492 - val_accuracy: 0.8667
# Epoch 75/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2032 - accuracy: 0.9000
# Epoch 00075: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2130 - accuracy: 0.8772 - val_loss: 0.3648 - val_accuracy: 0.9333
# Epoch 76/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3802 - accuracy: 0.9000
# Epoch 00076: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3143 - accuracy: 0.8421 - val_loss: 0.3614 - val_accuracy: 0.8000
# Epoch 77/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2644 - accuracy: 0.9000
# Epoch 00077: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2878 - accuracy: 0.8772 - val_loss: 0.4187 - val_accuracy: 0.7333
# Epoch 78/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0739 - accuracy: 1.0000
# Epoch 00078: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2667 - accuracy: 0.8596 - val_loss: 0.3735 - val_accuracy: 0.8000
# Epoch 79/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1654 - accuracy: 0.9000
# Epoch 00079: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1928 - accuracy: 0.9123 - val_loss: 0.3730 - val_accuracy: 0.7333
# Epoch 80/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4509 - accuracy: 0.7000
# Epoch 00080: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1944 - accuracy: 0.9123 - val_loss: 0.3647 - val_accuracy: 0.8000
# Epoch 81/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2882 - accuracy: 0.9000
# Epoch 00081: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1448 - accuracy: 0.9474 - val_loss: 0.3703 - val_accuracy: 0.8667
# Epoch 82/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1672 - accuracy: 1.0000
# Epoch 00082: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1968 - accuracy: 0.9298 - val_loss: 0.3912 - val_accuracy: 0.8000
# Epoch 83/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2038 - accuracy: 0.9000
# Epoch 00083: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1573 - accuracy: 0.9298 - val_loss: 0.3509 - val_accuracy: 0.8667
# Epoch 84/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3335 - accuracy: 0.8000
# Epoch 00084: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2974 - accuracy: 0.8947 - val_loss: 0.3825 - val_accuracy: 0.8000
# Epoch 85/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1749 - accuracy: 0.9000
# Epoch 00085: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2273 - accuracy: 0.8947 - val_loss: 0.3525 - val_accuracy: 0.8000
# Epoch 86/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2990 - accuracy: 0.8000
# Epoch 00086: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1841 - accuracy: 0.9123 - val_loss: 0.3594 - val_accuracy: 0.7333
# Epoch 87/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1417 - accuracy: 1.0000
# Epoch 00087: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1708 - accuracy: 0.9123 - val_loss: 0.3887 - val_accuracy: 0.8000
# Epoch 88/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1022 - accuracy: 1.0000
# Epoch 00088: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1542 - accuracy: 0.9474 - val_loss: 0.3973 - val_accuracy: 0.8000
# Epoch 89/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1761 - accuracy: 0.9000
# Epoch 00089: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1365 - accuracy: 0.9825 - val_loss: 0.4250 - val_accuracy: 0.8000
# Epoch 90/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0620 - accuracy: 1.0000
# Epoch 00090: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1715 - accuracy: 0.9298 - val_loss: 0.3880 - val_accuracy: 0.8000
# Epoch 91/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2601 - accuracy: 0.9000
# Epoch 00091: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1466 - accuracy: 0.9298 - val_loss: 0.4021 - val_accuracy: 0.8000
# Epoch 92/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0440 - accuracy: 1.0000
# Epoch 00092: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1437 - accuracy: 0.9298 - val_loss: 0.4002 - val_accuracy: 0.7333
# Epoch 93/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1575 - accuracy: 0.9000
# Epoch 00093: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1361 - accuracy: 0.9474 - val_loss: 0.4468 - val_accuracy: 0.8000
# Epoch 94/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1824 - accuracy: 0.9000
# Epoch 00094: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1383 - accuracy: 0.9474 - val_loss: 0.4909 - val_accuracy: 0.8000
# Epoch 95/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2019 - accuracy: 0.9000
# Epoch 00095: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1147 - accuracy: 0.9649 - val_loss: 0.4713 - val_accuracy: 0.8000
# Epoch 96/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0974 - accuracy: 1.0000
# Epoch 00096: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1436 - accuracy: 0.9474 - val_loss: 0.4389 - val_accuracy: 0.7333
# Epoch 97/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1901 - accuracy: 0.9000
# Epoch 00097: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1831 - accuracy: 0.9123 - val_loss: 0.5483 - val_accuracy: 0.8000
# Epoch 98/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1853 - accuracy: 0.9000
# Epoch 00098: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1534 - accuracy: 0.9298 - val_loss: 0.5054 - val_accuracy: 0.7333
# Epoch 99/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0903 - accuracy: 1.0000
# Epoch 00099: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2398 - accuracy: 0.8772 - val_loss: 0.6638 - val_accuracy: 0.8000
# Epoch 100/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2051 - accuracy: 0.9000
# Epoch 00100: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3154 - accuracy: 0.8596 - val_loss: 0.4703 - val_accuracy: 0.7333
# Epoch 101/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3166 - accuracy: 0.9000
# Epoch 00101: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4305 - accuracy: 0.8421 - val_loss: 0.5639 - val_accuracy: 0.8000
# Epoch 102/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4263 - accuracy: 0.7000
# Epoch 00102: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3256 - accuracy: 0.8070 - val_loss: 0.4146 - val_accuracy: 0.8000
# Epoch 103/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0931 - accuracy: 1.0000
# Epoch 00103: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2543 - accuracy: 0.8772 - val_loss: 0.4576 - val_accuracy: 0.8000
# Epoch 104/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1082 - accuracy: 0.9000
# Epoch 00104: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1659 - accuracy: 0.9298 - val_loss: 0.4836 - val_accuracy: 0.8000
# Epoch 105/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0477 - accuracy: 1.0000
# Epoch 00105: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1454 - accuracy: 0.9474 - val_loss: 0.4459 - val_accuracy: 0.7333
# Epoch 106/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0527 - accuracy: 1.0000
# Epoch 00106: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1342 - accuracy: 0.9123 - val_loss: 0.5069 - val_accuracy: 0.8000
# Epoch 107/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1518 - accuracy: 0.9000
# Epoch 00107: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1272 - accuracy: 0.9474 - val_loss: 0.4944 - val_accuracy: 0.8667
# Epoch 108/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0761 - accuracy: 1.0000
# Epoch 00108: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1102 - accuracy: 0.9474 - val_loss: 0.5463 - val_accuracy: 0.8667
# Epoch 109/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1843 - accuracy: 0.9000
# Epoch 00109: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0820 - accuracy: 0.9825 - val_loss: 0.5540 - val_accuracy: 0.8667
# Epoch 110/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0265 - accuracy: 1.0000
# Epoch 00110: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1827 - accuracy: 0.8947 - val_loss: 0.5750 - val_accuracy: 0.8000
# Epoch 111/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0508 - accuracy: 1.0000
# Epoch 00111: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1006 - accuracy: 0.9474 - val_loss: 0.4907 - val_accuracy: 0.8000
# Epoch 112/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0308 - accuracy: 1.0000
# Epoch 00112: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0758 - accuracy: 1.0000 - val_loss: 0.5238 - val_accuracy: 0.8000
# Epoch 113/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2508 - accuracy: 0.9000
# Epoch 00113: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0939 - accuracy: 0.9649 - val_loss: 0.4917 - val_accuracy: 0.8000
# Epoch 114/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2201 - accuracy: 0.9000
# Epoch 00114: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1165 - accuracy: 0.9649 - val_loss: 0.6718 - val_accuracy: 0.8000
# Epoch 115/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3697 - accuracy: 0.8000
# Epoch 00115: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2134 - accuracy: 0.8772 - val_loss: 0.5942 - val_accuracy: 0.8000
# Epoch 116/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0231 - accuracy: 1.0000
# Epoch 00116: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1437 - accuracy: 0.9298 - val_loss: 0.6112 - val_accuracy: 0.8000
# Epoch 117/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0571 - accuracy: 1.0000
# Epoch 00117: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1823 - accuracy: 0.9123 - val_loss: 0.5812 - val_accuracy: 0.8000
# Epoch 118/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0370 - accuracy: 1.0000
# Epoch 00118: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1047 - accuracy: 0.9649 - val_loss: 0.7256 - val_accuracy: 0.8000
# Epoch 119/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0632 - accuracy: 1.0000
# Epoch 00119: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0824 - accuracy: 0.9825 - val_loss: 0.5795 - val_accuracy: 0.8000
# Epoch 120/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0483 - accuracy: 1.0000
# Epoch 00120: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0988 - accuracy: 0.9649 - val_loss: 0.6154 - val_accuracy: 0.8000
# Epoch 121/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0855 - accuracy: 1.0000
# Epoch 00121: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1229 - accuracy: 0.9474 - val_loss: 0.5869 - val_accuracy: 0.8000
# Epoch 122/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0369 - accuracy: 1.0000
# Epoch 00122: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0533 - accuracy: 1.0000 - val_loss: 0.4458 - val_accuracy: 0.8000
# Epoch 123/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0975 - accuracy: 1.0000
# Epoch 00123: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1068 - accuracy: 0.9649 - val_loss: 0.5241 - val_accuracy: 0.8000
# Epoch 124/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1482 - accuracy: 0.9000
# Epoch 00124: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0924 - accuracy: 0.9649 - val_loss: 0.5325 - val_accuracy: 0.7333
# Epoch 125/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0339 - accuracy: 1.0000
# Epoch 00125: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0617 - accuracy: 0.9825 - val_loss: 0.5538 - val_accuracy: 0.7333
# Epoch 126/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0511 - accuracy: 1.0000
# Epoch 00126: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.0474 - accuracy: 1.0000 - val_loss: 0.6281 - val_accuracy: 0.8000
# Epoch 127/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1290 - accuracy: 0.9000
# Epoch 00127: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0946 - accuracy: 0.9474 - val_loss: 0.6547 - val_accuracy: 0.8000
# Epoch 128/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0256 - accuracy: 1.0000
# Epoch 00128: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0704 - accuracy: 1.0000 - val_loss: 0.6233 - val_accuracy: 0.7333
# Epoch 129/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0109 - accuracy: 1.0000
# Epoch 00129: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0752 - accuracy: 0.9825 - val_loss: 0.6904 - val_accuracy: 0.8000
# Epoch 130/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1428 - accuracy: 1.0000
# Epoch 00130: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0820 - accuracy: 0.9649 - val_loss: 0.6001 - val_accuracy: 0.7333
# Epoch 131/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0588 - accuracy: 1.0000
# Epoch 00131: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0728 - accuracy: 0.9649 - val_loss: 0.6394 - val_accuracy: 0.8000
# Epoch 132/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0122 - accuracy: 1.0000
# Epoch 00132: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0611 - accuracy: 0.9825 - val_loss: 0.5350 - val_accuracy: 0.7333
# Epoch 133/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0755 - accuracy: 1.0000
# Epoch 00133: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0690 - accuracy: 0.9825 - val_loss: 0.6134 - val_accuracy: 0.8000
# Epoch 134/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0416 - accuracy: 1.0000
# Epoch 00134: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0601 - accuracy: 0.9825 - val_loss: 0.5439 - val_accuracy: 0.7333
# Epoch 135/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0249 - accuracy: 1.0000
# Epoch 00135: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0689 - accuracy: 1.0000 - val_loss: 0.7078 - val_accuracy: 0.8000
# Epoch 136/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1904 - accuracy: 0.9000
# Epoch 00136: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0819 - accuracy: 0.9649 - val_loss: 0.5865 - val_accuracy: 0.8000
# Epoch 137/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1681 - accuracy: 0.9000
# Epoch 00137: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0754 - accuracy: 0.9649 - val_loss: 0.6813 - val_accuracy: 0.8000
# Epoch 138/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0407 - accuracy: 1.0000
# Epoch 00138: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0490 - accuracy: 0.9825 - val_loss: 0.7142 - val_accuracy: 0.8000
# Epoch 139/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1274 - accuracy: 0.9000
# Epoch 00139: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0547 - accuracy: 0.9825 - val_loss: 0.6685 - val_accuracy: 0.7333
# Epoch 140/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0613 - accuracy: 1.0000
# Epoch 00140: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0507 - accuracy: 0.9825 - val_loss: 0.6195 - val_accuracy: 0.7333
# Epoch 141/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0985 - accuracy: 0.9000
# Epoch 00141: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0710 - accuracy: 0.9474 - val_loss: 0.7014 - val_accuracy: 0.8000
# Epoch 142/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1607 - accuracy: 0.9000
# Epoch 00142: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0642 - accuracy: 0.9825 - val_loss: 0.6322 - val_accuracy: 0.7333
# Epoch 143/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0092 - accuracy: 1.0000
# Epoch 00143: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1013 - accuracy: 0.9298 - val_loss: 0.8057 - val_accuracy: 0.8000
# Epoch 144/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0789 - accuracy: 1.0000
# Epoch 00144: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0816 - accuracy: 0.9649 - val_loss: 0.7073 - val_accuracy: 0.8000
# Epoch 145/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0460 - accuracy: 1.0000
# Epoch 00145: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1740 - accuracy: 0.9298 - val_loss: 0.9458 - val_accuracy: 0.8000
# Epoch 146/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0633 - accuracy: 1.0000
# Epoch 00146: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1352 - accuracy: 0.9298 - val_loss: 0.6813 - val_accuracy: 0.8000
# Epoch 147/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 00147: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0824 - accuracy: 0.9474 - val_loss: 0.7822 - val_accuracy: 0.8000
# Epoch 148/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3047 - accuracy: 0.9000
# Epoch 00148: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1542 - accuracy: 0.9474 - val_loss: 0.6062 - val_accuracy: 0.8000
# Epoch 149/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0361 - accuracy: 1.0000
# Epoch 00149: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0639 - accuracy: 0.9825 - val_loss: 0.7174 - val_accuracy: 0.7333
# Epoch 150/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1947 - accuracy: 0.9000
# Epoch 00150: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1166 - accuracy: 0.9474 - val_loss: 0.6923 - val_accuracy: 0.7333
# Epoch 151/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2521 - accuracy: 0.8000
# Epoch 00151: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1938 - accuracy: 0.9298 - val_loss: 0.7432 - val_accuracy: 0.8000
# Epoch 152/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0093 - accuracy: 1.0000
# Epoch 00152: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1285 - accuracy: 0.9649 - val_loss: 0.6185 - val_accuracy: 0.8000
# Epoch 153/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0605 - accuracy: 1.0000
# Epoch 00153: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2036 - accuracy: 0.9123 - val_loss: 0.6871 - val_accuracy: 0.7333
# Epoch 154/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0967 - accuracy: 1.0000
# Epoch 00154: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2536 - accuracy: 0.9123 - val_loss: 0.8035 - val_accuracy: 0.8000
# Epoch 155/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 00155: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3549 - accuracy: 0.8421 - val_loss: 0.7429 - val_accuracy: 0.7333
# Epoch 156/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4358 - accuracy: 0.8000
# Epoch 00156: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2787 - accuracy: 0.8772 - val_loss: 0.5837 - val_accuracy: 0.8000
# Epoch 157/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4265 - accuracy: 0.8000
# Epoch 00157: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1882 - accuracy: 0.9123 - val_loss: 0.6359 - val_accuracy: 0.8667
# Epoch 158/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0279 - accuracy: 1.0000
# Epoch 00158: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0476 - accuracy: 1.0000 - val_loss: 0.6040 - val_accuracy: 0.7333
# Epoch 159/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0568 - accuracy: 1.0000
# Epoch 00159: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1469 - accuracy: 0.9474 - val_loss: 0.6775 - val_accuracy: 0.8000
# Epoch 160/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3277 - accuracy: 0.9000
# Epoch 00160: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1241 - accuracy: 0.9649 - val_loss: 0.9066 - val_accuracy: 0.8000
# Epoch 161/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0550 - accuracy: 1.0000
# Epoch 00161: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0882 - accuracy: 0.9825 - val_loss: 0.7103 - val_accuracy: 0.7333
# Epoch 162/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0188 - accuracy: 1.0000
# Epoch 00162: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1840 - accuracy: 0.9123 - val_loss: 0.8372 - val_accuracy: 0.8667
# Epoch 163/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1325 - accuracy: 0.9000
# Epoch 00163: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1061 - accuracy: 0.9649 - val_loss: 0.7725 - val_accuracy: 0.8667
# Epoch 164/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0238 - accuracy: 1.0000
# Epoch 00164: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0724 - accuracy: 0.9825 - val_loss: 0.6973 - val_accuracy: 0.7333
# Epoch 165/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0341 - accuracy: 1.0000
# Epoch 00165: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0811 - accuracy: 0.9649 - val_loss: 0.7551 - val_accuracy: 0.8667
# Epoch 166/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0755 - accuracy: 1.0000
# Epoch 00166: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0678 - accuracy: 0.9825 - val_loss: 0.6816 - val_accuracy: 0.8000
# Epoch 167/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0282 - accuracy: 1.0000
# Epoch 00167: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0556 - accuracy: 0.9825 - val_loss: 0.7334 - val_accuracy: 0.8000
# Epoch 168/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0557 - accuracy: 1.0000
# Epoch 00168: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0326 - accuracy: 1.0000 - val_loss: 0.7289 - val_accuracy: 0.8000
# Epoch 169/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1405 - accuracy: 1.0000
# Epoch 00169: val_accuracy did not improve from 0.93333
# ...
# Epoch 195/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0129 - accuracy: 1.0000
# Epoch 00195: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0620 - accuracy: 0.9825 - val_loss: 0.8509 - val_accuracy: 0.8000
# Epoch 196/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0075 - accuracy: 1.0000
# Epoch 00196: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0279 - accuracy: 1.0000 - val_loss: 0.7383 - val_accuracy: 0.8000
# Epoch 197/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1128 - accuracy: 1.0000
# Epoch 00197: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1226 - accuracy: 0.9649 - val_loss: 0.9168 - val_accuracy: 0.8667
# Epoch 198/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0243 - accuracy: 1.0000
# Epoch 00198: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0395 - accuracy: 0.9825 - val_loss: 0.8728 - val_accuracy: 0.8000
# Epoch 199/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0317 - accuracy: 1.0000
# Epoch 00199: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0190 - accuracy: 1.0000 - val_loss: 1.0008 - val_accuracy: 0.8000
# Epoch 200/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0234 - accuracy: 1.0000
# Epoch 00200: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0292 - accuracy: 1.0000 - val_loss: 0.9870 - val_accuracy: 0.8000
# Epoch 201/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0502 - accuracy: 1.0000
# Epoch 00201: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0658 - accuracy: 0.9649 - val_loss: 0.9997 - val_accuracy: 0.8667
# Epoch 202/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0144 - accuracy: 1.0000
# Epoch 00202: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.9643 - val_accuracy: 0.8000
# Epoch 203/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0101 - accuracy: 1.0000
# Epoch 00203: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.9560 - val_accuracy: 0.8000
# Epoch 204/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0256 - accuracy: 1.0000
# Epoch 00204: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0288 - accuracy: 1.0000 - val_loss: 1.0689 - val_accuracy: 0.8000
# Epoch 205/250
# 10/57 [====>.........................] - ETA: 0s - loss: 7.4371e-04 - accuracy: 1.0000
# Epoch 00205: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0258 - accuracy: 1.0000 - val_loss: 1.0247 - val_accuracy: 0.8000
# Epoch 206/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 00206: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0398 - accuracy: 0.9825 - val_loss: 1.0832 - val_accuracy: 0.8667
# Epoch 207/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0418 - accuracy: 1.0000
# Epoch 00207: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0612 - accuracy: 0.9825 - val_loss: 0.9261 - val_accuracy: 0.8000
# Epoch 208/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 00208: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1511 - accuracy: 0.9298 - val_loss: 1.3586 - val_accuracy: 0.8667
# Epoch 209/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0109 - accuracy: 1.0000
# Epoch 00209: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3298 - accuracy: 0.8947 - val_loss: 0.7928 - val_accuracy: 0.6667
# Epoch 210/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3458 - accuracy: 0.9000
# Epoch 00210: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1640 - accuracy: 0.9474 - val_loss: 0.8887 - val_accuracy: 0.8000
# Epoch 211/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0718 - accuracy: 1.0000
# Epoch 00211: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0659 - accuracy: 0.9825 - val_loss: 0.9639 - val_accuracy: 0.8000
# Epoch 212/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 00212: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0351 - accuracy: 0.9825 - val_loss: 0.8943 - val_accuracy: 0.8000
# Epoch 213/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0828 - accuracy: 1.0000
# Epoch 00213: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0540 - accuracy: 0.9825 - val_loss: 0.9395 - val_accuracy: 0.8000
# Epoch 214/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0453 - accuracy: 1.0000
# Epoch 00214: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0407 - accuracy: 0.9825 - val_loss: 0.8654 - val_accuracy: 0.8000
# Epoch 215/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0106 - accuracy: 1.0000
# Epoch 00215: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0365 - accuracy: 1.0000 - val_loss: 0.8979 - val_accuracy: 0.8000
# Epoch 216/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1578 - accuracy: 0.9000
# Epoch 00216: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0511 - accuracy: 0.9825 - val_loss: 1.1409 - val_accuracy: 0.8000
# Epoch 217/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0954 - accuracy: 0.9000
# Epoch 00217: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0383 - accuracy: 0.9825 - val_loss: 1.0093 - val_accuracy: 0.8000
# Epoch 218/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000
# Epoch 00218: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0351 - accuracy: 0.9825 - val_loss: 1.0452 - val_accuracy: 0.8000
# Epoch 219/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0734 - accuracy: 1.0000
# Epoch 00219: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0447 - accuracy: 0.9825 - val_loss: 1.0828 - val_accuracy: 0.8000
# Epoch 220/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0232 - accuracy: 1.0000
# Epoch 00220: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0343 - accuracy: 1.0000 - val_loss: 1.0731 - val_accuracy: 0.8000
# Epoch 221/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0672 - accuracy: 1.0000
# Epoch 00221: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0400 - accuracy: 1.0000 - val_loss: 1.0094 - val_accuracy: 0.8000
# Epoch 222/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0745 - accuracy: 1.0000
# Epoch 00222: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0455 - accuracy: 0.9825 - val_loss: 1.0489 - val_accuracy: 0.8000
# Epoch 223/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1012 - accuracy: 1.0000
# Epoch 00223: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1022 - accuracy: 0.9649 - val_loss: 1.0446 - val_accuracy: 0.8000
# Epoch 224/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 00224: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0136 - accuracy: 1.0000 - val_loss: 1.2783 - val_accuracy: 0.8000
# Epoch 225/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1193 - accuracy: 1.0000
# Epoch 00225: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0393 - accuracy: 1.0000 - val_loss: 1.0170 - val_accuracy: 0.8000
# Epoch 226/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0976 - accuracy: 0.9000
# Epoch 00226: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0547 - accuracy: 0.9649 - val_loss: 1.0939 - val_accuracy: 0.8000
# Epoch 227/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0589 - accuracy: 1.0000
# Epoch 00227: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0360 - accuracy: 1.0000 - val_loss: 1.0391 - val_accuracy: 0.8000
# Epoch 228/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0413 - accuracy: 1.0000
# Epoch 00228: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0593 - accuracy: 0.9649 - val_loss: 1.1335 - val_accuracy: 0.8667
# Epoch 229/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0062 - accuracy: 1.0000
# Epoch 00229: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0248 - accuracy: 1.0000 - val_loss: 1.0097 - val_accuracy: 0.8000
# Epoch 230/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0141 - accuracy: 1.0000
# Epoch 00230: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0221 - accuracy: 1.0000 - val_loss: 0.9867 - val_accuracy: 0.8000
# Epoch 231/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0102 - accuracy: 1.0000
# Epoch 00231: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0355 - accuracy: 0.9825 - val_loss: 1.0864 - val_accuracy: 0.8000
# Epoch 232/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 00232: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0117 - accuracy: 1.0000 - val_loss: 1.2062 - val_accuracy: 0.8667
# Epoch 233/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0280 - accuracy: 1.0000
# Epoch 00233: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0551 - accuracy: 0.9649 - val_loss: 1.1315 - val_accuracy: 0.7333
# Epoch 234/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0360 - accuracy: 1.0000
# Epoch 00234: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0323 - accuracy: 0.9825 - val_loss: 1.3088 - val_accuracy: 0.8667
# Epoch 235/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0269 - accuracy: 1.0000
# Epoch 00235: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0545 - accuracy: 0.9825 - val_loss: 1.2300 - val_accuracy: 0.8000
# Epoch 236/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0266 - accuracy: 1.0000
# Epoch 00236: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0550 - accuracy: 0.9825 - val_loss: 1.2012 - val_accuracy: 0.9333
# Epoch 237/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0695 - accuracy: 1.0000
# Epoch 00237: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0405 - accuracy: 1.0000 - val_loss: 1.1696 - val_accuracy: 0.8667
# Epoch 238/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0064 - accuracy: 1.0000
# Epoch 00238: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0081 - accuracy: 1.0000 - val_loss: 1.0887 - val_accuracy: 0.8000
# Epoch 239/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 00239: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0298 - accuracy: 0.9825 - val_loss: 1.1791 - val_accuracy: 0.8000
# Epoch 240/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0118 - accuracy: 1.0000
# Epoch 00240: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0572 - accuracy: 0.9825 - val_loss: 0.9775 - val_accuracy: 0.8000
# Epoch 241/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0470 - accuracy: 1.0000
# Epoch 00241: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0896 - accuracy: 0.9649 - val_loss: 1.2839 - val_accuracy: 0.8000
# Epoch 242/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0442 - accuracy: 1.0000
# Epoch 00242: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0859 - accuracy: 0.9825 - val_loss: 0.9984 - val_accuracy: 0.8000
# Epoch 243/250
# 10/57 [====>.........................] - ETA: 0s - loss: 8.6200e-05 - accuracy: 1.0000
# Epoch 00243: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0551 - accuracy: 0.9649 - val_loss: 0.9536 - val_accuracy: 0.8000
# Epoch 244/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 00244: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0615 - accuracy: 0.9649 - val_loss: 1.0459 - val_accuracy: 0.8000
# Epoch 245/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0272 - accuracy: 1.0000
# Epoch 00245: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0781 - accuracy: 0.9649 - val_loss: 1.0771 - val_accuracy: 0.8000
# Epoch 246/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0971 - accuracy: 1.0000
# Epoch 00246: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0466 - accuracy: 0.9825 - val_loss: 1.6849 - val_accuracy: 0.8667
# Epoch 247/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0919 - accuracy: 0.9000
# Epoch 00247: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1623 - accuracy: 0.9298 - val_loss: 1.0381 - val_accuracy: 0.6667
# Epoch 248/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 00248: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0832 - accuracy: 0.9474 - val_loss: 1.2729 - val_accuracy: 0.9333
# Epoch 249/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1827 - accuracy: 0.9000
# Epoch 00249: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0543 - accuracy: 0.9825 - val_loss: 1.3148 - val_accuracy: 0.8667
# Epoch 250/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3740 - accuracy: 0.9000
# Epoch 00250: val_accuracy did not improve from 0.93333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0919 - accuracy: 0.9649 - val_loss: 1.1328 - val_accuracy: 0.7333
# Training completed in time:  0:00:18.063090

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste
#
# Lembrando que estamos utilizando o mesmo conjunto de validacão, que a princípio, pode incluir instâncias do conjunto de treinamento: o dataset utilizado foi gerado com corte de áudio, então alguns trechos do mesmo áudio podem estar presentes em ambos os conjuntos de treinamento e teste.
# Por ora deixamos assim já que estamos realizando uma investigacão inicial.

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.9649123
# Testing Accuracy:  0.73333335

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.67      0.86      0.75         7
#    Pneumonia       0.83      0.62      0.71         8
#
#     accuracy                           0.73        15
#    macro avg       0.75      0.74      0.73        15
# weighted avg       0.76      0.73      0.73        15

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[6 1]
#  [3 5]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])
