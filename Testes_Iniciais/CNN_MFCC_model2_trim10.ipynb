# %% [markdown]
# # Rede CNN - Modelo 2
#
# ## Dataset Respiratory_Sound_Database_Pneumo_Healthy_Only - trim5

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import os
import librosa
import librosa.display
import glob

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Necessário na minha máquina. Estava ocorrendo um erro devido à GPU e esse código resolveu.
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
GROUP = 'trim10'
MAX_PAD_LEN = 431

# %%
filepaths = glob.glob(f'./datasets/{GROUP}/**/*.wav', recursive=True)
filenames = [os.path.splitext(os.path.basename(p))[0] for p in filepaths]

# %%
p_id_in_file = [] # patient IDs corresponding to each file
for name in filenames:
    p_id_in_file.append(int(name[:3]))

p_id_in_file = np.array(p_id_in_file)

# %%
max_pad_len =  MAX_PAD_LEN

os.makedirs("./Respiratory_Sound_Database/features/", exist_ok=True)

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
    feature = os.path.splitext(os.path.basename(file_name))[0] + ".npy"
#     if (os.path.isfile(os.path.join("./Respiratory_Sound_Database/features/", feature))):
#         return np.load(os.path.join("./Respiratory_Sound_Database/features/", feature))
    
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=10) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
    np.save(os.path.join("./Respiratory_Sound_Database/features/", feature), mfccs)
    return mfccs

# %%
#filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
p_diag = pd.read_csv("./Respiratory_Sound_Database/Respiratory_Sound_Database/patient_diagnosis.csv",header=None) # patient diagnosis file

# %%
labels = np.array([p_diag[p_diag[0] == x][1].values[0] for x in p_id_in_file]) # labels for audio files

# %%
features = [] 

# Iterate through each sound file and extract the features
for file_name in filepaths:
    data = extract_features(file_name)
    features.append(data)

print('Finished feature extraction from ', len(features), ' files')
features = np.array(features)
# Out:
# Finished feature extraction from  72  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
features = np.array(features) # convert to numpy array

# %%
np.unique(labels)
# Out:
# array(['Healthy', 'Pneumonia'], dtype='<U9')

# %%
# delete diseases
'''
features1 = features
labels1 = labels'''

features1 = np.delete(features, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0) 

labels1 = np.delete(labels, np.where((labels == 'Asthma') | (labels == 'LRTI') | (labels == 'Bronchiectasis') | (labels == 'Bronchiolitis') | (labels == 'COPD') | (labels == "URTI"))[0], axis=0)

# %%
# print class counts
unique_elements, counts_elements = np.unique(labels1, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))
# Out:
# [['Healthy' 'Pneumonia']
#  ['35' '37']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(labels1)
oh_labels = to_categorical(i_labels)

# %%
features1.shape
# Out:
# (72, 40, 431)

# %%
# add channel dimension for CNN
features1 = np.reshape(features1, (*features1.shape,1)) 

# train test split
x_train, x_test, y_train, y_test = train_test_split(features1, oh_labels, stratify=oh_labels, 
                                                    test_size=0.2, random_state = 42)

# %% [markdown]
# **MLP model architecture**

# %%
num_rows = 40
num_columns = 431
num_channels = 1

num_labels = oh_labels.shape[1]
filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=16, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=8, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=4, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 430, 32)       160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 215, 32)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 215, 32)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 214, 16)       2064
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 107, 16)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 107, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 106, 8)         520
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 53, 8)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 53, 8)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 52, 4)          132
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 26, 4)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 26, 4)          0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 4)                 0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 10
# =================================================================
# Total params: 2,886
# Trainable params: 2,886
# Non-trainable params: 0
# _________________________________________________________________
# 15/15 [==============================] - 1s 58ms/sample - loss: 1.4255 - accuracy: 0.4667
# Pre-training accuracy: 46.6667%

# %% [markdown]
# **Training**
#
# Here we will train the model. If we have a trained model, we can load it instead from the next cell.

# %%
# train model
num_epochs = 250
num_batch_size = 10

os.makedirs('models', exist_ok=True)
callbacks = [
    ModelCheckpoint(
        filepath='models/model2_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
                    validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 57 samples, validate on 15 samples
# Epoch 1/250
# 10/57 [====>.........................] - ETA: 2s - loss: 1.6382 - accuracy: 0.6000
# Epoch 00001: val_accuracy improved from -inf to 0.46667, saving model to models/model2_01.h5
# 57/57 [==============================] - 1s 15ms/sample - loss: 1.2767 - accuracy: 0.5088 - val_loss: 1.5053 - val_accuracy: 0.4667
# Epoch 2/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.7435 - accuracy: 0.4000
# Epoch 00002: val_accuracy did not improve from 0.46667
# 57/57 [==============================] - 0s 1ms/sample - loss: 1.4567 - accuracy: 0.5088 - val_loss: 0.7285 - val_accuracy: 0.4667
# Epoch 3/250
# 10/57 [====>.........................] - ETA: 0s - loss: 1.3090 - accuracy: 0.4000
# Epoch 00003: val_accuracy did not improve from 0.46667
# 57/57 [==============================] - 0s 1ms/sample - loss: 1.0500 - accuracy: 0.4561 - val_loss: 0.7284 - val_accuracy: 0.4667
# Epoch 4/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.7214 - accuracy: 0.6000
# Epoch 00004: val_accuracy did not improve from 0.46667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.9519 - accuracy: 0.5439 - val_loss: 0.7209 - val_accuracy: 0.4667
# Epoch 5/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.9032 - accuracy: 0.3000
# Epoch 00005: val_accuracy did not improve from 0.46667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.8695 - accuracy: 0.4737 - val_loss: 0.6644 - val_accuracy: 0.4667
# Epoch 6/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4911 - accuracy: 0.8000
# Epoch 00006: val_accuracy did not improve from 0.46667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.7653 - accuracy: 0.6316 - val_loss: 0.6861 - val_accuracy: 0.4667
# Epoch 7/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5749 - accuracy: 0.7000
# Epoch 00007: val_accuracy did not improve from 0.46667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.7430 - accuracy: 0.6316 - val_loss: 0.7007 - val_accuracy: 0.4667
# Epoch 8/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.7563 - accuracy: 0.6000
# Epoch 00008: val_accuracy did not improve from 0.46667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.7748 - accuracy: 0.5965 - val_loss: 0.6880 - val_accuracy: 0.4667
# Epoch 9/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.7770 - accuracy: 0.5000
# Epoch 00009: val_accuracy did not improve from 0.46667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.7346 - accuracy: 0.6316 - val_loss: 0.6666 - val_accuracy: 0.4667
# Epoch 10/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5020 - accuracy: 0.7000
# Epoch 00010: val_accuracy did not improve from 0.46667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.6786 - accuracy: 0.5614 - val_loss: 0.6631 - val_accuracy: 0.4667
# Epoch 11/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4460 - accuracy: 0.9000
# Epoch 00011: val_accuracy did not improve from 0.46667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.5276 - accuracy: 0.6842 - val_loss: 0.6977 - val_accuracy: 0.4667
# Epoch 12/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5705 - accuracy: 0.6000
# Epoch 00012: val_accuracy did not improve from 0.46667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.7073 - accuracy: 0.5088 - val_loss: 0.6750 - val_accuracy: 0.4667
# Epoch 13/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5444 - accuracy: 0.7000
# Epoch 00013: val_accuracy improved from 0.46667 to 0.60000, saving model to models/model2_13.h5
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.7217 - accuracy: 0.5263 - val_loss: 0.6427 - val_accuracy: 0.6000
# Epoch 14/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5614 - accuracy: 0.8000
# Epoch 00014: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.6782 - accuracy: 0.6491 - val_loss: 0.6522 - val_accuracy: 0.5333
# Epoch 15/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.7685 - accuracy: 0.6000
# Epoch 00015: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.5985 - accuracy: 0.6667 - val_loss: 0.6800 - val_accuracy: 0.4667
# Epoch 16/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.6723 - accuracy: 0.5000
# Epoch 00016: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.5470 - accuracy: 0.6842 - val_loss: 0.6727 - val_accuracy: 0.4667
# Epoch 17/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.6510 - accuracy: 0.6000
# Epoch 00017: val_accuracy did not improve from 0.60000
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.5480 - accuracy: 0.7018 - val_loss: 0.6413 - val_accuracy: 0.6000
# Epoch 18/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5794 - accuracy: 0.9000
# Epoch 00018: val_accuracy improved from 0.60000 to 0.66667, saving model to models/model2_18.h5
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.6407 - accuracy: 0.7193 - val_loss: 0.6155 - val_accuracy: 0.6667
# Epoch 19/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.7526 - accuracy: 0.5000
# Epoch 00019: val_accuracy did not improve from 0.66667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.5889 - accuracy: 0.7018 - val_loss: 0.6173 - val_accuracy: 0.6000
# Epoch 20/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5113 - accuracy: 0.7000
# Epoch 00020: val_accuracy did not improve from 0.66667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.5970 - accuracy: 0.5965 - val_loss: 0.6208 - val_accuracy: 0.6000
# Epoch 21/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4615 - accuracy: 0.8000
# Epoch 00021: val_accuracy did not improve from 0.66667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4931 - accuracy: 0.8246 - val_loss: 0.5969 - val_accuracy: 0.6667
# Epoch 22/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5807 - accuracy: 0.7000
# Epoch 00022: val_accuracy did not improve from 0.66667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.5376 - accuracy: 0.6842 - val_loss: 0.5835 - val_accuracy: 0.6667
# Epoch 23/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.6969 - accuracy: 0.6000
# Epoch 00023: val_accuracy did not improve from 0.66667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.5325 - accuracy: 0.7193 - val_loss: 0.5849 - val_accuracy: 0.6667
# Epoch 24/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5233 - accuracy: 0.8000
# Epoch 00024: val_accuracy improved from 0.66667 to 0.73333, saving model to models/model2_24.h5
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.5187 - accuracy: 0.7544 - val_loss: 0.5603 - val_accuracy: 0.7333
# Epoch 25/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5762 - accuracy: 0.7000
# Epoch 00025: val_accuracy did not improve from 0.73333
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.5085 - accuracy: 0.7368 - val_loss: 0.5467 - val_accuracy: 0.7333
# Epoch 26/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3356 - accuracy: 0.9000
# Epoch 00026: val_accuracy improved from 0.73333 to 0.80000, saving model to models/model2_26.h5
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4840 - accuracy: 0.7544 - val_loss: 0.5415 - val_accuracy: 0.8000
# Epoch 27/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.9553 - accuracy: 0.5000
# Epoch 00027: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.5642 - accuracy: 0.6667 - val_loss: 0.5615 - val_accuracy: 0.6000
# Epoch 28/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.6033 - accuracy: 0.7000
# Epoch 00028: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.5628 - accuracy: 0.6842 - val_loss: 0.5273 - val_accuracy: 0.8000
# Epoch 29/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5649 - accuracy: 0.7000
# Epoch 00029: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.5028 - accuracy: 0.7018 - val_loss: 0.5253 - val_accuracy: 0.7333
# Epoch 30/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5806 - accuracy: 0.5000
# Epoch 00030: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.5308 - accuracy: 0.6842 - val_loss: 0.5380 - val_accuracy: 0.7333
# Epoch 31/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5841 - accuracy: 0.7000
# Epoch 00031: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4867 - accuracy: 0.7719 - val_loss: 0.5209 - val_accuracy: 0.8000
# Epoch 32/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5263 - accuracy: 0.6000
# Epoch 00032: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.5324 - accuracy: 0.6316 - val_loss: 0.5148 - val_accuracy: 0.7333
# Epoch 33/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5078 - accuracy: 0.8000
# Epoch 00033: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4030 - accuracy: 0.8772 - val_loss: 0.5093 - val_accuracy: 0.8000
# Epoch 34/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5528 - accuracy: 0.7000
# Epoch 00034: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4109 - accuracy: 0.7895 - val_loss: 0.5196 - val_accuracy: 0.8000
# Epoch 35/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5993 - accuracy: 0.7000
# Epoch 00035: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4932 - accuracy: 0.7544 - val_loss: 0.5019 - val_accuracy: 0.8000
# Epoch 36/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.6885 - accuracy: 0.4000
# Epoch 00036: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4711 - accuracy: 0.7018 - val_loss: 0.5063 - val_accuracy: 0.8000
# Epoch 37/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3928 - accuracy: 0.8000
# Epoch 00037: val_accuracy did not improve from 0.80000
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4451 - accuracy: 0.7895 - val_loss: 0.5070 - val_accuracy: 0.8000
# Epoch 38/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5056 - accuracy: 0.6000
# Epoch 00038: val_accuracy improved from 0.80000 to 0.86667, saving model to models/model2_38.h5
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.4192 - accuracy: 0.7895 - val_loss: 0.4821 - val_accuracy: 0.8667
# Epoch 39/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2646 - accuracy: 0.9000
# Epoch 00039: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4004 - accuracy: 0.7895 - val_loss: 0.4777 - val_accuracy: 0.8667
# Epoch 40/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4527 - accuracy: 0.8000
# Epoch 00040: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4338 - accuracy: 0.8246 - val_loss: 0.4748 - val_accuracy: 0.8000
# Epoch 41/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4035 - accuracy: 0.9000
# Epoch 00041: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3995 - accuracy: 0.8070 - val_loss: 0.4641 - val_accuracy: 0.8667
# Epoch 42/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.6006 - accuracy: 0.7000
# Epoch 00042: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4024 - accuracy: 0.8421 - val_loss: 0.4722 - val_accuracy: 0.8000
# Epoch 43/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4714 - accuracy: 0.6000
# Epoch 00043: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4344 - accuracy: 0.7719 - val_loss: 0.4561 - val_accuracy: 0.8667
# Epoch 44/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2386 - accuracy: 0.9000
# Epoch 00044: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3747 - accuracy: 0.8246 - val_loss: 0.4568 - val_accuracy: 0.8000
# Epoch 45/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3896 - accuracy: 0.8000
# Epoch 00045: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4359 - accuracy: 0.7719 - val_loss: 0.4528 - val_accuracy: 0.8667
# Epoch 46/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3090 - accuracy: 0.8000
# Epoch 00046: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3530 - accuracy: 0.8246 - val_loss: 0.4455 - val_accuracy: 0.8667
# Epoch 47/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2487 - accuracy: 1.0000
# Epoch 00047: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3341 - accuracy: 0.8421 - val_loss: 0.4582 - val_accuracy: 0.8000
# Epoch 48/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3489 - accuracy: 0.9000
# Epoch 00048: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4082 - accuracy: 0.7719 - val_loss: 0.4340 - val_accuracy: 0.8667
# Epoch 49/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2633 - accuracy: 0.9000
# Epoch 00049: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3779 - accuracy: 0.8070 - val_loss: 0.4401 - val_accuracy: 0.8667
# Epoch 50/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3074 - accuracy: 0.9000
# Epoch 00050: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3042 - accuracy: 0.8421 - val_loss: 0.4378 - val_accuracy: 0.7333
# Epoch 51/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2374 - accuracy: 1.0000
# Epoch 00051: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3588 - accuracy: 0.8246 - val_loss: 0.4224 - val_accuracy: 0.8667
# Epoch 52/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1705 - accuracy: 0.9000
# Epoch 00052: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.4026 - accuracy: 0.7895 - val_loss: 0.4162 - val_accuracy: 0.8000
# Epoch 53/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3575 - accuracy: 0.9000
# Epoch 00053: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3275 - accuracy: 0.8070 - val_loss: 0.4282 - val_accuracy: 0.7333
# Epoch 54/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3096 - accuracy: 0.9000
# Epoch 00054: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3344 - accuracy: 0.8772 - val_loss: 0.4308 - val_accuracy: 0.8000
# Epoch 55/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5766 - accuracy: 0.6000
# Epoch 00055: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3380 - accuracy: 0.8246 - val_loss: 0.4187 - val_accuracy: 0.8000
# Epoch 56/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3024 - accuracy: 0.9000
# Epoch 00056: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3101 - accuracy: 0.8772 - val_loss: 0.4025 - val_accuracy: 0.8667
# Epoch 57/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4500 - accuracy: 0.8000
# Epoch 00057: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3600 - accuracy: 0.8070 - val_loss: 0.4171 - val_accuracy: 0.8000
# Epoch 58/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3104 - accuracy: 0.9000
# Epoch 00058: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2756 - accuracy: 0.9123 - val_loss: 0.4023 - val_accuracy: 0.8000
# Epoch 59/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3598 - accuracy: 0.8000
# Epoch 00059: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2812 - accuracy: 0.8421 - val_loss: 0.4422 - val_accuracy: 0.7333
# Epoch 60/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1631 - accuracy: 0.9000
# Epoch 00060: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3438 - accuracy: 0.8246 - val_loss: 0.4225 - val_accuracy: 0.8000
# Epoch 61/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2844 - accuracy: 0.9000
# Epoch 00061: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3558 - accuracy: 0.8246 - val_loss: 0.3950 - val_accuracy: 0.8000
# Epoch 62/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1721 - accuracy: 1.0000
# Epoch 00062: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3144 - accuracy: 0.8596 - val_loss: 0.3920 - val_accuracy: 0.8667
# Epoch 63/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3397 - accuracy: 0.8000
# Epoch 00063: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 2ms/sample - loss: 0.2909 - accuracy: 0.8596 - val_loss: 0.3922 - val_accuracy: 0.8667
# Epoch 64/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1293 - accuracy: 0.9000
# Epoch 00064: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2988 - accuracy: 0.8596 - val_loss: 0.3932 - val_accuracy: 0.8000
# Epoch 65/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2432 - accuracy: 0.9000
# Epoch 00065: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3216 - accuracy: 0.8070 - val_loss: 0.3856 - val_accuracy: 0.8667
# Epoch 66/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3227 - accuracy: 0.9000
# Epoch 00066: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2830 - accuracy: 0.8947 - val_loss: 0.3840 - val_accuracy: 0.8667
# Epoch 67/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3333 - accuracy: 0.8000
# Epoch 00067: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3465 - accuracy: 0.8421 - val_loss: 0.3754 - val_accuracy: 0.7333
# Epoch 68/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1619 - accuracy: 1.0000
# Epoch 00068: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2862 - accuracy: 0.8772 - val_loss: 0.3877 - val_accuracy: 0.8667
# Epoch 69/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3741 - accuracy: 0.8000
# Epoch 00069: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3247 - accuracy: 0.8421 - val_loss: 0.3763 - val_accuracy: 0.7333
# Epoch 70/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2113 - accuracy: 1.0000
# Epoch 00070: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3063 - accuracy: 0.8596 - val_loss: 0.3733 - val_accuracy: 0.8667
# Epoch 71/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3186 - accuracy: 0.8000
# Epoch 00071: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2515 - accuracy: 0.8947 - val_loss: 0.3728 - val_accuracy: 0.8000
# Epoch 72/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2445 - accuracy: 0.8000
# Epoch 00072: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2835 - accuracy: 0.8596 - val_loss: 0.3879 - val_accuracy: 0.7333
# Epoch 73/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1620 - accuracy: 1.0000
# Epoch 00073: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2948 - accuracy: 0.8596 - val_loss: 0.3846 - val_accuracy: 0.8667
# Epoch 74/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2786 - accuracy: 0.8000
# Epoch 00074: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3347 - accuracy: 0.7895 - val_loss: 0.3867 - val_accuracy: 0.7333
# Epoch 75/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2491 - accuracy: 0.8000
# Epoch 00075: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3599 - accuracy: 0.8070 - val_loss: 0.3891 - val_accuracy: 0.7333
# Epoch 76/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3597 - accuracy: 0.9000
# Epoch 00076: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2641 - accuracy: 0.8772 - val_loss: 0.3690 - val_accuracy: 0.8000
# Epoch 77/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1790 - accuracy: 0.9000
# Epoch 00077: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3265 - accuracy: 0.8596 - val_loss: 0.3922 - val_accuracy: 0.8000
# Epoch 78/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2603 - accuracy: 0.8000
# Epoch 00078: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2825 - accuracy: 0.8421 - val_loss: 0.3624 - val_accuracy: 0.7333
# Epoch 79/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2869 - accuracy: 0.9000
# Epoch 00079: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2416 - accuracy: 0.8947 - val_loss: 0.3790 - val_accuracy: 0.8667
# Epoch 80/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5243 - accuracy: 0.5000
# Epoch 00080: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3002 - accuracy: 0.8246 - val_loss: 0.3649 - val_accuracy: 0.8000
# Epoch 81/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1035 - accuracy: 1.0000
# Epoch 00081: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2842 - accuracy: 0.8596 - val_loss: 0.3698 - val_accuracy: 0.8667
# Epoch 82/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3665 - accuracy: 0.8000
# Epoch 00082: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2785 - accuracy: 0.8772 - val_loss: 0.3494 - val_accuracy: 0.8667
# Epoch 83/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1760 - accuracy: 1.0000
# Epoch 00083: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2219 - accuracy: 0.9474 - val_loss: 0.3456 - val_accuracy: 0.8000
# Epoch 84/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5840 - accuracy: 0.7000
# Epoch 00084: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3137 - accuracy: 0.8246 - val_loss: 0.3500 - val_accuracy: 0.8667
# Epoch 85/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4046 - accuracy: 0.9000
# Epoch 00085: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2439 - accuracy: 0.9123 - val_loss: 0.3573 - val_accuracy: 0.8000
# Epoch 86/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2684 - accuracy: 0.9000
# Epoch 00086: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2465 - accuracy: 0.8772 - val_loss: 0.3568 - val_accuracy: 0.8667
# Epoch 87/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2989 - accuracy: 0.9000
# Epoch 00087: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2531 - accuracy: 0.8596 - val_loss: 0.3524 - val_accuracy: 0.8667
# Epoch 88/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5088 - accuracy: 0.8000
# Epoch 00088: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3131 - accuracy: 0.8421 - val_loss: 0.3738 - val_accuracy: 0.8000
# Epoch 89/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2260 - accuracy: 1.0000
# Epoch 00089: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2331 - accuracy: 0.8947 - val_loss: 0.3602 - val_accuracy: 0.8667
# Epoch 90/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1464 - accuracy: 1.0000
# Epoch 00090: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2906 - accuracy: 0.8596 - val_loss: 0.3784 - val_accuracy: 0.8000
# Epoch 91/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3015 - accuracy: 0.9000
# Epoch 00091: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2581 - accuracy: 0.8772 - val_loss: 0.3806 - val_accuracy: 0.8000
# Epoch 92/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1077 - accuracy: 1.0000
# Epoch 00092: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2014 - accuracy: 0.9649 - val_loss: 0.3828 - val_accuracy: 0.8667
# Epoch 93/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1798 - accuracy: 0.9000
# Epoch 00093: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2919 - accuracy: 0.8246 - val_loss: 0.3753 - val_accuracy: 0.7333
# Epoch 94/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0942 - accuracy: 1.0000
# Epoch 00094: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3069 - accuracy: 0.8421 - val_loss: 0.3971 - val_accuracy: 0.8000
# Epoch 95/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1220 - accuracy: 1.0000
# Epoch 00095: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2305 - accuracy: 0.9123 - val_loss: 0.3620 - val_accuracy: 0.8667
# Epoch 96/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1335 - accuracy: 0.9000
# Epoch 00096: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2261 - accuracy: 0.8772 - val_loss: 0.3700 - val_accuracy: 0.8000
# Epoch 97/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1261 - accuracy: 1.0000
# Epoch 00097: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3249 - accuracy: 0.8772 - val_loss: 0.3505 - val_accuracy: 0.8667
# Epoch 98/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1667 - accuracy: 1.0000
# Epoch 00098: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2508 - accuracy: 0.9123 - val_loss: 0.3591 - val_accuracy: 0.8667
# Epoch 99/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2415 - accuracy: 0.9000
# Epoch 00099: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2384 - accuracy: 0.9298 - val_loss: 0.4573 - val_accuracy: 0.8000
# Epoch 100/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2672 - accuracy: 0.8000
# Epoch 00100: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2348 - accuracy: 0.8947 - val_loss: 0.3566 - val_accuracy: 0.8667
# Epoch 101/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2003 - accuracy: 0.9000
# Epoch 00101: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2107 - accuracy: 0.9298 - val_loss: 0.3507 - val_accuracy: 0.7333
# Epoch 102/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1365 - accuracy: 1.0000
# Epoch 00102: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2710 - accuracy: 0.9123 - val_loss: 0.3760 - val_accuracy: 0.8000
# Epoch 103/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2834 - accuracy: 0.9000
# Epoch 00103: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2404 - accuracy: 0.8947 - val_loss: 0.3541 - val_accuracy: 0.8000
# Epoch 104/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2675 - accuracy: 0.9000
# Epoch 00104: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2544 - accuracy: 0.8947 - val_loss: 0.3307 - val_accuracy: 0.8000
# Epoch 105/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0332 - accuracy: 1.0000
# Epoch 00105: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2400 - accuracy: 0.8947 - val_loss: 0.3565 - val_accuracy: 0.8000
# Epoch 106/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3301 - accuracy: 0.8000
# Epoch 00106: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1747 - accuracy: 0.9123 - val_loss: 0.3314 - val_accuracy: 0.8000
# Epoch 107/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1144 - accuracy: 1.0000
# Epoch 00107: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2288 - accuracy: 0.9123 - val_loss: 0.3195 - val_accuracy: 0.8000
# Epoch 108/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1883 - accuracy: 0.9000
# Epoch 00108: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2439 - accuracy: 0.8772 - val_loss: 0.3200 - val_accuracy: 0.8000
# Epoch 109/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1177 - accuracy: 0.9000
# Epoch 00109: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2095 - accuracy: 0.8947 - val_loss: 0.3093 - val_accuracy: 0.8000
# Epoch 110/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2579 - accuracy: 0.9000
# Epoch 00110: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1931 - accuracy: 0.9123 - val_loss: 0.3128 - val_accuracy: 0.8000
# Epoch 111/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1298 - accuracy: 0.9000
# Epoch 00111: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1662 - accuracy: 0.9649 - val_loss: 0.3154 - val_accuracy: 0.8000
# Epoch 112/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1337 - accuracy: 1.0000
# Epoch 00112: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1936 - accuracy: 0.9649 - val_loss: 0.3161 - val_accuracy: 0.8000
# Epoch 113/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1759 - accuracy: 0.9000
# Epoch 00113: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1902 - accuracy: 0.9298 - val_loss: 0.3180 - val_accuracy: 0.8000
# Epoch 114/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1485 - accuracy: 1.0000
# Epoch 00114: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2231 - accuracy: 0.8772 - val_loss: 0.3145 - val_accuracy: 0.8000
# Epoch 115/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3939 - accuracy: 0.7000
# Epoch 00115: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2441 - accuracy: 0.8947 - val_loss: 0.3518 - val_accuracy: 0.8000
# Epoch 116/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4318 - accuracy: 0.8000
# Epoch 00116: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.3543 - accuracy: 0.8246 - val_loss: 0.3352 - val_accuracy: 0.8667
# Epoch 117/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1708 - accuracy: 1.0000
# Epoch 00117: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2049 - accuracy: 0.9298 - val_loss: 0.3664 - val_accuracy: 0.8000
# Epoch 118/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3708 - accuracy: 0.8000
# Epoch 00118: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2078 - accuracy: 0.9123 - val_loss: 0.3089 - val_accuracy: 0.8000
# Epoch 119/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3125 - accuracy: 0.8000
# Epoch 00119: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2044 - accuracy: 0.8772 - val_loss: 0.3108 - val_accuracy: 0.8000
# Epoch 120/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2361 - accuracy: 0.9000
# Epoch 00120: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2537 - accuracy: 0.8772 - val_loss: 0.3333 - val_accuracy: 0.8000
# Epoch 121/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0877 - accuracy: 1.0000
# Epoch 00121: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1741 - accuracy: 0.9474 - val_loss: 0.3363 - val_accuracy: 0.8000
# Epoch 122/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1571 - accuracy: 1.0000
# Epoch 00122: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1898 - accuracy: 0.9298 - val_loss: 0.3805 - val_accuracy: 0.8000
# Epoch 123/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2591 - accuracy: 0.9000
# Epoch 00123: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2563 - accuracy: 0.8947 - val_loss: 0.3134 - val_accuracy: 0.8000
# Epoch 124/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1907 - accuracy: 1.0000
# Epoch 00124: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2182 - accuracy: 0.9123 - val_loss: 0.3272 - val_accuracy: 0.8667
# Epoch 125/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2801 - accuracy: 0.9000
# Epoch 00125: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1608 - accuracy: 0.9474 - val_loss: 0.3407 - val_accuracy: 0.8000
# Epoch 126/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3190 - accuracy: 0.8000
# Epoch 00126: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2148 - accuracy: 0.9123 - val_loss: 0.3130 - val_accuracy: 0.8000
# Epoch 127/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0925 - accuracy: 1.0000
# Epoch 00127: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1650 - accuracy: 0.9298 - val_loss: 0.3432 - val_accuracy: 0.8000
# Epoch 128/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1325 - accuracy: 0.9000
# Epoch 00128: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1769 - accuracy: 0.9474 - val_loss: 0.3181 - val_accuracy: 0.8000
# Epoch 129/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2103 - accuracy: 1.0000
# Epoch 00129: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1886 - accuracy: 0.9298 - val_loss: 0.3078 - val_accuracy: 0.8000
# Epoch 130/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0803 - accuracy: 1.0000
# Epoch 00130: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1946 - accuracy: 0.9298 - val_loss: 0.3068 - val_accuracy: 0.8667
# Epoch 131/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2329 - accuracy: 0.9000
# Epoch 00131: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2903 - accuracy: 0.8596 - val_loss: 0.3137 - val_accuracy: 0.8000
# Epoch 132/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2321 - accuracy: 0.9000
# Epoch 00132: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1499 - accuracy: 0.9649 - val_loss: 0.4398 - val_accuracy: 0.8000
# Epoch 133/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2278 - accuracy: 0.9000
# Epoch 00133: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1571 - accuracy: 0.9298 - val_loss: 0.3168 - val_accuracy: 0.8000
# Epoch 134/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2631 - accuracy: 0.8000
# Epoch 00134: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2537 - accuracy: 0.8947 - val_loss: 0.3148 - val_accuracy: 0.7333
# Epoch 135/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1484 - accuracy: 1.0000
# Epoch 00135: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1998 - accuracy: 0.8947 - val_loss: 0.3408 - val_accuracy: 0.8000
# Epoch 136/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2522 - accuracy: 0.9000
# Epoch 00136: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1518 - accuracy: 0.9474 - val_loss: 0.3268 - val_accuracy: 0.7333
# Epoch 137/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4306 - accuracy: 0.7000
# Epoch 00137: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1845 - accuracy: 0.9123 - val_loss: 0.3611 - val_accuracy: 0.8667
# Epoch 138/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1703 - accuracy: 0.9000
# Epoch 00138: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1965 - accuracy: 0.9123 - val_loss: 0.3838 - val_accuracy: 0.8000
# Epoch 139/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2949 - accuracy: 0.9000
# Epoch 00139: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2983 - accuracy: 0.8947 - val_loss: 0.3142 - val_accuracy: 0.8667
# Epoch 140/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0955 - accuracy: 0.9000
# Epoch 00140: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2195 - accuracy: 0.8596 - val_loss: 0.3084 - val_accuracy: 0.8000
# Epoch 141/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0634 - accuracy: 1.0000
# Epoch 00141: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2628 - accuracy: 0.8947 - val_loss: 0.2888 - val_accuracy: 0.8667
# Epoch 142/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0440 - accuracy: 1.0000
# Epoch 00142: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1785 - accuracy: 0.9474 - val_loss: 0.2986 - val_accuracy: 0.8000
# Epoch 143/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0853 - accuracy: 1.0000
# Epoch 00143: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1451 - accuracy: 0.9298 - val_loss: 0.2846 - val_accuracy: 0.8667
# Epoch 144/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0566 - accuracy: 1.0000
# Epoch 00144: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1836 - accuracy: 0.9474 - val_loss: 0.2852 - val_accuracy: 0.8667
# Epoch 145/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1559 - accuracy: 1.0000
# Epoch 00145: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1575 - accuracy: 0.9123 - val_loss: 0.2844 - val_accuracy: 0.8667
# Epoch 146/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1507 - accuracy: 0.9000
# Epoch 00146: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2186 - accuracy: 0.8947 - val_loss: 0.2856 - val_accuracy: 0.8667
# Epoch 147/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0957 - accuracy: 1.0000
# Epoch 00147: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1923 - accuracy: 0.9298 - val_loss: 0.3169 - val_accuracy: 0.8000
# Epoch 148/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1297 - accuracy: 0.9000
# Epoch 00148: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1754 - accuracy: 0.9298 - val_loss: 0.2966 - val_accuracy: 0.8000
# Epoch 149/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1953 - accuracy: 0.9000
# Epoch 00149: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1344 - accuracy: 0.9649 - val_loss: 0.3008 - val_accuracy: 0.8000
# Epoch 150/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2006 - accuracy: 0.9000
# Epoch 00150: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1827 - accuracy: 0.9123 - val_loss: 0.3192 - val_accuracy: 0.8000
# Epoch 151/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2449 - accuracy: 0.9000
# Epoch 00151: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1791 - accuracy: 0.9474 - val_loss: 0.2963 - val_accuracy: 0.8000
# Epoch 152/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0827 - accuracy: 1.0000
# Epoch 00152: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1702 - accuracy: 0.9123 - val_loss: 0.2928 - val_accuracy: 0.8667
# Epoch 153/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0796 - accuracy: 1.0000
# Epoch 00153: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2028 - accuracy: 0.9474 - val_loss: 0.3006 - val_accuracy: 0.8000
# Epoch 154/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1090 - accuracy: 1.0000
# Epoch 00154: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1780 - accuracy: 0.9298 - val_loss: 0.2935 - val_accuracy: 0.8667
# Epoch 155/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1384 - accuracy: 1.0000
# Epoch 00155: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1609 - accuracy: 0.9649 - val_loss: 0.3977 - val_accuracy: 0.8000
# Epoch 156/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2363 - accuracy: 0.8000
# Epoch 00156: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2815 - accuracy: 0.8596 - val_loss: 0.3135 - val_accuracy: 0.8000
# Epoch 157/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1325 - accuracy: 0.9000
# Epoch 00157: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1480 - accuracy: 0.9298 - val_loss: 0.3711 - val_accuracy: 0.8000
# Epoch 158/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1195 - accuracy: 1.0000
# Epoch 00158: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1643 - accuracy: 0.9474 - val_loss: 0.3597 - val_accuracy: 0.8000
# Epoch 159/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1932 - accuracy: 0.9000
# Epoch 00159: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1498 - accuracy: 0.9474 - val_loss: 0.3103 - val_accuracy: 0.7333
# Epoch 160/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0471 - accuracy: 1.0000
# Epoch 00160: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1907 - accuracy: 0.8947 - val_loss: 0.4811 - val_accuracy: 0.8667
# Epoch 161/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4130 - accuracy: 0.7000
# Epoch 00161: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2007 - accuracy: 0.9298 - val_loss: 0.3184 - val_accuracy: 0.8000
# Epoch 162/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0947 - accuracy: 1.0000
# Epoch 00162: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2207 - accuracy: 0.9123 - val_loss: 0.5575 - val_accuracy: 0.8667
# Epoch 163/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.5663 - accuracy: 0.7000
# Epoch 00163: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2669 - accuracy: 0.8947 - val_loss: 0.3978 - val_accuracy: 0.8000
# Epoch 164/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0685 - accuracy: 1.0000
# Epoch 00164: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1999 - accuracy: 0.9123 - val_loss: 0.3514 - val_accuracy: 0.8000
# Epoch 165/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0477 - accuracy: 1.0000
# Epoch 00165: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1506 - accuracy: 0.9474 - val_loss: 0.4256 - val_accuracy: 0.8000
# Epoch 166/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2381 - accuracy: 0.9000
# Epoch 00166: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1936 - accuracy: 0.9298 - val_loss: 0.3379 - val_accuracy: 0.7333
# Epoch 167/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1491 - accuracy: 0.9000
# Epoch 00167: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2255 - accuracy: 0.8772 - val_loss: 0.5827 - val_accuracy: 0.8667
# Epoch 168/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2916 - accuracy: 0.8000
# Epoch 00168: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1739 - accuracy: 0.9123 - val_loss: 0.3431 - val_accuracy: 0.7333
# Epoch 169/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4007 - accuracy: 0.9000
# Epoch 00169: val_accuracy did not improve from 0.86667
# ...
# Epoch 195/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0177 - accuracy: 1.0000
# Epoch 00195: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1576 - accuracy: 0.9123 - val_loss: 0.4294 - val_accuracy: 0.8000
# Epoch 196/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0796 - accuracy: 1.0000
# Epoch 00196: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1555 - accuracy: 0.9474 - val_loss: 0.4409 - val_accuracy: 0.8000
# Epoch 197/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3207 - accuracy: 0.7000
# Epoch 00197: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1516 - accuracy: 0.9123 - val_loss: 0.5300 - val_accuracy: 0.8000
# Epoch 198/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2963 - accuracy: 0.9000
# Epoch 00198: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1731 - accuracy: 0.9298 - val_loss: 0.5933 - val_accuracy: 0.8000
# Epoch 199/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1638 - accuracy: 0.9000
# Epoch 00199: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1526 - accuracy: 0.9474 - val_loss: 0.4338 - val_accuracy: 0.8000
# Epoch 200/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1692 - accuracy: 0.9000
# Epoch 00200: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1467 - accuracy: 0.9649 - val_loss: 0.5259 - val_accuracy: 0.8000
# Epoch 201/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2571 - accuracy: 0.8000
# Epoch 00201: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1279 - accuracy: 0.9474 - val_loss: 0.5163 - val_accuracy: 0.8000
# Epoch 202/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1656 - accuracy: 1.0000
# Epoch 00202: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1349 - accuracy: 0.9649 - val_loss: 0.4715 - val_accuracy: 0.8000
# Epoch 203/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1440 - accuracy: 0.9000
# Epoch 00203: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1504 - accuracy: 0.9474 - val_loss: 0.3952 - val_accuracy: 0.8000
# Epoch 204/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0345 - accuracy: 1.0000
# Epoch 00204: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1223 - accuracy: 0.9474 - val_loss: 0.4348 - val_accuracy: 0.8000
# Epoch 205/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2939 - accuracy: 0.9000
# Epoch 00205: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1655 - accuracy: 0.9474 - val_loss: 0.3789 - val_accuracy: 0.8000
# Epoch 206/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0903 - accuracy: 1.0000
# Epoch 00206: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1273 - accuracy: 0.9649 - val_loss: 0.4054 - val_accuracy: 0.8000
# Epoch 207/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2233 - accuracy: 0.9000
# Epoch 00207: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1482 - accuracy: 0.9298 - val_loss: 0.3306 - val_accuracy: 0.8000
# Epoch 208/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3768 - accuracy: 0.7000
# Epoch 00208: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2110 - accuracy: 0.8596 - val_loss: 0.6848 - val_accuracy: 0.8000
# Epoch 209/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1491 - accuracy: 0.9000
# Epoch 00209: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1954 - accuracy: 0.8947 - val_loss: 0.3616 - val_accuracy: 0.8000
# Epoch 210/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 00210: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1854 - accuracy: 0.8947 - val_loss: 0.3956 - val_accuracy: 0.8000
# Epoch 211/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3038 - accuracy: 0.9000
# Epoch 00211: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2211 - accuracy: 0.9123 - val_loss: 0.4172 - val_accuracy: 0.8000
# Epoch 212/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0363 - accuracy: 1.0000
# Epoch 00212: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1618 - accuracy: 0.9474 - val_loss: 0.3738 - val_accuracy: 0.7333
# Epoch 213/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1345 - accuracy: 1.0000
# Epoch 00213: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1831 - accuracy: 0.9298 - val_loss: 0.3231 - val_accuracy: 0.8000
# Epoch 214/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1389 - accuracy: 0.9000
# Epoch 00214: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1797 - accuracy: 0.9123 - val_loss: 0.3297 - val_accuracy: 0.8000
# Epoch 215/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1533 - accuracy: 0.9000
# Epoch 00215: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1415 - accuracy: 0.9298 - val_loss: 0.3073 - val_accuracy: 0.8667
# Epoch 216/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2916 - accuracy: 0.8000
# Epoch 00216: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1560 - accuracy: 0.9123 - val_loss: 0.5811 - val_accuracy: 0.8667
# Epoch 217/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2844 - accuracy: 0.9000
# Epoch 00217: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1221 - accuracy: 0.9825 - val_loss: 0.4371 - val_accuracy: 0.8000
# Epoch 218/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0370 - accuracy: 1.0000
# Epoch 00218: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0973 - accuracy: 0.9649 - val_loss: 0.4510 - val_accuracy: 0.8000
# Epoch 219/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1690 - accuracy: 0.9000
# Epoch 00219: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1755 - accuracy: 0.8947 - val_loss: 0.5138 - val_accuracy: 0.8000
# Epoch 220/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2158 - accuracy: 0.9000
# Epoch 00220: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1804 - accuracy: 0.9298 - val_loss: 0.3349 - val_accuracy: 0.8000
# Epoch 221/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.3961 - accuracy: 0.8000
# Epoch 00221: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1647 - accuracy: 0.9123 - val_loss: 0.4178 - val_accuracy: 0.8000
# Epoch 222/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0335 - accuracy: 1.0000
# Epoch 00222: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1205 - accuracy: 0.9474 - val_loss: 0.3552 - val_accuracy: 0.8000
# Epoch 223/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0486 - accuracy: 1.0000
# Epoch 00223: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1150 - accuracy: 0.9474 - val_loss: 0.3329 - val_accuracy: 0.8000
# Epoch 224/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1628 - accuracy: 0.9000
# Epoch 00224: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1878 - accuracy: 0.9123 - val_loss: 0.3070 - val_accuracy: 0.8667
# Epoch 225/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0770 - accuracy: 1.0000
# Epoch 00225: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1077 - accuracy: 0.9474 - val_loss: 0.3440 - val_accuracy: 0.8000
# Epoch 226/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1422 - accuracy: 0.9000
# Epoch 00226: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1166 - accuracy: 0.9474 - val_loss: 0.3980 - val_accuracy: 0.8000
# Epoch 227/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1090 - accuracy: 0.9000
# Epoch 00227: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1479 - accuracy: 0.8947 - val_loss: 0.3320 - val_accuracy: 0.8000
# Epoch 228/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0294 - accuracy: 1.0000
# Epoch 00228: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1174 - accuracy: 0.9474 - val_loss: 0.4493 - val_accuracy: 0.8000
# Epoch 229/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0223 - accuracy: 1.0000
# Epoch 00229: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1409 - accuracy: 0.9474 - val_loss: 0.3298 - val_accuracy: 0.8000
# Epoch 230/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1258 - accuracy: 0.9000
# Epoch 00230: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1851 - accuracy: 0.9123 - val_loss: 0.4484 - val_accuracy: 0.8000
# Epoch 231/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1710 - accuracy: 0.9000
# Epoch 00231: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1594 - accuracy: 0.9123 - val_loss: 0.4744 - val_accuracy: 0.8000
# Epoch 232/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0906 - accuracy: 1.0000
# Epoch 00232: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0751 - accuracy: 0.9825 - val_loss: 0.3350 - val_accuracy: 0.7333
# Epoch 233/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4190 - accuracy: 0.7000
# Epoch 00233: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1545 - accuracy: 0.9123 - val_loss: 0.4006 - val_accuracy: 0.8000
# Epoch 234/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1468 - accuracy: 0.9000
# Epoch 00234: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1130 - accuracy: 0.9474 - val_loss: 0.4084 - val_accuracy: 0.8000
# Epoch 235/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0300 - accuracy: 1.0000
# Epoch 00235: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.0872 - accuracy: 0.9649 - val_loss: 0.4362 - val_accuracy: 0.8000
# Epoch 236/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0367 - accuracy: 1.0000
# Epoch 00236: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1287 - accuracy: 0.9298 - val_loss: 0.4444 - val_accuracy: 0.8000
# Epoch 237/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0962 - accuracy: 1.0000
# Epoch 00237: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1188 - accuracy: 0.9474 - val_loss: 0.4108 - val_accuracy: 0.8000
# Epoch 238/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0699 - accuracy: 1.0000
# Epoch 00238: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1145 - accuracy: 0.9474 - val_loss: 0.4008 - val_accuracy: 0.8000
# Epoch 239/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1959 - accuracy: 0.9000
# Epoch 00239: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1183 - accuracy: 0.9474 - val_loss: 0.4510 - val_accuracy: 0.8000
# Epoch 240/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0950 - accuracy: 0.9000
# Epoch 00240: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1389 - accuracy: 0.8772 - val_loss: 0.5318 - val_accuracy: 0.8000
# Epoch 241/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1494 - accuracy: 0.9000
# Epoch 00241: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1157 - accuracy: 0.9474 - val_loss: 0.6680 - val_accuracy: 0.8667
# Epoch 242/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0849 - accuracy: 0.9000
# Epoch 00242: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1173 - accuracy: 0.9474 - val_loss: 0.4009 - val_accuracy: 0.8000
# Epoch 243/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0181 - accuracy: 1.0000
# Epoch 00243: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1815 - accuracy: 0.9298 - val_loss: 0.5916 - val_accuracy: 0.8000
# Epoch 244/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0509 - accuracy: 1.0000
# Epoch 00244: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1423 - accuracy: 0.9474 - val_loss: 0.6191 - val_accuracy: 0.8000
# Epoch 245/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1949 - accuracy: 0.8000
# Epoch 00245: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1419 - accuracy: 0.9123 - val_loss: 0.3735 - val_accuracy: 0.8000
# Epoch 246/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.2276 - accuracy: 0.9000
# Epoch 00246: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1607 - accuracy: 0.9298 - val_loss: 0.6867 - val_accuracy: 0.8667
# Epoch 247/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1910 - accuracy: 0.9000
# Epoch 00247: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1189 - accuracy: 0.9474 - val_loss: 0.4103 - val_accuracy: 0.8000
# Epoch 248/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.0413 - accuracy: 1.0000
# Epoch 00248: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1280 - accuracy: 0.9649 - val_loss: 0.4996 - val_accuracy: 0.8000
# Epoch 249/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.1084 - accuracy: 0.9000
# Epoch 00249: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.1088 - accuracy: 0.9298 - val_loss: 0.5848 - val_accuracy: 0.8000
# Epoch 250/250
# 10/57 [====>.........................] - ETA: 0s - loss: 0.4229 - accuracy: 0.8000
# Epoch 00250: val_accuracy did not improve from 0.86667
# 57/57 [==============================] - 0s 1ms/sample - loss: 0.2363 - accuracy: 0.9123 - val_loss: 0.4742 - val_accuracy: 0.8000
# Training completed in time:  0:00:19.290023

# %% [markdown]
# **Plot accuracies and losses**

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Teste
#
# Lembrando que estamos utilizando o mesmo conjunto de validacão, que a princípio, pode incluir instâncias do conjunto de treinamento: o dataset utilizado foi gerado com corte de áudio, então alguns trechos do mesmo áudio podem estar presentes em ambos os conjuntos de treinamento e teste.
# Por ora deixamos assim já que estamos realizando uma investigacão inicial.

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.9649123
# Testing Accuracy:  0.8

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=2 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names = ['Healthy', 'Pneumonia']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.75      0.86      0.80         7
#    Pneumonia       0.86      0.75      0.80         8
#
#     accuracy                           0.80        15
#    macro avg       0.80      0.80      0.80        15
# weighted avg       0.81      0.80      0.80        15

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[6 1]
#  [2 6]]

# %%
import itertools
def plot_confusion_matrix(cm, unique_labels, show=True, output=None,
                          title='Confusion matrix', cmap=plt.cm.Oranges):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(cm.shape[1])
    plt.xticks(tick_marks, rotation=45)
    ax = plt.gca()
    ax.set_xticklabels((ax.get_xticks() + 1).astype(str))
    plt.yticks(tick_marks)

    ax.set_xticklabels(unique_labels)
    ax.set_yticklabels(unique_labels)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], '.1f'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if show:
        plt.show()
    if output is not None:
        plt.savefig(output)
    plt.close()
    return output

# %%
plot_confusion_matrix(confusion_matrix(y_testclass, classpreds), unique_labels=["Healthy", "Pneumonia"])
